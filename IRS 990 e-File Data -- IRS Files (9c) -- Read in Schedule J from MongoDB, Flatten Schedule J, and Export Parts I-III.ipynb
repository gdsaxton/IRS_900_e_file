# %% [markdown]
# # Overview
#
# Based off *IRS 990 e-File Data -- Excise Tax Project (1) -- Read in Schedule J from MongoDB, Flatten Schedule J, and Export Parts I-III.ipynb*
#
# In this notebook I read in Schedule J from MongoDB, Flatten the Schedule J columns, and Export Parts I-III in three separate files.
#
# Note that I create a combined file out of AWS-based filings in ``filings_990`` and the new IRS-based filings in ``filings_990_y``
#
# Saved files:
# - *Schedule J (non-flattened).pkl.gz*
# - *Schedule J (flattened).pkl.gz*
# - *Schedule J (Part II).pkl.gz*
# - *Schedule J (Part III).pkl.gz*
# - *Schedule J (Part I).pkl.gz*
#
# Note that in the original notebook -- *IRS 990 e-File Data -- Excise Tax Project (1) -- Read in Schedule J from MongoDB, Flatten Schedule J, and Export Parts I-III.ipynb* I also read in a Schedule J concordance file, created *MongoDB_Name* column for new variables, then saved the following version:
# - *concordance - Schedule J.xlsx*
#
# I had then also opened the file in Excel and created separate versions for Part I, Part II, and Part III, respectively. I  then tested the files in the follow-up notebooks and finalized the concordance files and saved new Excel and pickled versions.
#
# *Note*:
# - When flattening *Schedule J* using *json_normalize*, be sure to set 'max_level=0'. Otherwise, what was happening is that, if there are multiple people in Part II (and thus a *list*), then it will put the data in the *Form990ScheduleJPartII* or *RltdOrgOfficerTrstKeyEmplGrp* column. However, if there is only one person (and thus a *dictionary*), then it creates separate columns such as *Form990ScheduleJPartII.TotalCompensationFilingOrg* and *Form990ScheduleJPartII.TotalCompensationRelatedOrgs*.

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from pandas import Series

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
from platform import python_version
print(python_version())
# Out:
# 3.10.11

# %%
#http://pandas.pydata.org/pandas-docs/stable/options.html
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 250)

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)

# %% [markdown]
# #### Set working directory

# %%
#cd '/Users/gsaxton/Dropbox/990 e-file data'

# %%
pwd
# Out:
# 'C:\\Users\\Gregory\\Jupyter_Notebooks'

# %%
cd "C:\\Users\\Gregory\\IRS 990 Control Variables\\"
# Out:
# C:\Users\Gregory\IRS 990 Control Variables

# %% [markdown]
# # Load Packages and Connect to MongoDB

# %%
import sys
import time
import json

# %%
import pymongo
from pymongo import MongoClient
client = MongoClient()

# %%
print(pymongo.__version__)
# Out:
# 4.3.3

# %%
MongoClient().list_database_names()
# Out:
# ['ICIJ',
#  'OWS',
#  'SMC',
#  'admin',
#  'cashtags',
#  'config',
#  'enron',
#  'irs_990_db',
#  'irs_990_db_v2',
#  'local',
#  'paradisepapers',
#  'sec',
#  'sp1500',
#  'sp500']

# %%
# DEFINE MY mongoDB DATABASE
db = client['irs_990_db']

# DEFINE MY COLLECTION HOUSING 990 DATA
filings_990 = db['filings_990']

# %%
#dfj[dfj['URL']=='https://s3.amazonaws.com/irs-form-990/201423149349302877_public.xml']

# %%
db.filings_990.find_one({'URL' : "https://s3.amazonaws.com/irs-form-990/201423149349302877_public.xml" })
# Out:
# {'_id': ObjectId('5d04714578ffca27b430a8a1'),
#  'OrganizationName': 'COLUMBUS ELECTRIC COOPERATIVE INC',
#  'ObjectId': '201423149349302877',
#  'URL': 'https://s3.amazonaws.com/irs-form-990/201423149349302877_public.xml',
#  'SubmittedOn': '2014-12-04',
#  'DLN': '93493314028774',
#  'LastUpdated': '2016-03-21T17:23:53',
#  'TaxPeriod': '201312',
#  'FormType': '990',
#  'EIN': '850094212',
#  '@xmlns': 'http://www.irs.gov/efile',
#  '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#  '@xsi:schemaLocation': 'http://www.irs.gov/efile',
#  '@returnVersion': '2013v3.0',
#  'ReturnHeader': {'@binaryAttachmentCnt': '0',
#   'ReturnTs': '2014-11-10T17:15:36-06:00',
#   'TaxPeriodEndDt': '2013-12-31',
#   'PreparerFirmGrp': {'PreparerFirmEIN': '750882037',
#    'PreparerFirmName': {'BusinessNameLine1': 'BOLINGER SEGARS GILBERT AND MOSS LLP'},
#    'PreparerUSAddress': {'AddressLine1': '8215 NASHVILLE AVENUE',
#     'City': 'LUBBOCK',
#     'State': 'TX',
#     'ZIPCode': '79423'}},
#   'ReturnTypeCd': '990',
#   'TaxPeriodBeginDt': '2013-01-01',
#   'Filer': {'EIN': '850094212',
#    'BusinessName': {'BusinessNameLine1': 'COLUMBUS ELECTRIC COOPERATIVE INC'},
#    'BusinessNameControlTxt': 'COLU',
#    'PhoneNum': '5755468838',
#    'USAddress': {'AddressLine1': 'PO BOX 631',
#     'City': 'DEMING',
#     'State': 'NM',
#     'ZIPCode': '880310631'}},
#   'BusinessOfficerGrp': {'PersonNm': 'CHRISTOPHER MARTINEZ',
#    'PersonTitleTxt': 'GENERAL MANAGER',
#    'PhoneNum': '5755468838',
#    'SignatureDt': '2014-10-31',
#    'DiscussWithPaidPreparerInd': '1'},
#   'PreparerPersonGrp': {'PreparerPersonNm': 'Matt R Willis',
#    'PTIN': 'P00419741',
#    'PhoneNum': '8067473806',
#    'PreparationDt': '2014-10-31',
#    'SelfEmployedInd': 'X'},
#   'TaxYr': '2013',
#   'BuildTS': '2015-11-30 17:44:51Z'},
#  '@documentCount': '6',
#  'IRS990ScheduleD': {'@documentId': 'RetDoc1040000001',
#   'LandGrp': {'OtherCostOrOtherBasisAmt': '39492', 'BookValueAmt': '39492'},
#   'BuildingsGrp': {'OtherCostOrOtherBasisAmt': '1187862',
#    'DepreciationAmt': '687419',
#    'BookValueAmt': '500443'},
#   'EquipmentGrp': {'OtherCostOrOtherBasisAmt': '38484972',
#    'DepreciationAmt': '15309238',
#    'BookValueAmt': '23175734'},
#   'OtherLandBuildingsGrp': {'OtherCostOrOtherBasisAmt': '649908',
#    'BookValueAmt': '649908'},
#   'TotalBookValueLandBuildingsAmt': '24365577',
#   'InvstProgramRelatedOrgGrp': [{'Desc': 'PATRONAGE CAPITAL - CFC',
#     'BookValueAmt': '72971',
#     'MethodValuationCd': 'C'},
#    {'Desc': 'PATRONAGE CAPITAL - FEDERATED',
#     'BookValueAmt': '65519',
#     'MethodValuationCd': 'C'},
#    {'Desc': 'PATRONAGE CAPITAL - OTHER',
#     'BookValueAmt': '18131',
#     'MethodValuationCd': 'C'},
#    {'Desc': 'PATRONAGE CAPITAL - COBANK',
#     'BookValueAmt': '20905',
#     'MethodValuationCd': 'C'},
#    {'Desc': 'CAPITAL TERM CERTIFICATES - CFC',
#     'BookValueAmt': '314922',
#     'MethodValuationCd': 'C'},
#    {'Desc': 'PATRONAGE CAPITAL - TRI-STATE',
#     'BookValueAmt': '3410626',
#     'MethodValuationCd': 'C'},
#    {'Desc': 'MEMBERSHIPS', 'BookValueAmt': '1220', 'MethodValuationCd': 'C'},
#    {'Desc': 'OTHER INVESTMENTS',
#     'BookValueAmt': '7665',
#     'MethodValuationCd': 'C'},
#    {'Desc': 'WUESC PATRONAGE CAPITAL',
#     'BookValueAmt': '16088',
#     'MethodValuationCd': 'C'}],
#   'TotalBookValueProgramRltdAmt': '3928047',
#   'OtherAssetsOrgGrp': [{'Desc': 'OTHER CURRENT & ACCRUED ASSETS',
#     'BookValueAmt': '10729'},
#    {'Desc': 'MISCELLANEOUS DEFERRED DEBITS', 'BookValueAmt': '1344753'},
#    {'Desc': 'REGULATORY ASSETS', 'BookValueAmt': '496867'}],
#   'TotalBookValueOtherAssetsAmt': '1852349',
#   'OtherLiabilitiesOrgGrp': [{'Desc': 'OTHER CURRENT AND ACCRUED LIABILITIES',
#     'Amt': '156443'},
#    {'Desc': 'CUSTOMER DEPOSITS', 'Amt': '334066'},
#    {'Desc': 'DEFERRED CREDITS AND OTHER ACCRUED LIABILITIES', 'Amt': '173061'},
#    {'Desc': 'ACCRUED EMPLOYEE COMPENSATED ABSENCES', 'Amt': '198506'},
#    {'Desc': 'ACCUMULATED PROVISION FOR PENSION & BENEFITS', 'Amt': '176512'}],
#   'TotalLiabilityAmt': '1038588',
#   'FootnoteTextInd': 'X',
#   'SupplementalInformationDetail': {'FormAndLineReferenceDesc': 'Part X, Line 2:',
#    'ExplanationTxt': 'THE COOPERATIVE HAS ADOPTED THE "UNCERTAIN TAX POSITIONS" PROVISIONS OF ACCOUNTING PRINCIPLES GENERALLY ACCEPTED IN THE UNITED STATES OF AMERICA. THE PRIMARY TAX POSITION OF THE COOPERATIVE IS ITS FILING STATUS AS A TAX EXEMPT ENTITY. THE COOPERATIVE DETERMINED THAT IT IS MORE LIKELY THAN NOT THAT THEIR TAX POSITIONS WILL BE SUSTAINED UPON EXAMINATION BY THE INTERNAL REVENUE SERVICE (IRS), OR OTHER STATE TAXING AUTHORITY AND THAT ALL TAX BENEFITS ARE LIKELY TO BE REALIZED UPON SETTLEMENT WITH TAXING AUTHORITIES.'}},
#  'IRS990ScheduleJ': {'@documentId': 'RetDoc1042400001',
#   'ClubDuesOrFeesInd': 'X',
#   'WrittenPolicyRefTAndEExpnssInd': '1',
#   'SubstantiationRequiredInd': '1',
#   'BoardOrCommitteeApprovalInd': 'X',
#   'SeverancePaymentInd': '0',
#   'SupplementalNonqualRtrPlanInd': '0',
#   'EquityBasedCompArrngmInd': '0',
#   'RltdOrgOfficerTrstKeyEmplGrp': {'PersonNm': 'CHRISTOPHER MARTINEZ',
#    'TitleTxt': 'GENERAL MANAGER',
#    'BaseCompensationFilingOrgAmt': '88508',
#    'CompensationBasedOnRltdOrgsAmt': '0',
#    'BonusFilingOrganizationAmount': '7500',
#    'BonusRelatedOrganizationsAmt': '0',
#    'OtherCompensationFilingOrgAmt': '12956',
#    'OtherCompensationRltdOrgsAmt': '0',
#    'DeferredCompensationFlngOrgAmt': '42652',
#    'DeferredCompRltdOrgsAmt': '0',
#    'NontaxableBenefitsFilingOrgAmt': '24011',
#    'NontaxableBenefitsRltdOrgsAmt': '0',
#    'TotalCompensationFilingOrgAmt': '175627',
#    'TotalCompensationRltdOrgsAmt': '0',
#    'CompReportPrior990FilingOrgAmt': '0',
#    'CompReportPrior990RltdOrgsAmt': '0'},
#   'SupplementalInformationDetail': [{'FormAndLineReferenceDesc': 'Part I, Line 1a',
#     'ExplanationTxt': "THE COOPERATIVE PAYS HEALTH CLUB DUES AFTER THE FIRST $50. THIS IS PART OF THE COOPERATIVE'S WELLNESS PROGRAM AND IS COMPLETELY VOLUNTARY. THE COOPERATIVE WILL PAY FOR EMPLOYEES, BOARD MEMBERS AND THEIR DEPENDENTS."},
#    {'FormAndLineReferenceDesc': 'FROM 990, PART II, COLUMN C',
#     'ExplanationTxt': "Part II, Column C INCLUDED IN THIS AMOUNT IS THE INCREASE IN ACTUARIAL VALUE OF BENEFITS PAYABLE UNDER A DEFINED BENEFIT RETIREMENT PLAN. THE CONTRIBUTION RATE FOR PARTICIPANTS IN THE NRECA R&S DEFINED BENEFIT PENSION PLAN ARE THE SAME FOR ALL INDIVIDUALS IN THIS MULTI-EMPLOYER PLAN. THE CHANGE IN ACTUARIAL VALUE FOR EACH PARTICIPANT, HOWEVER, VARIES WITH AGE. IN OTHER WORDS, THE OLDER A PLAN PARTICIPANT IS, THE GREATER THE INCREASE IN THAT INDIVIDUAL'S CHANGE IN ACTUARIAL VALUE, ALL OTHER THINGS BEING EQUAL. BECAUSE THIS RELATES TO A MULTI-EMPLOYER PLAN, CASH CONTRIBUTION TO THE PLAN IN LIEU OF THE ACTUARIAL INCREASE ARE EXPENSED IN THE FINANCIAL STATEMENTS. CHRISTOPHER MARTINEZ ACTUARIAL INCREASE IN DEFINED BENEFIT PLAN $ 36,920 401(K) EMPLOYER MATCH 5,732 TOTAL COLUMN C: 42,652 LESS: ACTUARIAL INCREASE IN DEFINED BENEFIT PLAN: (36,920) ADD: CASH CONTRIBUTION TO DEFINED BENEFIT PLAN: 21,909 TOTAL COOPERATIVE CASH CONTRIBUTION $ 27,641"}]},
#  'IRS990ScheduleL': {'@documentId': 'RetDoc1042800001',
#   'BusTrInvolveInterestedPrsnGrp': {'NameOfInterested': {'BusinessName': {'BusinessNameLine1': 'TRI-STATE G&T'}},
#    'RelationshipDescriptionTxt': 'BOARD DIRECTOR HAL KEELER IS A BOARD MEMBER OF TRI-STATE G&T',
#    'TransactionAmt': '8060858',
#    'TransactionDesc': 'THE COOPERATIVE PURCHASES ELECTRIC ENERGY FROM TRI-STATE G&T',
#    'SharingOfRevenuesInd': '0'}},
#  'IRS990ScheduleO': {'@documentId': 'RetDoc1044400001',
#   'SupplementalInformationDetail': [{'FormAndLineReferenceDesc': 'Form 990, Part VI, Section A, line 6',
#     'ExplanationTxt': 'THE COOPERATIVE WAS FORMED BY THE MEMBERS TO PROVIDE ELECTRIC SERVICE AT COST ON A COOPERATIVE BASIS.'},
#    {'FormAndLineReferenceDesc': 'Form 990, Part VI, Section A, line 7a',
#     'ExplanationTxt': 'THE MEMBERS OF THE COOPERATIVE VOTE ON THE BOARD OF DIRECTORS. ELECTIONS ARE DONE ON A ONE MEMBER ONE VOTE BASIS.'},
#    {'FormAndLineReferenceDesc': 'Form 990, Part VI, Section A, line 7b',
#     'ExplanationTxt': "THE FOLLOWING ACTS REQUIRE APPROVAL OF THE MEMBERS OF THE COOPERATIVE: 1. THE DISPOSAL OF A SUBSTANTIAL PORTION OF THE COOPERATIVE'S ASSETS; 2. THE DISSOLUTION/LIQUIDATION OF THE COOPERATIVE; AND 3. THE MERGER OR CONSOLIDATION OF THE COOPERATIVE WITH ANOTHER ORGANIZATION."},
#    {'FormAndLineReferenceDesc': 'Form 990, Part VI, Section A, line 8b',
#     'ExplanationTxt': 'EXECUTIVE SESSION MINUTES FROM TIME TO TIME THE ENTIRE BOARD WILL GO INTO EXECUTIVE SESSION FOR DISCUSSING ITEMS OF A SENSITIVE AND CONFIDENTIAL NATURE. WHEN THIS OCCURS MANAGEMENT AND OTHERS IN ATTENDANCE ARE REMOVED FROM THE MEETING ROOM. ITEMS DISCUSSED IN EXECUTIVE SESSION ARE NOT DOCUMENTED. HOWEVER, ACTIONS TAKEN BY THE BOARD AFTER EXECUTIVE SESSIONS ARE ADJOURNED ARE FULLY DOCUMENTED IN THE WRITTEN MINUTES.'},
#    {'FormAndLineReferenceDesc': 'Form 990, Part VI, Section B, line 11',
#     'ExplanationTxt': 'MANAGEMENT PRESENTED A COPY OF THE FORM 990 TO THE BOARD FOR DISCUSSION, REVIEW AND APPROVAL PRIOR TO FILING. THE DISCUSSION AND REVIEW WAS PERFORMED AT THE BOARD MEETING IMMEDIATELY BEFORE FILING THE FORM 990.'},
#    {'FormAndLineReferenceDesc': 'Form 990, Part VI, Section C, line 19',
#     'ExplanationTxt': 'THE COOPERATIVE WILL PROVIDE A COMPLETE COPY OF ITS GOVERNING DOCUMENTS, CONFLICT OF INTEREST POLICY AND AUDITED FINANCIAL STATEMENTS TO ANY MEMBER WHO REQUESTS A COPY OF ANY SUCH DOCUMENT.'},
#    {'FormAndLineReferenceDesc': 'Form 990, Part VI, Line 14',
#     'ExplanationTxt': 'THE COOPERATIVE DOES NOT HAVE A WRITTEN DOCUMENT RETENTION AND DESTRUCTION POLICY IN PLACE, BUT FOLLOWS THE RUS AND PRC RECOMMENDATIONS REGARDING DOCUMENT RETENTION AND DESTRUCTION.'},
#    {'FormAndLineReferenceDesc': 'Form 990, Part VI, Line 1B',
#     'ExplanationTxt': "HAL KEELER PER IRS FORM 990 INSTRUCTIONS IS NOT AN INDEPENDENT DIRECTOR BECAUSE HE IS ON THE BOARD OF TRI-STATE G&T ASSOCIATION, INC. THE COOPERATIVE PURCHASES ITS ELECTRIC ENERGY FROM TRI-STATE. THE COOPERATIVE IS A MEMBER OF TRI-STATE, AS SUCH MR. KEELER IS THE COOPERATIVE'S REPRESENTATIVE ON TRI-STATE'S BOARD. MR. KEELER HAS NO OWNERSHIP INTEREST IN TRI-STATE AND RECEIVES NO DIRECT OR INDIRECT BENEFIT FROM THE COOPERATIVE DOING BUSINESS WITH TRI-STATE."},
#    {'FormAndLineReferenceDesc': 'Form 990, Part VII, Column F',
#     'ExplanationTxt': 'IN ORDER TO PROVIDE RETIREMENT BENEFITS TO ITS EMPLOYEES, THE COOPERATIVE HAS ESTABLISHED A DEFINED CONTRIBUTION PLAN UNDER SECTION 401(K) OF THE INTERNAL REVENUE CODE. ADDITIONALLY, THE COOPERATIVE PARTICIPATES IN A MULTI-EMPLOYER DEFINED BENEFIT PLAN. CONTRIBUTIONS TO THIS PLAN ARE BASED ON THE FULL FUNDING LIMITATION OF SUCH PLAN. EMPLOYER CONTRIBUTIONS FOR BOTH PLANS ARE AVAILABLE TO PARTICIPATING EMPLOYEES, INCLUDING OFFICERS, MEETING THE ELIGIBILITY REQUIREMENTS OF SUCH PLANS. THE COOPERATIVE ALSO PROVIDES HEALTH, DENTAL, VISION AND LIFE INSURANCE TO ALL EMPLOYEES, INCLUDING OFFICERS, THROUGH A QUALIFIED PLAN. THE AMOUNTS REPORTED ON PART VII, COLUMN (F) FOR THE OFFICER IS COMPRISED OF THE ACTUARIAL INCREASE IN THE DEFINED BENEFIT PLAN FOR THE OFFICER, THE TOTAL AMOUNT CONTRIBUTED TO THE 401(K) PENSION PLAN AND THE INSURANCE PREMIUMS PAID FOR THE BENEFIT OF THE OFFICER.'},
#    {'FormAndLineReferenceDesc': 'Form 990, Part VII, Section A',
#     'ExplanationTxt': 'THE BOARD OF DIRECTORS CONSIDERS THE GENERAL MANAGER TO BE BOTH THE TOP MANAGEMENT OFFICIAL AND THE TOP FINANCIAL OFFICIAL. THEREFORE, ONLY THE GENERAL MANAGER IS LISTED AS AN EMPLOYEE OFFICER.'},
#    {'FormAndLineReferenceDesc': 'Form 990, Part VIII, Line 2B',
#     'ExplanationTxt': 'PATRONAGE DIVIDENDS RESULT FROM THE PURCHASE OF WHOLESALE POWER FROM A GENERATION & TRANSMISSION COOPERATIVE. PATRONAGE DIVIDENDS ALSO RESULT FROM THE PAYMENT OF INTEREST FROM COOPERATIVE BANKS AND THE PURCHASE OF SUPPLIES AND SERVICES FROM OTHER COOPERATIVE ORGANIZATIONS. THE EXPENSES ASSOCIATED WITH PURCHASES FROM AND PAYMENTS TO SUCH COOPERATIVE ORGANIZATIONS ARE A DIRECT COMPONENT OF COST OF THE ELECTRIC SERVICE PROVIDED BY THE COOPERATIVE TO ITS MEMBERS.'},
#    {'FormAndLineReferenceDesc': 'Form 990, Part IX',
#     'ExplanationTxt': 'THE ACCOUNTING RECORDS OF THE COOPERATIVE ARE MAINTAINED IN ACCORDANCE WITH THE UNIFORM SYSTEM OF ACCOUNTS AS PRESCRIBED BY THE FEDERAL ENERGY REGULATORY COMMISSION FOR CLASS A AND B ELECTRIC UTILITIES MODIFIED FOR ELECTRIC BORROWERS OF THE RURAL UTILITIES SERVICE(RUS). THE UNIFORM SYSTEM OF ACCOUNTING DOES NOT RECORD EXPENSES IN THE GENERAL EXPENSE CATEGORIES PROVIDED ON PART IX LINES 1 - 23. THE COOPERATIVE WILL BREAK OUT SALARIES AND WAGES, EMPLOYEE BENEFITS AND PAYROLL TAXES THAT ARE ALLOCATED IN ACCORDANCE WITH THEIR ACCOUNTING SYSTEM, BUT OTHER EXPENSES THAT ARE DESCRIBED IN LINES 1 - 23 WILL BE REPORTED ON LINE 24 UNDER THE EXPENSE CATEGORIES REQUIRED BY THE UNIFORM SYSTEM OF ACCOUNTS.'},
#    {'FormAndLineReferenceDesc': 'Form 990, Part IX, Lines 5-7',
#     'ExplanationTxt': 'SALARIES AND WAGES ARE ALLOCATED TO ASSET, LIABILITY, AND EXPENSE ACCOUNTS BASED ON THE ACCOUNTING SYSTEM DESCRIBED ABOVE. IN AN EFFORT TO EXPLAIN WHY THE AMOUNTS REPORTED ON LINES 5-7 DO NOT AGREE TO THE TOTAL WAGES ACCRUED AND/OR PAID THE FOLLOWING RECONCILIATION IS PROVIDED. TOTAL PER LINES 5-7 $ 1,161,373 LESS DIRECTORS FEES REPORTED ON 1099-MISC (144,542) PLUS SALARIES AND WAGES ALLOCATED TO ASSET ACCOUNTS 771,139 LESS EMPLOYEE OFFICER BENEFITS REPORTED ON LINE 5 (66,663) TOTAL WAGES ACCRUED AND/OR PAID $ 1,721,307'},
#    {'FormAndLineReferenceDesc': 'Form 990, Part IX, Line 24',
#     'ExplanationTxt': 'THE FOLLOWING IS A BREAKDOWN OF THE EXPENSES REPORTED AS ADMINISTRATIVE AND GENERAL EXPENSE ON FORM 990, PART IX, LINE 24 OFFICE SUPPLIES $ 45,802 OUTSIDE SERVICES 35,327 REGULATORY COMMISSION EXPENSE 62,034 MISCELLANEOUS EXPENSES 21,511 BOARD EXPENSE 208,559 DUES AND MEMBERSHIP FEES 63,302 ANNUAL MEETING EXPENSE 25,954 TRAVEL EXPENSE 12,945 MAINTENANCE OF GENERAL PLANT 74,049 TOTAL ADMINISTRATIVE AND GENERAL EXPENSE PER 990 $ 549,483'},
#    {'FormAndLineReferenceDesc': 'FORM 990, PART IX, LINE 4',
#     'ExplanationTxt': 'THE FORM 990 INSTRUCTIONS SPECIFICALLY STATE THAT THE AMOUNT OF PATRONAGE DIVIDENDS PAID TO THE MEMBERS (HEREINAFTER REFERRED TO AS PATRONS) SHOULD BE REPORTED ON PART IX, LINE 4 AS "BENEFITS PAID TO MEMBERS". THE PHRASE "PATRONAGE DIVIDENDS PAID" REFERS TO THE PROCESS, SUBSEQUENT TO YEAR-END, BY WHICH THE COOPERATIVE ALLOCATES PATRONAGE CAPITAL TO AND, THEREFORE, OPERATES AT COST WITH ITS PATRONS. THE COOPERATIVE\'S TAX EXEMPT PURPOSE IS TO PROVIDE ELECTRICITY TO ITS PATRONS AND TO DO SO ON A COOPERATIVE BASIS. TAX LAW DEFINES "OPERATING ON A COOPERATIVE BASIS" AS SUBORDINATION OF CAPITAL, DEMOCRATIC CONTROL, AND OPERATION AT COST. THE COOPERATIVE OPERATES AT COST THROUGH THE ALLOCATION OF TRUE PATRONAGE DIVIDENDS (ALSO REFERRED TO AS ALLOCATIONS OF PATRONAGE CAPITAL) TO ITS PATRONS. PATRONAGE DIVIDENDS ARE CONSIDERED PAID IF THE ALLOCATION IS MADE (1) PURSUANT TO A PRE-EXISTING OBLIGATION, (2) FROM THE MARGINS PRODUCED FROM THE TRANSACTIONS DONE WITH OR FOR PATRONS, AND (3) IN A FAIR AND EQUITABLE BASIS ON THE BASIS OF PATRONAGE (I.E. PURCHASES). ADDITIONALLY, THE ALLOCATION OF PATRONAGE DIVIDENDS SHOULD BE MADE WITHIN A REASONABLE TIME PERIOD AFTER THE CLOSE OF THE COOPERATIVE\'S YEAR-END OF DECEMBER 31. EACH ONE OF THESE REQUIREMENTS FOR A TRUE PATRONAGE DIVIDEND IS PROVIDED FOR IN THE NON-PROFIT OPERATION ARTICLE OF THE COOPERATIVE\'S BYLAWS AND IS SUMMARIZED AS FOLLOWS: (A) IN ORDER TO INDUCE PATRONAGE AND TO ASSURE THAT THE COOPERATIVE WILL OPERATE ON A NONPROFIT BASIS, THE COOPERATIVE IS OBLIGATED TO ACCOUNT ON A PATRONAGE BASIS TO ALL ITS PATRONS FOR ALL AMOUNTS RECEIVED AND RECEIVABLE FROM THE FURNISHING OF ELECTRIC POWER AND ENERGY IN EXCESS OF OPERATING COSTS AND EXPENSES PROPERLY CHARGEABLE AGAINST SUCH SERVICES (I.E. MARGINS FROM THE PROVISION OF ELECTRIC POWER AND ENERGY). (B) THE MARGINS FROM THE PROVISION OF ELECTRIC POWER AND ENERGY ARE RECEIVED WITH THE UNDERSTANDING THAT THEY ARE FURNISHED BY THE PATRONS AS CAPITAL. (C) THE COOPERATIVE IS OBLIGATED TO PAY BY CREDITS TO A CAPITAL ACCOUNT FOR EACH PATRON FOR ALL SUCH MARGINS. AND (D) ALL SUCH AMOUNTS CREDITED TO THE CAPITAL ACCOUNT OF ANY PATRONS SHALL HAVE THE SAME STATUS AS THOUGH THEY HAD BEEN PAID TO THE PATRON IN CASH IN PURSUANCE OF A LEGAL OBLIGATION TO DO SO AND THE PATRON HAD THEN FURNISHED TO THE COOPERATIVE CORRESPONDING AMOUNTS OF CAPITAL. THE AMOUNT REPORTED ON PART IX, LINE 4 REPRESENTS THE AMOUNT OF PATRONAGE CAPITAL THAT IS EITHER ALLOCATED OR TO BE ALLOCATED TO THE PATRONS RESULTING FROM THEIR PURCHASE OF ELECTRICITY FROM THE COOPERATIVE FOR THE 2013 CALENDAR YEAR. AS NOTED ABOVE, SUCH AMOUNTS ARE ALLOCATED SUBSEQUENT TO YEAR-END IN A FAIR AND EQUITABLE MANNER ON THE BASIS OF PATRONAGE (I.E. PURCHASES). THE AMOUNTS ALLOCATED ARE REPRESENTATIVE OF THE MARGINS FROM THE PROVISION OF ELECTRIC POWER AND ENERGY TO THE PATRONS AND ARE DONE PURSUANT TO THE OLBIGATION THAT EXISTED IN THE BYLAWS PRIOR TO THE COOPERATIVE PROVIDING ELECTRICITY TO ITS PATRONS. THEREFORE, THESE AMOUNTS MEET THE DEFINITION OF THE TERM "PATRONAGE DIVIDENDS PAID". PLEASE NOTE, HOWEVER, THAT BECAUSE PATRONAGE DIVIDENDS IS THE PROCESS BY WHICH THE COOPERATIVE OPERATES AT COST WITH ITS PATRONS AND THEREBY A KEY COMPONENT TO ACCOMPLISHING ITS EXEMPT PURPOSE, THE COOPERATIVE HAS REPORTED THE AMOUNT OF ITS 2013 MARGIN THAT HAS BEEN OR IS TO BE ALLOCATED TO THE PATRONS SUBSEQUENT TO YEAR-END. SUCH AMOUNTS ARE AN EXPENSE FOR FORM 990 REPORTING AND IS NOT AN EXPENSE FOR FINANCIAL STATEMENTS PREPARED IN ACCORDANCE WITH GENERALLY ACCEPTED ACCOUNTING PRINCIPLES. AS A RESULT, THE DIFFERENCE BETWEEN THE COOPERATIVE\'S GAAP BASIS FINANCIAL STATEMENTS AND THE REVENUE LESS EXPENSES REPORTED ON PART I, LINE 19 IS THE AMOUNT OF PATRONAGE DIVIDENDS REPORTED AS BENEFITS PAID TO MEMBERS.'},
#    {'FormAndLineReferenceDesc': 'Form 990, Part XI, line 9:',
#     'ExplanationTxt': 'PATRONAGE CAPITAL ASSIGNABLE 1,167,924.'},
#    {'FormAndLineReferenceDesc': 'Form 990, Part XII, Line 2B',
#     'ExplanationTxt': "AUDITED FINANCIAL STATEMENTS WERE PREPARED BY AN INDEPENDENT ACCOUNTANT FOR THE COOPERATIVE'S FISCAL YEAR END OF JULY 31ST. THE TAX RETURN HAS BEEN AND CONTINUES TO BE PREPARED BASED ON A CALENDAR YEAR END OF DECEMBER 31. THE BOARD AS A WHOLE IS RESPONSIBLE FOR OVERSEEING THE FINANCIAL STATEMENT AUDIT AND SELECTING THE INDEPENDENT FINANCIAL STATEMENT AUDITOR."}]},
#  'IRS990ScheduleR': {'@documentId': 'RetDoc1043400001',
#   'IdRelatedTaxExemptOrgGrp': {'DisregardedEntityName': {'BusinessNameLine1': 'COLUMBUS ELECTRIC SCHOLARSHIP INC'},
#    'USAddress': {'AddressLine1': 'PO BOX 631',
#     'City': 'DEMING',
#     'State': 'NM',
#     'ZIPCode': '88031'},
#    'EIN': '850373471',
#    'PrimaryActivitiesTxt': 'TO PROVIDE COLLEGE SCHOLARSHIPS TO ACTIVE MEMBERS AND FAMILIES.',
#    'LegalDomicileStateCd': 'NM',
#    'ExemptCodeSectionTxt': '501(C)(3)',
#    'PublicCharityStatusTxt': 'PF',
#    'DirectControllingEntityName': {'BusinessNameLine1': 'COLUMBUS ELECTRIC COOPERATIVE INC'},
#    'ControlledOrganizationInd': '1'},
#   'ReceiptOfIntAnntsRntsRyltsInd': '0',
#   'GiftGrntOrCapContriToOthOrgInd': '0',
#   'GiftGrntCapContriFromOthOrgInd': '0',
#   'LoansOrGuaranteesToOtherOrgInd': '0',
#   'LoansOrGuaranteesFromOthOrgInd': '0',
#   'DivRelatedOrganizationInd': '0',
#   'AssetSaleToOtherOrgInd': '0',
#   'AssetPurchaseFromOtherOrgInd': '0',
#   'AssetExchangeInd': '0',
#   'RentalOfFacilitiesToOthOrgInd': '0',
#   'RentalOfFcltsFromOthOrgInd': '0',
#   'PerformOfServicesForOthOrgInd': '0',
#   'PerformOfServicesByOtherOrgInd': '0',
#   'SharingOfFacilitiesInd': '0',
#   'PaidEmployeesSharingInd': '1',
#   'ReimbursementPaidToOtherOrgInd': '0',
#   'ReimbursementPaidByOtherOrgInd': '0',
#   'TransferToOtherOrgInd': '0',
#   'TransferFromOtherOrgInd': '0',
#   'TransactionsRelatedOrgGrp': {'OtherOrganizationName': {'BusinessNameLine1': 'COLUMBUS ELECTRIC SCHOLARSHIP INC'},
#    'TransactionTypeTxt': 'O',
#    'InvolvedAmt': '1460',
#    'MethodOfAmountDeterminationTxt': 'HOURS WORKED X HOURLY WAGE'}},
#  '@documentId': 'RetDoc1038000001',
#  '@referenceDocumentId': 'RetDoc1044400001',
#  'PrincipalOfficerNm': 'CHRISTOPHER MARTINEZ',
#  'USAddress': {'AddressLine1': 'PO BOX 631',
#   'City': 'DEMING',
#   'State': 'NM',
#   'ZIPCode': '880310631'},
#  'GrossReceiptsAmt': '14124586',
#  'GroupReturnForAffiliatesInd': '0',
#  'Organization501cInd': {'@organization501cTypeTxt': '12', '#text': 'X'},
#  'WebsiteAddressTxt': 'WWW.COLUMBUSCO-OP.ORG',
#  'TypeOfOrganizationCorpInd': 'X',
#  'FormationYr': '1958',
#  'LegalDomicileStateCd': 'NM',
#  'ActivityOrMissionDesc': 'TO PROVIDE ELECTRIC ENERGY TO RURAL AREAS AT COST ON A COOPERATIVE BASIS.',
#  'VotingMembersGoverningBodyCnt': '9',
#  'VotingMembersIndependentCnt': '8',
#  'TotalEmployeeCnt': '34',
#  'TotalVolunteersCnt': '0',
#  'TotalGrossUBIAmt': '0',
#  'NetUnrelatedBusTxblIncmAmt': '0',
#  'PYContributionsGrantsAmt': '0',
#  'CYContributionsGrantsAmt': '0',
#  'PYProgramServiceRevenueAmt': '13850533',
#  'CYProgramServiceRevenueAmt': '14082441',
#  'PYInvestmentIncomeAmt': '60763',
#  'CYInvestmentIncomeAmt': '30587',
#  'PYOtherRevenueAmt': '4440',
#  'CYOtherRevenueAmt': '8566',
#  'PYTotalRevenueAmt': '13915736',
#  'CYTotalRevenueAmt': '14121594',
#  'PYGrantsAndSimilarPaidAmt': '0',
#  'CYGrantsAndSimilarPaidAmt': '0',
#  'PYBenefitsPaidToMembersAmt': '931078',
#  'CYBenefitsPaidToMembersAmt': '1167924',
#  'PYSalariesCompEmpBnftPaidAmt': '1842889',
#  'CYSalariesCompEmpBnftPaidAmt': '1702479',
#  'PYTotalProfFndrsngExpnsAmt': '0',
#  'CYTotalProfFndrsngExpnsAmt': '0',
#  'CYTotalFundraisingExpenseAmt': '0',
#  'PYOtherExpensesAmt': '11081006',
#  'CYOtherExpensesAmt': '11220604',
#  'PYTotalExpensesAmt': '13854973',
#  'CYTotalExpensesAmt': '14091007',
#  'PYRevenuesLessExpensesAmt': '60763',
#  'CYRevenuesLessExpensesAmt': '30587',
#  'TotalAssetsBOYAmt': '31017580',
#  'TotalAssetsEOYAmt': '35304739',
#  'TotalLiabilitiesBOYAmt': '20536773',
#  'TotalLiabilitiesEOYAmt': '23625421',
#  'NetAssetsOrFundBalancesBOYAmt': '10480807',
#  'NetAssetsOrFundBalancesEOYAmt': '11679318',
#  'MissionDesc': "THE COOPERATIVE'S RESPONSIBILITY AND AIM IS TO PROVIDE EXCELLENT AND INNOVATIVE CUSTOMER SERVICE AS REFLECTED IN TOP QUALITY ELECTRIC SERVICE RELIABILITY, AFFORDABLE RATES, EMPLOYEE TEAMWORK AND THE HIGHEST DEGREE OF INTEGRITY IN ALL COOPERATIVE ENDEAVORS.",
#  'SignificantNewProgramSrvcInd': '0',
#  'SignificantChangeInd': '0',
#  'Desc': 'PROVIDING ELECTRIC ENERGY TO OUR MEMBERS - 5,050 ACTIVE SERVICES WERE PROVIDED POWER AT YEAR END AT COST ON A COOPERATIVE BASIS THROUGH THE ALLOCATION OF PATRONAGE CAPITAL.',
#  'DescribedInSection501c3Ind': '0',
#  'ScheduleBRequiredInd': '0',
#  'PoliticalCampaignActyInd': '0',
#  'SubjectToProxyTaxInd': '0',
#  'DonorAdvisedFundInd': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'ConservationEasementsInd': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'CollectionsOfArtInd': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'CreditCounselingInd': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'TempOrPermanentEndowmentsInd': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'ReportLandBuildingEquipmentInd': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '1'},
#  'ReportInvestmentsOtherSecInd': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'ReportProgramRelatedInvstInd': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '1'},
#  'ReportOtherAssetsInd': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '1'},
#  'ReportOtherLiabilitiesInd': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '1'},
#  'IncludeFIN48FootnoteInd': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '1'},
#  'IndependentAuditFinclStmtInd': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'ConsolidatedAuditFinclStmtInd': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'SchoolOperatingInd': '0',
#  'ForeignOfficeInd': '0',
#  'ForeignActivitiesInd': '0',
#  'MoreThan5000KToOrgInd': '0',
#  'MoreThan5000KToIndividualsInd': '0',
#  'ProfessionalFundraisingInd': '0',
#  'FundraisingActivitiesInd': '0',
#  'GamingActivitiesInd': '0',
#  'OperateHospitalInd': '0',
#  'GrantsToOrganizationsInd': '0',
#  'GrantsToIndividualsInd': '0',
#  'ScheduleJRequiredInd': {'@referenceDocumentId': 'RetDoc1042400001',
#   '#text': '1'},
#  'TaxExemptBondsInd': '0',
#  'LoanOutstandingInd': {'@referenceDocumentId': 'RetDoc1042800001',
#   '#text': '0'},
#  'GrantToRelatedPersonInd': {'@referenceDocumentId': 'RetDoc1042800001',
#   '#text': '0'},
#  'BusinessRlnWithOrgMemInd': {'@referenceDocumentId': 'RetDoc1042800001',
#   '#text': '0'},
#  'BusinessRlnWithFamMemInd': {'@referenceDocumentId': 'RetDoc1042800001',
#   '#text': '0'},
#  'BusinessRlnWithOfficerEntInd': {'@referenceDocumentId': 'RetDoc1042800001',
#   '#text': '1'},
#  'DeductibleNonCashContriInd': '0',
#  'DeductibleArtContributionInd': '0',
#  'TerminateOperationsInd': '0',
#  'PartialLiquidationInd': '0',
#  'DisregardedEntityInd': {'@referenceDocumentId': 'RetDoc1043400001',
#   '#text': '0'},
#  'RelatedEntityInd': {'@referenceDocumentId': 'RetDoc1043400001',
#   '#text': '1'},
#  'RelatedOrganizationCtrlEntInd': '1',
#  'TransactionWithControlEntInd': {'@referenceDocumentId': 'RetDoc1043400001',
#   '#text': '1'},
#  'ActivitiesConductedPrtshpInd': {'@referenceDocumentId': 'RetDoc1043400001',
#   '#text': '0'},
#  'ScheduleORequiredInd': '1',
#  'IRPDocumentCnt': '24',
#  'IRPDocumentW2GCnt': '0',
#  'EmployeeCnt': '34',
#  'EmploymentTaxReturnsFiledInd': '1',
#  'UnrelatedBusIncmOverLimitInd': '0',
#  'ForeignFinancialAccountInd': '0',
#  'ProhibitedTaxShelterTransInd': '0',
#  'TaxablePartyNotificationInd': '0',
#  'NondeductibleContributionsInd': '0',
#  'MembersAndShrGrossIncomeAmt': '14140228',
#  'OtherSourcesGrossIncomeAmt': '82079',
#  'IndoorTanningServicesInd': '0',
#  'InfoInScheduleOPartVIInd': 'X',
#  'GoverningBodyVotingMembersCnt': '9',
#  'IndependentVotingMemberCnt': '8',
#  'FamilyOrBusinessRlnInd': '0',
#  'DelegationOfMgmtDutiesInd': '0',
#  'ChangeToOrgDocumentsInd': '0',
#  'MaterialDiversionOrMisuseInd': '0',
#  'MembersOrStockholdersInd': '1',
#  'ElectionOfBoardMembersInd': '1',
#  'DecisionsSubjectToApprovaInd': '1',
#  'MinutesOfGoverningBodyInd': '1',
#  'MinutesOfCommitteesInd': '0',
#  'OfficerMailingAddressInd': '0',
#  'LocalChaptersInd': '0',
#  'Form990ProvidedToGvrnBodyInd': '1',
#  'ConflictOfInterestPolicyInd': '1',
#  'AnnualDisclosureCoveredPrsnInd': '1',
#  'RegularMonitoringEnfrcInd': '0',
#  'WhistleblowerPolicyInd': '1',
#  'DocumentRetentionPolicyInd': '0',
#  'CompensationProcessCEOInd': '0',
#  'CompensationProcessOtherInd': '0',
#  'InvestmentInJointVentureInd': '0',
#  'UponRequestInd': 'X',
#  'BooksInCareOfDetail': {'BusinessName': {'BusinessNameLine1': 'CHRISTOPHER MARTINEZ'},
#   'PhoneNum': '5755468838',
#   'USAddress': {'AddressLine1': '900 N GOLD STREET',
#    'City': 'DEMING',
#    'State': 'NM',
#    'ZIPCode': '88031'}},
#  'InfoInScheduleOPartVIIInd': 'X',
#  'Form990PartVIISectionAGrp': [{'PersonNm': 'EDWARD ELBROCK',
#    'TitleTxt': 'PRESIDENT',
#    'AverageHoursPerWeekRt': '5.00',
#    'IndividualTrusteeOrDirectorInd': 'X',
#    'OfficerInd': 'X',
#    'ReportableCompFromOrgAmt': '12771',
#    'ReportableCompFromRltdOrgAmt': '0',
#    'OtherCompensationAmt': '0'},
#   {'PersonNm': 'RANDY MASSEY',
#    'TitleTxt': 'VICE PRESIDENT',
#    'AverageHoursPerWeekRt': '2.70',
#    'IndividualTrusteeOrDirectorInd': 'X',
#    'OfficerInd': 'X',
#    'ReportableCompFromOrgAmt': '15702',
#    'ReportableCompFromRltdOrgAmt': '0',
#    'OtherCompensationAmt': '0'},
#   {'PersonNm': 'WILLIAM C MILLER JR',
#    'TitleTxt': 'SECRETARY/TREASURER',
#    'AverageHoursPerWeekRt': '6.90',
#    'IndividualTrusteeOrDirectorInd': 'X',
#    'OfficerInd': 'X',
#    'ReportableCompFromOrgAmt': '6538',
#    'ReportableCompFromRltdOrgAmt': '0',
#    'OtherCompensationAmt': '0'},
#   {'PersonNm': 'EDDIE DIAZ',
#    'TitleTxt': 'ASST SEC/TREAS',
#    'AverageHoursPerWeekRt': '1.50',
#    'IndividualTrusteeOrDirectorInd': 'X',
#    'OfficerInd': 'X',
#    'ReportableCompFromOrgAmt': '20201',
#    'ReportableCompFromRltdOrgAmt': '0',
#    'OtherCompensationAmt': '0'},
#   {'PersonNm': 'NANCY CLOPTON',
#    'TitleTxt': 'TRUSTEE',
#    'AverageHoursPerWeekRt': '3.90',
#    'IndividualTrusteeOrDirectorInd': 'X',
#    'ReportableCompFromOrgAmt': '20421',
#    'ReportableCompFromRltdOrgAmt': '0',
#    'OtherCompensationAmt': '0'},
#   {'PersonNm': 'JAY PETERSON',
#    'TitleTxt': 'TRUSTEE',
#    'AverageHoursPerWeekRt': '4.90',
#    'IndividualTrusteeOrDirectorInd': 'X',
#    'ReportableCompFromOrgAmt': '20601',
#    'ReportableCompFromRltdOrgAmt': '0',
#    'OtherCompensationAmt': '0'},
#   {'PersonNm': 'WILLIAM J CLOUDT',
#    'TitleTxt': 'TRUSTEE',
#    'AverageHoursPerWeekRt': '3.40',
#    'IndividualTrusteeOrDirectorInd': 'X',
#    'ReportableCompFromOrgAmt': '20601',
#    'ReportableCompFromRltdOrgAmt': '0',
#    'OtherCompensationAmt': '0'},
#   {'PersonNm': 'HAL B KEELER',
#    'TitleTxt': 'TRUSTEE',
#    'AverageHoursPerWeekRt': '2.30',
#    'IndividualTrusteeOrDirectorInd': 'X',
#    'ReportableCompFromOrgAmt': '7106',
#    'ReportableCompFromRltdOrgAmt': '0',
#    'OtherCompensationAmt': '0'},
#   {'PersonNm': 'JOE JOHNSON',
#    'TitleTxt': 'TRUSTEE',
#    'AverageHoursPerWeekRt': '1.50',
#    'IndividualTrusteeOrDirectorInd': 'X',
#    'ReportableCompFromOrgAmt': '20601',
#    'ReportableCompFromRltdOrgAmt': '0',
#    'OtherCompensationAmt': '0'},
#   {'PersonNm': 'CHRISTOPHER MARTINEZ',
#    'TitleTxt': 'GENERAL MANAGER',
#    'AverageHoursPerWeekRt': '50.00',
#    'OfficerInd': 'X',
#    'ReportableCompFromOrgAmt': '108964',
#    'ReportableCompFromRltdOrgAmt': '0',
#    'OtherCompensationAmt': '66663'}],
#  'TotalReportableCompFromOrgAmt': '253506',
#  'TotReportableCompRltdOrgAmt': '0',
#  'TotalOtherCompensationAmt': '66663',
#  'IndivRcvdGreaterThan100KCnt': '1',
#  'FormerOfcrEmployeesListedInd': '0',
#  'TotalCompGreaterThan150KInd': '1',
#  'CompensationFromOtherSrcsInd': '0',
#  'ContractorCompensationGrp': {'ContractorName': {'BusinessName': {'BusinessNameLine1': 'GILA CUTOUT CONSTRUCTION'}},
#   'ContractorAddress': {'USAddress': {'AddressLine1': 'PO BOX 2429',
#     'City': 'SILVER CITY',
#     'State': 'NM',
#     'ZIPCode': '88062'}},
#   'ServicesDesc': 'LINE CONSTRUCTION',
#   'CompensationAmt': '280799'},
#  'CntrctRcvdGreaterThan100KCnt': '1',
#  'InfoInScheduleOPartVIIIInd': 'X',
#  'ProgramServiceRevenueGrp': [{'Desc': 'ELECTRIC ENERGY',
#    'BusinessCd': '221000',
#    'TotalRevenueColumnAmt': '13477932',
#    'RelatedOrExemptFuncIncomeAmt': '13477932'},
#   {'Desc': 'PATRONAGE DIVIDENDS',
#    'BusinessCd': '221000',
#    'TotalRevenueColumnAmt': '604509',
#    'RelatedOrExemptFuncIncomeAmt': '604509'}],
#  'TotalProgramServiceRevenueAmt': '14082441',
#  'InvestmentIncomeGrp': {'TotalRevenueColumnAmt': '33579',
#   'ExclusionAmt': '33579'},
#  'GrossRentsGrp': {'PersonalAmt': '8566'},
#  'LessRentalExpensesGrp': {'PersonalAmt': '0'},
#  'RentalIncomeOrLossGrp': {'PersonalAmt': '8566'},
#  'NetRentalIncomeOrLossGrp': {'TotalRevenueColumnAmt': '8566',
#   'ExclusionAmt': '8566'},
#  'LessCostOthBasisSalesExpnssGrp': {'OtherAmt': '2992'},
#  'GainOrLossGrp': {'OtherAmt': '-2992'},
#  'NetGainOrLossInvestmentsGrp': {'TotalRevenueColumnAmt': '-2992',
#   'ExclusionAmt': '-2992'},
#  'TotalRevenueGrp': {'TotalRevenueColumnAmt': '14121594',
#   'RelatedOrExemptFuncIncomeAmt': '14082441',
#   'UnrelatedBusinessRevenueAmt': '0',
#   'ExclusionAmt': '39153'},
#  'InfoInScheduleOPartIXInd': 'X',
#  'BenefitsToMembersGrp': {'TotalAmt': '1167924'},
#  'CompCurrentOfcrDirectorsGrp': {'TotalAmt': '320169'},
#  'OtherSalariesAndWagesGrp': {'TotalAmt': '841204'},
#  'PensionPlanContributionsGrp': {'TotalAmt': '128859'},
#  'OtherEmployeeBenefitsGrp': {'TotalAmt': '334936'},
#  'PayrollTaxesGrp': {'TotalAmt': '77311'},
#  'InterestGrp': {'TotalAmt': '593089'},
#  'DepreciationDepletionGrp': {'TotalAmt': '1188345'},
#  'OtherExpensesGrp': [{'Desc': 'COST OF PURCHASED POWER',
#    'TotalAmt': '8060858'},
#   {'Desc': 'ADMIN AND GEN EXPENSE', 'TotalAmt': '549483'},
#   {'Desc': 'DISTRIBUTION EXPENSE', 'TotalAmt': '488057'},
#   {'Desc': 'CUSTOMER ACCOUNTS', 'TotalAmt': '327040'}],
#  'AllOtherExpensesGrp': {'TotalAmt': '13732'},
#  'TotalFunctionalExpensesGrp': {'TotalAmt': '14091007'},
#  'CashNonInterestBearingGrp': {'BOYAmt': '663899', 'EOYAmt': '706913'},
#  'SavingsAndTempCashInvstGrp': {'BOYAmt': '701000', 'EOYAmt': '3000000'},
#  'AccountsReceivableGrp': {'BOYAmt': '732667', 'EOYAmt': '824396'},
#  'InventoriesForSaleOrUseGrp': {'BOYAmt': '433250', 'EOYAmt': '453456'},
#  'PrepaidExpensesDefrdChargesGrp': {'BOYAmt': '169537', 'EOYAmt': '174001'},
#  'LandBldgEquipCostOrOtherBssAmt': '40362234',
#  'LandBldgEquipAccumDeprecAmt': '15996657',
#  'LandBldgEquipBasisNetGrp': {'BOYAmt': '23577993', 'EOYAmt': '24365577'},
#  'InvestmentsProgramRelatedGrp': {'BOYAmt': '3355351', 'EOYAmt': '3928047'},
#  'OtherAssetsTotalGrp': {'BOYAmt': '1383883', 'EOYAmt': '1852349'},
#  'TotalAssetsGrp': {'BOYAmt': '31017580', 'EOYAmt': '35304739'},
#  'AccountsPayableAccrExpnssGrp': {'BOYAmt': '549065', 'EOYAmt': '560188'},
#  'MortgNotesPyblScrdInvstPropGrp': {'BOYAmt': '18902107',
#   'EOYAmt': '22026645'},
#  'OtherLiabilitiesGrp': {'BOYAmt': '1085601', 'EOYAmt': '1038588'},
#  'TotalLiabilitiesGrp': {'BOYAmt': '20536773', 'EOYAmt': '23625421'},
#  'OrgDoesNotFollowSFAS117Ind': 'X',
#  'CapStkTrPrinCurrentFundsGrp': {'BOYAmt': '0', 'EOYAmt': '0'},
#  'PdInCapSrplsLandBldgEqpFundGrp': {'BOYAmt': '0', 'EOYAmt': '0'},
#  'RtnEarnEndowmentIncmOthFndsGrp': {'BOYAmt': '10480807',
#   'EOYAmt': '11679318'},
#  'TotalNetAssetsFundBalanceGrp': {'BOYAmt': '10480807', 'EOYAmt': '11679318'},
#  'TotLiabNetAssetsFundBalanceGrp': {'BOYAmt': '31017580',
#   'EOYAmt': '35304739'},
#  'InfoInScheduleOPartXIInd': 'X',
#  'ReconcilationRevenueExpnssAmt': '30587',
#  'OtherChangesInNetAssetsAmt': '1167924',
#  'InfoInScheduleOPartXIIInd': 'X',
#  'MethodOfAccountingAccrualInd': 'X',
#  'AccountantCompileOrReviewInd': '0',
#  'FSAuditedInd': '0',
#  'FederalGrantAuditRequiredInd': '0'}

# %%
db.filings_990.find_one({'URL' : "https://s3.amazonaws.com/irs-form-990/201401349349308135_public.xml" })
# Out:
# {'_id': ObjectId('5d047fcb78ffca27b430d4be'),
#  'OrganizationName': 'HARVEY L MILLER SUPPORTING FOUNDATION',
#  'ObjectId': '201401349349308135',
#  'URL': 'https://s3.amazonaws.com/irs-form-990/201401349349308135_public.xml',
#  'SubmittedOn': '2014-06-26',
#  'DLN': '93493134081354',
#  'LastUpdated': '2016-03-21T17:23:53',
#  'TaxPeriod': '201306',
#  'FormType': '990',
#  'EIN': '900187252',
#  '@xmlns': 'http://www.irs.gov/efile',
#  '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#  '@xsi:schemaLocation': 'http://www.irs.gov/efile',
#  '@returnVersion': '2012v2.1',
#  'ReturnHeader': {'@binaryAttachmentCount': '0',
#   'Timestamp': '2014-05-14T19:16:02-05:00',
#   'TaxPeriodEndDate': '2013-06-30',
#   'PreparerFirm': {'EIN': '420714325',
#    'PreparerFirmBusinessName': {'BusinessNameLine1': 'MCGLADREY LLP'},
#    'PreparerFirmUSAddress': {'AddressLine1': '1 S WACKER DRIVE STE 800',
#     'City': 'CHICAGO',
#     'State': 'IL',
#     'ZIPCode': '60606'}},
#   'ReturnType': '990',
#   'TaxPeriodBeginDate': '2012-07-01',
#   'Filer': {'EIN': '900187252',
#    'Name': {'BusinessNameLine1': 'Harvey L Miller Supporting Foundation'},
#    'NameControl': 'HARV',
#    'Phone': '3123574790',
#    'USAddress': {'AddressLine1': '30 South Wells Street No 4049',
#     'City': 'Chicago',
#     'State': 'IL',
#     'ZIPCode': '60606'}},
#   'Officer': {'Name': 'David S Rosen',
#    'Title': 'Treasurer',
#    'Phone': '3123574790',
#    'DateSigned': '2014-05-14',
#    'AuthorizeThirdParty': '1'},
#   'Preparer': {'Name': 'Zack Fortsch',
#    'PTIN': 'P00052725',
#    'Phone': '3126343400'},
#   'TaxYear': '2012',
#   'BuildTS': '2015-11-30 17:44:51Z'},
#  '@documentCount': '8',
#  'IRS990ScheduleA': {'@documentId': 'RetDoc1039100001',
#   'SupportingOrganization509a3': 'X',
#   'SupportingOrg509a3Type1': 'X',
#   'CertificationCheckbox': 'X',
#   'ContribByControllingIndividual': '0',
#   'ContributionByRelatedParty': '0',
#   'ContribBy35ControlledEntity': '0',
#   'SupportedOrgInformation': {'Name': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#    'EIN': '362167761',
#    'TypeOfOrganization': '7',
#    'ListedInGoverningDoc': '1',
#    'Amount': '0'},
#   'TotalNumberOfSupportedOrgs': '1',
#   'SumOfAmounts': '0'},
#  'IRS990ScheduleB': {'@documentId': 'RetDoc1234500001',
#   'ContributorInfo': {'ContributorNumber': 'RESTRICTED',
#    'ContributorNameBusiness': {'BusinessNameLine1': 'RESTRICTED'},
#    'ContributorAddressUS': {'AddressLine1': 'RESTRICTED',
#     'AddressLine2': 'RESTRICTED',
#     'City': 'RESTRICTED',
#     'State': 'RESTRICTED',
#     'ZIPCode': 'RESTRICTED'},
#    'AggregateContributions': 'RESTRICTED'}},
#  'IRS990ScheduleD': {'@documentId': 'RetDoc1040000001',
#   'TotalOfBookValueLandBuildings': '0',
#   'FootnoteInPartXIII': 'X',
#   'Form990ScheduleDPartXIII': {'Identifier': 'Description of Uncertain Tax Positions Under FIN 48:',
#    'ReturnReference': 'Part X, Line 2:',
#    'Explanation': 'Harvey L. Miller Supporting Foundation (the Foundation) is exempt from income taxes under Section 501(c)(3) of the Internal Revenue Code and applicable state law. The accounting standard on accounting for uncertainty in income taxes addresses the determination of whether tax benefits claimed or expected to be claimed on a tax return should be recorded in the financial statements. Under this guidance, the Foundation may recognize the tax benefit from an uncertain tax position only if it is more likely than not that the tax position will be sustained on examination by taxing authorities, based on the technical merits of the position. The tax benefits recognized in the financial statements from such a position are measured based on the largest benefit that has a greater than 50 percent likelihood of being realized upon ultimate settlement. At June 30, 2013, there were no unrecognized tax benefits identified or recorded as liabilities. The Foundation files Form 990 in the U.S. federal jurisdiction and the State of Illinois. The Foundation is generally no longer subject to examination by the Internal Revenue Service for years before 2010.'}},
#  'IRS990ScheduleI': {'@documentId': 'RetDoc1041900001',
#   'RecordsMaintained': '1',
#   'RecipientTable': [{'RecipientNameBusiness': {'BusinessNameLine1': 'Inner-City Computer Stars Foundation'},
#     'AddressUS': {'AddressLine1': '212 West Superior 300',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60610'},
#     'EINOfRecipient': '364253411',
#     'IRCSection': '501(C)(3)',
#     'AmountOfCashGrant': '50000',
#     'PurposeOfGrant': 'General Operating Support'},
#    {'RecipientNameBusiness': {'BusinessNameLine1': 'Jewish Theological Seminary'},
#     'AddressUS': {'AddressLine1': '3080 Broadway',
#      'City': 'New York',
#      'State': 'NY',
#      'ZIPCode': '10027'},
#     'EINOfRecipient': '136167967',
#     'IRCSection': '501(C)(3)',
#     'AmountOfCashGrant': '250000',
#     'PurposeOfGrant': 'General Operating Support'},
#    {'RecipientNameBusiness': {'BusinessNameLine1': 'Anti-Defamation League'},
#     'AddressUS': {'AddressLine1': '605 Third Avenue',
#      'City': 'New York',
#      'State': 'NY',
#      'ZIPCode': '10158'},
#     'EINOfRecipient': '131818723',
#     'IRCSection': '501(C)(3)',
#     'AmountOfCashGrant': '100000',
#     'PurposeOfGrant': 'General Operating Support'},
#    {'RecipientNameBusiness': {'BusinessNameLine1': 'The Schechter Institutes Inc'},
#     'AddressUS': {'AddressLine1': '2300 Computer Ave Suite D-18',
#      'City': 'Willow Grove',
#      'State': 'PA',
#      'ZIPCode': '19090'},
#     'EINOfRecipient': '223342043',
#     'IRCSection': '501(C)(3)',
#     'AmountOfCashGrant': '100000',
#     'PurposeOfGrant': 'General Operating Support'},
#    {'RecipientNameBusiness': {'BusinessNameLine1': 'Jewish United Fund of Metropolitan Chicago'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EINOfRecipient': '362167034',
#     'IRCSection': '501(C)(3)',
#     'AmountOfCashGrant': '200000',
#     'PurposeOfGrant': 'General Operating Support'},
#    {'RecipientNameBusiness': {'BusinessNameLine1': 'Shedd Aquarium Society'},
#     'AddressUS': {'AddressLine1': '1200 S Lake Shore Drive',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60605'},
#     'EINOfRecipient': '362167918',
#     'IRCSection': '501(C)(3)',
#     'AmountOfCashGrant': '250000',
#     'PurposeOfGrant': 'General Operating Support'},
#    {'RecipientNameBusiness': {'BusinessNameLine1': 'Chicagoland Jewish High School'},
#     'AddressUS': {'AddressLine1': '1095 Lake Cook Road',
#      'City': 'Deerfield',
#      'State': 'IL',
#      'ZIPCode': '60015'},
#     'EINOfRecipient': '364167962',
#     'IRCSection': '501(C)(3)',
#     'AmountOfCashGrant': '100000',
#     'PurposeOfGrant': 'General Operating Support'},
#    {'RecipientNameBusiness': {'BusinessNameLine1': 'Congregation Beth Shalom'},
#     'AddressUS': {'AddressLine1': '3433 Walters Ave',
#      'City': 'Northbrook',
#      'State': 'IL',
#      'ZIPCode': '60062'},
#     'EINOfRecipient': '362661160',
#     'IRCSection': '501(C)(3)',
#     'AmountOfCashGrant': '100000',
#     'PurposeOfGrant': 'General Operating Support'},
#    {'RecipientNameBusiness': {'BusinessNameLine1': 'Illinois Holocaust Museum and Education Center'},
#     'AddressUS': {'AddressLine1': '9603 Woods Drive',
#      'City': 'Skokie',
#      'State': 'IL',
#      'ZIPCode': '60077'},
#     'EINOfRecipient': '363156154',
#     'IRCSection': '501(C)(3)',
#     'AmountOfCashGrant': '100000',
#     'PurposeOfGrant': 'General Operating Support'},
#    {'RecipientNameBusiness': {'BusinessNameLine1': 'Cantors Assembly Inc'},
#     'AddressUS': {'AddressLine1': '55 South Miller Road No 201',
#      'City': 'Fairlawn',
#      'State': 'OH',
#      'ZIPCode': '44333'},
#     'EINOfRecipient': '131959506',
#     'IRCSection': '501(C)(3)',
#     'AmountOfCashGrant': '50000',
#     'PurposeOfGrant': 'General Operating Support'}],
#   'TotalNbrOf501C3AndGovtGrants': '10',
#   'TotalNbrOfOtherOrganizations': '0',
#   'Form990ScheduleIPartIV': {'Identifier': 'Procedure for Monitoring Grants in the U.S.:',
#    'ReturnReference': 'Part I, Line 2:',
#    'Explanation': 'Schedule I, Part I, Line 2: Foundation staff perform due diligence on all organizations seeking grants from the Foundation and review grant compliance each year.'}},
#  'IRS990ScheduleJ': {'@documentId': 'RetDoc1042400001',
#   'SeverancePayment': '0',
#   'SupplementalNonqualRetirePlan': '1',
#   'EquityBasedCompArrangement': '0',
#   'CompBasedOnRevenueOfFilingOrg': '0',
#   'CompBasedOnRevenueRelatedOrgs': '0',
#   'CompBasedNetEarningsFilingOrg': '0',
#   'CompBasedNetEarningsRelateOrgs': '0',
#   'AnyNonFixedPayments': '0',
#   'InitialContractException': '0',
#   'Form990ScheduleJPartII': [{'NamePerson': 'Steven B Nasatir',
#     'Title': 'Vice President',
#     'BaseCompensationFilingOrg': '0',
#     'CompBasedOnRelatedOrgs': '448049',
#     'BonusFilingOrg': '0',
#     'BonusRelatedOrgs': '0',
#     'OtherCompensationFilingOrg': '0',
#     'OtherCompensationRelatedOrgs': '174294',
#     'DeferredCompFilingOrg': '0',
#     'DeferredCompRelatedOrgs': '72319',
#     'NontaxableBenefitsFilingOrg': '0',
#     'NontaxableBenefitsRelatedOrgs': '17277',
#     'TotalCompensationFilingOrg': '0',
#     'TotalCompensationRelatedOrgs': '711939',
#     'CompReportPrior990FilingOrg': '0',
#     'CompReportPrior990RelatedOrgs': '0'},
#    {'NamePerson': 'David S Rosen',
#     'Title': 'Treasurer',
#     'BaseCompensationFilingOrg': '0',
#     'CompBasedOnRelatedOrgs': '285348',
#     'BonusFilingOrg': '0',
#     'BonusRelatedOrgs': '0',
#     'OtherCompensationFilingOrg': '0',
#     'OtherCompensationRelatedOrgs': '12044',
#     'DeferredCompFilingOrg': '0',
#     'DeferredCompRelatedOrgs': '121264',
#     'NontaxableBenefitsFilingOrg': '0',
#     'NontaxableBenefitsRelatedOrgs': '8853',
#     'TotalCompensationFilingOrg': '0',
#     'TotalCompensationRelatedOrgs': '427509',
#     'CompReportPrior990FilingOrg': '0',
#     'CompReportPrior990RelatedOrgs': '0'},
#    {'NamePerson': 'Peter Chiswick',
#     'Title': 'Assistant Treasurer',
#     'BaseCompensationFilingOrg': '0',
#     'CompBasedOnRelatedOrgs': '151291',
#     'BonusFilingOrg': '0',
#     'BonusRelatedOrgs': '0',
#     'OtherCompensationFilingOrg': '0',
#     'OtherCompensationRelatedOrgs': '1067',
#     'DeferredCompFilingOrg': '0',
#     'DeferredCompRelatedOrgs': '42815',
#     'NontaxableBenefitsFilingOrg': '0',
#     'NontaxableBenefitsRelatedOrgs': '9077',
#     'TotalCompensationFilingOrg': '0',
#     'TotalCompensationRelatedOrgs': '204250',
#     'CompReportPrior990FilingOrg': '0',
#     'CompReportPrior990RelatedOrgs': '0'}],
#   'Form990ScheduleJPartIII': {'ReturnReference': 'Part I, Line 4b',
#    'Explanation': 'Steven B. Nasatir: In 1999 the Jewish Federation entered into an agreement with Steven Nasatir that was contingent upon 5 more years of service as president and CEO and would result in annual payments of $50,000 per year (net of tax) beginning at age 64 and lasting throughout his lifetime. Dr. Nasatir began receiving payments under this agreement in 2009. During 2012, the Jewish Federation entered into a second agreement with Steven Nasatir which provides for annual payments of $5,000 beginning April 1, 2015 and lasting throughout his lifetime. Steven Nasatir became fully vested in this benefit during 2012 and as a result, $116,876 has been included on the Form 990 as compensation in Part VII and Schedule J. This $116,876 was not paid to Dr. Nasatir in 2012, but it instead represents the present value of the future stream of payments due under this agreement. Per IRS guidelines, the present value of the annuity is taxable the year in which vesting occurs. On a cash basis, Dr. Nasatir did not receive any payments from this arrangement in 2012. The $50,000 and $5,000 annual payment amounts are to be adjusted annually in accordance with the CPI index. These benefits are payable to him only for as long as he lives. There are no guaranteed payment amounts and no survivor benefits at his death. In 2012, Steven Nasatir received payments of $68,832 from the first supplemental non-qualified retirement plan. David Rosen: The Jewish Federation has an agreement with David Rosen which provides for annual payments of $25,000 per year beginning in 2018 and lasting for ten years.'}},
#  'IRS990ScheduleO': {'@documentId': 'RetDoc1044400001',
#   'GeneralExplanation': [{'ReturnReference': 'Form 990, Part VI, Section A, line 6',
#     'Explanation': 'The by-laws stipulate that members of the Foundation are divided into three classes: the donor member, the independent member and the publicly supported organization member, which is the Jewish Federation of Metropolitan Chicago.'},
#    {'ReturnReference': 'Form 990, Part VI, Section A, line 7a',
#     'Explanation': 'The Board of Directors consists of 3 total persons, 1 of whom is elected by the donor member, 1 of whom is elected by the independent member and 1 of whom is elected by the publicly supported organization member pursuant to its established procedures.'},
#    {'ReturnReference': 'Form 990, Part VI, Section B, line 11',
#     'Explanation': 'The voting members of the governing body reviewed the Form 990 prior to filing with the IRS.'},
#    {'ReturnReference': 'Form 990, Part VI, Section B, line 12c',
#     'Explanation': "A conflict of interest questionnaire is circulated to all board members on an annual basis. This process is managed by the Foundation's secretary who ensures that all questionnaires are completed. The completed questionnaires are reviewed and any conflicts are disclosed to the board of directors. If a director does have a conflict or business relationship, he or she is required to abstain from any votes related to that matter."},
#    {'ReturnReference': 'Form 990, Part VI, Section C, line 19',
#     'Explanation': 'The organization made its governing documents, conflict of interest policy, and financial statements available to the public during the tax year upon request.'}]},
#  'IRS990ScheduleR': {'@documentId': 'RetDoc1043400001',
#   'Form990ScheduleRPartII': [{'NameOfDisregardedEntity': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '362167761',
#     'PrimaryActivities': 'Social Welfare Institution',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(c)(3)',
#     'PublicCharityStatus': 'Line 7',
#     'DirectControllingEntityNA': 'N/A',
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'JFMC Facilities Corporation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '363368912',
#     'PrimaryActivities': 'Property Management of Related Non-Profit Organizations',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(c)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Jewish United Fund of Metropolitan Chicago'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '362167034',
#     'PrimaryActivities': 'Fundraising & Grantmaking',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(c)(3)',
#     'PublicCharityStatus': 'Line 7',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Karl Perl Charitable Trust'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '466113637',
#     'PrimaryActivities': 'Support the Jewish United Fund',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(c)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish United Fund of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': '1261 Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364018186',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Arnold I & Bette Sobel Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '311528640',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Bellows Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '363864415',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'BLS Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364420871',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Bucksbaum Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364341914',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Carol Lavin Bernick Family Supporting Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364067510',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Charles & Audrey Dann Charitable Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364018189',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Chicago Center for Jewish Genetic Disorders'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '200120266',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'The First Spoke Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '200894628',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Crown Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '363330462',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Epstein Wenger Family Support Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364380168',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Eva Cooper Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '363436617',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Eve and Stuart L Pinkert Family Charitable Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '367230842',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Glickman Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '363857009',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Goodman Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364018187',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Helene Diamond & Jorde Nathan Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364157242',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Hillels of Illinois Endowment Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364310755',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Irvin & Ruth Swartzberg Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '363864416',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'JFMCP3 Corporation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '262053862',
#     'PrimaryActivities': 'Supporting Organization',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Lawrence E & Nancy S Glick Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '363662985',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Leibow Family Supporting Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '201420425',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Leonard and Diane Sherman Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364345181',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Leonard Rose Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364420873',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Lya and Louis Rosenblum Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '311529058',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Manfred and Fern Steinfeld Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364244346',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Michael Reese Health Trust'},
#     'AddressUS': {'AddressLine1': '150 North Wacker Drive Suite 2320',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '362170910',
#     'PrimaryActivities': 'Grantmaking',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'PF',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Paul G Delman Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '363914632',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Prairie Minerals Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '320062771',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'The Pritzker Family Philanthropic Fund'},
#     'AddressUS': {'AddressLine1': '71 S Wacker Drive Ste 4600',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '363623264',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Ring Family Supporting Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '201642012',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Robert U & Roberta Goldman Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '203921714',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Robert L & Sylvia M Haag Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '300149729',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Rose Family Supporting Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '205389086',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Sarnoff Levin Family Supporting Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364157233',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Seder Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '363988995',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Sisyphus Supporting Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '205944850',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Tamar & Jonathan Koschitzky Family Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '300149723',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'The Robert and Yadelle Sklare Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364389423',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': "Wagner Descendant's Foundation"},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '204004517',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Weiss Memorial Hospital Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '364413031',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'},
#    {'NameOfDisregardedEntity': {'BusinessNameLine1': 'Z Frank Camp Apachi Supporting Foundation'},
#     'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#      'City': 'Chicago',
#      'State': 'IL',
#      'ZIPCode': '60606'},
#     'EIN': '363833108',
#     'PrimaryActivities': 'Supporting Foundation',
#     'LegalDomicileState': 'IL',
#     'ExemptCodeSection': '501(C)(3)',
#     'PublicCharityStatus': 'Line 11a, I',
#     'DirectControllingEntityName': {'BusinessNameLine1': 'Jewish Federation of Metropolitan Chicago'},
#     'ControlledOrg': '0'}],
#   'ReceiptOfIntAnnRentsRoyalties': '0',
#   'GiftGrantOrCapContrToOtherOrg': '1',
#   'GiftGrantOrCapContrFrOtherOrg': '0',
#   'LoansOrGuaranteesToOtherOrg': '0',
#   'LoansOrGuaranteesFromOtherOrg': '0',
#   'DividendsRelatedOrganization': '0',
#   'SaleOfAssetsToOtherOrg': '0',
#   'PurchaseOfAssetsFromOtherOrg': '0',
#   'ExchangeOfAssets': '0',
#   'RentalOfFacilitiesToOtherOrgs': '0',
#   'RentalOfFacilitiesFrOtherOrgs': '0',
#   'PerformOfServicesForOtherOrgs': '0',
#   'PerformOfServicesByOtherOrgs': '0',
#   'SharingOfFacilities': '0',
#   'SharingOfPaidEmployees': '0',
#   'ReimbursementPaidToOtherOrg': '0',
#   'ReimbursementPaidByOtherOrg': '0',
#   'OtherTransferToOtherOrg': '0',
#   'OtherTransferFromOtherOrg': '0',
#   'Form990ScheduleRPartVII': [{'Identifier': 'Portfolio, LLC: To serve as an endowment investment solution for',
#     'ReturnReference': 'Schedule R, Part III, column (b), Primary Activity - JFMC Pooled Endowment',
#     'Explanation': 'charitable organizations pursuing Jewish philanthropic goals and provides access to professional investment management, administration, and reporting for its members.'},
#    {'Identifier': 'a Corporation or Trust: Split interest trusts, in order to preserve donor',
#     'ReturnReference': 'Schedule R, Part IV, Identification of Related Organizations Taxable as',
#     'Explanation': 'privacy, and in accordance with the 2012 IRS instructions for Schedule R, the organization has refrained from disclosing the details of split interest trusts and has instead reported the aggregate number of charitable remainder unitrusts and charitable remainder annuity trusts. The trusts listed are domiciled in Illinois.'}]},
#  '@documentId': 'RetDoc1038000001',
#  '@referenceDocumentId': 'RetDoc1044400001',
#  'NameOfPrincipalOfficerPerson': 'L Khanuk',
#  'AddressPrincipalOfficerUS': {'AddressLine1': '30 South Wells Street No 4049',
#   'City': 'Chicago',
#   'State': 'IL',
#   'ZIPCode': '60606'},
#  'GrossReceipts': '1226094',
#  'GroupReturnForAffiliates': '0',
#  'Organization501c3': 'X',
#  'WebSite': 'N/A',
#  'TypeOfOrganizationCorporation': 'X',
#  'YearFormation': '2005',
#  'StateLegalDomicile': 'IL',
#  'ActivityOrMissionDescription': 'The Foundation is organized to foster, promote, support, develop, and maintain the broad, charitable, educational or religious purposes or functions as authorized by the charter of the Jewish Federation of Metropolitan Chicago and the by-laws of the Foundation.',
#  'NbrVotingMembersGoverningBody': '3',
#  'NbrIndependentVotingMembers': '2',
#  'TotalNbrEmployees': '0',
#  'TotalNbrVolunteers': '2',
#  'TotalGrossUBI': '0',
#  'NetUnrelatedBusinessTxblIncome': '0',
#  'ContributionsGrantsPriorYear': '1227770',
#  'ContributionsGrantsCurrentYear': '1225570',
#  'ProgramServiceRevenuePriorYear': '0',
#  'ProgramServiceRevenueCY': '0',
#  'InvestmentIncomePriorYear': '1395',
#  'InvestmentIncomeCurrentYear': '524',
#  'OtherRevenuePriorYear': '0',
#  'OtherRevenueCurrentYear': '0',
#  'TotalRevenuePriorYear': '1229165',
#  'TotalRevenueCurrentYear': '1226094',
#  'GrantsAndSimilarAmntsPriorYear': '1150000',
#  'GrantsAndSimilarAmntsCY': '1300000',
#  'BenefitsPaidToMembersPriorYear': '0',
#  'BenefitsPaidToMembersCY': '0',
#  'SalariesEtcPriorYear': '0',
#  'SalariesEtcCurrentYear': '0',
#  'TotalProfFundrsngExpPriorYear': '0',
#  'TotalProfFundrsngExpCY': '0',
#  'TotalFundrsngExpCurrentYear': '0',
#  'OtherExpensePriorYear': '1638',
#  'OtherExpensesCurrentYear': '1610',
#  'TotalExpensesPriorYear': '1151638',
#  'TotalExpensesCurrentYear': '1301610',
#  'RevenuesLessExpensesPriorYear': '77527',
#  'RevenuesLessExpensesCY': '-75516',
#  'TotalAssetsBOY': '78945',
#  'TotalAssetsEOY': '3429',
#  'TotalLiabilitiesBOY': '1600',
#  'TotalLiabilitiesEOY': '1600',
#  'NetAssetsOrFundBalancesBOY': '77345',
#  'NetAssetsOrFundBalancesEOY': '1829',
#  'MissionDescription': 'The Foundation is organized to foster, promote, support, develop, and maintain the broad, charitable, educational or religious purposes or functions as authorized by the charter of the Jewish Federation of Metropolitan Chicago and the by-laws of the Foundation.',
#  'SignificantNewProgramServices': '0',
#  'SignificantChange': '0',
#  'Expense': '1300000',
#  'Grants': '1300000',
#  'Description': 'The Foundation makes grants to charitable organizations which are tax exempt under the IRC Section 501(c)(3) and meet the guidelines of the charter of the Jewish Federation of Metropolitan Chicago & the by-laws of the Foundation.',
#  'TotalProgramServiceExpense': '1300000',
#  'DescribedIn501C3': {'@referenceDocumentId': 'RetDoc1039100001',
#   '#text': '1'},
#  'ScheduleBRequired': {'@referenceDocumentId': 'RetDoc1234500001',
#   '#text': '1'},
#  'PoliticalActivities': '0',
#  'LobbyingActivities': '0',
#  'SubjectToProxyTax': '0',
#  'DonorAdvisedFunds': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'ConservationEasements': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'CollectionsOfArt': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'CreditCounseling': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'TermOrPermanentEndowments': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'ReportLandBldgEquip': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'ReportInvestOthSecurities': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'ReportProgRelInvest': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'ReportOtherAssets': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'ReportOtherLiabilities': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'ReportFin48Footnote': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '1'},
#  'IndependentAuditFinancialStmt': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '0'},
#  'ConsolidatedAuditFinancialStmt': {'@referenceDocumentId': 'RetDoc1040000001',
#   '#text': '1'},
#  'School': '0',
#  'ForeignOffice': '0',
#  'ForeignActivities': '0',
#  'MoreThan5000KToOrganizations': '0',
#  'MoreThan5000KToIndividuals': '0',
#  'ProfessionalFundraising': '0',
#  'FundraisingActivities': '0',
#  'Gaming': '0',
#  'Hospital': '0',
#  'GrantsToOrganizations': {'@referenceDocumentId': 'RetDoc1041900001',
#   '#text': '1'},
#  'GrantsToIndividuals': {'@referenceDocumentId': 'RetDoc1041900001',
#   '#text': '0'},
#  'ScheduleJRequired': {'@referenceDocumentId': 'RetDoc1042400001',
#   '#text': '1'},
#  'TaxExemptBonds': '0',
#  'ExcessBenefitTransaction': '0',
#  'PriorExcessBenefitTransaction': '0',
#  'LoanToOfficerOrDQP': '0',
#  'GrantToRelatedPerson': '0',
#  'BsnssRltnshpWithOrganization': '0',
#  'BsnssRltnshpThruFamilyMember': '0',
#  'OfficerEntityWithBsnssRltnshp': '0',
#  'DeductibleNonCashContributions': '0',
#  'DeductibleContributionsOfArt': '0',
#  'Terminated': '0',
#  'PartialLiquidation': '0',
#  'DisregardedEntity': {'@referenceDocumentId': 'RetDoc1043400001',
#   '#text': '0'},
#  'RelatedEntity': {'@referenceDocumentId': 'RetDoc1043400001', '#text': '1'},
#  'RelatedOrgControlledEntity': '0',
#  'TransfersToExemptNonChrtblOrg': {'@referenceDocumentId': 'RetDoc1043400001',
#   '#text': '0'},
#  'ActivitiesConductedPartnership': {'@referenceDocumentId': 'RetDoc1043400001',
#   '#text': '0'},
#  'ScheduleORequired': '1',
#  'NumberFormsTransmittedWith1096': '0',
#  'NumberW2GIncluded': '0',
#  'NumberOfEmployees': '0',
#  'UnrelatedBusinessIncome': '0',
#  'ForeignFinancialAccount': '0',
#  'ProhibitedTaxShelterTrans': '0',
#  'TaxablePartyNotification': '0',
#  'NonDeductibleContributions': '0',
#  'QuidProQuoContributions': '0',
#  'Form8282PropertyDisposedOf': '0',
#  'FundsToPayPremiums': '0',
#  'PremiumsPaid': '0',
#  'IndoorTanningServices': '0',
#  'InfoInScheduleOPartVI': 'X',
#  'NbrVotingGoverningBodyMembers': '3',
#  'NumberIndependentVotingMembers': '2',
#  'FamilyOrBusinessRelationship': '0',
#  'DelegationOfManagementDuties': '0',
#  'ChangesToOrganizingDocs': '0',
#  'MaterialDiversionOrMisuse': '0',
#  'MembersOrStockholders': '1',
#  'ElectionOfBoardMembers': '1',
#  'DecisionsSubjectToApproval': '0',
#  'MinutesOfGoverningBody': '1',
#  'MinutesOfCommittees': '1',
#  'OfficerMailingAddress': '0',
#  'LocalChapters': '0',
#  'Form990ProvidedToGoverningBody': '1',
#  'ConflictOfInterestPolicy': '1',
#  'AnnualDisclosureCoveredPersons': '1',
#  'RegularMonitoringEnforcement': '1',
#  'WhistleblowerPolicy': '1',
#  'DocumentRetentionPolicy': '1',
#  'CompensationProcessCEO': '0',
#  'CompensationProcessOther': '0',
#  'InvestmentInJointVenture': '0',
#  'StatesWhereCopyOfReturnIsFiled': 'IL',
#  'UponRequest': 'X',
#  'TheBooksAreInCareOf': {'NameBusiness': {'BusinessNameLine1': 'Peter Chiswick'},
#   'TelephoneNumber': '3124442814',
#   'AddressUS': {'AddressLine1': '30 South Wells Suite 4049',
#    'City': 'Chicago',
#    'State': 'IL',
#    'ZIPCode': '60606'}},
#  'Form990PartVIISectionA': [{'NamePerson': 'L Khanuk',
#    'Title': 'President',
#    'AverageHoursPerWeek': '0.30',
#    'IndividualTrusteeOrDirector': 'X',
#    'Officer': 'X',
#    'ReportableCompFromOrganization': '0',
#    'ReportableCompFromRelatedOrgs': '0',
#    'OtherCompensation': '0'},
#   {'NamePerson': 'Jeff Kauffman',
#    'Title': 'Director',
#    'AverageHoursPerWeek': '0.30',
#    'IndividualTrusteeOrDirector': 'X',
#    'ReportableCompFromOrganization': '0',
#    'ReportableCompFromRelatedOrgs': '0',
#    'OtherCompensation': '0'},
#   {'NamePerson': 'Steven B Nasatir',
#    'Title': 'Vice President',
#    'AverageHoursPerWeek': '0.30',
#    'AverageHoursPerWeekRelated': '49.70',
#    'IndividualTrusteeOrDirector': 'X',
#    'Officer': 'X',
#    'ReportableCompFromOrganization': '0',
#    'ReportableCompFromRelatedOrgs': '622343',
#    'OtherCompensation': '88818'},
#   {'NamePerson': 'David S Rosen',
#    'Title': 'Treasurer',
#    'AverageHoursPerWeek': '0.30',
#    'AverageHoursPerWeekRelated': '49.70',
#    'Officer': 'X',
#    'ReportableCompFromOrganization': '0',
#    'ReportableCompFromRelatedOrgs': '297392',
#    'OtherCompensation': '129340'},
#   {'NamePerson': 'Peter Chiswick',
#    'Title': 'Assistant Treasurer',
#    'AverageHoursPerWeek': '0.30',
#    'AverageHoursPerWeekRelated': '49.70',
#    'Officer': 'X',
#    'ReportableCompFromOrganization': '0',
#    'ReportableCompFromRelatedOrgs': '152358',
#    'OtherCompensation': '51352'},
#   {'NamePerson': 'Rose Jagust',
#    'Title': 'Secretary',
#    'AverageHoursPerWeek': '0.30',
#    'AverageHoursPerWeekRelated': '39.70',
#    'Officer': 'X',
#    'ReportableCompFromOrganization': '0',
#    'ReportableCompFromRelatedOrgs': '105449',
#    'OtherCompensation': '35238'}],
#  'TotalReportableCompFromOrg': '0',
#  'TotalReportableCompFrmRltdOrgs': '1177542',
#  'TotalOtherCompensation': '304748',
#  'NumberIndividualsGT100K': '0',
#  'FormersListed': '0',
#  'TotalCompGT150K': '1',
#  'CompensationFromOtherSources': '0',
#  'NumberOfContractorsGT100K': '0',
#  'AllOtherContributions': '1225570',
#  'TotalContributions': '1225570',
#  'InvestmentIncome': {'TotalRevenueColumn': '524', 'ExclusionAmount': '524'},
#  'TotalRevenue': {'TotalRevenueColumn': '1226094',
#   'RelatedOrExemptFunctionIncome': '0',
#   'UnrelatedBusinessRevenue': '0',
#   'ExclusionAmount': '524'},
#  'GrantsToDomesticOrgs': {'Total': '1300000', 'ProgramServices': '1300000'},
#  'FeesForServicesAccounting': {'Total': '1600',
#   'ManagementAndGeneral': '1600'},
#  'OtherExpenses': {'Description': 'Filing Fees',
#   'Total': '10',
#   'ManagementAndGeneral': '10'},
#  'TotalFunctionalExpenses': {'Total': '1301610',
#   'ProgramServices': '1300000',
#   'ManagementAndGeneral': '1610',
#   'Fundraising': '0'},
#  'SavingsAndTempCashInvestments': {'BOY': '78945', 'EOY': '3429'},
#  'TotalAssets': {'BOY': '78945', 'EOY': '3429'},
#  'AccountsPayableAccruedExpenses': {'BOY': '1600', 'EOY': '1600'},
#  'TotalLiabilities': {'BOY': '1600', 'EOY': '1600'},
#  'DoNotFollowSFAS117': 'X',
#  'CapStckTrstPrinCurrentFunds': {'BOY': '0', 'EOY': '0'},
#  'PaidInCapSrplsLandBldgEqpFund': {'BOY': '0', 'EOY': '0'},
#  'RetainedEarningsEndowmentEtc': {'BOY': '77345', 'EOY': '1829'},
#  'TotalNetAssetsFundBalances': {'BOY': '77345', 'EOY': '1829'},
#  'TotalLiabNetAssetsFundBalances': {'BOY': '78945', 'EOY': '3429'},
#  'ReconcilationRevenueExpenses': '-75516',
#  'ReconcilationOtherChanges': '0',
#  'MethodOfAccountingAccrual': 'X',
#  'AccountantCompileOrReview': '0',
#  'FSAudited': '1',
#  'FSAuditedBasis': {'FinancialStatementConsolidated': 'X'},
#  'AuditCommittee': '1',
#  'FederalGrantAuditRequired': '0'}

# %%
db.filings_990.find_one({'URL' : "https://s3.amazonaws.com/irs-form-990/201100289349300910_public.xml" })
# Out:
# {'_id': ObjectId('5d01cfed78ffca27b428aa97'),
#  'OrganizationName': 'ASSEMBLEIA DE DEUS MINISTERIO BELEM CHUR',
#  'ObjectId': '201100289349300910',
#  'URL': 'https://s3.amazonaws.com/irs-form-990/201100289349300910_public.xml',
#  'SubmittedOn': '2011-09-22',
#  'DLN': '93493028009101',
#  'LastUpdated': '2016-03-21T17:23:53',
#  'TaxPeriod': '201012',
#  'FormType': '990',
#  'EIN': '954745380',
#  '@xmlns': 'http://www.irs.gov/efile',
#  '@returnVersion': '2010v3.2',
#  'ReturnHeader': {'@binaryAttachmentCount': '0',
#   'Timestamp': '2011-01-28T13:07:07-08:00',
#   'TaxPeriodEndDate': '2010-12-31',
#   'PreparerFirm': {'PreparerFirmBusinessName': {'BusinessNameLine1': 'VIRULAS GENERAL OFFICE'},
#    'PreparerFirmUSAddress': {'AddressLine1': '4138 ATLANTIC AVE',
#     'City': 'Long Beach',
#     'State': 'CA',
#     'ZIPCode': '90807'}},
#   'ReturnType': '990',
#   'TaxPeriodBeginDate': '2010-01-01',
#   'Filer': {'EIN': '954745380',
#    'Name': {'BusinessNameLine1': 'ASSEMBLEIA DE DEUS MINISTERIO BELEM CHUR'},
#    'NameControl': 'ASSE',
#    'USAddress': {'AddressLine1': '6520 ARIZONA AVE',
#     'City': 'Los Angeles',
#     'State': 'CA',
#     'ZIPCode': '90045'}},
#   'Officer': {'Name': 'JOEL A DA SILVA',
#    'Title': 'PASTOR',
#    'Phone': '3104149879',
#    'DateSigned': '2011-01-19',
#    'AuthorizeThirdParty': 'false'},
#   'Preparer': {'Name': 'MARIO R VIRULA',
#    'Phone': '5629881169',
#    'DatePrepared': '2011-01-28',
#    'SelfEmployed': 'X'},
#   'TaxYear': '2010',
#   'BuildTS': '2016-02-24 21:20:13Z'},
#  '@documentCount': '3',
#  'IRS990ScheduleA': {'@documentId': '990A', 'Church170b1Ai': 'X'},
#  'IRS990ScheduleO': {'@documentId': '990O',
#   'GeneralExplanation': [{'Identifier': '01. Form 990 governing body review (Part VI, line 11)',
#     'Explanation': 'JOEL A DA SILVA IS AUTHORIZED TO REVIEW AND SIGN WITHOUT THE GOVERNING BODY'},
#    {'Identifier': '02. Governing documents, etc, available to public (Part VI, line 19)',
#     'Explanation': 'nNO OTHER DOCUMENTS ARE AVAILABLE TO THE PUBLIC'}]},
#  '@documentId': '990',
#  'NameOfPrincipalOfficerPerson': 'JOEL A DA SILVA',
#  'GrossReceipts': '68057',
#  'GroupReturnForAffiliates': 'false',
#  'Organization501c3': 'X',
#  'TypeOfOrganizationOther': 'X',
#  'TypeOfOrgOtherDescription': 'CHURCH',
#  'YearFormation': '1999',
#  'StateLegalDomicile': 'CA',
#  'ActivityOrMissionDescription': 'FAMILIES AND TEENAGERS ARE COUNCELED AND SHOWN A BETTER ALTERNATIVE FROM GANGS DIVORCES TO FORM A BETTER SOCIETY',
#  'NbrVotingMembersGoverningBody': '7',
#  'NbrIndependentVotingMembers': '0',
#  'TotalNbrEmployees': '0',
#  'TotalGrossUBI': '0',
#  'NetUnrelatedBusinessTxblIncome': '0',
#  'ContributionsGrantsCurrentYear': '68057',
#  'ProgramServiceRevenueCY': '0',
#  'InvestmentIncomeCurrentYear': '0',
#  'OtherRevenueCurrentYear': '0',
#  'TotalRevenueCurrentYear': '68057',
#  'GrantsAndSimilarAmntsCY': '0',
#  'BenefitsPaidToMembersCY': '0',
#  'SalariesEtcCurrentYear': '23400',
#  'TotalProfFundrsngExpCY': '0',
#  'TotalFundrsngExpCurrentYear': '0',
#  'OtherExpensesCurrentYear': '43346',
#  'TotalExpensesCurrentYear': '66746',
#  'RevenuesLessExpensesCY': '1311',
#  'TotalAssetsEOY': '1311',
#  'TotalLiabilitiesEOY': '0',
#  'NetAssetsOrFundBalancesEOY': '1311',
#  'MissionDescription': 'FAMILIES AND TEENAGERS ARE COUNCELED AND SHOWN A BETTER ALTERNATIVE FROM GANGS DIVORCES TO FORM A BETTER SOCIETY',
#  'SignificantNewProgramServices': 'false',
#  'SignificantChange': 'false',
#  'Expense': '66746',
#  'Description': 'ALL FAMILIES YOUTHS AND PEOPLE FROM VARIOUS BACKROUNDS ARE COUNCELED AND SHOWN A BETTER WAY OF LIFE THAN FROM DIVORCES AND GANGS AND DRUGS SO THAT WE CAN FORM A BETTER SOCIETY',
#  'TotalProgramServiceExpense': '66746',
#  'DescribedIn501C3': {'@referenceDocumentId': '990A', '#text': 'true'},
#  'ScheduleBRequired': 'false',
#  'PoliticalActivities': 'false',
#  'LobbyingActivities': 'false',
#  'DonorAdvisedFunds': 'false',
#  'ConservationEasements': 'false',
#  'CollectionsOfArt': 'false',
#  'CreditCounseling': 'false',
#  'TermOrPermanentEndowments': 'false',
#  'ReportLandBldgEquip': 'false',
#  'ReportInvestOthSecurities': 'false',
#  'ReportProgRelInvest': 'false',
#  'ReportOtherAssets': 'false',
#  'ReportOtherLiabilities': 'false',
#  'ReportFin48Footnote': 'false',
#  'IndependentAuditFinancialStmt': 'false',
#  'ConsolidatedAuditFinancialStmt': 'false',
#  'School': 'false',
#  'ForeignOffice': 'false',
#  'ForeignActivities': 'false',
#  'MoreThan5000KToOrganizations': 'false',
#  'MoreThan5000KToIndividuals': 'false',
#  'ProfessionalFundraising': 'false',
#  'FundraisingActivities': 'false',
#  'Gaming': 'false',
#  'Hospital': 'false',
#  'GrantsToOrganizations': 'false',
#  'GrantsToIndividuals': 'false',
#  'ScheduleJRequired': 'false',
#  'TaxExemptBonds': 'false',
#  'ExcessBenefitTransaction': 'false',
#  'PriorExcessBenefitTransaction': 'false',
#  'LoanToOfficerOrDQP': 'false',
#  'GrantToRelatedPerson': 'false',
#  'BsnssRltnshpWithOrganization': 'false',
#  'BsnssRltnshpThruFamilyMember': 'false',
#  'OfficerEntityWithBsnssRltnshp': 'false',
#  'DeductibleNonCashContributions': 'false',
#  'DeductibleContributionsOfArt': 'false',
#  'Terminated': 'false',
#  'PartialLiquidation': 'false',
#  'DisregardedEntity': 'false',
#  'RelatedEntity': 'false',
#  'RelatedOrgControlledEntity': 'false',
#  'TransactionRelatedEntity': 'false',
#  'TransfersToExemptNonChrtblOrg': 'false',
#  'ActivitiesConductedPartnership': 'false',
#  'ScheduleORequired': 'true',
#  'NumberFormsTransmittedWith1096': '0',
#  'NumberW2GIncluded': '0',
#  'ComplianceWithBackupWitholding': 'false',
#  'NumberOfEmployees': '0',
#  'EmploymentTaxReturnsFiled': 'false',
#  'UnrelatedBusinessIncome': 'false',
#  'ForeignFinancialAccount': 'false',
#  'ProhibitedTaxShelterTrans': 'false',
#  'TaxablePartyNotification': 'false',
#  'NonDeductibleContributions': 'false',
#  'QuidProQuoContributions': 'false',
#  'Form8282PropertyDisposedOf': 'false',
#  'FundsToPayPremiums': 'false',
#  'PremiumsPaid': 'false',
#  'Form8899Filed': 'false',
#  'Form1098CFiled': 'false',
#  'ExcessBusinessHoldings': 'false',
#  'TaxableDistributions': 'false',
#  'DistributionToDonor': 'false',
#  'IndoorTanningServices': 'false',
#  'InfoInScheduleOPartVI': 'X',
#  'NbrVotingGoverningBodyMembers': '7',
#  'NumberIndependentVotingMembers': '0',
#  'FamilyOrBusinessRelationship': 'false',
#  'DelegationOfManagementDuties': 'false',
#  'ChangesToOrganizingDocs': 'false',
#  'MaterialDiversionOrMisuse': 'false',
#  'MembersOrStockholders': 'false',
#  'ElectionOfBoardMembers': 'false',
#  'DecisionsSubjectToApproval': 'false',
#  'MinutesOfGoverningBody': 'true',
#  'MinutesOfCommittees': 'true',
#  'OfficerMailingAddress': 'false',
#  'LocalChapters': 'false',
#  'Form990ProvidedToGoverningBody': 'false',
#  'ConflictOfInterestPolicy': 'false',
#  'WhistleblowerPolicy': 'false',
#  'DocumentRetentionPolicy': 'false',
#  'CompensationProcessCEO': 'false',
#  'CompensationProcessOther': 'false',
#  'InvestmentInJointVenture': 'false',
#  'StatesWhereCopyOfReturnIsFiled': 'CA',
#  'UponRequest': 'X',
#  'TheBooksAreInCareOf': {'NamePerson': 'JOEL A DA SILVA',
#   'TelephoneNumber': '3104149879',
#   'AddressUS': {'AddressLine1': '6520 ARIZONA AVE',
#    'City': 'Los Angeles',
#    'State': 'CA',
#    'ZIPCode': '90045'}},
#  'Form990PartVIISectionA': {'NamePerson': 'JOEL A DA SILVA',
#   'Title': 'PRESIDENT',
#   'AverageHoursPerWeek': '40.00',
#   'IndividualTrusteeOrDirector': 'X',
#   'Officer': 'X',
#   'KeyEmployee': 'X',
#   'HighestCompensatedEmployee': 'X',
#   'ReportableCompFromOrganization': '23400',
#   'ReportableCompFromRelatedOrgs': '0',
#   'OtherCompensation': '0'},
#  'TotalReportableCompFromOrg': '23400',
#  'TotalReportableCompFrmRltdOrgs': '0',
#  'TotalOtherCompensation': '0',
#  'NumberIndividualsGT100K': '0',
#  'FormersListed': 'false',
#  'TotalCompGT150K': 'false',
#  'CompensationFromOtherSources': 'false',
#  'RelatedOrganizations': '68057',
#  'TotalContributions': '68057',
#  'TotalRevenue': {'TotalRevenueColumn': '68057',
#   'RelatedOrExemptFunctionIncome': '0',
#   'UnrelatedBusinessRevenue': '0',
#   'ExclusionAmount': '0'},
#  'OtherSalariesAndWages': {'Total': '23400', 'ProgramServices': '23400'},
#  'OtherExpenses': {'Description': 'CHURCH EXPENSES',
#   'Total': '43346',
#   'ProgramServices': '43346'},
#  'TotalFunctionalExpenses': {'Total': '66746',
#   'ProgramServices': '66746',
#   'ManagementAndGeneral': '0',
#   'Fundraising': '0'},
#  'CashNonInterestBearing': {'EOY': '1311'},
#  'TotalAssets': {'BOY': '0', 'EOY': '1311'},
#  'TotalLiabilities': {'BOY': '0', 'EOY': '0'},
#  'FollowSFAS117': 'X',
#  'UnrestrictedNetAssets': {'EOY': '1311'},
#  'TotalNetAssetsFundBalances': {'BOY': '0', 'EOY': '1311'},
#  'TotalLiabNetAssetsFundBalances': {'BOY': '0', 'EOY': '1311'},
#  'ReconcilationRevenueExpenses': '1311',
#  'MethodOfAccountingCash': 'X',
#  'AccountantCompileOrReview': 'false',
#  'FSAudited': 'false'}

# %%
for f in filings_990.find({})[2:3]:
    print(sorted(f['IRS990ScheduleJ']))
# Out:
# ['@documentId', '@softwareId', '@softwareVersion', 'AnyNonFixedPayments', 'BoardOrCommitteeApproval', 'CompBasedNetEarningsFilingOrg', 'CompBasedNetEarningsRelateOrgs', 'CompBasedOnRevenueOfFilingOrg', 'CompBasedOnRevenueRelatedOrgs', 'CompensationCommittee', 'CompensationSurvey', 'EquityBasedCompArrangement', 'Form990ScheduleJPartII', 'InitialContractException', 'RebuttablePresumptionProcedure', 'SeverancePayment', 'SupplementalNonqualRetirePlan']

# %%
for f in filings_990.find({})[:1]:
    print(sorted(f.keys()))
# Out:
# ['@documentCount', '@documentId', '@referenceDocumentId', '@returnVersion', '@xmlns', '@xmlns:xsi', '@xsi:schemaLocation', 'AccountantCompileOrReview', 'AccountsPayableAccruedExpenses', 'AccountsReceivable', 'ActivitiesConductedPartnership', 'ActivityOrMissionDescription', 'AddressChange', 'AddressPrincipalOfficerUS', 'AllOtherContributions', 'AllOtherExpenses', 'AnnualDisclosureCoveredPersons', 'AuditCommittee', 'BenefitsPaidToMembersCY', 'BenefitsPaidToMembersPriorYear', 'BsnssRltnshpThruFamilyMember', 'BsnssRltnshpWithOrganization', 'ChangesToOrganizingDocs', 'CollectionsOfArt', 'CompensationFromOtherSources', 'CompensationProcessCEO', 'CompensationProcessOther', 'ComplianceWithBackupWitholding', 'ConflictOfInterestPolicy', 'ConservationEasements', 'ConsolidatedAuditFinancialStmt', 'ContributionsGrantsCurrentYear', 'ContributionsGrantsPriorYear', 'CreditCounseling', 'DLN', 'DecisionsSubjectToApproval', 'DeductibleContributionsOfArt', 'DeductibleNonCashContributions', 'DelegationOfManagementDuties', 'DepreciationDepletion', 'DescribedIn501C3', 'Description', 'DisregardedEntity', 'DocumentRetentionPolicy', 'DonorAdvisedFunds', 'EIN', 'ElectionOfBoardMembers', 'ExcessBenefitTransaction', 'Expense', 'FSAudited', 'FamilyOrBusinessRelationship', 'FederalGrantAuditRequired', 'FeesForServicesAccounting', 'FeesForServicesLegal', 'FinancialStatementSeparate', 'FollowSFAS117', 'ForeignActivities', 'ForeignFinancialAccount', 'ForeignOffice', 'Form8282PropertyDisposedOf', 'Form990PartVIISectionA', 'Form990ProvidedToGoverningBody', 'FormType', 'FormersListed', 'FundraisingActivities', 'FundsToPayPremiums', 'Gaming', 'GrantToRelatedPerson', 'Grants', 'GrantsAndSimilarAmntsCY', 'GrantsAndSimilarAmntsPriorYear', 'GrantsPayable', 'GrantsToDomesticIndividuals', 'GrantsToDomesticOrgs', 'GrantsToIndividuals', 'GrantsToOrganizations', 'GrossReceipts', 'GroupReturnForAffiliates', 'Hospital', 'IRS990ScheduleA', 'IRS990ScheduleB', 'IRS990ScheduleD', 'IRS990ScheduleI', 'IRS990ScheduleO', 'IndependentAuditFinancialStmt', 'IndoorTanningServices', 'InfoInScheduleOPartIII', 'InfoInScheduleOPartVI', 'InfoInScheduleOPartXI', 'InfoInScheduleOPartXII', 'InvestmentInJointVenture', 'InvestmentIncome', 'InvestmentIncomeCurrentYear', 'InvestmentIncomePriorYear', 'InvestmentsOtherSecurities', 'LandBldgEquipmentAccumDeprec', 'LandBuildingsEquipmentBasis', 'LandBuildingsEquipmentBasisNet', 'LastUpdated', 'LoanToOfficerOrDQP', 'LobbyingActivities', 'LocalChapters', 'MaterialDiversionOrMisuse', 'MembersOrStockholders', 'MethodOfAccountingAccrual', 'MinutesOfCommittees', 'MinutesOfGoverningBody', 'MissionDescription', 'MoreThan5000KToIndividuals', 'MoreThan5000KToOrganizations', 'NameOfPrincipalOfficerPerson', 'NbrIndependentVotingMembers', 'NbrVotingGoverningBodyMembers', 'NbrVotingMembersGoverningBody', 'NetAssetsOrFundBalancesBOY', 'NetAssetsOrFundBalancesEOY', 'NetUnrelatedBusinessTxblIncome', 'NoListedPersonsCompensated', 'NonDeductibleContributions', 'NumberFormsTransmittedWith1096', 'NumberIndependentVotingMembers', 'NumberIndividualsGT100K', 'NumberOfContractorsGT100K', 'NumberOfEmployees', 'NumberW2GIncluded', 'ObjectId', 'OfficeExpenses', 'OfficerEntityWithBsnssRltnshp', 'OfficerMailingAddress', 'Organization501c3', 'OrganizationName', 'OtherExpensePriorYear', 'OtherExpenses', 'OtherExpensesCurrentYear', 'OtherLiabilities', 'OtherRevenueCurrentYear', 'OtherRevenueMisc', 'OtherRevenuePriorYear', 'PartialLiquidation', 'PaymentsToAffiliates', 'PoliticalActivities', 'PremiumsPaid', 'PriorExcessBenefitTransaction', 'ProfessionalFundraising', 'ProgramServiceRevenueCY', 'ProgramServiceRevenuePriorYear', 'ProhibitedTaxShelterTrans', 'QuidProQuoContributions', 'ReconcilationOtherChanges', 'ReconcilationRevenueExpenses', 'RegularMonitoringEnforcement', 'RelatedEntity', 'RelatedOrgControlledEntity', 'ReportFin48Footnote', 'ReportInvestOthSecurities', 'ReportLandBldgEquip', 'ReportOtherAssets', 'ReportOtherLiabilities', 'ReportProgRelInvest', 'ReturnHeader', 'RevenuesL ...

# %%
list(db.filings_990.index_information())
# Out:
# ['_id_', 'URL_1']

# %%
filings_990.estimated_document_count()
# Out:
# 3469008

# %%
df = pd.DataFrame(list(filings_990.find({}, {'_id': 0, 'EIN': 1, 'OrganizationName': 1, 'DLN': 1, 'URL': 1, 
    'TaxPeriod': 1, 
    'IRS990ScheduleJ': 1})[:2]))
df
# Out:
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#               DLN TaxPeriod        EIN  \
# 0  93493313013011    201012  232705170
# 1  93493313013111    201106  581805618
#
#                                                                                                                                                                                                                                              IRS990ScheduleJ
# 0                                                                                                                                                                                                                                                        NaN
# 1  {'@documentId': 'IRS990ScheduleJ', '@softwareId': '10000105', '@softwareVersion': '2010v3.2', 'CompensationCommittee': 'X', 'CompensationSurvey': 'X', 'BoardOrCommitteeApproval': 'X', 'SeverancePayment': 'false', 'SupplementalNonqualRetirePlan': ...

# %%
def iterator2dataframe(iterator, chunk_size: int):
    #Turn an iterator into multiple small pandas.DataFrame
    #This is a balance between memory and efficiency
    records = []
    frames = []
    for i, record in enumerate(iterator):
        records.append(record)
        if i % chunk_size == chunk_size - 1:
            frames.append(pd.DataFrame(records))
            records = []
    if records:
        frames.append(pd.DataFrame(records))
    return pd.concat(frames, sort=False) if frames else pd.DataFrame()

# %% [markdown]
# ##### Test for Schedule I

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
dfi = iterator2dataframe(filings_990.find({}, {'_id': 0, 'URL': 1,
    'IRS990ScheduleI': 1}), 1000)
print("Number of columns:", len(dfi.columns))
print("Number of observations:", len(dfi))
dfi[:2]
# Out:
# Current date and time :  2025-06-20 16:26:55
#
# Number of columns: 2
# Number of observations: 3469008
# CPU times: total: 1min 27s
# Wall time: 5min 46s
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#                                                                                                                                                                                                                                              IRS990ScheduleI
# 0  {'@documentId': 'RetDoc1041900001', 'RecordsMaintained': '1', 'RecipientTable': [{'RecipientNameBusiness': {'BusinessNameLine1': 'RMH - WILMINGTON DE'}, 'AddressUS': {'AddressLine1': '1901 ROCKLAND ROAD', 'City': 'WILMINGTON', 'State': 'DE', 'ZIP...
# 1                                                                                                                                                                                                                                                        NaN

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
print(len(dfi[dfi['IRS990ScheduleI'].isnull()]))
print(len(dfi[dfi['IRS990ScheduleI'].notnull()]))
# Out:
# Current date and time :  2025-06-20 16:34:49
#
# 2687713
# 781295
# CPU times: total: 828 ms
# Wall time: 881 ms

# %% [markdown]
# #### Schedule J

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df = iterator2dataframe(filings_990.find({}, {'_id': 0, 'EIN': 1, 'OrganizationName': 1, 'DLN': 1, 'URL': 1,
    'IRS990ScheduleJ': 1}), 1000)
print("Number of columns:", len(df.columns))
print("Number of observations:", len(df))
df[:2]
# Out:
# Current date and time :  2025-06-20 16:35:00
#
# Number of columns: 5
# Number of observations: 3469008
# CPU times: total: 48.5 s
# Wall time: 2min 17s
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#               DLN        EIN  \
# 0  93493313013011  232705170
# 1  93493313013111  581805618
#
#                                                                                                                                                                                                                                              IRS990ScheduleJ
# 0                                                                                                                                                                                                                                                        NaN
# 1  {'@documentId': 'IRS990ScheduleJ', '@softwareId': '10000105', '@softwareVersion': '2010v3.2', 'CompensationCommittee': 'X', 'CompensationSurvey': 'X', 'BoardOrCommitteeApproval': 'X', 'SeverancePayment': 'false', 'SupplementalNonqualRetirePlan': ...

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
print(len(df[df['IRS990ScheduleJ'].isnull()]))
print(len(df[df['IRS990ScheduleJ'].notnull()]))
# Out:
# Current date and time :  2025-06-20 16:41:07
#
# 2695894
# 773114
# CPU times: total: 1.73 s
# Wall time: 1.87 s

# %%
df[df['IRS990ScheduleJ'].isnull()].sample(10)
# Out:
#                                                  OrganizationName  \
# 620                                                           NaN
# 894                           AMERICAN LEGION JOE HOOPER POST 209
# 691                                                           NaN
# 269                                                           NaN
# 85                                             CAUSE FOR PAWZ INC
# 540                                        CAROLINA SHAG CLUB INC
# 868                            MOBILE MEDICAL DISASTER RELIEF INC
# 318                                    SEAL LEGACY FOUNDATION INC
# 636                                                           NaN
# 633  NATIONAL REGISTRY OF REHABILITATION TECHNOLOGY SUPPLIERS INC
#
#                                                                      URL  \
# 620  https://s3.amazonaws.com/irs-form-990/202243199349302839_public.xml
# 894  https://s3.amazonaws.com/irs-form-990/201521359349306062_public.xml
# 691  https://s3.amazonaws.com/irs-form-990/202311749349300306_public.xml
# 269  https://s3.amazonaws.com/irs-form-990/202231789349301013_public.xml
# 85   https://s3.amazonaws.com/irs-form-990/201321939349301252_public.xml
# 540  https://s3.amazonaws.com/irs-form-990/201710719349300151_public.xml
# 868  https://s3.amazonaws.com/irs-form-990/201323169349304142_public.xml
# 318  https://s3.amazonaws.com/irs-form-990/201543209349313729_public.xml
# 636  https://s3.amazonaws.com/irs-form-990/202123099349301497_public.xml
# 633  https://s3.amazonaws.com/irs-form-990/201841349349304169_public.xml
#
#                 DLN        EIN IRS990ScheduleJ
# 620             NaN        NaN             NaN
# 894  93493135060625  916075472             NaN
# 691             NaN        NaN             NaN
# 269             NaN        NaN             NaN
# 85   93493193012523  273028992             NaN
# 540  93493071001517  570970084             NaN
# 868  93493316041423  300345964             NaN
# 318  93493320137295  453117712             NaN
# 636             NaN        NaN             NaN
# 633  93493134041698  541648579             NaN

# %%
df[df['IRS990ScheduleJ'].notnull()].sample(5)
# Out:
#                       OrganizationName  \
# 558                                NaN
# 503                FAMILY SERVICES INC
# 691                                NaN
# 776                                NaN
# 708  GLOBAL OUTREACH INTERNATIONAL INC
#
#                                                                      URL  \
# 558  https://s3.amazonaws.com/irs-form-990/202341099349300129_public.xml
# 503  https://s3.amazonaws.com/irs-form-990/201501909349300615_public.xml
# 691  https://s3.amazonaws.com/irs-form-990/202243349349300739_public.xml
# 776  https://s3.amazonaws.com/irs-form-990/202212999349301731_public.xml
# 708  https://s3.amazonaws.com/irs-form-990/202033149349303788_public.xml
#
#                 DLN        EIN  \
# 558             NaN        NaN
# 503  93493190006155  930991864
# 691             NaN        NaN
# 776             NaN        NaN
# 708  93493314037880  481256219
#
#                                                                                                                                                                                                                                                IRS990ScheduleJ
# 558  {'@documentId': 'RetDoc1042400001', 'CompensationCommitteeInd': 'X', 'IndependentConsultantInd': 'X', 'Form990OfOtherOrganizationsInd': 'X', 'WrittenEmploymentContractInd': 'X', 'CompensationSurveyInd': 'X', 'BoardOrCommitteeApprovalInd': 'X', 'S...
# 503  {'@documentId': '00000005', 'SeverancePaymentInd': 'false', 'SupplementalNonqualRtrPlanInd': 'false', 'EquityBasedCompArrngmInd': 'false', 'CompBasedOnRevenueOfFlngOrgInd': 'false', 'CompBsdOnRevRelatedOrgsInd': 'false', 'CompBsdNetEarnsFlngOrgIn...
# 691  {'@documentId': 'RetDoc1042400001', 'BoardOrCommitteeApprovalInd': 'X', 'SeverancePaymentInd': '0', 'SupplementalNonqualRtrPlanInd': '0', 'EquityBasedCompArrngmInd': '0', 'CompBasedOnRevenueOfFlngOrgInd': '0', 'CompBsdOnRevRelatedOrgsInd': '0', '...
# 776  {'@documentId': 'RetDoc1042400001', 'SeverancePaymentInd': '0', 'SupplementalNonqualRtrPlanInd': '0', 'EquityBasedCompArrngmInd': '0', 'CompBasedOnRevenueOfFlngOrgInd': '0', 'CompBsdOnRevRelatedOrgsInd': '0', 'CompBsdNetEarnsFlngOrgInd': '0', 'Co...
# 708  {'@documentId': 'RetDoc1042400001', 'Form990OfOtherOrganizationsInd': 'X', 'CompensationSurveyInd': 'X', 'BoardOrCommitteeApprovalInd': 'X', 'SeverancePaymentInd': '0', 'SupplementalNonqualRtrPlanInd': '0', 'EquityBasedCompArrngmInd': '0', 'CompB...

# %% [markdown]
# #### Limit DF to non-null Schedule J

# %%
dfj = df[df['IRS990ScheduleJ'].notnull()]
print(len(dfj))
dfj.sample(2)
# Out:
# 773114
#                    OrganizationName  \
# 873  IBEW 654 H AND W FUND TRUSTEES
# 646            SNAME PROPERTIES INC
#
#                                                                      URL  \
# 873  https://s3.amazonaws.com/irs-form-990/201912749349300601_public.xml
# 646  https://s3.amazonaws.com/irs-form-990/201403169349303545_public.xml
#
#                 DLN        EIN  \
# 873  93493274006019  231613860
# 646  93493316035454  222807776
#
#                                                                                                                                                                                                                                                IRS990ScheduleJ
# 873  {'@documentId': 'RetDoc1042400001', 'SeverancePaymentInd': '0', 'SupplementalNonqualRtrPlanInd': '0', 'EquityBasedCompArrngmInd': '0', 'RltdOrgOfficerTrstKeyEmplGrp': [{'PersonNm': 'WILLIAM ADAMS', 'TitleTxt': 'UNION TRUSTEE', 'BaseCompensationFi...
# 646  {'@documentId': 'R000003', '@softwareId': '13000241', '@softwareVersion': 'v1.00', 'CompensationCommitteeInd': 'X', 'SeverancePaymentInd': '0', 'SupplementalNonqualRtrPlanInd': '0', 'EquityBasedCompArrngmInd': '0', 'RltdOrgOfficerTrstKeyEmplGrp':...

# %% [markdown]
# #### Save DF

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
dfj.to_pickle('Schedule J (non-flattened).pkl.gz', compression='gzip')
# Out:
# Current date and time :  2025-06-20 16:41:58
#
# CPU times: total: 2min 8s
# Wall time: 2min 12s

# %%
#%%time
#import datetime
#print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
#dfj = pd.read_pickle('Excise Tax Project - Schedule J (non-flattened).pkl')
#print(len(dfj))
#dfj[:1]
# Out:
# 430161
# Wall time: 18.3 s
#                                      OrganizationName  \
# 1  TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                                                                    URL  \
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#               DLN        EIN  \
# 1  93493313013111  581805618
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        IRS990ScheduleJ
# 1  {'@documentId': 'IRS990ScheduleJ', '@softwareId': '10000105', '@softwareVersion': '2010v3.2', 'CompensationCommittee': 'X', 'CompensationSurvey': 'X', 'BoardOrCommitteeApproval': 'X', 'SeverancePayment': 'false', 'SupplementalNonqualRetirePlan': 'true', 'EquityBasedCompArrangement': 'false', 'CompBasedOnRevenueOfFilingOrg': 'false', 'CompBasedOnRevenueRelatedOrgs': 'false', 'CompBasedNetEarningsFilingOrg': 'false', 'CompBasedNetEarningsRelateOrgs': 'false', 'AnyNonFixedPayments': 'false', 'I...

# %% [markdown]
# # Flatten Schedule J

# %%
pd.set_option('max_colwidth', 500)

# %%
df[df['IRS990ScheduleJ'].notnull()][['URL', 'IRS990ScheduleJ']][:1]
# Out:
#                                                                    URL  \
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        IRS990ScheduleJ
# 1  {'@documentId': 'IRS990ScheduleJ', '@softwareId': '10000105', '@softwareVersion': '2010v3.2', 'CompensationCommittee': 'X', 'CompensationSurvey': 'X', 'BoardOrCommitteeApproval': 'X', 'SeverancePayment': 'false', 'SupplementalNonqualRetirePlan': 'true', 'EquityBasedCompArrangement': 'false', 'CompBasedOnRevenueOfFilingOrg': 'false', 'CompBasedOnRevenueRelatedOrgs': 'false', 'CompBasedNetEarningsFilingOrg': 'false', 'CompBasedNetEarningsRelateOrgs': 'false', 'AnyNonFixedPayments': 'false', 'I...

# %%
#%%time
#dfj = pd.concat([dfj.drop(['IRS990ScheduleJ'], axis=1), dfj['IRS990ScheduleJ'].apply(pd.Series)], axis=1)
#dfj[:1]

# %% [markdown]
# ### Process All Filings

# %%
# flatten the list-like column into a DataFrame
j = pd.json_normalize(dfj["IRS990ScheduleJ"], max_level=0)

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
#from pandas.io.json import json_normalize
j = pd.json_normalize(dfj['IRS990ScheduleJ'][:], max_level=0)
print(len(j.columns))
print(len(j))
j[:1]
# Out:
# Current date and time :  2025-06-20 16:47:50
#
# 61
# 773114
# CPU times: total: 1min 31s
# Wall time: 1min 44s
#        @documentId @softwareId @softwareVersion CompensationCommittee  \
# 0  IRS990ScheduleJ    10000105         2010v3.2                     X
#
#   CompensationSurvey BoardOrCommitteeApproval SeverancePayment  \
# 0                  X                        X            false
#
#   SupplementalNonqualRetirePlan EquityBasedCompArrangement  \
# 0                          true                      false
#
#   CompBasedOnRevenueOfFilingOrg CompBasedOnRevenueRelatedOrgs  \
# 0                         false                         false
#
#   CompBasedNetEarningsFilingOrg CompBasedNetEarningsRelateOrgs  \
# 0                         false                          false
#
#   AnyNonFixedPayments InitialContractException RebuttablePresumptionProcedure  \
# 0               false                    false                          false
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Form990ScheduleJPartII  \
# 0  [{'NamePerson': 'THOMAS D TURNBULL', 'CompBasedOnRelatedOrgs': '100712', 'BonusRelatedOrgs': '790', 'OtherCompensationRelatedOrgs': '1257', 'DeferredCompRelatedOrgs': '54308', 'NontaxableBenefitsRelatedOrgs': '62342', 'TotalCompensationRelatedOrgs': '219409'}, {'NamePerson': 'RONALD W PATTERSON', 'CompBasedOnRelatedOrgs': '192455', 'BonusRelatedOrgs': '814', 'OtherCompensationRelatedOrgs': '2071', 'DeferredCompRelatedOrgs': '17271', 'NontaxableBenefitsRelatedOrgs': '23201', 'TotalCompensatio...
#
#   IndependentConsultant WrittenEmploymentContract Form990ScheduleJPartIII  \
# 0                   NaN                       NaN                     NaN
#
#   HousingAllowanceOrResidence WrittenPolicyReTAndEExpenses  \
# 0                         NaN                          NaN
#
#   SubstantiationRequired IdemnificationGrossUpPayments  \
# 0                    NaN                           NaN
#
#   DiscretionarySpendingAccount ClubDuesOrFees FirstClassOrCharterTravel  \
# 0                          NaN            NaN                       NaN
#
#   TravelForCompanions Form990OfOtherOrganizations PaymentsForUseOfResidence  \
# 0                 NaN                         NaN                       NaN
#
#   PersonalServices SeverancePaymentInd SupplementalNonqualRtrPlanInd  \
# 0              NaN                 NaN                           NaN
#
#   EquityBasedCompArrngmInd CompBasedOnRevenueOfFlngOrgInd  \
# 0                      NaN                            NaN
#
#   CompBsdOnRevRelatedOrgsInd CompBsdNetEarnsFlngOrgInd  \
# 0                        NaN                       NaN
#
#   CompBsdNetEarnsRltdOrgsInd AnyNonFixedPaymentsInd  \
# 0                        NaN                    NaN
#
#   InitialContractExceptionInd RltdOrgOfficerTrstKeyEmplGrp  \
# 0                         NaN                          NaN
#
#   CompensationCommitteeInd BoardOrCommitteeApprovalInd  \
# 0                      NaN                         NaN
#
#   RebuttablePresumptionProcInd IndependentConsultantInd  \
# 0                          NaN                      NaN
#
#   WrittenEmploymentContractInd CompensationSurveyInd  \
# 0                          NaN                   NaN
#
#   SupplementalInformationDetail Form990OfOtherOrganizationsInd  \
# 0                           NaN                            NaN
#
#   DiscretionarySpendingAcctInd WrittenPolicyRefTAndEExpnssInd  \
# 0                          NaN                            NaN
#
#   SubstantiationRequiredInd TravelForCompanionsInd  \
# 0                       NaN                    NaN
#
#   IdemnificationGrossUpPmtsInd ClubDuesOrFeesInd  \
# 0                          NaN               NaN
#
#   HousingAllowanceOrResidenceInd FirstClassOrCharterTravelInd  \
# 0                            NaN                          NaN
#
#   PersonalServicesInd PaymentsForUseOfResidenceInd @documentName  \
# 0                 NaN                          NaN           NaN
#
#   @softwareVersionNum
# 0                 NaN

# %%
jcols = j.columns.tolist()
jcols
# Out:
# ['@documentId',
#  '@softwareId',
#  '@softwareVersion',
#  'CompensationCommittee',
#  'CompensationSurvey',
#  'BoardOrCommitteeApproval',
#  'SeverancePayment',
#  'SupplementalNonqualRetirePlan',
#  'EquityBasedCompArrangement',
#  'CompBasedOnRevenueOfFilingOrg',
#  'CompBasedOnRevenueRelatedOrgs',
#  'CompBasedNetEarningsFilingOrg',
#  'CompBasedNetEarningsRelateOrgs',
#  'AnyNonFixedPayments',
#  'InitialContractException',
#  'RebuttablePresumptionProcedure',
#  'Form990ScheduleJPartII',
#  'IndependentConsultant',
#  'WrittenEmploymentContract',
#  'Form990ScheduleJPartIII',
#  'HousingAllowanceOrResidence',
#  'WrittenPolicyReTAndEExpenses',
#  'SubstantiationRequired',
#  'IdemnificationGrossUpPayments',
#  'DiscretionarySpendingAccount',
#  'ClubDuesOrFees',
#  'FirstClassOrCharterTravel',
#  'TravelForCompanions',
#  'Form990OfOtherOrganizations',
#  'PaymentsForUseOfResidence',
#  'PersonalServices',
#  'SeverancePaymentInd',
#  'SupplementalNonqualRtrPlanInd',
#  'EquityBasedCompArrngmInd',
#  'CompBasedOnRevenueOfFlngOrgInd',
#  'CompBsdOnRevRelatedOrgsInd',
#  'CompBsdNetEarnsFlngOrgInd',
#  'CompBsdNetEarnsRltdOrgsInd',
#  'AnyNonFixedPaymentsInd',
#  'InitialContractExceptionInd',
#  'RltdOrgOfficerTrstKeyEmplGrp',
#  'CompensationCommitteeInd',
#  'BoardOrCommitteeApprovalInd',
#  'RebuttablePresumptionProcInd',
#  'IndependentConsultantInd',
#  'WrittenEmploymentContractInd',
#  'CompensationSurveyInd',
#  'SupplementalInformationDetail',
#  'Form990OfOtherOrganizationsInd',
#  'DiscretionarySpendingAcctInd',
#  'WrittenPolicyRefTAndEExpnssInd',
#  'SubstantiationRequiredInd',
#  'TravelForCompanionsInd',
#  'IdemnificationGrossUpPmtsInd',
#  'ClubDuesOrFeesInd',
#  'HousingAllowanceOrResidenceInd',
#  'FirstClassOrCharterTravelInd',
#  'PersonalServicesInd',
#  'PaymentsForUseOfResidenceInd',
#  '@documentName',
#  '@softwareVersionNum']

# %%
set(j.columns) - set(jcols)
# Out:
# set()

# %%
set(jcols) - set(j.columns)
# Out:
# set()

# %%
#%%time
#from pandas.io.json import json_normalize
#j = pd.json_normalize(dfj['IRS990ScheduleJ'][:])
#print(len(j))
#j[:1]
# Out:
# 430161
# Wall time: 2.01 ms
#        @documentId @softwareId @softwareVersion CompensationCommittee  \
# 0  IRS990ScheduleJ    10000105         2010v3.2                     X
#
#   CompensationSurvey BoardOrCommitteeApproval SeverancePayment  \
# 0                  X                        X            false
#
#   SupplementalNonqualRetirePlan EquityBasedCompArrangement  \
# 0                          true                      false
#
#   CompBasedOnRevenueOfFilingOrg CompBasedOnRevenueRelatedOrgs  \
# 0                         false                         false
#
#   CompBasedNetEarningsFilingOrg CompBasedNetEarningsRelateOrgs  \
# 0                         false                          false
#
#   AnyNonFixedPayments InitialContractException RebuttablePresumptionProcedure  \
# 0               false                    false                          false
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Form990ScheduleJPartII  \
# 0  [{'NamePerson': 'THOMAS D TURNBULL', 'CompBasedOnRelatedOrgs': '100712', 'BonusRelatedOrgs': '790', 'OtherCompensationRelatedOrgs': '1257', 'DeferredCompRelatedOrgs': '54308', 'NontaxableBenefitsRelatedOrgs': '62342', 'TotalCompensationRelatedOrgs': '219409'}, {'NamePerson': 'RONALD W PATTERSON', 'CompBasedOnRelatedOrgs': '192455', 'BonusRelatedOrgs': '814', 'OtherCompensationRelatedOrgs': '2071', 'DeferredCompRelatedOrgs': '17271', 'NontaxableBenefitsRelatedOrgs': '23201', 'TotalCompensatio...
#
#   IndependentConsultant WrittenEmploymentContract Form990ScheduleJPartIII  \
# 0                   NaN                       NaN                     NaN
#
#   Form990ScheduleJPartII.NamePerson  \
# 0                               NaN
#
#   Form990ScheduleJPartII.BaseCompensationFilingOrg  \
# 0                                              NaN
#
#   Form990ScheduleJPartII.CompBasedOnRelatedOrgs  \
# 0                                           NaN
#
#   Form990ScheduleJPartII.BonusFilingOrg  \
# 0                                   NaN
#
#   Form990ScheduleJPartII.BonusRelatedOrgs  \
# 0                                     NaN
#
#   Form990ScheduleJPartII.OtherCompensationFilingOrg  \
# 0                                               NaN
#
#   Form990ScheduleJPartII.OtherCompensationRelatedOrgs  \
# 0                                                 NaN
#
#   Form990ScheduleJPartII.DeferredCompFilingOrg  \
# 0                                          NaN
#
#   Form990ScheduleJPartII.DeferredCompRelatedOrgs  \
# 0                                            NaN
#
#   Form990ScheduleJPartII.NontaxableBenefitsFilingOrg  \
# 0                                                NaN
#
#   Form990ScheduleJPartII.NontaxableBenefitsRelatedOrgs  \
# 0                                                  NaN
#
#   Form990ScheduleJPartII.TotalCompensationFilingOrg  \
# 0                                               NaN
#
#   Form990ScheduleJPartII.TotalCompensationRelatedOrgs  \
# 0                                                 NaN
#
#   Form990ScheduleJPartII.CompReportPrior990FilingOrg  \
# 0                                                NaN
#
#   Form990ScheduleJPartII.CompReportPrior990RelatedOrgs  \
# 0                                                  NaN
#
#   Form990ScheduleJPartIII.Identifier Form990ScheduleJPartIII.ReturnReference  \
# 0                                NaN                                     NaN
#
#   Form990ScheduleJPartIII.Explanation HousingAllowanceOrResidence  \
# 0                                 NaN                         NaN
#
#   WrittenPolicyReTAndEExpenses SubstantiationRequired  \
# 0                          NaN                    NaN
#
#   IdemnificationGrossUpPayments DiscretionarySpendingAccount ClubDuesOrFees  \
# 0                           NaN                          NaN            NaN
#
#   FirstClassOrCharterTravel TravelForCompanions Form990OfOtherOrganizations  \
# 0                       NaN                 NaN                         NaN
#
#   PaymentsForUseOfResidence  \
# 0                       NaN
#
#   Form990ScheduleJPartII.NameBusiness.BusinessNameLine1 PersonalServices  \
# 0                                                   NaN              NaN
#
#   Form990ScheduleJPartII.NameBusiness.BusinessNameLine2  \
# 0                                                   NaN
#
#   Form990ScheduleJPartII.Title SeverancePaymentInd  \
# 0                          NaN                 NaN
#
#   SupplementalNonqualRtrPlanInd EquityBasedCompArrngmInd  \
# 0                           NaN                      NaN
#
#   CompBasedOnRevenueOfFlngOrgInd CompBsdOnRevRelatedOrgsInd  \
# 0                            NaN                        NaN
#
#   CompBsdNetEarnsFlngOrgInd CompBsdNetEarnsRltdOrgsInd AnyNonFixedPaymentsInd  \
# 0                       NaN                        NaN                    NaN
#
#   InitialContractExceptionInd RltdOrgOfficerTrstKeyEmplGrp.PersonNm  \
# 0                         NaN                                   NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.TitleTxt  \
# 0                                   NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.BaseCompensationFilingOrgAmt  \
# 0                                                       NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.CompensationBasedOnRltdOrgsAmt  \
# 0                                                         NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.BonusFilingOrganizationAmount  \
# 0                                                        NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.BonusRelatedOrganizationsAmt  \
# 0                                                       NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.OtherCompensationFilingOrgAmt  \
# 0                                                        NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.OtherCompensationRltdOrgsAmt  \
# 0                                                       NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.DeferredCompensationFlngOrgAmt  \
# 0                                                         NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.DeferredCompRltdOrgsAmt  \
# 0                                                  NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.NontaxableBenefitsFilingOrgAmt  \
# 0                                                         NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.NontaxableBenefitsRltdOrgsAmt  \
# 0                                                        NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.TotalCompensationFilingOrgAmt  \
# 0                                                        NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.TotalCompensationRltdOrgsAmt  \
# 0                                                       NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.CompReportPrior990FilingOrgAmt  \
# 0                                                         NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.CompReportPrior990RltdOrgsAmt  \
# 0                                                        NaN
#
#   CompensationCommitteeInd BoardOrCommitteeApprovalInd  \
# 0                      NaN                         NaN
#
#   RebuttablePresumptionProcInd RltdOrgOfficerTrstKeyEmplGrp  \
# 0                          NaN                          NaN
#
#   IndependentConsultantInd WrittenEmploymentContractInd CompensationSurveyInd  \
# 0                      NaN                          NaN                   NaN
#
#   SupplementalInformationDetail.FormAndLineReferenceDesc  \
# 0                                                    NaN
#
#   SupplementalInformationDetail.ExplanationTxt Form990OfOtherOrganizationsInd  \
# 0                                          NaN                            NaN
#
#   DiscretionarySpendingAcctInd WrittenPolicyRefTAndEExpnssInd  \
# 0                          NaN                            NaN
#
#   SubstantiationRequiredInd SupplementalInformationDetail  \
# 0                       NaN                           NaN
#
#   TravelForCompanionsInd IdemnificationGrossUpPmtsInd ClubDuesOrFeesInd  \
# 0                    NaN                          NaN               NaN
#
#   HousingAllowanceOrResidenceInd FirstClassOrCharterTravelInd  \
# 0                            NaN                          NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.BusinessName.BusinessNameLine1  \
# 0                                                         NaN
#
#   PersonalServicesInd PaymentsForUseOfResidenceInd  \
# 0                 NaN                          NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.BusinessName.BusinessNameLine2 @documentName  \
# 0                                                         NaN           NaN
#
#   @softwareVersionNum  \
# 0                 NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.BusinessName.BusinessNameLine1Txt  \
# 0                                                            NaN
#
#   RltdOrgOfficerTrstKeyEmplGrp.BusinessName.BusinessNameLine2Txt
# 0                                                            NaN

# %%
"""
#####NEXT TIME RUN THIS INSTEAD OF ABOVE BLOCK
import timeit
start_time = timeit.default_timer()
df = pd.concat([df.drop(['USER'], axis=1), df['USER'].apply(pd.Series).add_prefix('USER_')], axis=1)
elapsed = timeit.default_timer() - start_time
print('# of minutes: ', elapsed/60)
df[:1]
"""

# %%
dfj[:1]
# Out:
#                                      OrganizationName  \
# 1  TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                                                                    URL  \
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#               DLN        EIN  \
# 1  93493313013111  581805618
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        IRS990ScheduleJ
# 1  {'@documentId': 'IRS990ScheduleJ', '@softwareId': '10000105', '@softwareVersion': '2010v3.2', 'CompensationCommittee': 'X', 'CompensationSurvey': 'X', 'BoardOrCommitteeApproval': 'X', 'SeverancePayment': 'false', 'SupplementalNonqualRetirePlan': 'true', 'EquityBasedCompArrangement': 'false', 'CompBasedOnRevenueOfFilingOrg': 'false', 'CompBasedOnRevenueRelatedOrgs': 'false', 'CompBasedNetEarningsFilingOrg': 'false', 'CompBasedNetEarningsRelateOrgs': 'false', 'AnyNonFixedPayments': 'false', 'I...

# %%
print(len(j[j['Form990ScheduleJPartIII'].isnull()]))
print(len(j[j['Form990ScheduleJPartIII'].notnull()]))
# Out:
# 719801
# 53313

# %%
dfj = dfj.reset_index()
dfj[:2]
# Out:
#    index                                    OrganizationName  \
# 0      1  TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
# 1      2   HOUSTON VOA INDEPENDENT HOUSING INC HEIGHTS MANOR
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301316_public.xml
#
#               DLN        EIN  \
# 0  93493313013111  581805618
# 1  93493313013161  581876019
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        IRS990ScheduleJ
# 0  {'@documentId': 'IRS990ScheduleJ', '@softwareId': '10000105', '@softwareVersion': '2010v3.2', 'CompensationCommittee': 'X', 'CompensationSurvey': 'X', 'BoardOrCommitteeApproval': 'X', 'SeverancePayment': 'false', 'SupplementalNonqualRetirePlan': 'true', 'EquityBasedCompArrangement': 'false', 'CompBasedOnRevenueOfFilingOrg': 'false', 'CompBasedOnRevenueRelatedOrgs': 'false', 'CompBasedNetEarningsFilingOrg': 'false', 'CompBasedNetEarningsRelateOrgs': 'false', 'AnyNonFixedPayments': 'false', 'I...
# 1  {'@documentId': 'IRS990ScheduleJ', '@softwareId': '10000105', '@softwareVersion': '2010v3.2', 'CompensationCommittee': 'X', 'CompensationSurvey': 'X', 'BoardOrCommitteeApproval': 'X', 'SeverancePayment': 'false', 'SupplementalNonqualRetirePlan': 'true', 'EquityBasedCompArrangement': 'false', 'CompBasedOnRevenueOfFilingOrg': 'false', 'CompBasedOnRevenueRelatedOrgs': 'false', 'CompBasedNetEarningsFilingOrg': 'false', 'CompBasedNetEarningsRelateOrgs': 'false', 'AnyNonFixedPayments': 'false', 'I...

# %%
dfj[-2:]
# Out:
#         index OrganizationName  \
# 773112    988              NaN
# 773113      2              NaN
#
#                                                                         URL  \
# 773112  https://s3.amazonaws.com/irs-form-990/202441449349301409_public.xml
# 773113  https://s3.amazonaws.com/irs-form-990/202441449349301564_public.xml
#
#         DLN  EIN  \
# 773112  NaN  NaN
# 773113  NaN  NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             IRS990ScheduleJ
# 773112  {'@documentId': 'RetDoc6', 'CompensationCommitteeInd': 'X', 'IndependentConsultantInd': 'X', 'Form990OfOtherOrganizationsInd': 'X', 'WrittenEmploymentContractInd': 'X', 'CompensationSurveyInd': 'X', 'BoardOrCommitteeApprovalInd': 'X', 'SeverancePaymentInd': 'false', 'SupplementalNonqualRtrPlanInd': 'false', 'EquityBasedCompArrngmInd': 'false', 'CompBasedOnRevenueOfFlngOrgInd': 'false', 'CompBsdOnRevRelatedOrgsInd': 'false', 'CompBsdNetEarnsFlngOrgInd': 'false', 'CompBsdNetEarnsRltdOrgsInd': ...
# 773113  {'@documentId': 'IRS990ScheduleJ', '@softwareId': '23017437', '@softwareVersionNum': '2023v5.0', 'CompensationCommitteeInd': 'X', 'CompensationSurveyInd': 'X', 'BoardOrCommitteeApprovalInd': 'X', 'SeverancePaymentInd': 'false', 'SupplementalNonqualRtrPlanInd': 'false', 'EquityBasedCompArrngmInd': 'false', 'CompBasedOnRevenueOfFlngOrgInd': 'false', 'CompBsdOnRevRelatedOrgsInd': 'false', 'CompBsdNetEarnsFlngOrgInd': 'false', 'CompBsdNetEarnsRltdOrgsInd': 'false', 'AnyNonFixedPaymentsInd': 'fal...

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
dfj = pd.concat([dfj.drop(['index', 'IRS990ScheduleJ'], axis=1), j], axis=1)
print(len(df))
dfj[:1]
# Out:
# Current date and time :  2025-06-20 16:55:34
#
# 3469008
# CPU times: total: 1.06 s
# Wall time: 1.13 s
#                                      OrganizationName  \
# 0  TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#               DLN        EIN      @documentId @softwareId @softwareVersion  \
# 0  93493313013111  581805618  IRS990ScheduleJ    10000105         2010v3.2
#
#   CompensationCommittee CompensationSurvey BoardOrCommitteeApproval  \
# 0                     X                  X                        X
#
#   SeverancePayment SupplementalNonqualRetirePlan EquityBasedCompArrangement  \
# 0            false                          true                      false
#
#   CompBasedOnRevenueOfFilingOrg CompBasedOnRevenueRelatedOrgs  \
# 0                         false                         false
#
#   CompBasedNetEarningsFilingOrg CompBasedNetEarningsRelateOrgs  \
# 0                         false                          false
#
#   AnyNonFixedPayments InitialContractException RebuttablePresumptionProcedure  \
# 0               false                    false                          false
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Form990ScheduleJPartII  \
# 0  [{'NamePerson': 'THOMAS D TURNBULL', 'CompBasedOnRelatedOrgs': '100712', 'BonusRelatedOrgs': '790', 'OtherCompensationRelatedOrgs': '1257', 'DeferredCompRelatedOrgs': '54308', 'NontaxableBenefitsRelatedOrgs': '62342', 'TotalCompensationRelatedOrgs': '219409'}, {'NamePerson': 'RONALD W PATTERSON', 'CompBasedOnRelatedOrgs': '192455', 'BonusRelatedOrgs': '814', 'OtherCompensationRelatedOrgs': '2071', 'DeferredCompRelatedOrgs': '17271', 'NontaxableBenefitsRelatedOrgs': '23201', 'TotalCompensatio...
#
#   IndependentConsultant WrittenEmploymentContract Form990ScheduleJPartIII  \
# 0                   NaN                       NaN                     NaN
#
#   HousingAllowanceOrResidence WrittenPolicyReTAndEExpenses  \
# 0                         NaN                          NaN
#
#   SubstantiationRequired IdemnificationGrossUpPayments  \
# 0                    NaN                           NaN
#
#   DiscretionarySpendingAccount ClubDuesOrFees FirstClassOrCharterTravel  \
# 0                          NaN            NaN                       NaN
#
#   TravelForCompanions Form990OfOtherOrganizations PaymentsForUseOfResidence  \
# 0                 NaN                         NaN                       NaN
#
#   PersonalServices SeverancePaymentInd SupplementalNonqualRtrPlanInd  \
# 0              NaN                 NaN                           NaN
#
#   EquityBasedCompArrngmInd CompBasedOnRevenueOfFlngOrgInd  \
# 0                      NaN                            NaN
#
#   CompBsdOnRevRelatedOrgsInd CompBsdNetEarnsFlngOrgInd  \
# 0                        NaN                       NaN
#
#   CompBsdNetEarnsRltdOrgsInd AnyNonFixedPaymentsInd  \
# 0                        NaN                    NaN
#
#   InitialContractExceptionInd RltdOrgOfficerTrstKeyEmplGrp  \
# 0                         NaN                          NaN
#
#   CompensationCommitteeInd BoardOrCommitteeApprovalInd  \
# 0                      NaN                         NaN
#
#   RebuttablePresumptionProcInd IndependentConsultantInd  \
# 0                          NaN                      NaN
#
#   WrittenEmploymentContractInd CompensationSurveyInd  \
# 0                          NaN                   NaN
#
#   SupplementalInformationDetail Form990OfOtherOrganizationsInd  \
# 0                           NaN                            NaN
#
#   DiscretionarySpendingAcctInd WrittenPolicyRefTAndEExpnssInd  \
# 0                          NaN                            NaN
#
#   SubstantiationRequiredInd TravelForCompanionsInd  \
# 0                       NaN                    NaN
#
#   IdemnificationGrossUpPmtsInd ClubDuesOrFeesInd  \
# 0                          NaN               NaN
#
#   HousingAllowanceOrResidenceInd FirstClassOrCharterTravelInd  \
# 0                            NaN                          NaN
#
#   PersonalServicesInd PaymentsForUseOfResidenceInd @documentName  \
# 0                 NaN                          NaN           NaN
#
#   @softwareVersionNum
# 0                 NaN

# %%
print(len(dfj))
# Out:
# 773114

# %%
dfj.sample(2)
# Out:
#                       OrganizationName  \
# 635278                             NaN
# 339028  HUDSON VALLEY SENIOR RESIDENCE
#
#                                                                         URL  \
# 635278  https://s3.amazonaws.com/irs-form-990/202331309349302628_public.xml
# 339028  https://s3.amazonaws.com/irs-form-990/201803099349301565_public.xml
#
#                    DLN        EIN       @documentId @softwareId  \
# 635278             NaN        NaN   IRS990ScheduleJ    21013475
# 339028  93493309015658  141364545  RetDoc1042400001         NaN
#
#        @softwareVersion CompensationCommittee CompensationSurvey  \
# 635278              NaN                   NaN                NaN
# 339028              NaN                   NaN                NaN
#
#        BoardOrCommitteeApproval SeverancePayment  \
# 635278                      NaN              NaN
# 339028                      NaN              NaN
#
#        SupplementalNonqualRetirePlan EquityBasedCompArrangement  \
# 635278                           NaN                        NaN
# 339028                           NaN                        NaN
#
#        CompBasedOnRevenueOfFilingOrg CompBasedOnRevenueRelatedOrgs  \
# 635278                           NaN                           NaN
# 339028                           NaN                           NaN
#
#        CompBasedNetEarningsFilingOrg CompBasedNetEarningsRelateOrgs  \
# 635278                           NaN                            NaN
# 339028                           NaN                            NaN
#
#        AnyNonFixedPayments InitialContractException  \
# 635278                 NaN                      NaN
# 339028                 NaN                      NaN
#
#        RebuttablePresumptionProcedure Form990ScheduleJPartII  \
# 635278                            NaN                    NaN
# 339028                            NaN                    NaN
#
#        IndependentConsultant WrittenEmploymentContract  \
# 635278                   NaN                       NaN
# 339028                   NaN                       NaN
#
#        Form990ScheduleJPartIII HousingAllowanceOrResidence  \
# 635278                     NaN                         NaN
# 339028                     NaN                         NaN
#
#        WrittenPolicyReTAndEExpenses SubstantiationRequired  \
# 635278                          NaN                    NaN
# 339028                          NaN                    NaN
#
#        IdemnificationGrossUpPayments DiscretionarySpendingAccount  \
# 635278                           NaN                          NaN
# 339028                           NaN                          NaN
#
#        ClubDuesOrFees FirstClassOrCharterTravel TravelForCompanions  \
# 635278            NaN                       NaN                 NaN
# 339028            NaN                       NaN                 NaN
#
#        Form990OfOtherOrganizations PaymentsForUseOfResidence PersonalServices  \
# 635278                         NaN                       NaN              NaN
# 339028                         NaN                       NaN              NaN
#
#        SeverancePaymentInd SupplementalNonqualRtrPlanInd  \
# 635278               false                         false
# 339028                   0                             0
#
#        EquityBasedCompArrngmInd CompBasedOnRevenueOfFlngOrgInd  \
# 635278                    false                          false
# 339028                        0                              0
#
#        CompBsdOnRevRelatedOrgsInd CompBsdNetEarnsFlngOrgInd  \
# 635278                      false                     false
# 339028                          0                         0
#
#        CompBsdNetEarnsRltdOrgsInd AnyNonFixedPaymentsInd  \
# 635278                      false                  false
# 339028                          0                      0
#
#        InitialContractExceptionInd  \
# 635278                       false
# 339028                           0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                RltdOrgOfficerTrstKeyEmplGrp  \
# 635278  [{'PersonNm': 'BRIAN PERRY', 'TitleTxt': 'DIRECTOR', 'BaseCompensationFilingOrgAmt': '141154', 'DeferredCompensationFlngOrgAmt': '8648', 'NontaxableBenefitsFilingOrgAmt': '26513', 'TotalCompensationFilingOrgAmt': '176315'}, {'PersonNm': 'BRUCE D COLLIER', 'TitleTxt': 'President', 'BaseCompensationFilingOrgAmt': '221209', 'DeferredCompensationFlngOrgAmt': '13248', 'NontaxableBenefitsFilingOrgAmt': '30584', 'TotalCompensationFilingOrgAmt': '265041'}, {'PersonNm': 'DAVID THOMAS', 'TitleTxt': 'E...
# 339028  [{'PersonNm': 'FRANK TRIPODI', 'TitleTxt': 'BOARD MEMBER & PRESIDENT', 'BaseCompensationFilingOrgAmt': '0', 'CompensationBasedOnRltdOrgsAmt': '410951', 'BonusFilingOrganizationAmount': '0', 'BonusRelatedOrganizationsAmt': '0', 'OtherCompensationFilingOrgAmt': '0', 'OtherCompensationRltdOrgsAmt': '52530', 'DeferredCompensationFlngOrgAmt': '0', 'DeferredCompRltdOrgsAmt': '5400', 'NontaxableBenefitsFilingOrgAmt': '0', 'NontaxableBenefitsRltdOrgsAmt': '27560', 'TotalCompensationFilingOrgAmt': '0...
#
#        CompensationCommitteeInd BoardOrCommitteeApprovalInd  \
# 635278                      NaN                           X
# 339028                      NaN                         NaN
#
#        RebuttablePresumptionProcInd IndependentConsultantInd  \
# 635278                          NaN                      NaN
# 339028                          NaN                      NaN
#
#        WrittenEmploymentContractInd CompensationSurveyInd  \
# 635278                          NaN                   NaN
# 339028                          NaN                   NaN
#
#        SupplementalInformationDetail Form990OfOtherOrganizationsInd  \
# 635278                           NaN                            NaN
# 339028                           NaN                            NaN
#
#        DiscretionarySpendingAcctInd WrittenPolicyRefTAndEExpnssInd  \
# 635278                          NaN                            NaN
# 339028                          NaN                            NaN
#
#        SubstantiationRequiredInd TravelForCompanionsInd  \
# 635278                       NaN                    NaN
# 339028                       NaN                    NaN
#
#        IdemnificationGrossUpPmtsInd ClubDuesOrFeesInd  \
# 635278                          NaN               NaN
# 339028                          NaN               NaN
#
#        HousingAllowanceOrResidenceInd FirstClassOrCharterTravelInd  \
# 635278                            NaN                          NaN
# 339028                            NaN                          NaN
#
#        PersonalServicesInd PaymentsForUseOfResidenceInd @documentName  \
# 635278                 NaN                          NaN           NaN
# 339028                 NaN                          NaN           NaN
#
#        @softwareVersionNum
# 635278            2021v4.1
# 339028                 NaN

# %%
print(dfj.columns.tolist())
# Out:
# ['OrganizationName', 'URL', 'DLN', 'EIN', '@documentId', '@softwareId', '@softwareVersion', 'CompensationCommittee', 'CompensationSurvey', 'BoardOrCommitteeApproval', 'SeverancePayment', 'SupplementalNonqualRetirePlan', 'EquityBasedCompArrangement', 'CompBasedOnRevenueOfFilingOrg', 'CompBasedOnRevenueRelatedOrgs', 'CompBasedNetEarningsFilingOrg', 'CompBasedNetEarningsRelateOrgs', 'AnyNonFixedPayments', 'InitialContractException', 'RebuttablePresumptionProcedure', 'Form990ScheduleJPartII', 'IndependentConsultant', 'WrittenEmploymentContract', 'Form990ScheduleJPartIII', 'HousingAllowanceOrResidence', 'WrittenPolicyReTAndEExpenses', 'SubstantiationRequired', 'IdemnificationGrossUpPayments', 'DiscretionarySpendingAccount', 'ClubDuesOrFees', 'FirstClassOrCharterTravel', 'TravelForCompanions', 'Form990OfOtherOrganizations', 'PaymentsForUseOfResidence', 'PersonalServices', 'SeverancePaymentInd', 'SupplementalNonqualRtrPlanInd', 'EquityBasedCompArrngmInd', 'CompBasedOnRevenueOfFlngOrgInd', 'CompBsdOnRevRelatedOrgsInd', 'CompBsdNetEarnsFlngOrgInd', 'CompBsdNetEarnsRltdOrgsInd', 'AnyNonFixedPaymentsInd', 'InitialContractExceptionInd', 'RltdOrgOfficerTrstKeyEmplGrp', 'CompensationCommitteeInd', 'BoardOrCommitteeApprovalInd', 'RebuttablePresumptionProcInd', 'IndependentConsultantInd', 'WrittenEmploymentContractInd', 'CompensationSurveyInd', 'SupplementalInformationDetail', 'Form990OfOtherOrganizationsInd', 'DiscretionarySpendingAcctInd', 'WrittenPolicyRefTAndEExpnssInd', 'SubstantiationRequiredInd', 'TravelForCompanionsInd', 'IdemnificationGrossUpPmtsInd', 'ClubDuesOrFeesInd', 'HousingAllowanceOrResidenceInd', 'FirstClassOrCharterTravelInd', 'PersonalServicesInd', 'PaymentsForUseOfResidenceInd', '@documentName', '@softwareVersionNum']

# %% [markdown]
# #### Save DF

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
dfj.to_pickle('Schedule J (flattened).pkl.gz', compression='gzip')
# Out:
# Current date and time :  2025-06-20 16:56:19
#
# CPU times: total: 2min 12s
# Wall time: 2min 17s

# %% [markdown]
# # Read in Concordance File
# We are going to read in two codebooks. First, there is the 'concordance' file. Specifically, before re-arranging and renaming variables, we will read in the relevant section from the *master concordance* file, and then use this file to identify the relevant 'compensation' variables. In a following notebook, we will be using the *new_variable_name* field as our variable name.

# %%
concordance = pd.read_excel('concordance - Schedule J.xlsx')
print('# of columns:', len(concordance.columns))
print('# of observations:', len(concordance))
concordance[:2]
# Out:
# # of columns: 15
# # of observations: 105
#    Unnamed: 0                                                 xpath  \
# 0           0     /Return/ReturnData/IRS990ScheduleJ/ClubDuesOrFees
# 1           1  /Return/ReturnData/IRS990ScheduleJ/ClubDuesOrFeesInd
#
#     variable_name_new  # of Characters (newly named)  variable name notes  \
# 0  SJ_01_PC_CLUB_FEES                            NaN                  NaN
# 1  SJ_01_PC_CLUB_FEES                            NaN                  NaN
#
#    PARSING NOTES  OTHER NOTES        description            location_code  \
# 0            NaN          NaN  Club dues or fees  SCHED-J-PART-01-LINE-1a
# 1            NaN          NaN  Club dues or fees  SCHED-J-PART-01-LINE-1a
#
#       part data_type_xsd       MongoDB_Name  sub_key      MongoDB_Name2  \
# 0  PART-01  CheckboxType     ClubDuesOrFees      NaN     ClubDuesOrFees
# 1  PART-01  CheckboxType  ClubDuesOrFeesInd      NaN  ClubDuesOrFeesInd
#
#      MongoDB_Name3
# 0  IRS990ScheduleJ
# 1  IRS990ScheduleJ

# %%
concordance['MongoDB_Name2'] = concordance['xpath'].str.split('/')
concordance['MongoDB_Name2'] = concordance['MongoDB_Name2'].apply(lambda x: x[-1])
concordance[['xpath', 'MongoDB_Name', 'MongoDB_Name2', 'variable_name_new']][:2]
# Out:
#                                                   xpath       MongoDB_Name  \
# 0     /Return/ReturnData/IRS990ScheduleJ/ClubDuesOrFees     ClubDuesOrFees
# 1  /Return/ReturnData/IRS990ScheduleJ/ClubDuesOrFeesInd  ClubDuesOrFeesInd
#
#        MongoDB_Name2   variable_name_new
# 0     ClubDuesOrFees  SJ_01_PC_CLUB_FEES
# 1  ClubDuesOrFeesInd  SJ_01_PC_CLUB_FEES

# %%
concordance[(concordance['MongoDB_Name'].notnull())&(concordance['MongoDB_Name2']!=concordance['MongoDB_Name'])]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, xpath, variable_name_new, # of Characters (newly named), variable name notes, PARSING NOTES, OTHER NOTES, description, location_code, part, data_type_xsd, MongoDB_Name, sub_key, MongoDB_Name2, MongoDB_Name3]
# Index: []

# %%
part2_cols = set(concordance[concordance['part']=='PART-02']['MongoDB_Name2'].tolist())
print(len(part2_cols))
part2_cols
# Out:
# 36
# {'BaseCompensationFilingOrg',
#  'BaseCompensationFilingOrgAmt',
#  'BonusFilingOrg',
#  'BonusFilingOrganizationAmount',
#  'BonusRelatedOrganizationsAmt',
#  'BonusRelatedOrgs',
#  'BusinessNameLine1',
#  'BusinessNameLine1Txt',
#  'BusinessNameLine2',
#  'BusinessNameLine2Txt',
#  'CompBasedOnRelatedOrgs',
#  'CompReportPrior990FilingOrg',
#  'CompReportPrior990FilingOrgAmt',
#  'CompReportPrior990RelatedOrgs',
#  'CompReportPrior990RltdOrgsAmt',
#  'CompensationBasedOnRltdOrgsAmt',
#  'DeferredCompFilingOrg',
#  'DeferredCompRelatedOrgs',
#  'DeferredCompRltdOrgsAmt',
#  'DeferredCompensationFlngOrgAmt',
#  'NamePerson',
#  'NontaxableBenefitsFilingOrg',
#  'NontaxableBenefitsFilingOrgAmt',
#  'NontaxableBenefitsRelatedOrgs',
#  'NontaxableBenefitsRltdOrgsAmt',
#  'OtherCompensationFilingOrg',
#  'OtherCompensationFilingOrgAmt',
#  'OtherCompensationRelatedOrgs',
#  'OtherCompensationRltdOrgsAmt',
#  'PersonNm',
#  'Title',
#  'TitleTxt',
#  'TotalCompensationFilingOrg',
#  'TotalCompensationFilingOrgAmt',
#  'TotalCompensationRelatedOrgs',
#  'TotalCompensationRltdOrgsAmt'}

# %%
concordance[['xpath', 'part', 'MongoDB_Name', 'MongoDB_Name2', 'MongoDB_Name3', 'variable_name_new']][-44:-6]
# Out:
#                                                                                                 xpath  \
# 61                               /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/NamePerson
# 62                           /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/PersonNm
# 63           /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/NameBusiness/BusinessNameLine1
# 64     /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/BusinessName/BusinessNameLine1
# 65  /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/BusinessName/BusinessNameLine1Txt
# 66           /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/NameBusiness/BusinessNameLine2
# 67     /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/BusinessName/BusinessNameLine2
# 68  /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/BusinessName/BusinessNameLine2Txt
# 69                                    /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/Title
# 70                           /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/TitleTxt
# 71                /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/BaseCompensationFilingOrg
# 72       /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/BaseCompensationFilingOrgAmt
# 73                   /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/CompBasedOnRelatedOrgs
# 74     /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/CompensationBasedOnRltdOrgsAmt
# 75                           /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/BonusFilingOrg
# 76      /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/BonusFilingOrganizationAmount
# 77                         /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/BonusRelatedOrgs
# 78       /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/BonusRelatedOrganizationsAmt
# 79               /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/OtherCompensationFilingOrg
# 80      /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/OtherCompensationFilingOrgAmt
# 81             /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/OtherCompensationRelatedOrgs
# 82       /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/OtherCompensationRltdOrgsAmt
# 83                    /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/DeferredCompFilingOrg
# 84     /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/DeferredCompensationFlngOrgAmt
# 85                  /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/DeferredCompRelatedOrgs
# 86            /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/DeferredCompRltdOrgsAmt
# 87              /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/NontaxableBenefitsFilingOrg
# 88     /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/NontaxableBenefitsFilingOrgAmt
# 89            /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/NontaxableBenefitsRelatedOrgs
# 90      /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/NontaxableBenefitsRltdOrgsAmt
# 91               /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/TotalCompensationFilingOrg
# 92      /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/TotalCompensationFilingOrgAmt
# 93             /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/TotalCompensationRelatedOrgs
# 94       /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/TotalCompensationRltdOrgsAmt
# 95              /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/CompReportPrior990FilingOrg
# 96     /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/CompReportPrior990FilingOrgAmt
# 97            /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartII/CompReportPrior990RelatedOrgs
# 98      /Return/ReturnData/IRS990ScheduleJ/RltdOrgOfficerTrstKeyEmplGrp/CompReportPrior990RltdOrgsAmt
#
#        part MongoDB_Name                   MongoDB_Name2  \
# 61  PART-02          NaN                      NamePerson
# 62  PART-02          NaN                        PersonNm
# 63  PART-02          NaN               BusinessNameLine1
# 64  PART-02          NaN               BusinessNameLine1
# 65  PART-02          NaN            BusinessNameLine1Txt
# 66  PART-02          NaN               BusinessNameLine2
# 67  PART-02          NaN               BusinessNameLine2
# 68  PART-02          NaN            BusinessNameLine2Txt
# 69  PART-02          NaN                           Title
# 70  PART-02          NaN                        TitleTxt
# 71  PART-02          NaN       BaseCompensationFilingOrg
# 72  PART-02          NaN    BaseCompensationFilingOrgAmt
# 73  PART-02          NaN          CompBasedOnRelatedOrgs
# 74  PART-02          NaN  CompensationBasedOnRltdOrgsAmt
# 75  PART-02          NaN                  BonusFilingOrg
# 76  PART-02          NaN   BonusFilingOrganizationAmount
# 77  PART-02          NaN                BonusRelatedOrgs
# 78  PART-02          NaN    BonusRelatedOrganizationsAmt
# 79  PART-02          NaN      OtherCompensationFilingOrg
# 80  PART-02          NaN   OtherCompensationFilingOrgAmt
# 81  PART-02          NaN    OtherCompensationRelatedOrgs
# 82  PART-02          NaN    OtherCompensationRltdOrgsAmt
# 83  PART-02          NaN           DeferredCompFilingOrg
# 84  PART-02          NaN  DeferredCompensationFlngOrgAmt
# 85  PART-02          NaN         DeferredCompRelatedOrgs
# 86  PART-02          NaN         DeferredCompRltdOrgsAmt
# 87  PART-02          NaN     NontaxableBenefitsFilingOrg
# 88  PART-02          NaN  NontaxableBenefitsFilingOrgAmt
# 89  PART-02          NaN   NontaxableBenefitsRelatedOrgs
# 90  PART-02          NaN   NontaxableBenefitsRltdOrgsAmt
# 91  PART-02          NaN      TotalCompensationFilingOrg
# 92  PART-02          NaN   TotalCompensationFilingOrgAmt
# 93  PART-02          NaN    TotalCompensationRelatedOrgs
# 94  PART-02          NaN    TotalCompensationRltdOrgsAmt
# 95  PART-02          NaN     CompReportPrior990FilingOrg
# 96  PART-02          NaN  CompReportPrior990FilingOrgAmt
# 97  PART-02          NaN   CompReportPrior990RelatedOrgs
# 98  PART-02          NaN   CompReportPrior990RltdOrgsAmt
#
#                    MongoDB_Name3                 variable_name_new
# 61        Form990ScheduleJPartII     SJ_02_PC_NAME_OFF_TRST_KEYEMP
# 62  RltdOrgOfficerTrstKeyEmplGrp     SJ_02_PC_NAME_OFF_TRST_KEYEMP
# 63                  NameBusiness  SJ_02_PC_NAME_OFF_TRST_KEYEMP_L1
# 64                  BusinessName  SJ_02_PC_NAME_OFF_TRST_KEYEMP_L1
# 65                  BusinessName  SJ_02_PC_NAME_OFF_TRST_KEYEMP_L1
# 66                  NameBusiness  SJ_02_PC_NAME_OFF_TRST_KEYEMP_L2
# 67                  BusinessName  SJ_02_PC_NAME_OFF_TRST_KEYEMP_L2
# 68                  BusinessName  SJ_02_PC_NAME_OFF_TRST_KEYEMP_L2
# 69        Form990ScheduleJPartII                    SJ_02_PC_TITLE
# 70  RltdOrgOfficerTrstKeyEmplGrp                    SJ_02_PC_TITLE
# 71        Form990ScheduleJPartII                SJ_02_PC_COMP_BASE
# 72  RltdOrgOfficerTrstKeyEmplGrp                SJ_02_PC_COMP_BASE
# 73        Form990ScheduleJPartII        SJ_02_PC_COMP_BASE_RELATED
# 74  RltdOrgOfficerTrstKeyEmplGrp        SJ_02_PC_COMP_BASE_RELATED
# 75        Form990ScheduleJPartII               SJ_02_PC_COMP_BONUS
# 76  RltdOrgOfficerTrstKeyEmplGrp               SJ_02_PC_COMP_BONUS
# 77        Form990ScheduleJPartII       SJ_02_PC_COMP_BONUS_RELATED
# 78  RltdOrgOfficerTrstKeyEmplGrp       SJ_02_PC_COMP_BONUS_RELATED
# 79        Form990ScheduleJPartII               SJ_02_PC_COMP_OTHER
# 80  RltdOrgOfficerTrstKeyEmplGrp               SJ_02_PC_COMP_OTHER
# 81        Form990ScheduleJPartII       SJ_02_PC_COMP_OTHER_RELATED
# 82  RltdOrgOfficerTrstKeyEmplGrp       SJ_02_PC_COMP_OTHER_RELATED
# 83        Form990ScheduleJPartII            SJ_02_PC_COMP_DEFERRED
# 84  RltdOrgOfficerTrstKeyEmplGrp            SJ_02_PC_COMP_DEFERRED
# 85        Form990ScheduleJPartII    SJ_02_PC_COMP_DEFERRED_RELATED
# 86  RltdOrgOfficerTrstKeyEmplGrp    SJ_02_PC_COMP_DEFERRED_RELATED
# 87        Form990ScheduleJPartII            SJ_02_PC_NONTAXED_BENF
# 88  RltdOrgOfficerTrstKeyEmplGrp            SJ_02_PC_NONTAXED_BENF
# 89        Form990ScheduleJPartII    SJ_02_PC_NONTAXED_BENF_RELATED
# 90  RltdOrgOfficerTrstKeyEmplGrp    SJ_02_PC_NONTAXED_BENF_RELATED
# 91        Form990ScheduleJPartII               SJ_02_PC_COMP_TOTAL
# 92  RltdOrgOfficerTrstKeyEmplGrp               SJ_02_PC_COMP_TOTAL
# 93        Form990ScheduleJPartII       SJ_02_PC_COMP_TOTAL_RELATED
# 94  RltdOrgOfficerTrstKeyEmplGrp       SJ_02_PC_COMP_TOTAL_RELATED
# 95        Form990ScheduleJPartII           SJ_02_PC_COMP_DEF_PRIOR
# 96  RltdOrgOfficerTrstKeyEmplGrp           SJ_02_PC_COMP_DEF_PRIOR
# 97        Form990ScheduleJPartII   SJ_02_PC_COMP_DEF_PRIOR_RELATED
# 98  RltdOrgOfficerTrstKeyEmplGrp   SJ_02_PC_COMP_DEF_PRIOR_RELATED

# %%
['RltdOrgOfficerTrstKeyEmplGrp', 'Form990ScheduleJPartII']
# Out:
# ['RltdOrgOfficerTrstKeyEmplGrp', 'Form990ScheduleJPartII']

# %%
concordance['MongoDB_Name3'] = concordance['xpath'].str.split('/')
concordance['MongoDB_Name3'] = concordance['MongoDB_Name3'].apply(lambda x: x[-2])
concordance[['xpath', 'part', 'MongoDB_Name', 'MongoDB_Name2', 'MongoDB_Name3', 'variable_name_new']][-6:]
# Out:
#                                                                                          xpath  \
# 99                      /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartIII/Explanation
# 100            /Return/ReturnData/IRS990ScheduleJ/SupplementalInformationDetail/ExplanationTxt
# 101                 /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartIII/ReturnReference
# 102  /Return/ReturnData/IRS990ScheduleJ/SupplementalInformationDetail/FormAndLineReferenceDesc
# 103                      /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartIII/Identifier
# 104             /Return/ReturnData/IRS990ScheduleJ/SupplementalInformationDetail/IdentifierTxt
#
#         part MongoDB_Name             MongoDB_Name2  \
# 99   PART-03          NaN               Explanation
# 100  PART-03          NaN            ExplanationTxt
# 101  PART-03          NaN           ReturnReference
# 102  PART-03          NaN  FormAndLineReferenceDesc
# 103  PART-03          NaN                Identifier
# 104  PART-03          NaN             IdentifierTxt
#
#                      MongoDB_Name3                 variable_name_new
# 99         Form990ScheduleJPartIII         SJ_03_PC_EXPLANATION_TEXT
# 100  SupplementalInformationDetail         SJ_03_PC_EXPLANATION_TEXT
# 101        Form990ScheduleJPartIII  SJ_03_PC_FORM_AND_LINE_REFERENCE
# 102  SupplementalInformationDetail  SJ_03_PC_FORM_AND_LINE_REFERENCE
# 103        Form990ScheduleJPartIII               SJ_03_PC_IDENTIFIER
# 104  SupplementalInformationDetail               SJ_03_PC_IDENTIFIER

# %%
part2_cols = set(concordance[concordance['part']=='PART-02']['MongoDB_Name3'].tolist())
print(len(part2_cols))
part2_cols
# Out:
# 4
# {'BusinessName',
#  'Form990ScheduleJPartII',
#  'NameBusiness',
#  'RltdOrgOfficerTrstKeyEmplGrp'}

# %%
part3_cols = set(concordance[concordance['part']=='PART-03']['MongoDB_Name3'].tolist())
print(len(part3_cols))
part3_cols
# Out:
# 2
# {'Form990ScheduleJPartIII', 'SupplementalInformationDetail'}

# %%
set(part2_cols).intersection(set(dfj.columns.tolist()))
# Out:
# {'Form990ScheduleJPartII', 'RltdOrgOfficerTrstKeyEmplGrp'}

# %%
set(part3_cols).intersection(set(dfj.columns.tolist()))
# Out:
# {'Form990ScheduleJPartIII', 'SupplementalInformationDetail'}

# %% [markdown]
# #### Save Part II of Schedule J

# %%
dfj[['URL', 'Form990ScheduleJPartII', 'RltdOrgOfficerTrstKeyEmplGrp']].sample(5)
# Out:
#                                                                         URL  \
# 527936  https://s3.amazonaws.com/irs-form-990/202230469349301663_public.xml
# 308927  https://s3.amazonaws.com/irs-form-990/201800609349300120_public.xml
# 306149  https://s3.amazonaws.com/irs-form-990/201801009349301210_public.xml
# 507472  https://s3.amazonaws.com/irs-form-990/202202179349301750_public.xml
# 697642  https://s3.amazonaws.com/irs-form-990/202540169349300429_public.xml
#
#        Form990ScheduleJPartII  \
# 527936                    NaN
# 308927                    NaN
# 306149                    NaN
# 507472                    NaN
# 697642                    NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                RltdOrgOfficerTrstKeyEmplGrp
# 527936  [{'PersonNm': 'Alex Corrales', 'TitleTxt': 'WHA CEO', 'BaseCompensationFilingOrgAmt': '0', 'CompensationBasedOnRltdOrgsAmt': '192142', 'BonusFilingOrganizationAmount': '0', 'BonusRelatedOrganizationsAmt': '0', 'OtherCompensationFilingOrgAmt': '0', 'OtherCompensationRltdOrgsAmt': '0', 'DeferredCompensationFlngOrgAmt': '0', 'DeferredCompRltdOrgsAmt': '33756', 'NontaxableBenefitsFilingOrgAmt': '0', 'NontaxableBenefitsRltdOrgsAmt': '71730', 'TotalCompensationFilingOrgAmt': '0', 'TotalCompensatio...
# 308927                                                                                                                                                                                                                                                                                                                                 {'PersonNm': 'FRANK SIRIANNI', 'TitleTxt': 'PRESIDENT', 'BaseCompensationFilingOrgAmt': '165454', 'OtherCompensationFilingOrgAmt': '780', 'TotalCompensationFilingOrgAmt': '166234'}
# 306149  {'PersonNm': 'LES WATERS', 'TitleTxt': 'ARTISTIC DIRECTOR', 'BaseCompensationFilingOrgAmt': '216644', 'CompensationBasedOnRltdOrgsAmt': '0', 'BonusFilingOrganizationAmount': '0', 'BonusRelatedOrganizationsAmt': '0', 'OtherCompensationFilingOrgAmt': '7378', 'OtherCompensationRltdOrgsAmt': '0', 'DeferredCompensationFlngOrgAmt': '4371', 'DeferredCompRltdOrgsAmt': '0', 'NontaxableBenefitsFilingOrgAmt': '6346', 'NontaxableBenefitsRltdOrgsAmt': '0', 'TotalCompensationFilingOrgAmt': '234739', 'Tota...
# 507472                                                                                                                                                                                                                                                               {'PersonNm': 'Laurie Szenicer', 'TitleTxt': 'Chief Executive & Dev. Officer', 'BaseCompensationFilingOrgAmt': '172250', 'BonusFilingOrganizationAmount': '10000', 'NontaxableBenefitsFilingOrgAmt': '3135', 'TotalCompensationFilingOrgAmt': '185385'}
# 697642                                                                                                                                                                                                                                                                                                                    {'PersonNm': 'CHRISTOPHER MCGHEE', 'TitleTxt': 'TRAINING COORD', 'BaseCompensationFilingOrgAmt': '159889', 'DeferredCompensationFlngOrgAmt': '101251', 'TotalCompensationFilingOrgAmt': '261140'}

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
dfj[['URL', 'Form990ScheduleJPartII', 'RltdOrgOfficerTrstKeyEmplGrp']].to_pickle('Schedule J (Part II).pkl.gz', compression='gzip')
# Out:
# Current date and time :  2025-06-20 17:05:41
#
# CPU times: total: 1min 22s
# Wall time: 1min 27s

# %% [markdown]
# #### Drop Part II columns

# %%
# %%time
dfj = dfj.drop('Form990ScheduleJPartII', axis=1)
dfj = dfj.drop('RltdOrgOfficerTrstKeyEmplGrp', axis=1)
# Out:
# CPU times: total: 2.44 s
# Wall time: 2.51 s

# %% [markdown]
# #### Save Part III

# %%
dfj[['URL', 'Form990ScheduleJPartIII', 'SupplementalInformationDetail']].sample(5)
# Out:
#                                                                         URL  \
# 705046  https://s3.amazonaws.com/irs-form-990/202422959349301912_public.xml
# 771345  https://s3.amazonaws.com/irs-form-990/202441359349301999_public.xml
# 680635  https://s3.amazonaws.com/irs-form-990/202343139349303809_public.xml
# 75048   https://s3.amazonaws.com/irs-form-990/201300749349300535_public.xml
# 85020   https://s3.amazonaws.com/irs-form-990/201322209349300412_public.xml
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Form990ScheduleJPartIII  \
# 705046                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 771345                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 680635                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 75048                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# 85020   [{'Identifier': 'SchJ_P01_S00_L04', 'ReturnReference': 'Schedule J, Part I, Line 4', 'Explanation': 'Michael Cleary, former senior VP & COO, received a severance payment of $162,656. Cheryl Yager, Director of Credit, received a severance payment of $97,414.'}, {'Identifier': 'SchJ_P01_S00_L07', 'ReturnReference': 'Schedule J, Part I, Line 7', 'Explanation': 'ERCOT maintains an employee recognition award program whereby employees can receive one or more awards during the course of the year up...
#
#                                                                                                                                                                                                                                                                                                                                         SupplementalInformationDetail
# 705046                                                                                                                                                                                                                                                                                                                                                            NaN
# 771345                                                                                                                                                                                                                                                                                                                                                            NaN
# 680635  {'FormAndLineReferenceDesc': 'SCHEDULE J PART I', 'ExplanationTxt': 'LINE 3: COMPENSATION OF THE ORGANIZATION'S TOP MANAGEMENT OFFICIALS WAS PAID BY A RELATED ORGANIZATION. MENNONITE CHURCH BUILDINGS, INC. RELIED ON THE RELATED ORGANIZATION, WHICH USED SEVERAL OF THE METHODS DESCRIBED ON LINE 3, TO ESTABLISH TOP MANAGEMENT OFFICIAL COMPENSATION.'}
# 75048                                                                                                                                                                                                                                                                                                                                                             NaN
# 85020                                                                                                                                                                                                                                                                                                                                                             NaN

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
dfj[['URL', 'Form990ScheduleJPartIII', 'SupplementalInformationDetail']].to_pickle('Schedule J (Part III).pkl.gz', compression='gzip')
# Out:
# Current date and time :  2025-06-20 22:23:56
#
# CPU times: total: 22.2 s
# Wall time: 25.8 s

# %%
dfj[dfj['URL']=='https://s3.amazonaws.com/irs-form-990/201401349349308135_public.xml']
# Out:
#                              OrganizationName  \
# 137883  HARVEY L MILLER SUPPORTING FOUNDATION
#
#                                                                         URL  \
# 137883  https://s3.amazonaws.com/irs-form-990/201401349349308135_public.xml
#
#                    DLN        EIN       @documentId @softwareId  \
# 137883  93493134081354  900187252  RetDoc1042400001         NaN
#
#        @softwareVersion CompensationCommittee CompensationSurvey  \
# 137883              NaN                   NaN                NaN
#
#        BoardOrCommitteeApproval SeverancePayment  \
# 137883                      NaN                0
#
#        SupplementalNonqualRetirePlan EquityBasedCompArrangement  \
# 137883                             1                          0
#
#        CompBasedOnRevenueOfFilingOrg CompBasedOnRevenueRelatedOrgs  \
# 137883                             0                             0
#
#        CompBasedNetEarningsFilingOrg CompBasedNetEarningsRelateOrgs  \
# 137883                             0                              0
#
#        AnyNonFixedPayments InitialContractException  \
# 137883                   0                        0
#
#        RebuttablePresumptionProcedure IndependentConsultant  \
# 137883                            NaN                   NaN
#
#        WrittenEmploymentContract  \
# 137883                       NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Form990ScheduleJPartIII  \
# 137883  {'ReturnReference': 'Part I, Line 4b', 'Explanation': 'Steven B. Nasatir: In 1999 the Jewish Federation entered into an agreement with Steven Nasatir that was contingent upon 5 more years of service as president and CEO and would result in annual payments of $50,000 per year (net of tax) beginning at age 64 and lasting throughout his lifetime. Dr. Nasatir began receiving payments under this agreement in 2009. During 2012, the Jewish Federation entered into a second agreement with Steven Nasa...
#
#        HousingAllowanceOrResidence WrittenPolicyReTAndEExpenses  \
# 137883                         NaN                          NaN
#
#        SubstantiationRequired IdemnificationGrossUpPayments  \
# 137883                    NaN                           NaN
#
#        DiscretionarySpendingAccount ClubDuesOrFees FirstClassOrCharterTravel  \
# 137883                          NaN            NaN                       NaN
#
#        TravelForCompanions Form990OfOtherOrganizations  \
# 137883                 NaN                         NaN
#
#        PaymentsForUseOfResidence PersonalServices SeverancePaymentInd  \
# 137883                       NaN              NaN                 NaN
#
#        SupplementalNonqualRtrPlanInd EquityBasedCompArrngmInd  \
# 137883                           NaN                      NaN
#
#        CompBasedOnRevenueOfFlngOrgInd CompBsdOnRevRelatedOrgsInd  \
# 137883                            NaN                        NaN
#
#        CompBsdNetEarnsFlngOrgInd CompBsdNetEarnsRltdOrgsInd  \
# 137883                       NaN                        NaN
#
#        AnyNonFixedPaymentsInd InitialContractExceptionInd  \
# 137883                    NaN                         NaN
#
#        CompensationCommitteeInd BoardOrCommitteeApprovalInd  \
# 137883                      NaN                         NaN
#
#        RebuttablePresumptionProcInd IndependentConsultantInd  \
# 137883                          NaN                      NaN
#
#        WrittenEmploymentContractInd CompensationSurveyInd  \
# 137883                          NaN                   NaN
#
#        SupplementalInformationDetail Form990OfOtherOrganizationsInd  \
# 137883                           NaN                            NaN
#
#        DiscretionarySpendingAcctInd WrittenPolicyRefTAndEExpnssInd  \
# 137883                          NaN                            NaN
#
#        SubstantiationRequiredInd TravelForCompanionsInd  \
# 137883                       NaN                    NaN
#
#        IdemnificationGrossUpPmtsInd ClubDuesOrFeesInd  \
# 137883                          NaN               NaN
#
#        HousingAllowanceOrResidenceInd FirstClassOrCharterTravelInd  \
# 137883                            NaN                          NaN
#
#        PersonalServicesInd PaymentsForUseOfResidenceInd @documentName  \
# 137883                 NaN                          NaN           NaN
#
#        @softwareVersionNum
# 137883                 NaN

# %% [markdown]
# #### Drop Part III columns

# %%
# %%time
dfj = dfj.drop('Form990ScheduleJPartIII', axis=1)
dfj = dfj.drop('SupplementalInformationDetail', axis=1)
# Out:
# CPU times: total: 2.31 s
# Wall time: 2.43 s

# %% [markdown]
# #### Save Part I

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
dfj.to_pickle('Schedule J (Part I).pkl.gz', compression='gzip')
# Out:
# Current date and time :  2024-04-17 13:40:06
#
# CPU times: total: 24.7 s
# Wall time: 25.7 s
