# %% [markdown]
# # Overview
#
# Based off *IRS 990 e-File Data -- Excise Tax Project (2) -- Schedule J Part (I) -- Verify New Variables and Combine and Binarize Columns.ipynb*
#
# From the prior notebook I read in this file:
# - *Schedule J (Part I).pkl.gz*
#
# In this notebook I read in the Part I of Schedule J, along with the unverified concordance file. After initial verifications I go back to Excel and modify the concordance file, read it back in, and perform additional verifications. I then combine and binarize the 26 Schedule J (Part I) columns and save the following files:
#
# - *Schedule J (Part I) - parsed.pkl.gz*

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from pandas import Series

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
from platform import python_version
print(python_version())
# Out:
# 3.10.11

# %%
#http://pandas.pydata.org/pandas-docs/stable/options.html
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 250)

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)

# %% [markdown]
# #### Set working directory

# %%
#cd '/Users/gsaxton/Dropbox/990 e-file data'

# %%
pwd
# Out:
# 'C:\\Users\\Gregory\\Jupyter_Notebooks'

# %%
cd "C:\\Users\\Gregory\\IRS 990 Control Variables\\"
# Out:
# C:\Users\Gregory\IRS 990 Control Variables

# %% [markdown]
# # Read in Concordance File
# We are going to read in two codebooks. First, there is the 'concordance' file. Specifically, before re-arranging and renaming variables, we will read in the relevant section from the *master concordance* file, and then use this file to identify the relevant 'compensation' variables. In a following notebook, we will be using the *new_variable_name* field as our variable name.

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
concordance = pd.read_excel('concordance - Schedule J (Part I).xlsx')
print('# of columns:', len(concordance.columns))
print('# of observations:', len(concordance))
concordance[:2]
# Out:
# Current date and time :  2025-06-20 22:28:28
#
# # of columns: 15
# # of observations: 52
# CPU times: total: 172 ms
# Wall time: 11.2 s
#                                                   xpath   variable_name_new  \
# 0     /Return/ReturnData/IRS990ScheduleJ/ClubDuesOrFees  SJ_01_PC_CLUB_FEES
# 1  /Return/ReturnData/IRS990ScheduleJ/ClubDuesOrFeesInd  SJ_01_PC_CLUB_FEES
#
#    # of Characters (newly named)  variable name notes  PARSING NOTES  \
# 0                            NaN                  NaN            NaN
# 1                            NaN                  NaN            NaN
#
#    OTHER NOTES        description            location_code     part  \
# 0          NaN  Club dues or fees  SCHED-J-PART-01-LINE-1a  PART-01
# 1          NaN  Club dues or fees  SCHED-J-PART-01-LINE-1a  PART-01
#
#   data_type_xsd  fill_null  BINARIZE       MongoDB_Name  sub_key  sub_sub_key
# 0  CheckboxType        NaN  binarize     ClubDuesOrFees      NaN          NaN
# 1  CheckboxType        NaN  binarize  ClubDuesOrFeesInd      NaN          NaN

# %%
concordance[concordance['data_type_xsd'].isnull()][['variable_name_new', 'description']]
# Out:
# Empty DataFrame
# Columns: [variable_name_new, description]
# Index: []

# %%
concordance['data_type_xsd'].value_counts()
# Out:
# data_type_xsd
# CheckboxType    28
# BooleanType     24
# Name: count, dtype: int64

# %%
concordance[concordance['data_type_xsd']=='BooleanType'][:1]
# Out:
#                                                                 xpath  \
# 16  /Return/ReturnData/IRS990ScheduleJ/WrittenPolicyRefTAndEExpnssInd
#
#           variable_name_new  # of Characters (newly named)  \
# 16  SJ_01_PC_WRITTEN_POLICY                            NaN
#
#     variable name notes  PARSING NOTES  OTHER NOTES  \
# 16                  NaN            NaN          NaN
#
#                                    description            location_code  \
# 16  Written policy reference T and E expenses?  SCHED-J-PART-01-LINE-1b
#
#        part data_type_xsd  fill_null  BINARIZE  \
# 16  PART-01   BooleanType        NaN  binarize
#
#                       MongoDB_Name  sub_key  sub_sub_key
# 16  WrittenPolicyRefTAndEExpnssInd      NaN          NaN

# %%
concordance[concordance['data_type_xsd']=='CheckboxType'][:1]
# Out:
#                                                xpath   variable_name_new  \
# 0  /Return/ReturnData/IRS990ScheduleJ/ClubDuesOrFees  SJ_01_PC_CLUB_FEES
#
#    # of Characters (newly named)  variable name notes  PARSING NOTES  \
# 0                            NaN                  NaN            NaN
#
#    OTHER NOTES        description            location_code     part  \
# 0          NaN  Club dues or fees  SCHED-J-PART-01-LINE-1a  PART-01
#
#   data_type_xsd  fill_null  BINARIZE    MongoDB_Name  sub_key  sub_sub_key
# 0  CheckboxType        NaN  binarize  ClubDuesOrFees      NaN          NaN

# %% [markdown]
# # Read 990 DB into PANDAS
# - In previous round there were 1,547,828 observations; in Feb. 2020 there were 1,727,056 observations; in Nov. 2020 there are 1,895,016 observations
# - I also switched to using the *.pkl* file

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df = pd.read_pickle('Schedule J (Part I).pkl.gz', compression='gzip')
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
df[:2]
# Out:
# Current date and time :  2025-06-20 22:29:27
#
# # of columns: 58
# # of observations: 687646
# CPU times: total: 4.73 s
# Wall time: 5.94 s
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301316_public.xml
#
#        @documentId @softwareId @softwareVersion CompensationCommittee  \
# 0  IRS990ScheduleJ    10000105         2010v3.2                     X
# 1  IRS990ScheduleJ    10000105         2010v3.2                     X
#
#   CompensationSurvey BoardOrCommitteeApproval SeverancePayment  \
# 0                  X                        X            false
# 1                  X                        X            false
#
#   SupplementalNonqualRetirePlan EquityBasedCompArrangement  \
# 0                          true                      false
# 1                          true                      false
#
#   CompBasedOnRevenueOfFilingOrg CompBasedOnRevenueRelatedOrgs  \
# 0                         false                         false
# 1                         false                         false
#
#   CompBasedNetEarningsFilingOrg CompBasedNetEarningsRelateOrgs  \
# 0                         false                          false
# 1                         false                          false
#
#   AnyNonFixedPayments InitialContractException RebuttablePresumptionProcedure  \
# 0               false                    false                          false
# 1               false                    false                          false
#
#   IndependentConsultant WrittenEmploymentContract HousingAllowanceOrResidence  \
# 0                   NaN                       NaN                         NaN
# 1                   NaN                       NaN                         NaN
#
#   WrittenPolicyReTAndEExpenses SubstantiationRequired  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
#
#   IdemnificationGrossUpPayments DiscretionarySpendingAccount ClubDuesOrFees  \
# 0                           NaN                          NaN            NaN
# 1                           NaN                          NaN            NaN
#
#   FirstClassOrCharterTravel TravelForCompanions Form990OfOtherOrganizations  \
# 0                       NaN                 NaN                         NaN
# 1                       NaN                 NaN                         NaN
#
#   PaymentsForUseOfResidence PersonalServices SeverancePaymentInd  \
# 0                       NaN              NaN                 NaN
# 1                       NaN              NaN                 NaN
#
#   SupplementalNonqualRtrPlanInd EquityBasedCompArrngmInd  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
#
#   CompBasedOnRevenueOfFlngOrgInd CompBsdOnRevRelatedOrgsInd  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
#
#   CompBsdNetEarnsFlngOrgInd CompBsdNetEarnsRltdOrgsInd AnyNonFixedPaymentsInd  \
# 0                       NaN                        NaN                    NaN
# 1                       NaN                        NaN                    NaN
#
#   InitialContractExceptionInd CompensationCommitteeInd  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
#
#   BoardOrCommitteeApprovalInd RebuttablePresumptionProcInd  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
#
#   IndependentConsultantInd WrittenEmploymentContractInd CompensationSurveyInd  \
# 0                      NaN                          NaN                   NaN
# 1                      NaN                          NaN                   NaN
#
#   Form990OfOtherOrganizationsInd DiscretionarySpendingAcctInd  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
#
#   WrittenPolicyRefTAndEExpnssInd SubstantiationRequiredInd  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
#
#   TravelForCompanionsInd IdemnificationGrossUpPmtsInd ClubDuesOrFeesInd  \
# 0                    NaN                          NaN               NaN
# 1                    NaN                          NaN               NaN
#
#   HousingAllowanceOrResidenceInd FirstClassOrCharterTravelInd  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
#
#   PersonalServicesInd PaymentsForUseOfResidenceInd @documentName  \
# 0                 NaN                          NaN           NaN
# 1                 NaN                          NaN           NaN
#
#   @softwareVersionNum
# 0                 NaN
# 1                 NaN

# %% [markdown]
# ### Identify which *MongoDB_Names* and xpaths are not in data

# %%
print(df.columns.tolist()[:5])
# Out:
# ['URL', '@documentId', '@softwareId', '@softwareVersion', 'CompensationCommittee']

# %%
print(concordance['MongoDB_Name'].tolist())
# Out:
# ['ClubDuesOrFees', 'ClubDuesOrFeesInd', 'DiscretionarySpendingAccount', 'DiscretionarySpendingAcctInd', 'FirstClassOrCharterTravel', 'FirstClassOrCharterTravelInd', 'HousingAllowanceOrResidence', 'HousingAllowanceOrResidenceInd', 'IdemnificationGrossUpPayments', 'IdemnificationGrossUpPmtsInd', 'PaymentsForUseOfResidence', 'PaymentsForUseOfResidenceInd', 'PersonalServices', 'PersonalServicesInd', 'TravelForCompanions', 'TravelForCompanionsInd', 'WrittenPolicyRefTAndEExpnssInd', 'WrittenPolicyReTAndEExpenses', 'SubstantiationRequired', 'SubstantiationRequiredInd', 'BoardOrCommitteeApproval', 'BoardOrCommitteeApprovalInd', 'CompensationCommittee', 'CompensationCommitteeInd', 'CompensationSurvey', 'CompensationSurveyInd', 'Form990OfOtherOrganizations', 'Form990OfOtherOrganizationsInd', 'IndependentConsultant', 'IndependentConsultantInd', 'WrittenEmploymentContract', 'WrittenEmploymentContractInd', 'SeverancePayment', 'SeverancePaymentInd', 'SupplementalNonqualRetirePlan', 'SupplementalNonqualRtrPlanInd', 'EquityBasedCompArrangement', 'EquityBasedCompArrngmInd', 'CompBasedOnRevenueOfFilingOrg', 'CompBasedOnRevenueOfFlngOrgInd', 'CompBasedOnRevenueRelatedOrgs', 'CompBsdOnRevRelatedOrgsInd', 'CompBasedNetEarningsFilingOrg', 'CompBsdNetEarnsFlngOrgInd', 'CompBasedNetEarningsRelateOrgs', 'CompBsdNetEarnsRltdOrgsInd', 'AnyNonFixedPayments', 'AnyNonFixedPaymentsInd', 'InitialContractException', 'InitialContractExceptionInd', 'RebuttablePresumptionProcedure', 'RebuttablePresumptionProcInd']

# %%
set(df.columns.tolist()) - set(concordance['MongoDB_Name'].tolist())
# Out:
# {'@documentId',
#  '@documentName',
#  '@softwareId',
#  '@softwareVersion',
#  '@softwareVersionNum',
#  'URL'}

# %%
df[['@documentId',
 '@documentName',
 '@softwareId',
 '@softwareVersion',
 '@softwareVersionNum', 
 'URL']].describe().T
# Out:
#                       count  unique  \
# @documentId          687646     529
# @documentName          1225       1
# @softwareId          103808     100
# @softwareVersion      25771      31
# @softwareVersionNum   76149      41
# URL                  687646  687646
#
#                                                                                      top  \
# @documentId                                                             RetDoc1042400001
# @documentName                                                            IRS990ScheduleJ
# @softwareId                                                                     21013475
# @softwareVersion                                                                   v1.00
# @softwareVersionNum                                                                v1.00
# URL                  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#                        freq
# @documentId          416532
# @documentName          1225
# @softwareId            4861
# @softwareVersion       5696
# @softwareVersionNum   12993
# URL                       1

# %%
df[['@documentId',
 '@documentName',
 '@softwareId',
 '@softwareVersion',
 '@softwareVersionNum']].sample(15)
# Out:
#              @documentId @documentName @softwareId @softwareVersion  \
# 105744   IRS990ScheduleJ           NaN    12000229         2012v2.0
# 71531            R000007           NaN    11000129            v1.00
# 145314  RetDoc1042400001           NaN         NaN              NaN
# 285295  RetDoc1042400001           NaN         NaN              NaN
# 376968          00000005           NaN         NaN              NaN
# 283947  RetDoc1042400001           NaN         NaN              NaN
# 97282   RetDoc1042400001           NaN         NaN              NaN
# 247884  RetDoc1042400001           NaN         NaN              NaN
# 395361  RetDoc1042400001           NaN         NaN              NaN
# 648921  RetDoc1042400001           NaN         NaN              NaN
# 642112   IRS990ScheduleJ           NaN    22015553              NaN
# 352928   IRS990ScheduleJ           NaN    17005038              NaN
# 410479  RetDoc1042400001           NaN         NaN              NaN
# 182547  RetDoc1042400001           NaN         NaN              NaN
# 356930  RetDoc1042400001           NaN         NaN              NaN
#
#        @softwareVersionNum
# 105744                 NaN
# 71531                  NaN
# 145314                 NaN
# 285295                 NaN
# 376968                 NaN
# 283947                 NaN
# 97282                  NaN
# 247884                 NaN
# 395361                 NaN
# 648921                 NaN
# 642112            2022v5.0
# 352928            2017v2.2
# 410479                 NaN
# 182547                 NaN
# 356930                 NaN

# %% [markdown]
# #### Drop the five columns

# %%
df = df.drop('@documentId', axis=1)
df = df.drop('@documentName', axis=1)
df = df.drop('@softwareId', axis=1)
df = df.drop('@softwareVersion', axis=1)
df = df.drop('@softwareVersionNum', axis=1)
df[:1]
# Out:
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#   CompensationCommittee CompensationSurvey BoardOrCommitteeApproval  \
# 0                     X                  X                        X
#
#   SeverancePayment SupplementalNonqualRetirePlan EquityBasedCompArrangement  \
# 0            false                          true                      false
#
#   CompBasedOnRevenueOfFilingOrg CompBasedOnRevenueRelatedOrgs  \
# 0                         false                         false
#
#   CompBasedNetEarningsFilingOrg CompBasedNetEarningsRelateOrgs  \
# 0                         false                          false
#
#   AnyNonFixedPayments InitialContractException RebuttablePresumptionProcedure  \
# 0               false                    false                          false
#
#   IndependentConsultant WrittenEmploymentContract HousingAllowanceOrResidence  \
# 0                   NaN                       NaN                         NaN
#
#   WrittenPolicyReTAndEExpenses SubstantiationRequired  \
# 0                          NaN                    NaN
#
#   IdemnificationGrossUpPayments DiscretionarySpendingAccount ClubDuesOrFees  \
# 0                           NaN                          NaN            NaN
#
#   FirstClassOrCharterTravel TravelForCompanions Form990OfOtherOrganizations  \
# 0                       NaN                 NaN                         NaN
#
#   PaymentsForUseOfResidence PersonalServices SeverancePaymentInd  \
# 0                       NaN              NaN                 NaN
#
#   SupplementalNonqualRtrPlanInd EquityBasedCompArrngmInd  \
# 0                           NaN                      NaN
#
#   CompBasedOnRevenueOfFlngOrgInd CompBsdOnRevRelatedOrgsInd  \
# 0                            NaN                        NaN
#
#   CompBsdNetEarnsFlngOrgInd CompBsdNetEarnsRltdOrgsInd AnyNonFixedPaymentsInd  \
# 0                       NaN                        NaN                    NaN
#
#   InitialContractExceptionInd CompensationCommitteeInd  \
# 0                         NaN                      NaN
#
#   BoardOrCommitteeApprovalInd RebuttablePresumptionProcInd  \
# 0                         NaN                          NaN
#
#   IndependentConsultantInd WrittenEmploymentContractInd CompensationSurveyInd  \
# 0                      NaN                          NaN                   NaN
#
#   Form990OfOtherOrganizationsInd DiscretionarySpendingAcctInd  \
# 0                            NaN                          NaN
#
#   WrittenPolicyRefTAndEExpnssInd SubstantiationRequiredInd  \
# 0                            NaN                       NaN
#
#   TravelForCompanionsInd IdemnificationGrossUpPmtsInd ClubDuesOrFeesInd  \
# 0                    NaN                          NaN               NaN
#
#   HousingAllowanceOrResidenceInd FirstClassOrCharterTravelInd  \
# 0                            NaN                          NaN
#
#   PersonalServicesInd PaymentsForUseOfResidenceInd
# 0                 NaN                          NaN

# %%
set(df.columns.tolist()) - set(concordance['MongoDB_Name'].tolist())
# Out:
# {'URL'}

# %%
set(concordance['MongoDB_Name'].tolist()) - set(df.columns.tolist())
# Out:
# set()

# %% [markdown]
# ##### Check for whether 'Form990ScheduleJPartI' in in the DF
# In the initial concordance file, there were three *xpaths* for each variable, e.g., for *SJ_01_PC_SEVERANCE* there were these three:
#
# /Return/ReturnData/IRS990ScheduleJ/SeverancePayment
# /Return/ReturnData/IRS990ScheduleJ/SeverancePaymentInd
# /Return/ReturnData/IRS990ScheduleJ/Form990ScheduleJPartI/SeverancePayment
#
# None of the data is contained in a 'Form990ScheduleJPartI' heading so I will now delete those rows from the concordance file.

# %%
'Form990ScheduleJPartI' in df.columns.tolist()
# Out:
# False

# %% [markdown]
# #### Re-read in modified concordance file (after deleting unneeded rows) and then re-verify
# - This was done in the original notebook so I didn't need to do it again.

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
concordance = pd.read_excel('concordance - Schedule J (Part I).xlsx')
print('# of columns:', len(concordance.columns))
print('# of observations:', len(concordance))
concordance[:2]
# Out:
# Current date and time :  2025-06-20 22:30:04
#
# # of columns: 15
# # of observations: 52
# CPU times: total: 31.2 ms
# Wall time: 43.4 ms
#                                                   xpath   variable_name_new  \
# 0     /Return/ReturnData/IRS990ScheduleJ/ClubDuesOrFees  SJ_01_PC_CLUB_FEES
# 1  /Return/ReturnData/IRS990ScheduleJ/ClubDuesOrFeesInd  SJ_01_PC_CLUB_FEES
#
#    # of Characters (newly named)  variable name notes  PARSING NOTES  \
# 0                            NaN                  NaN            NaN
# 1                            NaN                  NaN            NaN
#
#    OTHER NOTES        description            location_code     part  \
# 0          NaN  Club dues or fees  SCHED-J-PART-01-LINE-1a  PART-01
# 1          NaN  Club dues or fees  SCHED-J-PART-01-LINE-1a  PART-01
#
#   data_type_xsd  fill_null  BINARIZE       MongoDB_Name  sub_key  sub_sub_key
# 0  CheckboxType        NaN  binarize     ClubDuesOrFees      NaN          NaN
# 1  CheckboxType        NaN  binarize  ClubDuesOrFeesInd      NaN          NaN

# %%
set(df.columns.tolist()) - set(concordance['MongoDB_Name'].tolist())
# Out:
# {'URL'}

# %%
set(concordance['MongoDB_Name'].tolist()) - set(df.columns.tolist())
# Out:
# set()

# %% [markdown]
# ### Collapse
# "Pandas is warning that, in future versions, the sub-dataframe x you get inside agg_funcs will not include the column(s) you grouped on (variable_name_new)."

# %%
def agg_funcs(x):
    names = {
        #'name': x['variable_name_new'].head(1).values[0],
        'original_names':  list(set(x['MongoDB_Name'].tolist())),
        'data_type_xsd': x['data_type_xsd'].head(1).values[0],
        'BINARIZE': x['BINARIZE'].head(1).values[0]
        }
    #THE FOLLOWING SHORTCUT WORKS BUT CHANGES THE ORDER OF THE COLUMNS
    #return pd.Series(names, index = list(names.keys()))
    return pd.Series(names, index=['original_names', 'data_type_xsd', 'BINARIZE'])
new_variables_df = concordance[:].groupby(['variable_name_new']).apply(agg_funcs)
new_variables_df = new_variables_df.reset_index()
print('# of variables:', len(new_variables_df))
new_variables_df[:5]
# Out:
# # of variables: 26
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_251400\4235985636.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   new_variables_df = concordance[:].groupby(['variable_name_new']).apply(agg_funcs)
#                  variable_name_new  \
# 0          SJ_01_PC_BOARD_APPROVAL
# 1               SJ_01_PC_CLUB_FEES
# 2        SJ_01_PC_COMPANION_TRAVEL
# 3  SJ_01_PC_COMPENSATION_COMMITTEE
# 4     SJ_01_PC_COMPENSATION_SURVEY
#
#                                             original_names data_type_xsd  \
# 0  [BoardOrCommitteeApproval, BoardOrCommitteeApprovalInd]  CheckboxType
# 1                      [ClubDuesOrFeesInd, ClubDuesOrFees]  CheckboxType
# 2            [TravelForCompanionsInd, TravelForCompanions]  CheckboxType
# 3        [CompensationCommittee, CompensationCommitteeInd]  CheckboxType
# 4              [CompensationSurvey, CompensationSurveyInd]  CheckboxType
#
#    BINARIZE
# 0  binarize
# 1  binarize
# 2  binarize
# 3  binarize
# 4  binarize

# %% [markdown]
# ##### Option 1

# %%
def agg_funcs(x):
    return pd.Series({
        'original_names': list(dict.fromkeys(x['MongoDB_Name'])),  # preserves first-seen order
        'data_type_xsd' : x['data_type_xsd'].iat[0],
        'BINARIZE'      : x['BINARIZE'].iat[0]
    })

new_variables_df = (
    concordance
      .groupby('variable_name_new')          # group on the new name
      .apply(agg_funcs, include_groups=False)  # <-- no warning
      .reset_index()
)

print('# of variables:', len(new_variables_df))
new_variables_df[:5]
# Out:
# # of variables: 26
#                  variable_name_new  \
# 0          SJ_01_PC_BOARD_APPROVAL
# 1               SJ_01_PC_CLUB_FEES
# 2        SJ_01_PC_COMPANION_TRAVEL
# 3  SJ_01_PC_COMPENSATION_COMMITTEE
# 4     SJ_01_PC_COMPENSATION_SURVEY
#
#                                             original_names data_type_xsd  \
# 0  [BoardOrCommitteeApproval, BoardOrCommitteeApprovalInd]  CheckboxType
# 1                      [ClubDuesOrFees, ClubDuesOrFeesInd]  CheckboxType
# 2            [TravelForCompanions, TravelForCompanionsInd]  CheckboxType
# 3        [CompensationCommittee, CompensationCommitteeInd]  CheckboxType
# 4              [CompensationSurvey, CompensationSurveyInd]  CheckboxType
#
#    BINARIZE
# 0  binarize
# 1  binarize
# 2  binarize
# 3  binarize
# 4  binarize

# %% [markdown]
# ##### Option 2

# %%
new_variables_df = (
    concordance
      .groupby('variable_name_new', as_index=False)
      .agg(
          original_names = ('MongoDB_Name', lambda s: list(dict.fromkeys(s))),
          data_type_xsd  = ('data_type_xsd', 'first'),
          BINARIZE       = ('BINARIZE', 'first')
      )
)

print('# of variables:', len(new_variables_df))
new_variables_df[:5]
# Out:
# # of variables: 26
#                  variable_name_new  \
# 0          SJ_01_PC_BOARD_APPROVAL
# 1               SJ_01_PC_CLUB_FEES
# 2        SJ_01_PC_COMPANION_TRAVEL
# 3  SJ_01_PC_COMPENSATION_COMMITTEE
# 4     SJ_01_PC_COMPENSATION_SURVEY
#
#                                             original_names data_type_xsd  \
# 0  [BoardOrCommitteeApproval, BoardOrCommitteeApprovalInd]  CheckboxType
# 1                      [ClubDuesOrFees, ClubDuesOrFeesInd]  CheckboxType
# 2            [TravelForCompanions, TravelForCompanionsInd]  CheckboxType
# 3        [CompensationCommittee, CompensationCommitteeInd]  CheckboxType
# 4              [CompensationSurvey, CompensationSurveyInd]  CheckboxType
#
#    BINARIZE
# 0  binarize
# 1  binarize
# 2  binarize
# 3  binarize
# 4  binarize

# %%
new_variables_df['len'] = new_variables_df['original_names'].apply(lambda x: len(x))
print(new_variables_df['len'].value_counts(), '\n')
new_variables_df[:4]
# Out:
# len
# 2    26
# Name: count, dtype: int64
#                  variable_name_new  \
# 0          SJ_01_PC_BOARD_APPROVAL
# 1               SJ_01_PC_CLUB_FEES
# 2        SJ_01_PC_COMPANION_TRAVEL
# 3  SJ_01_PC_COMPENSATION_COMMITTEE
#
#                                             original_names data_type_xsd  \
# 0  [BoardOrCommitteeApproval, BoardOrCommitteeApprovalInd]  CheckboxType
# 1                      [ClubDuesOrFees, ClubDuesOrFeesInd]  CheckboxType
# 2            [TravelForCompanions, TravelForCompanionsInd]  CheckboxType
# 3        [CompensationCommittee, CompensationCommitteeInd]  CheckboxType
#
#    BINARIZE  len
# 0  binarize    2
# 1  binarize    2
# 2  binarize    2
# 3  binarize    2

# %% [markdown]
# # Combine all columns where *len*==2

# %% [markdown]
# ### Define Function to combine columns
# In Python we can thus create a series of functions that can be used as shortcuts. First we'll create a function called 'combine' that will combine two variables. It takes as *inputs* four things: our dataset/dataframe (*df*), the name we'd like for our new variable (*newvar*), the name of the first variable to combine (*var1*), and the name of the second variable to combine (*var2*).

# %%
def combine(df, newvar, var1, var2):
    df[newvar] = np.where(df[var1].notnull(), df[var1], df[var2])
    #print(df[newvar].value_counts().head(), '\n')
    #print('# of missing observations:', len(df[df[newvar].isnull()]))
    #print('# of valid observations:', len(df[df[newvar].notnull()]), '\n')  
    #return df.sample(5)[[newvar, var1, var2, 'DLN']] 
    #print(df[[newvar, var1, var2, 'ObjectId']][:5], '\n\n\n')

# %% [markdown]
# #### Do initial check to ensure that no row has values in both columns

# %%
# %%time
for index, row in new_variables_df[new_variables_df['len']==2][:].iterrows():
    #print(row['variable_name_new'])
    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    print('\t\t', len(df[df[row['original_names'][0]].notnull()]))
    print('\t\t', len(df[df[row['original_names'][1]].notnull()]))
    #print(len(df[(df[row['original_names'][0]].isnull()) & (df[row['original_names'][1]].isnull())]), '\n\n')      
    print('OK IF ZERO:', len(df[(df[row['original_names'][0]].notnull()) & (df[row['original_names'][1]].notnull())]), '\n\n')
# Out:
# SJ_01_PC_BOARD_APPROVAL BoardOrCommitteeApproval BoardOrCommitteeApprovalInd
# 		 82699
# 		 315609
# OK IF ZERO: 0
#
#
# SJ_01_PC_CLUB_FEES ClubDuesOrFees ClubDuesOrFeesInd
# 		 10596
# 		 29276
# OK IF ZERO: 0
#
#
# SJ_01_PC_COMPANION_TRAVEL TravelForCompanions TravelForCompanionsInd
# 		 7291
# 		 21248
# OK IF ZERO: 0
#
#
# SJ_01_PC_COMPENSATION_COMMITTEE CompensationCommittee CompensationCommitteeInd
# 		 46589
# 		 151930
# OK IF ZERO: 0
#
#
# SJ_01_PC_COMPENSATION_SURVEY CompensationSurvey CompensationSurveyInd
# 		 58300
# 		 196366
# OK IF ZERO: 0
#
#
# SJ_01_PC_CONSULTANT IndependentConsultant IndependentConsultantInd
# 		 25949
# 		 72355
# OK IF ZERO: 0
#
#
# SJ_01_PC_CONTINGENT_NET_OWN CompBasedNetEarningsFilingOrg CompBsdNetEarnsFlngOrgInd
# 		 104079
# 		 445893
# OK IF ZERO: 0
#
#
# SJ_01_PC_CONTINGENT_NET_RELATED CompBasedNetEarningsRelateOrgs CompBsdNetEarnsRltdOrgsInd
# 		 104058
# 		 445845
# OK IF ZERO: 0
#
#
# SJ_01_PC_CONTINGENT_REV_OWN CompBasedOnRevenueOfFilingOrg CompBasedOnRevenueOfFlngOrgInd
# 		 104087
# 		 445923
# OK IF ZERO: 0
#
#
# SJ_01_PC_CONTINGENT_REV_RELATED CompBasedOnRevenueRelatedOrgs CompBsdOnRevRelatedOrgsInd
# 		 104053
# 		 445758
# OK IF ZERO: 0
#
#
# SJ_01_PC_CONTRACT WrittenEmploymentContract WrittenEmploymentContractInd
# 		 37565
# 		 116786
# OK IF ZERO: 0
#
#
# SJ_01_PC_CONTRACT_EXCEPTION InitialContractException InitialContractExceptionInd
# 		 103652
# 		 444735
# OK IF ZERO: 0
#
#
# SJ_01_PC_DISCRETIONARY_ACCOUNT DiscretionarySpendingAccount DiscretionarySpendingAcctInd
# 		 2829
# 		 8256
# OK IF ZERO: 0
#
#
# SJ_01_PC_EQUITY_BASED_COMP EquityBasedCompArrangement EquityBasedCompArrngmInd
# 		 125044
# 		 552070
# OK IF ZERO: 0
#
#
# SJ_01_PC_FIRST_CLASS_TRAVEL FirstClassOrCharterTravel FirstClassOrCharterTravelInd
# 		 3772
# 		 12721
# OK IF ZERO: 0
#
#
# SJ_01_PC_HOME_OFFICE_SUBSIDY PaymentsForUseOfResidence PaymentsForUseOfResidenceInd
# 		 487
# 		 1579
# OK IF ZERO: 0
#
#
# SJ_01_PC_HOUSING_ALLOWANCE HousingAllowanceOrResidence HousingAllowanceOrResidenceInd
# 		 9040
# 		 26368
# OK IF ZERO: 0
#
#
# SJ_01_PC_INDEMNIFICATION IdemnificationGrossUpPayments IdemnificationGrossUpPmtsInd
# 		 5123
# 		 13707
# OK IF ZERO: 0
#
#
# SJ_01_PC_NON_FIXED_PAYMENTS AnyNonFixedPayments AnyNonFixedPaymentsInd
# 		 103706
# 		 444672
# OK IF ZERO: 0
#
#
# SJ_01_PC_OTHER_ORGS_990 Form990OfOtherOrganizations Form990OfOtherOrganizationsInd
# 		 23268
# 		 93041
# OK IF ZERO: 0
#
#
# SJ_01_PC_PERSONAL_SERVICES PersonalServices PersonalServicesInd
# 		 2070
# 		 5157
# OK IF ZERO: 0
#
#
# SJ_01_PC_REBUTTABLE_PRESUMPTION RebuttablePresumptionProcedure RebuttablePresumptionProcInd
# 		 9364
# 		 23752
# OK IF ZERO: 0
#
#
# SJ_01_PC_SEVERANCE SeverancePayment SeverancePaymentInd
# 		 125094
# 		 552228
# OK IF ZERO: 0
#
#
# SJ_01_PC_SUBSTANTIATION_REQUIRED SubstantiationRequired SubstantiationRequiredInd
# 		 29229
# 		 95080
# OK IF ZERO: 0
#
#
# SJ_01_PC_SUPPLEMENTAL_RETIREMENT SupplementalNonqualRetirePlan SupplementalNonqualRtrPlanInd
# 		 125120
# 		 552221
# OK IF ZERO: 0
#
#
# SJ_01_PC_WRITTEN_POLICY WrittenPolicyRefTAndEExpnssInd WrittenPolicyReTAndEExpenses
# 		 78350
# 		 25136
# OK IF ZERO: 0
#
#
# CPU times: total: 9.03 s
# Wall time: 10 s

# %% [markdown]
# ### Combine

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
combo_fails = []
for index, row in new_variables_df[new_variables_df['len']==2][:].iterrows():
    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    try:
        combine(df, row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    except:
        print('\n\n\n\n\n***********issue with variable: ', row['variable_name_new'])
        combo_fails.append(row['variable_name_new'])

print(combo_fails)
# Out:
# Current date and time :  2025-06-20 22:34:23
#
# SJ_01_PC_BOARD_APPROVAL BoardOrCommitteeApproval BoardOrCommitteeApprovalInd
# SJ_01_PC_CLUB_FEES ClubDuesOrFees ClubDuesOrFeesInd
# SJ_01_PC_COMPANION_TRAVEL TravelForCompanions TravelForCompanionsInd
# SJ_01_PC_COMPENSATION_COMMITTEE CompensationCommittee CompensationCommitteeInd
# SJ_01_PC_COMPENSATION_SURVEY CompensationSurvey CompensationSurveyInd
# SJ_01_PC_CONSULTANT IndependentConsultant IndependentConsultantInd
# SJ_01_PC_CONTINGENT_NET_OWN CompBasedNetEarningsFilingOrg CompBsdNetEarnsFlngOrgInd
# SJ_01_PC_CONTINGENT_NET_RELATED CompBasedNetEarningsRelateOrgs CompBsdNetEarnsRltdOrgsInd
# SJ_01_PC_CONTINGENT_REV_OWN CompBasedOnRevenueOfFilingOrg CompBasedOnRevenueOfFlngOrgInd
# SJ_01_PC_CONTINGENT_REV_RELATED CompBasedOnRevenueRelatedOrgs CompBsdOnRevRelatedOrgsInd
# SJ_01_PC_CONTRACT WrittenEmploymentContract WrittenEmploymentContractInd
# SJ_01_PC_CONTRACT_EXCEPTION InitialContractException InitialContractExceptionInd
# SJ_01_PC_DISCRETIONARY_ACCOUNT DiscretionarySpendingAccount DiscretionarySpendingAcctInd
# SJ_01_PC_EQUITY_BASED_COMP EquityBasedCompArrangement EquityBasedCompArrngmInd
# SJ_01_PC_FIRST_CLASS_TRAVEL FirstClassOrCharterTravel FirstClassOrCharterTravelInd
# SJ_01_PC_HOME_OFFICE_SUBSIDY PaymentsForUseOfResidence PaymentsForUseOfResidenceInd
# SJ_01_PC_HOUSING_ALLOWANCE HousingAllowanceOrResidence HousingAllowanceOrResidenceInd
# SJ_01_PC_INDEMNIFICATION IdemnificationGrossUpPayments IdemnificationGrossUpPmtsInd
# SJ_01_PC_NON_FIXED_PAYMENTS AnyNonFixedPayments AnyNonFixedPaymentsInd
# SJ_01_PC_OTHER_ORGS_990 Form990OfOtherOrganizations Form990OfOtherOrganizationsInd
# SJ_01_PC_PERSONAL_SERVICES PersonalServices PersonalServicesInd
# SJ_01_PC_REBUTTABLE_PRESUMPTION RebuttablePresumptionProcedure RebuttablePresumptionProcInd
# SJ_01_PC_SEVERANCE SeverancePayment SeverancePaymentInd
# SJ_01_PC_SUBSTANTIATION_REQUIRED SubstantiationRequired SubstantiationRequiredInd
# SJ_01_PC_SUPPLEMENTAL_RETIREMENT SupplementalNonqualRetirePlan SupplementalNonqualRtrPlanInd
# SJ_01_PC_WRITTEN_POLICY WrittenPolicyRefTAndEExpnssInd WrittenPolicyReTAndEExpenses
# []
# CPU times: total: 891 ms
# Wall time: 948 ms

# %% [markdown]
# ### Binarize

# %%
#binarize_cols = [c for c in new_variables_df[new_variables_df['data_type_xsd'].isin(['BooleanType', 'CheckboxType'])]['variable_name_new'].tolist()] 
#print(len(binarize_cols))
#print(binarize_cols)

# %%
binarize_cols = [c for c in new_variables_df[new_variables_df['BINARIZE']=='binarize']['variable_name_new'].tolist()] 
print(len(binarize_cols))
print(binarize_cols)
# Out:
# 26
# ['SJ_01_PC_BOARD_APPROVAL', 'SJ_01_PC_CLUB_FEES', 'SJ_01_PC_COMPANION_TRAVEL', 'SJ_01_PC_COMPENSATION_COMMITTEE', 'SJ_01_PC_COMPENSATION_SURVEY', 'SJ_01_PC_CONSULTANT', 'SJ_01_PC_CONTINGENT_NET_OWN', 'SJ_01_PC_CONTINGENT_NET_RELATED', 'SJ_01_PC_CONTINGENT_REV_OWN', 'SJ_01_PC_CONTINGENT_REV_RELATED', 'SJ_01_PC_CONTRACT', 'SJ_01_PC_CONTRACT_EXCEPTION', 'SJ_01_PC_DISCRETIONARY_ACCOUNT', 'SJ_01_PC_EQUITY_BASED_COMP', 'SJ_01_PC_FIRST_CLASS_TRAVEL', 'SJ_01_PC_HOME_OFFICE_SUBSIDY', 'SJ_01_PC_HOUSING_ALLOWANCE', 'SJ_01_PC_INDEMNIFICATION', 'SJ_01_PC_NON_FIXED_PAYMENTS', 'SJ_01_PC_OTHER_ORGS_990', 'SJ_01_PC_PERSONAL_SERVICES', 'SJ_01_PC_REBUTTABLE_PRESUMPTION', 'SJ_01_PC_SEVERANCE', 'SJ_01_PC_SUBSTANTIATION_REQUIRED', 'SJ_01_PC_SUPPLEMENTAL_RETIREMENT', 'SJ_01_PC_WRITTEN_POLICY']

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
for c in binarize_cols[:]:
    print(df[df[c].notnull()][c].value_counts().head(), '\n')
# Out:
# Current date and time :  2025-06-20 22:34:31
#
# SJ_01_PC_BOARD_APPROVAL
# X    398308
# Name: count, dtype: int64
#
# SJ_01_PC_CLUB_FEES
# X    39872
# Name: count, dtype: int64
#
# SJ_01_PC_COMPANION_TRAVEL
# X    28539
# Name: count, dtype: int64
#
# SJ_01_PC_COMPENSATION_COMMITTEE
# X    198519
# Name: count, dtype: int64
#
# SJ_01_PC_COMPENSATION_SURVEY
# X    254666
# Name: count, dtype: int64
#
# SJ_01_PC_CONSULTANT
# X    98304
# Name: count, dtype: int64
#
# SJ_01_PC_CONTINGENT_NET_OWN
# 0        344654
# false    194652
# 1          7013
# true       3653
# Name: count, dtype: int64
#
# SJ_01_PC_CONTINGENT_NET_RELATED
# 0        347092
# false    195598
# 1          4571
# true       2642
# Name: count, dtype: int64
#
# SJ_01_PC_CONTINGENT_REV_OWN
# 0        345772
# false    195334
# 1          5892
# true       3012
# Name: count, dtype: int64
#
# SJ_01_PC_CONTINGENT_REV_RELATED
# 0        349646
# false    197199
# 1          2018
# true        948
# Name: count, dtype: int64
#
# SJ_01_PC_CONTRACT
# X    154351
# Name: count, dtype: int64
#
# SJ_01_PC_CONTRACT_EXCEPTION
# 0        350393
# false    195896
# 1          1212
# true        886
# Name: count, dtype: int64
#
# SJ_01_PC_DISCRETIONARY_ACCOUNT
# X    11085
# Name: count, dtype: int64
#
# SJ_01_PC_EQUITY_BASED_COMP
# 0        435537
# false    240452
# 1           732
# true        393
# Name: count, dtype: int64
#
# SJ_01_PC_FIRST_CLASS_TRAVEL
# X    16493
# Name: count, dtype: int64
#
# SJ_01_PC_HOME_OFFICE_SUBSIDY
# X    2066
# Name: count, dtype: int64
#
# SJ_01_PC_HOUSING_ALLOWANCE
# X    35408
# Name: count, dtype: int64
#
# SJ_01_PC_INDEMNIFICATION
# X    18830
# Name: count, dtype: int64
#
# SJ_01_PC_NON_FIXED_PAYMENTS
# 0        318116
# false    178401
# 1         33513
# true      18348
# Name: count, dtype: int64
#
# SJ_01_PC_OTHER_ORGS_990
# X    116309
# Name: count, dtype: int64
#
# SJ_01_PC_PERSONAL_SERVICES
# X    7227
# Name: count, dtype: int64
#
# SJ_01_PC_REBUTTABLE_PRESUMPTION
# false    31042
# 1          916
# true       790
# 0          368
# Name: count, dtype: int64
#
# SJ_01_PC_SEVERANCE
# 0        409519
# false    223977
# 1         26754
# true      17072
# Name: count, dtype: int64
#
# SJ_01_PC_SUBSTANTIATION_REQUIRED
# 1        74807
# true     35736
# 0         8972
# false     4794
# Name: count, dtype: int64
#
# SJ_01_PC_SUPPLEMENTAL_RETIREMENT
# 0        368004
# false    198936
# 1         68267
# true      42134
# Name: count, dtype: int64
#
# SJ_01_PC_WRITTEN_POLICY
# 1        57772
# true     31173
# 0         9196
# false     5345
# Name: count, dtype: int64
#
# CPU times: total: 11.9 s
# Wall time: 13.2 s

# %% [markdown]
# ##### BASED ON THE PRECEDING CODE BLOCK, NONE OF THE ABOVE VARIABLES ARE LIKELY TO FAIL THE BINARIZATION PROCESS

# %%
#binarize_with_dict_cols = ['F9_00_HD_EXEMPT_STATUS_501C', 'F9_00_HD_INCLUDES_SUBORD_ORGS', 
#                           'F9_04_PC_FR_EVENT_INC_GT_15K', 'F9_04_PC_GAMING_INC_GT_15K',
#                           'F9_04_PC_PROF_FR_EXP_GT_15K', 'F9_12_PC_ACCTG_METHOD_OTHER']

# %%
#for c in binarize_with_dict_cols[:]:
#    print(df[df[c].notnull()][c].value_counts()[:10], '\n')

# %%
#print(len(binarize_cols))
#binarize_cols = list(set(binarize_cols) - set(binarize_with_dict_cols))
#print(len(binarize_cols))

# %% [markdown]
# ##### Check *F9_12_PC_ACCTG_METHOD_OTHER*, *F9_00_HD_EXEMPT_STATUS_501C*, and *F9_00_HD_INCLUDES_SUBORD_ORGS*
# Based on the following frequencies,for *F9_12_PC_ACCTG_METHOD_OTHER* do an *np.where* and make it 'other'. Leave *F9_00_HD_EXEMPT_STATUS_501C* and *F9_00_HD_INCLUDES_SUBORD_ORGS* alone.

# %%
#print(df[df['F9_00_HD_EXEMPT_STATUS_501C'].notnull()]['F9_00_HD_EXEMPT_STATUS_501C'].value_counts().head())

# %% [markdown]
# #### Fix *F9_00_HD_EXEMPT_STATUS_501C*

# %%
"""
def func(x, key1, key2):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    elif key1 in x.keys():
        return x[key1]
    elif key2 in x.keys():
        return x[key2]
    else:
        return np.nan
"""

# %%
#df['F9_00_HD_EXEMPT_STATUS_501C'] = df['F9_00_HD_EXEMPT_STATUS_501C'][:].apply(func, 
#                            key1='@organization501cTypeTxt', key2 ='@typeOf501cOrganization')

# %%
#df = df.drop('Organization501c_type', 1)

# %%
#df['F9_00_HD_EXEMPT_STATUS_501C'].value_counts()[:10]

# %% [markdown]
# #### Fix other five variables

# %%
#binarize_with_dict_cols

# %%
""" 
def func_text(x, key1):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    
    elif type(x)==dict: 
        if key1 in x.keys():
            return x[key1]
    else:
        return x
"""

# %%
#df['F9_00_HD_INCLUDES_SUBORD_ORGS'] = df['F9_00_HD_INCLUDES_SUBORD_ORGS'][:].apply(func_text, 
#                            key1='#text')

# %%
##df = df.drop('test', 1)

# %%
#df['F9_00_HD_INCLUDES_SUBORD_ORGS'].value_counts()

# %%
##binarize_with_dict_cols

# %%
#df['F9_04_PC_FR_EVENT_INC_GT_15K'] = df['F9_04_PC_FR_EVENT_INC_GT_15K'][:].apply(func_text, 
#                            key1='#text')

# %%
#df['F9_04_PC_FR_EVENT_INC_GT_15K'].value_counts()

# %%
#for c in binarize_with_dict_cols[:]:
#    print(df[df[c].notnull()][c].value_counts()[:10], '\n')

# %%
#df['F9_04_PC_GAMING_INC_GT_15K'] = df['F9_04_PC_GAMING_INC_GT_15K'][:].apply(func_text, 
#                            key1='#text')

# %%
#df['F9_04_PC_GAMING_INC_GT_15K'].value_counts()

# %%
#df['F9_04_PC_PROF_FR_EXP_GT_15K'] = df['F9_04_PC_PROF_FR_EXP_GT_15K'][:].apply(func_text, 
#                            key1='#text')

# %%
#df['F9_04_PC_FR_EVENT_INC_GT_15K'].value_counts()

# %% [markdown]
# #### Fix *F9_12_PC_ACCTG_METHOD_OTHER*

# %%
"""
def func_text2(x, key1, key2):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    
    elif type(x)==dict: 
        if key1 in x.keys():
            return x[key1]
        elif key2 in x.keys():
            return x[key2]
    else:
        return x
"""

# %%
#df['F9_12_PC_ACCTG_METHOD_OTHER'] = df['F9_12_PC_ACCTG_METHOD_OTHER'][:].apply(func_text2, 
##                            key1='@note', key2='@methodOfAccountingOtherDesc')

# %%
#df=df.drop('test', 1)

# %%
#df['F9_12_PC_ACCTG_METHOD_OTHER'].value_counts()[:10]

# %% [markdown]
# ##### Remove two variables from *binarize_cols*

# %%
#print(len(binarize_cols))
#binarize_cols.remove('F9_12_PC_ACCTG_METHOD_OTHER') 
#binarize_cols.remove('F9_00_HD_EXEMPT_STATUS_501C')
#print(len(binarize_cols))

# %% [markdown]
# # Binarize Columns

# %%
#for col in binarize_cols:
#    print(df[col].value_counts(), '\n\n')

# %%
print(len(binarize_cols))
# Out:
# 26

# %%
def binarize(df, variable):
    print(df[variable].value_counts(), '\n')
    df[variable] = np.where(df[variable]=='true', 1, df[variable])
    df[variable] = np.where(df[variable]=='false', 0, df[variable])
    df[variable] = np.where(df[variable]=='1', 1, df[variable])
    df[variable] = np.where(df[variable]=='0', 0, df[variable])
    df[variable] = np.where(df[variable]=='X', 1, df[variable])
    print(df[variable].value_counts(), '\n\n')
    return df.sample(10)[['URL', variable]]

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
for col in binarize_cols:
    binarize(df, col)
# Out:
# Current date and time :  2025-06-20 22:35:02
#
# SJ_01_PC_BOARD_APPROVAL
# X    398308
# Name: count, dtype: int64
#
# SJ_01_PC_BOARD_APPROVAL
# 1    398308
# Name: count, dtype: int64
#
#
# SJ_01_PC_CLUB_FEES
# X    39872
# Name: count, dtype: int64
#
# SJ_01_PC_CLUB_FEES
# 1    39872
# Name: count, dtype: int64
#
#
# SJ_01_PC_COMPANION_TRAVEL
# X    28539
# Name: count, dtype: int64
#
# SJ_01_PC_COMPANION_TRAVEL
# 1    28539
# Name: count, dtype: int64
#
#
# SJ_01_PC_COMPENSATION_COMMITTEE
# X    198519
# Name: count, dtype: int64
#
# SJ_01_PC_COMPENSATION_COMMITTEE
# 1    198519
# Name: count, dtype: int64
#
#
# SJ_01_PC_COMPENSATION_SURVEY
# X    254666
# Name: count, dtype: int64
#
# SJ_01_PC_COMPENSATION_SURVEY
# 1    254666
# Name: count, dtype: int64
#
#
# SJ_01_PC_CONSULTANT
# X    98304
# Name: count, dtype: int64
#
# SJ_01_PC_CONSULTANT
# 1    98304
# Name: count, dtype: int64
#
#
# SJ_01_PC_CONTINGENT_NET_OWN
# 0        344654
# false    194652
# 1          7013
# true       3653
# Name: count, dtype: int64
#
# SJ_01_PC_CONTINGENT_NET_OWN
# 0    539306
# 1     10666
# Name: count, dtype: int64
#
#
# SJ_01_PC_CONTINGENT_NET_RELATED
# 0        347092
# false    195598
# 1          4571
# true       2642
# Name: count, dtype: int64
#
# SJ_01_PC_CONTINGENT_NET_RELATED
# 0    542690
# 1      7213
# Name: count, dtype: int64
#
#
# SJ_01_PC_CONTINGENT_REV_OWN
# 0        345772
# false    195334
# 1          5892
# true       3012
# Name: count, dtype: int64
#
# SJ_01_PC_CONTINGENT_REV_OWN
# 0    541106
# 1      8904
# Name: count, dtype: int64
#
#
# SJ_01_PC_CONTINGENT_REV_RELATED
# 0        349646
# false    197199
# 1          2018
# true        948
# Name: count, dtype: int64
#
# SJ_01_PC_CONTINGENT_REV_RELATED
# 0    546845
# 1      2966
# Name: count, dtype: int64
#
#
# SJ_01_PC_CONTRACT
# X    154351
# Name: count, dtype: int64
#
# SJ_01_PC_CONTRACT
# 1    154351
# Name: count, dtype: int64
#
#
# SJ_01_PC_CONTRACT_EXCEPTION
# 0        350393
# false    195896
# 1          1212
# true        886
# Name: count, dtype: int64
#
# SJ_01_PC_CONTRACT_EXCEPTION
# 0    546289
# 1      2098
# Name: count, dtype: int64
#
#
# SJ_01_PC_DISCRETIONARY_ACCOUNT
# X    11085
# Name: count, dtype: int64
#
# SJ_01_PC_DISCRETIONARY_ACCOUNT
# 1    11085
# Name: count, dtype: int64
#
#
# SJ_01_PC_EQUITY_BASED_COMP
# 0        435537
# false    240452
# 1           732
# true        393
# Name: count, dtype: int64
#
# SJ_01_PC_EQUITY_BASED_COMP
# 0    675989
# 1      1125
# Name: count, dtype: int64
#
#
# SJ_01_PC_FIRST_CLASS_TRAVEL
# X    16493
# Name: count, dtype: int64
#
# SJ_01_PC_FIRST_CLASS_TRAVEL
# 1    16493
# Name: count, dtype: int64
#
#
# SJ_01_PC_HOME_OFFICE_SUBSIDY
# X    2066
# Name: count, dtype: int64
#
# SJ_01_PC_HOME_OFFICE_SUBSIDY
# 1    2066
# Name: count, dtype: int64
#
#
# SJ_01_PC_HOUSING_ALLOWANCE
# X    35408
# Name: count, dtype: int64
#
# SJ_01_PC_HOUSING_ALLOWANCE
# 1    35408
# Name: count, dtype: int64
#
#
# SJ_01_PC_INDEMNIFICATION
# X    18830
# Name: count, dtype: int64
#
# SJ_01_PC_INDEMNIFICATION
# 1    18830
# Name: count, dtype: int64
#
#
# SJ_01_PC_NON_FIXED_PAYMENTS
# 0        318116
# false    178401
# 1         33513
# true      18348
# Name: count, dtype: int64
#
# SJ_01_PC_NON_FIXED_PAYMENTS
# 0    496517
# 1     51861
# Name: count, dtype: int64
#
#
# SJ_01_PC_OTHER_ORGS_990
# X    116309
# Name: count, dtype: int64
#
# SJ_01_PC_OTHER_ORGS_990
# 1    116309
# Name: count, dtype: int64
#
#
# SJ_01_PC_PERSONAL_SERVICES
# X    7227
# Name: count, dtype: int64
#
# SJ_01_PC_PERSONAL_SERVICES
# 1    7227
# Name: count, dtype: int64
#
#
# SJ_01_PC_REBUTTABLE_PRESUMPTION
# false    31042
# 1          916
# true       790
# 0          368
# Name: count, dtype: int64
#
# SJ_01_PC_REBUTTABLE_PRESUMPTION
# 0    31410
# 1     1706
# Name: count, dtype: int64
#
#
# SJ_01_PC_SEVERANCE
# 0        409519
# false    223977
# 1         26754
# true      17072
# Name: count, dtype: int64
#
# SJ_01_PC_SEVERANCE
# 0    633496
# 1     43826
# Name: count, dtype: int64
#
#
# SJ_01_PC_SUBSTANTIATION_REQUIRED
# 1        74807
# true     35736
# 0         8972
# false     4794
# Name: count, dtype: int64
#
# SJ_01_PC_SUBSTANTIATION_REQUIRED
# 1    110543
# 0     13766
# Name: count, dtype: int64
#
#
# SJ_01_PC_SUPPLEMENTAL_RETIREMENT
# 0        368004
# false    198936
# 1         68267
# true      42134
# Name: count, dtype: int64
#
# SJ_01_PC_SUPPLEMENTAL_RETIREMENT
# 0    566940
# 1    110401
# Name: count, dtype: int64
#
#
# SJ_01_PC_WRITTEN_POLICY
# 1        57772
# true     31173
# 0         9196
# false     5345
# Name: count, dtype: int64
#
# SJ_01_PC_WRITTEN_POLICY
# 1    88945
# 0    14541
# Name: count, dtype: int64
#
#
# CPU times: total: 7.48 s
# Wall time: 8.53 s

# %%
df[binarize_cols].sample(10)
# Out:
#        SJ_01_PC_BOARD_APPROVAL SJ_01_PC_CLUB_FEES SJ_01_PC_COMPANION_TRAVEL  \
# 680774                     NaN                NaN                       NaN
# 585880                       1                NaN                       NaN
# 581376                     NaN                NaN                       NaN
# 266390                     NaN                NaN                       NaN
# 215627                     NaN                NaN                       NaN
# 480301                       1                NaN                       NaN
# 441084                       1                NaN                       NaN
# 409942                     NaN                NaN                       NaN
# 648154                       1                  1                       NaN
# 641008                       1                NaN                       NaN
#
#        SJ_01_PC_COMPENSATION_COMMITTEE SJ_01_PC_COMPENSATION_SURVEY  \
# 680774                             NaN                          NaN
# 585880                             NaN                          NaN
# 581376                             NaN                          NaN
# 266390                             NaN                          NaN
# 215627                             NaN                          NaN
# 480301                               1                          NaN
# 441084                               1                            1
# 409942                             NaN                          NaN
# 648154                               1                          NaN
# 641008                             NaN                            1
#
#        SJ_01_PC_CONSULTANT SJ_01_PC_CONTINGENT_NET_OWN  \
# 680774                 NaN                           0
# 585880                 NaN                         NaN
# 581376                 NaN                           0
# 266390                 NaN                         NaN
# 215627                 NaN                         NaN
# 480301                 NaN                           0
# 441084                   1                           0
# 409942                 NaN                           0
# 648154                 NaN                         NaN
# 641008                 NaN                           0
#
#        SJ_01_PC_CONTINGENT_NET_RELATED SJ_01_PC_CONTINGENT_REV_OWN  \
# 680774                               0                           0
# 585880                             NaN                         NaN
# 581376                               0                           0
# 266390                             NaN                         NaN
# 215627                             NaN                         NaN
# 480301                               0                           0
# 441084                               0                           0
# 409942                               0                           0
# 648154                             NaN                         NaN
# 641008                               0                           0
#
#        SJ_01_PC_CONTINGENT_REV_RELATED SJ_01_PC_CONTRACT  \
# 680774                               0               NaN
# 585880                             NaN                 1
# 581376                               0               NaN
# 266390                             NaN               NaN
# 215627                             NaN               NaN
# 480301                               0                 1
# 441084                               0               NaN
# 409942                               0               NaN
# 648154                             NaN               NaN
# 641008                               0               NaN
#
#        SJ_01_PC_CONTRACT_EXCEPTION SJ_01_PC_DISCRETIONARY_ACCOUNT  \
# 680774                           0                            NaN
# 585880                         NaN                            NaN
# 581376                           0                            NaN
# 266390                         NaN                            NaN
# 215627                         NaN                            NaN
# 480301                           0                            NaN
# 441084                           0                            NaN
# 409942                           0                            NaN
# 648154                         NaN                            NaN
# 641008                           0                            NaN
#
#        SJ_01_PC_EQUITY_BASED_COMP SJ_01_PC_FIRST_CLASS_TRAVEL  \
# 680774                          0                         NaN
# 585880                          0                         NaN
# 581376                          0                         NaN
# 266390                          0                         NaN
# 215627                          0                         NaN
# 480301                          0                         NaN
# 441084                          0                         NaN
# 409942                          0                         NaN
# 648154                          0                         NaN
# 641008                          0                         NaN
#
#        SJ_01_PC_HOME_OFFICE_SUBSIDY SJ_01_PC_HOUSING_ALLOWANCE  \
# 680774                          NaN                        NaN
# 585880                          NaN                        NaN
# 581376                          NaN                        NaN
# 266390                          NaN                        NaN
# 215627                          NaN                        NaN
# 480301                          NaN                        NaN
# 441084                          NaN                        NaN
# 409942                          NaN                        NaN
# 648154                          NaN                        NaN
# 641008                          NaN                        NaN
#
#        SJ_01_PC_INDEMNIFICATION SJ_01_PC_NON_FIXED_PAYMENTS  \
# 680774                      NaN                           0
# 585880                      NaN                         NaN
# 581376                      NaN                           1
# 266390                      NaN                         NaN
# 215627                      NaN                         NaN
# 480301                      NaN                           0
# 441084                      NaN                           1
# 409942                      NaN                           0
# 648154                      NaN                         NaN
# 641008                      NaN                           0
#
#        SJ_01_PC_OTHER_ORGS_990 SJ_01_PC_PERSONAL_SERVICES  \
# 680774                     NaN                        NaN
# 585880                     NaN                        NaN
# 581376                     NaN                        NaN
# 266390                     NaN                        NaN
# 215627                     NaN                        NaN
# 480301                       1                        NaN
# 441084                     NaN                        NaN
# 409942                     NaN                        NaN
# 648154                     NaN                        NaN
# 641008                     NaN                        NaN
#
#        SJ_01_PC_REBUTTABLE_PRESUMPTION SJ_01_PC_SEVERANCE  \
# 680774                             NaN                  0
# 585880                             NaN                  0
# 581376                             NaN                  1
# 266390                             NaN                  0
# 215627                             NaN                  0
# 480301                             NaN                  0
# 441084                             NaN                  0
# 409942                             NaN                  1
# 648154                             NaN                  0
# 641008                             NaN                  0
#
#        SJ_01_PC_SUBSTANTIATION_REQUIRED SJ_01_PC_SUPPLEMENTAL_RETIREMENT  \
# 680774                              NaN                                0
# 585880                              NaN                                0
# 581376                              NaN                                1
# 266390                              NaN                                0
# 215627                              NaN                                0
# 480301                                1                                0
# 441084                              NaN                                0
# 409942                              NaN                                0
# 648154                                1                                0
# 641008                              NaN                                0
#
#        SJ_01_PC_WRITTEN_POLICY
# 680774                     NaN
# 585880                     NaN
# 581376                     NaN
# 266390                     NaN
# 215627                     NaN
# 480301                     NaN
# 441084                     NaN
# 409942                     NaN
# 648154                       1
# 641008                     NaN

# %% [markdown]
# ### Check that total number of values in new variable equal sum of prior 2 variables

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
for index, row in new_variables_df[new_variables_df['len']==2][:].iterrows():
    #print(row['variable_name_new'])
    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    print(len(df[df[row['original_names'][0]].notnull()]) + len(df[df[row['original_names'][1]].notnull()]))    
    print(len(df[df[row['variable_name_new']].notnull()]), '\n')
    #print(len(df[(df[row['original_names'][0]].notnull()) & (df[row['original_names'][1]].notnull())]), '\n')
# Out:
# Current date and time :  2025-06-20 22:35:38
#
# SJ_01_PC_BOARD_APPROVAL BoardOrCommitteeApproval BoardOrCommitteeApprovalInd
# 398308
# 398308
#
# SJ_01_PC_CLUB_FEES ClubDuesOrFees ClubDuesOrFeesInd
# 39872
# 39872
#
# SJ_01_PC_COMPANION_TRAVEL TravelForCompanions TravelForCompanionsInd
# 28539
# 28539
#
# SJ_01_PC_COMPENSATION_COMMITTEE CompensationCommittee CompensationCommitteeInd
# 198519
# 198519
#
# SJ_01_PC_COMPENSATION_SURVEY CompensationSurvey CompensationSurveyInd
# 254666
# 254666
#
# SJ_01_PC_CONSULTANT IndependentConsultant IndependentConsultantInd
# 98304
# 98304
#
# SJ_01_PC_CONTINGENT_NET_OWN CompBasedNetEarningsFilingOrg CompBsdNetEarnsFlngOrgInd
# 549972
# 549972
#
# SJ_01_PC_CONTINGENT_NET_RELATED CompBasedNetEarningsRelateOrgs CompBsdNetEarnsRltdOrgsInd
# 549903
# 549903
#
# SJ_01_PC_CONTINGENT_REV_OWN CompBasedOnRevenueOfFilingOrg CompBasedOnRevenueOfFlngOrgInd
# 550010
# 550010
#
# SJ_01_PC_CONTINGENT_REV_RELATED CompBasedOnRevenueRelatedOrgs CompBsdOnRevRelatedOrgsInd
# 549811
# 549811
#
# SJ_01_PC_CONTRACT WrittenEmploymentContract WrittenEmploymentContractInd
# 154351
# 154351
#
# SJ_01_PC_CONTRACT_EXCEPTION InitialContractException InitialContractExceptionInd
# 548387
# 548387
#
# SJ_01_PC_DISCRETIONARY_ACCOUNT DiscretionarySpendingAccount DiscretionarySpendingAcctInd
# 11085
# 11085
#
# SJ_01_PC_EQUITY_BASED_COMP EquityBasedCompArrangement EquityBasedCompArrngmInd
# 677114
# 677114
#
# SJ_01_PC_FIRST_CLASS_TRAVEL FirstClassOrCharterTravel FirstClassOrCharterTravelInd
# 16493
# 16493
#
# SJ_01_PC_HOME_OFFICE_SUBSIDY PaymentsForUseOfResidence PaymentsForUseOfResidenceInd
# 2066
# 2066
#
# SJ_01_PC_HOUSING_ALLOWANCE HousingAllowanceOrResidence HousingAllowanceOrResidenceInd
# 35408
# 35408
#
# SJ_01_PC_INDEMNIFICATION IdemnificationGrossUpPayments IdemnificationGrossUpPmtsInd
# 18830
# 18830
#
# SJ_01_PC_NON_FIXED_PAYMENTS AnyNonFixedPayments AnyNonFixedPaymentsInd
# 548378
# 548378
#
# SJ_01_PC_OTHER_ORGS_990 Form990OfOtherOrganizations Form990OfOtherOrganizationsInd
# 116309
# 116309
#
# SJ_01_PC_PERSONAL_SERVICES PersonalServices PersonalServicesInd
# 7227
# 7227
#
# SJ_01_PC_REBUTTABLE_PRESUMPTION RebuttablePresumptionProcedure RebuttablePresumptionProcInd
# 33116
# 33116
#
# SJ_01_PC_SEVERANCE SeverancePayment SeverancePaymentInd
# 677322
# 677322
#
# SJ_01_PC_SUBSTANTIATION_REQUIRED SubstantiationRequired SubstantiationRequiredInd
# 124309
# 124309
#
# SJ_01_PC_SUPPLEMENTAL_RETIREMENT SupplementalNonqualRetirePlan SupplementalNonqualRtrPlanInd
# 677341
# 677341
#
# SJ_01_PC_WRITTEN_POLICY WrittenPolicyRefTAndEExpnssInd WrittenPolicyReTAndEExpenses
# 103486
# 103486
#
# CPU times: total: 22.8 s
# Wall time: 24.9 s

# %% [markdown]
# <br><br>
# From the above we are fine with deleting the 138 variables related to the 69 above variables in *variable_name_new* (numbers from earlier version of notebook).

# %% [markdown]
# ### Inspect the Combined and Original Variables
# Here I'm showing one variable

# %%
df[df['SJ_01_PC_SEVERANCE'].notnull()].sample(5)[['SJ_01_PC_SEVERANCE', 'SeverancePaymentInd', 'SeverancePayment']]
# Out:
#        SJ_01_PC_SEVERANCE SeverancePaymentInd SeverancePayment
# 647862                  0                   0              NaN
# 499612                  0                   0              NaN
# 447863                  0                   0              NaN
# 553675                  0                   0              NaN
# 677132                  0               false              NaN

# %% [markdown]
# ### Drop variables

# %%
new_variables_df[new_variables_df['len']!=2]['original_names'].tolist()
# Out:
# []

# %%
new_variables_df[new_variables_df['len']==2]['original_names'].tolist()
# Out:
# [['BoardOrCommitteeApproval', 'BoardOrCommitteeApprovalInd'],
#  ['ClubDuesOrFees', 'ClubDuesOrFeesInd'],
#  ['TravelForCompanions', 'TravelForCompanionsInd'],
#  ['CompensationCommittee', 'CompensationCommitteeInd'],
#  ['CompensationSurvey', 'CompensationSurveyInd'],
#  ['IndependentConsultant', 'IndependentConsultantInd'],
#  ['CompBasedNetEarningsFilingOrg', 'CompBsdNetEarnsFlngOrgInd'],
#  ['CompBasedNetEarningsRelateOrgs', 'CompBsdNetEarnsRltdOrgsInd'],
#  ['CompBasedOnRevenueOfFilingOrg', 'CompBasedOnRevenueOfFlngOrgInd'],
#  ['CompBasedOnRevenueRelatedOrgs', 'CompBsdOnRevRelatedOrgsInd'],
#  ['WrittenEmploymentContract', 'WrittenEmploymentContractInd'],
#  ['InitialContractException', 'InitialContractExceptionInd'],
#  ['DiscretionarySpendingAccount', 'DiscretionarySpendingAcctInd'],
#  ['EquityBasedCompArrangement', 'EquityBasedCompArrngmInd'],
#  ['FirstClassOrCharterTravel', 'FirstClassOrCharterTravelInd'],
#  ['PaymentsForUseOfResidence', 'PaymentsForUseOfResidenceInd'],
#  ['HousingAllowanceOrResidence', 'HousingAllowanceOrResidenceInd'],
#  ['IdemnificationGrossUpPayments', 'IdemnificationGrossUpPmtsInd'],
#  ['AnyNonFixedPayments', 'AnyNonFixedPaymentsInd'],
#  ['Form990OfOtherOrganizations', 'Form990OfOtherOrganizationsInd'],
#  ['PersonalServices', 'PersonalServicesInd'],
#  ['RebuttablePresumptionProcedure', 'RebuttablePresumptionProcInd'],
#  ['SeverancePayment', 'SeverancePaymentInd'],
#  ['SubstantiationRequired', 'SubstantiationRequiredInd'],
#  ['SupplementalNonqualRetirePlan', 'SupplementalNonqualRtrPlanInd'],
#  ['WrittenPolicyRefTAndEExpnssInd', 'WrittenPolicyReTAndEExpenses']]

# %%
flat_list = [item for sublist in new_variables_df[new_variables_df['len']==2]['original_names'].tolist() for item in sublist]
print(len(flat_list))
print(flat_list[:])
# Out:
# 52
# ['BoardOrCommitteeApproval', 'BoardOrCommitteeApprovalInd', 'ClubDuesOrFees', 'ClubDuesOrFeesInd', 'TravelForCompanions', 'TravelForCompanionsInd', 'CompensationCommittee', 'CompensationCommitteeInd', 'CompensationSurvey', 'CompensationSurveyInd', 'IndependentConsultant', 'IndependentConsultantInd', 'CompBasedNetEarningsFilingOrg', 'CompBsdNetEarnsFlngOrgInd', 'CompBasedNetEarningsRelateOrgs', 'CompBsdNetEarnsRltdOrgsInd', 'CompBasedOnRevenueOfFilingOrg', 'CompBasedOnRevenueOfFlngOrgInd', 'CompBasedOnRevenueRelatedOrgs', 'CompBsdOnRevRelatedOrgsInd', 'WrittenEmploymentContract', 'WrittenEmploymentContractInd', 'InitialContractException', 'InitialContractExceptionInd', 'DiscretionarySpendingAccount', 'DiscretionarySpendingAcctInd', 'EquityBasedCompArrangement', 'EquityBasedCompArrngmInd', 'FirstClassOrCharterTravel', 'FirstClassOrCharterTravelInd', 'PaymentsForUseOfResidence', 'PaymentsForUseOfResidenceInd', 'HousingAllowanceOrResidence', 'HousingAllowanceOrResidenceInd', 'IdemnificationGrossUpPayments', 'IdemnificationGrossUpPmtsInd', 'AnyNonFixedPayments', 'AnyNonFixedPaymentsInd', 'Form990OfOtherOrganizations', 'Form990OfOtherOrganizationsInd', 'PersonalServices', 'PersonalServicesInd', 'RebuttablePresumptionProcedure', 'RebuttablePresumptionProcInd', 'SeverancePayment', 'SeverancePaymentInd', 'SubstantiationRequired', 'SubstantiationRequiredInd', 'SupplementalNonqualRetirePlan', 'SupplementalNonqualRtrPlanInd', 'WrittenPolicyRefTAndEExpnssInd', 'WrittenPolicyReTAndEExpenses']

# %% [markdown]
# <br> Flatten a list of lists: https://stackoverflow.com/questions/952914/how-to-make-a-flat-list-out-of-list-of-lists

# %%
print(len([c for c in df.columns.tolist() if c not in flat_list]))
print([c for c in df.columns.tolist() if c not in flat_list])
# Out:
# 27
# ['URL', 'SJ_01_PC_BOARD_APPROVAL', 'SJ_01_PC_CLUB_FEES', 'SJ_01_PC_COMPANION_TRAVEL', 'SJ_01_PC_COMPENSATION_COMMITTEE', 'SJ_01_PC_COMPENSATION_SURVEY', 'SJ_01_PC_CONSULTANT', 'SJ_01_PC_CONTINGENT_NET_OWN', 'SJ_01_PC_CONTINGENT_NET_RELATED', 'SJ_01_PC_CONTINGENT_REV_OWN', 'SJ_01_PC_CONTINGENT_REV_RELATED', 'SJ_01_PC_CONTRACT', 'SJ_01_PC_CONTRACT_EXCEPTION', 'SJ_01_PC_DISCRETIONARY_ACCOUNT', 'SJ_01_PC_EQUITY_BASED_COMP', 'SJ_01_PC_FIRST_CLASS_TRAVEL', 'SJ_01_PC_HOME_OFFICE_SUBSIDY', 'SJ_01_PC_HOUSING_ALLOWANCE', 'SJ_01_PC_INDEMNIFICATION', 'SJ_01_PC_NON_FIXED_PAYMENTS', 'SJ_01_PC_OTHER_ORGS_990', 'SJ_01_PC_PERSONAL_SERVICES', 'SJ_01_PC_REBUTTABLE_PRESUMPTION', 'SJ_01_PC_SEVERANCE', 'SJ_01_PC_SUBSTANTIATION_REQUIRED', 'SJ_01_PC_SUPPLEMENTAL_RETIREMENT', 'SJ_01_PC_WRITTEN_POLICY']

# %%
print(len(new_variables_df['variable_name_new'].tolist()))
# Out:
# 26

# %%
set([c for c in df.columns.tolist() if c not in flat_list]) - set(new_variables_df['variable_name_new'].tolist())
# Out:
# {'URL'}

# %% [markdown]
# <br>The following block drops 52 columns

# %%
print(len(df.columns))
df = df[[c for c in df.columns.tolist() if c not in flat_list]]
print(len(df.columns))
df[:2]
# Out:
# 79
# 27
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301316_public.xml
#
#   SJ_01_PC_BOARD_APPROVAL SJ_01_PC_CLUB_FEES SJ_01_PC_COMPANION_TRAVEL  \
# 0                       1                NaN                       NaN
# 1                       1                NaN                       NaN
#
#   SJ_01_PC_COMPENSATION_COMMITTEE SJ_01_PC_COMPENSATION_SURVEY  \
# 0                               1                            1
# 1                               1                            1
#
#   SJ_01_PC_CONSULTANT SJ_01_PC_CONTINGENT_NET_OWN  \
# 0                 NaN                           0
# 1                 NaN                           0
#
#   SJ_01_PC_CONTINGENT_NET_RELATED SJ_01_PC_CONTINGENT_REV_OWN  \
# 0                               0                           0
# 1                               0                           0
#
#   SJ_01_PC_CONTINGENT_REV_RELATED SJ_01_PC_CONTRACT  \
# 0                               0               NaN
# 1                               0               NaN
#
#   SJ_01_PC_CONTRACT_EXCEPTION SJ_01_PC_DISCRETIONARY_ACCOUNT  \
# 0                           0                            NaN
# 1                           0                            NaN
#
#   SJ_01_PC_EQUITY_BASED_COMP SJ_01_PC_FIRST_CLASS_TRAVEL  \
# 0                          0                         NaN
# 1                          0                         NaN
#
#   SJ_01_PC_HOME_OFFICE_SUBSIDY SJ_01_PC_HOUSING_ALLOWANCE  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
#
#   SJ_01_PC_INDEMNIFICATION SJ_01_PC_NON_FIXED_PAYMENTS  \
# 0                      NaN                           0
# 1                      NaN                           0
#
#   SJ_01_PC_OTHER_ORGS_990 SJ_01_PC_PERSONAL_SERVICES  \
# 0                     NaN                        NaN
# 1                     NaN                        NaN
#
#   SJ_01_PC_REBUTTABLE_PRESUMPTION SJ_01_PC_SEVERANCE  \
# 0                               0                  0
# 1                               0                  0
#
#   SJ_01_PC_SUBSTANTIATION_REQUIRED SJ_01_PC_SUPPLEMENTAL_RETIREMENT  \
# 0                              NaN                                1
# 1                              NaN                                1
#
#   SJ_01_PC_WRITTEN_POLICY
# 0                     NaN
# 1                     NaN

# %% [markdown]
# ##### Verify

# %%
print(len(df.columns.tolist()))
# Out:
# 27

# %%
set(df.columns.tolist()) - set(new_variables_df['variable_name_new'].tolist())
# Out:
# {'URL'}

# %%
set(new_variables_df['variable_name_new'].tolist()) - set(df.columns.tolist())
# Out:
# set()

# %%
df.dtypes
# Out:
# URL                                 object
# SJ_01_PC_BOARD_APPROVAL             object
# SJ_01_PC_CLUB_FEES                  object
# SJ_01_PC_COMPANION_TRAVEL           object
# SJ_01_PC_COMPENSATION_COMMITTEE     object
# SJ_01_PC_COMPENSATION_SURVEY        object
# SJ_01_PC_CONSULTANT                 object
# SJ_01_PC_CONTINGENT_NET_OWN         object
# SJ_01_PC_CONTINGENT_NET_RELATED     object
# SJ_01_PC_CONTINGENT_REV_OWN         object
# SJ_01_PC_CONTINGENT_REV_RELATED     object
# SJ_01_PC_CONTRACT                   object
# SJ_01_PC_CONTRACT_EXCEPTION         object
# SJ_01_PC_DISCRETIONARY_ACCOUNT      object
# SJ_01_PC_EQUITY_BASED_COMP          object
# SJ_01_PC_FIRST_CLASS_TRAVEL         object
# SJ_01_PC_HOME_OFFICE_SUBSIDY        object
# SJ_01_PC_HOUSING_ALLOWANCE          object
# SJ_01_PC_INDEMNIFICATION            object
# SJ_01_PC_NON_FIXED_PAYMENTS         object
# SJ_01_PC_OTHER_ORGS_990             object
# SJ_01_PC_PERSONAL_SERVICES          object
# SJ_01_PC_REBUTTABLE_PRESUMPTION     object
# SJ_01_PC_SEVERANCE                  object
# SJ_01_PC_SUBSTANTIATION_REQUIRED    object
# SJ_01_PC_SUPPLEMENTAL_RETIREMENT    object
# SJ_01_PC_WRITTEN_POLICY             object
# dtype: object

# %%
len(new_variables_df['variable_name_new'].tolist())
new_variables_df['variable_name_new'].tolist()[:2]
# Out:
# ['SJ_01_PC_BOARD_APPROVAL', 'SJ_01_PC_CLUB_FEES']

# %%
df[new_variables_df['variable_name_new'].tolist()] = df[new_variables_df['variable_name_new'].tolist()].apply(pd.to_numeric, errors='coerce')

# %%
df.dtypes
# Out:
# URL                                  object
# SJ_01_PC_BOARD_APPROVAL             float64
# SJ_01_PC_CLUB_FEES                  float64
# SJ_01_PC_COMPANION_TRAVEL           float64
# SJ_01_PC_COMPENSATION_COMMITTEE     float64
# SJ_01_PC_COMPENSATION_SURVEY        float64
# SJ_01_PC_CONSULTANT                 float64
# SJ_01_PC_CONTINGENT_NET_OWN         float64
# SJ_01_PC_CONTINGENT_NET_RELATED     float64
# SJ_01_PC_CONTINGENT_REV_OWN         float64
# SJ_01_PC_CONTINGENT_REV_RELATED     float64
# SJ_01_PC_CONTRACT                   float64
# SJ_01_PC_CONTRACT_EXCEPTION         float64
# SJ_01_PC_DISCRETIONARY_ACCOUNT      float64
# SJ_01_PC_EQUITY_BASED_COMP          float64
# SJ_01_PC_FIRST_CLASS_TRAVEL         float64
# SJ_01_PC_HOME_OFFICE_SUBSIDY        float64
# SJ_01_PC_HOUSING_ALLOWANCE          float64
# SJ_01_PC_INDEMNIFICATION            float64
# SJ_01_PC_NON_FIXED_PAYMENTS         float64
# SJ_01_PC_OTHER_ORGS_990             float64
# SJ_01_PC_PERSONAL_SERVICES          float64
# SJ_01_PC_REBUTTABLE_PRESUMPTION     float64
# SJ_01_PC_SEVERANCE                  float64
# SJ_01_PC_SUBSTANTIATION_REQUIRED    float64
# SJ_01_PC_SUPPLEMENTAL_RETIREMENT    float64
# SJ_01_PC_WRITTEN_POLICY             float64
# dtype: object

# %%
df.describe().T
# Out:
#                                      count  mean  std  min  25%  50%  75%  max
# SJ_01_PC_BOARD_APPROVAL          398308.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_CLUB_FEES                39872.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_COMPANION_TRAVEL         28539.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_COMPENSATION_COMMITTEE  198519.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_COMPENSATION_SURVEY     254666.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_CONSULTANT               98304.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_CONTINGENT_NET_OWN      549972.00  0.02 0.14 0.00 0.00 0.00 0.00 1.00
# SJ_01_PC_CONTINGENT_NET_RELATED  549903.00  0.01 0.11 0.00 0.00 0.00 0.00 1.00
# SJ_01_PC_CONTINGENT_REV_OWN      550010.00  0.02 0.13 0.00 0.00 0.00 0.00 1.00
# SJ_01_PC_CONTINGENT_REV_RELATED  549811.00  0.01 0.07 0.00 0.00 0.00 0.00 1.00
# SJ_01_PC_CONTRACT                154351.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_CONTRACT_EXCEPTION      548387.00  0.00 0.06 0.00 0.00 0.00 0.00 1.00
# SJ_01_PC_DISCRETIONARY_ACCOUNT    11085.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_EQUITY_BASED_COMP       677114.00  0.00 0.04 0.00 0.00 0.00 0.00 1.00
# SJ_01_PC_FIRST_CLASS_TRAVEL       16493.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_HOME_OFFICE_SUBSIDY       2066.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_HOUSING_ALLOWANCE        35408.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_INDEMNIFICATION          18830.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_NON_FIXED_PAYMENTS      548378.00  0.09 0.29 0.00 0.00 0.00 0.00 1.00
# SJ_01_PC_OTHER_ORGS_990          116309.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_PERSONAL_SERVICES         7227.00  1.00 0.00 1.00 1.00 1.00 1.00 1.00
# SJ_01_PC_REBUTTABLE_PRESUMPTION   33116.00  0.05 0.22 0.00 0.00 0.00 0.00 1.00
# SJ_01_PC_SEVERANCE               677322.00  0.06 0.25 0.00 0.00 0.00 0.00 1.00
# SJ_01_PC_SUBSTANTIATION_REQUIRED 124309.00  0.89 0.31 0.00 1.00 1.00 1.00 1.00
# SJ_01_PC_SUPPLEMENTAL_RETIREMENT 677341.00  0.16 0.37 0.00 0.00 0.00 0.00 1.00
# SJ_01_PC_WRITTEN_POLICY          103486.00  0.86 0.35 0.00 1.00 1.00 1.00 1.00

# %% [markdown]
# ##### Save DF

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df.to_pickle('Schedule J (Part I) - parsed.pkl.gz', compression='gzip')
# Out:
# Current date and time :  2025-06-20 22:46:28
#
# CPU times: total: 24 s
# Wall time: 24.6 s
