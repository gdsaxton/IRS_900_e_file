# %% [markdown]
# #### Update of this notebook:
# - *IRS Form 990 e-File Data (5) -- Parse Nested 'Sub-Key' Variables -- DOWNLOADED XML FILINGS.ipynb*

# %% [markdown]
# # Overview
#
# This is the fifth in a series of tutorials that illustrate how to download, extract, and parse the IRS 990 e-file data available at https://aws.amazon.com/public-data-sets/irs-990/
#
# In the previous notebook we used the information contained in the concordance file to combine pairs of columns that reflect the same 990 variable, such as *TaxPeriodBeginDt* and *TaxPeriodBeginDate*, and assign the relevant 'standardized' name from the concordance file, and then 'binarized' relevant columns and, lastly, deleted unneeded columns.
#
#
# The goal of this notebook is to parse all of the 'dictionary' columns, or those with 'nested' dictionary structures. For example, the data for one observation in the column in the XML file called *Filer* might look like this:
#
# ``{'EIN': '203840246', 'Name': {'BusinessNameLine1': 'NEW ALBANY WALKING CLUB INC'}, 'NameControl': 'NEWA', 'USAddress': {'AddressLine1': '4000 BAUGHMAN GRANT', 'City': 'NEW ALBANY', 'State': 'OH', 'ZIPCode': '43054'}}``
#
# And the data for *F9_10_PC_UNSECURED_NOTES_BOY* may look like this:
#
# ``{'BOYAmt': '24000', 'EOYAmt': '47479'}``
#
# In effect, multiple variables are nested under the same column extracted from the raw e-file data. In the concordance file I have added a column, called 'sub_key', that tells us that, for the variable *F9_10_PC_UNSECURED_NOTES_BOY*, we will want to extract data nested under the ``EOYAmt`` and ``EOY`` keys. I added this data after conducting extensive verifications on the data.
#
# Accordingly, our first step  in this notebook will be to read in the concordance file that has all the reconciled and verified variables to date:
# - The file is called *concordance_VERIFIED.xlsx*
#
# We then read in the PANDAS data file (N=2,104,435) saved in our last notebook:
# - *all filings August 2022 - all control variables (renamed).pkl.gz*
#
# I then parse all columns that have Python dictionaries as values and then save an updated e-file dataframe:
# - *all filings August 2022 - all control variables (with parsed sub-key variables).pkl.gz*

# %% [markdown]
# # Load Packages and Connect to MongoDB

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from pandas import Series

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
#http://pandas.pydata.org/pandas-docs/stable/options.html
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 250)

# %% [markdown]
# #### Set working directory

# %%
cd "C:\\Users\\Gregory\\IRS 990 Control Variables\\"
# Out:
# C:\Users\Gregory\IRS 990 Control Variables

# %% [markdown]
# # Read in Concordance File
# Read in the 'concordance' file. This codebook will help us identify the variables that contain dictionaries. We will then use the 'sub-key' column to help parse these columns.

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
concordance = pd.read_excel('concordance_VERIFIED.xlsx')
print('# of columns:', len(concordance.columns))
print('# of observations:', len(concordance))
concordance[:2]
# Out:
# Current date and time :  2025-04-17 16:11:58
#
# # of columns: 17
# # of observations: 574
# CPU times: total: 297 ms
# Wall time: 6.7 s
#                                                    xpath  \
# 0         /Return/ReturnData/IRS990/SpecialConditionDesc
# 1  /Return/ReturnData/IRS990/SpecialConditionDescription
#
#                  variable_name_new  # of Characters (newly named)  \
# 0  F9_00_HD_SPECIAL_CONDITION_DESC                            NaN
# 1  F9_00_HD_SPECIAL_CONDITION_DESC                           31.0
#
#   variable name notes PARSING NOTES OTHER NOTES  \
# 0                 NaN           NaN         NaN
# 1                 NaN           NaN         NaN
#
#                      description    location_code     part data_type_xsd  \
# 0  Special condition description  F990-PC-PART-00  PART-00      TextType
# 1  Special condition description  F990-PC-PART-00  PART-00      TextType
#
#   python_data_type         fill_null BINARIZE                 MongoDB_Name  \
# 0           string  Do not fill null      NaN         SpecialConditionDesc
# 1           string  Do not fill null      NaN  SpecialConditionDescription
#
#   sub_key sub_sub_key cardinality
# 0     NaN         NaN         NaN
# 1     NaN         NaN         NaN

# %%
concordance['cardinality'].value_counts()
# Out:
# cardinality
# ONE     88
# MANY     2
# Name: count, dtype: int64

# %%
concordance[concordance['cardinality']=='MANY']
# Out:
#                                                    xpath  variable_name_new  \
# 422        /Return/ReturnData/IRS990/OtherExpenses/Total  F9_09_EXP_OTH_TOT
# 423  /Return/ReturnData/IRS990/OtherExpensesGrp/TotalAmt  F9_09_EXP_OTH_TOT
#
#      # of Characters (newly named) variable name notes PARSING NOTES  \
# 422                            NaN                 NaN           NaN
# 423                            NaN                 NaN           NaN
#
#     OTHER NOTES                         description             location_code  \
# 422         NaN  All Other expenses - total expense  F990-PC-PART-09-LINE-24A
# 423         NaN      Other Expenses - total expense  F990-PC-PART-09-LINE-24A
#
#         part data_type_xsd python_data_type fill_null BINARIZE  \
# 422  PART-09  USAmountType            Int64       NaN      NaN
# 423  PART-09  USAmountType            Int64       NaN      NaN
#
#          MongoDB_Name   sub_key sub_sub_key cardinality
# 422     OtherExpenses     Total         NaN        MANY
# 423  OtherExpensesGrp  TotalAmt         NaN        MANY

# %%
concordance[concordance['sub_key'].notnull()][['variable_name_new', 'MongoDB_Name', 'sub_key']]
# Out:
#                 variable_name_new           MongoDB_Name         sub_key
# 122  F9_03_PC_PROG_SVC_ACC_2_CODE              Activity2    ActivityCode
# 123  F9_03_PC_PROG_SVC_ACC_2_CODE  ProgSrvcAccomActy2Grp    ActivityCode
# 124  F9_03_PC_PROG_SVC_ACC_3_CODE              Activity3    ActivityCode
# 125  F9_03_PC_PROG_SVC_ACC_3_CODE  ProgSrvcAccomActy3Grp    ActivityCode
# 146  F9_03_PC_PROG_SVC_ACC_2_DESC              Activity2     Description
# ..                            ...                    ...             ...
# 556        F9_00_HD_FILER_CITY_US                  Filer       USAddress
# 557   F9_00_HD_FILER_COUNTRY_FRGN                  Filer  ForeignAddress
# 558   F9_00_HD_FILER_COUNTRY_FRGN                  Filer  ForeignAddress
# 559         F9_00_HD_FILER_ZIP_US                  Filer       USAddress
# 560         F9_00_HD_FILER_ZIP_US                  Filer       USAddress
#
# [218 rows x 3 columns]

# %%
subkeycols = list(set(concordance[concordance['sub_key'].notnull()]['variable_name_new'].tolist()))
print(len(subkeycols))
subkeycols
# Out:
# 109
# ['F9_09_PC_TOTAL_FUNC_EXPENSES',
#  'F9_10_PC_SAVINGS_TEMP_INVEST_EOY',
#  'F9_09_PC_COMP_DISQUAL_MGMT',
#  'F9_00_HD_FILER_COUNTRY_FRGN',
#  'F9_09_PC_TOTAL_PROG_SVCE_EXPENSE',
#  'F9_09_PC_PAYROLL_TAX_FUNDRAISE',
#  'F9_10_PC_SECURE_MORT_NOTES_EOY',
#  'F9_09_PC_OTHER_SALARY_TOTAL',
#  'F9_09_PC_PAYROLL_TAX_PROG_SVCE',
#  'F9_10_PC_CASH_NON_INTEREST_BOY',
#  'F9_09_EXP_OFFICE_TOT',
#  'F9_10_ASSETS_INTANGIB_EOY',
#  'F9_10_LIAB_GRANTS_PAYABLE_EOY',
#  'F9_09_PC_COMP_OFFICERS_MGMT',
#  'F9_10_ASSETS_OTH_EOY',
#  'F9_09_EXP_OTH_OTH_TOT',
#  'F9_09_PC_OTHER_EMP_BEN_MGMT',
#  'F9_09_EXP_CONF_MEETING_TOT',
#  'F9_09_PC_FEES_FOR_SVCE_LOBB_TOT',
#  'F9_00_HD_SIGNING_OFFICER_SIGNTR',
#  'F9_09_EXP_JOINT_COSTS_TOT',
#  'F9_09_EXP_AD_PROMO_TOT',
#  'F9_03_PC_PROG_SVC_ACC_3_EXP',
#  'F9_10_PC_ESCROW_LIABILITY_EOY',
#  'F9_00_HD_FILER_CITY_US',
#  'F9_09_PC_COMP_OFFICERS_PROG_SVCE',
#  'F9_10_PC_LOANS_FROM_OFFICERS_EOY',
#  'F9_03_PC_PROG_SVC_ACC_3_GRNT',
#  'F9_09_PC_FEES_FOR_SVCE_OTH_TOT',
#  'F9_09_PC_COMP_OFFICERS_TOTAL',
#  'F9_09_EXP_INTEREST_TOT',
#  'F9_10_ASSETS_NOTES_LOANS_NET_EOY',
#  'F9_10_PC_RET_EARNINGS_ENDWMT_EOY',
#  'F9_00_HD_FILER_ADDR_US_L2',
#  'F9_09_PC_PAYMENT_TO_AFFILIATES',
#  'F9_09_PC_FEES_FOR_SVCE_ACCT_TOT',
#  'F9_10_NAFB_RESTRICT_PERM_EOY',
#  'F9_09_EXP_INSURANCE_TOT',
#  'F9_10_LIAB_ACC_PAYABLE_EOY',
#  'F9_10_PC_SECURED_MORTGAGES_EOY',
#  'F9_09_PC_PENSION_CONT_FUNDRAISE',
#  'F9_03_PC_PROG_SVC_ACC_2_CODE',
#  'F9_09_PC_TOTAL_FUNDRAISE_EXPENSE',
#  'F9_09_PC_OTHER_SALARY_FUNDRAISE',
#  'F9_10_ASSETS_LOANS_DISQUAL_EOY',
#  'F9_09_PC_PENSION_CONT_TOTAL',
#  'F9_09_PC_OTHER_SALARY_MGMT',
#  'F9_10_ASSETS_INVENT_SALE_EOY',
#  'F9_10_PC_INVEST_OTHER_SEC_EOY',
#  'F9_10_PC_UNSECURED_NOTES_EOY',
#  'F9_09_PC_PAYROLL_TAX_MGMT',
#  'F9_10_NAFB_UNRESTRICT_EOY',
#  'F9_09_PC_PENSION_CONT_PROG_SVCE',
#  'F9_09_PC_FEES_FOR_SVCE_INVST_TOT',
#  'F9_03_PC_PROG_SVC_ACC_2_EXP',
#  'F9_09_EXP_OCCUPANCY_TOT',
#  'F9_08_PC_TOTAL_REVENUE',
#  'F9_00_HD_FILER_ZIP_US',
#  'F9_09_PC_COMP_DISQUAL_TOTAL',
#  'F9_09_EXP_DEPREC_MAG',
#  'F9_10_PC_CASH_NON_INTEREST_EOY',
#  'F9_10_ASSETS_ACC_NET_EOY',
#  'F9_09_PC_OTHER_EMP_BEN_FUNDRAISE',
#  'F9_09_PC_PENSION_CONT_MGMT',
#  'F9_09_EXP_GRANT_ORG_DMSTC_TOT',
#  'F9_09_PC_OTHER_EMP_BEN_PROG_SVCE',
#  'F9_09_PC_OTHER_SALARY_PROG_SVCE',
#  'F9_10_PC_INVEST_PROG_RELTD_EOY',
#  'F9_09_EXP_GRANT_FRGN_TOT',
#  'F9_10_PC_INVEST_PUB_TRADED_EOY',
#  'F9_09_PC_COMP_DISQUAL_PROG_SVCE',
#  'F9_09_PC_COMP_OFFICERS_FUNDRAISE',
#  'F9_09_EXP_DEPREC_FUNDR',
#  'F9_09_PC_TOTAL_MGMT_EXPENSE',
#  'F9_03_PC_PROG_SVC_ACC_3_CODE',
#  'F9_03_PC_PROG_SVC_ACC_2_DESC',
#  'F9_10_LIAB_REV_DEFERRED_EOY',
#  'F9_10_PC_BOND_LIABILITY_EOY',
#  'F9_09_EXP_INFO_TECH_TOT',
#  'F9_10_PC_UNSECURED_LOANS_EOY',
#  'F9_10_PZ_TOTAL_ASSETS_EOY',
#  'F9_03_PC_PROG_SVC_ACC_3_DESC',
#  'F9_09_EXP_GRANT_INDIV_DMSTC_TOT',
#  'F9_10_PC_OTHER_LIABILITIES_EOY',
#  'F9_10_PC_UNSECURED_NOTES_BOY',
#  'F9_00_HD_FILER_STATE_US',
#  'F9_09_EXP_BENF_PAID_MEMB_TOT',
#  'F9_09_EXP_TRAVEL_TOT',
#  'F9_09_PC_COMP_DISQUAL_FUNDRAISE',
#  'F9_09_PC_FEES_FOR_SVCE_FR_TOT',
#  'F9_10_ASSETS_EXP_PREPAID_EOY',
#  'F9_09_EXP_DEPREC_TOT',
#  'F9_00_HD_FILER_ADDR_US_L1',
#  'F9_09_PC_FEES_FOR_SVCE_MGMT_TOT',
#  'F9_09_EXP_ROY_TOT',
#  'F9_09_PC_OTHER_EMP_BEN_TOTAL',
#  'F9_09_EXP_TRAVEL_ENTRTNMNT_TOT',
#  'F9_10_ASSETS_PLEDGES_NET_EOY',
#  'F9_10_NAFB_RESTRICT_TEMP_EOY',
#  'F9_09_EXP_DEPREC_PROG',
#  'F9_09_EXP_OTH_TOT',
#  'F9_10_PC_SAVINGS_TEMP_INVEST_BOY',
#  'F9_09_PC_PAYROLL_TAX_TOTAL',
#  'F9_03_PC_PROG_SVC_ACC_2_GRNT',
#  'F9_03_PC_PROG_SVC_ACC_3_REV',
#  'F9_03_PC_PROG_SVC_ACC_2_REV',
#  'F9_09_PC_FEES_FOR_SVCE_LEGL_TOT',
#  'F9_10_ASSETS_LESS_DEPREC_EOY',
#  'F9_10_LIAB_LOANS_OFF_EOY']

# %% [markdown]
# # Read 990 Data
# In the following code block we read the file (produced in the previous notebook) containing all filings into a PANDAS dataframe.

# %%
#%%time
#import datetime
#print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
#df = pd.read_pickle('all NEW filings February 2024 - all control variables (renamed).pkl.gz', compression='gzip')
#print('# of columns:', len(df.columns))
#print('# of observations:', len(df))
#df[:1]
# Out:
# Current date and time :  2024-03-29 23:59:41
#
# # of columns: 292
# # of observations: 891980
# CPU times: total: 1min 39s
# Wall time: 1min 48s
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201812509349300101_public.xml
#
#   F9_09_PC_FEES_FOR_SVCE_FR_TOT F9_00_HD_BUILD_TIME_STAMP fiscal_year  \
# 0                           NaN      2022-09-23 18:48:47Z        2018
#
#          EIN                                          BusinessName  \
# 0  346526754  {'BusinessNameLine1Txt': 'Lucas County Farm Bureau'}
#
#   BusinessNameControlTxt    PhoneNum  \
# 0                   LUCA  4198338015
#
#                                                                                                      USAddress  \
# 0  {'AddressLine1Txt': '109 Portage St', 'CityNm': 'Woodville', 'StateAbbreviationCd': 'OH', 'ZIPCd': '43469'}
#
#   InCareOfNm ForeignAddress ForeignPhoneNum F9_00_HD_ADDR_CHANGE  \
# 0        NaN            NaN             NaN                  NaN
#
#   F9_00_HD_AMENDED_RETURN F9_00_HD_CTRY_OF_DOMICILE  \
# 0                     NaN                       NaN
#
#   F9_00_HD_EXEMPT_STATUS_4847A1 F9_00_HD_EXEMPT_STATUS_501C  \
# 0                           NaN                           5
#
#   F9_00_HD_EXEMPT_STATUS_501C3 F9_00_HD_FINAL_RETURN  \
# 0                          NaN                   NaN
#
#   F9_00_HD_GROSS_EXEMPT_NUM F9_00_HD_GROSS_RCPT F9_00_HD_GROUP_RETURN  \
# 0                       NaN              272756                     0
#
#   F9_00_HD_INCLUDES_SUBORD_ORGS F9_00_HD_INITIAL_RETURN  \
# 0                           NaN                     NaN
#
#   F9_00_HD_PRIN_OFF_NAME  \
# 0         KAYLA RICHARDS
#
#                                                                                                     F9_00_HD_SIGNING_OFFICER_SIGNTR  \
# 0  {'PersonNm': 'KAYLA RICHARDS', 'PersonTitleTxt': 'ORGANIZATION DIRECTOR', 'PhoneNum': '4198338015', 'SignatureDt': '2018-08-29'}
#
#   F9_00_HD_SPECIAL_CONDITION_DESC F9_00_HD_STATE_OF_DOMICILE  \
# 0                             NaN                         OH
#
#   F9_00_HD_TAX_PER_BEGIN F9_00_HD_TAX_PER_END F9_00_HD_TAX_YEAR  \
# 0             2017-08-01           2018-07-31              2017
#
#          F9_00_HD_TIME_STAMP F9_00_HD_TYPE_ORG_ASSOCIATION  \
# 0  2018-09-07T04:44:38-07:00                           NaN
#
#   F9_00_HD_TYPE_ORG_CORP F9_00_HD_TYPE_ORG_OTHER F9_00_HD_TYPE_ORG_OTHER_DESC  \
# 0                      1                     NaN                          NaN
#
#   F9_00_HD_TYPE_ORG_TRUST F9_00_HD_WEBSITE F9_00_HD_YEAR_FORMED  \
# 0                     NaN              N/A                 1916
#
#   F9_01_PC_BEN_PAID_MEMB_PRIOR F9_01_PC_CONTR_GRANTS_CURR  \
# 0                       239263                     236036
#
#   F9_01_PC_CONTR_GRANTS_PRIOR F9_01_PC_GRANTS_PRIOR  \
# 0                      278582                   NaN
#
#   F9_01_PC_INDEP_VOTING_MEMB F9_01_PC_INVEST_INCOME_PRIOR  \
# 0                         10                        15945
#
#   F9_01_PC_NET_ASSETS_BOY F9_01_PC_OTHER_EXPENSE_PRIOR  \
# 0                  383254                        94080
#
#   F9_01_PC_OTHER_REV_PRIOR F9_01_PC_PROF_FUNDRISING_EXP_CURR  \
# 0                    29098                                 0
#
#   F9_01_PC_PROF_FUNDRISING_EXP_PRIOR F9_01_PC_PROG_SERVICE_REV_PRIOR  \
# 0                                NaN                             NaN
#
#   F9_01_PC_REV_LESS_EXP_CURR F9_01_PC_REV_LESS_EXP_PRIOR  \
# 0                       3331                      -30456
#
#   F9_01_PC_TERMINATION_CONTRACTION F9_01_PC_TOT_ASSETS_EOY  \
# 0                              NaN                  424855
#
#   F9_01_PC_TOT_EXP_PRIOR F9_01_PC_TOT_FNDR_EXP_CURR  \
# 0                 354081                          0
#
#   F9_01_PC_TOT_INDIV_EMPLOYED F9_01_PC_TOT_INDIV_VOLUNTEERS  \
# 0                           7                            39
#
#   F9_01_PC_TOT_LIABILITIES_EOY F9_01_PC_TOT_REVENUE_PRIOR  \
# 0                        38270                     323625
#
#   F9_01_PC_TOT_UBI_GROSS F9_01_PC_TOT_UBI_NET F9_01_PC_VOTING_MEMB_GOV_BODY  \
# 0                      0                  NaN                            10
#
#   F9_01_PZ_BEN_PAID_TO_MEMB_CURR F9_01_PZ_GRANTS_PAID_CURR  \
# 0                         181041                         0
#
#   F9_01_PZ_INVEST_INCOME_CURR F9_01_PZ_NAFB_EOY  \
# 0                       10719            386585
#
#      F9_01_PZ_ORGANIZATIONAL_MISSION F9_01_PZ_OTHER_EXPENSE_CURR  \
# 0  IMPROVE RURAL STANDARD OF LIVING.                       65279
#
#   F9_01_PZ_OTHER_REV_CURR F9_01_PZ_PROG_SERVICE_REV_CURR  \
# 0                   26001                              0
#
#   F9_01_PZ_SALARIES_CURR F9_01_PZ_SALARIES_PRIOR F9_01_PZ_TOT_ASSETS_BOY  \
# 0                  23105                   20738                  424800
#
#   F9_01_PZ_TOT_EXP_CURR F9_01_PZ_TOT_LIAB_BOY F9_01_PZ_TOT_REV_CURR  \
# 0                269425                 41546                272756
#
#   F9_03_PC_PGMSVC_SIGNIF_CHG F9_03_PC_PGMSVC_SIGNIF_NEW  \
# 0                          0                          0
#
#   F9_03_PC_PROG_SVC_ACC_1_CODE  \
# 0                          NaN
#
#                                                                                                                                                              F9_03_PC_PROG_SVC_ACC_1_DESC  \
# 0  BENEFITS PAID TO OR FOR MEMBERS - THIS IS PAID MEMBERSHIPS TO OHIO FARM BUREAU AND TO AMERICAN FARM BUREAU TO FUTHER THEIR EFFORTS IN PROGRAMMING AND PROMOTING THE FARMING COMMUNITY.
#
#   F9_03_PC_PROG_SVC_ACC_1_EXP F9_03_PC_PROG_SVC_ACC_1_GRNT  \
# 0                         NaN                          NaN
#
#   F9_03_PC_PROG_SVC_ACC_1_REV  \
# 0                         NaN
#
#                                                                                                                                                                             F9_03_PC_PROG_SVC_ACC_2_CODE  \
# 0  {'Desc': 'MEMBERSHIP - COSTS OF PROMOTING FARM BUREAU AND ITS MISSION. PROMOTION OF FARM BUREAU PROGRAMS AND EVENTS IN ORDER TO EDUCATE THE FARMER AND CONSUMER IN CURRENT FARMING AND FOOD ISSUES.'}
#
#                                                                                                                                                                             F9_03_PC_PROG_SVC_ACC_2_DESC  \
# 0  {'Desc': 'MEMBERSHIP - COSTS OF PROMOTING FARM BUREAU AND ITS MISSION. PROMOTION OF FARM BUREAU PROGRAMS AND EVENTS IN ORDER TO EDUCATE THE FARMER AND CONSUMER IN CURRENT FARMING AND FOOD ISSUES.'}
#
#                                                                                                                                                                              F9_03_PC_PROG_SVC_ACC_2_EXP  \
# 0  {'Desc': 'MEMBERSHIP - COSTS OF PROMOTING FARM BUREAU AND ITS MISSION. PROMOTION OF FARM BUREAU PROGRAMS AND EVENTS IN ORDER TO EDUCATE THE FARMER AND CONSUMER IN CURRENT FARMING AND FOOD ISSUES.'}
#
#                                                                                                                                                                             F9_03_PC_PROG_SVC_ACC_2_GRNT  \
# 0  {'Desc': 'MEMBERSHIP - COSTS OF PROMOTING FARM BUREAU AND ITS MISSION. PROMOTION OF FARM BUREAU PROGRAMS AND EVENTS IN ORDER TO EDUCATE THE FARMER AND CONSUMER IN CURRENT FARMING AND FOOD ISSUES.'}
#
#                                                                                                                                                                              F9_03_PC_PROG_SVC_ACC_2_REV  \
# 0  {'Desc': 'MEMBERSHIP - COSTS OF PROMOTING FARM BUREAU AND ITS MISSION. PROMOTION OF FARM BUREAU PROGRAMS AND EVENTS IN ORDER TO EDUCATE THE FARMER AND CONSUMER IN CURRENT FARMING AND FOOD ISSUES.'}
#
#                                                                                                                     F9_03_PC_PROG_SVC_ACC_3_CODE  \
# 0  {'Desc': 'CONFERENCE, CONVENTIONS AND MEETINGS - EDUCATION OF VOLUNTEERS FOR THE PROMOTING AND MARKETING OF FARM ISSUES AND CURRENT EVENTS.'}
#
#                                                                                                                     F9_03_PC_PROG_SVC_ACC_3_DESC  \
# 0  {'Desc': 'CONFERENCE, CONVENTIONS AND MEETINGS - EDUCATION OF VOLUNTEERS FOR THE PROMOTING AND MARKETING OF FARM ISSUES AND CURRENT EVENTS.'}
#
#                                                                                                                      F9_03_PC_PROG_SVC_ACC_3_EXP  \
# 0  {'Desc': 'CONFERENCE, CONVENTIONS AND MEETINGS - EDUCATION OF VOLUNTEERS FOR THE PROMOTING AND MARKETING OF FARM ISSUES AND CURRENT EVENTS.'}
#
#                                                                                                                     F9_03_PC_PROG_SVC_ACC_3_GRNT  \
# 0  {'Desc': 'CONFERENCE, CONVENTIONS AND MEETINGS - EDUCATION OF VOLUNTEERS FOR THE PROMOTING AND MARKETING OF FARM ISSUES AND CURRENT EVENTS.'}
#
#                                                                                                                      F9_03_PC_PROG_SVC_ACC_3_REV  \
# 0  {'Desc': 'CONFERENCE, CONVENTIONS AND MEETINGS - EDUCATION OF VOLUNTEERS FOR THE PROMOTING AND MARKETING OF FARM ISSUES AND CURRENT EVENTS.'}
#
#   F9_03_PC_TOT_OTH_PROG_SVC_EXP F9_03_PC_TOT_OTH_PROG_SVC_GRNT  \
# 0                           NaN                            NaN
#
#   F9_03_PC_TOT_OTH_PROG_SVC_REV F9_03_PC_TOT_PROG_SVC_EXPENSE  \
# 0                           NaN                           NaN
#
#         F9_03_PZ_MISSION_DESCRIPTION F9_03_PZ_SCHEDULE_O_PART3  \
# 0  Improve rural standard of living.                       NaN
#
#   F9_04_PC_ACTVITIES_VIA_PARTNER F9_04_PC_CONTROLLED_ENTITY  \
# 0                              0                          0
#
#   F9_04_PC_DISREGARDED_ENTITY F9_04_PC_EXCESS_BENEFIT_TRANS  \
# 0                           0                             0
#
#   F9_04_PC_FR_EVENT_INC_GT_15K F9_04_PC_GAMING_INC_GT_15K  \
# 0                            0                          0
#
#   F9_04_PC_LOBBYING_ACTIVITIES F9_04_PC_POLITICAL_ACTIVITIES  \
# 0                            0                             0
#
#   F9_04_PC_PRIOR_EXCESS_BEN_TRAN F9_04_PC_PROF_FR_EXP_GT_15K  \
# 0                              0                           0
#
#   F9_04_PC_RELATED_ENTITY F9_04_PC_TRANS_TO_CNTRLD_ENT  \
# 0                       0                          NaN
#
#   F9_04_PC_TRANS_WITH_CNTRLD_ENT F9_05_EXP_SCHED_O_X  \
# 0                              0                 NaN
#
#   F9_05_PC_NUMBER_EMPLOYEES_W3 F9_05_PC_NUMBER_FORMS_1096  \
# 0                            7                          0
#
#   F9_05_PC_UNRELATED_BUS_INCOME F9_06_EXP_SCHED_O_X  \
# 0                             0                   1
#
#   F9_06_PC_990_PROVIDED_GOV_BODY F9_06_PC_ANNUAL_DISC_COVRD_PERS  \
# 0                              1                               1
#
#   F9_06_PC_CEO_COMPENSTN_PROCESS F9_06_PC_CHANGES_ORGANIZING_DOCS  \
# 0                              1                                0
#
#   F9_06_PC_CONFLICT_OF_INTEREST F9_06_PC_DECISIONS_SUBJ_APPROVAL  \
# 0                             1                                0
#
#   F9_06_PC_DELEGATION_MGT_DUTIES F9_06_PC_DELEGATION_OF_MGT  \
# 0                              0                          0
#
#   F9_06_PC_DOCUMENT_RET_POLICY F9_06_PC_ELECTION_BOARD_MEMBERS  \
# 0                            1                               0
#
#   F9_06_PC_FAMILY_OR_BUSINESS_REL F9_06_PC_FORM_AVAIL_OWN_WEBSITE  \
# 0                               1                             NaN
#
#   F9_06_PC_FORM_UPON_REQUEST F9_06_PC_JOINT_VENTURE_INVESTMNT  \
# 0                          1                                0
#
#   F9_06_PC_JOINT_VENTURE_POLICY F9_06_PC_LOCAL_CHAPTERS  \
# 0                           NaN                       0
#
#   F9_06_PC_MATERIAL_DIVERSION F9_06_PC_MEMBERS_OR_STOCKHOLDERS  \
# 0                           0                                1
#
#   F9_06_PC_MINUTES_COMMITTEES F9_06_PC_MINUTES_GOVERNING_BODY  \
# 0                           1                               1
#
#   F9_06_PC_MONITORING_OF_COI_POLICY F9_06_PC_NUM_IND_VOTING_MEMBERS  \
# 0                                 1                              10
#
#   F9_06_PC_NUM_VOTING_GOV_MEMBERS F9_06_PC_OFFICER_MAILING_ADDRESS  \
# 0                              10                                0
#
#   F9_06_PC_OTHER_COMPENSTN_PROCESS F9_06_PC_OTHER_WEBSITE  \
# 0                                1                    NaN
#
#   F9_06_PC_OWN_WEBSITE F9_06_PC_POLICIES_GOVERN_CHAPTER  \
# 0                  NaN                              NaN
#
#   F9_06_PC_STATES_WHERE_RET_FILED F9_06_PC_WHISTLEBLOWER_POLICY  \
# 0                              OH                             1
#
#   F9_07_EXP_SCHED_O_X F9_07_PC_COMPENSATION_OTHER_SRCE  \
# 0                 NaN                                0
#
#   F9_07_PC_FORMER_OFFICER_LISTED F9_07_PC_NO_LISTED_PERS_COMPENSD  \
# 0                              0                              NaN
#
#   F9_07_PC_NUM_CONTRCTRS_GRTR_100K F9_07_PC_NUM_INDS_GREATER_100K  \
# 0                              NaN                            NaN
#
#   F9_07_PC_TOTAL_COMP_GRTR_150K F9_07_PC_TOT_OTHER_COMPENSATION  \
# 0                             0                             NaN
#
#   F9_07_PC_TOT_REPRT_COMP_FROM_ORG F9_07_PC_TOT_REPRT_COMP_RLTD_ORG  \
# 0                             2130                              NaN
#
#   F9_08_EXP_SCHED_O_X F9_08_PC_ALL_OTHER_CONTRIBUTIONS  \
# 0                 NaN                              NaN
#
#   F9_08_PC_CONTS_REPRTD_FNDRAISNG F9_08_PC_COST_OF_GOODS_SOLD  \
# 0                             NaN                         NaN
#
#   F9_08_PC_FEDERATED_CAMPAIGNS F9_08_PC_FUNDRAISING_DIRECT_EXP  \
# 0                          NaN                             NaN
#
#   F9_08_PC_FUNDRAISING_EVENTS F9_08_PC_FUNDRAISING_GROSS_INC  \
# 0                         NaN                            NaN
#
#   F9_08_PC_GAMING_DIRECT_EXPENSES F9_08_PC_GAMING_GROSS_INCOME  \
# 0                             NaN                          NaN
#
#   F9_08_PC_GOVERNMENT_GRANTS F9_08_PC_GROSS_SALES_INVENTORY  \
# 0                        NaN                            NaN
#
#   F9_08_PC_MEMBERSHIP_DUES F9_08_PC_NONCASH_CONTRIBUTIONS  \
# 0                   236036                            NaN
#
#   F9_08_PC_PROGRAM_SVCE_REV_TOTAL F9_08_PC_RELATED_ORGANIZATIONS  \
# 0                             NaN                            NaN
#
#   F9_08_PC_TOTAL_CONTRIBUTIONS F9_08_PC_TOTAL_OTHER_REVENUE  \
# 0                       236036                        26001
#
#   F9_08_PC_TOTAL_PROG_SVCE_REVENUE  \
# 0                              NaN
#
#                                                                                   F9_08_PC_TOTAL_REVENUE  \
# 0  {'TotalRevenueColumnAmt': '272756', 'RelatedOrExemptFuncIncomeAmt': '26001', 'ExclusionAmt': '10719'}
#
#   F9_09_EXP_AD_PROMO_TOT  \
# 0                    NaN
#
#                              F9_09_EXP_BENF_PAID_MEMB_TOT  \
# 0  {'TotalAmt': '181041', 'ProgramServicesAmt': '181041'}
#
#                            F9_09_EXP_CONF_MEETING_TOT  \
# 0  {'TotalAmt': '7018', 'ProgramServicesAmt': '7018'}
#
#                                     F9_09_EXP_DEPREC_FUNDR  \
# 0  {'TotalAmt': '6770', 'ManagementAndGeneralAmt': '6770'}
#
#                                       F9_09_EXP_DEPREC_MAG  \
# 0  {'TotalAmt': '6770', 'ManagementAndGeneralAmt': '6770'}
#
#                                      F9_09_EXP_DEPREC_PROG  \
# 0  {'TotalAmt': '6770', 'ManagementAndGeneralAmt': '6770'}
#
#                                       F9_09_EXP_DEPREC_TOT  \
# 0  {'TotalAmt': '6770', 'ManagementAndGeneralAmt': '6770'}
#
#   F9_09_EXP_GRANT_FRGN_TOT F9_09_EXP_GRANT_INDIV_DMSTC_TOT  \
# 0                      NaN                             NaN
#
#   F9_09_EXP_GRANT_ORG_DMSTC_TOT F9_09_EXP_INFO_TECH_TOT  \
# 0                           NaN                     NaN
#
#                             F9_09_EXP_INSURANCE_TOT F9_09_EXP_INTEREST_TOT  \
# 0  {'TotalAmt': '697', 'ProgramServicesAmt': '697'}                    NaN
#
#   F9_09_EXP_JOINT_COSTS_TOT  \
# 0                       NaN
#
#                                                                 F9_09_EXP_OCCUPANCY_TOT  \
# 0  {'TotalAmt': '3478', 'ProgramServicesAmt': '3242', 'ManagementAndGeneralAmt': '236'}
#
#                                       F9_09_EXP_OFFICE_TOT  \
# 0  {'TotalAmt': '2283', 'ManagementAndGeneralAmt': '2283'}
#
#                                                                      F9_09_EXP_OTH_OTH_TOT  \
# 0  {'TotalAmt': '42350', 'ProgramServicesAmt': '36428', 'ManagementAndGeneralAmt': '5922'}
#
#   F9_09_EXP_OTH_TOT F9_09_EXP_ROY_TOT F9_09_EXP_SCHED_O_X  \
# 0               NaN               NaN                 NaN
#
#   F9_09_EXP_TRAVEL_ENTRTNMNT_TOT  \
# 0                            NaN
#
#                                F9_09_EXP_TRAVEL_TOT  \
# 0  {'TotalAmt': '331', 'ProgramServicesAmt': '331'}
#
#   F9_09_PC_COMP_DISQUAL_FUNDRAISE F9_09_PC_COMP_DISQUAL_MGMT  \
# 0                             NaN                        NaN
#
#   F9_09_PC_COMP_DISQUAL_PROG_SVCE F9_09_PC_COMP_DISQUAL_TOTAL  \
# 0                             NaN                         NaN
#
#                      F9_09_PC_COMP_OFFICERS_FUNDRAISE  \
# 0  {'TotalAmt': '1860', 'ProgramServicesAmt': '1860'}
#
#                           F9_09_PC_COMP_OFFICERS_MGMT  \
# 0  {'TotalAmt': '1860', 'ProgramServicesAmt': '1860'}
#
#                      F9_09_PC_COMP_OFFICERS_PROG_SVCE  \
# 0  {'TotalAmt': '1860', 'ProgramServicesAmt': '1860'}
#
#                          F9_09_PC_COMP_OFFICERS_TOTAL  \
# 0  {'TotalAmt': '1860', 'ProgramServicesAmt': '1860'}
#
#                            F9_09_PC_FEES_FOR_SVCE_ACCT_TOT  \
# 0  {'TotalAmt': '2352', 'ManagementAndGeneralAmt': '2352'}
#
#   F9_09_PC_FEES_FOR_SVCE_INVST_TOT F9_09_PC_FEES_FOR_SVCE_LEGL_TOT  \
# 0                              NaN                             NaN
#
#   F9_09_PC_FEES_FOR_SVCE_LOBB_TOT F9_09_PC_FEES_FOR_SVCE_MGMT_TOT  \
# 0                             NaN                             NaN
#
#   F9_09_PC_FEES_FOR_SVCE_OTH_TOT F9_09_PC_OTHER_EMP_BEN_FUNDRAISE  \
# 0                            NaN                              NaN
#
#   F9_09_PC_OTHER_EMP_BEN_MGMT F9_09_PC_OTHER_EMP_BEN_PROG_SVCE  \
# 0                         NaN                              NaN
#
#   F9_09_PC_OTHER_EMP_BEN_TOTAL  \
# 0                          NaN
#
#                         F9_09_PC_OTHER_SALARY_FUNDRAISE  \
# 0  {'TotalAmt': '21245', 'ProgramServicesAmt': '21245'}
#
#                              F9_09_PC_OTHER_SALARY_MGMT  \
# 0  {'TotalAmt': '21245', 'ProgramServicesAmt': '21245'}
#
#                         F9_09_PC_OTHER_SALARY_PROG_SVCE  \
# 0  {'TotalAmt': '21245', 'ProgramServicesAmt': '21245'}
#
#                             F9_09_PC_OTHER_SALARY_TOTAL  \
# 0  {'TotalAmt': '21245', 'ProgramServicesAmt': '21245'}
#
#   F9_09_PC_PAYMENT_TO_AFFILIATES F9_09_PC_PAYROLL_TAX_FUNDRAISE  \
# 0                            NaN                            NaN
#
#   F9_09_PC_PAYROLL_TAX_MGMT F9_09_PC_PAYROLL_TAX_PROG_SVCE  \
# 0                       NaN                            NaN
#
#   F9_09_PC_PAYROLL_TAX_TOTAL F9_09_PC_PENSION_CONT_FUNDRAISE  \
# 0                        NaN                             NaN
#
#   F9_09_PC_PENSION_CONT_MGMT F9_09_PC_PENSION_CONT_PROG_SVCE  \
# 0                        NaN                             NaN
#
#   F9_09_PC_PENSION_CONT_TOTAL  \
# 0                         NaN
#
#                                                                  F9_09_PC_TOTAL_FUNC_EXPENSES  \
# 0  {'TotalAmt': '269425', 'ProgramServicesAmt': '251862', 'ManagementAndGeneralAmt': '17563'}
#
#                                                              F9_09_PC_TOTAL_FUNDRAISE_EXPENSE  \
# 0  {'TotalAmt': '269425', 'ProgramServicesAmt': '251862', 'ManagementAndGeneralAmt': '17563'}
#
#                                                                   F9_09_PC_TOTAL_MGMT_EXPENSE  \
# 0  {'TotalAmt': '269425', 'ProgramServicesAmt': '251862', 'ManagementAndGeneralAmt': '17563'}
#
#                                                              F9_09_PC_TOTAL_PROG_SVCE_EXPENSE  \
# 0  {'TotalAmt': '269425', 'ProgramServicesAmt': '251862', 'ManagementAndGeneralAmt': '17563'}
#
#                F9_10_ASSETS_ACC_NET_EOY        F9_10_ASSETS_EXP_PREPAID_EOY  \
# 0  {'BOYAmt': '8765', 'EOYAmt': '6278'}  {'BOYAmt': '882', 'EOYAmt': '733'}
#
#   F9_10_ASSETS_INTANGIB_EOY          F9_10_ASSETS_INVENT_SALE_EOY  \
# 0                       NaN  {'BOYAmt': '1197', 'EOYAmt': '1197'}
#
#                F9_10_ASSETS_LESS_DEPREC_EOY F9_10_ASSETS_LOANS_DISQUAL_EOY  \
# 0  {'BOYAmt': '116555', 'EOYAmt': '109784'}                            NaN
#
#   F9_10_ASSETS_NOTES_LOANS_NET_EOY F9_10_ASSETS_OTH_EOY  \
# 0                              NaN                  NaN
#
#   F9_10_ASSETS_PLEDGES_NET_EOY              F9_10_LIAB_ACC_PAYABLE_EOY  \
# 0                          NaN  {'BOYAmt': '19368', 'EOYAmt': '11076'}
#
#   F9_10_LIAB_GRANTS_PAYABLE_EOY F9_10_LIAB_LOANS_OFF_EOY  \
# 0                           NaN                      NaN
#
#               F9_10_LIAB_REV_DEFERRED_EOY F9_10_NAFB_RESTRICT_PERM_EOY  \
# 0  {'BOYAmt': '22178', 'EOYAmt': '27194'}                          NaN
#
#   F9_10_NAFB_RESTRICT_TEMP_EOY F9_10_NAFB_UNRESTRICT_EOY  \
# 0                          NaN                       NaN
#
#   F9_10_PC_BOND_LIABILITY_EOY          F9_10_PC_CASH_NON_INTEREST_BOY  \
# 0                         NaN  {'BOYAmt': '74474', 'EOYAmt': '72904'}
#
#            F9_10_PC_CASH_NON_INTEREST_EOY F9_10_PC_ESCROW_LIABILITY_EOY  \
# 0  {'BOYAmt': '74474', 'EOYAmt': '72904'}                           NaN
#
#   F9_10_PC_INVEST_OTHER_SEC_EOY F9_10_PC_INVEST_PROG_RELTD_EOY  \
# 0                           NaN                            NaN
#
#              F9_10_PC_INVEST_PUB_TRADED_EOY F9_10_PC_LAND_BLDG_EQPMT  \
# 0  {'BOYAmt': '222927', 'EOYAmt': '233959'}                   165116
#
#   F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN F9_10_PC_LOANS_FROM_OFFICERS_EOY  \
# 0                            55332                              NaN
#
#   F9_10_PC_ORG_FOLLOWS_SFAS117 F9_10_PC_ORG_NOT_FOLLOW_SFAS117  \
# 0                          NaN                               1
#
#   F9_10_PC_OTHER_LIABILITIES_EOY          F9_10_PC_RET_EARNINGS_ENDWMT_EOY  \
# 0                            NaN  {'BOYAmt': '383254', 'EOYAmt': '386585'}
#
#   F9_10_PC_SAVINGS_TEMP_INVEST_BOY F9_10_PC_SAVINGS_TEMP_INVEST_EOY  \
# 0                              NaN                              NaN
#
#   F9_10_PC_SECURED_MORTGAGES_EOY F9_10_PC_SECURE_MORT_NOTES_EOY  \
# 0                            NaN                            NaN
#
#   F9_10_PC_UNSECURED_LOANS_EOY F9_10_PC_UNSECURED_NOTES_BOY  \
# 0                          NaN                          NaN
#
#   F9_10_PC_UNSECURED_NOTES_EOY                 F9_10_PZ_TOTAL_ASSETS_EOY  \
# 0                          NaN  {'BOYAmt': '424800', 'EOYAmt': '424855'}
#
#   F9_10_SCHED_O_X F9_11_PC_RECNCLTN_DONATED_SVCES  \
# 0             NaN                             NaN
#
#   F9_11_PC_RECNCLTN_INVSTMNT_EXP F9_11_PC_RECNCLTN_PRIOR_PER_ADJ  \
# 0                            NaN                             NaN
#
#   F9_11_PC_RECNCLTN_REV_LESS_EXP F9_11_PC_RECNCLTN_UNRLZD_GAIN  \
# 0                           3331                           NaN
#
#   F9_11_SCHED_O_X F9_12_PC_ACCNT_COMPILE_OR_REVIEW  \
# 0             NaN                                0
#
#   F9_12_PC_ACCTG_METHOD_ACCRUAL F9_12_PC_ACCTG_METHOD_CASH  \
# 0                             1                        NaN
#
#   F9_12_PC_ACCTG_METHOD_OTHER F9_12_PC_AUDIT_COMMITTEE  \
# 0                         NaN                      NaN
#
#   F9_12_PC_FED_GRNT_AUDIT_PERFORMD F9_12_PC_FED_GRNT_AUDIT_REQUIRED  \
# 0                              NaN                                0
#
#   F9_12_PC_FINCL_STMTS_AUDITED F9_12_SCHED_O_X number_of_other_prog_svces  \
# 0                            0             NaN                        NaN
#
#    501c3
# 0      0

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df = pd.read_feather('D:/all_filings_april_2025_all_controls_combined.feather')
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
df[:1]
# Out:
# Current date and time :  2025-04-17 16:09:15

# %%
df.dtypes
# Out:
# _id                                 object
# OrganizationName                    object
# URL                                 object
# DLN                                 object
# TaxPeriod                           object
#                                      ...
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED     int64
# F9_12_PC_FINCL_STMTS_AUDITED         int64
# F9_12_SCHED_O_X                      int64
# number_of_other_prog_svces          object
# 501c3                                int32
# Length: 300, dtype: object

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3469008 entries, 0 to 3469007
# Data columns (total 300 columns):
#  #    Column                              Dtype
# ---   ------                              -----
#  0    _id                                 object
#  1    OrganizationName                    object
#  2    URL                                 object
#  3    DLN                                 object
#  4    TaxPeriod                           object
#  5    F9_09_PC_FEES_FOR_SVCE_FR_TOT       object
#  6    F9_00_HD_BUILD_TIME_STAMP           object
#  7    fiscal_year                         object
#  8    EIN                                 object
#  9    Name                                object
#  10   NameControl                         object
#  11   Phone                               object
#  12   USAddress                           object
#  13   ForeignAddress                      object
#  14   InCareOfName                        object
#  15   BusinessName                        object
#  16   BusinessNameControlTxt              object
#  17   PhoneNum                            object
#  18   InCareOfNm                          object
#  19   ForeignPhoneNum                     object
#  20   F9_00_HD_ADDR_CHANGE                int64
#  21   F9_00_HD_AMENDED_RETURN             int64
#  22   F9_00_HD_CTRY_OF_DOMICILE           object
#  23   F9_00_HD_EXEMPT_STATUS_4847A1       int64
#  24   F9_00_HD_EXEMPT_STATUS_501C         object
#  25   F9_00_HD_EXEMPT_STATUS_501C3        int64
#  26   F9_00_HD_FINAL_RETURN               int64
#  27   F9_00_HD_GROSS_EXEMPT_NUM           object
#  28   F9_00_HD_GROSS_RCPT                 object
#  29   F9_00_HD_GROUP_RETURN               int64
#  30   F9_00_HD_INCLUDES_SUBORD_ORGS       int64
#  31   F9_00_HD_INITIAL_RETURN             int64
#  32   F9_00_HD_PRIN_OFF_NAME              object
#  33   F9_00_HD_SIGNING_OFFICER_SIGNTR     object
#  34   F9_00_HD_SPECIAL_CONDITION_DESC     object
#  35   F9_00_HD_STATE_OF_DOMICILE          object
#  36   F9_00_HD_TAX_PER_BEGIN              object
#  37   F9_00_HD_TAX_PER_END                object
#  38   F9_00_HD_TAX_YEAR                   object
#  39   F9_00_HD_TIME_STAMP                 object
#  40   F9_00_HD_TYPE_ORG_ASSOCIATION       int64
#  41   F9_00_HD_TYPE_ORG_CORP              int64
#  42   F9_00_HD_TYPE_ORG_OTHER             int64
#  43   F9_00_HD_TYPE_ORG_OTHER_DESC        object
#  44   F9_00_HD_TYPE_ORG_TRUST             int64
#  45   F9_00_HD_WEBSITE                    object
#  46   F9_00_HD_YEAR_FORMED                object
#  47   F9_01_PC_BEN_PAID_MEMB_PRIOR        object
#  48   F9_01_PC_CONTR_GRANTS_CURR          object
#  49   F9_01_PC_CONTR_GRANTS_PRIOR         object
#  50   F9_01_PC_GRANTS_PRIOR               object
#  51   F9_01_PC_INDEP_VOTING_MEMB          object
#  52   F9_01_PC_INVEST_INCOME_PRIOR        object
#  53   F9_01_PC_NET_ASSETS_BOY             object
#  54   F9_01_PC_OTHER_EXPENSE_PRIOR        object
#  55   F9_01_PC_OTHER_REV_PRIOR            object
#  56   F9_01_PC_PROF_FUNDRISING_EXP_CURR   object
#  57   F9_01_PC_PROF_FUNDRISING_EXP_PRIOR  object
#  58   F9_01_PC_PROG_SERVICE_REV_PRIOR     object
#  59   F9_01_PC_REV_LESS_EXP_CURR          object
#  60   F9_01_PC_REV_LESS_EXP_PRIOR         object
#  61   F9_01_PC_TERMINATION_CONTRACTION    int64
#  62   F9_01_PC_TOT_ASSETS_EOY             object
#  63   F9_01_PC_TOT_EXP_PRIOR              object
#  64   F9_01_PC_TOT_FNDR_EXP_CURR          object
#  65   F9_01_PC_TOT_INDIV_EMPLOYED         object
#  66   F9_01_PC_TOT_INDIV_VOLUNTEERS       object
#  67   F9_01_PC_TOT_LIABILITIES_EOY        object
#  68   F9_01_PC_TOT_REVENUE_PRIOR          object
#  69   F9_01_PC_TOT_UBI_GROSS              object
#  70   F9_01_PC_TOT_UBI_NET                object
#  71   F9_01_PC_VOTING_MEMB_GOV_BODY       object
#  72   F9_01_PZ_BEN_PAID_TO_MEMB_CURR      object
#  73   F9_01_PZ_GRANTS_PAID_CURR           object
#  74   F9_01_PZ_INVEST_INCOME_CURR         object
#  75   F9_01_PZ_NAFB_EOY                   object
#  76   F9_01_PZ_ORGANIZATIONAL_MISSION     object
#  77   F9_01_PZ_OTHER_EXPENSE_CURR         object
#  78   F9_01_PZ_OTHER_REV_CURR             object
#  79   F9_01_PZ_PROG_SERVICE_REV_CURR      object
#  80   F9_01_PZ_SALARIES_CURR              object
#  81   F9_01_PZ_SALARIES_PRIOR             object
#  82   F9_01_PZ_TOT_ASSETS_BOY             object
#  83   F9_01_PZ_TOT_EXP_CURR               object
#  84   F9_01_PZ_TOT_LIAB_BOY               object
#  85   F9_01_PZ_TOT_REV_CURR               object
#  86   F9_03_PC_PGMSVC_SIGNIF_CHG          int64
#  87   F9_03_PC_PGMSVC_SIGNIF_NEW          int64
#  88   F9_03_PC_PROG_SVC_ACC_1_CODE        object
#  89   F9_03_PC_PROG_SVC_ACC_1_DESC        object
#  90   F9_03_PC_PROG_SVC_ACC_1_EXP         object
#  91   F9_03_PC_PROG_SVC_ACC_1_GRNT        object
#  92   F9_03_PC_PROG_SVC_ACC_1_REV         object
#  93   F9_03_PC_PROG_SVC_ACC_2_CODE        object
#  94   F9_03_PC_PROG_SVC_ACC_2_DESC        object
#  95   F9_03_PC_PROG_SVC_ACC_2_EXP         object
#  96   F9_03_PC_PROG_SVC_ACC_2_GRNT        object
#  97   F9_03_PC_PROG_SVC_ACC_2_REV         object
#  98   F9_03_PC_PROG_SVC_ACC_3_CODE        object
#  99   F9_03_PC_PROG_SVC_ACC_3_DESC        object
#  100  F9_03_PC_PROG_SVC_ACC_3_EXP         object
#  101  F9_03_PC_PROG_SVC_ACC_3_GRNT        object
#  102  F9_03_PC_PROG_SVC_ACC_3_REV         object
#  103  F9_03_PC_TOT_OTH_PROG_SVC_EXP       object
#  104  F9_03_PC_TOT_OTH_PROG_SVC_GRNT      object
#  105  F9_03_PC_TOT_OTH_PROG_SVC_REV       object
#  106  F9_03_PC_TOT_PROG_SVC_EXPENSE       object
#  107  F9_03_PZ_MISSION_DESCRIPTION        object
#  108  F9_03_PZ_SCHEDULE_O_PART3           int64
#  109  F9_04_PC_ACTVITIES_VIA_PARTNER      int64
#  110  F9_04_PC_CONTROLLED_ENTITY          int64
#  111  F9_04_PC_DISREGARDED_ENTITY         int64
#  112  F9_04_PC_EXCESS_BENEFIT_TRANS       int64
#  113  F9_04_PC_FR_EVENT_INC_GT_15K        int64
#  114  F9_04_PC_GAMING_INC_GT_15K          int64
#  115  F9_04_PC_LOBBYING_ACTIVITIES        int64
#  116  F9_04_PC_POLITICAL_ACTIVITIES       int64
#  117  F9_04_PC_PRIOR_EXCESS_BEN_TRAN      int64
#  118  F9_04_PC_PROF_FR_EXP_GT_15K         int64
#  119  F9_04_PC_RELATED_ENTITY             int64
#  120  F9_04_PC_TRANS_TO_CNTRLD_ENT        int64
#  121  F9_04_PC_TRANS_WITH_CNTRLD_ENT      int64
#  122  F9_05_EXP_SCHED_O_X                 int64
#  123  F9_05_PC_NUMBER_EMPLOYEES_W3        object
#  124  F9_05_PC_NUMBER_FORMS_1096          object
#  125  F9_05_PC_UNRELATED_BUS_INCOME       int64
#  126  F9_06_EXP_SCHED_O_X                 int64
#  127  F9_06_PC_990_PROVIDED_GOV_BODY      int64
#  128  F9_06_PC_ANNUAL_DISC_COVRD_PERS     int64
#  129  F9_06_PC_CEO_COMPENSTN_PROCESS      int64
#  130  F9_06_PC_CHANGES_ORGANIZING_DOCS    int64
#  131  F9_06_PC_CONFLICT_OF_INTEREST       int64
#  132  F9_06_PC_DECISIONS_SUBJ_APPROVAL    int64
#  133  F9_06_PC_DELEGATION_MGT_DUTIES      int64
#  134  F9_06_PC_DELEGATION_OF_MGT          int64
#  135  F9_06_PC_DOCUMENT_RET_POLICY        int64
#  136  F9_06_PC_ELECTION_BOARD_MEMBERS     int64
#  137  F9_06_PC_FAMILY_OR_BUSINESS_REL     int64
#  138  F9_06_PC_FORM_AVAIL_OWN_WEBSITE     int64
#  139  F9_06_PC_FORM_UPON_REQUEST          int64
#  140  F9_06_PC_JOINT_VENTURE_INVESTMNT    int64
#  141  F9_06_PC_JOINT_VENTURE_POLICY       int64
#  142  F9_06_PC_LOCAL_CHAPTERS             int64
#  143  F9_06_PC_MATERIAL_DIVERSION         int64
#  144  F9_06_PC_MEMBERS_OR_STOCKHOLDERS    int64
#  145  F9_06_PC_MINUTES_COMMITTEES         int64
#  146  F9_06_PC_MINUTES_GOVERNING_BODY     int64
#  147  F9_06_PC_MONITORING_OF_COI_POLICY   int64
#  148  F9_06_PC_NUM_IND_VOTING_MEMBERS     object
#  149  F9_06_PC_NUM_VOTING_GOV_MEMBERS     object
#  150  F9_06_PC_OFFICER_MAILING_ADDRESS    int64
#  151  F9_06_PC_OTHER_COMPENSTN_PROCESS    int64
#  152  F9_06_PC_OTHER_WEBSITE              int64
#  153  F9_06_PC_OWN_WEBSITE                int64
#  154  F9_06_PC_POLICIES_GOVERN_CHAPTER    int64
#  155  F9_06_PC_STATES_WHERE_RET_FILED     object
#  156  F9_06_PC_WHISTLEBLOWER_POLICY       int64
#  157  F9_07_EXP_SCHED_O_X                 int64
#  158  F9_07_PC_COMPENSATION_OTHER_SRCE    int64
#  159  F9_07_PC_FORMER_OFFICER_LISTED      int64
#  160  F9_07_PC_NO_LISTED_PERS_COMPENSD    int64
#  161  F9_07_PC_NUM_CONTRCTRS_GRTR_100K    object
#  162  F9_07_PC_NUM_INDS_GREATER_100K      object
#  163  F9_07_PC_TOTAL_COMP_GRTR_150K       int64
#  164  F9_07_PC_TOT_OTHER_COMPENSATION     object
#  165  F9_07_PC_TOT_REPRT_COMP_FROM_ORG    object
#  166  F9_07_PC_TOT_REPRT_COMP_RLTD_ORG    object
#  167  F9_08_EXP_SCHED_O_X                 int64
#  168  F9_08_PC_ALL_OTHER_CONTRIBUTIONS    object
#  169  F9_08_PC_CONTS_REPRTD_FNDRAISNG     object
#  170  F9_08_PC_COST_OF_GOODS_SOLD         object
#  171  F9_08_PC_FEDERATED_CAMPAIGNS        object
#  172  F9_08_PC_FUNDRAISING_DIRECT_EXP     object
#  173  F9_08_PC_FUNDRAISING_EVENTS         object
#  174  F9_08_PC_FUNDRAISING_GROSS_INC      object
#  175  F9_08_PC_GAMING_DIRECT_EXPENSES     object
#  176  F9_08_PC_GAMING_GROSS_INCOME        object
#  177  F9_08_PC_GOVERNMENT_GRANTS          object
#  178  F9_08_PC_GROSS_SALES_INVENTORY      object
#  179  F9_08_PC_MEMBERSHIP_DUES            object
#  180  F9_08_PC_NONCASH_CONTRIBUTIONS      object
#  181  F9_08_PC_PROGRAM_SVCE_REV_TOTAL     object
#  182  F9_08_PC_RELATED_ORGANIZATIONS      object
#  183  F9_08_PC_TOTAL_CONTRIBUTIONS        object
#  184  F9_08_PC_TOTAL_OTHER_REVENUE        object
#  185  F9_08_PC_TOTAL_PROG_SVCE_REVENUE    object
#  186  F9_08_PC_TOTAL_REVENUE              object
#  187  F9_09_EXP_AD_PROMO_TOT              object
#  188  F9_09_EXP_BENF_PAID_MEMB_TOT        object
#  189  F9_09_EXP_CONF_MEETING_TOT          object
#  190  F9_09_EXP_DEPREC_FUNDR              object
#  191  F9_09_EXP_DEPREC_MAG                object
#  192  F9_09_EXP_DEPREC_PROG               object
#  193  F9_09_EXP_DEPREC_TOT                object
#  194  F9_09_EXP_GRANT_FRGN_TOT            object
#  195  F9_09_EXP_GRANT_INDIV_DMSTC_TOT     object
#  196  F9_09_EXP_GRANT_ORG_DMSTC_TOT       object
#  197  F9_09_EXP_INFO_TECH_TOT             object
#  198  F9_09_EXP_INSURANCE_TOT             object
#  199  F9_09_EXP_INTEREST_TOT              object
#  200  F9_09_EXP_JOINT_COSTS_TOT           object
#  201  F9_09_EXP_OCCUPANCY_TOT             object
#  202  F9_09_EXP_OFFICE_TOT                object
#  203  F9_09_EXP_OTH_OTH_TOT               object
#  204  F9_09_EXP_OTH_TOT                   object
#  205  F9_09_EXP_ROY_TOT                   object
#  206  F9_09_EXP_SCHED_O_X                 int64
#  207  F9_09_EXP_TRAVEL_ENTRTNMNT_TOT      object
#  208  F9_09_EXP_TRAVEL_TOT                object
#  209  F9_09_PC_COMP_DISQUAL_FUNDRAISE     object
#  210  F9_09_PC_COMP_DISQUAL_MGMT          object
#  211  F9_09_PC_COMP_DISQUAL_PROG_SVCE     object
#  212  F9_09_PC_COMP_DISQUAL_TOTAL         object
#  213  F9_09_PC_COMP_OFFICERS_FUNDRAISE    object
#  214  F9_09_PC_COMP_OFFICERS_MGMT         object
#  215  F9_09_PC_COMP_OFFICERS_PROG_SVCE    object
#  216  F9_09_PC_COMP_OFFICERS_TOTAL        object
#  217  F9_09_PC_FEES_FOR_SVCE_ACCT_TOT     object
#  218  F9_09_PC_FEES_FOR_SVCE_INVST_TOT    object
#  219  F9_09_PC_FEES_FOR_SVCE_LEGL_TOT     object
#  220  F9_09_PC_FEES_FOR_SVCE_LOBB_TOT     object
#  221  F9_09_PC_FEES_FOR_SVCE_MGMT_TOT     object
#  222  F9_09_PC_FEES_FOR_SVCE_OTH_TOT      object
#  223  F9_09_PC_OTHER_EMP_BEN_FUNDRAISE    object
#  224  F9_09_PC_OTHER_EMP_BEN_MGMT         object
#  225  F9_09_PC_OTHER_EMP_BEN_PROG_SVCE    object
#  226  F9_09_PC_OTHER_EMP_BEN_TOTAL        object
#  227  F9_09_PC_OTHER_SALARY_FUNDRAISE     object
#  228  F9_09_PC_OTHER_SALARY_MGMT          object
#  229  F9_09_PC_OTHER_SALARY_PROG_SVCE     object
#  230  F9_09_PC_OTHER_SALARY_TOTAL         object
#  231  F9_09_PC_PAYMENT_TO_AFFILIATES      object
#  232  F9_09_PC_PAYROLL_TAX_FUNDRAISE      object
#  233  F9_09_PC_PAYROLL_TAX_MGMT           object
#  234  F9_09_PC_PAYROLL_TAX_PROG_SVCE      object
#  235  F9_09_PC_PAYROLL_TAX_TOTAL          object
#  236  F9_09_PC_PENSION_CONT_FUNDRAISE     object
#  237  F9_09_PC_PENSION_CONT_MGMT          object
#  238  F9_09_PC_PENSION_CONT_PROG_SVCE     object
#  239  F9_09_PC_PENSION_CONT_TOTAL         object
#  240  F9_09_PC_TOTAL_FUNC_EXPENSES        object
#  241  F9_09_PC_TOTAL_FUNDRAISE_EXPENSE    object
#  242  F9_09_PC_TOTAL_MGMT_EXPENSE         object
#  243  F9_09_PC_TOTAL_PROG_SVCE_EXPENSE    object
#  244  F9_10_ASSETS_ACC_NET_EOY            object
#  245  F9_10_ASSETS_EXP_PREPAID_EOY        object
#  246  F9_10_ASSETS_INTANGIB_EOY           object
#  247  F9_10_ASSETS_INVENT_SALE_EOY        object
#  248  F9_10_ASSETS_LESS_DEPREC_EOY        object
#  249  F9_10_ASSETS_LOANS_DISQUAL_EOY      object
#  250  F9_10_ASSETS_NOTES_LOANS_NET_EOY    object
#  251  F9_10_ASSETS_OTH_EOY                object
#  252  F9_10_ASSETS_PLEDGES_NET_EOY        object
#  253  F9_10_LIAB_ACC_PAYABLE_EOY          object
#  254  F9_10_LIAB_GRANTS_PAYABLE_EOY       object
#  255  F9_10_LIAB_LOANS_OFF_EOY            object
#  256  F9_10_LIAB_REV_DEFERRED_EOY         object
#  257  F9_10_NAFB_RESTRICT_PERM_EOY        object
#  258  F9_10_NAFB_RESTRICT_TEMP_EOY        object
#  259  F9_10_NAFB_UNRESTRICT_EOY           object
#  260  F9_10_PC_BOND_LIABILITY_EOY         object
#  261  F9_10_PC_CASH_NON_INTEREST_BOY      object
#  262  F9_10_PC_CASH_NON_INTEREST_EOY      object
#  263  F9_10_PC_ESCROW_LIABILITY_EOY       object
#  264  F9_10_PC_INVEST_OTHER_SEC_EOY       object
#  265  F9_10_PC_INVEST_PROG_RELTD_EOY      object
#  266  F9_10_PC_INVEST_PUB_TRADED_EOY      object
#  267  F9_10_PC_LAND_BLDG_EQPMT            object
#  268  F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN    object
#  269  F9_10_PC_LOANS_FROM_OFFICERS_EOY    object
#  270  F9_10_PC_ORG_FOLLOWS_SFAS117        int64
#  271  F9_10_PC_ORG_NOT_FOLLOW_SFAS117     int64
#  272  F9_10_PC_OTHER_LIABILITIES_EOY      object
#  273  F9_10_PC_RET_EARNINGS_ENDWMT_EOY    object
#  274  F9_10_PC_SAVINGS_TEMP_INVEST_BOY    object
#  275  F9_10_PC_SAVINGS_TEMP_INVEST_EOY    object
#  276  F9_10_PC_SECURED_MORTGAGES_EOY      object
#  277  F9_10_PC_SECURE_MORT_NOTES_EOY      object
#  278  F9_10_PC_UNSECURED_LOANS_EOY        object
#  279  F9_10_PC_UNSECURED_NOTES_BOY        object
#  280  F9_10_PC_UNSECURED_NOTES_EOY        object
#  281  F9_10_PZ_TOTAL_ASSETS_EOY           object
#  282  F9_10_SCHED_O_X                     int64
#  283  F9_11_PC_RECNCLTN_DONATED_SVCES     object
#  284  F9_11_PC_RECNCLTN_INVSTMNT_EXP      object
#  285  F9_11_PC_RECNCLTN_PRIOR_PER_ADJ     object
#  286  F9_11_PC_RECNCLTN_REV_LESS_EXP      object
#  287  F9_11_PC_RECNCLTN_UNRLZD_GAIN       object
#  288  F9_11_SCHED_O_X                     int64
#  289  F9_12_PC_ACCNT_COMPILE_OR_REVIEW    int64
#  290  F9_12_PC_ACCTG_METHOD_ACCRUAL       int64
#  291  F9_12_PC_ACCTG_METHOD_CASH          int64
#  292  F9_12_PC_ACCTG_METHOD_OTHER         object
#  293  F9_12_PC_AUDIT_COMMITTEE            int64
#  294  F9_12_PC_FED_GRNT_AUDIT_PERFORMD    int64
#  295  F9_12_PC_FED_GRNT_AUDIT_REQUIRED    int64
#  296  F9_12_PC_FINCL_STMTS_AUDITED        int64
#  297  F9_12_SCHED_O_X                     int64
#  298  number_of_other_prog_svces          object
#  299  501c3                               int32
# dtypes: int32(1), int64(78), object(221)
# memory usage: 7.7+ GB

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3469008 entries, 0 to 3469007
# Data columns (total 300 columns):
#  #    Column                              Dtype
# ---   ------                              -----
#  0    _id                                 object
#  1    OrganizationName                    object
#  2    URL                                 object
#  3    DLN                                 object
#  4    TaxPeriod                           object
#  5    F9_09_PC_FEES_FOR_SVCE_FR_TOT       object
#  6    F9_00_HD_BUILD_TIME_STAMP           object
#  7    fiscal_year                         object
#  8    EIN                                 object
#  9    Name                                object
#  10   NameControl                         object
#  11   Phone                               object
#  12   USAddress                           object
#  13   ForeignAddress                      object
#  14   InCareOfName                        object
#  15   BusinessName                        object
#  16   BusinessNameControlTxt              object
#  17   PhoneNum                            object
#  18   InCareOfNm                          object
#  19   ForeignPhoneNum                     object
#  20   F9_00_HD_ADDR_CHANGE                int64
#  21   F9_00_HD_AMENDED_RETURN             int64
#  22   F9_00_HD_CTRY_OF_DOMICILE           object
#  23   F9_00_HD_EXEMPT_STATUS_4847A1       int64
#  24   F9_00_HD_EXEMPT_STATUS_501C         object
#  25   F9_00_HD_EXEMPT_STATUS_501C3        int64
#  26   F9_00_HD_FINAL_RETURN               int64
#  27   F9_00_HD_GROSS_EXEMPT_NUM           object
#  28   F9_00_HD_GROSS_RCPT                 object
#  29   F9_00_HD_GROUP_RETURN               int64
#  30   F9_00_HD_INCLUDES_SUBORD_ORGS       int64
#  31   F9_00_HD_INITIAL_RETURN             int64
#  32   F9_00_HD_PRIN_OFF_NAME              object
#  33   F9_00_HD_SIGNING_OFFICER_SIGNTR     object
#  34   F9_00_HD_SPECIAL_CONDITION_DESC     object
#  35   F9_00_HD_STATE_OF_DOMICILE          object
#  36   F9_00_HD_TAX_PER_BEGIN              object
#  37   F9_00_HD_TAX_PER_END                object
#  38   F9_00_HD_TAX_YEAR                   object
#  39   F9_00_HD_TIME_STAMP                 object
#  40   F9_00_HD_TYPE_ORG_ASSOCIATION       int64
#  41   F9_00_HD_TYPE_ORG_CORP              int64
#  42   F9_00_HD_TYPE_ORG_OTHER             int64
#  43   F9_00_HD_TYPE_ORG_OTHER_DESC        object
#  44   F9_00_HD_TYPE_ORG_TRUST             int64
#  45   F9_00_HD_WEBSITE                    object
#  46   F9_00_HD_YEAR_FORMED                object
#  47   F9_01_PC_BEN_PAID_MEMB_PRIOR        object
#  48   F9_01_PC_CONTR_GRANTS_CURR          object
#  49   F9_01_PC_CONTR_GRANTS_PRIOR         object
#  50   F9_01_PC_GRANTS_PRIOR               object
#  51   F9_01_PC_INDEP_VOTING_MEMB          object
#  52   F9_01_PC_INVEST_INCOME_PRIOR        object
#  53   F9_01_PC_NET_ASSETS_BOY             object
#  54   F9_01_PC_OTHER_EXPENSE_PRIOR        object
#  55   F9_01_PC_OTHER_REV_PRIOR            object
#  56   F9_01_PC_PROF_FUNDRISING_EXP_CURR   object
#  57   F9_01_PC_PROF_FUNDRISING_EXP_PRIOR  object
#  58   F9_01_PC_PROG_SERVICE_REV_PRIOR     object
#  59   F9_01_PC_REV_LESS_EXP_CURR          object
#  60   F9_01_PC_REV_LESS_EXP_PRIOR         object
#  61   F9_01_PC_TERMINATION_CONTRACTION    int64
#  62   F9_01_PC_TOT_ASSETS_EOY             object
#  63   F9_01_PC_TOT_EXP_PRIOR              object
#  64   F9_01_PC_TOT_FNDR_EXP_CURR          object
#  65   F9_01_PC_TOT_INDIV_EMPLOYED         object
#  66   F9_01_PC_TOT_INDIV_VOLUNTEERS       object
#  67   F9_01_PC_TOT_LIABILITIES_EOY        object
#  68   F9_01_PC_TOT_REVENUE_PRIOR          object
#  69   F9_01_PC_TOT_UBI_GROSS              object
#  70   F9_01_PC_TOT_UBI_NET                object
#  71   F9_01_PC_VOTING_MEMB_GOV_BODY       object
#  72   F9_01_PZ_BEN_PAID_TO_MEMB_CURR      object
#  73   F9_01_PZ_GRANTS_PAID_CURR           object
#  74   F9_01_PZ_INVEST_INCOME_CURR         object
#  75   F9_01_PZ_NAFB_EOY                   object
#  76   F9_01_PZ_ORGANIZATIONAL_MISSION     object
#  77   F9_01_PZ_OTHER_EXPENSE_CURR         object
#  78   F9_01_PZ_OTHER_REV_CURR             object
#  79   F9_01_PZ_PROG_SERVICE_REV_CURR      object
#  80   F9_01_PZ_SALARIES_CURR              object
#  81   F9_01_PZ_SALARIES_PRIOR             object
#  82   F9_01_PZ_TOT_ASSETS_BOY             object
#  83   F9_01_PZ_TOT_EXP_CURR               object
#  84   F9_01_PZ_TOT_LIAB_BOY               object
#  85   F9_01_PZ_TOT_REV_CURR               object
#  86   F9_03_PC_PGMSVC_SIGNIF_CHG          int64
#  87   F9_03_PC_PGMSVC_SIGNIF_NEW          int64
#  88   F9_03_PC_PROG_SVC_ACC_1_CODE        object
#  89   F9_03_PC_PROG_SVC_ACC_1_DESC        object
#  90   F9_03_PC_PROG_SVC_ACC_1_EXP         object
#  91   F9_03_PC_PROG_SVC_ACC_1_GRNT        object
#  92   F9_03_PC_PROG_SVC_ACC_1_REV         object
#  93   F9_03_PC_PROG_SVC_ACC_2_CODE        object
#  94   F9_03_PC_PROG_SVC_ACC_2_DESC        object
#  95   F9_03_PC_PROG_SVC_ACC_2_EXP         object
#  96   F9_03_PC_PROG_SVC_ACC_2_GRNT        object
#  97   F9_03_PC_PROG_SVC_ACC_2_REV         object
#  98   F9_03_PC_PROG_SVC_ACC_3_CODE        object
#  99   F9_03_PC_PROG_SVC_ACC_3_DESC        object
#  100  F9_03_PC_PROG_SVC_ACC_3_EXP         object
#  101  F9_03_PC_PROG_SVC_ACC_3_GRNT        object
#  102  F9_03_PC_PROG_SVC_ACC_3_REV         object
#  103  F9_03_PC_TOT_OTH_PROG_SVC_EXP       object
#  104  F9_03_PC_TOT_OTH_PROG_SVC_GRNT      object
#  105  F9_03_PC_TOT_OTH_PROG_SVC_REV       object
#  106  F9_03_PC_TOT_PROG_SVC_EXPENSE       object
#  107  F9_03_PZ_MISSION_DESCRIPTION        object
#  108  F9_03_PZ_SCHEDULE_O_PART3           int64
#  109  F9_04_PC_ACTVITIES_VIA_PARTNER      int64
#  110  F9_04_PC_CONTROLLED_ENTITY          int64
#  111  F9_04_PC_DISREGARDED_ENTITY         int64
#  112  F9_04_PC_EXCESS_BENEFIT_TRANS       int64
#  113  F9_04_PC_FR_EVENT_INC_GT_15K        int64
#  114  F9_04_PC_GAMING_INC_GT_15K          int64
#  115  F9_04_PC_LOBBYING_ACTIVITIES        int64
#  116  F9_04_PC_POLITICAL_ACTIVITIES       int64
#  117  F9_04_PC_PRIOR_EXCESS_BEN_TRAN      int64
#  118  F9_04_PC_PROF_FR_EXP_GT_15K         int64
#  119  F9_04_PC_RELATED_ENTITY             int64
#  120  F9_04_PC_TRANS_TO_CNTRLD_ENT        int64
#  121  F9_04_PC_TRANS_WITH_CNTRLD_ENT      int64
#  122  F9_05_EXP_SCHED_O_X                 int64
#  123  F9_05_PC_NUMBER_EMPLOYEES_W3        object
#  124  F9_05_PC_NUMBER_FORMS_1096          object
#  125  F9_05_PC_UNRELATED_BUS_INCOME       int64
#  126  F9_06_EXP_SCHED_O_X                 int64
#  127  F9_06_PC_990_PROVIDED_GOV_BODY      int64
#  128  F9_06_PC_ANNUAL_DISC_COVRD_PERS     int64
#  129  F9_06_PC_CEO_COMPENSTN_PROCESS      int64
#  130  F9_06_PC_CHANGES_ORGANIZING_DOCS    int64
#  131  F9_06_PC_CONFLICT_OF_INTEREST       int64
#  132  F9_06_PC_DECISIONS_SUBJ_APPROVAL    int64
#  133  F9_06_PC_DELEGATION_MGT_DUTIES      int64
#  134  F9_06_PC_DELEGATION_OF_MGT          int64
#  135  F9_06_PC_DOCUMENT_RET_POLICY        int64
#  136  F9_06_PC_ELECTION_BOARD_MEMBERS     int64
#  137  F9_06_PC_FAMILY_OR_BUSINESS_REL     int64
#  138  F9_06_PC_FORM_AVAIL_OWN_WEBSITE     int64
#  139  F9_06_PC_FORM_UPON_REQUEST          int64
#  140  F9_06_PC_JOINT_VENTURE_INVESTMNT    int64
#  141  F9_06_PC_JOINT_VENTURE_POLICY       int64
#  142  F9_06_PC_LOCAL_CHAPTERS             int64
#  143  F9_06_PC_MATERIAL_DIVERSION         int64
#  144  F9_06_PC_MEMBERS_OR_STOCKHOLDERS    int64
#  145  F9_06_PC_MINUTES_COMMITTEES         int64
#  146  F9_06_PC_MINUTES_GOVERNING_BODY     int64
#  147  F9_06_PC_MONITORING_OF_COI_POLICY   int64
#  148  F9_06_PC_NUM_IND_VOTING_MEMBERS     object
#  149  F9_06_PC_NUM_VOTING_GOV_MEMBERS     object
#  150  F9_06_PC_OFFICER_MAILING_ADDRESS    int64
#  151  F9_06_PC_OTHER_COMPENSTN_PROCESS    int64
#  152  F9_06_PC_OTHER_WEBSITE              int64
#  153  F9_06_PC_OWN_WEBSITE                int64
#  154  F9_06_PC_POLICIES_GOVERN_CHAPTER    int64
#  155  F9_06_PC_STATES_WHERE_RET_FILED     object
#  156  F9_06_PC_WHISTLEBLOWER_POLICY       int64
#  157  F9_07_EXP_SCHED_O_X                 int64
#  158  F9_07_PC_COMPENSATION_OTHER_SRCE    int64
#  159  F9_07_PC_FORMER_OFFICER_LISTED      int64
#  160  F9_07_PC_NO_LISTED_PERS_COMPENSD    int64
#  161  F9_07_PC_NUM_CONTRCTRS_GRTR_100K    object
#  162  F9_07_PC_NUM_INDS_GREATER_100K      object
#  163  F9_07_PC_TOTAL_COMP_GRTR_150K       int64
#  164  F9_07_PC_TOT_OTHER_COMPENSATION     object
#  165  F9_07_PC_TOT_REPRT_COMP_FROM_ORG    object
#  166  F9_07_PC_TOT_REPRT_COMP_RLTD_ORG    object
#  167  F9_08_EXP_SCHED_O_X                 int64
#  168  F9_08_PC_ALL_OTHER_CONTRIBUTIONS    object
#  169  F9_08_PC_CONTS_REPRTD_FNDRAISNG     object
#  170  F9_08_PC_COST_OF_GOODS_SOLD         object
#  171  F9_08_PC_FEDERATED_CAMPAIGNS        object
#  172  F9_08_PC_FUNDRAISING_DIRECT_EXP     object
#  173  F9_08_PC_FUNDRAISING_EVENTS         object
#  174  F9_08_PC_FUNDRAISING_GROSS_INC      object
#  175  F9_08_PC_GAMING_DIRECT_EXPENSES     object
#  176  F9_08_PC_GAMING_GROSS_INCOME        object
#  177  F9_08_PC_GOVERNMENT_GRANTS          object
#  178  F9_08_PC_GROSS_SALES_INVENTORY      object
#  179  F9_08_PC_MEMBERSHIP_DUES            object
#  180  F9_08_PC_NONCASH_CONTRIBUTIONS      object
#  181  F9_08_PC_PROGRAM_SVCE_REV_TOTAL     object
#  182  F9_08_PC_RELATED_ORGANIZATIONS      object
#  183  F9_08_PC_TOTAL_CONTRIBUTIONS        object
#  184  F9_08_PC_TOTAL_OTHER_REVENUE        object
#  185  F9_08_PC_TOTAL_PROG_SVCE_REVENUE    object
#  186  F9_08_PC_TOTAL_REVENUE              object
#  187  F9_09_EXP_AD_PROMO_TOT              object
#  188  F9_09_EXP_BENF_PAID_MEMB_TOT        object
#  189  F9_09_EXP_CONF_MEETING_TOT          object
#  190  F9_09_EXP_DEPREC_FUNDR              object
#  191  F9_09_EXP_DEPREC_MAG                object
#  192  F9_09_EXP_DEPREC_PROG               object
#  193  F9_09_EXP_DEPREC_TOT                object
#  194  F9_09_EXP_GRANT_FRGN_TOT            object
#  195  F9_09_EXP_GRANT_INDIV_DMSTC_TOT     object
#  196  F9_09_EXP_GRANT_ORG_DMSTC_TOT       object
#  197  F9_09_EXP_INFO_TECH_TOT             object
#  198  F9_09_EXP_INSURANCE_TOT             object
#  199  F9_09_EXP_INTEREST_TOT              object
#  200  F9_09_EXP_JOINT_COSTS_TOT           object
#  201  F9_09_EXP_OCCUPANCY_TOT             object
#  202  F9_09_EXP_OFFICE_TOT                object
#  203  F9_09_EXP_OTH_OTH_TOT               object
#  204  F9_09_EXP_OTH_TOT                   object
#  205  F9_09_EXP_ROY_TOT                   object
#  206  F9_09_EXP_SCHED_O_X                 int64
#  207  F9_09_EXP_TRAVEL_ENTRTNMNT_TOT      object
#  208  F9_09_EXP_TRAVEL_TOT                object
#  209  F9_09_PC_COMP_DISQUAL_FUNDRAISE     object
#  210  F9_09_PC_COMP_DISQUAL_MGMT          object
#  211  F9_09_PC_COMP_DISQUAL_PROG_SVCE     object
#  212  F9_09_PC_COMP_DISQUAL_TOTAL         object
#  213  F9_09_PC_COMP_OFFICERS_FUNDRAISE    object
#  214  F9_09_PC_COMP_OFFICERS_MGMT         object
#  215  F9_09_PC_COMP_OFFICERS_PROG_SVCE    object
#  216  F9_09_PC_COMP_OFFICERS_TOTAL        object
#  217  F9_09_PC_FEES_FOR_SVCE_ACCT_TOT     object
#  218  F9_09_PC_FEES_FOR_SVCE_INVST_TOT    object
#  219  F9_09_PC_FEES_FOR_SVCE_LEGL_TOT     object
#  220  F9_09_PC_FEES_FOR_SVCE_LOBB_TOT     object
#  221  F9_09_PC_FEES_FOR_SVCE_MGMT_TOT     object
#  222  F9_09_PC_FEES_FOR_SVCE_OTH_TOT      object
#  223  F9_09_PC_OTHER_EMP_BEN_FUNDRAISE    object
#  224  F9_09_PC_OTHER_EMP_BEN_MGMT         object
#  225  F9_09_PC_OTHER_EMP_BEN_PROG_SVCE    object
#  226  F9_09_PC_OTHER_EMP_BEN_TOTAL        object
#  227  F9_09_PC_OTHER_SALARY_FUNDRAISE     object
#  228  F9_09_PC_OTHER_SALARY_MGMT          object
#  229  F9_09_PC_OTHER_SALARY_PROG_SVCE     object
#  230  F9_09_PC_OTHER_SALARY_TOTAL         object
#  231  F9_09_PC_PAYMENT_TO_AFFILIATES      object
#  232  F9_09_PC_PAYROLL_TAX_FUNDRAISE      object
#  233  F9_09_PC_PAYROLL_TAX_MGMT           object
#  234  F9_09_PC_PAYROLL_TAX_PROG_SVCE      object
#  235  F9_09_PC_PAYROLL_TAX_TOTAL          object
#  236  F9_09_PC_PENSION_CONT_FUNDRAISE     object
#  237  F9_09_PC_PENSION_CONT_MGMT          object
#  238  F9_09_PC_PENSION_CONT_PROG_SVCE     object
#  239  F9_09_PC_PENSION_CONT_TOTAL         object
#  240  F9_09_PC_TOTAL_FUNC_EXPENSES        object
#  241  F9_09_PC_TOTAL_FUNDRAISE_EXPENSE    object
#  242  F9_09_PC_TOTAL_MGMT_EXPENSE         object
#  243  F9_09_PC_TOTAL_PROG_SVCE_EXPENSE    object
#  244  F9_10_ASSETS_ACC_NET_EOY            object
#  245  F9_10_ASSETS_EXP_PREPAID_EOY        object
#  246  F9_10_ASSETS_INTANGIB_EOY           object
#  247  F9_10_ASSETS_INVENT_SALE_EOY        object
#  248  F9_10_ASSETS_LESS_DEPREC_EOY        object
#  249  F9_10_ASSETS_LOANS_DISQUAL_EOY      object
#  250  F9_10_ASSETS_NOTES_LOANS_NET_EOY    object
#  251  F9_10_ASSETS_OTH_EOY                object
#  252  F9_10_ASSETS_PLEDGES_NET_EOY        object
#  253  F9_10_LIAB_ACC_PAYABLE_EOY          object
#  254  F9_10_LIAB_GRANTS_PAYABLE_EOY       object
#  255  F9_10_LIAB_LOANS_OFF_EOY            object
#  256  F9_10_LIAB_REV_DEFERRED_EOY         object
#  257  F9_10_NAFB_RESTRICT_PERM_EOY        object
#  258  F9_10_NAFB_RESTRICT_TEMP_EOY        object
#  259  F9_10_NAFB_UNRESTRICT_EOY           object
#  260  F9_10_PC_BOND_LIABILITY_EOY         object
#  261  F9_10_PC_CASH_NON_INTEREST_BOY      object
#  262  F9_10_PC_CASH_NON_INTEREST_EOY      object
#  263  F9_10_PC_ESCROW_LIABILITY_EOY       object
#  264  F9_10_PC_INVEST_OTHER_SEC_EOY       object
#  265  F9_10_PC_INVEST_PROG_RELTD_EOY      object
#  266  F9_10_PC_INVEST_PUB_TRADED_EOY      object
#  267  F9_10_PC_LAND_BLDG_EQPMT            object
#  268  F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN    object
#  269  F9_10_PC_LOANS_FROM_OFFICERS_EOY    object
#  270  F9_10_PC_ORG_FOLLOWS_SFAS117        int64
#  271  F9_10_PC_ORG_NOT_FOLLOW_SFAS117     int64
#  272  F9_10_PC_OTHER_LIABILITIES_EOY      object
#  273  F9_10_PC_RET_EARNINGS_ENDWMT_EOY    object
#  274  F9_10_PC_SAVINGS_TEMP_INVEST_BOY    object
#  275  F9_10_PC_SAVINGS_TEMP_INVEST_EOY    object
#  276  F9_10_PC_SECURED_MORTGAGES_EOY      object
#  277  F9_10_PC_SECURE_MORT_NOTES_EOY      object
#  278  F9_10_PC_UNSECURED_LOANS_EOY        object
#  279  F9_10_PC_UNSECURED_NOTES_BOY        object
#  280  F9_10_PC_UNSECURED_NOTES_EOY        object
#  281  F9_10_PZ_TOTAL_ASSETS_EOY           object
#  282  F9_10_SCHED_O_X                     int64
#  283  F9_11_PC_RECNCLTN_DONATED_SVCES     object
#  284  F9_11_PC_RECNCLTN_INVSTMNT_EXP      object
#  285  F9_11_PC_RECNCLTN_PRIOR_PER_ADJ     object
#  286  F9_11_PC_RECNCLTN_REV_LESS_EXP      object
#  287  F9_11_PC_RECNCLTN_UNRLZD_GAIN       object
#  288  F9_11_SCHED_O_X                     int64
#  289  F9_12_PC_ACCNT_COMPILE_OR_REVIEW    int64
#  290  F9_12_PC_ACCTG_METHOD_ACCRUAL       int64
#  291  F9_12_PC_ACCTG_METHOD_CASH          int64
#  292  F9_12_PC_ACCTG_METHOD_OTHER         object
#  293  F9_12_PC_AUDIT_COMMITTEE            int64
#  294  F9_12_PC_FED_GRNT_AUDIT_PERFORMD    int64
#  295  F9_12_PC_FED_GRNT_AUDIT_REQUIRED    int64
#  296  F9_12_PC_FINCL_STMTS_AUDITED        int64
#  297  F9_12_SCHED_O_X                     int64
#  298  number_of_other_prog_svces          object
#  299  501c3                               int32
# dtypes: int32(1), int64(78), object(221)
# memory usage: 7.7+ GB

# %%
df.describe().T
# Out:
#                                       count      mean       std  min  25%  \
# F9_00_HD_ADDR_CHANGE              3469008.0  0.039835  0.195571  0.0  0.0
# F9_00_HD_AMENDED_RETURN           3469008.0  0.011920  0.108527  0.0  0.0
# F9_00_HD_EXEMPT_STATUS_4847A1     3469008.0  0.000709  0.026626  0.0  0.0
# F9_00_HD_EXEMPT_STATUS_501C3      3469008.0  0.752216  0.431726  0.0  1.0
# F9_00_HD_FINAL_RETURN             3469008.0  0.005586  0.074533  0.0  0.0
# ...                                     ...       ...       ...  ...  ...
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD  3469008.0  0.085901  0.280217  0.0  0.0
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED  3469008.0  0.086664  0.281342  0.0  0.0
# F9_12_PC_FINCL_STMTS_AUDITED      3469008.0  0.434902  0.495744  0.0  0.0
# F9_12_SCHED_O_X                   3469008.0  0.165592  0.371714  0.0  0.0
# 501c3                             3469008.0  0.760385  0.426849  0.0  1.0
#
#                                   50%  75%  max
# F9_00_HD_ADDR_CHANGE              0.0  0.0  1.0
# F9_00_HD_AMENDED_RETURN           0.0  0.0  1.0
# F9_00_HD_EXEMPT_STATUS_4847A1     0.0  0.0  1.0
# F9_00_HD_EXEMPT_STATUS_501C3      1.0  1.0  1.0
# F9_00_HD_FINAL_RETURN             0.0  0.0  1.0
# ...                               ...  ...  ...
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD  0.0  0.0  1.0
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED  0.0  0.0  1.0
# F9_12_PC_FINCL_STMTS_AUDITED      0.0  1.0  1.0
# F9_12_SCHED_O_X                   0.0  0.0  1.0
# 501c3                             1.0  1.0  1.0
#
# [79 rows x 8 columns]

# %%
df.describe().T
# Out:
#                                       count      mean       std  min  25%  \
# F9_00_HD_ADDR_CHANGE              3469008.0  0.039835  0.195571  0.0  0.0
# F9_00_HD_AMENDED_RETURN           3469008.0  0.011920  0.108527  0.0  0.0
# F9_00_HD_EXEMPT_STATUS_4847A1     3469008.0  0.000709  0.026626  0.0  0.0
# F9_00_HD_EXEMPT_STATUS_501C3      3469008.0  0.752216  0.431726  0.0  1.0
# F9_00_HD_FINAL_RETURN             3469008.0  0.005586  0.074533  0.0  0.0
# ...                                     ...       ...       ...  ...  ...
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD  3469008.0  0.085901  0.280217  0.0  0.0
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED  3469008.0  0.086664  0.281342  0.0  0.0
# F9_12_PC_FINCL_STMTS_AUDITED      3469008.0  0.434902  0.495744  0.0  0.0
# F9_12_SCHED_O_X                   3469008.0  0.165592  0.371714  0.0  0.0
# 501c3                             3469008.0  0.760385  0.426849  0.0  1.0
#
#                                   50%  75%  max
# F9_00_HD_ADDR_CHANGE              0.0  0.0  1.0
# F9_00_HD_AMENDED_RETURN           0.0  0.0  1.0
# F9_00_HD_EXEMPT_STATUS_4847A1     0.0  0.0  1.0
# F9_00_HD_EXEMPT_STATUS_501C3      1.0  1.0  1.0
# F9_00_HD_FINAL_RETURN             0.0  0.0  1.0
# ...                               ...  ...  ...
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD  0.0  0.0  1.0
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED  0.0  0.0  1.0
# F9_12_PC_FINCL_STMTS_AUDITED      0.0  1.0  1.0
# F9_12_SCHED_O_X                   0.0  0.0  1.0
# 501c3                             1.0  1.0  1.0
#
# [79 rows x 8 columns]

# %%
# %%time
import datetime
print("🕓 read started:", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Step 3: Save
#df_clean.to_parquet("D:/filings_full.parquet", engine="pyarrow", compression="snappy", index=False)
df = pd.read_parquet("D:/all_filings_april_2025_all_controls_combined.parquet", engine="pyarrow")

print("✅ read completed:", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print("✅ Loaded:", df.shape)
# Out:
# 🕓 read started: 2025-04-17 16:12:05
# ✅ read completed: 2025-04-17 16:15:26
# ✅ Loaded: (3469008, 300)
# CPU times: total: 5min 43s
# Wall time: 3min 20s

# %%
#%%time
#import datetime
#print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
#df = pd.read_pickle('D:/all_filings_april_2025_all_controls_combined.pkl.gz', compression='gzip')
#print('# of columns:', len(df.columns))
#print('# of observations:', len(df))
#df[:1]

# %% [markdown]
# <br>Print out list of all 300 columns

# %%
print(df.columns.tolist())
# Out:
# ['_id', 'OrganizationName', 'URL', 'DLN', 'TaxPeriod', 'F9_09_PC_FEES_FOR_SVCE_FR_TOT', 'F9_00_HD_BUILD_TIME_STAMP', 'fiscal_year', 'EIN', 'Name', 'NameControl', 'Phone', 'USAddress', 'ForeignAddress', 'InCareOfName', 'BusinessName', 'BusinessNameControlTxt', 'PhoneNum', 'InCareOfNm', 'ForeignPhoneNum', 'F9_00_HD_ADDR_CHANGE', 'F9_00_HD_AMENDED_RETURN', 'F9_00_HD_CTRY_OF_DOMICILE', 'F9_00_HD_EXEMPT_STATUS_4847A1', 'F9_00_HD_EXEMPT_STATUS_501C', 'F9_00_HD_EXEMPT_STATUS_501C3', 'F9_00_HD_FINAL_RETURN', 'F9_00_HD_GROSS_EXEMPT_NUM', 'F9_00_HD_GROSS_RCPT', 'F9_00_HD_GROUP_RETURN', 'F9_00_HD_INCLUDES_SUBORD_ORGS', 'F9_00_HD_INITIAL_RETURN', 'F9_00_HD_PRIN_OFF_NAME', 'F9_00_HD_SIGNING_OFFICER_SIGNTR', 'F9_00_HD_SPECIAL_CONDITION_DESC', 'F9_00_HD_STATE_OF_DOMICILE', 'F9_00_HD_TAX_PER_BEGIN', 'F9_00_HD_TAX_PER_END', 'F9_00_HD_TAX_YEAR', 'F9_00_HD_TIME_STAMP', 'F9_00_HD_TYPE_ORG_ASSOCIATION', 'F9_00_HD_TYPE_ORG_CORP', 'F9_00_HD_TYPE_ORG_OTHER', 'F9_00_HD_TYPE_ORG_OTHER_DESC', 'F9_00_HD_TYPE_ORG_TRUST', 'F9_00_HD_WEBSITE', 'F9_00_HD_YEAR_FORMED', 'F9_01_PC_BEN_PAID_MEMB_PRIOR', 'F9_01_PC_CONTR_GRANTS_CURR', 'F9_01_PC_CONTR_GRANTS_PRIOR', 'F9_01_PC_GRANTS_PRIOR', 'F9_01_PC_INDEP_VOTING_MEMB', 'F9_01_PC_INVEST_INCOME_PRIOR', 'F9_01_PC_NET_ASSETS_BOY', 'F9_01_PC_OTHER_EXPENSE_PRIOR', 'F9_01_PC_OTHER_REV_PRIOR', 'F9_01_PC_PROF_FUNDRISING_EXP_CURR', 'F9_01_PC_PROF_FUNDRISING_EXP_PRIOR', 'F9_01_PC_PROG_SERVICE_REV_PRIOR', 'F9_01_PC_REV_LESS_EXP_CURR', 'F9_01_PC_REV_LESS_EXP_PRIOR', 'F9_01_PC_TERMINATION_CONTRACTION', 'F9_01_PC_TOT_ASSETS_EOY', 'F9_01_PC_TOT_EXP_PRIOR', 'F9_01_PC_TOT_FNDR_EXP_CURR', 'F9_01_PC_TOT_INDIV_EMPLOYED', 'F9_01_PC_TOT_INDIV_VOLUNTEERS', 'F9_01_PC_TOT_LIABILITIES_EOY', 'F9_01_PC_TOT_REVENUE_PRIOR', 'F9_01_PC_TOT_UBI_GROSS', 'F9_01_PC_TOT_UBI_NET', 'F9_01_PC_VOTING_MEMB_GOV_BODY', 'F9_01_PZ_BEN_PAID_TO_MEMB_CURR', 'F9_01_PZ_GRANTS_PAID_CURR', 'F9_01_PZ_INVEST_INCOME_CURR', 'F9_01_PZ_NAFB_EOY', 'F9_01_PZ_ORGANIZATIONAL_MISSION', 'F9_01_PZ_OTHER_EXPENSE_CURR', 'F9_01_PZ_OTHER_REV_CURR', 'F9_01_PZ_PROG_SERVICE_REV_CURR', 'F9_01_PZ_SALARIES_CURR', 'F9_01_PZ_SALARIES_PRIOR', 'F9_01_PZ_TOT_ASSETS_BOY', 'F9_01_PZ_TOT_EXP_CURR', 'F9_01_PZ_TOT_LIAB_BOY', 'F9_01_PZ_TOT_REV_CURR', 'F9_03_PC_PGMSVC_SIGNIF_CHG', 'F9_03_PC_PGMSVC_SIGNIF_NEW', 'F9_03_PC_PROG_SVC_ACC_1_CODE', 'F9_03_PC_PROG_SVC_ACC_1_DESC', 'F9_03_PC_PROG_SVC_ACC_1_EXP', 'F9_03_PC_PROG_SVC_ACC_1_GRNT', 'F9_03_PC_PROG_SVC_ACC_1_REV', 'F9_03_PC_PROG_SVC_ACC_2_CODE', 'F9_03_PC_PROG_SVC_ACC_2_DESC', 'F9_03_PC_PROG_SVC_ACC_2_EXP', 'F9_03_PC_PROG_SVC_ACC_2_GRNT', 'F9_03_PC_PROG_SVC_ACC_2_REV', 'F9_03_PC_PROG_SVC_ACC_3_CODE', 'F9_03_PC_PROG_SVC_ACC_3_DESC', 'F9_03_PC_PROG_SVC_ACC_3_EXP', 'F9_03_PC_PROG_SVC_ACC_3_GRNT', 'F9_03_PC_PROG_SVC_ACC_3_REV', 'F9_03_PC_TOT_OTH_PROG_SVC_EXP', 'F9_03_PC_TOT_OTH_PROG_SVC_GRNT', 'F9_03_PC_TOT_OTH_PROG_SVC_REV', 'F9_03_PC_TOT_PROG_SVC_EXPENSE', 'F9_03_PZ_MISSION_DESCRIPTION', 'F9_03_PZ_SCHEDULE_O_PART3', 'F9_04_PC_ACTVITIES_VIA_PARTNER', 'F9_04_PC_CONTROLLED_ENTITY', 'F9_04_PC_DISREGARDED_ENTITY', 'F9_04_PC_EXCESS_BENEFIT_TRANS', 'F9_04_PC_FR_EVENT_INC_GT_15K', 'F9_04_PC_GAMING_INC_GT_15K', 'F9_04_PC_LOBBYING_ACTIVITIES', 'F9_04_PC_POLITICAL_ACTIVITIES', 'F9_04_PC_PRIOR_EXCESS_BEN_TRAN', 'F9_04_PC_PROF_FR_EXP_GT_15K', 'F9_04_PC_RELATED_ENTITY', 'F9_04_PC_TRANS_TO_CNTRLD_ENT', 'F9_04_PC_TRANS_WITH_CNTRLD_ENT', 'F9_05_EXP_SCHED_O_X', 'F9_05_PC_NUMBER_EMPLOYEES_W3', 'F9_05_PC_NUMBER_FORMS_1096', 'F9_05_PC_UNRELATED_BUS_INCOME', 'F9_06_EXP_SCHED_O_X', 'F9_06_PC_990_PROVIDED_GOV_BODY', 'F9_06_PC_ANNUAL_DISC_COVRD_PERS', 'F9_06_PC_CEO_COMPENSTN_PROCESS', 'F9_06_PC_CHANGES_ORGANIZING_DOCS', 'F9_06_PC_CONFLICT_OF_INTEREST', 'F9_06_PC_DECISIONS_SUBJ_APPROVAL', 'F9_06_PC_DELEGATION_MGT_DUTIES', 'F9_06_PC_DELEGATION_OF_MGT', 'F9_06_PC_DOCUMENT_RET_POLICY', 'F9_06_PC_ELECTION_BOARD_MEMBERS', 'F9_06_PC_FAMILY_OR_BUSINESS_REL', 'F9_06_PC_FORM_AVAIL_OWN_WEBSITE', 'F9_06_PC_FORM_UPON_REQUEST', 'F9_06_PC_JOINT_VENTURE_INVESTMNT', 'F9_06_PC_JOINT_VENTURE_POLI ...

# %% [markdown]
# # CODE TO FLATTEN DICTIONARY

# %% [markdown]
# ### Combine Variables in *Concordance* File

# %%
[c for c in df.columns if 'tax' in c.lower()]
# Out:
# ['TaxPeriod',
#  'F9_00_HD_TAX_PER_BEGIN',
#  'F9_00_HD_TAX_PER_END',
#  'F9_00_HD_TAX_YEAR',
#  'F9_09_PC_PAYROLL_TAX_FUNDRAISE',
#  'F9_09_PC_PAYROLL_TAX_MGMT',
#  'F9_09_PC_PAYROLL_TAX_PROG_SVCE',
#  'F9_09_PC_PAYROLL_TAX_TOTAL']

# %%
df[['F9_00_HD_BUILD_TIME_STAMP' ,'F9_00_HD_TIME_STAMP', 'TaxPeriod', 'F9_00_HD_TAX_YEAR', 'F9_00_HD_TAX_PER_END']].sample(5)
# Out:
#         F9_00_HD_BUILD_TIME_STAMP        F9_00_HD_TIME_STAMP TaxPeriod  \
# 2912878      2023-04-26 12:10:37Z  2023-08-18T12:42:57-04:00      None
# 2675889      2022-09-23 18:48:47Z  2022-11-15T16:33:05-05:00      None
# 1072135      2017-02-10 21:41:12Z  2017-01-26T10:24:47-08:00    201606
# 689742       2016-02-25 16:41:14Z  2015-05-11T13:15:07-07:00    201412
# 1758216      2020-01-14 16:20:31Z  2019-11-12T13:04:07-06:00    201906
#
#         F9_00_HD_TAX_YEAR F9_00_HD_TAX_PER_END
# 2912878              2022           2022-12-31
# 2675889              2021           2021-12-31
# 1072135              2015           2016-06-30
# 689742               2014           2014-12-31
# 1758216              2018           2019-06-30

# %% [markdown]
# ### Collapse concordance file
# We'll aggregate the concordance file in order to get the list of valid 'sub-keys' for each nested/dictionary variable
# - Note: I added 'cardinality' to *new_variables_df* in order to deal with *F9_09_EXP_OTH_TOT*

# %%
#def agg_funcs(x):
#    names = {
#        #'name': x['variable_name_new'].head(1).values[0],
#        'original_names':  list(set(x['MongoDB_Name'].tolist())),
#        'sub_keys':  list(set(x['sub_key'].tolist())),
#        'data_type_xsd': x['data_type_xsd'].head(1).values[0],
#        'cardinality': x['cardinality'].head(1).values[0]
#    }
#    #THE FOLLOWING SHORTCUT WORKS BUT CHANGES THE ORDER OF THE COLUMNS
#    #return pd.Series(names, index = list(names.keys()))
#    return pd.Series(names, index=['original_names', 'sub_keys', 'data_type_xsd', 'cardinality'])
#new_variables_df = concordance[concordance['sub_key'].notnull()][:].groupby(['variable_name_new']).apply(agg_funcs)
#new_variables_df = new_variables_df.reset_index()
#print('# of variables:', len(new_variables_df))
#new_variables_df[:]

# %% [markdown]
# #### New way
# Here is the original code rewritten in the newer `.groupby().agg()` style for better readability and performance. This version handles all fields using named aggregation.
#
# Notes:
# - `list(set(x))` replaces the manual `set().tolist()` logic.
# - `first` is used to pull the top value in the group for `data_type_xsd` and `cardinality`, just as `head(1).values[0]` did.
# - I kept the `.reset_index()` for a flat DataFrame like your original.
# - The filtering on `sub_key.notnull()` is preserved.

# %%
# %%time
new_variables_df = (
    concordance[concordance['sub_key'].notnull()]
    .groupby('variable_name_new')
    .agg(
        original_names=('MongoDB_Name', lambda x: list(set(x))),
        sub_keys=('sub_key', lambda x: list(set(x))),
        data_type_xsd=('data_type_xsd', 'first'),
        cardinality=('cardinality', 'first')
    )
    .reset_index()
  )

print('# of variables:', len(new_variables_df))
new_variables_df
# Out:
# # of variables: 109
# CPU times: total: 0 ns
# Wall time: 17.6 ms
#                   variable_name_new  \
# 0         F9_00_HD_FILER_ADDR_US_L1
# 1         F9_00_HD_FILER_ADDR_US_L2
# 2            F9_00_HD_FILER_CITY_US
# 3       F9_00_HD_FILER_COUNTRY_FRGN
# 4           F9_00_HD_FILER_STATE_US
# ..                              ...
# 104  F9_10_PC_SECURE_MORT_NOTES_EOY
# 105    F9_10_PC_UNSECURED_LOANS_EOY
# 106    F9_10_PC_UNSECURED_NOTES_BOY
# 107    F9_10_PC_UNSECURED_NOTES_EOY
# 108       F9_10_PZ_TOTAL_ASSETS_EOY
#
#                                                        original_names  \
# 0                                                             [Filer]
# 1                                                             [Filer]
# 2                                                             [Filer]
# 3                                                             [Filer]
# 4                                                             [Filer]
# ..                                                                ...
# 104  [MortNotesPyblSecuredInvestProp, MortgNotesPyblScrdInvstPropGrp]
# 105       [UnsecuredNotesLoansPayableGrp, UnsecuredNotesLoansPayable]
# 106       [UnsecuredNotesLoansPayableGrp, UnsecuredNotesLoansPayable]
# 107       [UnsecuredNotesLoansPayableGrp, UnsecuredNotesLoansPayable]
# 108                                     [TotalAssets, TotalAssetsGrp]
#
#              sub_keys      data_type_xsd cardinality
# 0         [USAddress]  StreetAddressType        None
# 1         [USAddress]  StreetAddressType        None
# 2         [USAddress]           CityType        None
# 3    [ForeignAddress]        CountryType        None
# 4         [USAddress]          StateType        None
# ..                ...                ...         ...
# 104     [EOY, EOYAmt]       USAmountType        None
# 105     [EOYAmt, EOY]       USAmountType        None
# 106     [BOYAmt, BOY]       USAmountType        None
# 107     [EOY, EOYAmt]       USAmountType        None
# 108     [EOYAmt, EOY]       USAmountType        None
#
# [109 rows x 5 columns]

# %% [markdown]
# <br>One variable in this list has a value of 'MANY' for *cardinality*

# %%
new_variables_df['cardinality'].value_counts()
# Out:
# cardinality
# ONE     36
# MANY     1
# Name: count, dtype: int64

# %%
new_variables_df[new_variables_df['cardinality']=='MANY']
# Out:
#     variable_name_new                     original_names           sub_keys  \
# 35  F9_09_EXP_OTH_TOT  [OtherExpenses, OtherExpensesGrp]  [TotalAmt, Total]
#
#    data_type_xsd cardinality
# 35  USAmountType        MANY

# %% [markdown]
# <br>Create new variable in the collapsed concordance file to indicate the number of original names for each variable in the XML (e-file) data. Seven of the variables have one original name while 102 have two.

# %%
new_variables_df['len'] = new_variables_df['original_names'].apply(lambda x: len(x))
print(new_variables_df['len'].value_counts(), '\n')
new_variables_df
# Out:
# len
# 2    102
# 1      7
# Name: count, dtype: int64
#                   variable_name_new  \
# 0         F9_00_HD_FILER_ADDR_US_L1
# 1         F9_00_HD_FILER_ADDR_US_L2
# 2            F9_00_HD_FILER_CITY_US
# 3       F9_00_HD_FILER_COUNTRY_FRGN
# 4           F9_00_HD_FILER_STATE_US
# ..                              ...
# 104  F9_10_PC_SECURE_MORT_NOTES_EOY
# 105    F9_10_PC_UNSECURED_LOANS_EOY
# 106    F9_10_PC_UNSECURED_NOTES_BOY
# 107    F9_10_PC_UNSECURED_NOTES_EOY
# 108       F9_10_PZ_TOTAL_ASSETS_EOY
#
#                                                        original_names  \
# 0                                                             [Filer]
# 1                                                             [Filer]
# 2                                                             [Filer]
# 3                                                             [Filer]
# 4                                                             [Filer]
# ..                                                                ...
# 104  [MortNotesPyblSecuredInvestProp, MortgNotesPyblScrdInvstPropGrp]
# 105       [UnsecuredNotesLoansPayableGrp, UnsecuredNotesLoansPayable]
# 106       [UnsecuredNotesLoansPayableGrp, UnsecuredNotesLoansPayable]
# 107       [UnsecuredNotesLoansPayableGrp, UnsecuredNotesLoansPayable]
# 108                                     [TotalAssets, TotalAssetsGrp]
#
#              sub_keys      data_type_xsd cardinality  len
# 0         [USAddress]  StreetAddressType        None    1
# 1         [USAddress]  StreetAddressType        None    1
# 2         [USAddress]           CityType        None    1
# 3    [ForeignAddress]        CountryType        None    1
# 4         [USAddress]          StateType        None    1
# ..                ...                ...         ...  ...
# 104     [EOY, EOYAmt]       USAmountType        None    2
# 105     [EOYAmt, EOY]       USAmountType        None    2
# 106     [BOYAmt, BOY]       USAmountType        None    2
# 107     [EOY, EOYAmt]       USAmountType        None    2
# 108     [EOYAmt, EOY]       USAmountType        None    2
#
# [109 rows x 6 columns]

# %% [markdown]
# <br>We'll also do the same for the number of sub-keys for each of the dictionary variables.

# %%
new_variables_df['len_subkeys'] = new_variables_df['sub_keys'].apply(lambda x: len(x))
print(new_variables_df['len_subkeys'].value_counts(), '\n')
new_variables_df
# Out:
# len_subkeys
# 2    100
# 1      9
# Name: count, dtype: int64
#                   variable_name_new  \
# 0         F9_00_HD_FILER_ADDR_US_L1
# 1         F9_00_HD_FILER_ADDR_US_L2
# 2            F9_00_HD_FILER_CITY_US
# 3       F9_00_HD_FILER_COUNTRY_FRGN
# 4           F9_00_HD_FILER_STATE_US
# ..                              ...
# 104  F9_10_PC_SECURE_MORT_NOTES_EOY
# 105    F9_10_PC_UNSECURED_LOANS_EOY
# 106    F9_10_PC_UNSECURED_NOTES_BOY
# 107    F9_10_PC_UNSECURED_NOTES_EOY
# 108       F9_10_PZ_TOTAL_ASSETS_EOY
#
#                                                        original_names  \
# 0                                                             [Filer]
# 1                                                             [Filer]
# 2                                                             [Filer]
# 3                                                             [Filer]
# 4                                                             [Filer]
# ..                                                                ...
# 104  [MortNotesPyblSecuredInvestProp, MortgNotesPyblScrdInvstPropGrp]
# 105       [UnsecuredNotesLoansPayableGrp, UnsecuredNotesLoansPayable]
# 106       [UnsecuredNotesLoansPayableGrp, UnsecuredNotesLoansPayable]
# 107       [UnsecuredNotesLoansPayableGrp, UnsecuredNotesLoansPayable]
# 108                                     [TotalAssets, TotalAssetsGrp]
#
#              sub_keys      data_type_xsd cardinality  len  len_subkeys
# 0         [USAddress]  StreetAddressType        None    1            1
# 1         [USAddress]  StreetAddressType        None    1            1
# 2         [USAddress]           CityType        None    1            1
# 3    [ForeignAddress]        CountryType        None    1            1
# 4         [USAddress]          StateType        None    1            1
# ..                ...                ...         ...  ...          ...
# 104     [EOY, EOYAmt]       USAmountType        None    2            2
# 105     [EOYAmt, EOY]       USAmountType        None    2            2
# 106     [BOYAmt, BOY]       USAmountType        None    2            2
# 107     [EOY, EOYAmt]       USAmountType        None    2            2
# 108     [EOYAmt, EOY]       USAmountType        None    2            2
#
# [109 rows x 7 columns]

# %% [markdown]
# ### Write extended 'lambda' functions to parse sub-key variables
# Here we will write two functions to deal with dictionary variables that have one and two nested sub-keys, respectively. I have leaned here on functions on Stack Overflow: https://stackoverflow.com/questions/48872234/using-apply-in-pandas-lambda-functions-with-multiple-if-statements?noredirect=1&lq=1
#
# The trick is that these functions will return the nested sub-key value if it exists (and no value if the nested key(s) do not exist). We will apply these functions in loops later on in this notebook.

# %%
def func_onekey(x, key1):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    elif key1 in x.keys():
        return x[key1]
    else:
        return np.nan

# %%
def func(x, key1, key2):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    elif key1 in x.keys():
        return x[key1]
    elif key2 in x.keys():
        return x[key2]
    else:
        return np.nan

# %% [markdown]
# <br>Show the nine variables with a single nested sub-key

# %%
new_variables_df[new_variables_df['len_subkeys']!=2]
# Out:
#                    variable_name_new  \
# 0          F9_00_HD_FILER_ADDR_US_L1
# 1          F9_00_HD_FILER_ADDR_US_L2
# 2             F9_00_HD_FILER_CITY_US
# 3        F9_00_HD_FILER_COUNTRY_FRGN
# 4            F9_00_HD_FILER_STATE_US
# 5              F9_00_HD_FILER_ZIP_US
# 7       F9_03_PC_PROG_SVC_ACC_2_CODE
# 12      F9_03_PC_PROG_SVC_ACC_3_CODE
# 98  F9_10_PC_LOANS_FROM_OFFICERS_EOY
#
#                                                  original_names  \
# 0                                                       [Filer]
# 1                                                       [Filer]
# 2                                                       [Filer]
# 3                                                       [Filer]
# 4                                                       [Filer]
# 5                                                       [Filer]
# 7                            [ProgSrvcAccomActy2Grp, Activity2]
# 12                           [Activity3, ProgSrvcAccomActy3Grp]
# 98  [LoansFromOfficersDirectors, LoansFromOfficersDirectorsGrp]
#
#             sub_keys      data_type_xsd cardinality  len  len_subkeys
# 0        [USAddress]  StreetAddressType        None    1            1
# 1        [USAddress]  StreetAddressType        None    1            1
# 2        [USAddress]           CityType        None    1            1
# 3   [ForeignAddress]        CountryType        None    1            1
# 4        [USAddress]          StateType        None    1            1
# 5        [USAddress]        ZIPCodeType        None    1            1
# 7     [ActivityCode]      IntegerNNType        None    2            1
# 12    [ActivityCode]      IntegerNNType        None    2            1
# 98          [EOYAmt]       USAmountType        None    2            1

# %% [markdown]
# ### Process
# I first deal with a handful of variables a la carte. In future iterations of this notebook I will incorporate into the loop we'll be processing later on.
#
# Note: the reason these are being dealt with separately here is that the *Filer* variables contain double-nested data and I have yet to add the 'sub-sub-keys' to the concordance file. So, in the next code block I am first transforming the data for these four variables to be the value of the nested sub-key *USAddress*. Then in the subsequent code blocks we further transfrom these four variables to take the value of the sub-sub-key.

# %% [markdown]
# ##### We won't do it this following way any more, because we've already parsed the *Filer* column

# %%
#df[['F9_00_HD_FILER_ADDR_US_L1' ,'F9_00_HD_FILER_ADDR_US_L2', 'F9_00_HD_FILER_CITY_US', 'F9_00_HD_FILER_ZIP_US']].sample(5)

# %%
#%%time
#df['F9_00_HD_FILER_ADDR_US_L1'] = df['Filer'][:].apply(func_onekey, key1='USAddress')
#df['F9_00_HD_FILER_ADDR_US_L2'] = df['Filer'][:].apply(func_onekey, key1='USAddress')
#df['F9_00_HD_FILER_CITY_US'] = df['Filer'][:].apply(func_onekey, key1='USAddress')
#df['F9_00_HD_FILER_ZIP_US'] = df['Filer'][:].apply(func_onekey, key1='USAddress')

# %%
df[['F9_09_PC_FEES_FOR_SVCE_FR_TOT', 'F9_00_HD_BUILD_TIME_STAMP', 
       'EIN', 'BusinessName', 'BusinessNameControlTxt', 'USAddress', 'PhoneNum', 'InCareOfNm',
       'ForeignAddress', 'ForeignPhoneNum']].sample(5)
# Out:
#         F9_09_PC_FEES_FOR_SVCE_FR_TOT F9_00_HD_BUILD_TIME_STAMP        EIN  \
# 1175070             {"TotalAmt": "0"}      2017-02-10 21:41:12Z  330319261
# 1010229             {"TotalAmt": "0"}      2017-02-10 21:41:12Z  370922390
# 590870                           None      2015-11-30 17:44:51Z  411841352
# 1721347                          None      2019-02-21 02:37:17Z  510204577
# 3289147             {"TotalAmt": "0"}      2024-10-15 13:58:12Z  042104831
#
#                                                                                                       BusinessName  \
# 1175070                                                     {'BusinessNameLine1Txt': 'Corona Youth Tennis League'}
# 1010229  {'BusinessNameLine1Txt': 'HUMAN RESOURCES CENTER OF EDGAR AND', 'BusinessNameLine2Txt': 'CLARK COUNTIES'}
# 590870                                                                                                        None
# 1721347                                                {'BusinessNameLine1Txt': "EAST LOS ANGELES WOMEN'S CENTER"}
# 3289147                                           {'BusinessNameLine1Txt': 'PEOPLES INSTITUTE OF NORTHAMPTON INC'}
#
#         BusinessNameControlTxt  \
# 1175070                   CORO
# 1010229                   HUMA
# 590870                    None
# 1721347                   EAST
# 3289147                   PEOP
#
#                                                                                                                           USAddress  \
# 1175070  {'AddressLine1Txt': '2279 Eagle Glen Pkwy 112 PMB 356', 'CityNm': 'Corona', 'StateAbbreviationCd': 'CA', 'ZIPCd': '92883'}
# 1010229                       {'AddressLine1Txt': 'P O BOX 1118', 'CityNm': 'PARIS', 'StateAbbreviationCd': 'IL', 'ZIPCd': '61944'}
# 590870                                   {'AddressLine1': '579 WELLS STREET', 'City': 'ST PAUL', 'State': 'MN', 'ZIPCode': '55130'}
# 1721347         {'AddressLine1Txt': '1431 S ATLANTIC BLVD', 'CityNm': 'LOS ANGELES', 'StateAbbreviationCd': 'CA', 'ZIPCd': '90022'}
# 3289147                 {'AddressLine1Txt': '38 GOTHIC ST', 'CityNm': 'NORTHAMPTON', 'StateAbbreviationCd': 'MA', 'ZIPCd': '01060'}
#
#            PhoneNum InCareOfNm ForeignAddress ForeignPhoneNum
# 1175070  9513714371       None           None            None
# 1010229  2174654118       None           None            None
# 590870         None       None           None            None
# 1721347  3235265819       None           None            None
# 3289147  4135848313       None           None            None

# %% [markdown]
# <br>The following variable is not of great interest to us so I'm just going to take the value of the entire *ForeignAddress* key and not parse it any further.

# %% [markdown]
# ##### Updating approach for new XML filings
# Actually, I'll do that later (see below)

# %%
#%%time
#df['F9_00_HD_FILER_COUNTRY_FRGN'] = df['Filer'][:].apply(func_onekey, key1='ForeignAddress')
# Out:
# Wall time: 9.05 s

# %%
print(len(df[df['ForeignAddress'].notnull()]))
df[df['ForeignAddress'].notnull()][['ForeignAddress']].sample(5)
# Out:
# 3742
#                                                                                                                                               ForeignAddress
# 2230376    {'AddressLine1Txt': 'PO BOX 21345', 'CityNm': 'San Juan', 'ProvinceOrStateNm': 'Puerto Rico', 'CountryCd': 'RQ', 'ForeignPostalCd': '00928-1345'}
# 2636540                     {'AddressLine1Txt': 'DEAN BRADLEY HOUSE 52 HORSEFERRY RD', 'CityNm': 'LONDON', 'CountryCd': 'UK', 'ForeignPostalCd': 'SW1P 2AF'}
# 702803                                                       {'AddressLine1Txt': '272 ATTWELL DRIVE', 'CityNm': 'ETOBICOKE ONTARIO CA M', 'CountryCd': 'CA'}
# 402855                        {'AddressLine1': 'KARLAVGEN 108', 'City': '5TH FLOOR', 'ProvinceOrState': 'STOCKHOLM', 'Country': 'SW', 'PostalCode': '11526'}
# 2470884  {'AddressLine1Txt': '31 33 Avenue Giuseppe Motta', 'CityNm': 'Geneva', 'ProvinceOrStateNm': 'Geneva', 'CountryCd': 'SZ', 'ForeignPostalCd': '1202'}

# %%
#%%time
#df['F9_00_HD_FILER_COUNTRY_FRGN'] = df['ForeignAddress'][:].apply(func_onekey, key1='CountryCd')
# Out:
# CPU times: total: 31.2 ms
# Wall time: 26.9 ms

# %%
#print(len(df[df['ForeignAddress'].notnull()]))
#df[df['ForeignAddress'].notnull()][['ForeignAddress', 'F9_00_HD_FILER_COUNTRY_FRGN']].sample(5)
# Out:
# 30
#                                                                                                                                                  ForeignAddress  \
# 18059                {'AddressLine1Txt': '502 ELLIS STREET', 'CityNm': 'PENTICTON', 'ProvinceOrStateNm': 'BC', 'CountryCd': 'CA', 'ForeignPostalCd': 'V2A 4M3'}
# 13846                           {'AddressLine1Txt': 'WATERSIDESTRATFORD-UPON-AVON', 'CityNm': 'WARWICKSHIRE', 'CountryCd': 'UK', 'ForeignPostalCd': 'CV37 6BB'}
# 894    {'AddressLine1Txt': '2934 Baseline Road Suite 202', 'CityNm': 'OTTAWA', 'ProvinceOrStateNm': 'ONTARIO', 'CountryCd': 'CA', 'ForeignPostalCd': 'K2H 1B2'}
# 19373     {'AddressLine1Txt': 'PO BOX 10007 SUITE 104', 'CityNm': 'GUAYAMA', 'ProvinceOrStateNm': 'PUERTO RICO', 'CountryCd': 'RQ', 'ForeignPostalCd': '00785'}
# 4137                                                                {'AddressLine1Txt': 'PO Box 351', 'ProvinceOrStateNm': '1007, Lausanne', 'CountryCd': 'SZ'}
#
#       F9_00_HD_FILER_COUNTRY_FRGN
# 18059                          CA
# 13846                          UK
# 894                            CA
# 19373                          RQ
# 4137                           SZ

# %% [markdown]
# <br>Now let's parse the four variables noted above in order. Note that for each of these four we are applying our custom function ``func`` and transforming the variable to be the value of either of the two sub-keys. Recall a few things here. First, looking at *F9_00_HD_FILER_ADDR_US_L1*, above we have already changed this variable to be not all of what is contained under *Filer* but only the *USAddress* key. Below we then change the variable to be the value of either 'AddressLine1' or 'AddressLine1Txt'. Each filing will only have one of these two sub-keys depending on the year of the filing.

# %% [markdown]
# ##### I've updated these four for the new XML filings

# %%
#%%time
#df['F9_00_HD_FILER_ADDR_US_L1'] = df['F9_00_HD_FILER_ADDR_US_L1'][:].apply(func, key1='AddressLine1', key2='AddressLine1Txt')
# Out:
# Wall time: 9.64 s

# %%
#%%time
#df['F9_00_HD_FILER_ADDR_US_L2'] = df['F9_00_HD_FILER_ADDR_US_L2'][:].apply(func, key1='AddressLine2', key2='AddressLine2Txt')
# Out:
# Wall time: 9.25 s

# %%
#%%time
#df['F9_00_HD_FILER_CITY_US'] = df['F9_00_HD_FILER_CITY_US'][:].apply(func, key1='City', key2='CityNm')
# Out:
# Wall time: 9.08 s

# %%
#%%time
#df['F9_00_HD_FILER_ZIP_US'] = df['F9_00_HD_FILER_ZIP_US'][:].apply(func, key1='ZIPCd', key2='ZIPCode')
# Out:
# Wall time: 9.07 s

# %%
df[['EIN', 'BusinessName', 'USAddress']].sample(5)
# Out:
#                EIN  \
# 2380140  222488540
# 2863386  840410760
# 1862287  586066597
# 2892841  260030908
# 447454   830246840
#
#                                                                                              BusinessName  \
# 2380140  {'BusinessNameLine1Txt': 'LAW ENFORCEMENT ALLIANCE OF SOUTH-', 'BusinessNameLine2Txt': 'INGTON'}
# 2863386                                            {'BusinessNameLine1Txt': 'THE COLORADO MOUNTAIN CLUB'}
# 1862287                                    {'BusinessNameLine1Txt': 'SOUTHEASTERN CARP & MW HEALTH PLAN'}
# 2892841                                                 {'BusinessNameLine1Txt': 'THE DREAM PROGRAM INC'}
# 447454                                                                                               None
#
#                                                                                                                    USAddress
# 2380140            {'AddressLine1Txt': 'PO BOX 126', 'CityNm': 'SOUTHINGTON', 'StateAbbreviationCd': 'CT', 'ZIPCd': '06489'}
# 2863386  {'AddressLine1Txt': '710 10TH STREET SUITE 200', 'CityNm': 'GOLDEN', 'StateAbbreviationCd': 'CO', 'ZIPCd': '80401'}
# 1862287    {'AddressLine1Txt': 'PO BOX 1449', 'CityNm': 'GOODLETTSVILLE', 'StateAbbreviationCd': 'TN', 'ZIPCd': '370701449'}
# 2892841               {'AddressLine1Txt': 'PO BOX 361', 'CityNm': 'WINOOSKI', 'StateAbbreviationCd': 'VT', 'ZIPCd': '05404'}
# 447454                                  {'AddressLine1': 'PO BOX 2799', 'City': 'CASPER', 'State': 'WY', 'ZIPCode': '82602'}

# %% [markdown]
# #### Conversion code for feather/parquet files

# %%
import ast
import json

def convert_to_dict(x):
    """Convert string to dictionary if needed"""
    if pd.isnull(x):
        return np.nan
    
    if isinstance(x, dict):
        return x
        
    try:
        # Try using json.loads first (safer and handles more formats)
        return json.loads(x)
    except:
        try:
            # Fallback to ast.literal_eval
            return ast.literal_eval(x)
        except:
            return np.nan

# %%
#%%time
## First convert strings to dictionaries
#df['F9_00_HD_EXEMPT_STATUS_501C'] = df['F9_00_HD_EXEMPT_STATUS_501C'].apply(convert_to_dict)

# %%
dict_cols = ['USAddress', 'ForeignAddress']
df[dict_cols].dtypes
# Out:
# USAddress         object
# ForeignAddress    object
# dtype: object

# %%
# Print a few non-null values to see what we're working with
sample_values = df[df[dict_cols[0]].notnull()][dict_cols[0]].head(3).tolist()
print(f"Sample values from {dict_cols[0]}:")
for val in sample_values:
    print(f"Value: {val}")
    print(f"Type: {type(val)}")
# Out:
# Sample values from USAddress:
# Value: {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300', 'City': 'BETHLEHEM', 'State': 'PA', 'ZIPCode': '18017'}
# Type: <class 'str'>
# Value: {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA', 'State': 'VA', 'ZIPCode': '22314'}
# Type: <class 'str'>
# Value: {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA', 'State': 'VA', 'ZIPCode': '22314'}
# Type: <class 'str'>

# %%
# %%time
# Apply the conversion to each column directly
for col in dict_cols:
    if col in df.columns:
        print(f"Converting {col}...")
        #df[col] = df[col].apply(convert_to_dict)
        df[col] = df[col].map(convert_to_dict)
# Out:
# Converting USAddress...
# Converting ForeignAddress...
# CPU times: total: 2min 6s
# Wall time: 2min 8s

# %%
# Print a few non-null values to see what we're working with
sample_values = df[df[dict_cols[0]].notnull()][dict_cols[0]].head(3).tolist()
print(f"Sample values from {dict_cols[0]}:")
for val in sample_values:
    print(f"Value: {val}")
    print(f"Type: {type(val)}")
# Out:
# Sample values from USAddress:
# Value: {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300', 'City': 'BETHLEHEM', 'State': 'PA', 'ZIPCode': '18017'}
# Type: <class 'dict'>
# Value: {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA', 'State': 'VA', 'ZIPCode': '22314'}
# Type: <class 'dict'>
# Value: {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA', 'State': 'VA', 'ZIPCode': '22314'}
# Type: <class 'dict'>

# %%
import gc
gc.collect()
# Out:
# 513

# %% [markdown]
# #### Back to former code
#
# Next time, consider this:
#
#
# Step 1: Convert stringified dicts to actual dicts [if needed]
# ```python
# df['USAddress'] = df['USAddress'].map(convert_to_dict)
# ```
#
# Step 2: Extract value using a clean, efficient function
# ```python
#
# def extract_first_available(d, *keys):
#     if not isinstance(d, dict):
#         return np.nan
#     for key in keys:
#         if key in d:
#             return d[key]
#     return np.nan
#
# df['F9_00_HD_FILER_ZIP_US'] = df['USAddress'].map(lambda d: extract_first_available(d, 'ZIPCd', 'ZIPCode'))
# ```

# %% [markdown]
# #### New function

# %%
# %%time
#df['F9_00_HD_FILER_ADDR_US_L1'] = df['USAddress'][:].apply(func, key1='AddressLine1', key2='AddressLine1Txt')
df['F9_00_HD_FILER_ADDR_US_L1'] = df['USAddress'].map(lambda d: extract_first_available(d, 'AddressLine1', 'AddressLine1Txt'))
# Out:
# CPU times: total: 13.8 s
# Wall time: 15.1 s

# %%
# %%time
#df['F9_00_HD_FILER_ADDR_US_L2'] = df['USAddress'][:].apply(func, key1='AddressLine2', key2='AddressLine2Txt')
df['F9_00_HD_FILER_ADDR_US_L2'] = df['USAddress'].map(lambda d: extract_first_available(d, 'AddressLine2', 'AddressLine2Txt'))
# Out:
# CPU times: total: 2.16 s
# Wall time: 2.31 s

# %%
# %%time
#df['F9_00_HD_FILER_CITY_US'] = df['USAddress'][:].apply(func, key1='City', key2='CityNm')
df['F9_00_HD_FILER_CITY_US'] = df['USAddress'].map(lambda d: extract_first_available(d, 'City', 'CityNm'))
# Out:
# CPU times: total: 1.88 s
# Wall time: 2.12 s

# %%
# %%time
#df['F9_00_HD_FILER_ZIP_US'] = df['USAddress'][:].apply(func, key1='ZIPCd', key2='ZIPCode')
df['F9_00_HD_FILER_ZIP_US'] = df['USAddress'].map(lambda d: extract_first_available(d, 'ZIPCd', 'ZIPCode'))
# Out:
# CPU times: total: 1.83 s
# Wall time: 2.09 s

# %% [markdown]
# <br>Now let's take a look at these four variables in a random sample of five filings. All appear to be parsed successfully.

# %%
print(len(df[df['F9_00_HD_FILER_ADDR_US_L2'].notnull()]))
# Out:
# 43179

# %%
# %%time
df[['F9_00_HD_FILER_ADDR_US_L1', 'F9_00_HD_FILER_ADDR_US_L2', 'F9_00_HD_FILER_CITY_US', 'F9_00_HD_FILER_ZIP_US']].sample(5)
# Out:
# CPU times: total: 703 ms
# Wall time: 775 ms
#         F9_00_HD_FILER_ADDR_US_L1 F9_00_HD_FILER_ADDR_US_L2  \
# 1996086       429 N MAIN STREET 2                       NaN
# 2598268                 PO BOX 28                       NaN
# 3097367            129 ELM STREET                       NaN
# 1572876      102 COURTHOUSE DRIVE                       NaN
# 2130624             700 Pass Road                       NaN
#
#         F9_00_HD_FILER_CITY_US F9_00_HD_FILER_ZIP_US
# 1996086             GREENVILLE                 29601
# 2598268         Bruceton Mills                 26525
# 3097367              VACAVILLE                 95688
# 1572876            ST MATTHEWS                 29135
# 2130624               Gulfport                 39501

# %% [markdown]
# <br>Parse another variable and then show some descriptives.

# %% [markdown]
# ##### Update variable for new XML filings

# %%
#%%time
#df['F9_00_HD_FILER_COUNTRY_FRGN'] = df['F9_00_HD_FILER_COUNTRY_FRGN'][:].apply(func, key1='Country', key2='CountryCd')
# Out:
# Wall time: 26.1 s

# %%
# %%time
#df['F9_00_HD_FILER_COUNTRY_FRGN'] = df['ForeignAddress'][:].apply(func, key1='Country', key2='CountryCd')
df['F9_00_HD_FILER_COUNTRY_FRGN'] = df['ForeignAddress'].map(lambda d: extract_first_available(d, 'Country', 'CountryCd'))
# Out:
# CPU times: total: 1.64 s
# Wall time: 1.72 s

# %%
df['F9_00_HD_FILER_COUNTRY_FRGN'].value_counts()
# Out:
# F9_00_HD_FILER_COUNTRY_FRGN
# CA    1210
# RQ     737
# UK     382
# IS     279
# FR      82
#       ...
# SP       1
# ET       1
# PS       1
# TU       1
# AL       1
# Name: count, Length: 94, dtype: int64

# %%
# %%time
df[['F9_00_HD_FILER_ADDR_US_L1', 'F9_00_HD_FILER_ADDR_US_L2', 'F9_00_HD_FILER_CITY_US', 'F9_00_HD_FILER_ZIP_US',
   'F9_00_HD_FILER_COUNTRY_FRGN']].describe().T
# Out:
# CPU times: total: 5.88 s
# Wall time: 6.08 s
#                                count  unique                    top   freq
# F9_00_HD_FILER_ADDR_US_L1    3465266  636068  2335 NORTH BANK DRIVE   2260
# F9_00_HD_FILER_ADDR_US_L2      43179    4612                  Suite  13463
# F9_00_HD_FILER_CITY_US       3465266   29086               NEW YORK  61732
# F9_00_HD_FILER_ZIP_US        3465266   96995                  20036   9132
# F9_00_HD_FILER_COUNTRY_FRGN     3742      94                     CA   1210

# %% [markdown]
# <br>Here I want to double-check that the parsing was correct for *F9_00_HD_FILER_COUNTRY_FRGN*. There are few observations in the dataset with a value for this variable, so rather than show a random sample of five observations, we take a random sample of five observations that actually have a value for this variable using the ``notnull()`` function.

# %%
# %%time
df[df['F9_00_HD_FILER_COUNTRY_FRGN'].notnull()][['F9_00_HD_FILER_ADDR_US_L1', 'F9_00_HD_FILER_ADDR_US_L2', 'F9_00_HD_FILER_CITY_US', 'F9_00_HD_FILER_ZIP_US',
   'F9_00_HD_FILER_COUNTRY_FRGN']].sample(5)
# Out:
# CPU times: total: 250 ms
# Wall time: 272 ms
#         F9_00_HD_FILER_ADDR_US_L1 F9_00_HD_FILER_ADDR_US_L2  \
# 2738345                       NaN                       NaN
# 3089207                       NaN                       NaN
# 2809718                       NaN                       NaN
# 2566885                       NaN                       NaN
# 1497007                       NaN                       NaN
#
#         F9_00_HD_FILER_CITY_US F9_00_HD_FILER_ZIP_US  \
# 2738345                    NaN                   NaN
# 3089207                    NaN                   NaN
# 2809718                    NaN                   NaN
# 2566885                    NaN                   NaN
# 1497007                    NaN                   NaN
#
#         F9_00_HD_FILER_COUNTRY_FRGN
# 2738345                          UK
# 3089207                          RQ
# 2809718                          CA
# 2566885                          CA
# 1497007                          KR

# %%
#%%time
#df[['URL', 'F9_00_HD_FILER_ADDR_US_L1', 'F9_00_HD_FILER_ADDR_US_L2', 'F9_00_HD_FILER_CITY_US',
#    'F9_00_HD_FILER_ZIP_US', 'F9_00_HD_FILER_COUNTRY_FRGN']].to_pickle('efile address variables.pkl')
# Out:
# Wall time: 5.21 s

# %% [markdown]
# <br>Process variable for state. As with the four variables parsed above this is another 'two-step' parsing process.

# %% [markdown]
# ##### Update for new XML filings

# %%
#%%time
#df['F9_00_HD_FILER_STATE_US'] = df['Filer'][:].apply(func_onekey, key1='USAddress')
# Out:
# Wall time: 9.41 s

# %%
#%%time
#df['F9_00_HD_FILER_STATE_US'] = df['F9_00_HD_FILER_STATE_US'][:].apply(func, key1='State', key2='StateAbbreviationCd')

# %%
df[['EIN', 'USAddress']].sample(5)
# Out:
#                EIN  \
# 2590898  391860172
# 604154   391563654
# 929665   541648579
# 2781915  222146908
# 2548867  680027507
#
#                                                                                                                          USAddress
# 2590898      {'AddressLine1Txt': '16300 W NATIONAL AVENUE', 'CityNm': 'NEW BERLIN', 'StateAbbreviationCd': 'WI', 'ZIPCd': '53151'}
# 604154                              {'AddressLine1': 'P O BOX 99', 'City': 'BLACK RIVER FALLS', 'State': 'WI', 'ZIPCode': '54615'}
# 929665   {'AddressLine1Txt': '5815 82ND STREET SUITE 145 317', 'CityNm': 'LUBBOCK', 'StateAbbreviationCd': 'TX', 'ZIPCd': '79424'}
# 2781915       {'AddressLine1Txt': '601 WASHINGTON AVENUE', 'CityNm': 'SOUTH AMBOY', 'StateAbbreviationCd': 'NJ', 'ZIPCd': '08879'}
# 2548867        {'AddressLine1Txt': '2577 CALIFORNIA PARK DRIVE', 'CityNm': 'CHICO', 'StateAbbreviationCd': 'CA', 'ZIPCd': '95928'}

# %%
# %%time
#df['F9_00_HD_FILER_STATE_US'] = df['USAddress'][:].apply(func, key1='State', key2='StateAbbreviationCd')
df['F9_00_HD_FILER_STATE_US'] = df['USAddress'].map(lambda d: extract_first_available(d, 'State', 'StateAbbreviationCd'))
# Out:
# CPU times: total: 2.28 s
# Wall time: 2.44 s

# %%
#%%time
#print(len(df[df['F9_00_HD_FILER_STATE_US'].notnull()]))
# Out:
# 3465266
# CPU times: total: 18.8 s
# Wall time: 19.2 s

# %% [markdown]
# #### This is much faster for counting non-nulls

# %%
# %%time
df['F9_00_HD_FILER_STATE_US'].count()  # ✅ Fastest for non-nulls
# Out:
# CPU times: total: 312 ms
# Wall time: 317 ms
# 3465266

# %%
# %%time
df['F9_00_HD_FILER_STATE_US'].isna().sum()
# Out:
# CPU times: total: 281 ms
# Wall time: 313 ms
# 3742

# %%
df[['F9_00_HD_FILER_ADDR_US_L1', 'F9_00_HD_FILER_ADDR_US_L2', 'F9_00_HD_FILER_CITY_US',
                     'F9_00_HD_FILER_COUNTRY_FRGN', 'F9_00_HD_FILER_STATE_US', 'F9_00_HD_FILER_ZIP_US']].count()
# Out:
# F9_00_HD_FILER_ADDR_US_L1      3465266
# F9_00_HD_FILER_ADDR_US_L2        43179
# F9_00_HD_FILER_CITY_US         3465266
# F9_00_HD_FILER_COUNTRY_FRGN       3742
# F9_00_HD_FILER_STATE_US        3465266
# F9_00_HD_FILER_ZIP_US          3465266
# dtype: int64

# %% [markdown]
# <br>The code block above shows that there are 1,810 observations with a value for *Filer* that do not have a value for US state. To check what is going on here, I will run the following code block to show me the *Filer* column for a random sample of five observations that have a value for *Filer* but are missing the state variable. As you can see, the missing values all have a foreign address so we are in good shape.

# %%
#df[(df['Filer'].notnull())&(df['F9_00_HD_FILER_STATE_US'].isnull())][['Filer']].sample(5)
# Out:
#                                                                                                                                                                                                                                                              Filer
# 950575   {'EIN': '980506316', 'BusinessName': {'BusinessNameLine1Txt': 'GSM ASSOCIATION'}, 'InCareOfNm': '% OONAGH STEIN', 'BusinessNameControlTxt': 'GSMA', 'PhoneNum': '2073560600', 'ForeignAddress': {'AddressLine1Txt': 'FLOOR 2 WALBROOK BLDG 25 WALBROOK...
# 159777   {'EIN': '980160122', 'Name': {'BusinessNameLine1': 'Eshel-the Assn for the Planning & Development', 'BusinessNameLine2': 'of Services for the Aged in Israel'}, 'InCareOfName': '% ELIYAHU EREZ', 'NameControl': 'ESHE', 'Phone': '2126876200', 'Forei...
# 420180   {'EIN': '980437032', 'BusinessName': {'BusinessNameLine1': 'CANADIAN LUNG ASSOCIATION'}, 'BusinessNameControlTxt': 'CANA', 'PhoneNum': '6135696411', 'ForeignAddress': {'AddressLine1': '1750 Courtwood Crescent', 'AddressLine2': 'Suite 300', 'City'...
# 1128020  {'EIN': '391522897', 'BusinessName': {'BusinessNameLine1Txt': 'THE BRITISH NORTH AMERICA', 'BusinessNameLine2Txt': 'PHILATELIC SOCIETY LTD'}, 'BusinessNameControlTxt': 'BRIT', 'PhoneNum': '4104422040', 'ForeignAddress': {'AddressLine1Txt': '15 BR...
# 1163810  {'EIN': '981253233', 'BusinessName': {'BusinessNameLine1Txt': 'MUSEUM KAMPA - THE JAN AND MEDA', 'BusinessNameLine2Txt': 'MLADEK FOUNDATION'}, 'BusinessNameControlTxt': 'MUSE', 'PhoneNum': '3017188920', 'ForeignAddress': {'AddressLine1Txt': 'U SO...

# %% [markdown]
# <br>Now show a random sample of the state variable for five observations.

# %%
df[['F9_00_HD_FILER_STATE_US']].sample(5)
# Out:
#         F9_00_HD_FILER_STATE_US
# 2777629                      CA
# 2288069                      NJ
# 2107366                      OH
# 1050425                      IN
# 952436                       NY

# %% [markdown]
# <br>For further verification we can also check a sample of observations that have a value for *F9_00_HD_FILER_COUNTRY_FRGN*. All of the US variables are empty for these five observations so, again, we are in good shape.

# %%
df[df['F9_00_HD_FILER_COUNTRY_FRGN'].notnull()][['F9_00_HD_FILER_ADDR_US_L1', 'F9_00_HD_FILER_ADDR_US_L2', 'F9_00_HD_FILER_CITY_US', 'F9_00_HD_FILER_STATE_US',
    'F9_00_HD_FILER_ZIP_US', 'F9_00_HD_FILER_COUNTRY_FRGN']].sample(5)
# Out:
#         F9_00_HD_FILER_ADDR_US_L1 F9_00_HD_FILER_ADDR_US_L2  \
# 1384129                       NaN                       NaN
# 3356655                       NaN                       NaN
# 2482536                       NaN                       NaN
# 3408835                       NaN                       NaN
# 257288                        NaN                       NaN
#
#         F9_00_HD_FILER_CITY_US F9_00_HD_FILER_STATE_US F9_00_HD_FILER_ZIP_US  \
# 1384129                    NaN                     NaN                   NaN
# 3356655                    NaN                     NaN                   NaN
# 2482536                    NaN                     NaN                   NaN
# 3408835                    NaN                     NaN                   NaN
# 257288                     NaN                     NaN                   NaN
#
#         F9_00_HD_FILER_COUNTRY_FRGN
# 1384129                          CA
# 3356655                          UK
# 2482536                          UK
# 3408835                          UK
# 257288                           CA

# %%
df[['F9_00_HD_FILER_ADDR_US_L1', 'F9_00_HD_FILER_ADDR_US_L2', 'F9_00_HD_FILER_CITY_US', 'F9_00_HD_FILER_STATE_US',
    'F9_00_HD_FILER_ZIP_US', 'F9_00_HD_FILER_COUNTRY_FRGN']].sample(5)
# Out:
#                F9_00_HD_FILER_ADDR_US_L1 F9_00_HD_FILER_ADDR_US_L2  \
# 3436058  1220 VALLEY FORGE ROAD SUITE 16                       NaN
# 2569070             11561 STATE ROUTE 60                       NaN
# 2497768       1010 N UNIVERSITY PARKS DR                       NaN
# 1081701                        PO BOX 12                       NaN
# 240622                  2002 LONDON ROAD                       NaN
#
#         F9_00_HD_FILER_CITY_US F9_00_HD_FILER_STATE_US F9_00_HD_FILER_ZIP_US  \
# 3436058           PHOENIXVILLE                      PA             194602676
# 2569070                 LOWELL                      OH                 45744
# 2497768                   WACO                      TX                 76707
# 1081701              LEXINGTON                      MA                 02420
# 240622                  DULUTH                      MN                 55812
#
#         F9_00_HD_FILER_COUNTRY_FRGN
# 3436058                         NaN
# 2569070                         NaN
# 2497768                         NaN
# 1081701                         NaN
# 240622                          NaN

# %% [markdown]
# <br>Now let's drop *F9_00_HD_FILER_STATE_US* and other 'Filer' variables from *new_variables_df* because they are now dealt with above.

# %%
new_variables_df[:6]
# Out:
#              variable_name_new original_names          sub_keys  \
# 0    F9_00_HD_FILER_ADDR_US_L1        [Filer]       [USAddress]
# 1    F9_00_HD_FILER_ADDR_US_L2        [Filer]       [USAddress]
# 2       F9_00_HD_FILER_CITY_US        [Filer]       [USAddress]
# 3  F9_00_HD_FILER_COUNTRY_FRGN        [Filer]  [ForeignAddress]
# 4      F9_00_HD_FILER_STATE_US        [Filer]       [USAddress]
# 5        F9_00_HD_FILER_ZIP_US        [Filer]       [USAddress]
#
#        data_type_xsd cardinality  len  len_subkeys
# 0  StreetAddressType        None    1            1
# 1  StreetAddressType        None    1            1
# 2           CityType        None    1            1
# 3        CountryType        None    1            1
# 4          StateType        None    1            1
# 5        ZIPCodeType        None    1            1

# %%
variables_to_drop = ['F9_00_HD_FILER_ADDR_US_L1', 'F9_00_HD_FILER_ADDR_US_L2', 'F9_00_HD_FILER_CITY_US',
                     'F9_00_HD_FILER_COUNTRY_FRGN', 'F9_00_HD_FILER_STATE_US', 'F9_00_HD_FILER_ZIP_US']
print(len(new_variables_df))
new_variables_df = new_variables_df[~new_variables_df['variable_name_new'].isin(variables_to_drop)]
print(len(new_variables_df))
# Out:
# 109
# 103

# %%
new_variables_df[:2]
# Out:
#                  variable_name_new                      original_names  \
# 6  F9_00_HD_SIGNING_OFFICER_SIGNTR       [BusinessOfficerGrp, Officer]
# 7     F9_03_PC_PROG_SVC_ACC_2_CODE  [Activity2, ProgSrvcAccomActy2Grp]
#
#                     sub_keys  data_type_xsd cardinality  len  len_subkeys
# 6  [SignatureDt, DateSigned]       DateType        None    2            2
# 7             [ActivityCode]  IntegerNNType        None    2            1

# %% [markdown]
# #### Also drop *Filer* from our PANDAS dataset

# %%
#df = df.drop('Filer', axis=1)

# %% [markdown]
# # 4/17/2025 - These three variables are missing!
# The issue for `F9_03_PC_PROG_SVC_ACC_2_CODE` and `F9_03_PC_PROG_SVC_ACC_3_CODE` is that `ActivityCode` no longers seems to be included. Instead, it is things like {"Expense": "0", "Grants": "0", "Revenue": "0", "Description": "FINANCIAL COUNSELLING"}

# %%
#%%time
#import datetime
#print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
#dfx = pd.read_feather('D:/all_filings_april_2025_all_controls_combined.feather')
#print('# of columns:', len(dfx.columns))
#print('# of observations:', len(dfx))
#dfx[:1]
# Out:
# Current date and time :  2025-04-17 15:51:16
#
# # of columns: 300
# # of observations: 3469008
# CPU times: total: 4min 37s
# Wall time: 4min
#                         _id  \
# 0  5d019e6778ffca27b42818d7
#
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
#
#               DLN TaxPeriod F9_09_PC_FEES_FOR_SVCE_FR_TOT  \
# 0  93493313013011    201012                          None
#
#   F9_00_HD_BUILD_TIME_STAMP fiscal_year        EIN  \
# 0      2016-02-24 21:20:13Z        None  232705170
#
#                                                                                                         Name  \
# 0  {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}
#
#   NameControl       Phone  \
# 0        RONA  8565826843
#
#                                                                                                        USAddress  \
# 0  {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300', 'City': 'BETHLEHEM', 'State': 'PA', 'ZIPCode': '18017'}
#
#   ForeignAddress InCareOfName BusinessName BusinessNameControlTxt PhoneNum  \
# 0           None         None         None                   None     None
#
#   InCareOfNm ForeignPhoneNum  F9_00_HD_ADDR_CHANGE  F9_00_HD_AMENDED_RETURN  \
# 0       None            None                     1                        0
#
#   F9_00_HD_CTRY_OF_DOMICILE  F9_00_HD_EXEMPT_STATUS_4847A1  \
# 0                      None                              0
#
#   F9_00_HD_EXEMPT_STATUS_501C  F9_00_HD_EXEMPT_STATUS_501C3  \
# 0                        None                             1
#
#    F9_00_HD_FINAL_RETURN F9_00_HD_GROSS_EXEMPT_NUM F9_00_HD_GROSS_RCPT  \
# 0                      0                      None             1473903
#
#    F9_00_HD_GROUP_RETURN  F9_00_HD_INCLUDES_SUBORD_ORGS  \
# 0                      0                              0
#
#    F9_00_HD_INITIAL_RETURN F9_00_HD_PRIN_OFF_NAME  \
# 0                        0          MICHAEL ANTON
#
#                                                                                                 F9_00_HD_SIGNING_OFFICER_SIGNTR  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
#
#   F9_00_HD_SPECIAL_CONDITION_DESC F9_00_HD_STATE_OF_DOMICILE  \
# 0                            None                         PA
#
#   F9_00_HD_TAX_PER_BEGIN F9_00_HD_TAX_PER_END F9_00_HD_TAX_YEAR  \
# 0             2010-01-01           2010-12-31              2010
#
#          F9_00_HD_TIME_STAMP  F9_00_HD_TYPE_ORG_ASSOCIATION  \
# 0  2011-11-09T06:41:09-06:00                              0
#
#    F9_00_HD_TYPE_ORG_CORP  F9_00_HD_TYPE_ORG_OTHER  \
# 0                       1                        0
#
#   F9_00_HD_TYPE_ORG_OTHER_DESC  F9_00_HD_TYPE_ORG_TRUST F9_00_HD_WEBSITE  \
# 0                         None                        0              N/A
#
#   F9_00_HD_YEAR_FORMED F9_01_PC_BEN_PAID_MEMB_PRIOR  \
# 0                 1992                            0
#
#   F9_01_PC_CONTR_GRANTS_CURR F9_01_PC_CONTR_GRANTS_PRIOR  \
# 0                    1439340                     1044925
#
#   F9_01_PC_GRANTS_PRIOR F9_01_PC_INDEP_VOTING_MEMB  \
# 0                638637                         10
#
#   F9_01_PC_INVEST_INCOME_PRIOR F9_01_PC_NET_ASSETS_BOY  \
# 0                        30447                 1753405
#
#   F9_01_PC_OTHER_EXPENSE_PRIOR F9_01_PC_OTHER_REV_PRIOR  \
# 0                       243131                        0
#
#   F9_01_PC_PROF_FUNDRISING_EXP_CURR F9_01_PC_PROF_FUNDRISING_EXP_PRIOR  \
# 0                                 0                                  0
#
#   F9_01_PC_PROG_SERVICE_REV_PRIOR F9_01_PC_REV_LESS_EXP_CURR  \
# 0                               0                      89152
#
#   F9_01_PC_REV_LESS_EXP_PRIOR  F9_01_PC_TERMINATION_CONTRACTION  \
# 0                      193604                                 0
#
#   F9_01_PC_TOT_ASSETS_EOY F9_01_PC_TOT_EXP_PRIOR F9_01_PC_TOT_FNDR_EXP_CURR  \
# 0                 2440859                 881768                     195892
#
#   F9_01_PC_TOT_INDIV_EMPLOYED F9_01_PC_TOT_INDIV_VOLUNTEERS  \
# 0                           0                             0
#
#   F9_01_PC_TOT_LIABILITIES_EOY F9_01_PC_TOT_REVENUE_PRIOR  \
# 0                       450430                    1075372
#
#   F9_01_PC_TOT_UBI_GROSS F9_01_PC_TOT_UBI_NET F9_01_PC_VOTING_MEMB_GOV_BODY  \
# 0                      0                    0                            10
#
#   F9_01_PZ_BEN_PAID_TO_MEMB_CURR F9_01_PZ_GRANTS_PAID_CURR  \
# 0                              0                    925000
#
#   F9_01_PZ_INVEST_INCOME_CURR F9_01_PZ_NAFB_EOY  \
# 0                       33563           1990429
#
#                                                             F9_01_PZ_ORGANIZATIONAL_MISSION  \
# 0  MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
#
#   F9_01_PZ_OTHER_EXPENSE_CURR F9_01_PZ_OTHER_REV_CURR  \
# 0                      459751                    1000
#
#   F9_01_PZ_PROG_SERVICE_REV_CURR F9_01_PZ_SALARIES_CURR  \
# 0                              0                      0
#
#   F9_01_PZ_SALARIES_PRIOR F9_01_PZ_TOT_ASSETS_BOY F9_01_PZ_TOT_EXP_CURR  \
# 0                       0                 1925215               1384751
#
#   F9_01_PZ_TOT_LIAB_BOY F9_01_PZ_TOT_REV_CURR  F9_03_PC_PGMSVC_SIGNIF_CHG  \
# 0                171810               1473903                           0
#
#    F9_03_PC_PGMSVC_SIGNIF_NEW F9_03_PC_PROG_SVC_ACC_1_CODE  \
# 0                           0                         None
#
#                                                                                                                                                                                                                                 F9_03_PC_PROG_SVC_ACC_1_DESC  \
# 0  RMHC OF THE PHILADELPHIA REGION, INC. GRANTS HUNDREDS OF THOUSANDS OF DOLLARS PER YEAR TO SUPPORT NON-PROFIT PROGRAMS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN. LOCALLY, RMHC SUPPORTS THE PHILADELPHIA, SOUTHERN NEW JERSEY AND DE...
#
#   F9_03_PC_PROG_SVC_ACC_1_EXP F9_03_PC_PROG_SVC_ACC_1_GRNT  \
# 0                     1043744                       925000
#
#   F9_03_PC_PROG_SVC_ACC_1_REV F9_03_PC_PROG_SVC_ACC_2_CODE  \
# 0                        None                         None
#
#   F9_03_PC_PROG_SVC_ACC_2_DESC F9_03_PC_PROG_SVC_ACC_2_EXP  \
# 0                         None                        None
#
#   F9_03_PC_PROG_SVC_ACC_2_GRNT F9_03_PC_PROG_SVC_ACC_2_REV  \
# 0                         None                        None
#
#   F9_03_PC_PROG_SVC_ACC_3_CODE F9_03_PC_PROG_SVC_ACC_3_DESC  \
# 0                         None                         None
#
#   F9_03_PC_PROG_SVC_ACC_3_EXP F9_03_PC_PROG_SVC_ACC_3_GRNT  \
# 0                        None                         None
#
#   F9_03_PC_PROG_SVC_ACC_3_REV F9_03_PC_TOT_OTH_PROG_SVC_EXP  \
# 0                        None                          None
#
#   F9_03_PC_TOT_OTH_PROG_SVC_GRNT F9_03_PC_TOT_OTH_PROG_SVC_REV  \
# 0                           None                          None
#
#   F9_03_PC_TOT_PROG_SVC_EXPENSE  \
# 0                       1043744
#
#                                                                                                                                                                                                                                 F9_03_PZ_MISSION_DESCRIPTION  \
# 0  THE CORPORATION IS ORGANIZED AND WILL BE OPERATED EXCLUSIVELY FOR CHARITABLE, EDUCATIONAL AND SCIENTIFIC PURPOSES WITHIN THE MEANING OF SECTION 501(C)(3) OF THE INTERNAL REVENUE CODE. SUCH PURPOSES SHALL BE LIMITED TO PROVIDING SUPPORT AND FUNDIN...
#
#    F9_03_PZ_SCHEDULE_O_PART3  F9_04_PC_ACTVITIES_VIA_PARTNER  \
# 0                          1                               0
#
#    F9_04_PC_CONTROLLED_ENTITY  F9_04_PC_DISREGARDED_ENTITY  \
# 0                           0                            0
#
#    F9_04_PC_EXCESS_BENEFIT_TRANS  F9_04_PC_FR_EVENT_INC_GT_15K  \
# 0                              0                             0
#
#    F9_04_PC_GAMING_INC_GT_15K  F9_04_PC_LOBBYING_ACTIVITIES  \
# 0                           0                             0
#
#    F9_04_PC_POLITICAL_ACTIVITIES  F9_04_PC_PRIOR_EXCESS_BEN_TRAN  \
# 0                              0                               0
#
#    F9_04_PC_PROF_FR_EXP_GT_15K  F9_04_PC_RELATED_ENTITY  \
# 0                            0                        0
#
#    F9_04_PC_TRANS_TO_CNTRLD_ENT  F9_04_PC_TRANS_WITH_CNTRLD_ENT  \
# 0                             0                               0
#
#    F9_05_EXP_SCHED_O_X F9_05_PC_NUMBER_EMPLOYEES_W3  \
# 0                    0                            0
#
#   F9_05_PC_NUMBER_FORMS_1096  F9_05_PC_UNRELATED_BUS_INCOME  \
# 0                          0                              0
#
#    F9_06_EXP_SCHED_O_X  F9_06_PC_990_PROVIDED_GOV_BODY  \
# 0                    1                               1
#
#    F9_06_PC_ANNUAL_DISC_COVRD_PERS  F9_06_PC_CEO_COMPENSTN_PROCESS  \
# 0                                1                               0
#
#    F9_06_PC_CHANGES_ORGANIZING_DOCS  F9_06_PC_CONFLICT_OF_INTEREST  \
# 0                                 0                              1
#
#    F9_06_PC_DECISIONS_SUBJ_APPROVAL  F9_06_PC_DELEGATION_MGT_DUTIES  \
# 0                                 0                               0
#
#    F9_06_PC_DELEGATION_OF_MGT  F9_06_PC_DOCUMENT_RET_POLICY  \
# 0                           0                             0
#
#    F9_06_PC_ELECTION_BOARD_MEMBERS  F9_06_PC_FAMILY_OR_BUSINESS_REL  \
# 0                                0                                0
#
#    F9_06_PC_FORM_AVAIL_OWN_WEBSITE  F9_06_PC_FORM_UPON_REQUEST  \
# 0                                0                           1
#
#    F9_06_PC_JOINT_VENTURE_INVESTMNT  F9_06_PC_JOINT_VENTURE_POLICY  \
# 0                                 0                              0
#
#    F9_06_PC_LOCAL_CHAPTERS  F9_06_PC_MATERIAL_DIVERSION  \
# 0                        0                            0
#
#    F9_06_PC_MEMBERS_OR_STOCKHOLDERS  F9_06_PC_MINUTES_COMMITTEES  \
# 0                                 0                            1
#
#    F9_06_PC_MINUTES_GOVERNING_BODY  F9_06_PC_MONITORING_OF_COI_POLICY  \
# 0                                1                                  1
#
#   F9_06_PC_NUM_IND_VOTING_MEMBERS F9_06_PC_NUM_VOTING_GOV_MEMBERS  \
# 0                              10                              10
#
#    F9_06_PC_OFFICER_MAILING_ADDRESS  F9_06_PC_OTHER_COMPENSTN_PROCESS  \
# 0                                 0                                 0
#
#    F9_06_PC_OTHER_WEBSITE  F9_06_PC_OWN_WEBSITE  \
# 0                       0                     0
#
#    F9_06_PC_POLICIES_GOVERN_CHAPTER F9_06_PC_STATES_WHERE_RET_FILED  \
# 0                                 0              ["PA", "NJ", "DE"]
#
#    F9_06_PC_WHISTLEBLOWER_POLICY  F9_07_EXP_SCHED_O_X  \
# 0                              0                    0
#
#    F9_07_PC_COMPENSATION_OTHER_SRCE  F9_07_PC_FORMER_OFFICER_LISTED  \
# 0                                 0                               0
#
#    F9_07_PC_NO_LISTED_PERS_COMPENSD F9_07_PC_NUM_CONTRCTRS_GRTR_100K  \
# 0                                 1                                0
#
#   F9_07_PC_NUM_INDS_GREATER_100K  F9_07_PC_TOTAL_COMP_GRTR_150K  \
# 0                              0                              0
#
#   F9_07_PC_TOT_OTHER_COMPENSATION F9_07_PC_TOT_REPRT_COMP_FROM_ORG  \
# 0                               0                                0
#
#   F9_07_PC_TOT_REPRT_COMP_RLTD_ORG  F9_08_EXP_SCHED_O_X  \
# 0                                0                    0
#
#   F9_08_PC_ALL_OTHER_CONTRIBUTIONS F9_08_PC_CONTS_REPRTD_FNDRAISNG  \
# 0                          1439340                            None
#
#   F9_08_PC_COST_OF_GOODS_SOLD F9_08_PC_FEDERATED_CAMPAIGNS  \
# 0                        None                         None
#
#   F9_08_PC_FUNDRAISING_DIRECT_EXP F9_08_PC_FUNDRAISING_EVENTS  \
# 0                            None                        None
#
#   F9_08_PC_FUNDRAISING_GROSS_INC F9_08_PC_GAMING_DIRECT_EXPENSES  \
# 0                           None                            None
#
#   F9_08_PC_GAMING_GROSS_INCOME F9_08_PC_GOVERNMENT_GRANTS  \
# 0                         None                       None
#
#   F9_08_PC_GROSS_SALES_INVENTORY F9_08_PC_MEMBERSHIP_DUES  \
# 0                           None                     None
#
#   F9_08_PC_NONCASH_CONTRIBUTIONS F9_08_PC_PROGRAM_SVCE_REV_TOTAL  \
# 0                           None                            None
#
#   F9_08_PC_RELATED_ORGANIZATIONS F9_08_PC_TOTAL_CONTRIBUTIONS  \
# 0                           None                      1439340
#
#   F9_08_PC_TOTAL_OTHER_REVENUE F9_08_PC_TOTAL_PROG_SVCE_REVENUE  \
# 0                         1000                             None
#
#                                                                                                                     F9_08_PC_TOTAL_REVENUE  \
# 0  {"TotalRevenueColumn": "1473903", "RelatedOrExemptFunctionIncome": "1000", "UnrelatedBusinessRevenue": "0", "ExclusionAmount": "33563"}
#
#   F9_09_EXP_AD_PROMO_TOT F9_09_EXP_BENF_PAID_MEMB_TOT  \
# 0                   None                         None
#
#   F9_09_EXP_CONF_MEETING_TOT  \
# 0                       None
#
#                                 F9_09_EXP_DEPREC_FUNDR  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
#
#                                   F9_09_EXP_DEPREC_MAG  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
#
#                                  F9_09_EXP_DEPREC_PROG  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
#
#                                   F9_09_EXP_DEPREC_TOT  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
#
#   F9_09_EXP_GRANT_FRGN_TOT                 F9_09_EXP_GRANT_INDIV_DMSTC_TOT  \
# 0                     None  {"Total": "33000", "ProgramServices": "33000"}
#
#                       F9_09_EXP_GRANT_ORG_DMSTC_TOT F9_09_EXP_INFO_TECH_TOT  \
# 0  {"Total": "892000", "ProgramServices": "892000"}                    None
#
#   F9_09_EXP_INSURANCE_TOT F9_09_EXP_INTEREST_TOT F9_09_EXP_JOINT_COSTS_TOT  \
# 0                    None                   None                      None
#
#   F9_09_EXP_OCCUPANCY_TOT                             F9_09_EXP_OFFICE_TOT  \
# 0                    None  {"Total": "123", "ManagementAndGeneral": "123"}
#
#                              F9_09_EXP_OTH_OTH_TOT  \
# 0  {"Total": "763", "ManagementAndGeneral": "763"}
#
#                                                                                                                                                                                                                                            F9_09_EXP_OTH_TOT  \
# 0  [{"Description": "FUNDRAISING COSTS", "Total": "108311", "Fundraising": "108311"}, {"Description": "CANISTER COLLECTION FEE", "Total": "81925", "Fundraising": "81925"}, {"Description": "PR/ADMINISTRATIVE SERVI", "Total": "34517", "ManagementAndGe...
#
#   F9_09_EXP_ROY_TOT  F9_09_EXP_SCHED_O_X F9_09_EXP_TRAVEL_ENTRTNMNT_TOT  \
# 0              None                    0                           None
#
#   F9_09_EXP_TRAVEL_TOT F9_09_PC_COMP_DISQUAL_FUNDRAISE  \
# 0                 None                            None
#
#   F9_09_PC_COMP_DISQUAL_MGMT F9_09_PC_COMP_DISQUAL_PROG_SVCE  \
# 0                       None                            None
#
#   F9_09_PC_COMP_DISQUAL_TOTAL F9_09_PC_COMP_OFFICERS_FUNDRAISE  \
# 0                        None                             None
#
#   F9_09_PC_COMP_OFFICERS_MGMT F9_09_PC_COMP_OFFICERS_PROG_SVCE  \
# 0                        None                             None
#
#   F9_09_PC_COMP_OFFICERS_TOTAL  \
# 0                         None
#
#                        F9_09_PC_FEES_FOR_SVCE_ACCT_TOT  \
# 0  {"Total": "21675", "ManagementAndGeneral": "21675"}
#
#   F9_09_PC_FEES_FOR_SVCE_INVST_TOT  \
# 0                             None
#
#                    F9_09_PC_FEES_FOR_SVCE_LEGL_TOT  \
# 0  {"Total": "215", "ManagementAndGeneral": "215"}
#
#   F9_09_PC_FEES_FOR_SVCE_LOBB_TOT F9_09_PC_FEES_FOR_SVCE_MGMT_TOT  \
# 0                            None                            None
#
#   F9_09_PC_FEES_FOR_SVCE_OTH_TOT F9_09_PC_OTHER_EMP_BEN_FUNDRAISE  \
# 0                           None                             None
#
#   F9_09_PC_OTHER_EMP_BEN_MGMT F9_09_PC_OTHER_EMP_BEN_PROG_SVCE  \
# 0                        None                             None
#
#   F9_09_PC_OTHER_EMP_BEN_TOTAL F9_09_PC_OTHER_SALARY_FUNDRAISE  \
# 0                         None                            None
#
#   F9_09_PC_OTHER_SALARY_MGMT F9_09_PC_OTHER_SALARY_PROG_SVCE  \
# 0                       None                            None
#
#   F9_09_PC_OTHER_SALARY_TOTAL  \
# 0                        None
#
#                      F9_09_PC_PAYMENT_TO_AFFILIATES  \
# 0  {"Total": "118744", "ProgramServices": "118744"}
#
#   F9_09_PC_PAYROLL_TAX_FUNDRAISE F9_09_PC_PAYROLL_TAX_MGMT  \
# 0                           None                      None
#
#   F9_09_PC_PAYROLL_TAX_PROG_SVCE F9_09_PC_PAYROLL_TAX_TOTAL  \
# 0                           None                       None
#
#   F9_09_PC_PENSION_CONT_FUNDRAISE F9_09_PC_PENSION_CONT_MGMT  \
# 0                            None                       None
#
#   F9_09_PC_PENSION_CONT_PROG_SVCE F9_09_PC_PENSION_CONT_TOTAL  \
# 0                            None                        None
#
#                                                                                     F9_09_PC_TOTAL_FUNC_EXPENSES  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
#
#                                                                                 F9_09_PC_TOTAL_FUNDRAISE_EXPENSE  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
#
#                                                                                      F9_09_PC_TOTAL_MGMT_EXPENSE  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
#
#                                                                                 F9_09_PC_TOTAL_PROG_SVCE_EXPENSE  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
#
#              F9_10_ASSETS_ACC_NET_EOY F9_10_ASSETS_EXP_PREPAID_EOY  \
# 0  {"BOY": "103412", "EOY": "147981"}                         None
#
#   F9_10_ASSETS_INTANGIB_EOY F9_10_ASSETS_INVENT_SALE_EOY  \
# 0                      None                         None
#
#     F9_10_ASSETS_LESS_DEPREC_EOY F9_10_ASSETS_LOANS_DISQUAL_EOY  \
# 0  {"BOY": "0", "EOY": "170617"}                           None
#
#   F9_10_ASSETS_NOTES_LOANS_NET_EOY F9_10_ASSETS_OTH_EOY  \
# 0                             None                 None
#
#   F9_10_ASSETS_PLEDGES_NET_EOY        F9_10_LIAB_ACC_PAYABLE_EOY  \
# 0                         None  {"BOY": "39670", "EOY": "44353"}
#
#        F9_10_LIAB_GRANTS_PAYABLE_EOY F9_10_LIAB_LOANS_OFF_EOY  \
# 0  {"BOY": "80500", "EOY": "166000"}                     None
#
#   F9_10_LIAB_REV_DEFERRED_EOY F9_10_NAFB_RESTRICT_PERM_EOY  \
# 0                        None                         None
#
#   F9_10_NAFB_RESTRICT_TEMP_EOY             F9_10_NAFB_UNRESTRICT_EOY  \
# 0                         None  {"BOY": "1753405", "EOY": "1990429"}
#
#   F9_10_PC_BOND_LIABILITY_EOY F9_10_PC_CASH_NON_INTEREST_BOY  \
# 0                        None                           None
#
#   F9_10_PC_CASH_NON_INTEREST_EOY F9_10_PC_ESCROW_LIABILITY_EOY  \
# 0                           None                          None
#
#           F9_10_PC_INVEST_OTHER_SEC_EOY F9_10_PC_INVEST_PROG_RELTD_EOY  \
# 0  {"BOY": "1489143", "EOY": "1851561"}                           None
#
#   F9_10_PC_INVEST_PUB_TRADED_EOY F9_10_PC_LAND_BLDG_EQPMT  \
# 0                           None                   256845
#
#   F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN F9_10_PC_LOANS_FROM_OFFICERS_EOY  \
# 0                            86228                             None
#
#    F9_10_PC_ORG_FOLLOWS_SFAS117  F9_10_PC_ORG_NOT_FOLLOW_SFAS117  \
# 0                             1                                0
#
#       F9_10_PC_OTHER_LIABILITIES_EOY F9_10_PC_RET_EARNINGS_ENDWMT_EOY  \
# 0  {"BOY": "51640", "EOY": "240077"}                             None
#
#      F9_10_PC_SAVINGS_TEMP_INVEST_BOY    F9_10_PC_SAVINGS_TEMP_INVEST_EOY  \
# 0  {"BOY": "332660", "EOY": "270700"}  {"BOY": "332660", "EOY": "270700"}
#
#   F9_10_PC_SECURED_MORTGAGES_EOY F9_10_PC_SECURE_MORT_NOTES_EOY  \
# 0                           None                           None
#
#   F9_10_PC_UNSECURED_LOANS_EOY F9_10_PC_UNSECURED_NOTES_BOY  \
# 0                         None                         None
#
#   F9_10_PC_UNSECURED_NOTES_EOY             F9_10_PZ_TOTAL_ASSETS_EOY  \
# 0                         None  {"BOY": "1925215", "EOY": "2440859"}
#
#    F9_10_SCHED_O_X F9_11_PC_RECNCLTN_DONATED_SVCES  \
# 0                0                            None
#
#   F9_11_PC_RECNCLTN_INVSTMNT_EXP F9_11_PC_RECNCLTN_PRIOR_PER_ADJ  \
# 0                           None                            None
#
#   F9_11_PC_RECNCLTN_REV_LESS_EXP F9_11_PC_RECNCLTN_UNRLZD_GAIN  \
# 0                          89152                          None
#
#    F9_11_SCHED_O_X  F9_12_PC_ACCNT_COMPILE_OR_REVIEW  \
# 0                1                                 0
#
#    F9_12_PC_ACCTG_METHOD_ACCRUAL  F9_12_PC_ACCTG_METHOD_CASH  \
# 0                              1                           0
#
#   F9_12_PC_ACCTG_METHOD_OTHER  F9_12_PC_AUDIT_COMMITTEE  \
# 0                        None                         1
#
#    F9_12_PC_FED_GRNT_AUDIT_PERFORMD  F9_12_PC_FED_GRNT_AUDIT_REQUIRED  \
# 0                                 0                                 0
#
#    F9_12_PC_FINCL_STMTS_AUDITED  F9_12_SCHED_O_X number_of_other_prog_svces  \
# 0                             1                1                       None
#
#    501c3
# 0      1

# %%
#dfx[['F9_03_PC_PROG_SVC_ACC_2_CODE', 'F9_03_PC_PROG_SVC_ACC_3_CODE', 'F9_10_PC_LOANS_FROM_OFFICERS_EOY']].sample(5)
# Out:
#         F9_03_PC_PROG_SVC_ACC_2_CODE F9_03_PC_PROG_SVC_ACC_3_CODE  \
# 60461                           None                         None
# 1930237                         None                         None
# 2474388                         None                         None
# 3090841                         None                         None
# 1369567                         None                         None
#
#         F9_10_PC_LOANS_FROM_OFFICERS_EOY
# 60461                               None
# 1930237                             None
# 2474388                             None
# 3090841                             None
# 1369567                             None

# %%
import gc
gc.collect()
# Out:
# 471

# %% [markdown]
# #### There needs to be `EOY` and `EOYAmt`!!!

# %%
df[df['F9_10_PC_LOANS_FROM_OFFICERS_EOY'].notnull()][[ 'F9_10_PC_LOANS_FROM_OFFICERS_EOY', #'F9_03_PC_PROG_SVC_ACC_1_CODE', 
              'F9_03_PC_PROG_SVC_ACC_2_CODE', 'F9_03_PC_PROG_SVC_ACC_3_CODE']].sample(5)
# Out:
#              F9_10_PC_LOANS_FROM_OFFICERS_EOY  \
# 2060184  {"BOYAmt": "4150", "EOYAmt": "4407"}
# 1926716                   {"EOYAmt": "12000"}
# 1691999        {"BOYAmt": "0", "EOYAmt": "0"}
# 2958495        {"BOYAmt": "0", "EOYAmt": "0"}
# 1622574        {"BOYAmt": "0", "EOYAmt": "0"}
#
#                                                                                                                                                                                                                                     F9_03_PC_PROG_SVC_ACC_2_CODE  \
# 2060184                                                                                                                                                                                                                                                     None
# 1926716                                                                               {"Desc": "THE COALITION PROVIDED INFORMATION IN SPANISH TO INDIVIDUALS NEEDING IMMEDIATE ASSISTANCE AND ALLEVIATED CULTURAL AND LANGUAGE BARRIERS TO ACCESSING SERVICES."}
# 1691999  {"ExpenseAmt": "2300549", "RevenueAmt": "422598", "Desc": "GIFFORD RETIREMENT COMMUNITY, INC., OPENED AN INDEPENDENT LIVING FACILITY IN AUGUST 2017. THIS FACILITY WILL AID THOSE 55 AND OVER LOOKING TO DOWNSIZE AND LIVE A MORE CAREFREE LIFESTYLE."}
# 2958495                                                                                                                                                                                                  {"ExpenseAmt": "0", "GrantAmt": "0", "RevenueAmt": "0"}
# 1622574                                                                                                                                                                                                                                                     None
#
#                                                                                                                                                                                                                                       F9_03_PC_PROG_SVC_ACC_3_CODE
# 2060184                                                                                                                                                                                                                                                       None
# 1926716       {"Desc": "CREATED AND MAINTAINED REGIONAL ASSISTANCE NETWORKS OF BILINQUAL/BICULTURAL SERVICE PROVIDERS, COMMUNITY LEADERS, AND VOLUNTEERS TO DEVELOP STRATEGIES FOR ADDRESSING THE LOCAL NEEDS OF LATINO FAMILINES AND FILLING GAPS IN RESOURCES."}
# 1691999  {"ExpenseAmt": "1271414", "RevenueAmt": "673456", "Desc": "GIFFORD RETIREMENT COMMUNITY, INC. OPERATES TWO ADULT DAY FACILITIES TO SERVE THE NEEDS OF THE ELDERLY AND DISABLED POPULATION IN THE AREA. THE FACILITIES ARE LOCATED IN BETHEL AND BARRE,...
# 2958495                                                                                                                                                                                                    {"ExpenseAmt": "0", "GrantAmt": "0", "RevenueAmt": "0"}
# 1622574                                                                                                                                                                                                                                                       None

# %% [markdown]
# ### Loop over variables with a single sub-key
# Now we'll proceed to a more efficient looping process. First, we will loop over the over the three variables that have a single sub-key and apply our 'one key' function to each of the three variables in turn.

# %%
new_variables_df[new_variables_df['len_subkeys']!=2]
# Out:
#                    variable_name_new  \
# 7       F9_03_PC_PROG_SVC_ACC_2_CODE
# 12      F9_03_PC_PROG_SVC_ACC_3_CODE
# 98  F9_10_PC_LOANS_FROM_OFFICERS_EOY
#
#                                                  original_names  \
# 7                            [Activity2, ProgSrvcAccomActy2Grp]
# 12                           [ProgSrvcAccomActy3Grp, Activity3]
# 98  [LoansFromOfficersDirectorsGrp, LoansFromOfficersDirectors]
#
#           sub_keys  data_type_xsd cardinality  len  len_subkeys
# 7   [ActivityCode]  IntegerNNType        None    2            1
# 12  [ActivityCode]  IntegerNNType        None    2            1
# 98        [EOYAmt]   USAmountType        None    2            1

# %%
new_variables_df.at[
    new_variables_df[new_variables_df['variable_name_new'] == 'F9_10_PC_LOANS_FROM_OFFICERS_EOY'].index[0],
    'sub_keys'] = ['EOYAmt', 'EOY']

# %%
new_variables_df[new_variables_df['len_subkeys']!=2]
# Out:
#                    variable_name_new  \
# 7       F9_03_PC_PROG_SVC_ACC_2_CODE
# 12      F9_03_PC_PROG_SVC_ACC_3_CODE
# 98  F9_10_PC_LOANS_FROM_OFFICERS_EOY
#
#                                                  original_names  \
# 7                            [Activity2, ProgSrvcAccomActy2Grp]
# 12                           [ProgSrvcAccomActy3Grp, Activity3]
# 98  [LoansFromOfficersDirectorsGrp, LoansFromOfficersDirectors]
#
#           sub_keys  data_type_xsd cardinality  len  len_subkeys
# 7   [ActivityCode]  IntegerNNType        None    2            1
# 12  [ActivityCode]  IntegerNNType        None    2            1
# 98   [EOYAmt, EOY]   USAmountType        None    2            1

# %%
#new_variables_df['len_subkeys'] = new_variables_df['sub_keys'].apply(len)

# %% [markdown]
# <br>In the following loop we will loop over each of the three above variables in *new_variables_df* and, taking the variable name and associated sub-key from *new_variables_df*, we will apply our custom ``func_onekey`` function to that variable in our e-filing dataset.

# %%
#df[['LoansFromOfficersDirectors', 'LoansFromOfficersDirectorsGrp']][:2]

# %%
#%%time
#for index, row in new_variables_df[new_variables_df['len_subkeys']!=2].iterrows():
#    variable = row['variable_name_new']
#    keys = row['sub_keys']
#    key = keys[0]
#    #key2 = keys[1]
#    print(variable, key)
#    #print(type(row['variable_name_new']))
#    #df.loc[df.index[index], row['variable_name_new']] = 
#    #df.loc[df.index[45], 'reptrak100-rank-2013 (binary)'] = 0
#    
#    df[variable] = df[variable][:].apply(func_onekey, key1=key)
# Out:
# F9_03_PC_PROG_SVC_ACC_2_CODE ActivityCode
# F9_03_PC_PROG_SVC_ACC_3_CODE ActivityCode
# F9_10_PC_LOANS_FROM_OFFICERS_EOY EOYAmt
# CPU times: total: 20.4 s
# Wall time: 22.6 s

# %% [markdown]
# #### New way
# ✅ Why this is better:
# Uses map() for speed and clarity.
#
# Uses extract_first_available() to avoid rewriting logic.
#
# No slicing ([:]) or use of index from iterrows() needed.
#
# To extend to two keys:
# ```python
# %%time
# for _, row in new_variables_df.iterrows():
#     variable = row['variable_name_new']
#     subkeys = row['sub_keys']
#
#     print(f"Processing: {variable} → {subkeys}")
#
#     df[variable] = df[variable].map(lambda d: extract_first_available(d, *subkeys))
# ```
#
# For example, the last row could be:
# ```python
# df[variable] = df[variable].map(lambda d: extract_first_available(d, 'SignatureDt', 'DateSigned'))
# ```

# %%
new_variables_df[new_variables_df['len_subkeys'] != 2]
# Out:
#                    variable_name_new  \
# 7       F9_03_PC_PROG_SVC_ACC_2_CODE
# 12      F9_03_PC_PROG_SVC_ACC_3_CODE
# 98  F9_10_PC_LOANS_FROM_OFFICERS_EOY
#
#                                                  original_names  \
# 7                            [Activity2, ProgSrvcAccomActy2Grp]
# 12                           [ProgSrvcAccomActy3Grp, Activity3]
# 98  [LoansFromOfficersDirectorsGrp, LoansFromOfficersDirectors]
#
#           sub_keys  data_type_xsd cardinality  len  len_subkeys
# 7   [ActivityCode]  IntegerNNType        None    2            1
# 12  [ActivityCode]  IntegerNNType        None    2            1
# 98   [EOYAmt, EOY]   USAmountType        None    2            1

# %% [markdown]
# #### Convert to dict

# %%
for col in new_variables_df[new_variables_df['len_subkeys'] != 2]['variable_name_new']:
    if col in df.columns:
        print(f"Would convert: {col}")
    else:
        print(f"⚠️ Missing in df: {col}")
# Out:
# Would convert: F9_03_PC_PROG_SVC_ACC_2_CODE
# Would convert: F9_03_PC_PROG_SVC_ACC_3_CODE
# Would convert: F9_10_PC_LOANS_FROM_OFFICERS_EOY

# %%
# %%time
# Apply the conversion to each column directly
for col in new_variables_df[new_variables_df['len_subkeys'] != 2]['variable_name_new']:
    if col in df.columns:
        print(f"Converting {col}...")
        #df[col] = df[col].apply(convert_to_dict)
        df[col] = df[col].map(convert_to_dict)
# Out:
# Converting F9_03_PC_PROG_SVC_ACC_2_CODE...
# Converting F9_03_PC_PROG_SVC_ACC_3_CODE...
# Converting F9_10_PC_LOANS_FROM_OFFICERS_EOY...
# CPU times: total: 16.3 s
# Wall time: 17.1 s

# %% [markdown]
# ### Notes on new loop
# 🔧 TL;DR:
# ✅ Use for _, row in df.iterrows() when you don’t care about the index and want clean access to row values.
#
# ⚠️ Avoid for row in df.iterrows() unless you specifically want both index and Series together and plan to unpack them yourself.

# %%
# %%time
for _, row in new_variables_df[new_variables_df['len_subkeys'] != 2].iterrows():
    variable = row['variable_name_new']
    subkey = row['sub_keys'][0]  # safe since len_subkeys == 1
    new_variable = f"{variable}_alt"  # new column name

    print(f"Processing: {variable} → {subkey} → storing in {new_variable}")
    
    df[new_variable] = df[variable].map(lambda d: extract_first_available(d, subkey))
    df[new_variable] = df[variable].map(lambda d: extract_first_available(d, *row['sub_keys']))
# Out:
# Processing: F9_03_PC_PROG_SVC_ACC_2_CODE → ActivityCode → storing in F9_03_PC_PROG_SVC_ACC_2_CODE_alt
# Processing: F9_03_PC_PROG_SVC_ACC_3_CODE → ActivityCode → storing in F9_03_PC_PROG_SVC_ACC_3_CODE_alt
# Processing: F9_10_PC_LOANS_FROM_OFFICERS_EOY → EOYAmt → storing in F9_10_PC_LOANS_FROM_OFFICERS_EOY_alt
# CPU times: total: 46.6 s
# Wall time: 49.6 s

# %%
df[new_variables_df[new_variables_df['len_subkeys'] != 2]['variable_name_new'].tolist()].isna().sum()
# Out:
# F9_03_PC_PROG_SVC_ACC_2_CODE        2417803
# F9_03_PC_PROG_SVC_ACC_3_CODE        2729652
# F9_10_PC_LOANS_FROM_OFFICERS_EOY    3183768
# dtype: int64

# %%
df[['F9_10_PC_LOANS_FROM_OFFICERS_EOY_alt', 'F9_03_PC_PROG_SVC_ACC_2_CODE_alt', 'F9_03_PC_PROG_SVC_ACC_3_CODE_alt']].isna().sum()
# Out:
# F9_10_PC_LOANS_FROM_OFFICERS_EOY_alt    3203031
# F9_03_PC_PROG_SVC_ACC_2_CODE_alt        3468613
# F9_03_PC_PROG_SVC_ACC_3_CODE_alt        3468726
# dtype: int64

# %%
df[new_variables_df[new_variables_df['len_subkeys'] != 2]['variable_name_new'].tolist()].isna().sum()
# Out:
# F9_03_PC_PROG_SVC_ACC_2_CODE        2415853
# F9_03_PC_PROG_SVC_ACC_3_CODE        2727658
# F9_10_PC_LOANS_FROM_OFFICERS_EOY    3183767
# dtype: int64

# %%
df[df['F9_10_PC_LOANS_FROM_OFFICERS_EOY'].notnull()][['F9_10_PC_LOANS_FROM_OFFICERS_EOY',
                                                      'F9_10_PC_LOANS_FROM_OFFICERS_EOY_alt',
                                'F9_03_PC_PROG_SVC_ACC_2_CODE_alt', 'F9_03_PC_PROG_SVC_ACC_3_CODE_alt']].sample(15)
# Out:
#                  F9_10_PC_LOANS_FROM_OFFICERS_EOY  \
# 1689360            {'BOYAmt': '0', 'EOYAmt': '0'}
# 2834420            {'BOYAmt': '0', 'EOYAmt': '0'}
# 1304733            {'BOYAmt': '0', 'EOYAmt': '0'}
# 220201           {'BOY': '21069', 'EOY': '32574'}
# 1923311            {'BOYAmt': '0', 'EOYAmt': '0'}
# 3050461            {'BOYAmt': '0', 'EOYAmt': '0'}
# 754205                       {'EOYAmt': '134451'}
# 2275782  {'BOYAmt': '764360', 'EOYAmt': '761589'}
# 2852164            {'BOYAmt': '0', 'EOYAmt': '0'}
# 2774044            {'BOYAmt': '0', 'EOYAmt': '0'}
# 2881776    {'BOYAmt': '25110', 'EOYAmt': '22481'}
# 311903                   {'BOY': '0', 'EOY': '0'}
# 3461753            {'BOYAmt': '0', 'EOYAmt': '0'}
# 1343405            {'BOYAmt': '0', 'EOYAmt': '0'}
# 612298             {'BOYAmt': '0', 'EOYAmt': '0'}
#
#         F9_10_PC_LOANS_FROM_OFFICERS_EOY_alt F9_03_PC_PROG_SVC_ACC_2_CODE_alt  \
# 1689360                                    0                              NaN
# 2834420                                    0                              NaN
# 1304733                                    0                              NaN
# 220201                                 32574                              NaN
# 1923311                                    0                              NaN
# 3050461                                    0                              NaN
# 754205                                134451                              NaN
# 2275782                               761589                              NaN
# 2852164                                    0                              NaN
# 2774044                                    0                              NaN
# 2881776                                22481                              NaN
# 311903                                     0                              NaN
# 3461753                                    0                              NaN
# 1343405                                    0                              NaN
# 612298                                     0                              NaN
#
#         F9_03_PC_PROG_SVC_ACC_3_CODE_alt
# 1689360                              NaN
# 2834420                              NaN
# 1304733                              NaN
# 220201                               NaN
# 1923311                              NaN
# 3050461                              NaN
# 754205                               NaN
# 2275782                              NaN
# 2852164                              NaN
# 2774044                              NaN
# 2881776                              NaN
# 311903                               NaN
# 3461753                              NaN
# 1343405                              NaN
# 612298                               NaN

# %%
df[df['F9_03_PC_PROG_SVC_ACC_3_CODE_alt'].notnull()][['F9_10_PC_LOANS_FROM_OFFICERS_EOY_alt', 'F9_03_PC_PROG_SVC_ACC_2_CODE',
                                 'F9_03_PC_PROG_SVC_ACC_2_CODE_alt', 'F9_03_PC_PROG_SVC_ACC_3_CODE',                     
                                 'F9_03_PC_PROG_SVC_ACC_3_CODE_alt']].sample(5)
# Out:
#        F9_10_PC_LOANS_FROM_OFFICERS_EOY_alt  \
# 33778                                   NaN
# 300660                                  NaN
# 191378                                  NaN
# 64688                                   NaN
# 374254                                    0
#
#                                                                                                                                                                                                                                      F9_03_PC_PROG_SVC_ACC_2_CODE  \
# 33778   {'ActivityCode': '713990', 'Expense': '804832', 'Revenue': '1031532', 'Description': 'MEMBERSHIP DUES & ANUAC FEES: MEMBERSHIP DUES ARE ESTABLISHED & COLLECTED TO COVER NORMAL OPERATING EXPENSES OF INDIVIDUAL UNITS. MEMBERSHIP FEES INCLUDE MONTHL...
# 300660                                                                                                             {'ActivityCode': '522130', 'Expense': '138473', 'Revenue': '934818', 'Description': 'INTEREST ON LOANS MADE TO MEMBERS LOAN FEES LOAN LOSSES'}
# 191378                                                                                                                                                        {'ActivityCode': '90099', 'Expense': '13852', 'Description': 'WEDNESDAY NIGHT PROGRAM AND WORSHIP'}
# 64688   {'ActivityCode': '2', 'Grants': '38000', 'Description': 'THE CONTINUOUS BLESSINGS FOUNDATION SPONSORED THE BOYS AND GIRLS CLUB OF WAKE COUNTY PROGRAM WHICH ALLOWS UNDERPRIVILEGED CHILDREN THE OPPORTUNITY TO PARTICIPATE IN AMATEUR ATHLETIC COMPETI...
# 374254  {'ActivityCode': '611710', 'Expense': '1947705', 'Grants': '1930000', 'Description': 'Lightning Community Heroes - Lightning owner Jeff Vinik, along with his wife Penny, launched the Community Heroes initiative at the beginning of the 2011-2012 s...
#
#        F9_03_PC_PROG_SVC_ACC_2_CODE_alt  \
# 33778                            713990
# 300660                           522130
# 191378                            90099
# 64688                                 2
# 374254                           611710
#
#                                                                                                                                                                                                                                      F9_03_PC_PROG_SVC_ACC_3_CODE  \
# 33778   {'ActivityCode': '712110', 'Expense': '279871', 'Revenue': '246601', 'Description': 'MUSEUM ADMISSIONS FOR THE CAF ARE FOR MONIES COLLECTED BY INDIVIDUAL UNITS, LOCATED THROUGHOUT THE UNITED STATES, FOR ENTRY INTO THEIR FACILITIES. FACILITIES ARE...
# 300660                                              {'ActivityCode': '522130', 'Expense': '932492', 'Revenue': '66825', 'Description': 'ALL OTHER INCOME AND EXPENSES THAT SERVE BOTH PROGRAM SERVICES ABOVE INVESTMENT SALARIES BUILDING INSURANCE AUDITS ETC.'}
# 191378                                                                                                                                                      {'ActivityCode': '90099', 'Expense': '6661', 'Description': 'OUTREACH PROGRAMS FOR COLLEGE STUDENTS'}
# 64688                                                                 {'ActivityCode': '3', 'Grants': '2500', 'Description': 'THE CONTINUOUS BLESSINGS FOUNDATION SPONSORED THE FRIENDS OF THE WAKE COUNTY GUARDIAN AD LITEM BACK TO SCHOOL WITH PRIDE PROJECT.'}
# 374254  {'ActivityCode': '611710', 'Expense': '63279', 'Revenue': '62638', 'Description': 'Hockey Camps - Lightning Made Hockey is designed to give hockey players or all ages and skill levels the opportunity to experience, learn, and enjoy the game of ho...
#
#        F9_03_PC_PROG_SVC_ACC_3_CODE_alt
# 33778                            712110
# 300660                           522130
# 191378                            90099
# 64688                                 3
# 374254                           611710

# %% [markdown]
# #### Redo and overwrite

# %%
# %%time
for _, row in new_variables_df[new_variables_df['len_subkeys'] != 2].iterrows():
    variable = row['variable_name_new']
    subkeys = row['sub_keys']  # may be 1 or more

    print(f"Processing: {variable} → {subkeys}")
    
    df[variable] = df[variable].map(lambda d: extract_first_available(d, *subkeys))
# Out:
# Processing: F9_03_PC_PROG_SVC_ACC_2_CODE → ['ActivityCode']
# Processing: F9_03_PC_PROG_SVC_ACC_3_CODE → ['ActivityCode']
# Processing: F9_10_PC_LOANS_FROM_OFFICERS_EOY → ['EOYAmt', 'EOY']
# CPU times: total: 6.48 s
# Wall time: 7.12 s

# %%
df[df['F9_10_PC_LOANS_FROM_OFFICERS_EOY'].notnull()][['F9_10_PC_LOANS_FROM_OFFICERS_EOY', 'F9_10_PC_LOANS_FROM_OFFICERS_EOY_alt', 'F9_03_PC_PROG_SVC_ACC_2_CODE',
                                 'F9_03_PC_PROG_SVC_ACC_2_CODE_alt', 'F9_03_PC_PROG_SVC_ACC_3_CODE',                     
                                 'F9_03_PC_PROG_SVC_ACC_3_CODE_alt']].sample(5)
# Out:
#         F9_10_PC_LOANS_FROM_OFFICERS_EOY F9_10_PC_LOANS_FROM_OFFICERS_EOY_alt  \
# 2270557                                0                                    0
# 2247748                                0                                    0
# 1165550                          3714399                              3714399
# 1156933                                0                                    0
# 3029236                                0                                    0
#
#         F9_03_PC_PROG_SVC_ACC_2_CODE F9_03_PC_PROG_SVC_ACC_2_CODE_alt  \
# 2270557                          NaN                              NaN
# 2247748                          NaN                              NaN
# 1165550                          NaN                              NaN
# 1156933                          NaN                              NaN
# 3029236                          NaN                              NaN
#
#         F9_03_PC_PROG_SVC_ACC_3_CODE F9_03_PC_PROG_SVC_ACC_3_CODE_alt
# 2270557                          NaN                              NaN
# 2247748                          NaN                              NaN
# 1165550                          NaN                              NaN
# 1156933                          NaN                              NaN
# 3029236                          NaN                              NaN

# %%
df[df['F9_03_PC_PROG_SVC_ACC_3_CODE'].notnull()][['F9_10_PC_LOANS_FROM_OFFICERS_EOY_alt', 'F9_03_PC_PROG_SVC_ACC_2_CODE',
                                 'F9_03_PC_PROG_SVC_ACC_2_CODE_alt', 'F9_03_PC_PROG_SVC_ACC_3_CODE',                     
                                 'F9_03_PC_PROG_SVC_ACC_3_CODE_alt']].sample(5)
# Out:
#        F9_10_PC_LOANS_FROM_OFFICERS_EOY_alt F9_03_PC_PROG_SVC_ACC_2_CODE  \
# 120685                                    0                       611110
# 118594                                    0                       561499
# 625578                                  NaN                            2
# 386410                                  NaN                        61100
# 86404                                   NaN                       541900
#
#        F9_03_PC_PROG_SVC_ACC_2_CODE_alt F9_03_PC_PROG_SVC_ACC_3_CODE  \
# 120685                           611110                       611110
# 118594                           561499                       561499
# 625578                                2                            3
# 386410                            61100                       531100
# 86404                            541900                       541900
#
#        F9_03_PC_PROG_SVC_ACC_3_CODE_alt
# 120685                           611110
# 118594                           561499
# 625578                                3
# 386410                           531100
# 86404                            541900

# %%
df = df.drop('F9_10_PC_LOANS_FROM_OFFICERS_EOY_alt', axis=1)
df = df.drop('F9_03_PC_PROG_SVC_ACC_2_CODE_alt', axis=1)
df = df.drop('F9_03_PC_PROG_SVC_ACC_3_CODE_alt', axis=1)

# %%
df[df['F9_03_PC_PROG_SVC_ACC_1_CODE'].notnull()][['F9_03_PC_PROG_SVC_ACC_1_CODE']].sample(5)
# Out:
#         F9_03_PC_PROG_SVC_ACC_1_CODE
# 915594                             0
# 3453945                            0
# 2568973                       310000
# 1595885                          162
# 1574738                       611310

# %% [markdown]
# #### Save DF

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df.to_feather('D:/all_filings_april_2025_all_controls_parsed.feather')
# Out:
# Current date and time :  2025-04-17 21:50:55
#
# CPU times: total: 2min 39s
# Wall time: 2min 10s

# %%
#%%time
#df.to_parquet("D:/all_filings_april_2025_all_controls_combined.parquet", engine="pyarrow", compression="snappy", index=False)

# %%
#%%time
#import datetime
#print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
#df.to_pickle('D:/all_filings_april_2025_all_controls_combined.pkl.gz', compression='gzip')

# %% [markdown]
# <br>We can print out frequencies for the first two variables to verify that the above function worked correctly.

# %%
df['F9_03_PC_PROG_SVC_ACC_2_CODE'].value_counts()
# Out:
# F9_03_PC_PROG_SVC_ACC_2_CODE
# 2         49
# 522130    46
# 900099    34
# 611710    25
# 624100    21
#           ..
# 221100     1
# 110000     1
# 488490     1
# 813410     1
# 711190     1
# Name: count, Length: 88, dtype: int64

# %%
df['F9_03_PC_PROG_SVC_ACC_3_CODE'].value_counts()
# Out:
# F9_03_PC_PROG_SVC_ACC_3_CODE
# 3         35
# 522130    32
# 900099    31
# 611710    22
# 624100    17
#           ..
# 100        1
# 10         1
# 71320      1
# 541100     1
# 623990     1
# Name: count, Length: 64, dtype: int64

# %% [markdown]
# <br>Inspect the data type for the above three variables. All three are 'object' (text) type for now.

# %%
#%%time
#df[['F9_10_PC_LOANS_FROM_OFFICERS_EOY', 'F9_03_PC_PROG_SVC_ACC_2_CODE', 'F9_03_PC_PROG_SVC_ACC_3_CODE']].dtypes
# Out:
# CPU times: total: 8.44 s
# Wall time: 8.97 s
# F9_10_PC_LOANS_FROM_OFFICERS_EOY     object
# F9_03_PC_PROG_SVC_ACC_2_CODE        float64
# F9_03_PC_PROG_SVC_ACC_3_CODE        float64
# dtype: object

# %%
# %%time
df[['F9_10_PC_LOANS_FROM_OFFICERS_EOY', 'F9_03_PC_PROG_SVC_ACC_2_CODE', 'F9_03_PC_PROG_SVC_ACC_3_CODE']].dtypes
# Out:
# CPU times: total: 93.8 ms
# Wall time: 140 ms
# F9_10_PC_LOANS_FROM_OFFICERS_EOY    object
# F9_03_PC_PROG_SVC_ACC_2_CODE        object
# F9_03_PC_PROG_SVC_ACC_3_CODE        object
# dtype: object

# %% [markdown]
# <br>Look at a sample of 10 observations for these three variables.

# %%
df[['F9_10_PC_LOANS_FROM_OFFICERS_EOY', 'F9_03_PC_PROG_SVC_ACC_2_CODE', 'F9_03_PC_PROG_SVC_ACC_3_CODE']].count()
# Out:
# F9_10_PC_LOANS_FROM_OFFICERS_EOY    265977
# F9_03_PC_PROG_SVC_ACC_2_CODE           395
# F9_03_PC_PROG_SVC_ACC_3_CODE           282
# dtype: int64

# %%
df[['F9_10_PC_LOANS_FROM_OFFICERS_EOY', 'F9_03_PC_PROG_SVC_ACC_2_CODE', 'F9_03_PC_PROG_SVC_ACC_3_CODE']].count()/len(df)
# Out:
# F9_10_PC_LOANS_FROM_OFFICERS_EOY    0.076672
# F9_03_PC_PROG_SVC_ACC_2_CODE        0.000114
# F9_03_PC_PROG_SVC_ACC_3_CODE        0.000081
# dtype: float64

# %%
df[['F9_10_PC_LOANS_FROM_OFFICERS_EOY', 'F9_03_PC_PROG_SVC_ACC_2_CODE', 'F9_03_PC_PROG_SVC_ACC_3_CODE']].isna().sum()
# Out:
# F9_10_PC_LOANS_FROM_OFFICERS_EOY    3203031
# F9_03_PC_PROG_SVC_ACC_2_CODE        3468613
# F9_03_PC_PROG_SVC_ACC_3_CODE        3468726
# dtype: int64

# %%
df[['F9_10_PC_LOANS_FROM_OFFICERS_EOY', 'F9_03_PC_PROG_SVC_ACC_2_CODE', 'F9_03_PC_PROG_SVC_ACC_3_CODE']].isna().sum()/len(df)
# Out:
# F9_10_PC_LOANS_FROM_OFFICERS_EOY    0.923328
# F9_03_PC_PROG_SVC_ACC_2_CODE        0.999886
# F9_03_PC_PROG_SVC_ACC_3_CODE        0.999919
# dtype: float64

# %%
# %%time
df[['F9_10_PC_LOANS_FROM_OFFICERS_EOY', 'F9_03_PC_PROG_SVC_ACC_2_CODE', 'F9_03_PC_PROG_SVC_ACC_3_CODE']].sample(15)
# Out:
# CPU times: total: 203 ms
# Wall time: 269 ms
#         F9_10_PC_LOANS_FROM_OFFICERS_EOY F9_03_PC_PROG_SVC_ACC_2_CODE  \
# 635815                               NaN                          NaN
# 3208144                            17257                          NaN
# 2485154                              NaN                          NaN
# 2318258                              NaN                          NaN
# 116894                               NaN                          NaN
# 1973265                              NaN                          NaN
# 1180290                              NaN                          NaN
# 3421205                              NaN                          NaN
# 1723196                              NaN                          NaN
# 1725940                              NaN                          NaN
# 2704122                              NaN                          NaN
# 3178326                              NaN                          NaN
# 2376906                              NaN                          NaN
# 2282138                              NaN                          NaN
# 1008002                              NaN                          NaN
#
#         F9_03_PC_PROG_SVC_ACC_3_CODE
# 635815                           NaN
# 3208144                          NaN
# 2485154                          NaN
# 2318258                          NaN
# 116894                           NaN
# 1973265                          NaN
# 1180290                          NaN
# 3421205                          NaN
# 1723196                          NaN
# 1725940                          NaN
# 2704122                          NaN
# 3178326                          NaN
# 2376906                          NaN
# 2282138                          NaN
# 1008002                          NaN

# %% [markdown]
# <br>Show the three variables in *new_variables_df*. We're using the ``isin()`` function to apply a filter (any rows where the value of *variable_name_new* matches the three in the list.

# %%
new_variables_df[new_variables_df['variable_name_new'].isin(['F9_10_PC_LOANS_FROM_OFFICERS_EOY', 'F9_03_PC_PROG_SVC_ACC_2_CODE', 'F9_03_PC_PROG_SVC_ACC_3_CODE'])]
# Out:
#                    variable_name_new  \
# 7       F9_03_PC_PROG_SVC_ACC_2_CODE
# 12      F9_03_PC_PROG_SVC_ACC_3_CODE
# 98  F9_10_PC_LOANS_FROM_OFFICERS_EOY
#
#                                                  original_names  \
# 7                            [Activity2, ProgSrvcAccomActy2Grp]
# 12                           [ProgSrvcAccomActy3Grp, Activity3]
# 98  [LoansFromOfficersDirectorsGrp, LoansFromOfficersDirectors]
#
#           sub_keys  data_type_xsd cardinality  len  len_subkeys
# 7   [ActivityCode]  IntegerNNType        None    2            1
# 12  [ActivityCode]  IntegerNNType        None    2            1
# 98   [EOYAmt, EOY]   USAmountType        None    2            1

# %% [markdown]
# <br>Drop *F9_10_PC_LOANS_FROM_OFFICERS_EOY*, *F9_03_PC_PROG_SVC_ACC_2_CODE*, and *F9_03_PC_PROG_SVC_ACC_3_CODE* from ``new_variables_df``. They are already dealt with above.

# %%
variables_to_drop = ['F9_10_PC_LOANS_FROM_OFFICERS_EOY', 'F9_03_PC_PROG_SVC_ACC_2_CODE', 'F9_03_PC_PROG_SVC_ACC_3_CODE']
print(len(new_variables_df))
new_variables_df = new_variables_df[~new_variables_df['variable_name_new'].isin(variables_to_drop)]
print(len(new_variables_df))
# Out:
# 103
# 100

# %% [markdown]
# #### Loop and apply main function
# All of the remaining variables in *new_variables_df* have two sub-keys, as verified by the empty data outputted by the following line.

# %%
new_variables_df[new_variables_df['len_subkeys']!=2]
# Out:
# Empty DataFrame
# Columns: [variable_name_new, original_names, sub_keys, data_type_xsd, cardinality, len, len_subkeys]
# Index: []

# %% [markdown]
# <br>I'm pasting in our custom function ``func`` here again to have it handy.

# %%
def func(x, key1, key2):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    elif key1 in x.keys():
        return x[key1]
    elif key2 in x.keys():
        return x[key2]
    else:
        return np.nan

# %% [markdown]
# <br>We can see that there are 100 variables with two sub-keys. We will process all 100 in one loop.

# %%
print(len(new_variables_df[new_variables_df['len_subkeys']!=2]))
print(len(new_variables_df[(new_variables_df['len_subkeys']==2)]))
# Out:
# 0
# 100

# %%
new_variables_df[(new_variables_df['len_subkeys']==2)]
# Out:
#                    variable_name_new  \
# 6    F9_00_HD_SIGNING_OFFICER_SIGNTR
# 8       F9_03_PC_PROG_SVC_ACC_2_DESC
# 9        F9_03_PC_PROG_SVC_ACC_2_EXP
# 10      F9_03_PC_PROG_SVC_ACC_2_GRNT
# 11       F9_03_PC_PROG_SVC_ACC_2_REV
# ..                               ...
# 104   F9_10_PC_SECURE_MORT_NOTES_EOY
# 105     F9_10_PC_UNSECURED_LOANS_EOY
# 106     F9_10_PC_UNSECURED_NOTES_BOY
# 107     F9_10_PC_UNSECURED_NOTES_EOY
# 108        F9_10_PZ_TOTAL_ASSETS_EOY
#
#                                                        original_names  \
# 6                                       [BusinessOfficerGrp, Officer]
# 8                                  [Activity2, ProgSrvcAccomActy2Grp]
# 9                                  [Activity2, ProgSrvcAccomActy2Grp]
# 10                                 [Activity2, ProgSrvcAccomActy2Grp]
# 11                                 [Activity2, ProgSrvcAccomActy2Grp]
# ..                                                                ...
# 104  [MortNotesPyblSecuredInvestProp, MortgNotesPyblScrdInvstPropGrp]
# 105       [UnsecuredNotesLoansPayableGrp, UnsecuredNotesLoansPayable]
# 106       [UnsecuredNotesLoansPayableGrp, UnsecuredNotesLoansPayable]
# 107       [UnsecuredNotesLoansPayableGrp, UnsecuredNotesLoansPayable]
# 108                                     [TotalAssets, TotalAssetsGrp]
#
#                       sub_keys    data_type_xsd cardinality  len  len_subkeys
# 6    [SignatureDt, DateSigned]         DateType        None    2            2
# 8          [Desc, Description]  ExplanationType        None    2            2
# 9        [Expense, ExpenseAmt]     USAmountType        None    2            2
# 10          [GrantAmt, Grants]     USAmountType        None    2            2
# 11       [RevenueAmt, Revenue]     USAmountType        None    2            2
# ..                         ...              ...         ...  ...          ...
# 104              [EOY, EOYAmt]     USAmountType        None    2            2
# 105              [EOYAmt, EOY]     USAmountType        None    2            2
# 106              [BOYAmt, BOY]     USAmountType        None    2            2
# 107              [EOY, EOYAmt]     USAmountType        None    2            2
# 108              [EOYAmt, EOY]     USAmountType        None    2            2
#
# [100 rows x 7 columns]

# %% [markdown]
# ### Main Loop
# Now we will loop over all 100 variables that have two subkeys. For each variable we will apply our custom function ``func``. If you're wondering why there are two keys, recall that each variable, for example ``F9_09_PC_COMP_OFFICERS_TOTAL ``, was the result of combining two different XML sections from the e-file data. Not only were there different variable names, but the nested variable names were distinct. For this example variable there are two different variable 'keys'' -- ``Total`` and ``TotalAmt`` so we will take the values from either of these two keys.
#
# Accordingly, below you will see for each variable a printout of the variable name and the two keys from which we are grabbing data.

# %%
df[['F9_09_EXP_OTH_TOT']].sample(5)
# Out:
#                                                                                                                                                                                                                                                  F9_09_EXP_OTH_TOT
# 2511900  [{"Desc": "COMMISSIONING AND DECOMMISIONING DOCKS", "TotalAmt": "8350", "ProgramServicesAmt": "8350"}, {"Desc": "BANK AND CREDIT CARD PROCESSING FEES", "TotalAmt": "1597", "ProgramServicesAmt": "1597"}, {"Desc": "GENERAL REPAIRS AND MAINTENANCE",...
# 595117   [{"Desc": "POSTAGE & PRINTING", "TotalAmt": "1507027", "ProgramServicesAmt": "1449101", "ManagementAndGeneralAmt": "57926"}, {"Desc": "CREDIT CARD/BANK FEES", "TotalAmt": "676160", "ProgramServicesAmt": "660249", "ManagementAndGeneralAmt": "15911...
# 2950950                                                                                                                                                                                                                                                       None
# 2425050  [{"Desc": "CAMP MAINTENANCE", "TotalAmt": "15424", "ProgramServicesAmt": "15424", "ManagementAndGeneralAmt": "0", "FundraisingAmt": "0"}, {"Desc": "MISCELLANEOUS", "TotalAmt": "9207", "ProgramServicesAmt": "95", "ManagementAndGeneralAmt": "8887",...
# 156309   [{"Description": "BANQUET", "Total": "2686", "ProgramServices": "2686"}, {"Description": "POSTAGE", "Total": "2465", "ProgramServices": "2465"}, {"Description": "ALUMNI SHIRTS", "Total": "761", "ProgramServices": "761"}, {"Description": "LICENSE ...

# %%
#%%time
#for index, row in new_variables_df[new_variables_df['len_subkeys']==2][:].iterrows():
#    variable = row['variable_name_new']
#    keys = row['sub_keys']
#    key1 = keys[0]
#    key2 = keys[1]
#    print(variable, key1, key2)
#    #print(type(row['variable_name_new']))
#    #df.loc[df.index[index], row['variable_name_new']] = 
#    #df.loc[df.index[45], 'reptrak100-rank-2013 (binary)'] = 0
#    
#    df[variable] = df[variable][:].apply(func, key1=key1, key2=key2)
#    #df[variable] = df[variable].astype('float')

# %% [markdown]
# <br>Note that the above will cause an error when we get to the variable *F9_09_EXP_OTH_TOT*. The reason, as you can see below, is that this is the only variable with a *cardinality* value of 'MANY'. So, before running the code, you may want to simply delete *F9_09_EXP_OTH_TOT* from *new_variables_df* before proceeding.
#
# In case you're interested, the error you would see is the following: ``ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()``

# %%
new_variables_df[new_variables_df['variable_name_new']=='F9_09_EXP_OTH_TOT']
# Out:
# Empty DataFrame
# Columns: [variable_name_new, original_names, sub_keys, data_type_xsd, cardinality, len, len_subkeys]
# Index: []

# %% [markdown]
# #### The Fix: Drop *F9_09_EXP_OTH_TOT* from *new_variables_df* and *df*

# %%
variables_to_drop = ['F9_09_EXP_OTH_TOT']
print(len(new_variables_df))
new_variables_df = new_variables_df[~new_variables_df['variable_name_new'].isin(variables_to_drop)]
print(len(new_variables_df))
# Out:
# 100
# 99

# %% [markdown]
# <br>Alternatively, you can skip this variable by running our loop twice. First, modify the second row to stop looping at the 28th element:
#
# ``for index, row in new_variables_df[new_variables_df['len_subkeys']==2][:27].iterrows():``
#
# and then run it again startign at the 29th element:
#
#
# ``for index, row in new_variables_df[new_variables_df['len_subkeys']==2][28:].iterrows():``
#
# The easiest solution, though, is to simply delete *F9_09_EXP_OTH_TOT* from *new_variables_df* and *df* and then run the main loop above. There are few research cases where you might want this variable.

# %% [markdown]
# <br>Here we can see a sample of five rows for *F9_09_EXP_OTH_TOT* and *F9_09_EXP_OTH_OTH_TOT*.

# %%
df[['F9_09_EXP_OTH_TOT', 'F9_09_EXP_OTH_OTH_TOT']].sample(5)
# Out:
#                                                                                                                                                                                                                                                 F9_09_EXP_OTH_TOT  \
# 406557  [{'Desc': 'ASSOCIATION MEMBERSHIPS', 'TotalAmt': '16037', 'ProgramServicesAmt': '10000', 'ManagementAndGeneralAmt': '6037'}, {'Desc': 'PAYMENT PROCESSING FEES', 'TotalAmt': '10485', 'ProgramServicesAmt': '10485'}, {'Desc': 'BANK CHARGES', 'TotalA...
# 30053   [{'Desc': 'TELEPHONE', 'TotalAmt': '7157', 'ProgramServicesAmt': '1638', 'ManagementAndGeneralAmt': '3965', 'FundraisingAmt': '1554'}, {'Desc': 'TRAINING', 'TotalAmt': '2887', 'ProgramServicesAmt': '1010', 'ManagementAndGeneralAmt': '1684', 'Fund...
# 92290          [{'Desc': 'MAINTENANCE CONTRACT', 'TotalAmt': '361255', 'ProgramServicesAmt': '361255'}, {'Desc': 'SUPPLIES', 'TotalAmt': '13973', 'ProgramServicesAmt': '13973'}, {'Desc': 'EQUIPMENT RENTAL', 'TotalAmt': '1002', 'ProgramServicesAmt': '1002'}]
# 496251  [{'Desc': 'SYMPOSIUM EXPENSES', 'TotalAmt': '99172', 'ProgramServicesAmt': '99172'}, {'Desc': 'RECONCILIATION PARK MAI', 'TotalAmt': '98017', 'ProgramServicesAmt': '98017'}, {'Desc': 'FACILITIES AND EQUIPMEN', 'TotalAmt': '13971', 'ManagementAndG...
# 262039  [{'Desc': 'CONSULTING', 'TotalAmt': '12000', 'ProgramServicesAmt': '12000'}, {'Desc': 'PROFESSIONAL SERVICES', 'TotalAmt': '2722', 'ProgramServicesAmt': '2722'}, {'Desc': 'FEES', 'TotalAmt': '1107', 'ProgramServicesAmt': '1107'}, {'Desc': 'ENTERT...
#
#                                                                                            F9_09_EXP_OTH_OTH_TOT
# 406557                                                     {'TotalAmt': '613', 'ManagementAndGeneralAmt': '613'}
# 30053   {'TotalAmt': '396', 'ProgramServicesAmt': '324', 'ManagementAndGeneralAmt': '5', 'FundraisingAmt': '67'}
# 92290                                                                                                        NaN
# 496251                                                   {'TotalAmt': '1956', 'ManagementAndGeneralAmt': '1956'}
# 262039                                                            {'TotalAmt': '98', 'ProgramServicesAmt': '98'}

# %% [markdown]
# <br>Let's drop *F9_09_EXP_OTH_TOT* from our PANDAS dataset.

# %%
df = df.drop('F9_09_EXP_OTH_TOT', axis=1)

# %% [markdown]
# <br>Create a list of all 99 (now) sub-key variables.

# %%
subkey_vars = new_variables_df[new_variables_df['sub_keys'].notnull()]['variable_name_new'].tolist()
print(len(subkey_vars))
# Out:
# 99

# %% [markdown]
# #### Convert to dict

# %%
# %%time
print(len(subkey_vars))
# Print a few non-null values to see what we're working with
sample_values = df[df[subkey_vars[0]].notnull()][subkey_vars[0]].head(3).tolist()
print(f"Sample values from {subkey_vars[0]}:")
for val in sample_values:
    print(f"Value: {val}")
    print(f"Type: {type(val)}")
# Out:
# 99
# Sample values from F9_00_HD_SIGNING_OFFICER_SIGNTR:
# Value: {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
# Type: <class 'str'>
# Value: {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
# Type: <class 'str'>
# Value: {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
# Type: <class 'str'>
# CPU times: total: 40 s
# Wall time: 40.8 s

# %%
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# #### Save DF

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df.to_feather('D:/all_filings_april_2025_all_controls_parsed.feather')
# Out:
# Current date and time :  2025-04-17 22:48:38
#
# CPU times: total: 6min 14s
# Wall time: 7min 10s

# %%
# %%time
# Apply the conversion to each column directly
for col in subkey_vars:
    if col in df.columns:
        print(f"Converting {col}...")
        #df[col] = df[col].apply(convert_to_dict)
        df[col] = df[col].map(convert_to_dict)
# Out:
# Converting F9_00_HD_SIGNING_OFFICER_SIGNTR...
# Converting F9_03_PC_PROG_SVC_ACC_2_DESC...
# Converting F9_03_PC_PROG_SVC_ACC_2_EXP...
# Converting F9_03_PC_PROG_SVC_ACC_2_GRNT...
# Converting F9_03_PC_PROG_SVC_ACC_2_REV...
# Converting F9_03_PC_PROG_SVC_ACC_3_DESC...
# Converting F9_03_PC_PROG_SVC_ACC_3_EXP...
# Converting F9_03_PC_PROG_SVC_ACC_3_GRNT...
# Converting F9_03_PC_PROG_SVC_ACC_3_REV...
# Converting F9_08_PC_TOTAL_REVENUE...
# Converting F9_09_EXP_AD_PROMO_TOT...
# Converting F9_09_EXP_BENF_PAID_MEMB_TOT...
# Converting F9_09_EXP_CONF_MEETING_TOT...
# Converting F9_09_EXP_DEPREC_FUNDR...
# Converting F9_09_EXP_DEPREC_MAG...
# Converting F9_09_EXP_DEPREC_PROG...
# Converting F9_09_EXP_DEPREC_TOT...
# Converting F9_09_EXP_GRANT_FRGN_TOT...
# Converting F9_09_EXP_GRANT_INDIV_DMSTC_TOT...
# Converting F9_09_EXP_GRANT_ORG_DMSTC_TOT...
# Converting F9_09_EXP_INFO_TECH_TOT...
# Converting F9_09_EXP_INSURANCE_TOT...
# Converting F9_09_EXP_INTEREST_TOT...
# Converting F9_09_EXP_JOINT_COSTS_TOT...
# Converting F9_09_EXP_OCCUPANCY_TOT...
# Converting F9_09_EXP_OFFICE_TOT...
# Converting F9_09_EXP_OTH_OTH_TOT...
# Converting F9_09_EXP_ROY_TOT...
# Converting F9_09_EXP_TRAVEL_ENTRTNMNT_TOT...
# Converting F9_09_EXP_TRAVEL_TOT...
# Converting F9_09_PC_COMP_DISQUAL_FUNDRAISE...
# Converting F9_09_PC_COMP_DISQUAL_MGMT...
# Converting F9_09_PC_COMP_DISQUAL_PROG_SVCE...
# Converting F9_09_PC_COMP_DISQUAL_TOTAL...
# Converting F9_09_PC_COMP_OFFICERS_FUNDRAISE...
# Converting F9_09_PC_COMP_OFFICERS_MGMT...
# Converting F9_09_PC_COMP_OFFICERS_PROG_SVCE...
# Converting F9_09_PC_COMP_OFFICERS_TOTAL...
# Converting F9_09_PC_FEES_FOR_SVCE_ACCT_TOT...
# Converting F9_09_PC_FEES_FOR_SVCE_FR_TOT...
# Converting F9_09_PC_FEES_FOR_SVCE_INVST_TOT...
# Converting F9_09_PC_FEES_FOR_SVCE_LEGL_TOT...
# Converting F9_09_PC_FEES_FOR_SVCE_LOBB_TOT...
# Converting F9_09_PC_FEES_FOR_SVCE_MGMT_TOT...
# Converting F9_09_PC_FEES_FOR_SVCE_OTH_TOT...
# Converting F9_09_PC_OTHER_EMP_BEN_FUNDRAISE...
# Converting F9_09_PC_OTHER_EMP_BEN_MGMT...
# Converting F9_09_PC_OTHER_EMP_BEN_PROG_SVCE...
# Converting F9_09_PC_OTHER_EMP_BEN_TOTAL...
# Converting F9_09_PC_OTHER_SALARY_FUNDRAISE...
# Converting F9_09_PC_OTHER_SALARY_MGMT...
# Converting F9_09_PC_OTHER_SALARY_PROG_SVCE...
# Converting F9_09_PC_OTHER_SALARY_TOTAL...
# Converting F9_09_PC_PAYMENT_TO_AFFILIATES...
# Converting F9_09_PC_PAYROLL_TAX_FUNDRAISE...
# Converting F9_09_PC_PAYROLL_TAX_MGMT...
# Converting F9_09_PC_PAYROLL_TAX_PROG_SVCE...
# Converting F9_09_PC_PAYROLL_TAX_TOTAL...
# Converting F9_09_PC_PENSION_CONT_FUNDRAISE...
# Converting F9_09_PC_PENSION_CONT_MGMT...
# Converting F9_09_PC_PENSION_CONT_PROG_SVCE...
# Converting F9_09_PC_PENSION_CONT_TOTAL...
# Converting F9_09_PC_TOTAL_FUNC_EXPENSES...
# Converting F9_09_PC_TOTAL_FUNDRAISE_EXPENSE...
# Converting F9_09_PC_TOTAL_MGMT_EXPENSE...
# Converting F9_09_PC_TOTAL_PROG_SVCE_EXPENSE...
# Converting F9_10_ASSETS_ACC_NET_EOY...
# Converting F9_10_ASSETS_EXP_PREPAID_EOY...
# Converting F9_10_ASSETS_INTANGIB_EOY...
# Converting F9_10_ASSETS_INVENT_SALE_EOY...
# Converting F9_10_ASSETS_LESS_DEPREC_EOY...
# Converting F9_10_ASSETS_LOANS_DISQUAL_EOY...
# Converting F9_10_ASSETS_NOTES_LOANS_NET_EOY...
# Converting F9_10_ASSETS_OTH_EOY...
# Converting F9_10_ASSETS_PLEDGES_NET_EOY...
# Converting F9_10_LIAB_ACC_PAYABLE_EOY...
# Converting F9_10_LIAB_GRANTS_PAYABLE_EOY...
# Converting F9_10_LIAB_LOANS_OFF_EOY...
# Converting F9_10_LIAB_REV_DEFERRED_EOY...
# Converting F9_10_NAFB_RESTRICT_PERM_EOY...
# Converting F9_10_NAFB_RESTRICT_TEMP_EOY...
# Converting F9_10_NAFB_UNRESTRICT_EOY...
# Converting F9_10_PC_BOND_LIABILITY_EOY...
# Converting F9_10_PC_CASH_NON_INTEREST_BOY...
# Converting F9_10_PC_CASH_NON_INTEREST_EOY...
# Converting F9_10_PC_ESCROW_LIABILITY_EOY...
# Converting F9_10_PC_INVEST_OTHER_SEC_EOY...
# Converting F9_10_PC_INVEST_PROG_RELTD_EOY...
# Converting F9_10_PC_INVEST_PUB_TRADED_EOY...
# Converting F9_10_PC_OTHER_LIABILITIES_EOY...
# Converting F9_10_PC_RET_EARNINGS_ENDWMT_EOY...
# Converting F9_10_PC_SAVINGS_TEMP_INVEST_BOY...
# Converting F9_10_PC_SAVINGS_TEMP_INVEST_EOY...
# Converting F9_10_PC_SECURED_MORTGAGES_EOY...
# Converting F9_10_PC_SECURE_MORT_NOTES_EOY...
# Converting F9_10_PC_UNSECURED_LOANS_EOY...
# Converting F9_10_PC_UNSECURED_NOTES_BOY...
# Converting F9_10_PC_UNSECURED_NOTES_EOY...
# Converting F9_10_PZ_TOTAL_ASSETS_EOY...
# CPU times: total: 16min 45s
# Wall time: 17min 14s

# %%
# %%time
print(len(subkey_vars))
# Print a few non-null values to see what we're working with
sample_values = df[df[subkey_vars[0]].notnull()][subkey_vars[0]].head(3).tolist()
print(f"Sample values from {subkey_vars[0]}:")
for val in sample_values:
    print(f"Value: {val}")
    print(f"Type: {type(val)}")
# Out:
# 99
# Sample values from F9_00_HD_SIGNING_OFFICER_SIGNTR:
# Value: {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
# Type: <class 'dict'>
# Value: {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
# Type: <class 'dict'>
# Value: {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
# Type: <class 'dict'>
# CPU times: total: 1min 25s
# Wall time: 2min 36s

# %%
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# ##### Re-run loop
# `4/17/2025 - Use new loop below this one`

# %%
#%%time
#for index, row in new_variables_df[new_variables_df['len_subkeys']==2][:].iterrows():
#    variable = row['variable_name_new']
#    keys = row['sub_keys']
#    key1 = keys[0]
#    key2 = keys[1]
#    print(variable, key1, key2)
#    #print(type(row['variable_name_new']))
#    #df.loc[df.index[index], row['variable_name_new']] = 
#    #df.loc[df.index[45], 'reptrak100-rank-2013 (binary)'] = 0
#    
#    df[variable] = df[variable][:].apply(func, key1=key1, key2=key2)
#    #df[variable] = df[variable].astype('float')
# Out:
# F9_00_HD_SIGNING_OFFICER_SIGNTR SignatureDt DateSigned
# F9_03_PC_PROG_SVC_ACC_2_DESC Description Desc
# F9_03_PC_PROG_SVC_ACC_2_EXP Expense ExpenseAmt
# F9_03_PC_PROG_SVC_ACC_2_GRNT GrantAmt Grants
# F9_03_PC_PROG_SVC_ACC_2_REV RevenueAmt Revenue
# F9_03_PC_PROG_SVC_ACC_3_DESC Description Desc
# F9_03_PC_PROG_SVC_ACC_3_EXP Expense ExpenseAmt
# F9_03_PC_PROG_SVC_ACC_3_GRNT GrantAmt Grants
# F9_03_PC_PROG_SVC_ACC_3_REV RevenueAmt Revenue
# F9_08_PC_TOTAL_REVENUE TotalRevenueColumnAmt TotalRevenueColumn
# F9_09_EXP_AD_PROMO_TOT TotalAmt Total
# F9_09_EXP_BENF_PAID_MEMB_TOT TotalAmt Total
# F9_09_EXP_CONF_MEETING_TOT TotalAmt Total
# F9_09_EXP_DEPREC_FUNDR FundraisingAmt Fundraising
# F9_09_EXP_DEPREC_MAG ManagementAndGeneral ManagementAndGeneralAmt
# F9_09_EXP_DEPREC_PROG ProgramServicesAmt ProgramServices
# F9_09_EXP_DEPREC_TOT TotalAmt Total
# F9_09_EXP_GRANT_FRGN_TOT TotalAmt Total
# F9_09_EXP_GRANT_INDIV_DMSTC_TOT TotalAmt Total
# F9_09_EXP_GRANT_ORG_DMSTC_TOT TotalAmt Total
# F9_09_EXP_INFO_TECH_TOT TotalAmt Total
# F9_09_EXP_INSURANCE_TOT TotalAmt Total
# F9_09_EXP_INTEREST_TOT TotalAmt Total
# F9_09_EXP_JOINT_COSTS_TOT TotalAmt Total
# F9_09_EXP_OCCUPANCY_TOT TotalAmt Total
# F9_09_EXP_OFFICE_TOT TotalAmt Total
# F9_09_EXP_OTH_OTH_TOT TotalAmt Total
# F9_09_EXP_ROY_TOT TotalAmt Total
# F9_09_EXP_TRAVEL_ENTRTNMNT_TOT TotalAmt Total
# F9_09_EXP_TRAVEL_TOT TotalAmt Total
# F9_09_PC_COMP_DISQUAL_FUNDRAISE FundraisingAmt Fundraising
# F9_09_PC_COMP_DISQUAL_MGMT ManagementAndGeneral ManagementAndGeneralAmt
# F9_09_PC_COMP_DISQUAL_PROG_SVCE ProgramServicesAmt ProgramServices
# F9_09_PC_COMP_DISQUAL_TOTAL TotalAmt Total
# F9_09_PC_COMP_OFFICERS_FUNDRAISE FundraisingAmt Fundraising
# F9_09_PC_COMP_OFFICERS_MGMT ManagementAndGeneralAmt ManagementAndGeneral
# F9_09_PC_COMP_OFFICERS_PROG_SVCE ProgramServicesAmt ProgramServices
# F9_09_PC_COMP_OFFICERS_TOTAL TotalAmt Total
# F9_09_PC_FEES_FOR_SVCE_ACCT_TOT TotalAmt Total
# F9_09_PC_FEES_FOR_SVCE_FR_TOT TotalAmt Total
# F9_09_PC_FEES_FOR_SVCE_INVST_TOT TotalAmt Total
# F9_09_PC_FEES_FOR_SVCE_LEGL_TOT TotalAmt Total
# F9_09_PC_FEES_FOR_SVCE_LOBB_TOT TotalAmt Total
# F9_09_PC_FEES_FOR_SVCE_MGMT_TOT TotalAmt Total
# F9_09_PC_FEES_FOR_SVCE_OTH_TOT TotalAmt Total
# F9_09_PC_OTHER_EMP_BEN_FUNDRAISE FundraisingAmt Fundraising
# F9_09_PC_OTHER_EMP_BEN_MGMT ManagementAndGeneral ManagementAndGeneralAmt
# F9_09_PC_OTHER_EMP_BEN_PROG_SVCE ProgramServicesAmt ProgramServices
# F9_09_PC_OTHER_EMP_BEN_TOTAL TotalAmt Total
# F9_09_PC_OTHER_SALARY_FUNDRAISE FundraisingAmt Fundraising
# F9_09_PC_OTHER_SALARY_MGMT ManagementAndGeneral ManagementAndGeneralAmt
# F9_09_PC_OTHER_SALARY_PROG_SVCE ProgramServicesAmt ProgramServices
# F9_09_PC_OTHER_SALARY_TOTAL TotalAmt Total
# F9_09_PC_PAYMENT_TO_AFFILIATES TotalAmt Total
# F9_09_PC_PAYROLL_TAX_FUNDRAISE FundraisingAmt Fundraising
# F9_09_PC_PAYROLL_TAX_MGMT ManagementAndGeneral ManagementAndGeneralAmt
# F9_09_PC_PAYROLL_TAX_PROG_SVCE ProgramServicesAmt ProgramServices
# F9_09_PC_PAYROLL_TAX_TOTAL TotalAmt Total
# F9_09_PC_PENSION_CONT_FUNDRAISE FundraisingAmt Fundraising
# F9_09_PC_PENSION_CONT_MGMT ManagementAndGeneral ManagementAndGeneralAmt
# F9_09_PC_PENSION_CONT_PROG_SVCE ProgramServicesAmt ProgramServices
# F9_09_PC_PENSION_CONT_TOTAL TotalAmt Total
# F9_09_PC_TOTAL_FUNC_EXPENSES TotalAmt Total
# F9_09_PC_TOTAL_FUNDRAISE_EXPENSE FundraisingAmt Fundraising
# F9_09_PC_TOTAL_MGMT_EXPENSE ManagementAndGeneral ManagementAndGeneralAmt
# F9_09_PC_TOTAL_PROG_SVCE_EXPENSE ProgramServicesAmt ProgramServices
# F9_10_ASSETS_ACC_NET_EOY EOY EOYAmt
# F9_10_ASSETS_EXP_PREPAID_EOY EOY EOYAmt
# F9_10_ASSETS_INTANGIB_EOY EOY EOYAmt
# F9_10_ASSETS_INVENT_SALE_EOY EOY EOYAmt
# F9_10_ASSETS_LESS_DEPREC_EOY EOY EOYAmt
# F9_10_ASSETS_LOANS_DISQUAL_EOY EOY EOYAmt
# F9_10_ASSETS_NOTES_LOANS_NET_EOY EOY EOYAmt
# F9_10_ASSETS_OTH_EOY EOY EOYAmt
# F9_10_ASSETS_PLEDGES_NET_EOY EOY EOYAmt
# F9_10_LIAB_ACC_PAYABLE_EOY EOY EOYAmt
# F9_10_LIAB_GRANTS_PAYABLE_EOY EOY EOYAmt
# F9_10_LIAB_LOANS_OFF_EOY EOY EOYAmt
# F9_10_LIAB_REV_DEFERRED_EOY EOY EOYAmt
# F9_10_NAFB_RESTRICT_PERM_EOY EOY EOYAmt
# F9_10_NAFB_RESTRICT_TEMP_EOY EOY EOYAmt
# F9_10_NAFB_UNRESTRICT_EOY EOY EOYAmt
# F9_10_PC_BOND_LIABILITY_EOY EOY EOYAmt
# F9_10_PC_CASH_NON_INTEREST_BOY BOYAmt BOY
# F9_10_PC_CASH_NON_INTEREST_EOY EOY EOYAmt
# F9_10_PC_ESCROW_LIABILITY_EOY EOY EOYAmt
# F9_10_PC_INVEST_OTHER_SEC_EOY EOY EOYAmt
# F9_10_PC_INVEST_PROG_RELTD_EOY EOY EOYAmt
# F9_10_PC_INVEST_PUB_TRADED_EOY EOY EOYAmt
# F9_10_PC_OTHER_LIABILITIES_EOY EOY EOYAmt
# F9_10_PC_RET_EARNINGS_ENDWMT_EOY EOY EOYAmt
# F9_10_PC_SAVINGS_TEMP_INVEST_BOY BOYAmt BOY
# F9_10_PC_SAVINGS_TEMP_INVEST_EOY EOY EOYAmt
# F9_10_PC_SECURED_MORTGAGES_EOY EOY EOYAmt
# F9_10_PC_SECURE_MORT_NOTES_EOY EOY EOYAmt
# F9_10_PC_UNSECURED_LOANS_EOY EOY EOYAmt
# F9_10_PC_UNSECURED_NOTES_BOY BOYAmt BOY
# F9_10_PC_UNSECURED_NOTES_EOY EOY EOYAmt
# F9_10_PZ_TOTAL_ASSETS_EOY EOY EOYAmt
# CPU times: total: 10min 7s
# Wall time: 11min 2s

# %%
# %%time
for _, row in new_variables_df[new_variables_df['len_subkeys'] == 2].iterrows():
    variable = row['variable_name_new']
    subkeys = row['sub_keys']  # will contain exactly two keys

    print(f"Processing: {variable} → {subkeys}")
    
    df[variable] = df[variable].map(lambda d: extract_first_available(d, *subkeys))
# Out:
# Processing: F9_00_HD_SIGNING_OFFICER_SIGNTR → ['SignatureDt', 'DateSigned']
# Processing: F9_03_PC_PROG_SVC_ACC_2_DESC → ['Desc', 'Description']
# Processing: F9_03_PC_PROG_SVC_ACC_2_EXP → ['Expense', 'ExpenseAmt']
# Processing: F9_03_PC_PROG_SVC_ACC_2_GRNT → ['GrantAmt', 'Grants']
# Processing: F9_03_PC_PROG_SVC_ACC_2_REV → ['RevenueAmt', 'Revenue']
# Processing: F9_03_PC_PROG_SVC_ACC_3_DESC → ['Desc', 'Description']
# Processing: F9_03_PC_PROG_SVC_ACC_3_EXP → ['Expense', 'ExpenseAmt']
# Processing: F9_03_PC_PROG_SVC_ACC_3_GRNT → ['GrantAmt', 'Grants']
# Processing: F9_03_PC_PROG_SVC_ACC_3_REV → ['RevenueAmt', 'Revenue']
# Processing: F9_08_PC_TOTAL_REVENUE → ['TotalRevenueColumn', 'TotalRevenueColumnAmt']
# Processing: F9_09_EXP_AD_PROMO_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_BENF_PAID_MEMB_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_CONF_MEETING_TOT → ['Total', 'TotalAmt']
# Processing: F9_09_EXP_DEPREC_FUNDR → ['FundraisingAmt', 'Fundraising']
# Processing: F9_09_EXP_DEPREC_MAG → ['ManagementAndGeneral', 'ManagementAndGeneralAmt']
# Processing: F9_09_EXP_DEPREC_PROG → ['ProgramServicesAmt', 'ProgramServices']
# Processing: F9_09_EXP_DEPREC_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_GRANT_FRGN_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_GRANT_INDIV_DMSTC_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_GRANT_ORG_DMSTC_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_INFO_TECH_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_INSURANCE_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_INTEREST_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_JOINT_COSTS_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_OCCUPANCY_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_OFFICE_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_OTH_OTH_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_ROY_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_EXP_TRAVEL_ENTRTNMNT_TOT → ['Total', 'TotalAmt']
# Processing: F9_09_EXP_TRAVEL_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_PC_COMP_DISQUAL_FUNDRAISE → ['FundraisingAmt', 'Fundraising']
# Processing: F9_09_PC_COMP_DISQUAL_MGMT → ['ManagementAndGeneral', 'ManagementAndGeneralAmt']
# Processing: F9_09_PC_COMP_DISQUAL_PROG_SVCE → ['ProgramServicesAmt', 'ProgramServices']
# Processing: F9_09_PC_COMP_DISQUAL_TOTAL → ['TotalAmt', 'Total']
# Processing: F9_09_PC_COMP_OFFICERS_FUNDRAISE → ['FundraisingAmt', 'Fundraising']
# Processing: F9_09_PC_COMP_OFFICERS_MGMT → ['ManagementAndGeneral', 'ManagementAndGeneralAmt']
# Processing: F9_09_PC_COMP_OFFICERS_PROG_SVCE → ['ProgramServicesAmt', 'ProgramServices']
# Processing: F9_09_PC_COMP_OFFICERS_TOTAL → ['Total', 'TotalAmt']
# Processing: F9_09_PC_FEES_FOR_SVCE_ACCT_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_PC_FEES_FOR_SVCE_FR_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_PC_FEES_FOR_SVCE_INVST_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_PC_FEES_FOR_SVCE_LEGL_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_PC_FEES_FOR_SVCE_LOBB_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_PC_FEES_FOR_SVCE_MGMT_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_PC_FEES_FOR_SVCE_OTH_TOT → ['TotalAmt', 'Total']
# Processing: F9_09_PC_OTHER_EMP_BEN_FUNDRAISE → ['FundraisingAmt', 'Fundraising']
# Processing: F9_09_PC_OTHER_EMP_BEN_MGMT → ['ManagementAndGeneral', 'ManagementAndGeneralAmt']
# Processing: F9_09_PC_OTHER_EMP_BEN_PROG_SVCE → ['ProgramServicesAmt', 'ProgramServices']
# Processing: F9_09_PC_OTHER_EMP_BEN_TOTAL → ['TotalAmt', 'Total']
# Processing: F9_09_PC_OTHER_SALARY_FUNDRAISE → ['FundraisingAmt', 'Fundraising']
# Processing: F9_09_PC_OTHER_SALARY_MGMT → ['ManagementAndGeneral', 'ManagementAndGeneralAmt']
# Processing: F9_09_PC_OTHER_SALARY_PROG_SVCE → ['ProgramServicesAmt', 'ProgramServices']
# Processing: F9_09_PC_OTHER_SALARY_TOTAL → ['TotalAmt', 'Total']
# Processing: F9_09_PC_PAYMENT_TO_AFFILIATES → ['TotalAmt', 'Total']
# Processing: F9_09_PC_PAYROLL_TAX_FUNDRAISE → ['FundraisingAmt', 'Fundraising']
# Processing: F9_09_PC_PAYROLL_TAX_MGMT → ['ManagementAndGeneral', 'ManagementAndGeneralAmt']
# Processing: F9_09_PC_PAYROLL_TAX_PROG_SVCE → ['ProgramServicesAmt', 'ProgramServices']
# Processing: F9_09_PC_PAYROLL_TAX_TOTAL → ['TotalAmt', 'Total']
# Processing: F9_09_PC_PENSION_CONT_FUNDRAISE → ['FundraisingAmt', 'Fundraising']
# Processing: F9_09_PC_PENSION_CONT_MGMT → ['ManagementAndGeneral', 'ManagementAndGeneralAmt']
# Processing: F9_09_PC_PENSION_CONT_PROG_SVCE → ['ProgramServicesAmt', 'ProgramServices']
# Processing: F9_09_PC_PENSION_CONT_TOTAL → ['TotalAmt', 'Total']
# Processing: F9_09_PC_TOTAL_FUNC_EXPENSES → ['TotalAmt', 'Total']
# Processing: F9_09_PC_TOTAL_FUNDRAISE_EXPENSE → ['FundraisingAmt', 'Fundraising']
# Processing: F9_09_PC_TOTAL_MGMT_EXPENSE → ['ManagementAndGeneral', 'ManagementAndGeneralAmt']
# Processing: F9_09_PC_TOTAL_PROG_SVCE_EXPENSE → ['ProgramServicesAmt', 'ProgramServices']
# Processing: F9_10_ASSETS_ACC_NET_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_ASSETS_EXP_PREPAID_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_ASSETS_INTANGIB_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_ASSETS_INVENT_SALE_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_ASSETS_LESS_DEPREC_EOY → ['EOY', 'EOYAmt']
# Processing: F9_10_ASSETS_LOANS_DISQUAL_EOY → ['EOY', 'EOYAmt']
# Processing: F9_10_ASSETS_NOTES_LOANS_NET_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_ASSETS_OTH_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_ASSETS_PLEDGES_NET_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_LIAB_ACC_PAYABLE_EOY → ['EOY', 'EOYAmt']
# Processing: F9_10_LIAB_GRANTS_PAYABLE_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_LIAB_LOANS_OFF_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_LIAB_REV_DEFERRED_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_NAFB_RESTRICT_PERM_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_NAFB_RESTRICT_TEMP_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_NAFB_UNRESTRICT_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_PC_BOND_LIABILITY_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_PC_CASH_NON_INTEREST_BOY → ['BOYAmt', 'BOY']
# Processing: F9_10_PC_CASH_NON_INTEREST_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_PC_ESCROW_LIABILITY_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_PC_INVEST_OTHER_SEC_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_PC_INVEST_PROG_RELTD_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_PC_INVEST_PUB_TRADED_EOY → ['EOY', 'EOYAmt']
# Processing: F9_10_PC_OTHER_LIABILITIES_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_PC_RET_EARNINGS_ENDWMT_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_PC_SAVINGS_TEMP_INVEST_BOY → ['BOYAmt', 'BOY']
# Processing: F9_10_PC_SAVINGS_TEMP_INVEST_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_PC_SECURED_MORTGAGES_EOY → ['EOY', 'EOYAmt']
# Processing: F9_10_PC_SECURE_MORT_NOTES_EOY → ['EOY', 'EOYAmt']
# Processing: F9_10_PC_UNSECURED_LOANS_EOY → ['EOYAmt', 'EOY']
# Processing: F9_10_PC_UNSECURED_NOTES_BOY → ['BOYAmt', 'BOY']
# Processing: F9_10_PC_UNSECURED_NOTES_EOY → ['EOY', 'EOYAmt']
# Processing: F9_10_PZ_TOTAL_ASSETS_EOY → ['EOYAmt', 'EOY']
# CPU times: total: 4min 6s
# Wall time: 4min 26s

# %% [markdown]
# <br>Show a sample of five rows for each of the 99 variables. As you can see none is still 'nested'. Our variable transformations conducted in our main loop above have worked.

# %%
gc.collect()
# Out:
# 0

# %%
# %%time
print(len(df.columns), len(df))
print(len(df[subkey_vars].columns), len(df))
df[subkey_vars].sample(10)
# Out:
# 305 3469008
# 99 3469008
# CPU times: total: 26.3 s
# Wall time: 27.3 s
#         F9_00_HD_SIGNING_OFFICER_SIGNTR  \
# 1865558                      2020-05-06
# 1523879                      2018-11-14
# 1250364                      2017-04-20
# 2758199                      2023-02-21
# 166721                       2012-10-02
# 1157202                      2017-05-15
# 1330976                      2018-03-09
# 1716410                      2019-04-25
# 1050458                      2016-11-14
# 3132598                      2025-01-16
#
#                                                                                                                                                                                                                                       F9_03_PC_PROG_SVC_ACC_2_DESC  \
# 1865558                                                                                                                                                                                                                                                        NaN
# 1523879                                                                                                                                                                                                                                                        NaN
# 1250364                                                                                                                                                                                                                                                        NaN
# 2758199                                              VIVA PROVIDES A LONG TERM CARE FACILITY FOR CATS WHOSE OWNERS HAVE DIED OR CAN NO LONGER CARE FOR THEIR PETS. VIVA ASSUMES ALL RESPONSIBILITY FOR THE CARE OF THE CATS INCLUDING FOOD, LITTER & MEDICAL CARE.
# 166721                                                                                                                                                                                                                                                         NaN
# 1157202                                                                                                                                                                                                                                                        NaN
# 1330976                                                                                                                                                                                                                                                        NaN
# 1716410                                                                                                                                                                                                                                                        NaN
# 1050458  Rose Foundation (EIN #84-0418124), a supporting organization of Rose Community Foundation, makes grants in five primary issue areas within the seven-county Denver community. See Schedule O.A total of $8,711,000 in unrestricted funds was awarded i...
# 3132598                                                                                                                                                                                                                                                        NaN
#
#         F9_03_PC_PROG_SVC_ACC_2_EXP F9_03_PC_PROG_SVC_ACC_2_GRNT  \
# 1865558                         NaN                          NaN
# 1523879                         NaN                          NaN
# 1250364                         NaN                          NaN
# 2758199                       50192                          NaN
# 166721                          NaN                          NaN
# 1157202                         NaN                          NaN
# 1330976                         NaN                          NaN
# 1716410                         NaN                          NaN
# 1050458                         NaN                          NaN
# 3132598                         NaN                          NaN
#
#         F9_03_PC_PROG_SVC_ACC_2_REV  \
# 1865558                         NaN
# 1523879                         NaN
# 1250364                         NaN
# 2758199                         NaN
# 166721                          NaN
# 1157202                         NaN
# 1330976                         NaN
# 1716410                         NaN
# 1050458                         NaN
# 3132598                         NaN
#
#                                                                                                                                                                                                                                       F9_03_PC_PROG_SVC_ACC_3_DESC  \
# 1865558                                                                                                                                                                                                                                                        NaN
# 1523879                                                                                                                                                                                                                                                        NaN
# 1250364                                                                                                                                                                                                                                                        NaN
# 2758199  VIVA ESTABLISHED THE FERAL CAT SANCTUARY IN 2000. FERAL CATS ARE CAUGHT, NEUTERED AND RELEASED. IF THE FERAL CATS CANNOT BE RELEASED TO A COLONY DUE TO UNSAFE CONDITIONS, LACK OF FEED OR THE COLONY HAS DIMINISHED, THE CATS ARE HOUSED AT THE SANCT...
# 166721                                                                                                                                                                                                                                                         NaN
# 1157202                                                                                                                                                                                                                                                        NaN
# 1330976                                                                                                                                                                                                                                                        NaN
# 1716410                                                                                                                                                                                                                                                        NaN
# 1050458                                                                                                                                                                                                                                                        NaN
# 3132598                                                                                                                                                                                                                                                        NaN
#
#         F9_03_PC_PROG_SVC_ACC_3_EXP F9_03_PC_PROG_SVC_ACC_3_GRNT  \
# 1865558                         NaN                          NaN
# 1523879                         NaN                          NaN
# 1250364                         NaN                          NaN
# 2758199                       32317                          NaN
# 166721                          NaN                          NaN
# 1157202                         NaN                          NaN
# 1330976                         NaN                          NaN
# 1716410                         NaN                          NaN
# 1050458                         NaN                          NaN
# 3132598                         NaN                          NaN
#
#         F9_03_PC_PROG_SVC_ACC_3_REV F9_08_PC_TOTAL_REVENUE  \
# 1865558                         NaN                2062335
# 1523879                         NaN                1537298
# 1250364                         NaN                1028711
# 2758199                         NaN                 238185
# 166721                          NaN                1144336
# 1157202                         NaN                1215019
# 1330976                         NaN                 315127
# 1716410                         NaN                1445999
# 1050458                         NaN               26143602
# 3132598                         NaN                 314548
#
#         F9_09_EXP_AD_PROMO_TOT F9_09_EXP_BENF_PAID_MEMB_TOT  \
# 1865558                  13746                          NaN
# 1523879                   3389                            0
# 1250364                    NaN                          NaN
# 2758199                   5727                            0
# 166721                     NaN                          NaN
# 1157202                  41917                          NaN
# 1330976                      0                            0
# 1716410                  20463                          NaN
# 1050458                    NaN                          NaN
# 3132598                    NaN                          NaN
#
#         F9_09_EXP_CONF_MEETING_TOT F9_09_EXP_DEPREC_FUNDR  \
# 1865558                        NaN                    NaN
# 1523879                          0                    NaN
# 1250364                       3473                    NaN
# 2758199                          0                    NaN
# 166721                         NaN                    NaN
# 1157202                        NaN                    NaN
# 1330976                       1844                    NaN
# 1716410                        NaN                    NaN
# 1050458                     120607                    NaN
# 3132598                        NaN                    NaN
#
#         F9_09_EXP_DEPREC_MAG F9_09_EXP_DEPREC_PROG F9_09_EXP_DEPREC_TOT  \
# 1865558                  NaN                   NaN                  NaN
# 1523879                  NaN                  6488                 6488
# 1250364                 2583                 49086                51669
# 2758199                  NaN                   NaN                    0
# 166721                   NaN                   NaN               206444
# 1157202                  109                  2074                 2183
# 1330976                  500                   NaN                  500
# 1716410                 3760                103676               107436
# 1050458                12770                   NaN                12770
# 3132598                17637                   NaN                17637
#
#         F9_09_EXP_GRANT_FRGN_TOT F9_09_EXP_GRANT_INDIV_DMSTC_TOT  \
# 1865558                      NaN                             NaN
# 1523879                   686233                               0
# 1250364                      NaN                             NaN
# 2758199                        0                               0
# 166721                       NaN                             NaN
# 1157202                      NaN                             NaN
# 1330976                        0                               0
# 1716410                      NaN                             NaN
# 1050458                      NaN                             NaN
# 3132598                      NaN                             NaN
#
#         F9_09_EXP_GRANT_ORG_DMSTC_TOT F9_09_EXP_INFO_TECH_TOT  \
# 1865558                          2468                   17343
# 1523879                             0                       0
# 1250364                           NaN                     NaN
# 2758199                             0                       0
# 166721                            NaN                     NaN
# 1157202                           NaN                     NaN
# 1330976                             0                       0
# 1716410                           NaN                    5634
# 1050458                      11799932                     NaN
# 3132598                           NaN                     NaN
#
#         F9_09_EXP_INSURANCE_TOT F9_09_EXP_INTEREST_TOT  \
# 1865558                   59862                    NaN
# 1523879                    6469                   6375
# 1250364                   32349                  11344
# 2758199                   13750                      0
# 166721                    31187                    NaN
# 1157202                   28045                    NaN
# 1330976                       0                      0
# 1716410                   50643                    NaN
# 1050458                   11808                    NaN
# 3132598                    8804                    NaN
#
#         F9_09_EXP_JOINT_COSTS_TOT F9_09_EXP_OCCUPANCY_TOT  \
# 1865558                       NaN                  184402
# 1523879                       NaN                       0
# 1250364                       NaN                   67987
# 2758199                       NaN                   20365
# 166721                        NaN                  155773
# 1157202                       NaN                   74304
# 1330976                       NaN                    1214
# 1716410                       NaN                  125194
# 1050458                       NaN                   76801
# 3132598                       NaN                     NaN
#
#         F9_09_EXP_OFFICE_TOT F9_09_EXP_OTH_OTH_TOT F9_09_EXP_ROY_TOT  \
# 1865558                24976                 70834               NaN
# 1523879                    0                 74468                 0
# 1250364                 9852                 12014               NaN
# 2758199                 6433                     0                 0
# 166721                   NaN                 18109               NaN
# 1157202                20137                  5135               NaN
# 1330976                  128                  8890                 0
# 1716410                 9822                  3781               NaN
# 1050458               183298                   NaN               NaN
# 3132598                 9067                   NaN               NaN
#
#         F9_09_EXP_TRAVEL_ENTRTNMNT_TOT F9_09_EXP_TRAVEL_TOT  \
# 1865558                            NaN                  NaN
# 1523879                              0                13010
# 1250364                            NaN                 1561
# 2758199                              0                    0
# 166721                             NaN                  NaN
# 1157202                            NaN                37634
# 1330976                              0                 1482
# 1716410                            NaN                  290
# 1050458                            NaN                  NaN
# 3132598                            NaN                  NaN
#
#         F9_09_PC_COMP_DISQUAL_FUNDRAISE F9_09_PC_COMP_DISQUAL_MGMT  \
# 1865558                             NaN                        NaN
# 1523879                             NaN                        NaN
# 1250364                             NaN                        NaN
# 2758199                             NaN                        NaN
# 166721                              NaN                        NaN
# 1157202                           13647                      44862
# 1330976                             NaN                        NaN
# 1716410                             NaN                        NaN
# 1050458                             NaN                        NaN
# 3132598                             NaN                        NaN
#
#         F9_09_PC_COMP_DISQUAL_PROG_SVCE F9_09_PC_COMP_DISQUAL_TOTAL  \
# 1865558                             NaN                         NaN
# 1523879                             NaN                           0
# 1250364                             NaN                         NaN
# 2758199                             NaN                           0
# 166721                              NaN                         NaN
# 1157202                          540068                      598577
# 1330976                             NaN                           0
# 1716410                             NaN                         NaN
# 1050458                             NaN                         NaN
# 3132598                             NaN                         NaN
#
#         F9_09_PC_COMP_OFFICERS_FUNDRAISE F9_09_PC_COMP_OFFICERS_MGMT  \
# 1865558                              NaN                       79807
# 1523879                            17500                         NaN
# 1250364                              NaN                         NaN
# 2758199                              NaN                         NaN
# 166721                               NaN                         NaN
# 1157202                              NaN                         NaN
# 1330976                              NaN                         NaN
# 1716410                             4466                      127747
# 1050458                            92721                       51969
# 3132598                              NaN                         NaN
#
#         F9_09_PC_COMP_OFFICERS_PROG_SVCE F9_09_PC_COMP_OFFICERS_TOTAL  \
# 1865558                            79807                       159614
# 1523879                            17500                        35000
# 1250364                              NaN                          NaN
# 2758199                              NaN                            0
# 166721                               NaN                          NaN
# 1157202                              NaN                          NaN
# 1330976                            58269                        58269
# 1716410                           109815                       242028
# 1050458                             6691                       151381
# 3132598                              NaN                          NaN
#
#         F9_09_PC_FEES_FOR_SVCE_ACCT_TOT F9_09_PC_FEES_FOR_SVCE_FR_TOT  \
# 1865558                           15700                           NaN
# 1523879                               0                             0
# 1250364                            8300                           NaN
# 2758199                               0                             0
# 166721                            24600                           NaN
# 1157202                             NaN                           NaN
# 1330976                            3500                             0
# 1716410                           28000                           NaN
# 1050458                           28480                           NaN
# 3132598                             NaN                           NaN
#
#         F9_09_PC_FEES_FOR_SVCE_INVST_TOT F9_09_PC_FEES_FOR_SVCE_LEGL_TOT  \
# 1865558                              NaN                             NaN
# 1523879                                0                               0
# 1250364                              NaN                             NaN
# 2758199                                0                               0
# 166721                               NaN                             NaN
# 1157202                              NaN                           11860
# 1330976                                0                               0
# 1716410                              NaN                            1425
# 1050458                            42504                            1825
# 3132598                             2591                             NaN
#
#         F9_09_PC_FEES_FOR_SVCE_LOBB_TOT F9_09_PC_FEES_FOR_SVCE_MGMT_TOT  \
# 1865558                             NaN                             NaN
# 1523879                               0                               0
# 1250364                             NaN                             NaN
# 2758199                               0                               0
# 166721                              NaN                           21439
# 1157202                             NaN                             NaN
# 1330976                               0                           34365
# 1716410                             NaN                             NaN
# 1050458                             NaN                             NaN
# 3132598                             NaN                             NaN
#
#         F9_09_PC_FEES_FOR_SVCE_OTH_TOT F9_09_PC_OTHER_EMP_BEN_FUNDRAISE  \
# 1865558                          25102                              NaN
# 1523879                          33245                              NaN
# 1250364                           5769                              NaN
# 2758199                              0                              NaN
# 166721                             NaN                              NaN
# 1157202                            NaN                              NaN
# 1330976                              0                              NaN
# 1716410                           6111                              NaN
# 1050458                        1555545                            37659
# 3132598                            NaN                              NaN
#
#         F9_09_PC_OTHER_EMP_BEN_MGMT F9_09_PC_OTHER_EMP_BEN_PROG_SVCE  \
# 1865558                       43068                            35562
# 1523879                         NaN                              NaN
# 1250364                        1963                            63670
# 2758199                         NaN                              NaN
# 166721                          NaN                              NaN
# 1157202                         NaN                              NaN
# 1330976                         NaN                              NaN
# 1716410                        8090                            42409
# 1050458                       21107                            46815
# 3132598                         NaN                              NaN
#
#         F9_09_PC_OTHER_EMP_BEN_TOTAL F9_09_PC_OTHER_SALARY_FUNDRAISE  \
# 1865558                        78630                             NaN
# 1523879                            0                           28132
# 1250364                        65633                            1000
# 2758199                            0                             NaN
# 166721                         66520                             NaN
# 1157202                          NaN                             139
# 1330976                            0                             NaN
# 1716410                        50499                             NaN
# 1050458                       105581                          295776
# 3132598                          NaN                             NaN
#
#         F9_09_PC_OTHER_SALARY_MGMT F9_09_PC_OTHER_SALARY_PROG_SVCE  \
# 1865558                     342160                          574261
# 1523879                     166448                           15098
# 1250364                      46219                          569343
# 2758199                        NaN                           53679
# 166721                         NaN                             NaN
# 1157202                        139                           20556
# 1330976                        NaN                             NaN
# 1716410                      10291                          565989
# 1050458                     165779                          624795
# 3132598                        NaN                          208289
#
#         F9_09_PC_OTHER_SALARY_TOTAL F9_09_PC_PAYMENT_TO_AFFILIATES  \
# 1865558                      916421                            NaN
# 1523879                      209678                              0
# 1250364                      616562                            NaN
# 2758199                       53679                              0
# 166721                       354225                            NaN
# 1157202                       20834                            NaN
# 1330976                           0                              0
# 1716410                      576280                            NaN
# 1050458                     1086350                            NaN
# 3132598                      208289                            NaN
#
#         F9_09_PC_PAYROLL_TAX_FUNDRAISE F9_09_PC_PAYROLL_TAX_MGMT  \
# 1865558                            NaN                     27910
# 1523879                            NaN                       NaN
# 1250364                             90                      4160
# 2758199                            NaN                       NaN
# 166721                             NaN                       NaN
# 1157202                           1321                      4292
# 1330976                            NaN                       NaN
# 1716410                            391                     12915
# 1050458                          25380                     14225
# 3132598                            NaN                       NaN
#
#         F9_09_PC_PAYROLL_TAX_PROG_SVCE F9_09_PC_PAYROLL_TAX_TOTAL  \
# 1865558                          57214                      85124
# 1523879                            NaN                          0
# 1250364                          49144                      53394
# 2758199                           1749                       1749
# 166721                             NaN                      27269
# 1157202                          52277                      57890
# 1330976                            NaN                          0
# 1716410                          63083                      76389
# 1050458                          31747                      71352
# 3132598                          18116                      18116
#
#         F9_09_PC_PENSION_CONT_FUNDRAISE F9_09_PC_PENSION_CONT_MGMT  \
# 1865558                             NaN                      24787
# 1523879                             NaN                        NaN
# 1250364                             NaN                        NaN
# 2758199                             NaN                        NaN
# 166721                              NaN                        NaN
# 1157202                             NaN                        NaN
# 1330976                             NaN                        NaN
# 1716410                             NaN                       1571
# 1050458                           17750                       9949
# 3132598                             NaN                        NaN
#
#         F9_09_PC_PENSION_CONT_PROG_SVCE F9_09_PC_PENSION_CONT_TOTAL  \
# 1865558                             714                       25501
# 1523879                             NaN                           0
# 1250364                             NaN                         NaN
# 2758199                             NaN                           0
# 166721                              NaN                         NaN
# 1157202                             NaN                         NaN
# 1330976                             NaN                           0
# 1716410                            7410                        8981
# 1050458                           19169                       46868
# 3132598                             NaN                         NaN
#
#         F9_09_PC_TOTAL_FUNC_EXPENSES F9_09_PC_TOTAL_FUNDRAISE_EXPENSE  \
# 1865558                      2171712                                0
# 1523879                      1168787                           150086
# 1250364                       967380                             1090
# 2758199                       230097                                0
# 166721                       1232521                              NaN
# 1157202                      1044776                            45000
# 1330976                       287352                                0
# 1716410                      1375919                             5636
# 1050458                     16505897                           620125
# 3132598                       338365                                0
#
#         F9_09_PC_TOTAL_MGMT_EXPENSE F9_09_PC_TOTAL_PROG_SVCE_EXPENSE  \
# 1865558                      643009                          1528703
# 1523879                      282350                           736351
# 1250364                       74915                           891375
# 2758199                        1287                           228810
# 166721                          NaN                              NaN
# 1157202                       78526                           921250
# 1330976                      115433                           171919
# 1716410                      216505                          1153778
# 1050458                      742187                         15143585
# 3132598                       60339                           278026
#
#         F9_10_ASSETS_ACC_NET_EOY F9_10_ASSETS_EXP_PREPAID_EOY  \
# 1865558                    55733                        17537
# 1523879                        0                            0
# 1250364                      NaN                         9042
# 2758199                        0                            0
# 166721                       NaN                        17587
# 1157202                      NaN                          300
# 1330976                     9708                            0
# 1716410                       49                        19398
# 1050458                   238835                        91267
# 3132598                      NaN                          NaN
#
#         F9_10_ASSETS_INTANGIB_EOY F9_10_ASSETS_INVENT_SALE_EOY  \
# 1865558                       NaN                        35461
# 1523879                         0                            0
# 1250364                       NaN                          NaN
# 2758199                         0                            0
# 166721                        NaN                          NaN
# 1157202                       NaN                          NaN
# 1330976                         0                            0
# 1716410                       NaN                          NaN
# 1050458                       NaN                        23540
# 3132598                       NaN                          NaN
#
#         F9_10_ASSETS_LESS_DEPREC_EOY F9_10_ASSETS_LOANS_DISQUAL_EOY  \
# 1865558                          NaN                            NaN
# 1523879                       383327                              0
# 1250364                      1319595                            NaN
# 2758199                       525584                              0
# 166721                       4184118                            NaN
# 1157202                         9173                            NaN
# 1330976                          300                              0
# 1716410                      1226743                            NaN
# 1050458                       101216                            NaN
# 3132598                        55888                            NaN
#
#         F9_10_ASSETS_NOTES_LOANS_NET_EOY F9_10_ASSETS_OTH_EOY  \
# 1865558                              NaN                    0
# 1523879                                0                    0
# 1250364                              NaN                  NaN
# 2758199                                0                    0
# 166721                               NaN               167337
# 1157202                              NaN                13491
# 1330976                                0                    0
# 1716410                              NaN                  NaN
# 1050458                              NaN              1289598
# 3132598                              600                 5410
#
#         F9_10_ASSETS_PLEDGES_NET_EOY F9_10_LIAB_ACC_PAYABLE_EOY  \
# 1865558                          NaN                     130841
# 1523879                            0                      17714
# 1250364                        45174                      44863
# 2758199                            0                        NaN
# 166721                           NaN                       2085
# 1157202                       336286                      16649
# 1330976                            0                       7231
# 1716410                          NaN                      62421
# 1050458                      4577914                     246762
# 3132598                          NaN                       6746
#
#         F9_10_LIAB_GRANTS_PAYABLE_EOY F9_10_LIAB_LOANS_OFF_EOY  \
# 1865558                           NaN                      NaN
# 1523879                           NaN                      NaN
# 1250364                           NaN                      NaN
# 2758199                           NaN                      NaN
# 166721                            NaN                      NaN
# 1157202                           NaN                      NaN
# 1330976                           NaN                      NaN
# 1716410                           NaN                      NaN
# 1050458                       2018400                      NaN
# 3132598                           NaN                      NaN
#
#         F9_10_LIAB_REV_DEFERRED_EOY F9_10_NAFB_RESTRICT_PERM_EOY  \
# 1865558                           0                          NaN
# 1523879                         NaN                          NaN
# 1250364                         NaN                          NaN
# 2758199                         NaN                          NaN
# 166721                          NaN                          NaN
# 1157202                         NaN                          NaN
# 1330976                         NaN                          NaN
# 1716410                       49544                          NaN
# 1050458                         NaN                       290220
# 3132598                         NaN                          NaN
#
#         F9_10_NAFB_RESTRICT_TEMP_EOY F9_10_NAFB_UNRESTRICT_EOY  \
# 1865558                          NaN                   -134968
# 1523879                        83432                    582383
# 1250364                          NaN                    710097
# 2758199                          NaN                       NaN
# 166721                           NaN                       NaN
# 1157202                        13491                    380688
# 1330976                          NaN                    197691
# 1716410                          NaN                   1852910
# 1050458                      5913894                  33307741
# 3132598                          NaN                       NaN
#
#         F9_10_PC_BOND_LIABILITY_EOY F9_10_PC_CASH_NON_INTEREST_BOY  \
# 1865558                         NaN                         102518
# 1523879                         NaN                          74447
# 1250364                         NaN                            950
# 2758199                         NaN                         220402
# 166721                          NaN                         210907
# 1157202                         NaN                         101072
# 1330976                         NaN                         118655
# 1716410                         NaN                         372081
# 1050458                         NaN                        6364724
# 3132598                         NaN                         456679
#
#         F9_10_PC_CASH_NON_INTEREST_EOY F9_10_PC_ESCROW_LIABILITY_EOY  \
# 1865558                         135698                           NaN
# 1523879                         404094                           NaN
# 1250364                            950                           NaN
# 2758199                         228436                           NaN
# 166721                          465772                           NaN
# 1157202                          51578                           NaN
# 1330976                         194914                           NaN
# 1716410                         299983                           NaN
# 1050458                        7841030                           NaN
# 3132598                         430958                           NaN
#
#         F9_10_PC_INVEST_OTHER_SEC_EOY F9_10_PC_INVEST_PROG_RELTD_EOY  \
# 1865558                           NaN                            NaN
# 1523879                             0                              0
# 1250364                           NaN                            NaN
# 2758199                             0                              0
# 166721                            NaN                            NaN
# 1157202                           NaN                            NaN
# 1330976                             0                              0
# 1716410                           NaN                            NaN
# 1050458                      75858988                            NaN
# 3132598                        303248                            NaN
#
#         F9_10_PC_INVEST_PUB_TRADED_EOY F9_10_PC_OTHER_LIABILITIES_EOY  \
# 1865558                            NaN                         289540
# 1523879                              0                            NaN
# 1250364                            NaN                          13949
# 2758199                          30000                            NaN
# 166721                             NaN                          14955
# 1157202                            NaN                            NaN
# 1330976                              0                            NaN
# 1716410                          66945                            NaN
# 1050458                            NaN                       48245371
# 3132598                            NaN                            NaN
#
#         F9_10_PC_RET_EARNINGS_ENDWMT_EOY F9_10_PC_SAVINGS_TEMP_INVEST_BOY  \
# 1865558                              NaN                            40958
# 1523879                              NaN                              NaN
# 1250364                              NaN                           116820
# 2758199                          1148644                           364570
# 166721                           -108941                          3691720
# 1157202                              NaN                              NaN
# 1330976                              NaN                              NaN
# 1716410                              NaN                              NaN
# 1050458                              NaN                              NaN
# 3132598                           977488                           182500
#
#         F9_10_PC_SAVINGS_TEMP_INVEST_EOY F9_10_PC_SECURED_MORTGAGES_EOY  \
# 1865558                            40984                            NaN
# 1523879                                0                         103892
# 1250364                           264852                         870704
# 2758199                           364624                            NaN
# 166721                           3196372                            NaN
# 1157202                              NaN                            NaN
# 1330976                                0                            NaN
# 1716410                           351757                            NaN
# 1050458                              NaN                            NaN
# 3132598                           188130                            NaN
#
#         F9_10_PC_SECURE_MORT_NOTES_EOY F9_10_PC_UNSECURED_LOANS_EOY  \
# 1865558                            NaN                          NaN
# 1523879                         103892                          NaN
# 1250364                         870704                          NaN
# 2758199                            NaN                          NaN
# 166721                             NaN                          NaN
# 1157202                            NaN                          NaN
# 1330976                            NaN                          NaN
# 1716410                            NaN                          NaN
# 1050458                            NaN                          NaN
# 3132598                            NaN                          NaN
#
#         F9_10_PC_UNSECURED_NOTES_BOY F9_10_PC_UNSECURED_NOTES_EOY  \
# 1865558                          NaN                          NaN
# 1523879                          NaN                          NaN
# 1250364                          NaN                          NaN
# 2758199                          NaN                          NaN
# 166721                           NaN                          NaN
# 1157202                          NaN                          NaN
# 1330976                          NaN                          NaN
# 1716410                          NaN                          NaN
# 1050458                          NaN                          NaN
# 3132598                          NaN                          NaN
#
#         F9_10_PZ_TOTAL_ASSETS_EOY
# 1865558                    285413
# 1523879                    787421
# 1250364                   1639613
# 2758199                   1148644
# 166721                    8031186
# 1157202                    410828
# 1330976                    204922
# 1716410                   1964875
# 1050458                  90022388
# 3132598                    984234

# %% [markdown]
# ### Look at 501(c)(3)s

# %%
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
# Out:
# # of columns: 305
# # of observations: 3469008

# %%
df['501c3'].value_counts()
# Out:
# 501c3
# 1    2637781
# 0     831227
# Name: count, dtype: int64

# %%
print(len(df[df['501c3']==1]))
# Out:
# 2637781

# %% [markdown]
# #### Create and save list of EINs for BMF File

# %%
ein_list_2025_new = df[df['501c3']==1]['EIN'].tolist()
print(len(ein_list_2025_new))
print(len(set(ein_list_2025_new)))
ein_list_2025_new = list(set(ein_list_2025_new))
print(len(ein_list_2025_new))
# Out:
# 2637781
# 353116
# 353116

# %%
gc.collect()
# Out:
# 476

# %%
import json
with open('ein_list_501c3_new_2025.json', 'w') as fp:
    json.dump(ein_list_2025_new, fp)

# %% [markdown]
# ### Check for which variables might be missing

# %%
new_cols = concordance[:]['variable_name_new'].tolist()
print(len(new_cols))
print(len(set(new_cols)))
new_cols = list(set(new_cols))
print(len(new_cols))
print(new_cols[:5])
# Out:
# 574
# 288
# 288
# ['F9_04_PC_PROF_FR_EXP_GT_15K', 'F9_00_HD_EXEMPT_STATUS_501C', 'F9_01_PC_TOT_UBI_NET', 'F9_09_PC_TOTAL_FUNC_EXPENSES', 'F9_00_HD_TYPE_ORG_CORP']

# %% [markdown]
# <br>As shown in the next code block, only one variables is missing, which we deleted.

# %%
set(new_cols) - set(df.columns.tolist())
# Out:
# {'F9_09_EXP_OTH_TOT'}

# %%
set(df.columns.tolist()) - set(new_cols)
# Out:
# {'501c3',
#  'BusinessName',
#  'BusinessNameControlTxt',
#  'DLN',
#  'EIN',
#  'ForeignAddress',
#  'ForeignPhoneNum',
#  'InCareOfName',
#  'InCareOfNm',
#  'Name',
#  'NameControl',
#  'OrganizationName',
#  'Phone',
#  'PhoneNum',
#  'URL',
#  'USAddress',
#  '_id',
#  'fiscal_year'}

# %% [markdown]
# #### Save DF

# %%
len(df)
# Out:
# 3469008

# %%
def prepare_for_save(df):
    import gc

    # Drop any cached views
    df = df.copy()  # Break reference to any partial evaluation from .head(), etc.

    # Optionally sort or reset if needed
    # df = df.sort_values("some_column")  # Only if relevant
    # df = df.reset_index(drop=True)

    # Trigger garbage collection
    gc.collect()

    print("🧼 DataFrame copied + garbage collected. Ready to save.")
    return df

# %%
# Step 2: Clean up df (especially if you’ve been doing .head(), .sort(), etc.)
df = prepare_for_save(df)

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df.to_feather('D:/all_filings_april_2025_all_controls_combined_parsed.feather')
# Out:
# Current date and time :  2025-04-18 00:30:15
#
# CPU times: total: 1min 43s
# Wall time: 1min 34s

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df.to_parquet("D:/all_filings_april_2025_all_controls_combined_parsed.parquet", engine="pyarrow", compression="snappy", index=False)
# Out:
# Current date and time :  2025-04-18 00:37:47
#
# CPU times: total: 2min 31s
# Wall time: 2min 36s

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df.to_pickle('D:/all_filings_april_2025_all_controls_combined_parsed.pkl.gz', compression='gzip')
# Out:
# Current date and time :  2025-04-18 00:41:12
#
# CPU times: total: 30min 11s
# Wall time: 30min 47s
