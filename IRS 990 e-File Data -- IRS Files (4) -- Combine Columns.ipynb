# %% [markdown]
# #### Update of this notebook:
# - *IRS Form 990 e-File Data (4) -- Combine Columns -- DOWNLOADED XML FILINGS.ipynb*

# %% [markdown]
# # Overview
#
# This is the fourth in a series of tutorials that illustrate how to download, parse, and analyze the IRS 990 e-file data available at https://aws.amazon.com/public-data-sets/irs-990/
#
# In the previous notebook we extracted the JSON data from our MongoDB database into a Python PANDAS dataset. In this notebook I first read in the 'concordance' file and the e-file dataset that was generated in the previous notebook:
# - *all filings August 2022 - all control variables.pkl.gz*
#
# Regarding the concordance file, recall that the 990 e-file data contains myriad variables, each of which has to be verified before extracting and analyzing. Among other issues, most variables have more than one name in the XML files. Working with Jesse Lecy at Arizona State and others, a group of us has come up with a "concordance" file containing the *xpath* of all verified variables. Among other things, this concordance file maps the specific lines from the Form 990 to the xpaths in the XML file and contains a standardized, more descriptive variable name. Accordingly, we will read in the concordance file that has **_all_** reconciled and verified variables to date:
# - *concordance_VERIFIED.xlsx*
#
# I then use information contained in the concordance file to combine pairs of columns that reflect the same 990 variable, such as *TaxPeriodBeginDt* and *TaxPeriodBeginDate*, and assign the relevant 'standardized' name from the concordance file, such as *F9_00_HD_TAX_PER_BEGIN*. I then 'binarize' relevant columns and delete unneeded columns.
#
# Saved final file (N=2,104,435):
# - *all filings August 2022 - all control variables (renamed).pkl.gz*
#
#
# *Notes:*
# - This notebook was updated to use information in the 'BINARIZE' column in the concordance file in order to identify relevant variables (those with a mix of 'True', 1, 0, 'False', 'X', etc.).
#
# - This notebook was also recently updated to take into account a new way of creating the *ReturnHeader* variables. Namely, I have updated the concordance file to include additional *ReturnHeader* variables. I have also changed the MongoDB name to be not, for example, 'ReturnHeader.TaxYear' but instead 'ReturnHeader'. In the first notebook in this series I flatten the *ReturnHeader* column and then I do the combining and renaming. So, I need to make sure the changes are followed through in subsequent notebooks to parse the following variables:
#
#     - 'ReturnHeader.TaxYear': 1, 'ReturnHeader.TaxYr': 1,
#     - 'ReturnHeader.TaxPeriodEndDate': 1, 'ReturnHeader.TaxPeriodEndDt': 1,
#     - 'ReturnHeader.TaxPeriodBeginDate': 1, 'ReturnHeader.TaxPeriodBeginDt': 1,
#
# - Similarly, I needed to make sure that *F9_00_HD_FILER_STATE_US* works, which is based on the 'Filer' dictionary column subsumed under 'ReturnHeader'. [UPDATE: It works]
#
# - In future runs I might consider removing these variables from *binarize_cols*
#     - *F9_12_PC_ACCTG_METHOD_OTHER*
#     - *F9_00_HD_EXEMPT_STATUS_501C*

# %% [markdown]
# # Set up Working Space

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from pandas import Series

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
#http://pandas.pydata.org/pandas-docs/stable/options.html
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 250)

# %% [markdown]
# #### Set working directory

# %%
pwd
# Out:
# 'C:\\Users\\Gregory\\Jupyter_Notebooks'

# %%
cd "C:\\Users\\Gregory\\IRS 990 Control Variables\\"
# Out:
# C:\Users\Gregory\IRS 990 Control Variables

# %% [markdown]
# # Read in Concordance File
# We are going to read in a codebook called a 'concordance' file. We will use this file to identify variables to grab from the e-file data.

# %%
concordance = pd.read_excel('concordance_VERIFIED.xlsx')
print('# of columns:', len(concordance.columns))
print('# of observations:', len(concordance))
concordance[:2]
# Out:
# # of columns: 17
# # of observations: 574
#                                                    xpath  \
# 0         /Return/ReturnData/IRS990/SpecialConditionDesc
# 1  /Return/ReturnData/IRS990/SpecialConditionDescription
#
#                  variable_name_new  # of Characters (newly named)  \
# 0  F9_00_HD_SPECIAL_CONDITION_DESC                            NaN
# 1  F9_00_HD_SPECIAL_CONDITION_DESC                           31.0
#
#   variable name notes PARSING NOTES OTHER NOTES  \
# 0                 NaN           NaN         NaN
# 1                 NaN           NaN         NaN
#
#                      description    location_code     part data_type_xsd  \
# 0  Special condition description  F990-PC-PART-00  PART-00      TextType
# 1  Special condition description  F990-PC-PART-00  PART-00      TextType
#
#   python_data_type         fill_null BINARIZE                 MongoDB_Name  \
# 0           string  Do not fill null      NaN         SpecialConditionDesc
# 1           string  Do not fill null      NaN  SpecialConditionDescription
#
#   sub_key sub_sub_key cardinality
# 0     NaN         NaN         NaN
# 1     NaN         NaN         NaN

# %%
concordance['data_type_xsd'].value_counts()
# Out:
# data_type_xsd
# USAmountType            294
# BooleanType              98
# CheckboxType             62
# USAmountNNType           40
# IntegerNNType            14
# CountType                12
# ExplanationType           8
# DateType                  6
# StateType                 6
# ShortExplanationType      4
# CountryType               4
# StreetAddressType         4
# YearType                  4
# LineExplanationType       4
# TimestampType             3
# CityType                  2
# ZIPCodeType               2
# TextType                  2
# StringType                2
# PersonNameType            2
# YearMonthType             1
# Name: count, dtype: int64

# %%
concordance[concordance['data_type_xsd']=='CheckboxType']['MongoDB_Name'].tolist()
# Out:
# ['AddressChange',
#  'AddressChangeInd',
#  'AmendedReturn',
#  'AmendedReturnInd',
#  'FinalReturnInd',
#  'TerminatedReturn',
#  'InitialReturn',
#  'InitialReturnInd',
#  'Organization4947a1',
#  'Organization4947a1NotPFInd',
#  'Organization501c',
#  'Organization501cInd',
#  'Organization501c3',
#  'Organization501c3Ind',
#  'TypeOfOrganizationAssociation',
#  'TypeOfOrganizationAssocInd',
#  'TypeOfOrganizationCorpInd',
#  'TypeOfOrganizationCorporation',
#  'TypeOfOrganizationOther',
#  'TypeOfOrganizationOtherInd',
#  'TypeOfOrganizationTrust',
#  'TypeOfOrganizationTrustInd',
#  'ContractTerminationInd',
#  'TerminationOrContraction',
#  'InfoInScheduleOPartIII',
#  'InfoInScheduleOPartIIIInd',
#  'OwnWebsite',
#  'OwnWebsiteInd',
#  'OwnWebsite',
#  'OwnWebsiteInd',
#  'OtherWebsite',
#  'OtherWebsiteInd',
#  'UponRequest',
#  'UponRequestInd',
#  'NoListedPersonsCompensated',
#  'NoListedPersonsCompensatedInd',
#  'InfoInScheduleOPartIX',
#  'InfoInScheduleOPartIXInd',
#  'InfoInScheduleOPartX',
#  'InfoInScheduleOPartXInd',
#  'FollowSFAS117',
#  'OrganizationFollowsSFAS117Ind',
#  'DoNotFollowSFAS117',
#  'OrgDoesNotFollowSFAS117Ind',
#  'MethodOfAccountingAccrual',
#  'MethodOfAccountingAccrualInd',
#  'MethodOfAccountingCash',
#  'MethodOfAccountingCashInd',
#  'MethodOfAccountingOther',
#  'MethodOfAccountingOtherInd',
#  'InfoInScheduleOPartV',
#  'InfoInScheduleOPartVInd',
#  'InfoInScheduleOPartVI',
#  'InfoInScheduleOPartVIInd',
#  'InfoInScheduleOPartVII',
#  'InfoInScheduleOPartVIIInd',
#  'InfoInScheduleOPartVIII',
#  'InfoInScheduleOPartVIIIInd',
#  'InfoInScheduleOPartXI',
#  'InfoInScheduleOPartXIInd',
#  'InfoInScheduleOPartXII',
#  'InfoInScheduleOPartXIIInd']

# %%
concordance[concordance['data_type_xsd']=='CheckboxType'].sample(5)
# Out:
#                                                     xpath  \
# 109    /Return/ReturnData/IRS990/TerminationOrContraction
# 254                  /Return/ReturnData/IRS990/OwnWebsite
# 258                /Return/ReturnData/IRS990/OtherWebsite
# 33   /Return/ReturnData/IRS990/TypeOfOrganizationOtherInd
# 257               /Return/ReturnData/IRS990/OwnWebsiteInd
#
#                     variable_name_new  # of Characters (newly named)  \
# 109  F9_01_PC_TERMINATION_CONTRACTION                           32.0
# 254              F9_06_PC_OWN_WEBSITE                           20.0
# 258            F9_06_PC_OTHER_WEBSITE                           22.0
# 33            F9_00_HD_TYPE_ORG_OTHER                            NaN
# 257   F9_06_PC_FORM_AVAIL_OWN_WEBSITE                           31.0
#
#                                           variable name notes PARSING NOTES  \
# 109  old variable_name_new was F9_01_PC_TERMINATE_CONTRACTION           NaN
# 254                             variable_name_new value added           NaN
# 258                             variable_name_new value added           NaN
# 33                                                        NaN           NaN
# 257                             variable_name_new value added           NaN
#
#     OTHER NOTES                          description  \
# 109         NaN           Termination or contraction
# 254         NaN        Form available on own website
# 258         NaN  Form available on another's website
# 33          NaN          Form of organization: Other
# 257         NaN        Form available on own website
#
#                            location_code     part data_type_xsd  \
# 109               F990-PC-PART-01-LINE-2  PART-01  CheckboxType
# 254  F990-PC-PART-06-SECTION-C-LINE-18-1  PART-06  CheckboxType
# 258  F990-PC-PART-06-SECTION-C-LINE-18-2  PART-06  CheckboxType
# 33             F990-PC-PART-00-SECTION-K  PART-00  CheckboxType
# 257  F990-PC-PART-06-SECTION-C-LINE-18-1  PART-06  CheckboxType
#
#     python_data_type fill_null  BINARIZE                MongoDB_Name sub_key  \
# 109            Int64       NaN  binarize    TerminationOrContraction     NaN
# 254            Int64       NaN  binarize                  OwnWebsite     NaN
# 258            Int64       NaN  binarize                OtherWebsite     NaN
# 33             Int64       NaN  binarize  TypeOfOrganizationOtherInd     NaN
# 257            Int64       NaN  binarize               OwnWebsiteInd     NaN
#
#     sub_sub_key cardinality
# 109         NaN         NaN
# 254         NaN         NaN
# 258         NaN         NaN
# 33          NaN         NaN
# 257         NaN         NaN

# %%
concordance['python_data_type'].value_counts()
# Out:
# python_data_type
# Int64       524
# string       47
# DateTime      3
# Name: count, dtype: int64

# %%
[c for c in concordance['xpath'] if 'USAddress' in c]
# Out:
# ['/Return/ReturnHeader/Filer/USAddress/State',
#  '/Return/ReturnHeader/Filer/USAddress/StateAbbreviationCd',
#  '/Return/ReturnHeader/Filer/USAddress/AddressLine1',
#  '/Return/ReturnHeader/Filer/USAddress/AddressLine1Txt',
#  '/Return/ReturnHeader/Filer/USAddress/AddressLine2',
#  '/Return/ReturnHeader/Filer/USAddress/AddressLine2Txt',
#  '/Return/ReturnHeader/Filer/USAddress/City',
#  '/Return/ReturnHeader/Filer/USAddress/CityNm',
#  '/Return/ReturnHeader/Filer/USAddress/ZIPCd',
#  '/Return/ReturnHeader/Filer/USAddress/ZIPCode']

# %%
concordance[concordance['xpath'].isin(['/Return/ReturnHeader/Filer/USAddress/State',
 '/Return/ReturnHeader/Filer/USAddress/StateAbbreviationCd',
 '/Return/ReturnHeader/Filer/USAddress/AddressLine1',
 '/Return/ReturnHeader/Filer/USAddress/AddressLine1Txt',
 '/Return/ReturnHeader/Filer/USAddress/AddressLine2',
 '/Return/ReturnHeader/Filer/USAddress/AddressLine2Txt',
 '/Return/ReturnHeader/Filer/USAddress/City',
 '/Return/ReturnHeader/Filer/USAddress/CityNm',
 '/Return/ReturnHeader/Filer/USAddress/ZIPCd',
 '/Return/ReturnHeader/Filer/USAddress/ZIPCode'])]
# Out:
#                                                         xpath  \
# 549                /Return/ReturnHeader/Filer/USAddress/State
# 550  /Return/ReturnHeader/Filer/USAddress/StateAbbreviationCd
# 551         /Return/ReturnHeader/Filer/USAddress/AddressLine1
# 552      /Return/ReturnHeader/Filer/USAddress/AddressLine1Txt
# 553         /Return/ReturnHeader/Filer/USAddress/AddressLine2
# 554      /Return/ReturnHeader/Filer/USAddress/AddressLine2Txt
# 555                 /Return/ReturnHeader/Filer/USAddress/City
# 556               /Return/ReturnHeader/Filer/USAddress/CityNm
# 559                /Return/ReturnHeader/Filer/USAddress/ZIPCd
# 560              /Return/ReturnHeader/Filer/USAddress/ZIPCode
#
#              variable_name_new  # of Characters (newly named)  \
# 549    F9_00_HD_FILER_STATE_US                            NaN
# 550    F9_00_HD_FILER_STATE_US                            NaN
# 551  F9_00_HD_FILER_ADDR_US_L1                            NaN
# 552  F9_00_HD_FILER_ADDR_US_L1                            NaN
# 553  F9_00_HD_FILER_ADDR_US_L2                            NaN
# 554  F9_00_HD_FILER_ADDR_US_L2                            NaN
# 555     F9_00_HD_FILER_CITY_US                            NaN
# 556     F9_00_HD_FILER_CITY_US                            NaN
# 559      F9_00_HD_FILER_ZIP_US                            NaN
# 560      F9_00_HD_FILER_ZIP_US                            NaN
#
#     variable name notes                      PARSING NOTES OTHER NOTES  \
# 549                 NaN  Will be nested under ReturnHeader         NaN
# 550                 NaN  Will be nested under ReturnHeader         NaN
# 551                 NaN  Will be nested under ReturnHeader         NaN
# 552                 NaN  Will be nested under ReturnHeader         NaN
# 553                 NaN  Will be nested under ReturnHeader         NaN
# 554                 NaN  Will be nested under ReturnHeader         NaN
# 555                 NaN  Will be nested under ReturnHeader         NaN
# 556                 NaN  Will be nested under ReturnHeader         NaN
# 559                 NaN  Will be nested under ReturnHeader         NaN
# 560                 NaN  Will be nested under ReturnHeader         NaN
#
#                                       description              location_code  \
# 549     Address of Filing Organization (US State)                     HEADER
# 550     Address of Filing Organization (US State)                     HEADER
# 551    Address of Filing Organization (US Line 1)  HEADER-OR-SIGNATURE-BLOCK
# 552    Address of Filing Organization (US Line 1)  HEADER-OR-SIGNATURE-BLOCK
# 553    Address of Filing Organization (US Line 2)  HEADER-OR-SIGNATURE-BLOCK
# 554    Address of Filing Organization (US Line 2)  HEADER-OR-SIGNATURE-BLOCK
# 555      Address of Filing Organization (US City)  HEADER-OR-SIGNATURE-BLOCK
# 556      Address of Filing Organization (US City)  HEADER-OR-SIGNATURE-BLOCK
# 559  Address of Filing Organization (US Zip Code)  HEADER-OR-SIGNATURE-BLOCK
# 560  Address of Filing Organization (US Zip Code)  HEADER-OR-SIGNATURE-BLOCK
#
#         part      data_type_xsd python_data_type         fill_null BINARIZE  \
# 549  PART-00          StateType           string  Do not fill null      NaN
# 550  PART-00          StateType           string  Do not fill null      NaN
# 551  PART-00  StreetAddressType           string  Do not fill null      NaN
# 552  PART-00  StreetAddressType           string  Do not fill null      NaN
# 553  PART-00  StreetAddressType           string  Do not fill null      NaN
# 554  PART-00  StreetAddressType           string  Do not fill null      NaN
# 555  PART-00           CityType           string  Do not fill null      NaN
# 556  PART-00           CityType           string  Do not fill null      NaN
# 559  PART-00        ZIPCodeType           string  Do not fill null      NaN
# 560  PART-00        ZIPCodeType           string  Do not fill null      NaN
#
#     MongoDB_Name    sub_key          sub_sub_key cardinality
# 549        Filer  USAddress                State         NaN
# 550        Filer  USAddress  StateAbbreviationCd         NaN
# 551        Filer  USAddress         AddressLine1         NaN
# 552        Filer  USAddress      AddressLine1Txt         NaN
# 553        Filer  USAddress         AddressLine2         NaN
# 554        Filer  USAddress      AddressLine2Txt         NaN
# 555        Filer  USAddress                 City         NaN
# 556        Filer  USAddress               CityNm         NaN
# 559        Filer  USAddress                ZIPCd         NaN
# 560        Filer  USAddress              ZIPCode         NaN

# %%
concordance[concordance['xpath'].isin(['/Return/ReturnHeader/Filer/USAddress/State',
 '/Return/ReturnHeader/Filer/USAddress/StateAbbreviationCd',
 '/Return/ReturnHeader/Filer/USAddress/AddressLine1',
 '/Return/ReturnHeader/Filer/USAddress/AddressLine1Txt',
 '/Return/ReturnHeader/Filer/USAddress/AddressLine2',
 '/Return/ReturnHeader/Filer/USAddress/AddressLine2Txt',
 '/Return/ReturnHeader/Filer/USAddress/City',
 '/Return/ReturnHeader/Filer/USAddress/CityNm',
 '/Return/ReturnHeader/Filer/USAddress/ZIPCd',
 '/Return/ReturnHeader/Filer/USAddress/ZIPCode'])]['variable_name_new'].to_list()
# Out:
# ['F9_00_HD_FILER_STATE_US',
#  'F9_00_HD_FILER_STATE_US',
#  'F9_00_HD_FILER_ADDR_US_L1',
#  'F9_00_HD_FILER_ADDR_US_L1',
#  'F9_00_HD_FILER_ADDR_US_L2',
#  'F9_00_HD_FILER_ADDR_US_L2',
#  'F9_00_HD_FILER_CITY_US',
#  'F9_00_HD_FILER_CITY_US',
#  'F9_00_HD_FILER_ZIP_US',
#  'F9_00_HD_FILER_ZIP_US']

# %%
concordance[20:30]
# Out:
#                                                       xpath  \
# 20             /Return/ReturnData/IRS990/Organization4947a1
# 21     /Return/ReturnData/IRS990/Organization4947a1NotPFInd
# 22               /Return/ReturnData/IRS990/Organization501c
# 23            /Return/ReturnData/IRS990/Organization501cInd
# 24              /Return/ReturnData/IRS990/Organization501c3
# 25           /Return/ReturnData/IRS990/Organization501c3Ind
# 26                        /Return/ReturnData/IRS990/WebSite
# 27              /Return/ReturnData/IRS990/WebsiteAddressTxt
# 28  /Return/ReturnData/IRS990/TypeOfOrganizationAssociation
# 29     /Return/ReturnData/IRS990/TypeOfOrganizationAssocInd
#
#                 variable_name_new  # of Characters (newly named)  \
# 20  F9_00_HD_EXEMPT_STATUS_4847A1                            NaN
# 21  F9_00_HD_EXEMPT_STATUS_4847A1                            NaN
# 22    F9_00_HD_EXEMPT_STATUS_501C                            NaN
# 23    F9_00_HD_EXEMPT_STATUS_501C                            NaN
# 24   F9_00_HD_EXEMPT_STATUS_501C3                            NaN
# 25   F9_00_HD_EXEMPT_STATUS_501C3                            NaN
# 26               F9_00_HD_WEBSITE                            NaN
# 27               F9_00_HD_WEBSITE                            NaN
# 28  F9_00_HD_TYPE_ORG_ASSOCIATION                            NaN
# 29  F9_00_HD_TYPE_ORG_ASSOCIATION                            NaN
#
#    variable name notes  \
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
#
#                                                                      PARSING NOTES  \
# 20                                                                             NaN
# 21                                                                             NaN
# 22  need to parse dictionary for some values. Dealt with in Control Variables (A1)
# 23  need to parse dictionary for some values. Dealt with in Control Variables (A1)
# 24  need to parse dictionary for some values. Dealt with in Control Variables (A1)
# 25  need to parse dictionary for some values. Dealt with in Control Variables (A1)
# 26                                                                             NaN
# 27                                                                             NaN
# 28                                                                             NaN
# 29                                                                             NaN
#
#    OTHER NOTES                          description  \
# 20         NaN  Indicates a 4947(a)(1) organization
# 21         NaN  Indicates a 4947(a)(1) organization
# 22         NaN      Indicates a 501(c) organization
# 23         NaN      Indicates a 501(c) organization
# 24         NaN   Indicates a 501(c)(3) organization
# 25         NaN   Indicates a 501(c)(3) organization
# 26         NaN                              Website
# 27         NaN                              Website
# 28         NaN    Form of organization: Association
# 29         NaN    Form of organization: Association
#
#                 location_code     part        data_type_xsd python_data_type  \
# 20  F990-PC-PART-00-SECTION-I  PART-00         CheckboxType            Int64
# 21  F990-PC-PART-00-SECTION-I  PART-00         CheckboxType            Int64
# 22  F990-PC-PART-00-SECTION-I  PART-00         CheckboxType            Int64
# 23  F990-PC-PART-00-SECTION-I  PART-00         CheckboxType            Int64
# 24  F990-PC-PART-00-SECTION-I  PART-00         CheckboxType            Int64
# 25  F990-PC-PART-00-SECTION-I  PART-00         CheckboxType            Int64
# 26  F990-PC-PART-00-SECTION-J  PART-00  LineExplanationType           string
# 27  F990-PC-PART-00-SECTION-J  PART-00  LineExplanationType           string
# 28  F990-PC-PART-00-SECTION-K  PART-00         CheckboxType            Int64
# 29  F990-PC-PART-00-SECTION-K  PART-00         CheckboxType            Int64
#
#            fill_null            BINARIZE                   MongoDB_Name  \
# 20               NaN            binarize             Organization4947a1
# 21               NaN            binarize     Organization4947a1NotPFInd
# 22  Do not fill null  binarize_with_dict               Organization501c
# 23  Do not fill null  binarize_with_dict            Organization501cInd
# 24               NaN            binarize              Organization501c3
# 25               NaN            binarize           Organization501c3Ind
# 26  Do not fill null                 NaN                        WebSite
# 27  Do not fill null                 NaN              WebsiteAddressTxt
# 28               NaN            binarize  TypeOfOrganizationAssociation
# 29               NaN            binarize     TypeOfOrganizationAssocInd
#
#    sub_key sub_sub_key cardinality
# 20     NaN         NaN         NaN
# 21     NaN         NaN         NaN
# 22     NaN         NaN         NaN
# 23     NaN         NaN         NaN
# 24     NaN         NaN         NaN
# 25     NaN         NaN         NaN
# 26     NaN         NaN         NaN
# 27     NaN         NaN         NaN
# 28     NaN         NaN         NaN
# 29     NaN         NaN         NaN

# %% [markdown]
# <br>Show frequencies for intended data type for the variables

# %%
concordance['data_type_xsd'].value_counts()
# Out:
# data_type_xsd
# USAmountType            294
# BooleanType              98
# CheckboxType             62
# USAmountNNType           40
# IntegerNNType            14
# CountType                12
# ExplanationType           8
# DateType                  6
# StateType                 6
# ShortExplanationType      4
# CountryType               4
# StreetAddressType         4
# YearType                  4
# LineExplanationType       4
# TimestampType             3
# CityType                  2
# ZIPCodeType               2
# TextType                  2
# StringType                2
# PersonNameType            2
# YearMonthType             1
# Name: count, dtype: int64

# %% [markdown]
# <br>Show an example of a variable that is Boolean followed by one that is a CheckBox type.

# %%
concordance[concordance['data_type_xsd']=='BooleanType'][:1]
# Out:
#                                                  xpath      variable_name_new  \
# 14  /Return/ReturnData/IRS990/GroupReturnForAffiliates  F9_00_HD_GROUP_RETURN
#
#     # of Characters (newly named) variable name notes PARSING NOTES  \
# 14                            NaN                 NaN           NaN
#
#    OTHER NOTES                                             description  \
# 14         NaN  Indicates this form is a group return for subordinates
#
#                  location_code     part data_type_xsd python_data_type  \
# 14  F990-PC-PART-00-SECTION-HA  PART-00   BooleanType            Int64
#
#    fill_null  BINARIZE              MongoDB_Name sub_key sub_sub_key  \
# 14       NaN  binarize  GroupReturnForAffiliates     NaN         NaN
#
#    cardinality
# 14         NaN

# %%
concordance[concordance['data_type_xsd']=='CheckboxType'][:1]
# Out:
#                                      xpath     variable_name_new  \
# 2  /Return/ReturnData/IRS990/AddressChange  F9_00_HD_ADDR_CHANGE
#
#    # of Characters (newly named) variable name notes PARSING NOTES  \
# 2                           20.0                 NaN           NaN
#
#   OTHER NOTES                                description  \
# 2         NaN  Indicates this form has an address change
#
#                location_code     part data_type_xsd python_data_type  \
# 2  F990-PC-PART-00-SECTION-B  PART-00  CheckboxType            Int64
#
#   fill_null  BINARIZE   MongoDB_Name sub_key sub_sub_key cardinality
# 2       NaN  binarize  AddressChange     NaN         NaN         NaN

# %% [markdown]
# # Read 990 DB into PANDAS
# - In a previous round in 2019 there were 1,547,828 observations; in Feb. 2020 there were 1,727,056 observations; in Nov. 2020 there are 1,895,016 observations; in May 2021 there were 2,016,624 observations; in November 2021 there were 2,192,435 observations.
#
# - Now I am only going to parse the NEW filings

# %% [markdown]
# # Test Using `Feather`

# %%
import modin as mpd
import pandas as pd

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df = pd.read_feather("D:/all_filings.feather")
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
df[:2]
# Out:
# Current date and time :  2025-04-16 21:11:14
#
# # of columns: 496
# # of observations: 3469008
# CPU times: total: 2min 40s
# Wall time: 3min 52s
#                         _id  \
# 0  5d019e6778ffca27b42818d7
# 1  5d019e6778ffca27b42818d8
#
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#               DLN TaxPeriod AddressChange NameOfPrincipalOfficerPerson  \
# 0  93493313013011    201012             X                MICHAEL ANTON
# 1  93493313013111    201106          <NA>                         None
#
#   GrossReceipts GroupReturnForAffiliates Organization501c3 WebSite  \
# 0       1473903                        0                 X     N/A
# 1        266420                    false                 X     N/A
#
#   TypeOfOrganizationCorporation YearFormation StateLegalDomicile  \
# 0                             X          1992                 PA
# 1                             X          1993                 WY
#
#                                                                                                                     ActivityOrMissionDescription  \
# 0                                                       MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
# 1  PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   NbrVotingMembersGoverningBody NbrIndependentVotingMembers TotalNbrEmployees  \
# 0                            10                          10                 0
# 1                            19                          13                 0
#
#   TotalNbrVolunteers TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 0                  0             0                              0
# 1               None             0                           None
#
#   ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 0                      1044925                        1439340
# 1                         None                              0
#
#   ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 0                              0                       0
# 1                         222839                  265592
#
#   InvestmentIncomePriorYear InvestmentIncomeCurrentYear OtherRevenuePriorYear  \
# 0                     30447                       33563                     0
# 1                      1425                         828                  None
#
#   OtherRevenueCurrentYear TotalRevenuePriorYear TotalRevenueCurrentYear  \
# 0                    1000               1075372                 1473903
# 1                       0                224264                  266420
#
#   GrantsAndSimilarAmntsPriorYear GrantsAndSimilarAmntsCY  \
# 0                         638637                  925000
# 1                           None                       0
#
#   BenefitsPaidToMembersPriorYear BenefitsPaidToMembersCY SalariesEtcPriorYear  \
# 0                              0                       0                    0
# 1                           None                       0                71405
#
#   SalariesEtcCurrentYear TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 0                      0                             0                      0
# 1                  82955                          None                      0
#
#   TotalFundrsngExpCurrentYear OtherExpensePriorYear OtherExpensesCurrentYear  \
# 0                      195892                243131                   459751
# 1                           0                189785                   222550
#
#   TotalExpensesPriorYear TotalExpensesCurrentYear  \
# 0                 881768                  1384751
# 1                 261190                   305505
#
#   RevenuesLessExpensesPriorYear RevenuesLessExpensesCY TotalAssetsBOY  \
# 0                        193604                  89152        1925215
# 1                        -36926                 -39085        1455332
#
#   TotalAssetsEOY TotalLiabilitiesBOY TotalLiabilitiesEOY  \
# 0        2440859              171810              450430
# 1        1433342               17482               34577
#
#   NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesEOY  \
# 0                    1753405                    1990429
# 1                    1437850                    1398765
#
#   InfoInScheduleOPartIII  \
# 0                      X
# 1                   <NA>
#
#                                                                                                                                                                                                                                           MissionDescription  \
# 0  THE CORPORATION IS ORGANIZED AND WILL BE OPERATED EXCLUSIVELY FOR CHARITABLE, EDUCATIONAL AND SCIENTIFIC PURPOSES WITHIN THE MEANING OF SECTION 501(C)(3) OF THE INTERNAL REVENUE CODE. SUCH PURPOSES SHALL BE LIMITED TO PROVIDING SUPPORT AND FUNDIN...
# 1                                                                                                              PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   SignificantNewProgramServices SignificantChange  Expense  Grants  \
# 0                             0                 0  1043744  925000
# 1                         false             false   276405    None
#
#                                                                                                                                                                                                                                                  Description  \
# 0  RMHC OF THE PHILADELPHIA REGION, INC. GRANTS HUNDREDS OF THOUSANDS OF DOLLARS PER YEAR TO SUPPORT NON-PROFIT PROGRAMS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN. LOCALLY, RMHC SUPPORTS THE PHILADELPHIA, SOUTHERN NEW JERSEY AND DE...
# 1                                                                                                              PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   TotalProgramServiceExpense PoliticalActivities LobbyingActivities  \
# 0                    1043744                 "0"                "0"
# 1                     276405             "false"            "false"
#
#   ProfessionalFundraising FundraisingActivities   Gaming  \
# 0                     "0"                   "0"      "0"
# 1                 "false"               "false"  "false"
#
#   ExcessBenefitTransaction PriorExcessBenefitTransaction  \
# 0                      "0"                           "0"
# 1                  "false"                       "false"
#
#                                                DisregardedEntity  \
# 0                                                            "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "true"}
#
#                                                    RelatedEntity  \
# 0                                                            "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "true"}
#
#   RelatedOrgControlledEntity  \
# 0                        "0"
# 1                    "false"
#
#                                          TransactionRelatedEntity  \
# 0                                                             "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
#
#                                     TransfersToExemptNonChrtblOrg  \
# 0                                                             "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
#
#                                    ActivitiesConductedPartnership  \
# 0                                                             "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
#
#   NumberFormsTransmittedWith1096 NumberOfEmployees UnrelatedBusinessIncome  \
# 0                              0                 0                       0
# 1                              0                 0                   false
#
#   InfoInScheduleOPartVI NbrVotingGoverningBodyMembers  \
# 0                     X                            10
# 1                     X                            19
#
#   NumberIndependentVotingMembers FamilyOrBusinessRelationship  \
# 0                             10                            0
# 1                             13                         true
#
#   DelegationOfManagementDuties ChangesToOrganizingDocs  \
# 0                            0                       0
# 1                         true                   false
#
#   MaterialDiversionOrMisuse MembersOrStockholders ElectionOfBoardMembers  \
# 0                         0                     0                      0
# 1                     false                 false                   true
#
#   DecisionsSubjectToApproval MinutesOfGoverningBody MinutesOfCommittees  \
# 0                          0                      1                   1
# 1                       true                   true                true
#
#   OfficerMailingAddress LocalChapters Form990ProvidedToGoverningBody  \
# 0                     0             0                              1
# 1                 false         false                           true
#
#   ConflictOfInterestPolicy AnnualDisclosureCoveredPersons  \
# 0                        1                              1
# 1                     true                           true
#
#   RegularMonitoringEnforcement WhistleblowerPolicy DocumentRetentionPolicy  \
# 0                            1                   0                       0
# 1                         true               false                   false
#
#   CompensationProcessCEO CompensationProcessOther InvestmentInJointVenture  \
# 0                      0                        0                        0
# 1                   true                     true                    false
#
#   StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 0             ["PA", "NJ", "DE"]           X                          X
# 1                            NaN           X                       <NA>
#
#   TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 0                          0                              0
# 1                       None                        1180355
#
#   TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 0                      0                       0             0
# 1                 411648                       0          true
#
#   TotalCompGT150K CompensationFromOtherSources NumberOfContractorsGT100K  \
# 0               0                            0                         0
# 1            true                        false                         0
#
#   AllOtherContributions TotalContributions TotalOtherRevenue  \
# 0               1439340            1439340              1000
# 1                  None                  0                 0
#
#                                                                                                                               TotalRevenue  \
# 0  {"TotalRevenueColumn": "1473903", "RelatedOrExemptFunctionIncome": "1000", "UnrelatedBusinessRevenue": "0", "ExclusionAmount": "33563"}
# 1                                                              {"TotalRevenueColumn": "266420", "RelatedOrExemptFunctionIncome": "266420"}
#
#                                GrantsToDomesticOrgs  \
# 0  {"Total": "892000", "ProgramServices": "892000"}
# 1                                    {"Total": "0"}
#
#                       GrantsToDomesticIndividuals  \
# 0  {"Total": "33000", "ProgramServices": "33000"}
# 1                                  {"Total": "0"}
#
#                               FeesForServicesLegal  \
# 0  {"Total": "215", "ManagementAndGeneral": "215"}
# 1                                   {"Total": "0"}
#
#                              FeesForServicesAccounting  \
# 0  {"Total": "21675", "ManagementAndGeneral": "21675"}
# 1    {"Total": "7500", "ManagementAndGeneral": "7500"}
#
#                                     OfficeExpenses  \
# 0  {"Total": "123", "ManagementAndGeneral": "123"}
# 1   {"Total": "14222", "ProgramServices": "14222"}
#
#                                PaymentsToAffiliates  \
# 0  {"Total": "118744", "ProgramServices": "118744"}
# 1                                    {"Total": "0"}
#
#                                  DepreciationDepletion  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
# 1       {"Total": "66166", "ProgramServices": "66166"}
#
#                                                                                                                                                                                                                                                OtherExpenses  \
# 0  [{"Description": "FUNDRAISING COSTS", "Total": "108311", "Fundraising": "108311"}, {"Description": "CANISTER COLLECTION FEE", "Total": "81925", "Fundraising": "81925"}, {"Description": "PR/ADMINISTRATIVE SERVI", "Total": "34517", "ManagementAndGe...
# 1                [{"Description": "OPER. & MAINT.", "Total": "46164", "ProgramServices": "46164"}, {"Description": "MISC TAXES", "Total": "298", "ProgramServices": "298"}, {"Description": "ADMINISTRATIVE", "Total": "12176", "ProgramServices": "12176"}]
#
#                                   AllOtherExpenses  \
# 0  {"Total": "763", "ManagementAndGeneral": "763"}
# 1                                   {"Total": "0"}
#
#                                                                                          TotalFunctionalExpenses  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
# 1          {"Total": "305505", "ProgramServices": "276405", "ManagementAndGeneral": "29100", "Fundraising": "0"}
#
#         SavingsAndTempCashInvestments                  AccountsReceivable  \
# 0  {"BOY": "332660", "EOY": "270700"}  {"BOY": "103412", "EOY": "147981"}
# 1                        {"EOY": "0"}        {"BOY": "231", "EOY": "474"}
#
#   LandBuildingsEquipmentBasis LandBldgEquipmentAccumDeprec  \
# 0                      256845                        86228
# 1                     2187206                       904332
#
#          LandBuildingsEquipmentBasisNet            InvestmentsOtherSecurities  \
# 0         {"BOY": "0", "EOY": "170617"}  {"BOY": "1489143", "EOY": "1851561"}
# 1  {"BOY": "1306860", "EOY": "1282874"}    {"BOY": "125980", "EOY": "102794"}
#
#                             TotalAssets    AccountsPayableAccruedExpenses  \
# 0  {"BOY": "1925215", "EOY": "2440859"}  {"BOY": "39670", "EOY": "44353"}
# 1  {"BOY": "1455332", "EOY": "1433342"}   {"BOY": "2040", "EOY": "16145"}
#
#                        GrantsPayable                   OtherLiabilities  \
# 0  {"BOY": "80500", "EOY": "166000"}  {"BOY": "51640", "EOY": "240077"}
# 1                                NaN    {"BOY": "9203", "EOY": "11349"}
#
#   FollowSFAS117                 UnrestrictedNetAssets InfoInScheduleOPartXI  \
# 0             X  {"BOY": "1753405", "EOY": "1990429"}                     X
# 1             X  {"BOY": "1437850", "EOY": "1398765"}                  <NA>
#
#   ReconcilationRevenueExpenses InfoInScheduleOPartXII  \
# 0                        89152                      X
# 1                       -39085                   <NA>
#
#   MethodOfAccountingAccrual AccountantCompileOrReview FSAudited  \
# 0                         X                         0         1
# 1                         X                     false      true
#
#   AuditCommittee FederalGrantAuditRequired AllAffiliatesIncluded  \
# 0              1                         0                   NaN
# 1           true                      true               "false"
#
#   GroupExemptionNumber Revenue PoliciesReferenceChapters  \
# 0                 None    None                      None
# 1                 1736  266420                     false
#
#   WrittenPolicyOrProcedure TotalProgramServiceRevenue   ForeignGrants  \
# 0                     None                       None             NaN
# 1                    false                     265592  {"Total": "0"}
#
#   BenefitsToMembers CompCurrentOfficersDirectors CompDisqualPersons  \
# 0               NaN                          NaN                NaN
# 1    {"Total": "0"}               {"Total": "0"}     {"Total": "0"}
#
#                             OtherSalariesAndWages PensionPlanContributions  \
# 0                                             NaN                      NaN
# 1  {"Total": "59440", "ProgramServices": "59440"}           {"Total": "0"}
#
#                             OtherEmployeeBenefits  \
# 0                                             NaN
# 1  {"Total": "17714", "ProgramServices": "17714"}
#
#                                    PayrollTaxes  \
# 0                                           NaN
# 1  {"Total": "5801", "ProgramServices": "5801"}
#
#                              FeesForServicesManagement  \
# 0                                                  NaN
# 1  {"Total": "21600", "ManagementAndGeneral": "21600"}
#
#   FeesForServicesLobbying FeesForServicesProfFundraising  \
# 0                     NaN                            NaN
# 1          {"Total": "0"}                 {"Total": "0"}
#
#   FeesForServicesInvstMgmntFees FeesForServicesOther  \
# 0                           NaN                  NaN
# 1                {"Total": "0"}       {"Total": "0"}
#
#                                     Advertising InformationTechnology  \
# 0                                           NaN                   NaN
# 1  {"Total": "8433", "ProgramServices": "8433"}        {"Total": "0"}
#
#         Royalties                                       Occupancy  \
# 0             NaN                                             NaN
# 1  {"Total": "0"}  {"Total": "44077", "ProgramServices": "44077"}
#
#            Travel TravelEntrtnmntPublicOfficials  \
# 0             NaN                            NaN
# 1  {"Total": "0"}                 {"Total": "0"}
#
#                           ConferencesMeetings        Interest  \
# 0                                         NaN             NaN
# 1  {"Total": "806", "ProgramServices": "806"}  {"Total": "0"}
#
#                                       Insurance  \
# 0                                           NaN
# 1  {"Total": "1108", "ProgramServices": "1108"}
#
#            CashNonInterestBearing PledgesAndGrantsReceivable  \
# 0                             NaN                        NaN
# 1  {"BOY": "250", "EOY": "22261"}               {"EOY": "0"}
#
#   ReceivablesFromDisqualPersons OtherNotesLoansReceivableNet  \
# 0                           NaN                          NaN
# 1                  {"EOY": "0"}                 {"EOY": "0"}
#
#   InventoriesForSaleOrUse  PrepaidExpensesDeferredCharges  \
# 0                     NaN                             NaN
# 1            {"EOY": "0"}  {"BOY": "7628", "EOY": "7554"}
#
#   InvestmentsPubTradedSecurities InvestmentsProgramRelated IntangibleAssets  \
# 0                            NaN                       NaN              NaN
# 1                   {"EOY": "0"}              {"EOY": "0"}     {"EOY": "0"}
#
#                    OtherAssetsTotal             DeferredRevenue  \
# 0                               NaN                         NaN
# 1  {"BOY": "14383", "EOY": "17385"}  {"BOY": "20", "EOY": "48"}
#
#    MortNotesPyblSecuredInvestProp FederalGrantAuditPerformed  \
# 0                             NaN                       None
# 1  {"BOY": "6219", "EOY": "7035"}                       true
#
#   LoansFromOfficersDirectors MethodOfAccountingCash Activity2 Activity3  \
# 0                        NaN                   <NA>       NaN       NaN
# 1                        NaN                   <NA>       NaN       NaN
#
#   InfoInScheduleOPartVII TaxExemptBondLiabilities  \
# 0                   <NA>                      NaN
# 1                   <NA>                      NaN
#
#   TemporarilyRestrictedNetAssets OtherWebsite PermanentlyRestrictedNetAssets  \
# 0                            NaN         <NA>                            NaN
# 1                            NaN         <NA>                            NaN
#
#   FundraisingEvents CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 0              None                           None                 None
# 1              None                           None                 None
#
#   GrossIncomeFundraisingEvents FundraisingDirectExpenses FederatedCampaigns  \
# 0                         None                      None               None
# 1                         None                      None               None
#
#   GovernmentGrants MethodOfAccountingOther GrossSalesOfInventory  \
# 0             None                     NaN                  None
# 1             None                     NaN                  None
#
#   CostOfGoodsSold DoNotFollowSFAS117 RetainedEarningsEndowmentEtc  \
# 0            None               <NA>                          NaN
# 1            None               <NA>                          NaN
#
#   InitialReturn MembershipDues GrossIncomeGaming GamingDirectExpenses  \
# 0          <NA>           None              None                 None
# 1          <NA>           None              None                 None
#
#   NoncashContributions InfoInScheduleOPartV OwnWebsite  \
# 0                 None                 <NA>       <NA>
# 1                 None                 <NA>       <NA>
#
#   UnsecuredNotesLoansPayable ActivityOther TotalOfOtherProgramServiceExp  \
# 0                        NaN           NaN                          None
# 1                        NaN           NaN                          None
#
#   TotalOfOtherProgramServiceRev EscrowAccountLiability  \
# 0                          None                    NaN
# 1                          None                    NaN
#
#   TotalOfOtherProgramServiceGrnt TypeOfOrganizationOther Organization501c  \
# 0                           None                    <NA>              NaN
# 1                           None                    <NA>              NaN
#
#   TypeOfOrganizationTrust TypeOfOrganizationAssociation CountryLegalDomicile  \
# 0                    <NA>                          <NA>                 None
# 1                    <NA>                          <NA>                 None
#
#   AmendedReturn TypeOfOrgOtherDescription TotalJointCosts TerminatedReturn  \
# 0          <NA>                      None             NaN             <NA>
# 1          <NA>                      None             NaN             <NA>
#
#   TerminationOrContraction ActivityCode SpecialConditionDescription  \
# 0                     <NA>         None                        None
# 1                     <NA>         None                        None
#
#   Organization4947a1 InfoInScheduleOPartIX ReconciliationUnrealizedInvest  \
# 0               <NA>                  <NA>                           None
# 1               <NA>                  <NA>                           None
#
#   ReconcilationPriorAdjustment ReconcilationDonatedServices  \
# 0                         None                         None
# 1                         None                         None
#
#   ReconcilationInvestExpenses InfoInScheduleOPartVIII InfoInScheduleOPartX  \
# 0                        None                    <NA>                 <NA>
# 1                        None                    <NA>                 <NA>
#
#   PrincipalOfficerNm GrossReceiptsAmt GroupReturnForAffiliatesInd  \
# 0               None             None                        None
# 1               None             None                        None
#
#   Organization501c3Ind TypeOfOrganizationCorpInd FormationYr  \
# 0                 <NA>                      <NA>        None
# 1                 <NA>                      <NA>        None
#
#   LegalDomicileStateCd ActivityOrMissionDesc VotingMembersGoverningBodyCnt  \
# 0                 None                  None                          None
# 1                 None                  None                          None
#
#   VotingMembersIndependentCnt TotalEmployeeCnt TotalGrossUBIAmt  \
# 0                        None             None             None
# 1                        None             None             None
#
#   CYContributionsGrantsAmt CYProgramServiceRevenueAmt CYInvestmentIncomeAmt  \
# 0                     None                       None                  None
# 1                     None                       None                  None
#
#   CYOtherRevenueAmt CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 0              None              None                      None
# 1              None              None                      None
#
#   CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 0                       None                         None
# 1                       None                         None
#
#   CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt CYOtherExpensesAmt  \
# 0                       None                         None               None
# 1                       None                         None               None
#
#   CYTotalExpensesAmt CYRevenuesLessExpensesAmt TotalAssetsBOYAmt  \
# 0               None                      None              None
# 1               None                      None              None
#
#   TotalAssetsEOYAmt TotalLiabilitiesEOYAmt NetAssetsOrFundBalancesBOYAmt  \
# 0              None                   None                          None
# 1              None                   None                          None
#
#   NetAssetsOrFundBalancesEOYAmt InfoInScheduleOPartIIIInd MissionDesc  \
# 0                          None                      <NA>        None
# 1                          None                      <NA>        None
#
#   SignificantNewProgramSrvcInd SignificantChangeInd  Desc  \
# 0                         None                 None  None
# 1                         None                 None  None
#
#   PoliticalCampaignActyInd LobbyingActivitiesInd ProfessionalFundraisingInd  \
# 0                     None                  None                       None
# 1                     None                  None                       None
#
#   FundraisingActivitiesInd GamingActivitiesInd EngagedInExcessBenefitTransInd  \
# 0                     None                None                           None
# 1                     None                None                           None
#
#   PYExcessBenefitTransInd DisregardedEntityInd RelatedEntityInd  \
# 0                    None                 None             None
# 1                    None                 None             None
#
#   RelatedOrganizationCtrlEntInd TransactionWithControlEntInd  \
# 0                          None                         None
# 1                          None                         None
#
#   TrnsfrExmptNonChrtblRltdOrgInd ActivitiesConductedPrtshpInd IRPDocumentCnt  \
# 0                           None                         None           None
# 1                           None                         None           None
#
#   EmployeeCnt UnrelatedBusIncmOverLimitInd GoverningBodyVotingMembersCnt  \
# 0        None                         None                          None
# 1        None                         None                          None
#
#   IndependentVotingMemberCnt FamilyOrBusinessRlnInd DelegationOfMgmtDutiesInd  \
# 0                       None                   None                      None
# 1                       None                   None                      None
#
#   ChangeToOrgDocumentsInd MaterialDiversionOrMisuseInd  \
# 0                    None                         None
# 1                    None                         None
#
#   MembersOrStockholdersInd ElectionOfBoardMembersInd  \
# 0                     None                      None
# 1                     None                      None
#
#   DecisionsSubjectToApprovaInd MinutesOfGoverningBodyInd  \
# 0                         None                      None
# 1                         None                      None
#
#   MinutesOfCommitteesInd OfficerMailingAddressInd LocalChaptersInd  \
# 0                   None                     None             None
# 1                   None                     None             None
#
#   Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 0                         None                        None
# 1                         None                        None
#
#   WhistleblowerPolicyInd DocumentRetentionPolicyInd CompensationProcessCEOInd  \
# 0                   None                       None                      None
# 1                   None                       None                      None
#
#   CompensationProcessOtherInd InvestmentInJointVentureInd  \
# 0                        None                        None
# 1                        None                        None
#
#   StatesWhereCopyOfReturnIsFldCd NoListedPersonsCompensatedInd  \
# 0                           None                          <NA>
# 1                           None                          <NA>
#
#   FormerOfcrEmployeesListedInd TotalCompGreaterThan150KInd  \
# 0                         None                        None
# 1                         None                        None
#
#   CompensationFromOtherSrcsInd MembershipDuesAmt FundraisingAmt  \
# 0                         None              None           None
# 1                         None              None           None
#
#   AllOtherContributionsAmt TotalContributionsAmt OtherRevenueTotalAmt  \
# 0                     None                  None                 None
# 1                     None                  None                 None
#
#   TotalRevenueGrp FeesForServicesAccountingGrp OfficeExpensesGrp  \
# 0            None                         None              None
# 1            None                         None              None
#
#   InformationTechnologyGrp ConferencesMeetingsGrp InsuranceGrp  \
# 0                     None                   None         None
# 1                     None                   None         None
#
#   OtherExpensesGrp AllOtherExpensesGrp TotalFunctionalExpensesGrp  \
# 0             None                None                       None
# 1             None                None                       None
#
#   CashNonInterestBearingGrp TotalAssetsGrp OrgDoesNotFollowSFAS117Ind  \
# 0                      None           None                       <NA>
# 1                      None           None                       <NA>
#
#   RtnEarnEndowmentIncmOthFndsGrp ReconcilationRevenueExpnssAmt  \
# 0                           None                          None
# 1                           None                          None
#
#   MethodOfAccountingCashInd AccountantCompileOrReviewInd FSAuditedInd  \
# 0                      <NA>                         None         None
# 1                      <NA>                         None         None
#
#   FederalGrantAuditRequiredInd WebsiteAddressTxt TotalVolunteersCnt  \
# 0                         None              None               None
# 1                         None              None               None
#
#   NetUnrelatedBusTxblIncmAmt PYContributionsGrantsAmt  \
# 0                       None                     None
# 1                       None                     None
#
#   PYProgramServiceRevenueAmt PYInvestmentIncomeAmt PYOtherRevenueAmt  \
# 0                       None                  None              None
# 1                       None                  None              None
#
#   PYTotalRevenueAmt PYGrantsAndSimilarPaidAmt PYBenefitsPaidToMembersAmt  \
# 0              None                      None                       None
# 1              None                      None                       None
#
#   PYSalariesCompEmpBnftPaidAmt PYTotalProfFndrsngExpnsAmt PYOtherExpensesAmt  \
# 0                         None                       None               None
# 1                         None                       None               None
#
#   PYTotalExpensesAmt PYRevenuesLessExpensesAmt TotalLiabilitiesBOYAmt  \
# 0               None                      None                   None
# 1               None                      None                   None
#
#   ExpenseAmt GrantAmt RevenueAmt ProgSrvcAccomActy2Grp ProgSrvcAccomActy3Grp  \
# 0       None     None       None                  None                  None
# 1       None     None       None                  None                  None
#
#   ProgSrvcAccomActyOtherGrp TotalOtherProgSrvcGrantAmt  \
# 0                      None                       None
# 1                      None                       None
#
#   TotalProgramServiceExpensesAmt InfoInScheduleOPartVIInd  \
# 0                           None                     <NA>
# 1                           None                     <NA>
#
#   AnnualDisclosureCoveredPrsnInd RegularMonitoringEnfrcInd UponRequestInd  \
# 0                           None                      None           <NA>
# 1                           None                      None           <NA>
#
#   TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 0                          None                        None
# 1                          None                        None
#
#   TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 0                      None                        None
# 1                      None                        None
#
#   CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 0                         None                None
# 1                         None                None
#
#   TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 0                          None                      None
# 1                          None                      None
#
#   ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 0                         None                         None
# 1                         None                         None
#
#   GrossSalesOfInventoryAmt CostOfGoodsSoldAmt GrantsToDomesticIndividualsGrp  \
# 0                     None               None                           None
# 1                     None               None                           None
#
#   CompCurrentOfcrDirectorsGrp OtherSalariesAndWagesGrp  \
# 0                        None                     None
# 1                        None                     None
#
#   PensionPlanContributionsGrp OtherEmployeeBenefitsGrp PayrollTaxesGrp  \
# 0                        None                     None            None
# 1                        None                     None            None
#
#   FeesForServicesOtherGrp AdvertisingGrp TravelGrp InterestGrp  \
# 0                    None           None      None        None
# 1                    None           None      None        None
#
#   DepreciationDepletionGrp SavingsAndTempCashInvstGrp AccountsReceivableGrp  \
# 0                     None                       None                  None
# 1                     None                       None                  None
#
#   InventoriesForSaleOrUseGrp PrepaidExpensesDefrdChargesGrp  \
# 0                       None                           None
# 1                       None                           None
#
#   LandBldgEquipCostOrOtherBssAmt LandBldgEquipAccumDeprecAmt  \
# 0                           None                        None
# 1                           None                        None
#
#   LandBldgEquipBasisNetGrp InvestmentsOtherSecuritiesGrp IntangibleAssetsGrp  \
# 0                     None                          None                None
# 1                     None                          None                None
#
#   AccountsPayableAccrExpnssGrp DeferredRevenueGrp  \
# 0                         None               None
# 1                         None               None
#
#   MortgNotesPyblScrdInvstPropGrp OtherLiabilitiesGrp  \
# 0                           None                None
# 1                           None                None
#
#   OrganizationFollowsSFAS117Ind UnrestrictedNetAssetsGrp  \
# 0                          <NA>                     None
# 1                          <NA>                     None
#
#   TemporarilyRstrNetAssetsGrp InfoInScheduleOPartXIInd  \
# 0                        None                     <NA>
# 1                        None                     <NA>
#
#   NetUnrlzdGainsLossesInvstAmt InfoInScheduleOPartXIIInd AuditCommitteeInd  \
# 0                         None                      <NA>              None
# 1                         None                      <NA>              None
#
#   AllAffiliatesIncludedInd GrantsToDomesticOrgsGrp ForeignGrantsGrp  \
# 0                     None                    None             None
# 1                     None                    None             None
#
#   BenefitsToMembersGrp CompDisqualPersonsGrp FeesForServicesManagementGrp  \
# 0                 None                  None                         None
# 1                 None                  None                         None
#
#   FeesForServicesLegalGrp FeesForServicesLobbyingGrp  \
# 0                    None                       None
# 1                    None                       None
#
#   FeesForSrvcInvstMgmntFeesGrp RoyaltiesGrp OccupancyGrp  \
# 0                         None         None         None
# 1                         None         None         None
#
#   PymtTravelEntrtnmntPubOfclGrp PaymentsToAffiliatesGrp  \
# 0                          None                    None
# 1                          None                    None
#
#   PledgesAndGrantsReceivableGrp RcvblFromDisqualifiedPrsnGrp  \
# 0                          None                         None
# 1                          None                         None
#
#   OthNotesLoansReceivableNetGrp InvestmentsPubTradedSecGrp  \
# 0                          None                       None
# 1                          None                       None
#
#   InvestmentsProgramRelatedGrp OtherAssetsTotalGrp  \
# 0                         None                None
# 1                         None                None
#
#   TotalOtherProgSrvcExpenseAmt InfoInScheduleOPartVInd  \
# 0                         None                    <NA>
# 1                         None                    <NA>
#
#   MethodOfAccountingAccrualInd NoncashContributionsAmt GrantsPayableGrp  \
# 0                         <NA>                    None             None
# 1                         <NA>                    None             None
#
#   PermanentlyRstrNetAssetsGrp TaxExemptBondLiabilitiesGrp  \
# 0                        None                        None
# 1                        None                        None
#
#   EscrowAccountLiabilityGrp LoansFromOfficersDirectorsGrp  \
# 0                      None                          None
# 1                      None                          None
#
#   UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 0                          None                      None
# 1                          None                      None
#
#   FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd OtherWebsiteInd  \
# 0                          None                         None            <NA>
# 1                          None                         None            <NA>
#
#   AddressChangeInd WrittenPolicyOrProcedureInd RelatedOrganizationsAmt  \
# 0             <NA>                        None                    None
# 1             <NA>                        None                    None
#
#   TotalOtherProgSrvcRevenueAmt OwnWebsiteInd TotalJointCostsGrp  \
# 0                         None          <NA>               None
# 1                         None          <NA>               None
#
#   DonatedServicesAndUseFcltsAmt LegalDomicileCountryCd  \
# 0                          None                   None
# 1                          None                   None
#
#   InfoInScheduleOPartIXInd TypeOfOrganizationTrustInd FinalReturnInd  \
# 0                     <NA>                       <NA>           <NA>
# 1                     <NA>                       <NA>           <NA>
#
#   ContractTerminationInd InfoInScheduleOPartXInd GroupExemptionNum  \
# 0                   <NA>                    <NA>              None
# 1                   <NA>                    <NA>              None
#
#   InfoInScheduleOPartVIIInd FederatedCampaignsAmt TypeOfOrganizationOtherInd  \
# 0                      <NA>                  None                       <NA>
# 1                      <NA>                  None                       <NA>
#
#   OtherOrganizationDsc InfoInScheduleOPartVIIIInd TypeOfOrganizationAssocInd  \
# 0                 None                       <NA>                       <NA>
# 1                 None                       <NA>                       <NA>
#
#   InitialReturnInd GamingGrossIncomeAmt GamingDirectExpensesAmt  \
# 0             <NA>                 None                    None
# 1             <NA>                 None                    None
#
#   MethodOfAccountingOtherInd InvestmentExpenseAmt Organization501cInd  \
# 0                       <NA>                 None                <NA>
# 1                       <NA>                 None                <NA>
#
#   Organization4947a1NotPFInd AmendedReturnInd SpecialConditionDesc ActivityCd  \
# 0                       <NA>             <NA>                 None       None
# 1                       <NA>             <NA>                 None       None
#
#                    Timestamp TaxPeriodEndDate TaxPeriodBeginDate  \
# 0  2011-11-09T06:41:09-06:00       2010-12-31         2010-01-01
# 1  2011-11-09T07:32:06-08:00       2011-06-30         2010-07-01
#
#                                                                                                                         Officer  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
# 1                                         {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
#
#   TaxYear               BuildTS ReturnTs TaxPeriodEndDt TaxPeriodBeginDt  \
# 0    2010  2016-02-24 21:20:13Z     None           None             None
# 1    2010  2016-02-24 21:20:13Z     None           None             None
#
#   BusinessOfficerGrp TaxYr fiscal_year        EIN  \
# 0                nan  None        None  232705170
# 1                nan  None        None  581805618
#
#                                                                                                         Name  \
# 0  {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}
# 1        {'BusinessNameLine1': 'TORRINGTON VOA ELDERLY HOUSING INC', 'BusinessNameLine2': 'BELL PARK TOWER'}
#
#   NameControl       Phone  \
# 0        RONA  8565826843
# 1        TORR  7033415000
#
#                                                                                                        USAddress  \
# 0  {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300', 'City': 'BETHLEHEM', 'State': 'PA', 'ZIPCode': '18017'}
# 1                  {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA', 'State': 'VA', 'ZIPCode': '22314'}
#
#   ForeignAddress InCareOfName BusinessName BusinessNameControlTxt PhoneNum  \
# 0            nan         None          nan                   None     None
# 1            nan         None          nan                   None     None
#
#   InCareOfNm ForeignPhoneNum
# 0       None            None
# 1       None            None

# %%
df.dtypes[:25]
# Out:
# _id                                       object
# OrganizationName                          object
# URL                                       object
# DLN                                       object
# TaxPeriod                                 object
# AddressChange                     string[python]
# NameOfPrincipalOfficerPerson              object
# GrossReceipts                             object
# GroupReturnForAffiliates                  object
# Organization501c3                 string[python]
# WebSite                                   object
# TypeOfOrganizationCorporation     string[python]
# YearFormation                             object
# StateLegalDomicile                        object
# ActivityOrMissionDescription              object
# NbrVotingMembersGoverningBody             object
# NbrIndependentVotingMembers               object
# TotalNbrEmployees                         object
# TotalNbrVolunteers                        object
# TotalGrossUBI                             object
# NetUnrelatedBusinessTxblIncome            object
# ContributionsGrantsPriorYear              object
# ContributionsGrantsCurrentYear            object
# ProgramServiceRevenuePriorYear            object
# ProgramServiceRevenueCY                   object
# dtype: object

# %%
#%%time
#df = df.convert_dtypes()
# Out:
# CPU times: total: 2min 29s
# Wall time: 2min 42s

# %%
#df.dtypes[:25]
# Out:
# _id                               string[python]
# OrganizationName                  string[python]
# URL                               string[python]
# DLN                               string[python]
# TaxPeriod                         string[python]
# AddressChange                     string[python]
# NameOfPrincipalOfficerPerson      string[python]
# GrossReceipts                     string[python]
# GroupReturnForAffiliates          string[python]
# Organization501c3                 string[python]
# WebSite                           string[python]
# TypeOfOrganizationCorporation     string[python]
# YearFormation                     string[python]
# StateLegalDomicile                string[python]
# ActivityOrMissionDescription      string[python]
# NbrVotingMembersGoverningBody     string[python]
# NbrIndependentVotingMembers       string[python]
# TotalNbrEmployees                 string[python]
# TotalNbrVolunteers                string[python]
# TotalGrossUBI                     string[python]
# NetUnrelatedBusinessTxblIncome    string[python]
# ContributionsGrantsPriorYear      string[python]
# ContributionsGrantsCurrentYear    string[python]
# ProgramServiceRevenuePriorYear    string[python]
# ProgramServiceRevenueCY           string[python]
# dtype: object

# %% [markdown]
# ### Sidebar - Identify colums with 'X'

# %%
# Simple approach to find columns containing 'X'
import pandas as pd
import modin.pandas as mpd

# Assuming your DataFrame is already loaded as 'df'

def find_columns_with_x(df, sample_size=10000):
    """
    Find columns that contain 'X' by taking a sample of rows.
    
    Parameters:
    -----------
    df : DataFrame
        The DataFrame to check
    sample_size : int
        Number of rows to sample (default 10000)
    
    Returns:
    --------
    list
        Columns that contain 'X' values
    """
    # Take a sample to reduce memory usage
    sample_df = df.sample(min(sample_size, len(df)))
    
    # Convert the sample to strings for checking
    columns_with_x = []
    
    for col in sample_df.columns:
        # Check if column has any 'X' values
        if (sample_df[col].astype(str) == 'X').any():
            print(f"Column '{col}' contains 'X' values")
            columns_with_x.append(col)
        elif sample_df[col].astype(str).str.contains('X').any():
            print(f"Column '{col}' contains strings with 'X' in them")
            columns_with_x.append(col)
    
    print(f"\nFound {len(columns_with_x)} columns with 'X' values")
    return columns_with_x

# Find columns with 'X'
x_columns = find_columns_with_x(df)
print("\nList of columns with 'X':")
for col in x_columns:
    print(f"- {col}")
# Out:
# Column 'OrganizationName' contains strings with 'X' in them
# Column 'AddressChange' contains 'X' values
# Column 'NameOfPrincipalOfficerPerson' contains strings with 'X' in them
# Column 'Organization501c3' contains 'X' values
# Column 'WebSite' contains strings with 'X' in them
# Column 'TypeOfOrganizationCorporation' contains 'X' values
# Column 'StateLegalDomicile' contains strings with 'X' in them
# Column 'ActivityOrMissionDescription' contains strings with 'X' in them
# Column 'InfoInScheduleOPartIII' contains 'X' values
# Column 'MissionDescription' contains strings with 'X' in them
# Column 'Description' contains strings with 'X' in them
# Column 'InfoInScheduleOPartVI' contains 'X' values
# Column 'StatesWhereCopyOfReturnIsFiled' contains strings with 'X' in them
# Column 'UponRequest' contains 'X' values
# Column 'NoListedPersonsCompensated' contains 'X' values
# Column 'OtherExpenses' contains strings with 'X' in them
# Column 'FollowSFAS117' contains 'X' values
# Column 'InfoInScheduleOPartXI' contains 'X' values
# Column 'InfoInScheduleOPartXII' contains 'X' values
# Column 'MethodOfAccountingAccrual' contains 'X' values
# Column 'MethodOfAccountingCash' contains 'X' values
# Column 'Activity2' contains strings with 'X' in them
# Column 'Activity3' contains strings with 'X' in them
# Column 'InfoInScheduleOPartVII' contains 'X' values
# Column 'OtherWebsite' contains 'X' values
# Column 'MethodOfAccountingOther' contains strings with 'X' in them
# Column 'DoNotFollowSFAS117' contains 'X' values
# Column 'InitialReturn' contains 'X' values
# Column 'InfoInScheduleOPartV' contains 'X' values
# Column 'OwnWebsite' contains 'X' values
# Column 'ActivityOther' contains strings with 'X' in them
# Column 'TypeOfOrganizationOther' contains 'X' values
# Column 'Organization501c' contains strings with 'X' in them
# Column 'TypeOfOrganizationTrust' contains 'X' values
# Column 'TypeOfOrganizationAssociation' contains 'X' values
# Column 'AmendedReturn' contains 'X' values
# Column 'TerminatedReturn' contains 'X' values
# Column 'TerminationOrContraction' contains 'X' values
# Column 'Organization4947a1' contains 'X' values
# Column 'InfoInScheduleOPartIX' contains 'X' values
# Column 'InfoInScheduleOPartVIII' contains 'X' values
# Column 'InfoInScheduleOPartX' contains 'X' values
# Column 'PrincipalOfficerNm' contains strings with 'X' in them
# Column 'Organization501c3Ind' contains 'X' values
# Column 'TypeOfOrganizationCorpInd' contains 'X' values
# Column 'LegalDomicileStateCd' contains strings with 'X' in them
# Column 'ActivityOrMissionDesc' contains strings with 'X' in them
# Column 'InfoInScheduleOPartIIIInd' contains 'X' values
# Column 'MissionDesc' contains strings with 'X' in them
# Column 'Desc' contains strings with 'X' in them
# Column 'ProfessionalFundraisingInd' contains strings with 'X' in them
# Column 'FundraisingActivitiesInd' contains strings with 'X' in them
# Column 'GamingActivitiesInd' contains strings with 'X' in them
# Column 'PYExcessBenefitTransInd' contains strings with 'X' in them
# Column 'StatesWhereCopyOfReturnIsFldCd' contains strings with 'X' in them
# Column 'NoListedPersonsCompensatedInd' contains 'X' values
# Column 'OtherExpensesGrp' contains strings with 'X' in them
# Column 'OrgDoesNotFollowSFAS117Ind' contains 'X' values
# Column 'MethodOfAccountingCashInd' contains 'X' values
# Column 'WebsiteAddressTxt' contains strings with 'X' in them
# Column 'ProgSrvcAccomActy2Grp' contains strings with 'X' in them
# Column 'ProgSrvcAccomActy3Grp' contains strings with 'X' in them
# Column 'ProgSrvcAccomActyOtherGrp' contains strings with 'X' in them
# Column 'InfoInScheduleOPartVIInd' contains 'X' values
# Column 'UponRequestInd' contains 'X' values
# Column 'OrganizationFollowsSFAS117Ind' contains 'X' values
# Column 'InfoInScheduleOPartXIInd' contains 'X' values
# Column 'InfoInScheduleOPartXIIInd' contains 'X' values
# Column 'InfoInScheduleOPartVInd' contains 'X' values
# Column 'MethodOfAccountingAccrualInd' contains 'X' values
# Column 'OtherWebsiteInd' contains 'X' values
# Column 'AddressChangeInd' contains 'X' values
# Column 'OwnWebsiteInd' contains 'X' values
# Column 'InfoInScheduleOPartIXInd' contains 'X' values
# Column 'TypeOfOrganizationTrustInd' contains 'X' values
# Column 'FinalReturnInd' contains 'X' values
# Column 'ContractTerminationInd' contains 'X' values
# Column 'InfoInScheduleOPartXInd' contains 'X' values
# Column 'InfoInScheduleOPartVIIInd' contains 'X' values
# Column 'TypeOfOrganizationOtherInd' contains 'X' values
# Column 'OtherOrganizationDsc' contains strings with 'X' in them
# Column 'InfoInScheduleOPartVIIIInd' contains 'X' values
# Column 'TypeOfOrganizationAssocInd' contains 'X' values
# Column 'InitialReturnInd' contains 'X' values
# Column 'MethodOfAccountingOtherInd' contains strings with 'X' in them
# Column 'Organization501cInd' contains strings with 'X' in them
# Column 'Organization4947a1NotPFInd' contains 'X' values
# Column 'AmendedReturnInd' contains 'X' values
# Column 'SpecialConditionDesc' contains strings with 'X' in them
# Column 'Officer' contains strings with 'X' in them
# Column 'BusinessOfficerGrp' contains strings with 'X' in them
# Column 'Name' contains strings with 'X' in them
# Column 'NameControl' contains strings with 'X' in them
# Column 'USAddress' contains strings with 'X' in them
# Column 'ForeignAddress' contains strings with 'X' in them
# Column 'InCareOfName' contains strings with 'X' in them
# Column 'BusinessName' contains strings with 'X' in them
# Column 'BusinessNameControlTxt' contains strings with 'X' in them
# Column 'InCareOfNm' contains strings with 'X' in them
#
# Found 99 columns with 'X' values
#
# List of columns with 'X':
# - OrganizationName
# - AddressChange
# - NameOfPrincipalOfficerPerson
# - Organization501c3
# - WebSite
# - TypeOfOrganizationCorporation
# - StateLegalDomicile
# - ActivityOrMissionDescription
# - InfoInScheduleOPartIII
# - MissionDescription
# - Description
# - InfoInScheduleOPartVI
# - StatesWhereCopyOfReturnIsFiled
# - UponRequest
# - NoListedPersonsCompensated
# - OtherExpenses
# - FollowSFAS117
# - InfoInScheduleOPartXI
# - InfoInScheduleOPartXII
# - MethodOfAccountingAccrual
# - MethodOfAccountingCash
# - Activity2
# - Activity3
# - InfoInScheduleOPartVII
# - OtherWebsite
# - MethodOfAccountingOther
# - DoNotFollowSFAS117
# - InitialReturn
# - InfoInScheduleOPartV
# - OwnWebsite
# - ActivityOther
# - TypeOfOrganizationOther
# - Organization501c
# - TypeOfOrganizationTrust
# - TypeOfOrganizationAssociation
# - AmendedReturn
# - TerminatedReturn
# - TerminationOrContraction
# - Organization4947a1
# - InfoInScheduleOPartIX
# - InfoInScheduleOPartVIII
# - InfoInScheduleOPartX
# - PrincipalOfficerNm
# - Organization501c3Ind
# - TypeOfOrganizationCorpInd
# - LegalDomicileStateCd
# - ActivityOrMissionDesc
# - InfoInScheduleOPartIIIInd
# - MissionDesc
# - Desc
# - ProfessionalFundraisingInd
# - FundraisingActivitiesInd
# - GamingActivitiesInd
# - PYExcessBenefitTransInd
# - StatesWhereCopyOfReturnIsFldCd
# - NoListedPersonsCompensatedInd
# - OtherExpensesGrp
# - OrgDoesNotFollowSFAS117Ind
# - MethodOfAccountingCashInd
# - WebsiteAddressTxt
# - ProgSrvcAccomActy2Grp
# - ProgSrvcAccomActy3Grp
# - ProgSrvcAccomActyOtherGrp
# - InfoInScheduleOPartVIInd
# - UponRequestInd
# - OrganizationFollowsSFAS117Ind
# - InfoInScheduleOPartXIInd
# - InfoInScheduleOPartXIIInd
# - InfoInScheduleOPartVInd
# - MethodOfAccountingAccrualInd
# - OtherWebsiteInd
# - AddressChangeInd
# - OwnWebsiteInd
# - InfoInScheduleOPartIXInd
# - TypeOfOrganizationTrustInd
# - FinalReturnInd
# - ContractTerminationInd
# - InfoInScheduleOPartXInd
# - InfoInScheduleOPartVIIInd
# - TypeOfOrganizationOtherInd
# - OtherOrganizationDsc
# - InfoInScheduleOPartVIIIInd
# - TypeOfOrganizationAssocInd
# - InitialReturnInd
# - MethodOfAccountingOtherInd
# - Organization501cInd
# - Organization4947a1NotPFInd
# - AmendedReturnInd
# - SpecialConditionDesc
# - Officer
# - BusinessOfficerGrp
# - Name
# - NameControl
# - USAddress
# - ForeignAddress
# - InCareOfName
# - BusinessName
# - BusinessNameControlTxt
# - InCareOfNm

# %%
x_columns
# Out:
# ['OrganizationName',
#  'AddressChange',
#  'NameOfPrincipalOfficerPerson',
#  'Organization501c3',
#  'WebSite',
#  'TypeOfOrganizationCorporation',
#  'StateLegalDomicile',
#  'ActivityOrMissionDescription',
#  'InfoInScheduleOPartIII',
#  'MissionDescription',
#  'Description',
#  'InfoInScheduleOPartVI',
#  'StatesWhereCopyOfReturnIsFiled',
#  'UponRequest',
#  'NoListedPersonsCompensated',
#  'OtherExpenses',
#  'FollowSFAS117',
#  'InfoInScheduleOPartXI',
#  'InfoInScheduleOPartXII',
#  'MethodOfAccountingAccrual',
#  'MethodOfAccountingCash',
#  'Activity2',
#  'Activity3',
#  'InfoInScheduleOPartVII',
#  'OtherWebsite',
#  'MethodOfAccountingOther',
#  'DoNotFollowSFAS117',
#  'InitialReturn',
#  'InfoInScheduleOPartV',
#  'OwnWebsite',
#  'ActivityOther',
#  'TypeOfOrganizationOther',
#  'Organization501c',
#  'TypeOfOrganizationTrust',
#  'TypeOfOrganizationAssociation',
#  'AmendedReturn',
#  'TerminatedReturn',
#  'TerminationOrContraction',
#  'Organization4947a1',
#  'InfoInScheduleOPartIX',
#  'InfoInScheduleOPartVIII',
#  'InfoInScheduleOPartX',
#  'PrincipalOfficerNm',
#  'Organization501c3Ind',
#  'TypeOfOrganizationCorpInd',
#  'LegalDomicileStateCd',
#  'ActivityOrMissionDesc',
#  'InfoInScheduleOPartIIIInd',
#  'MissionDesc',
#  'Desc',
#  'ProfessionalFundraisingInd',
#  'FundraisingActivitiesInd',
#  'GamingActivitiesInd',
#  'PYExcessBenefitTransInd',
#  'StatesWhereCopyOfReturnIsFldCd',
#  'NoListedPersonsCompensatedInd',
#  'OtherExpensesGrp',
#  'OrgDoesNotFollowSFAS117Ind',
#  'MethodOfAccountingCashInd',
#  'WebsiteAddressTxt',
#  'ProgSrvcAccomActy2Grp',
#  'ProgSrvcAccomActy3Grp',
#  'ProgSrvcAccomActyOtherGrp',
#  'InfoInScheduleOPartVIInd',
#  'UponRequestInd',
#  'OrganizationFollowsSFAS117Ind',
#  'InfoInScheduleOPartXIInd',
#  'InfoInScheduleOPartXIIInd',
#  'InfoInScheduleOPartVInd',
#  'MethodOfAccountingAccrualInd',
#  'OtherWebsiteInd',
#  'AddressChangeInd',
#  'OwnWebsiteInd',
#  'InfoInScheduleOPartIXInd',
#  'TypeOfOrganizationTrustInd',
#  'FinalReturnInd',
#  'ContractTerminationInd',
#  'InfoInScheduleOPartXInd',
#  'InfoInScheduleOPartVIIInd',
#  'TypeOfOrganizationOtherInd',
#  'OtherOrganizationDsc',
#  'InfoInScheduleOPartVIIIInd',
#  'TypeOfOrganizationAssocInd',
#  'InitialReturnInd',
#  'MethodOfAccountingOtherInd',
#  'Organization501cInd',
#  'Organization4947a1NotPFInd',
#  'AmendedReturnInd',
#  'SpecialConditionDesc',
#  'Officer',
#  'BusinessOfficerGrp',
#  'Name',
#  'NameControl',
#  'USAddress',
#  'ForeignAddress',
#  'InCareOfName',
#  'BusinessName',
#  'BusinessNameControlTxt',
#  'InCareOfNm']

# %%
# To ensure these columns are saved as strings, simply convert them:
def fix_and_save_parquet(df, string_columns, output_path='fixed_dataframe.parquet'):
    """
    Convert specified columns to string type and save to parquet
    """
    # Make a copy of the dataframe
    df_fixed = df.copy()
    
    # Convert columns with 'X' to string type
    for col in string_columns:
        df_fixed[col] = df_fixed[col].astype(str)
        print(f"Converted '{col}' to string type")
    
    # Save to parquet with string_as_string option
    # If using modin, convert to pandas first
    if 'modin.pandas' in str(type(df_fixed)):
        df_fixed = df_fixed._to_pandas()
    
    # Save with options to preserve string type
    df_fixed.to_parquet(
        output_path,
        engine='pyarrow',
        # These options help ensure strings stay as strings
        use_dictionary=False
    )
    print(f"Saved to {output_path}")
    
    return df_fixed

# %%
# %%time
# Example usage:
fix_and_save_parquet(df, x_columns)
# Out:
# Converted 'OrganizationName' to string type
# Converted 'AddressChange' to string type
# Converted 'NameOfPrincipalOfficerPerson' to string type
# Converted 'Organization501c3' to string type
# Converted 'WebSite' to string type
# Converted 'TypeOfOrganizationCorporation' to string type
# Converted 'StateLegalDomicile' to string type
# Converted 'ActivityOrMissionDescription' to string type
# Converted 'InfoInScheduleOPartIII' to string type
# Converted 'MissionDescription' to string type
# Converted 'Description' to string type
# Converted 'InfoInScheduleOPartVI' to string type
# Converted 'StatesWhereCopyOfReturnIsFiled' to string type
# Converted 'UponRequest' to string type
# Converted 'NoListedPersonsCompensated' to string type
# Converted 'OtherExpenses' to string type
# Converted 'FollowSFAS117' to string type
# Converted 'InfoInScheduleOPartXI' to string type
# Converted 'InfoInScheduleOPartXII' to string type
# Converted 'MethodOfAccountingAccrual' to string type
# Converted 'MethodOfAccountingCash' to string type
# Converted 'Activity2' to string type
# Converted 'Activity3' to string type
# Converted 'InfoInScheduleOPartVII' to string type
# Converted 'OtherWebsite' to string type
# Converted 'MethodOfAccountingOther' to string type
# Converted 'DoNotFollowSFAS117' to string type
# Converted 'InitialReturn' to string type
# Converted 'InfoInScheduleOPartV' to string type
# Converted 'OwnWebsite' to string type
# Converted 'ActivityOther' to string type
# Converted 'TypeOfOrganizationOther' to string type
# Converted 'Organization501c' to string type
# Converted 'TypeOfOrganizationTrust' to string type
# Converted 'TypeOfOrganizationAssociation' to string type
# Converted 'AmendedReturn' to string type
# Converted 'TerminatedReturn' to string type
# Converted 'TerminationOrContraction' to string type
# Converted 'Organization4947a1' to string type
# Converted 'InfoInScheduleOPartIX' to string type
# Converted 'InfoInScheduleOPartVIII' to string type
# Converted 'InfoInScheduleOPartX' to string type
# Converted 'PrincipalOfficerNm' to string type
# Converted 'Organization501c3Ind' to string type
# Converted 'TypeOfOrganizationCorpInd' to string type
# Converted 'LegalDomicileStateCd' to string type
# Converted 'ActivityOrMissionDesc' to string type
# Converted 'InfoInScheduleOPartIIIInd' to string type
# Converted 'MissionDesc' to string type
# Converted 'Desc' to string type
# Converted 'ProfessionalFundraisingInd' to string type
# Converted 'FundraisingActivitiesInd' to string type
# Converted 'GamingActivitiesInd' to string type
# Converted 'PYExcessBenefitTransInd' to string type
# Converted 'StatesWhereCopyOfReturnIsFldCd' to string type
# Converted 'NoListedPersonsCompensatedInd' to string type
# Converted 'OtherExpensesGrp' to string type
# Converted 'OrgDoesNotFollowSFAS117Ind' to string type
# Converted 'MethodOfAccountingCashInd' to string type
# Converted 'WebsiteAddressTxt' to string type
# Converted 'ProgSrvcAccomActy2Grp' to string type
# Converted 'ProgSrvcAccomActy3Grp' to string type
# Converted 'ProgSrvcAccomActyOtherGrp' to string type
# Converted 'InfoInScheduleOPartVIInd' to string type
# Converted 'UponRequestInd' to string type
# Converted 'OrganizationFollowsSFAS117Ind' to string type
# Converted 'InfoInScheduleOPartXIInd' to string type
# Converted 'InfoInScheduleOPartXIIInd' to string type
# Converted 'InfoInScheduleOPartVInd' to string type
# Converted 'MethodOfAccountingAccrualInd' to string type
# Converted 'OtherWebsiteInd' to string type
# Converted 'AddressChangeInd' to string type
# Converted 'OwnWebsiteInd' to string type
# Converted 'InfoInScheduleOPartIXInd' to string type
# Converted 'TypeOfOrganizationTrustInd' to string type
# Converted 'FinalReturnInd' to string type
# Converted 'ContractTerminationInd' to string type
# Converted 'InfoInScheduleOPartXInd' to string type
# Converted 'InfoInScheduleOPartVIIInd' to string type
# Converted 'TypeOfOrganizationOtherInd' to string type
# Converted 'OtherOrganizationDsc' to string type
# Converted 'InfoInScheduleOPartVIIIInd' to string type
# Converted 'TypeOfOrganizationAssocInd' to string type
# Converted 'InitialReturnInd' to string type
# Converted 'MethodOfAccountingOtherInd' to string type
# Converted 'Organization501cInd' to string type
# Converted 'Organization4947a1NotPFInd' to string type
# Converted 'AmendedReturnInd' to string type
# Converted 'SpecialConditionDesc' to string type
# Converted 'Officer' to string type
# Converted 'BusinessOfficerGrp' to string type
# Converted 'Name' to string type
# Converted 'NameControl' to string type
# Converted 'USAddress' to string type
# Converted 'ForeignAddress' to string type
# Converted 'InCareOfName' to string type
# Converted 'BusinessName' to string type
# Converted 'BusinessNameControlTxt' to string type
# Converted 'InCareOfNm' to string type
# Saved to fixed_dataframe.parquet
# CPU times: total: 7min 29s
# Wall time: 26min 6s
#                               _id  \
# 0        5d019e6778ffca27b42818d7
# 1        5d019e6778ffca27b42818d8
# 2        5d019e6878ffca27b42818d9
# 3        5d019e6878ffca27b42818da
# 4        5d019e6878ffca27b42818db
# ...                           ...
# 3469003  67f0a6febea7582f201aed1e
# 3469004  67f0a6febea7582f201aed1f
# 3469005  67f0a6febea7582f201aed20
# 3469006  67f0a6febea7582f201aed21
# 3469007  67f0a6febea7582f201aed22
#
#                                                  OrganizationName  \
# 0        RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1              TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
# 2               HOUSTON VOA INDEPENDENT HOUSING INC HEIGHTS MANOR
# 3                                         FAITH-HAVEN CORPORATION
# 4                                     OCHSNER COMMUNITY HOSPITALS
# ...                                                           ...
# 3469003                                                      <NA>
# 3469004                                                      <NA>
# 3469005                                                      <NA>
# 3469006                                                      <NA>
# 3469007                                                      <NA>
#
#                                                                          URL  \
# 0        https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1        https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
# 2        https://s3.amazonaws.com/irs-form-990/201113139349301316_public.xml
# 3        https://s3.amazonaws.com/irs-form-990/201113139349301321_public.xml
# 4        https://s3.amazonaws.com/irs-form-990/201113139349301326_public.xml
# ...                                                                      ...
# 3469003  https://s3.amazonaws.com/irs-form-990/202441449349301604_public.xml
# 3469004  https://s3.amazonaws.com/irs-form-990/202441449349301609_public.xml
# 3469005  https://s3.amazonaws.com/irs-form-990/202441449349301614_public.xml
# 3469006  https://s3.amazonaws.com/irs-form-990/202441449349301654_public.xml
# 3469007  https://s3.amazonaws.com/irs-form-990/202441449349301704_public.xml
#
#                     DLN TaxPeriod AddressChange NameOfPrincipalOfficerPerson  \
# 0        93493313013011    201012             X                MICHAEL ANTON
# 1        93493313013111    201106          <NA>                         <NA>
# 2        93493313013161    201106          <NA>                         <NA>
# 3        93493313013211    201106          <NA>               John P Spiller
# 4        93493313013261    201012          <NA>            Patrick J Quinlan
# ...                 ...       ...           ...                          ...
# 3469003            <NA>      <NA>          <NA>                         <NA>
# 3469004            <NA>      <NA>          <NA>                         <NA>
# 3469005            <NA>      <NA>          <NA>                         <NA>
# 3469006            <NA>      <NA>          <NA>                         <NA>
# 3469007            <NA>      <NA>          <NA>                         <NA>
#
#         GrossReceipts GroupReturnForAffiliates Organization501c3  \
# 0             1473903                        0                 X
# 1              266420                    false                 X
# 2              217525                    false                 X
# 3               45615                    false                 X
# 4           666103016                        0                 X
# ...               ...                      ...               ...
# 3469003          <NA>                     <NA>              <NA>
# 3469004          <NA>                     <NA>              <NA>
# 3469005          <NA>                     <NA>              <NA>
# 3469006          <NA>                     <NA>              <NA>
# 3469007          <NA>                     <NA>              <NA>
#
#                  WebSite TypeOfOrganizationCorporation YearFormation  \
# 0                    N/A                             X          1992
# 1                    N/A                             X          1993
# 2                    N/A                             X          1990
# 3                    N/A                             X          1965
# 4        www.ochsner.org                             X          2006
# ...                  ...                           ...           ...
# 3469003             <NA>                          <NA>          <NA>
# 3469004             <NA>                          <NA>          <NA>
# 3469005             <NA>                          <NA>          <NA>
# 3469006             <NA>                          <NA>          <NA>
# 3469007             <NA>                          <NA>          <NA>
#
#         StateLegalDomicile  \
# 0                       PA
# 1                       WY
# 2                       TX
# 3                       WI
# 4                       LA
# ...                    ...
# 3469003               <NA>
# 3469004               <NA>
# 3469005               <NA>
# 3469006               <NA>
# 3469007               <NA>
#
#                                                                                                                           ActivityOrMissionDescription  \
# 0                                                             MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
# 1        PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
# 2                       PROVIDES HOUSING TO DISABLED PERSONS UNDER SECTION 811 OF THE NATIONAL HOUSING ACT UNDER AGREEMENT WITH THE DEPARTMENT OF HUD.
# 3                                                                                                                                    Spiritual retreat
# 4                                                        Provides Patient Care via ownership and operation of 2 hospitals in the New Orleans, LA area.
# ...                                                                                                                                                ...
# 3469003                                                                                                                                           <NA>
# 3469004                                                                                                                                           <NA>
# 3469005                                                                                                                                           <NA>
# 3469006                                                                                                                                           <NA>
# 3469007                                                                                                                                           <NA>
#
#         NbrVotingMembersGoverningBody NbrIndependentVotingMembers  \
# 0                                  10                          10
# 1                                  19                          13
# 2                                  19                          13
# 3                                   4                           4
# 4                                  15                           8
# ...                               ...                         ...
# 3469003                          <NA>                        <NA>
# 3469004                          <NA>                        <NA>
# 3469005                          <NA>                        <NA>
# 3469006                          <NA>                        <NA>
# 3469007                          <NA>                        <NA>
#
#         TotalNbrEmployees TotalNbrVolunteers TotalGrossUBI  \
# 0                       0                  0             0
# 1                       0               <NA>             0
# 2                       0               <NA>             0
# 3                       1               <NA>        -27746
# 4                    1716                148             0
# ...                   ...                ...           ...
# 3469003              <NA>               <NA>          <NA>
# 3469004              <NA>               <NA>          <NA>
# 3469005              <NA>               <NA>          <NA>
# 3469006              <NA>               <NA>          <NA>
# 3469007              <NA>               <NA>          <NA>
#
#         NetUnrelatedBusinessTxblIncome ContributionsGrantsPriorYear  \
# 0                                    0                      1044925
# 1                                 <NA>                         <NA>
# 2                                 <NA>                         <NA>
# 3                                 <NA>                      1397666
# 4                                    0                            0
# ...                                ...                          ...
# 3469003                           <NA>                         <NA>
# 3469004                           <NA>                         <NA>
# 3469005                           <NA>                         <NA>
# 3469006                           <NA>                         <NA>
# 3469007                           <NA>                         <NA>
#
#         ContributionsGrantsCurrentYear ProgramServiceRevenuePriorYear  \
# 0                              1439340                              0
# 1                                    0                         222839
# 2                                    0                         191659
# 3                                 6582                           <NA>
# 4                                    0                      629297438
# ...                                ...                            ...
# 3469003                           <NA>                           <NA>
# 3469004                           <NA>                           <NA>
# 3469005                           <NA>                           <NA>
# 3469006                           <NA>                           <NA>
# 3469007                           <NA>                           <NA>
#
#         ProgramServiceRevenueCY InvestmentIncomePriorYear  \
# 0                             0                     30447
# 1                        265592                      1425
# 2                        217457                        75
# 3                             0                     11306
# 4                     662987788                     58188
# ...                         ...                       ...
# 3469003                    <NA>                      <NA>
# 3469004                    <NA>                      <NA>
# 3469005                    <NA>                      <NA>
# 3469006                    <NA>                      <NA>
# 3469007                    <NA>                      <NA>
#
#         InvestmentIncomeCurrentYear OtherRevenuePriorYear  \
# 0                             33563                     0
# 1                               828                  <NA>
# 2                                68                  <NA>
# 3                             22783                -10099
# 4                              4682               1638243
# ...                             ...                   ...
# 3469003                        <NA>                  <NA>
# 3469004                        <NA>                  <NA>
# 3469005                        <NA>                  <NA>
# 3469006                        <NA>                  <NA>
# 3469007                        <NA>                  <NA>
#
#         OtherRevenueCurrentYear TotalRevenuePriorYear TotalRevenueCurrentYear  \
# 0                          1000               1075372                 1473903
# 1                             0                224264                  266420
# 2                             0                191734                  217525
# 3                        -27746               1398873                    1619
# 4                       1974404             630993869               664966874
# ...                         ...                   ...                     ...
# 3469003                    <NA>                  <NA>                    <NA>
# 3469004                    <NA>                  <NA>                    <NA>
# 3469005                    <NA>                  <NA>                    <NA>
# 3469006                    <NA>                  <NA>                    <NA>
# 3469007                    <NA>                  <NA>                    <NA>
#
#         GrantsAndSimilarAmntsPriorYear GrantsAndSimilarAmntsCY  \
# 0                               638637                  925000
# 1                                 <NA>                       0
# 2                                 <NA>                       0
# 3                                 <NA>                       0
# 4                                    0                       0
# ...                                ...                     ...
# 3469003                           <NA>                    <NA>
# 3469004                           <NA>                    <NA>
# 3469005                           <NA>                    <NA>
# 3469006                           <NA>                    <NA>
# 3469007                           <NA>                    <NA>
#
#         BenefitsPaidToMembersPriorYear BenefitsPaidToMembersCY  \
# 0                                    0                       0
# 1                                 <NA>                       0
# 2                                 <NA>                       0
# 3                                 <NA>                       0
# 4                                    0                       0
# ...                                ...                     ...
# 3469003                           <NA>                    <NA>
# 3469004                           <NA>                    <NA>
# 3469005                           <NA>                    <NA>
# 3469006                           <NA>                    <NA>
# 3469007                           <NA>                    <NA>
#
#         SalariesEtcPriorYear SalariesEtcCurrentYear  \
# 0                          0                      0
# 1                      71405                  82955
# 2                      68020                  82340
# 3                      12918                  12918
# 4                   62401266               68935384
# ...                      ...                    ...
# 3469003                 <NA>                   <NA>
# 3469004                 <NA>                   <NA>
# 3469005                 <NA>                   <NA>
# 3469006                 <NA>                   <NA>
# 3469007                 <NA>                   <NA>
#
#         TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 0                                   0                      0
# 1                                <NA>                      0
# 2                                <NA>                      0
# 3                                <NA>                      0
# 4                                   0                      0
# ...                               ...                    ...
# 3469003                          <NA>                   <NA>
# 3469004                          <NA>                   <NA>
# 3469005                          <NA>                   <NA>
# 3469006                          <NA>                   <NA>
# 3469007                          <NA>                   <NA>
#
#         TotalFundrsngExpCurrentYear OtherExpensePriorYear  \
# 0                            195892                243131
# 1                                 0                189785
# 2                                 0                152057
# 3                                 0                 53071
# 4                            178129             577137415
# ...                             ...                   ...
# 3469003                        <NA>                  <NA>
# 3469004                        <NA>                  <NA>
# 3469005                        <NA>                  <NA>
# 3469006                        <NA>                  <NA>
# 3469007                        <NA>                  <NA>
#
#         OtherExpensesCurrentYear TotalExpensesPriorYear  \
# 0                         459751                 881768
# 1                         222550                 261190
# 2                         167046                 220077
# 3                          42902                  65989
# 4                      604774393              639538681
# ...                          ...                    ...
# 3469003                     <NA>                   <NA>
# 3469004                     <NA>                   <NA>
# 3469005                     <NA>                   <NA>
# 3469006                     <NA>                   <NA>
# 3469007                     <NA>                   <NA>
#
#         TotalExpensesCurrentYear RevenuesLessExpensesPriorYear  \
# 0                        1384751                        193604
# 1                         305505                        -36926
# 2                         249386                        -28343
# 3                          55820                       1332884
# 4                      673709777                      -8544812
# ...                          ...                           ...
# 3469003                     <NA>                          <NA>
# 3469004                     <NA>                          <NA>
# 3469005                     <NA>                          <NA>
# 3469006                     <NA>                          <NA>
# 3469007                     <NA>                          <NA>
#
#         RevenuesLessExpensesCY TotalAssetsBOY TotalAssetsEOY  \
# 0                        89152        1925215        2440859
# 1                       -39085        1455332        1433342
# 2                       -31861         978564         950110
# 3                       -54201        1845077        1791712
# 4                     -8742903      139385579      147143219
# ...                        ...            ...            ...
# 3469003                   <NA>           <NA>           <NA>
# 3469004                   <NA>           <NA>           <NA>
# 3469005                   <NA>           <NA>           <NA>
# 3469006                   <NA>           <NA>           <NA>
# 3469007                   <NA>           <NA>           <NA>
#
#         TotalLiabilitiesBOY TotalLiabilitiesEOY NetAssetsOrFundBalancesBOY  \
# 0                    171810              450430                    1753405
# 1                     17482               34577                    1437850
# 2                     21245               24652                     957319
# 3                     20898               21734                    1824179
# 4                 229622579           245608219                  -90237000
# ...                     ...                 ...                        ...
# 3469003                <NA>                <NA>                       <NA>
# 3469004                <NA>                <NA>                       <NA>
# 3469005                <NA>                <NA>                       <NA>
# 3469006                <NA>                <NA>                       <NA>
# 3469007                <NA>                <NA>                       <NA>
#
#         NetAssetsOrFundBalancesEOY InfoInScheduleOPartIII  \
# 0                          1990429                      X
# 1                          1398765                   <NA>
# 2                           925458                   <NA>
# 3                          1769978                   <NA>
# 4                        -98465000                      X
# ...                            ...                    ...
# 3469003                       <NA>                   <NA>
# 3469004                       <NA>                   <NA>
# 3469005                       <NA>                   <NA>
# 3469006                       <NA>                   <NA>
# 3469007                       <NA>                   <NA>
#
#                                                                                                                                                                                                                                                 MissionDescription  \
# 0        THE CORPORATION IS ORGANIZED AND WILL BE OPERATED EXCLUSIVELY FOR CHARITABLE, EDUCATIONAL AND SCIENTIFIC PURPOSES WITHIN THE MEANING OF SECTION 501(C)(3) OF THE INTERNAL REVENUE CODE. SUCH PURPOSES SHALL BE LIMITED TO PROVIDING SUPPORT AND FUNDIN...
# 1                                                                                                                    PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
# 2                                                                                                                                   PROVIDES HOUSING TO DISABLED PERSONS UNDER SECTION 811 OF THE NATIONAL HOUSING ACT UNDER AGREEMENT WITH THE DEPARTMENT OF HUD.
# 3                                                                                                                                                                                                                                                Spiritual retreat
# 4        We Serve, Heal, Lead, Educate and Innovate. Ochsner will be a global medical and academic leader who will save and change lives. We will shape the future of healthcare through our integrated health system, fueled by the passion and strength of ou...
# ...                                                                                                                                                                                                                                                            ...
# 3469003                                                                                                                                                                                                                                                       <NA>
# 3469004                                                                                                                                                                                                                                                       <NA>
# 3469005                                                                                                                                                                                                                                                       <NA>
# 3469006                                                                                                                                                                                                                                                       <NA>
# 3469007                                                                                                                                                                                                                                                       <NA>
#
#         SignificantNewProgramServices SignificantChange    Expense  Grants  \
# 0                                   0                 0    1043744  925000
# 1                               false             false     276405    <NA>
# 2                               false             false     231299    <NA>
# 3                               false             false      53484    <NA>
# 4                                   0                 0  646184916    <NA>
# ...                               ...               ...        ...     ...
# 3469003                          <NA>              <NA>       <NA>    <NA>
# 3469004                          <NA>              <NA>       <NA>    <NA>
# 3469005                          <NA>              <NA>       <NA>    <NA>
# 3469006                          <NA>              <NA>       <NA>    <NA>
# 3469007                          <NA>              <NA>       <NA>    <NA>
#
#                                                                                                                                                                                                                                                        Description  \
# 0        RMHC OF THE PHILADELPHIA REGION, INC. GRANTS HUNDREDS OF THOUSANDS OF DOLLARS PER YEAR TO SUPPORT NON-PROFIT PROGRAMS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN. LOCALLY, RMHC SUPPORTS THE PHILADELPHIA, SOUTHERN NEW JERSEY AND DE...
# 1                                                                                                                    PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
# 2                                                                                                                                   PROVIDES HOUSING TO DISABLED PERSONS UNDER SECTION 811 OF THE NATIONAL HOUSING ACT UNDER AGREEMENT WITH THE DEPARTMENT OF HUD.
# 3                                                                                                                                                      Chapels provided to the public for use as a place for worship, weddings, meditation or ecumenical retreats.
# 4        Patient Care: Ochsner Community Hospitals operates two hospitals that served 17,002 inpatients for a total of 70,743 patient days. Outpatient visits totaled 128,154. There were a total of 1,238 births and 50,710 Emergency Room visits to Ochsner C...
# ...                                                                                                                                                                                                                                                            ...
# 3469003                                                                                                                                                                                                                                                       <NA>
# 3469004                                                                                                                                                                                                                                                       <NA>
# 3469005                                                                                                                                                                                                                                                       <NA>
# 3469006                                                                                                                                                                                                                                                       <NA>
# 3469007                                                                                                                                                                                                                                                       <NA>
#
#         TotalProgramServiceExpense  \
# 0                          1043744
# 1                           276405
# 2                           231299
# 3                            53484
# 4                        646613548
# ...                            ...
# 3469003                       <NA>
# 3469004                       <NA>
# 3469005                       <NA>
# 3469006                       <NA>
# 3469007                       <NA>
#
#                                                 PoliticalActivities  \
# 0                                                               "0"
# 1                                                           "false"
# 2                                                           "false"
# 3                                                           "false"
# 4        {"@referenceDocumentId": "RetDoc1039600001", "#text": "0"}
# ...                                                             ...
# 3469003                                                        <NA>
# 3469004                                                        <NA>
# 3469005                                                        <NA>
# 3469006                                                        <NA>
# 3469007                                                        <NA>
#
#                                                  LobbyingActivities  \
# 0                                                               "0"
# 1                                                           "false"
# 2                                                           "false"
# 3                                                           "false"
# 4        {"@referenceDocumentId": "RetDoc1039600001", "#text": "1"}
# ...                                                             ...
# 3469003                                                        <NA>
# 3469004                                                        <NA>
# 3469005                                                        <NA>
# 3469006                                                        <NA>
# 3469007                                                        <NA>
#
#         ProfessionalFundraising FundraisingActivities   Gaming  \
# 0                           "0"                   "0"      "0"
# 1                       "false"               "false"  "false"
# 2                       "false"               "false"  "false"
# 3                       "false"               "false"  "false"
# 4                           "0"                   "0"      "0"
# ...                         ...                   ...      ...
# 3469003                    <NA>                  <NA>     <NA>
# 3469004                    <NA>                  <NA>     <NA>
# 3469005                    <NA>                  <NA>     <NA>
# 3469006                    <NA>                  <NA>     <NA>
# 3469007                    <NA>                  <NA>     <NA>
#
#                                                ExcessBenefitTransaction  \
# 0                                                                   "0"
# 1                                                               "false"
# 2                                                               "false"
# 3        {"@referenceDocumentId": " IRS990ScheduleL", "#text": "false"}
# 4            {"@referenceDocumentId": "RetDoc1042800001", "#text": "0"}
# ...                                                                 ...
# 3469003                                                            <NA>
# 3469004                                                            <NA>
# 3469005                                                            <NA>
# 3469006                                                            <NA>
# 3469007                                                            <NA>
#
#                                           PriorExcessBenefitTransaction  \
# 0                                                                   "0"
# 1                                                               "false"
# 2                                                               "false"
# 3        {"@referenceDocumentId": " IRS990ScheduleL", "#text": "false"}
# 4            {"@referenceDocumentId": "RetDoc1042800001", "#text": "0"}
# ...                                                                 ...
# 3469003                                                            <NA>
# 3469004                                                            <NA>
# 3469005                                                            <NA>
# 3469006                                                            <NA>
# 3469007                                                            <NA>
#
#                                                      DisregardedEntity  \
# 0                                                                  "0"
# 1        {"@referenceDocumentId": " IRS990ScheduleR", "#text": "true"}
# 2        {"@referenceDocumentId": " IRS990ScheduleR", "#text": "true"}
# 3                                                              "false"
# 4           {"@referenceDocumentId": "RetDoc1043400001", "#text": "1"}
# ...                                                                ...
# 3469003                                                           <NA>
# 3469004                                                           <NA>
# 3469005                                                           <NA>
# 3469006                                                           <NA>
# 3469007                                                           <NA>
#
#                                                          RelatedEntity  \
# 0                                                                  "0"
# 1        {"@referenceDocumentId": " IRS990ScheduleR", "#text": "true"}
# 2        {"@referenceDocumentId": " IRS990ScheduleR", "#text": "true"}
# 3                                                              "false"
# 4           {"@referenceDocumentId": "RetDoc1043400001", "#text": "1"}
# ...                                                                ...
# 3469003                                                           <NA>
# 3469004                                                           <NA>
# 3469005                                                           <NA>
# 3469006                                                           <NA>
# 3469007                                                           <NA>
#
#         RelatedOrgControlledEntity  \
# 0                              "0"
# 1                          "false"
# 2                          "false"
# 3                          "false"
# 4                              "0"
# ...                            ...
# 3469003                       <NA>
# 3469004                       <NA>
# 3469005                       <NA>
# 3469006                       <NA>
# 3469007                       <NA>
#
#                                                TransactionRelatedEntity  \
# 0                                                                   "0"
# 1        {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
# 2        {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
# 3                                                               "false"
# 4            {"@referenceDocumentId": "RetDoc1043400001", "#text": "0"}
# ...                                                                 ...
# 3469003                                                            <NA>
# 3469004                                                            <NA>
# 3469005                                                            <NA>
# 3469006                                                            <NA>
# 3469007                                                            <NA>
#
#                                           TransfersToExemptNonChrtblOrg  \
# 0                                                                   "0"
# 1        {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
# 2        {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
# 3                                                               "false"
# 4            {"@referenceDocumentId": "RetDoc1043400001", "#text": "0"}
# ...                                                                 ...
# 3469003                                                            <NA>
# 3469004                                                            <NA>
# 3469005                                                            <NA>
# 3469006                                                            <NA>
# 3469007                                                            <NA>
#
#                                          ActivitiesConductedPartnership  \
# 0                                                                   "0"
# 1        {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
# 2        {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
# 3                                                               "false"
# 4            {"@referenceDocumentId": "RetDoc1043400001", "#text": "0"}
# ...                                                                 ...
# 3469003                                                            <NA>
# 3469004                                                            <NA>
# 3469005                                                            <NA>
# 3469006                                                            <NA>
# 3469007                                                            <NA>
#
#         NumberFormsTransmittedWith1096 NumberOfEmployees  \
# 0                                    0                 0
# 1                                    0                 0
# 2                                    0                 0
# 3                                    1                 1
# 4                                  115              1716
# ...                                ...               ...
# 3469003                           <NA>              <NA>
# 3469004                           <NA>              <NA>
# 3469005                           <NA>              <NA>
# 3469006                           <NA>              <NA>
# 3469007                           <NA>              <NA>
#
#         UnrelatedBusinessIncome InfoInScheduleOPartVI  \
# 0                             0                     X
# 1                         false                     X
# 2                         false                     X
# 3                         false                     X
# 4                             0                     X
# ...                         ...                   ...
# 3469003                    <NA>                  <NA>
# 3469004                    <NA>                  <NA>
# 3469005                    <NA>                  <NA>
# 3469006                    <NA>                  <NA>
# 3469007                    <NA>                  <NA>
#
#         NbrVotingGoverningBodyMembers NumberIndependentVotingMembers  \
# 0                                  10                             10
# 1                                  19                             13
# 2                                  19                             13
# 3                                   4                              4
# 4                                  15                              8
# ...                               ...                            ...
# 3469003                          <NA>                           <NA>
# 3469004                          <NA>                           <NA>
# 3469005                          <NA>                           <NA>
# 3469006                          <NA>                           <NA>
# 3469007                          <NA>                           <NA>
#
#         FamilyOrBusinessRelationship DelegationOfManagementDuties  \
# 0                                  0                            0
# 1                               true                         true
# 2                               true                         true
# 3                              false                        false
# 4                                  0                            0
# ...                              ...                          ...
# 3469003                         <NA>                         <NA>
# 3469004                         <NA>                         <NA>
# 3469005                         <NA>                         <NA>
# 3469006                         <NA>                         <NA>
# 3469007                         <NA>                         <NA>
#
#         ChangesToOrganizingDocs MaterialDiversionOrMisuse  \
# 0                             0                         0
# 1                         false                     false
# 2                         false                     false
# 3                         false                     false
# 4                             0                         0
# ...                         ...                       ...
# 3469003                    <NA>                      <NA>
# 3469004                    <NA>                      <NA>
# 3469005                    <NA>                      <NA>
# 3469006                    <NA>                      <NA>
# 3469007                    <NA>                      <NA>
#
#         MembersOrStockholders ElectionOfBoardMembers  \
# 0                           0                      0
# 1                       false                   true
# 2                       false                   true
# 3                       false                  false
# 4                           1                      1
# ...                       ...                    ...
# 3469003                  <NA>                   <NA>
# 3469004                  <NA>                   <NA>
# 3469005                  <NA>                   <NA>
# 3469006                  <NA>                   <NA>
# 3469007                  <NA>                   <NA>
#
#         DecisionsSubjectToApproval MinutesOfGoverningBody MinutesOfCommittees  \
# 0                                0                      1                   1
# 1                             true                   true                true
# 2                             true                   true                true
# 3                            false                   true                true
# 4                                1                      1                   1
# ...                            ...                    ...                 ...
# 3469003                       <NA>                   <NA>                <NA>
# 3469004                       <NA>                   <NA>                <NA>
# 3469005                       <NA>                   <NA>                <NA>
# 3469006                       <NA>                   <NA>                <NA>
# 3469007                       <NA>                   <NA>                <NA>
#
#         OfficerMailingAddress LocalChapters Form990ProvidedToGoverningBody  \
# 0                           0             0                              1
# 1                       false         false                           true
# ...
# 3                   <NA>                 <NA>                    <NA>
# 4                   <NA>                 <NA>                    <NA>
# ...                  ...                  ...                     ...
# 3469003             <NA>                 <NA>                    <NA>
# 3469004             <NA>                 <NA>                    <NA>
# 3469005             <NA>                 <NA>                    <NA>
# 3469006             <NA>                 <NA>                    <NA>
# 3469007             <NA>                    0                       0
#
#         MethodOfAccountingOtherInd InvestmentExpenseAmt  \
# 0                             <NA>                 <NA>
# 1                             <NA>                 <NA>
# 2                             <NA>                 <NA>
# 3                             <NA>                 <NA>
# 4                             <NA>                 <NA>
# ...                            ...                  ...
# 3469003                        NaN                 <NA>
# 3469004                        NaN                 <NA>
# 3469005                        NaN                 <NA>
# 3469006                        NaN                 <NA>
# 3469007                        NaN                 <NA>
#
#                                       Organization501cInd  \
# 0                                                    <NA>
# 1                                                    <NA>
# 2                                                    <NA>
# 3                                                    <NA>
# 4                                                    <NA>
# ...                                                   ...
# 3469003                                               NaN
# 3469004  {"@organization501cTypeTxt": "12", "#text": "X"}
# 3469005                                               NaN
# 3469006                                               NaN
# 3469007                                               NaN
#
#         Organization4947a1NotPFInd AmendedReturnInd SpecialConditionDesc  \
# 0                             <NA>             <NA>                 <NA>
# 1                             <NA>             <NA>                 <NA>
# 2                             <NA>             <NA>                 <NA>
# 3                             <NA>             <NA>                 <NA>
# 4                             <NA>             <NA>                 <NA>
# ...                            ...              ...                  ...
# 3469003                       <NA>             <NA>                 <NA>
# 3469004                       <NA>             <NA>                 <NA>
# 3469005                       <NA>             <NA>                 <NA>
# 3469006                       <NA>             <NA>                 <NA>
# 3469007                       <NA>             <NA>                 <NA>
#
#         ActivityCd                  Timestamp TaxPeriodEndDate  \
# 0             <NA>  2011-11-09T06:41:09-06:00       2010-12-31
# 1             <NA>  2011-11-09T07:32:06-08:00       2011-06-30
# 2             <NA>  2011-11-09T07:33:03-08:00       2011-06-30
# 3             <NA>  2011-11-09T07:54:44-08:00       2011-06-30
# 4             <NA>  2011-11-09T10:05:52-06:00       2010-12-31
# ...            ...                        ...              ...
# 3469003       <NA>                       <NA>             <NA>
# 3469004       <NA>                       <NA>             <NA>
# 3469005       <NA>                       <NA>             <NA>
# 3469006       <NA>                       <NA>             <NA>
# 3469007       <NA>                       <NA>             <NA>
#
#         TaxPeriodBeginDate  \
# 0               2010-01-01
# 1               2010-07-01
# 2               2010-07-01
# 3               2010-07-01
# 4               2010-01-01
# ...                    ...
# 3469003               <NA>
# 3469004               <NA>
# 3469005               <NA>
# 3469006               <NA>
# 3469007               <NA>
#
#                                                                                                                                               Officer  \
# 0                        {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
# 1                                                               {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
# 2                                                               {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
# 3                                                                  {'Name': 'John P Spiller', 'Title': 'Pres./Caretaker', 'DateSigned': '2011-11-09'}
# 4        {'Name': 'Bobby C Brannon', 'Title': 'VP, Secretary & Treas', 'Phone': '5048423400', 'DateSigned': '2011-11-09', 'AuthorizeThirdParty': '1'}
# ...                                                                                                                                               ...
# 3469003                                                                                                                                           nan
# 3469004                                                                                                                                           nan
# 3469005                                                                                                                                           nan
# 3469006                                                                                                                                           nan
# 3469007                                                                                                                                           nan
#
#         TaxYear               BuildTS                   ReturnTs  \
# 0          2010  2016-02-24 21:20:13Z                       <NA>
# 1          2010  2016-02-24 21:20:13Z                       <NA>
# 2          2010  2016-02-24 21:20:13Z                       <NA>
# 3          2010  2016-02-24 21:20:13Z                       <NA>
# 4          2010  2016-02-24 21:20:13Z                       <NA>
# ...         ...                   ...                        ...
# 3469003    <NA>  2023-04-26 12:10:37Z  2024-05-23T14:48:24-07:00
# 3469004    <NA>  2023-04-26 12:10:37Z  2024-05-23T17:57:52-04:00
# 3469005    <NA>  2023-04-26 12:10:37Z  2024-05-23T17:20:23-07:00
# 3469006    <NA>  2023-04-26 12:10:37Z  2024-05-23T21:26:20-04:00
# 3469007    <NA>  2023-04-26 12:10:37Z  2024-05-23T21:05:34-05:00
#
#         TaxPeriodEndDt TaxPeriodBeginDt  \
# 0                 <NA>             <NA>
# 1                 <NA>             <NA>
# 2                 <NA>             <NA>
# 3                 <NA>             <NA>
# 4                 <NA>             <NA>
# ...                ...              ...
# 3469003     2023-12-31       2023-01-01
# 3469004     2023-12-31       2023-01-01
# 3469005     2023-12-31       2023-01-01
# 3469006     2023-12-31       2023-01-01
# 3469007     2022-12-31       2022-01-01
#
#                                                                                                                                                   BusinessOfficerGrp  \
# 0                                                                                                                                                                nan
# 1                                                                                                                                                                nan
# 2                                                                                                                                                                nan
# 3                                                                                                                                                                nan
# 4                                                                                                                                                                nan
# ...                                                                                                                                                              ...
# 3469003                                 {'PersonNm': 'NICO WRIGHT', 'PersonTitleTxt': 'Director', 'SignatureDt': '2024-05-23', 'DiscussWithPaidPreparerInd': 'true'}
# 3469004      {'PersonNm': 'MARK HANNAN', 'PersonTitleTxt': 'PRESIDENT', 'PhoneNum': '9036758466', 'SignatureDt': '2024-05-10', 'DiscussWithPaidPreparerInd': 'true'}
# 3469005  {'PersonNm': 'Pamela Q Harris', 'PersonTitleTxt': 'President', 'PhoneNum': '2407779110', 'SignatureDt': '2024-02-17', 'DiscussWithPaidPreparerInd': 'true'}
# 3469006                                        {'PersonNm': 'JANETH TRUJILLO', 'PersonTitleTxt': 'PRESIDENT', 'PhoneNum': '9542401249', 'SignatureDt': '2024-05-09'}
# 3469007  {'PersonNm': 'ALEXIS RATHBORNE', 'PersonTitleTxt': 'DIRECTOR', 'PhoneNum': '2012924224', 'SignatureDt': '2024-06-15', 'DiscussWithPaidPreparerInd': 'true'}
#
#         TaxYr fiscal_year        EIN  \
# 0        <NA>        <NA>  232705170
# 1        <NA>        <NA>  581805618
# 2        <NA>        <NA>  581876019
# 3        <NA>        <NA>  391083432
# 4        <NA>        <NA>  205297040
# ...       ...         ...        ...
# 3469003  2023        2023  942831137
# 3469004  2023        2023  237162843
# 3469005  2023        2023  651261203
# 3469006  2023        2023  922617060
# 3469007  2022        2022  472669712
#
#                                                                                                               Name  \
# 0        {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}
# 1              {'BusinessNameLine1': 'TORRINGTON VOA ELDERLY HOUSING INC', 'BusinessNameLine2': 'BELL PARK TOWER'}
# 2               {'BusinessNameLine1': 'HOUSTON VOA INDEPENDENT HOUSING INC', 'BusinessNameLine2': 'HEIGHTS MANOR'}
# 3                                                                 {'BusinessNameLine1': 'Faith-Haven Corporation'}
# 4                                                             {'BusinessNameLine1': 'Ochsner Community Hospitals'}
# ...                                                                                                            ...
# 3469003                                                                                                        nan
# 3469004                                                                                                        nan
# 3469005                                                                                                        nan
# 3469006                                                                                                        nan
# 3469007                                                                                                        nan
#
#         NameControl       Phone  \
# 0              RONA  8565826843
# 1              TORR  7033415000
# 2              HOUS  7033415000
# 3              FAIT  2626299700
# 4              OCHS  5048423400
# ...             ...         ...
# 3469003        <NA>        <NA>
# 3469004        <NA>        <NA>
# 3469005        <NA>        <NA>
# 3469006        <NA>        <NA>
# 3469007        <NA>        <NA>
#
#                                                                                                                             USAddress  \
# 0                       {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300', 'City': 'BETHLEHEM', 'State': 'PA', 'ZIPCode': '18017'}
# 1                                       {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA', 'State': 'VA', 'ZIPCode': '22314'}
# 2                                       {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA', 'State': 'VA', 'ZIPCode': '22314'}
# 3                                              {'AddressLine1': '5611 Hwy D', 'City': 'West Bend', 'State': 'WI', 'ZIPCode': '53090'}
# 4                                {'AddressLine1': '1514 Jefferson Highway', 'City': 'New Orleans', 'State': 'LA', 'ZIPCode': '70121'}
# ...                                                                                                                               ...
# 3469003                      {'AddressLine1Txt': 'PO BOX 686', 'CityNm': 'BEN LOMOND', 'StateAbbreviationCd': 'CA', 'ZIPCd': '95005'}
# 3469004                 {'AddressLine1Txt': '6435 STATE HWY 19 N', 'CityNm': 'ATHENS', 'StateAbbreviationCd': 'TX', 'ZIPCd': '75752'}
# 3469005           {'AddressLine1Txt': '50 Maryland Avenue', 'CityNm': 'Rockville', 'StateAbbreviationCd': 'MD', 'ZIPCd': '208502303'}
# 3469006                     {'AddressLine1Txt': '14900 SW 51ST ST', 'CityNm': 'DAVIE', 'StateAbbreviationCd': 'FL', 'ZIPCd': '33331'}
# 3469007  {'AddressLine1Txt': '261 MADISON AVENUE FL 9 Ste 1040', 'CityNm': 'NEW YORK', 'StateAbbreviationCd': 'NY', 'ZIPCd': '10016'}
#
#         ForeignAddress InCareOfName  \
# 0                  nan         <NA>
# 1                  nan         <NA>
# 2                  nan         <NA>
# 3                  nan         <NA>
# 4                  nan         <NA>
# ...                ...          ...
# 3469003            nan         <NA>
# 3469004            nan         <NA>
# 3469005            nan         <NA>
# 3469006            nan         <NA>
# 3469007            nan         <NA>
#
#                                                                                         BusinessName  \
# 0                                                                                                nan
# 1                                                                                                nan
# 2                                                                                                nan
# 3                                                                                                nan
# 4                                                                                                nan
# ...                                                                                              ...
# 3469003                             {'BusinessNameLine1Txt': 'BEN LOMOND QUAKER CENTER ASSOCIATION'}
# 3469004                              {'BusinessNameLine1Txt': 'BETHEL ASH WATER SUPPLY CORPORATION'}
# 3469005                                        {'BusinessNameLine1Txt': "Montgomery's Miracles Inc"}
# 3469006  {'BusinessNameLine1Txt': 'FUTURE LEARNING CHRISTIAN SCHOOL', 'BusinessNameLine2Txt': 'INC'}
# 3469007                                                {'BusinessNameLine1Txt': 'DIDTECHNOLOGY INC'}
#
#         BusinessNameControlTxt    PhoneNum       InCareOfNm ForeignPhoneNum
# 0                         <NA>        <NA>             <NA>            <NA>
# 1                         <NA>        <NA>             <NA>            <NA>
# 2                         <NA>        <NA>             <NA>            <NA>
# 3                         <NA>        <NA>             <NA>            <NA>
# 4                         <NA>        <NA>             <NA>            <NA>
# ...                        ...         ...              ...             ...
# 3469003                   BENL  8313368333             <NA>            <NA>
# 3469004                   BETH  9036758466             <NA>            <NA>
# 3469005                   MONT  2407779110             <NA>            <NA>
# 3469006                   FUTU  9542401249             <NA>            <NA>
# 3469007                   DIDT  2012924224  % LEAH WILLIAMS            <NA>
#
# [3469008 rows x 496 columns]

# %%
df[x_columns].dtypes
# Out:
# OrganizationName                string[python]
# AddressChange                   string[python]
# NameOfPrincipalOfficerPerson    string[python]
# Organization501c3               string[python]
# WebSite                         string[python]
#                                      ...
# ForeignAddress                  string[python]
# InCareOfName                    string[python]
# BusinessName                    string[python]
# BusinessNameControlTxt          string[python]
# InCareOfNm                      string[python]
# Length: 99, dtype: object

# %% [markdown]
# #### Now re-save file

# %%
# %%time
import datetime
print("🕓 Save started:", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Step 3: Save
#df_clean.to_parquet("D:/filings_full.parquet", engine="pyarrow", compression="snappy", index=False)
df.to_parquet("D:/all_filings_april_2025_all_controls_v2.parquet", engine="pyarrow", compression="snappy", index=False)

print("✅ Save completed:", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 🕓 Save started: 2025-04-16 16:27:10
# ✅ Save completed: 2025-04-16 16:34:21
# CPU times: total: 4min 32s
# Wall time: 7min 11s

# %% [markdown]
# # Traditional Import

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
#df = pd.read_pickle('all NEW filings February 2024 - all control variables.pkl.gz', compression='gzip')
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
df[:2]
# Out:
# Current date and time :  2025-04-16 21:16:01
#
# # of columns: 496
# # of observations: 3469008
# CPU times: total: 0 ns
# Wall time: 1 ms
#                         _id  \
# 0  5d019e6778ffca27b42818d7
# 1  5d019e6778ffca27b42818d8
#
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#               DLN TaxPeriod AddressChange NameOfPrincipalOfficerPerson  \
# 0  93493313013011    201012             X                MICHAEL ANTON
# 1  93493313013111    201106          <NA>                         None
#
#   GrossReceipts GroupReturnForAffiliates Organization501c3 WebSite  \
# 0       1473903                        0                 X     N/A
# 1        266420                    false                 X     N/A
#
#   TypeOfOrganizationCorporation YearFormation StateLegalDomicile  \
# 0                             X          1992                 PA
# 1                             X          1993                 WY
#
#                                                                                                                     ActivityOrMissionDescription  \
# 0                                                       MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
# 1  PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   NbrVotingMembersGoverningBody NbrIndependentVotingMembers TotalNbrEmployees  \
# 0                            10                          10                 0
# 1                            19                          13                 0
#
#   TotalNbrVolunteers TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 0                  0             0                              0
# 1               None             0                           None
#
#   ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 0                      1044925                        1439340
# 1                         None                              0
#
#   ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 0                              0                       0
# 1                         222839                  265592
#
#   InvestmentIncomePriorYear InvestmentIncomeCurrentYear OtherRevenuePriorYear  \
# 0                     30447                       33563                     0
# 1                      1425                         828                  None
#
#   OtherRevenueCurrentYear TotalRevenuePriorYear TotalRevenueCurrentYear  \
# 0                    1000               1075372                 1473903
# 1                       0                224264                  266420
#
#   GrantsAndSimilarAmntsPriorYear GrantsAndSimilarAmntsCY  \
# 0                         638637                  925000
# 1                           None                       0
#
#   BenefitsPaidToMembersPriorYear BenefitsPaidToMembersCY SalariesEtcPriorYear  \
# 0                              0                       0                    0
# 1                           None                       0                71405
#
#   SalariesEtcCurrentYear TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 0                      0                             0                      0
# 1                  82955                          None                      0
#
#   TotalFundrsngExpCurrentYear OtherExpensePriorYear OtherExpensesCurrentYear  \
# 0                      195892                243131                   459751
# 1                           0                189785                   222550
#
#   TotalExpensesPriorYear TotalExpensesCurrentYear  \
# 0                 881768                  1384751
# 1                 261190                   305505
#
#   RevenuesLessExpensesPriorYear RevenuesLessExpensesCY TotalAssetsBOY  \
# 0                        193604                  89152        1925215
# 1                        -36926                 -39085        1455332
#
#   TotalAssetsEOY TotalLiabilitiesBOY TotalLiabilitiesEOY  \
# 0        2440859              171810              450430
# 1        1433342               17482               34577
#
#   NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesEOY  \
# 0                    1753405                    1990429
# 1                    1437850                    1398765
#
#   InfoInScheduleOPartIII  \
# 0                      X
# 1                   <NA>
#
#                                                                                                                                                                                                                                           MissionDescription  \
# 0  THE CORPORATION IS ORGANIZED AND WILL BE OPERATED EXCLUSIVELY FOR CHARITABLE, EDUCATIONAL AND SCIENTIFIC PURPOSES WITHIN THE MEANING OF SECTION 501(C)(3) OF THE INTERNAL REVENUE CODE. SUCH PURPOSES SHALL BE LIMITED TO PROVIDING SUPPORT AND FUNDIN...
# 1                                                                                                              PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   SignificantNewProgramServices SignificantChange  Expense  Grants  \
# 0                             0                 0  1043744  925000
# 1                         false             false   276405    None
#
#                                                                                                                                                                                                                                                  Description  \
# 0  RMHC OF THE PHILADELPHIA REGION, INC. GRANTS HUNDREDS OF THOUSANDS OF DOLLARS PER YEAR TO SUPPORT NON-PROFIT PROGRAMS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN. LOCALLY, RMHC SUPPORTS THE PHILADELPHIA, SOUTHERN NEW JERSEY AND DE...
# 1                                                                                                              PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   TotalProgramServiceExpense PoliticalActivities LobbyingActivities  \
# 0                    1043744                 "0"                "0"
# 1                     276405             "false"            "false"
#
#   ProfessionalFundraising FundraisingActivities   Gaming  \
# 0                     "0"                   "0"      "0"
# 1                 "false"               "false"  "false"
#
#   ExcessBenefitTransaction PriorExcessBenefitTransaction  \
# 0                      "0"                           "0"
# 1                  "false"                       "false"
#
#                                                DisregardedEntity  \
# 0                                                            "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "true"}
#
#                                                    RelatedEntity  \
# 0                                                            "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "true"}
#
#   RelatedOrgControlledEntity  \
# 0                        "0"
# 1                    "false"
#
#                                          TransactionRelatedEntity  \
# 0                                                             "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
#
#                                     TransfersToExemptNonChrtblOrg  \
# 0                                                             "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
#
#                                    ActivitiesConductedPartnership  \
# 0                                                             "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
#
#   NumberFormsTransmittedWith1096 NumberOfEmployees UnrelatedBusinessIncome  \
# 0                              0                 0                       0
# 1                              0                 0                   false
#
#   InfoInScheduleOPartVI NbrVotingGoverningBodyMembers  \
# 0                     X                            10
# 1                     X                            19
#
#   NumberIndependentVotingMembers FamilyOrBusinessRelationship  \
# 0                             10                            0
# 1                             13                         true
#
#   DelegationOfManagementDuties ChangesToOrganizingDocs  \
# 0                            0                       0
# 1                         true                   false
#
#   MaterialDiversionOrMisuse MembersOrStockholders ElectionOfBoardMembers  \
# 0                         0                     0                      0
# 1                     false                 false                   true
#
#   DecisionsSubjectToApproval MinutesOfGoverningBody MinutesOfCommittees  \
# 0                          0                      1                   1
# 1                       true                   true                true
#
#   OfficerMailingAddress LocalChapters Form990ProvidedToGoverningBody  \
# 0                     0             0                              1
# 1                 false         false                           true
#
#   ConflictOfInterestPolicy AnnualDisclosureCoveredPersons  \
# 0                        1                              1
# 1                     true                           true
#
#   RegularMonitoringEnforcement WhistleblowerPolicy DocumentRetentionPolicy  \
# 0                            1                   0                       0
# 1                         true               false                   false
#
#   CompensationProcessCEO CompensationProcessOther InvestmentInJointVenture  \
# 0                      0                        0                        0
# 1                   true                     true                    false
#
#   StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 0             ["PA", "NJ", "DE"]           X                          X
# 1                            NaN           X                       <NA>
#
#   TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 0                          0                              0
# 1                       None                        1180355
#
#   TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 0                      0                       0             0
# 1                 411648                       0          true
#
#   TotalCompGT150K CompensationFromOtherSources NumberOfContractorsGT100K  \
# 0               0                            0                         0
# 1            true                        false                         0
#
#   AllOtherContributions TotalContributions TotalOtherRevenue  \
# 0               1439340            1439340              1000
# 1                  None                  0                 0
#
#                                                                                                                               TotalRevenue  \
# 0  {"TotalRevenueColumn": "1473903", "RelatedOrExemptFunctionIncome": "1000", "UnrelatedBusinessRevenue": "0", "ExclusionAmount": "33563"}
# 1                                                              {"TotalRevenueColumn": "266420", "RelatedOrExemptFunctionIncome": "266420"}
#
#                                GrantsToDomesticOrgs  \
# 0  {"Total": "892000", "ProgramServices": "892000"}
# 1                                    {"Total": "0"}
#
#                       GrantsToDomesticIndividuals  \
# 0  {"Total": "33000", "ProgramServices": "33000"}
# 1                                  {"Total": "0"}
#
#                               FeesForServicesLegal  \
# 0  {"Total": "215", "ManagementAndGeneral": "215"}
# 1                                   {"Total": "0"}
#
#                              FeesForServicesAccounting  \
# 0  {"Total": "21675", "ManagementAndGeneral": "21675"}
# 1    {"Total": "7500", "ManagementAndGeneral": "7500"}
#
#                                     OfficeExpenses  \
# 0  {"Total": "123", "ManagementAndGeneral": "123"}
# 1   {"Total": "14222", "ProgramServices": "14222"}
#
#                                PaymentsToAffiliates  \
# 0  {"Total": "118744", "ProgramServices": "118744"}
# 1                                    {"Total": "0"}
#
#                                  DepreciationDepletion  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
# 1       {"Total": "66166", "ProgramServices": "66166"}
#
#                                                                                                                                                                                                                                                OtherExpenses  \
# 0  [{"Description": "FUNDRAISING COSTS", "Total": "108311", "Fundraising": "108311"}, {"Description": "CANISTER COLLECTION FEE", "Total": "81925", "Fundraising": "81925"}, {"Description": "PR/ADMINISTRATIVE SERVI", "Total": "34517", "ManagementAndGe...
# 1                [{"Description": "OPER. & MAINT.", "Total": "46164", "ProgramServices": "46164"}, {"Description": "MISC TAXES", "Total": "298", "ProgramServices": "298"}, {"Description": "ADMINISTRATIVE", "Total": "12176", "ProgramServices": "12176"}]
#
#                                   AllOtherExpenses  \
# 0  {"Total": "763", "ManagementAndGeneral": "763"}
# 1                                   {"Total": "0"}
#
#                                                                                          TotalFunctionalExpenses  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
# 1          {"Total": "305505", "ProgramServices": "276405", "ManagementAndGeneral": "29100", "Fundraising": "0"}
#
#         SavingsAndTempCashInvestments                  AccountsReceivable  \
# 0  {"BOY": "332660", "EOY": "270700"}  {"BOY": "103412", "EOY": "147981"}
# 1                        {"EOY": "0"}        {"BOY": "231", "EOY": "474"}
#
#   LandBuildingsEquipmentBasis LandBldgEquipmentAccumDeprec  \
# 0                      256845                        86228
# 1                     2187206                       904332
#
#          LandBuildingsEquipmentBasisNet            InvestmentsOtherSecurities  \
# 0         {"BOY": "0", "EOY": "170617"}  {"BOY": "1489143", "EOY": "1851561"}
# 1  {"BOY": "1306860", "EOY": "1282874"}    {"BOY": "125980", "EOY": "102794"}
#
#                             TotalAssets    AccountsPayableAccruedExpenses  \
# 0  {"BOY": "1925215", "EOY": "2440859"}  {"BOY": "39670", "EOY": "44353"}
# 1  {"BOY": "1455332", "EOY": "1433342"}   {"BOY": "2040", "EOY": "16145"}
#
#                        GrantsPayable                   OtherLiabilities  \
# 0  {"BOY": "80500", "EOY": "166000"}  {"BOY": "51640", "EOY": "240077"}
# 1                                NaN    {"BOY": "9203", "EOY": "11349"}
#
#   FollowSFAS117                 UnrestrictedNetAssets InfoInScheduleOPartXI  \
# 0             X  {"BOY": "1753405", "EOY": "1990429"}                     X
# 1             X  {"BOY": "1437850", "EOY": "1398765"}                  <NA>
#
#   ReconcilationRevenueExpenses InfoInScheduleOPartXII  \
# 0                        89152                      X
# 1                       -39085                   <NA>
#
#   MethodOfAccountingAccrual AccountantCompileOrReview FSAudited  \
# 0                         X                         0         1
# 1                         X                     false      true
#
#   AuditCommittee FederalGrantAuditRequired AllAffiliatesIncluded  \
# 0              1                         0                   NaN
# 1           true                      true               "false"
#
#   GroupExemptionNumber Revenue PoliciesReferenceChapters  \
# 0                 None    None                      None
# 1                 1736  266420                     false
#
#   WrittenPolicyOrProcedure TotalProgramServiceRevenue   ForeignGrants  \
# 0                     None                       None             NaN
# 1                    false                     265592  {"Total": "0"}
#
#   BenefitsToMembers CompCurrentOfficersDirectors CompDisqualPersons  \
# 0               NaN                          NaN                NaN
# 1    {"Total": "0"}               {"Total": "0"}     {"Total": "0"}
#
#                             OtherSalariesAndWages PensionPlanContributions  \
# 0                                             NaN                      NaN
# 1  {"Total": "59440", "ProgramServices": "59440"}           {"Total": "0"}
#
#                             OtherEmployeeBenefits  \
# 0                                             NaN
# 1  {"Total": "17714", "ProgramServices": "17714"}
#
#                                    PayrollTaxes  \
# 0                                           NaN
# 1  {"Total": "5801", "ProgramServices": "5801"}
#
#                              FeesForServicesManagement  \
# 0                                                  NaN
# 1  {"Total": "21600", "ManagementAndGeneral": "21600"}
#
#   FeesForServicesLobbying FeesForServicesProfFundraising  \
# 0                     NaN                            NaN
# 1          {"Total": "0"}                 {"Total": "0"}
#
#   FeesForServicesInvstMgmntFees FeesForServicesOther  \
# 0                           NaN                  NaN
# 1                {"Total": "0"}       {"Total": "0"}
#
#                                     Advertising InformationTechnology  \
# 0                                           NaN                   NaN
# 1  {"Total": "8433", "ProgramServices": "8433"}        {"Total": "0"}
#
#         Royalties                                       Occupancy  \
# 0             NaN                                             NaN
# 1  {"Total": "0"}  {"Total": "44077", "ProgramServices": "44077"}
#
#            Travel TravelEntrtnmntPublicOfficials  \
# 0             NaN                            NaN
# 1  {"Total": "0"}                 {"Total": "0"}
#
#                           ConferencesMeetings        Interest  \
# 0                                         NaN             NaN
# 1  {"Total": "806", "ProgramServices": "806"}  {"Total": "0"}
#
#                                       Insurance  \
# 0                                           NaN
# 1  {"Total": "1108", "ProgramServices": "1108"}
#
#            CashNonInterestBearing PledgesAndGrantsReceivable  \
# 0                             NaN                        NaN
# 1  {"BOY": "250", "EOY": "22261"}               {"EOY": "0"}
#
#   ReceivablesFromDisqualPersons OtherNotesLoansReceivableNet  \
# 0                           NaN                          NaN
# 1                  {"EOY": "0"}                 {"EOY": "0"}
#
#   InventoriesForSaleOrUse  PrepaidExpensesDeferredCharges  \
# 0                     NaN                             NaN
# 1            {"EOY": "0"}  {"BOY": "7628", "EOY": "7554"}
#
#   InvestmentsPubTradedSecurities InvestmentsProgramRelated IntangibleAssets  \
# 0                            NaN                       NaN              NaN
# 1                   {"EOY": "0"}              {"EOY": "0"}     {"EOY": "0"}
#
#                    OtherAssetsTotal             DeferredRevenue  \
# 0                               NaN                         NaN
# 1  {"BOY": "14383", "EOY": "17385"}  {"BOY": "20", "EOY": "48"}
#
#    MortNotesPyblSecuredInvestProp FederalGrantAuditPerformed  \
# 0                             NaN                       None
# 1  {"BOY": "6219", "EOY": "7035"}                       true
#
#   LoansFromOfficersDirectors MethodOfAccountingCash Activity2 Activity3  \
# 0                        NaN                   <NA>       NaN       NaN
# 1                        NaN                   <NA>       NaN       NaN
#
#   InfoInScheduleOPartVII TaxExemptBondLiabilities  \
# 0                   <NA>                      NaN
# 1                   <NA>                      NaN
#
#   TemporarilyRestrictedNetAssets OtherWebsite PermanentlyRestrictedNetAssets  \
# 0                            NaN         <NA>                            NaN
# 1                            NaN         <NA>                            NaN
#
#   FundraisingEvents CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 0              None                           None                 None
# 1              None                           None                 None
#
#   GrossIncomeFundraisingEvents FundraisingDirectExpenses FederatedCampaigns  \
# 0                         None                      None               None
# 1                         None                      None               None
#
#   GovernmentGrants MethodOfAccountingOther GrossSalesOfInventory  \
# 0             None                     NaN                  None
# 1             None                     NaN                  None
#
#   CostOfGoodsSold DoNotFollowSFAS117 RetainedEarningsEndowmentEtc  \
# 0            None               <NA>                          NaN
# 1            None               <NA>                          NaN
#
#   InitialReturn MembershipDues GrossIncomeGaming GamingDirectExpenses  \
# 0          <NA>           None              None                 None
# 1          <NA>           None              None                 None
#
#   NoncashContributions InfoInScheduleOPartV OwnWebsite  \
# 0                 None                 <NA>       <NA>
# 1                 None                 <NA>       <NA>
#
#   UnsecuredNotesLoansPayable ActivityOther TotalOfOtherProgramServiceExp  \
# 0                        NaN           NaN                          None
# 1                        NaN           NaN                          None
#
#   TotalOfOtherProgramServiceRev EscrowAccountLiability  \
# 0                          None                    NaN
# 1                          None                    NaN
#
#   TotalOfOtherProgramServiceGrnt TypeOfOrganizationOther Organization501c  \
# 0                           None                    <NA>              NaN
# 1                           None                    <NA>              NaN
#
#   TypeOfOrganizationTrust TypeOfOrganizationAssociation CountryLegalDomicile  \
# 0                    <NA>                          <NA>                 None
# 1                    <NA>                          <NA>                 None
#
#   AmendedReturn TypeOfOrgOtherDescription TotalJointCosts TerminatedReturn  \
# 0          <NA>                      None             NaN             <NA>
# 1          <NA>                      None             NaN             <NA>
#
#   TerminationOrContraction ActivityCode SpecialConditionDescription  \
# 0                     <NA>         None                        None
# 1                     <NA>         None                        None
#
#   Organization4947a1 InfoInScheduleOPartIX ReconciliationUnrealizedInvest  \
# 0               <NA>                  <NA>                           None
# 1               <NA>                  <NA>                           None
#
#   ReconcilationPriorAdjustment ReconcilationDonatedServices  \
# 0                         None                         None
# 1                         None                         None
#
#   ReconcilationInvestExpenses InfoInScheduleOPartVIII InfoInScheduleOPartX  \
# 0                        None                    <NA>                 <NA>
# 1                        None                    <NA>                 <NA>
#
#   PrincipalOfficerNm GrossReceiptsAmt GroupReturnForAffiliatesInd  \
# 0               None             None                        None
# 1               None             None                        None
#
#   Organization501c3Ind TypeOfOrganizationCorpInd FormationYr  \
# 0                 <NA>                      <NA>        None
# 1                 <NA>                      <NA>        None
#
#   LegalDomicileStateCd ActivityOrMissionDesc VotingMembersGoverningBodyCnt  \
# 0                 None                  None                          None
# 1                 None                  None                          None
#
#   VotingMembersIndependentCnt TotalEmployeeCnt TotalGrossUBIAmt  \
# 0                        None             None             None
# 1                        None             None             None
#
#   CYContributionsGrantsAmt CYProgramServiceRevenueAmt CYInvestmentIncomeAmt  \
# 0                     None                       None                  None
# 1                     None                       None                  None
#
#   CYOtherRevenueAmt CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 0              None              None                      None
# 1              None              None                      None
#
#   CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 0                       None                         None
# 1                       None                         None
#
#   CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt CYOtherExpensesAmt  \
# 0                       None                         None               None
# 1                       None                         None               None
#
#   CYTotalExpensesAmt CYRevenuesLessExpensesAmt TotalAssetsBOYAmt  \
# 0               None                      None              None
# 1               None                      None              None
#
#   TotalAssetsEOYAmt TotalLiabilitiesEOYAmt NetAssetsOrFundBalancesBOYAmt  \
# 0              None                   None                          None
# 1              None                   None                          None
#
#   NetAssetsOrFundBalancesEOYAmt InfoInScheduleOPartIIIInd MissionDesc  \
# 0                          None                      <NA>        None
# 1                          None                      <NA>        None
#
#   SignificantNewProgramSrvcInd SignificantChangeInd  Desc  \
# 0                         None                 None  None
# 1                         None                 None  None
#
#   PoliticalCampaignActyInd LobbyingActivitiesInd ProfessionalFundraisingInd  \
# 0                     None                  None                       None
# 1                     None                  None                       None
#
#   FundraisingActivitiesInd GamingActivitiesInd EngagedInExcessBenefitTransInd  \
# 0                     None                None                           None
# 1                     None                None                           None
#
#   PYExcessBenefitTransInd DisregardedEntityInd RelatedEntityInd  \
# 0                    None                 None             None
# 1                    None                 None             None
#
#   RelatedOrganizationCtrlEntInd TransactionWithControlEntInd  \
# 0                          None                         None
# 1                          None                         None
#
#   TrnsfrExmptNonChrtblRltdOrgInd ActivitiesConductedPrtshpInd IRPDocumentCnt  \
# 0                           None                         None           None
# 1                           None                         None           None
#
#   EmployeeCnt UnrelatedBusIncmOverLimitInd GoverningBodyVotingMembersCnt  \
# 0        None                         None                          None
# 1        None                         None                          None
#
#   IndependentVotingMemberCnt FamilyOrBusinessRlnInd DelegationOfMgmtDutiesInd  \
# 0                       None                   None                      None
# 1                       None                   None                      None
#
#   ChangeToOrgDocumentsInd MaterialDiversionOrMisuseInd  \
# 0                    None                         None
# 1                    None                         None
#
#   MembersOrStockholdersInd ElectionOfBoardMembersInd  \
# 0                     None                      None
# 1                     None                      None
#
#   DecisionsSubjectToApprovaInd MinutesOfGoverningBodyInd  \
# 0                         None                      None
# 1                         None                      None
#
#   MinutesOfCommitteesInd OfficerMailingAddressInd LocalChaptersInd  \
# 0                   None                     None             None
# 1                   None                     None             None
#
#   Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 0                         None                        None
# 1                         None                        None
#
#   WhistleblowerPolicyInd DocumentRetentionPolicyInd CompensationProcessCEOInd  \
# 0                   None                       None                      None
# 1                   None                       None                      None
#
#   CompensationProcessOtherInd InvestmentInJointVentureInd  \
# 0                        None                        None
# 1                        None                        None
#
#   StatesWhereCopyOfReturnIsFldCd NoListedPersonsCompensatedInd  \
# 0                           None                          <NA>
# 1                           None                          <NA>
#
#   FormerOfcrEmployeesListedInd TotalCompGreaterThan150KInd  \
# 0                         None                        None
# 1                         None                        None
#
#   CompensationFromOtherSrcsInd MembershipDuesAmt FundraisingAmt  \
# 0                         None              None           None
# 1                         None              None           None
#
#   AllOtherContributionsAmt TotalContributionsAmt OtherRevenueTotalAmt  \
# 0                     None                  None                 None
# 1                     None                  None                 None
#
#   TotalRevenueGrp FeesForServicesAccountingGrp OfficeExpensesGrp  \
# 0            None                         None              None
# 1            None                         None              None
#
#   InformationTechnologyGrp ConferencesMeetingsGrp InsuranceGrp  \
# 0                     None                   None         None
# 1                     None                   None         None
#
#   OtherExpensesGrp AllOtherExpensesGrp TotalFunctionalExpensesGrp  \
# 0             None                None                       None
# 1             None                None                       None
#
#   CashNonInterestBearingGrp TotalAssetsGrp OrgDoesNotFollowSFAS117Ind  \
# 0                      None           None                       <NA>
# 1                      None           None                       <NA>
#
#   RtnEarnEndowmentIncmOthFndsGrp ReconcilationRevenueExpnssAmt  \
# 0                           None                          None
# 1                           None                          None
#
#   MethodOfAccountingCashInd AccountantCompileOrReviewInd FSAuditedInd  \
# 0                      <NA>                         None         None
# 1                      <NA>                         None         None
#
#   FederalGrantAuditRequiredInd WebsiteAddressTxt TotalVolunteersCnt  \
# 0                         None              None               None
# 1                         None              None               None
#
#   NetUnrelatedBusTxblIncmAmt PYContributionsGrantsAmt  \
# 0                       None                     None
# 1                       None                     None
#
#   PYProgramServiceRevenueAmt PYInvestmentIncomeAmt PYOtherRevenueAmt  \
# 0                       None                  None              None
# 1                       None                  None              None
#
#   PYTotalRevenueAmt PYGrantsAndSimilarPaidAmt PYBenefitsPaidToMembersAmt  \
# 0              None                      None                       None
# 1              None                      None                       None
#
#   PYSalariesCompEmpBnftPaidAmt PYTotalProfFndrsngExpnsAmt PYOtherExpensesAmt  \
# 0                         None                       None               None
# 1                         None                       None               None
#
#   PYTotalExpensesAmt PYRevenuesLessExpensesAmt TotalLiabilitiesBOYAmt  \
# 0               None                      None                   None
# 1               None                      None                   None
#
#   ExpenseAmt GrantAmt RevenueAmt ProgSrvcAccomActy2Grp ProgSrvcAccomActy3Grp  \
# 0       None     None       None                  None                  None
# 1       None     None       None                  None                  None
#
#   ProgSrvcAccomActyOtherGrp TotalOtherProgSrvcGrantAmt  \
# 0                      None                       None
# 1                      None                       None
#
#   TotalProgramServiceExpensesAmt InfoInScheduleOPartVIInd  \
# 0                           None                     <NA>
# 1                           None                     <NA>
#
#   AnnualDisclosureCoveredPrsnInd RegularMonitoringEnfrcInd UponRequestInd  \
# 0                           None                      None           <NA>
# 1                           None                      None           <NA>
#
#   TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 0                          None                        None
# 1                          None                        None
#
#   TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 0                      None                        None
# 1                      None                        None
#
#   CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 0                         None                None
# 1                         None                None
#
#   TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 0                          None                      None
# 1                          None                      None
#
#   ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 0                         None                         None
# 1                         None                         None
#
#   GrossSalesOfInventoryAmt CostOfGoodsSoldAmt GrantsToDomesticIndividualsGrp  \
# 0                     None               None                           None
# 1                     None               None                           None
#
#   CompCurrentOfcrDirectorsGrp OtherSalariesAndWagesGrp  \
# 0                        None                     None
# 1                        None                     None
#
#   PensionPlanContributionsGrp OtherEmployeeBenefitsGrp PayrollTaxesGrp  \
# 0                        None                     None            None
# 1                        None                     None            None
#
#   FeesForServicesOtherGrp AdvertisingGrp TravelGrp InterestGrp  \
# 0                    None           None      None        None
# 1                    None           None      None        None
#
#   DepreciationDepletionGrp SavingsAndTempCashInvstGrp AccountsReceivableGrp  \
# 0                     None                       None                  None
# 1                     None                       None                  None
#
#   InventoriesForSaleOrUseGrp PrepaidExpensesDefrdChargesGrp  \
# 0                       None                           None
# 1                       None                           None
#
#   LandBldgEquipCostOrOtherBssAmt LandBldgEquipAccumDeprecAmt  \
# 0                           None                        None
# 1                           None                        None
#
#   LandBldgEquipBasisNetGrp InvestmentsOtherSecuritiesGrp IntangibleAssetsGrp  \
# 0                     None                          None                None
# 1                     None                          None                None
#
#   AccountsPayableAccrExpnssGrp DeferredRevenueGrp  \
# 0                         None               None
# 1                         None               None
#
#   MortgNotesPyblScrdInvstPropGrp OtherLiabilitiesGrp  \
# 0                           None                None
# 1                           None                None
#
#   OrganizationFollowsSFAS117Ind UnrestrictedNetAssetsGrp  \
# 0                          <NA>                     None
# 1                          <NA>                     None
#
#   TemporarilyRstrNetAssetsGrp InfoInScheduleOPartXIInd  \
# 0                        None                     <NA>
# 1                        None                     <NA>
#
#   NetUnrlzdGainsLossesInvstAmt InfoInScheduleOPartXIIInd AuditCommitteeInd  \
# 0                         None                      <NA>              None
# 1                         None                      <NA>              None
#
#   AllAffiliatesIncludedInd GrantsToDomesticOrgsGrp ForeignGrantsGrp  \
# 0                     None                    None             None
# 1                     None                    None             None
#
#   BenefitsToMembersGrp CompDisqualPersonsGrp FeesForServicesManagementGrp  \
# 0                 None                  None                         None
# 1                 None                  None                         None
#
#   FeesForServicesLegalGrp FeesForServicesLobbyingGrp  \
# 0                    None                       None
# 1                    None                       None
#
#   FeesForSrvcInvstMgmntFeesGrp RoyaltiesGrp OccupancyGrp  \
# 0                         None         None         None
# 1                         None         None         None
#
#   PymtTravelEntrtnmntPubOfclGrp PaymentsToAffiliatesGrp  \
# 0                          None                    None
# 1                          None                    None
#
#   PledgesAndGrantsReceivableGrp RcvblFromDisqualifiedPrsnGrp  \
# 0                          None                         None
# 1                          None                         None
#
#   OthNotesLoansReceivableNetGrp InvestmentsPubTradedSecGrp  \
# 0                          None                       None
# 1                          None                       None
#
#   InvestmentsProgramRelatedGrp OtherAssetsTotalGrp  \
# 0                         None                None
# 1                         None                None
#
#   TotalOtherProgSrvcExpenseAmt InfoInScheduleOPartVInd  \
# 0                         None                    <NA>
# 1                         None                    <NA>
#
#   MethodOfAccountingAccrualInd NoncashContributionsAmt GrantsPayableGrp  \
# 0                         <NA>                    None             None
# 1                         <NA>                    None             None
#
#   PermanentlyRstrNetAssetsGrp TaxExemptBondLiabilitiesGrp  \
# 0                        None                        None
# 1                        None                        None
#
#   EscrowAccountLiabilityGrp LoansFromOfficersDirectorsGrp  \
# 0                      None                          None
# 1                      None                          None
#
#   UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 0                          None                      None
# 1                          None                      None
#
#   FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd OtherWebsiteInd  \
# 0                          None                         None            <NA>
# 1                          None                         None            <NA>
#
#   AddressChangeInd WrittenPolicyOrProcedureInd RelatedOrganizationsAmt  \
# 0             <NA>                        None                    None
# 1             <NA>                        None                    None
#
#   TotalOtherProgSrvcRevenueAmt OwnWebsiteInd TotalJointCostsGrp  \
# 0                         None          <NA>               None
# 1                         None          <NA>               None
#
#   DonatedServicesAndUseFcltsAmt LegalDomicileCountryCd  \
# 0                          None                   None
# 1                          None                   None
#
#   InfoInScheduleOPartIXInd TypeOfOrganizationTrustInd FinalReturnInd  \
# 0                     <NA>                       <NA>           <NA>
# 1                     <NA>                       <NA>           <NA>
#
#   ContractTerminationInd InfoInScheduleOPartXInd GroupExemptionNum  \
# 0                   <NA>                    <NA>              None
# 1                   <NA>                    <NA>              None
#
#   InfoInScheduleOPartVIIInd FederatedCampaignsAmt TypeOfOrganizationOtherInd  \
# 0                      <NA>                  None                       <NA>
# 1                      <NA>                  None                       <NA>
#
#   OtherOrganizationDsc InfoInScheduleOPartVIIIInd TypeOfOrganizationAssocInd  \
# 0                 None                       <NA>                       <NA>
# 1                 None                       <NA>                       <NA>
#
#   InitialReturnInd GamingGrossIncomeAmt GamingDirectExpensesAmt  \
# 0             <NA>                 None                    None
# 1             <NA>                 None                    None
#
#   MethodOfAccountingOtherInd InvestmentExpenseAmt Organization501cInd  \
# 0                       <NA>                 None                <NA>
# 1                       <NA>                 None                <NA>
#
#   Organization4947a1NotPFInd AmendedReturnInd SpecialConditionDesc ActivityCd  \
# 0                       <NA>             <NA>                 None       None
# 1                       <NA>             <NA>                 None       None
#
#                    Timestamp TaxPeriodEndDate TaxPeriodBeginDate  \
# 0  2011-11-09T06:41:09-06:00       2010-12-31         2010-01-01
# 1  2011-11-09T07:32:06-08:00       2011-06-30         2010-07-01
#
#                                                                                                                         Officer  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
# 1                                         {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
#
#   TaxYear               BuildTS ReturnTs TaxPeriodEndDt TaxPeriodBeginDt  \
# 0    2010  2016-02-24 21:20:13Z     None           None             None
# 1    2010  2016-02-24 21:20:13Z     None           None             None
#
#   BusinessOfficerGrp TaxYr fiscal_year        EIN  \
# 0                nan  None        None  232705170
# 1                nan  None        None  581805618
#
#                                                                                                         Name  \
# 0  {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}
# 1        {'BusinessNameLine1': 'TORRINGTON VOA ELDERLY HOUSING INC', 'BusinessNameLine2': 'BELL PARK TOWER'}
#
#   NameControl       Phone  \
# 0        RONA  8565826843
# 1        TORR  7033415000
#
#                                                                                                        USAddress  \
# 0  {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300', 'City': 'BETHLEHEM', 'State': 'PA', 'ZIPCode': '18017'}
# 1                  {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA', 'State': 'VA', 'ZIPCode': '22314'}
#
#   ForeignAddress InCareOfName BusinessName BusinessNameControlTxt PhoneNum  \
# 0            nan         None          nan                   None     None
# 1            nan         None          nan                   None     None
#
#   InCareOfNm ForeignPhoneNum
# 0       None            None
# 1       None            None

# %% [markdown]
# <br>Look at last observation in the dataset.

# %%
df[-1:]
# Out:
#                               _id OrganizationName  \
# 3469007  67f0a6febea7582f201aed22             None
#
#                                                                          URL  \
# 3469007  https://s3.amazonaws.com/irs-form-990/202441449349301704_public.xml
#
#           DLN TaxPeriod AddressChange NameOfPrincipalOfficerPerson  \
# 3469007  None      None          <NA>                         None
#
#         GrossReceipts GroupReturnForAffiliates Organization501c3 WebSite  \
# 3469007          None                     None              <NA>    None
#
#         TypeOfOrganizationCorporation YearFormation StateLegalDomicile  \
# 3469007                          <NA>          None               None
#
#         ActivityOrMissionDescription NbrVotingMembersGoverningBody  \
# 3469007                         None                          None
#
#         NbrIndependentVotingMembers TotalNbrEmployees TotalNbrVolunteers  \
# 3469007                        None              None               None
#
#         TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 3469007          None                           None
#
#         ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 3469007                         None                           None
#
#         ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 3469007                           None                    None
#
#         InvestmentIncomePriorYear InvestmentIncomeCurrentYear  \
# 3469007                      None                        None
#
#         OtherRevenuePriorYear OtherRevenueCurrentYear TotalRevenuePriorYear  \
# 3469007                  None                    None                  None
#
#         TotalRevenueCurrentYear GrantsAndSimilarAmntsPriorYear  \
# 3469007                    None                           None
#
#         GrantsAndSimilarAmntsCY BenefitsPaidToMembersPriorYear  \
# 3469007                    None                           None
#
#         BenefitsPaidToMembersCY SalariesEtcPriorYear SalariesEtcCurrentYear  \
# 3469007                    None                 None                   None
#
#         TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 3469007                          None                   None
#
#         TotalFundrsngExpCurrentYear OtherExpensePriorYear  \
# 3469007                        None                  None
#
#         OtherExpensesCurrentYear TotalExpensesPriorYear  \
# 3469007                     None                   None
#
#         TotalExpensesCurrentYear RevenuesLessExpensesPriorYear  \
# 3469007                     None                          None
#
#         RevenuesLessExpensesCY TotalAssetsBOY TotalAssetsEOY  \
# 3469007                   None           None           None
#
#         TotalLiabilitiesBOY TotalLiabilitiesEOY NetAssetsOrFundBalancesBOY  \
# 3469007                None                None                       None
#
#         NetAssetsOrFundBalancesEOY InfoInScheduleOPartIII MissionDescription  \
# 3469007                       None                   <NA>               None
#
#         SignificantNewProgramServices SignificantChange Expense Grants  \
# 3469007                          None              None    None   None
#
#         Description TotalProgramServiceExpense PoliticalActivities  \
# 3469007        None                       None                None
#
#         LobbyingActivities ProfessionalFundraising FundraisingActivities  \
# 3469007               None                    None                  None
#
#         Gaming ExcessBenefitTransaction PriorExcessBenefitTransaction  \
# 3469007   None                     None                          None
#
#         DisregardedEntity RelatedEntity RelatedOrgControlledEntity  \
# 3469007              None          None                       None
#
#         TransactionRelatedEntity TransfersToExemptNonChrtblOrg  \
# 3469007                     None                          None
#
#         ActivitiesConductedPartnership NumberFormsTransmittedWith1096  \
# 3469007                           None                           None
#
#         NumberOfEmployees UnrelatedBusinessIncome InfoInScheduleOPartVI  \
# 3469007              None                    None                  <NA>
#
#         NbrVotingGoverningBodyMembers NumberIndependentVotingMembers  \
# 3469007                          None                           None
#
#         FamilyOrBusinessRelationship DelegationOfManagementDuties  \
# 3469007                         None                         None
#
#         ChangesToOrganizingDocs MaterialDiversionOrMisuse  \
# 3469007                    None                      None
#
#         MembersOrStockholders ElectionOfBoardMembers  \
# 3469007                  None                   None
#
#         DecisionsSubjectToApproval MinutesOfGoverningBody MinutesOfCommittees  \
# 3469007                       None                   None                None
#
#         OfficerMailingAddress LocalChapters Form990ProvidedToGoverningBody  \
# 3469007                  None          None                           None
#
#         ConflictOfInterestPolicy AnnualDisclosureCoveredPersons  \
# 3469007                     None                           None
#
#         RegularMonitoringEnforcement WhistleblowerPolicy  \
# 3469007                         None                None
#
#         DocumentRetentionPolicy CompensationProcessCEO  \
# 3469007                    None                   None
#
#         CompensationProcessOther InvestmentInJointVenture  \
# 3469007                     None                     None
#
#         StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 3469007                           None        <NA>                       <NA>
#
#         TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 3469007                       None                           None
#
#         TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 3469007                   None                    None          None
#
#         TotalCompGT150K CompensationFromOtherSources  \
# 3469007            None                         None
#
#         NumberOfContractorsGT100K AllOtherContributions TotalContributions  \
# 3469007                      None                  None               None
#
#         TotalOtherRevenue TotalRevenue GrantsToDomesticOrgs  \
# 3469007              None         None                 None
#
#         GrantsToDomesticIndividuals FeesForServicesLegal  \
# 3469007                        None                 None
#
#         FeesForServicesAccounting OfficeExpenses PaymentsToAffiliates  \
# 3469007                      None           None                 None
#
#         DepreciationDepletion OtherExpenses AllOtherExpenses  \
# 3469007                  None          None             None
#
#         TotalFunctionalExpenses SavingsAndTempCashInvestments  \
# 3469007                    None                          None
#
#         AccountsReceivable LandBuildingsEquipmentBasis  \
# 3469007               None                        None
#
#         LandBldgEquipmentAccumDeprec LandBuildingsEquipmentBasisNet  \
# 3469007                         None                           None
#
#         InvestmentsOtherSecurities TotalAssets AccountsPayableAccruedExpenses  \
# 3469007                       None        None                           None
#
#         GrantsPayable OtherLiabilities FollowSFAS117 UnrestrictedNetAssets  \
# 3469007          None             None          <NA>                  None
#
#         InfoInScheduleOPartXI ReconcilationRevenueExpenses  \
# 3469007                  <NA>                         None
#
#         InfoInScheduleOPartXII MethodOfAccountingAccrual  \
# 3469007                   <NA>                      <NA>
#
#         AccountantCompileOrReview FSAudited AuditCommittee  \
# 3469007                      None      None           None
#
#         FederalGrantAuditRequired AllAffiliatesIncluded GroupExemptionNumber  \
# 3469007                      None                  None                 None
#
#         Revenue PoliciesReferenceChapters WrittenPolicyOrProcedure  \
# 3469007    None                      None                     None
#
#         TotalProgramServiceRevenue ForeignGrants BenefitsToMembers  \
# 3469007                       None          None              None
#
#         CompCurrentOfficersDirectors CompDisqualPersons OtherSalariesAndWages  \
# 3469007                         None               None                  None
#
#         PensionPlanContributions OtherEmployeeBenefits PayrollTaxes  \
# 3469007                     None                  None         None
#
#         FeesForServicesManagement FeesForServicesLobbying  \
# 3469007                      None                    None
#
#         FeesForServicesProfFundraising FeesForServicesInvstMgmntFees  \
# 3469007              {"TotalAmt": "0"}                          None
#
#         FeesForServicesOther Advertising InformationTechnology Royalties  \
# 3469007                 None        None                  None      None
#
#         Occupancy Travel TravelEntrtnmntPublicOfficials ConferencesMeetings  \
# 3469007      None   None                           None                None
#
#         Interest Insurance CashNonInterestBearing PledgesAndGrantsReceivable  \
# 3469007     None      None                   None                       None
#
#         ReceivablesFromDisqualPersons OtherNotesLoansReceivableNet  \
# 3469007                          None                         None
#
#         InventoriesForSaleOrUse PrepaidExpensesDeferredCharges  \
# 3469007                    None                           None
#
#         InvestmentsPubTradedSecurities InvestmentsProgramRelated  \
# 3469007                           None                      None
#
#         IntangibleAssets OtherAssetsTotal DeferredRevenue  \
# 3469007             None             None            None
#
#         MortNotesPyblSecuredInvestProp FederalGrantAuditPerformed  \
# 3469007                           None                       None
#
#         LoansFromOfficersDirectors MethodOfAccountingCash Activity2 Activity3  \
# 3469007                       None                   <NA>      None      None
#
#         InfoInScheduleOPartVII TaxExemptBondLiabilities  \
# 3469007                   <NA>                     None
#
#         TemporarilyRestrictedNetAssets OtherWebsite  \
# 3469007                           None         <NA>
#
#         PermanentlyRestrictedNetAssets FundraisingEvents  \
# 3469007                           None              None
#
#         CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 3469007                           None                 None
#
#         GrossIncomeFundraisingEvents FundraisingDirectExpenses  \
# 3469007                         None                      None
#
#         FederatedCampaigns GovernmentGrants MethodOfAccountingOther  \
# 3469007               None             None                    <NA>
#
#         GrossSalesOfInventory CostOfGoodsSold DoNotFollowSFAS117  \
# 3469007                  None            None               <NA>
#
#         RetainedEarningsEndowmentEtc InitialReturn MembershipDues  \
# 3469007                         None          <NA>           None
#
#         GrossIncomeGaming GamingDirectExpenses NoncashContributions  \
# 3469007              None                 None                 None
#
#         InfoInScheduleOPartV OwnWebsite UnsecuredNotesLoansPayable  \
# 3469007                 <NA>       <NA>                       None
#
#         ActivityOther TotalOfOtherProgramServiceExp  \
# 3469007          None                          None
#
#         TotalOfOtherProgramServiceRev EscrowAccountLiability  \
# 3469007                          None                   None
#
#         TotalOfOtherProgramServiceGrnt TypeOfOrganizationOther  \
# 3469007                           None                    <NA>
#
#         Organization501c TypeOfOrganizationTrust  \
# 3469007             <NA>                    <NA>
#
#         TypeOfOrganizationAssociation CountryLegalDomicile AmendedReturn  \
# 3469007                          <NA>                 None          <NA>
#
#         TypeOfOrgOtherDescription TotalJointCosts TerminatedReturn  \
# 3469007                      None            None             <NA>
#
#         TerminationOrContraction ActivityCode SpecialConditionDescription  \
# 3469007                     <NA>         None                        None
#
#         Organization4947a1 InfoInScheduleOPartIX  \
# 3469007               <NA>                  <NA>
#
#         ReconciliationUnrealizedInvest ReconcilationPriorAdjustment  \
# 3469007                           None                         None
#
#         ReconcilationDonatedServices ReconcilationInvestExpenses  \
# 3469007                         None                        None
#
#         InfoInScheduleOPartVIII InfoInScheduleOPartX PrincipalOfficerNm  \
# 3469007                    <NA>                 <NA>   ALEXIS RATHBORNE
#
#         GrossReceiptsAmt GroupReturnForAffiliatesInd Organization501c3Ind  \
# 3469007          4180132                       false                    X
#
#         TypeOfOrganizationCorpInd FormationYr LegalDomicileStateCd  \
# 3469007                         X        2015                   GA
#
#                                                                                                                          ActivityOrMissionDesc  \
# 3469007  TO USE INNOVATION TO CREATE SYSTEM CHANGE BY CATALYZING ECONOMIC GROWTH FOR BLACK AND LATINX COMMUNITIES THROUGH WOMEN ENTREPRENEURS.
#
#         VotingMembersGoverningBodyCnt VotingMembersIndependentCnt  \
# 3469007                             7                           7
#
#         TotalEmployeeCnt TotalGrossUBIAmt CYContributionsGrantsAmt  \
# 3469007               19                0                  4178351
#
#         CYProgramServiceRevenueAmt CYInvestmentIncomeAmt CYOtherRevenueAmt  \
# 3469007                       1662                -43597                 0
#
#         CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 3469007           4136416                         0
#
#         CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 3469007                          0                       942906
#
#         CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt  \
# 3469007                          0                       375588
#
#         CYOtherExpensesAmt CYTotalExpensesAmt CYRevenuesLessExpensesAmt  \
# 3469007            2301471            3244377                    892039
#
#         TotalAssetsBOYAmt TotalAssetsEOYAmt TotalLiabilitiesEOYAmt  \
# 3469007           1752817           2792833                 189399
#
#         NetAssetsOrFundBalancesBOYAmt NetAssetsOrFundBalancesEOYAmt  \
# 3469007                       1711395                       2603434
#
#         InfoInScheduleOPartIIIInd  \
# 3469007                         X
#
#                                                                                                                                    MissionDesc  \
# 3469007  TO USE INNOVATION TO CREATE SYSTEM CHANGE BY CATALYZING ECONOMIC GROWTH FOR BLACK AND LATINX COMMUNITIES THROUGH WOMEN ENTREPRENEURS.
#
#         SignificantNewProgramSrvcInd SignificantChangeInd  \
# 3469007                        false                false
#
#                                                                                                                                                                                                                                                               Desc  \
# 3469007  BIG is a program designed for Black women and Latina founders who have already begun to build their startups and are still pre-revenue. Our BIG Pre-Accelerator includes access to resources to learn and apply the Lean Startup methods, discover how...
#
#         PoliticalCampaignActyInd LobbyingActivitiesInd  \
# 3469007                  "false"               "false"
#
#         ProfessionalFundraisingInd FundraisingActivitiesInd  \
# 3469007                    "false"                  "false"
#
#         GamingActivitiesInd  \
# 3469007             "false"
#
#                                         EngagedInExcessBenefitTransInd  \
# 3469007  {"@referenceDocumentId": "IRS990ScheduleL", "#text": "false"}
#
#                                                PYExcessBenefitTransInd  \
# 3469007  {"@referenceDocumentId": "IRS990ScheduleL", "#text": "false"}
#
#         DisregardedEntityInd RelatedEntityInd RelatedOrganizationCtrlEntInd  \
# 3469007              "false"          "false"                         false
#
#         TransactionWithControlEntInd TrnsfrExmptNonChrtblRltdOrgInd  \
# 3469007                          NaN                        "false"
#
#         ActivitiesConductedPrtshpInd IRPDocumentCnt EmployeeCnt  \
# 3469007                      "false"             84          19
#
#         UnrelatedBusIncmOverLimitInd GoverningBodyVotingMembersCnt  \
# 3469007                        false                             7
#
#         IndependentVotingMemberCnt FamilyOrBusinessRlnInd  \
# 3469007                          7                   true
#
#         DelegationOfMgmtDutiesInd ChangeToOrgDocumentsInd  \
# 3469007                      true                   false
#
#         MaterialDiversionOrMisuseInd MembersOrStockholdersInd  \
# 3469007                        false                    false
#
#         ElectionOfBoardMembersInd DecisionsSubjectToApprovaInd  \
# 3469007                     false                        false
#
#         MinutesOfGoverningBodyInd MinutesOfCommitteesInd  \
# 3469007                      true                   true
#
#         OfficerMailingAddressInd LocalChaptersInd  \
# 3469007                    false            false
#
#         Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 3469007                         true                        true
#
#         WhistleblowerPolicyInd DocumentRetentionPolicyInd  \
# 3469007                   true                       true
#
#         CompensationProcessCEOInd CompensationProcessOtherInd  \
# 3469007                      true                        true
#
#         InvestmentInJointVentureInd StatesWhereCopyOfReturnIsFldCd  \
# 3469007                       false                   ["GA", "NY"]
#
#         NoListedPersonsCompensatedInd FormerOfcrEmployeesListedInd  \
# 3469007                          <NA>                        false
#
#         TotalCompGreaterThan150KInd CompensationFromOtherSrcsInd  \
# 3469007                       false                        false
#
#         MembershipDuesAmt FundraisingAmt AllOtherContributionsAmt  \
# 3469007              None           None                  4178351
#
#         TotalContributionsAmt OtherRevenueTotalAmt  \
# 3469007               4178351                    0
#
#                                                                                                 TotalRevenueGrp  \
# 3469007  {"TotalRevenueColumnAmt": "4136416", "RelatedOrExemptFuncIncomeAmt": "1662", "ExclusionAmt": "-43597"}
#
#                                         FeesForServicesAccountingGrp  \
# 3469007  {"TotalAmt": "130887", "ManagementAndGeneralAmt": "130887"}
#
#                                                                                                           OfficeExpensesGrp  \
# 3469007  {"TotalAmt": "39036", "ProgramServicesAmt": "14961", "ManagementAndGeneralAmt": "19573", "FundraisingAmt": "4502"}
#
#                                                                                                      InformationTechnologyGrp  \
# 3469007  {"TotalAmt": "223547", "ProgramServicesAmt": "177948", "ManagementAndGeneralAmt": "44230", "FundraisingAmt": "1369"}
#
#                                                                                                     ConferencesMeetingsGrp  \
# 3469007  {"TotalAmt": "73777", "ProgramServicesAmt": "56284", "ManagementAndGeneralAmt": "524", "FundraisingAmt": "16969"}
#
#                                                       InsuranceGrp  \
# 3469007  {"TotalAmt": "12204", "ManagementAndGeneralAmt": "12204"}
#
#                                                                                                                                                                                                                                                   OtherExpensesGrp  \
# 3469007  [{"Desc": "SPECIAL PROJECTS", "TotalAmt": "275000", "ProgramServicesAmt": "275000"}, {"Desc": "DUES & SUBSCRIPTIONS", "TotalAmt": "16687", "ProgramServicesAmt": "2594", "ManagementAndGeneralAmt": "11033", "FundraisingAmt": "3060"}, {"Desc": "BAD ...
#
#                                              AllOtherExpensesGrp  \
# 3469007  {"TotalAmt": "4165", "ManagementAndGeneralAmt": "4165"}
#
#                                                                                                         TotalFunctionalExpensesGrp  \
# 3469007  {"TotalAmt": "3244377", "ProgramServicesAmt": "2476408", "ManagementAndGeneralAmt": "392381", "FundraisingAmt": "375588"}
#
#                         CashNonInterestBearingGrp  \
# 3469007  {"BOYAmt": "206982", "EOYAmt": "783983"}
#
#                                      TotalAssetsGrp  \
# 3469007  {"BOYAmt": "1752817", "EOYAmt": "2792833"}
#
#         OrgDoesNotFollowSFAS117Ind RtnEarnEndowmentIncmOthFndsGrp  \
# 3469007                       <NA>                            NaN
#
#         ReconcilationRevenueExpnssAmt MethodOfAccountingCashInd  \
# 3469007                        892039                      <NA>
#
#         AccountantCompileOrReviewInd FSAuditedInd  \
# 3469007                        false         true
#
#         FederalGrantAuditRequiredInd WebsiteAddressTxt TotalVolunteersCnt  \
# 3469007                        false               N/A                  7
#
#         NetUnrelatedBusTxblIncmAmt PYContributionsGrantsAmt  \
# 3469007                       None                  2055847
#
#         PYProgramServiceRevenueAmt PYInvestmentIncomeAmt PYOtherRevenueAmt  \
# 3469007                      21768                    62                 0
#
#         PYTotalRevenueAmt PYGrantsAndSimilarPaidAmt  \
# 3469007           2077677                         0
#
#         PYBenefitsPaidToMembersAmt PYSalariesCompEmpBnftPaidAmt  \
# 3469007                          0                       591675
#
#         PYTotalProfFndrsngExpnsAmt PYOtherExpensesAmt PYTotalExpensesAmt  \
# 3469007                          0            1390480            1982155
#
#         PYRevenuesLessExpensesAmt TotalLiabilitiesBOYAmt ExpenseAmt GrantAmt  \
# 3469007                     95522                  41422     336105     None
#
#         RevenueAmt  \
# 3469007       1662
#
#                                                                                                                                                                                                                                              ProgSrvcAccomActy2Grp  \
# 3469007  {"ExpenseAmt": "472863", "Desc": "COMMUNITY (BREAKTHROUGH): This growth-stage, five-session intensive program in partnership with JPMorgan Chase's Advancing Black Pathways, helps entrepreneurs scale their business past the five-figure mark and cr...
#
#                                                                                                                                                                                                                                              ProgSrvcAccomActy3Grp  \
# 3469007  {"ExpenseAmt": "326157", "Desc": "RESEARCH: The organization produces original qualitative and quantitative research on the state of Latina and Black women founders in the U.S. and other territories. This is the first organization to identify dis...
#
#                                                                                                                                                                                                                                  ProgSrvcAccomActyOtherGrp  \
# 3469007  [{"ExpenseAmt": "254385", "Desc": "DO YOU FELLOWSHIP"}, {"ExpenseAmt": "209971", "Desc": "START"}, {"ExpenseAmt": "64448", "Desc": "THOUGHT LEADERSHIP"}, {"ExpenseAmt": "812479", "Desc": "OTHER PROGRAMS (THE NEW C-SUITE, GENERAL PROGRAMS)"}]
#
#         TotalOtherProgSrvcGrantAmt TotalProgramServiceExpensesAmt  \
# 3469007                       None                        2476408
#
#         InfoInScheduleOPartVIInd AnnualDisclosureCoveredPrsnInd  \
# 3469007                        X                           true
#
#         RegularMonitoringEnfrcInd UponRequestInd  \
# 3469007                      true           <NA>
#
#         TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 3469007                        121703                           0
#
#         TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 3469007                      9077                           1
#
#         CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 3469007                            4                None
#
#         TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 3469007                          1662                         0
#
#         ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 3469007                         None                            0
#
#         GrossSalesOfInventoryAmt CostOfGoodsSoldAmt  \
# 3469007                        0                  0
#
#         GrantsToDomesticIndividualsGrp CompCurrentOfcrDirectorsGrp  \
# 3469007              {"TotalAmt": "0"}           {"TotalAmt": "0"}
#
#                                                                                                        OtherSalariesAndWagesGrp  \
# 3469007  {"TotalAmt": "815286", "ProgramServicesAmt": "636740", "ManagementAndGeneralAmt": "27216", "FundraisingAmt": "151330"}
#
#         PensionPlanContributionsGrp  \
# 3469007           {"TotalAmt": "0"}
#
#                                                                                                    OtherEmployeeBenefitsGrp  \
# 3469007  {"TotalAmt": "57429", "ProgramServicesAmt": "43668", "ManagementAndGeneralAmt": "3383", "FundraisingAmt": "10378"}
#
#                                                                                                             PayrollTaxesGrp  \
# 3469007  {"TotalAmt": "70191", "ProgramServicesAmt": "52910", "ManagementAndGeneralAmt": "4931", "FundraisingAmt": "12350"}
#
#                                                                                                         FeesForServicesOtherGrp  \
# 3469007  {"TotalAmt": "945157", "ProgramServicesAmt": "728903", "ManagementAndGeneralAmt": "77699", "FundraisingAmt": "138555"}
#
#                                                                                     AdvertisingGrp  \
# 3469007  {"TotalAmt": "141993", "ProgramServicesAmt": "140415", "ManagementAndGeneralAmt": "1578"}
#
#                                                                                  TravelGrp  \
# 3469007  {"TotalAmt": "227640", "ProgramServicesAmt": "193360", "FundraisingAmt": "34280"}
#
#                InterestGrp  \
# 3469007  {"TotalAmt": "0"}
#
#                                           DepreciationDepletionGrp  \
# 3469007  {"TotalAmt": "15755", "ManagementAndGeneralAmt": "15755"}
#
#                        SavingsAndTempCashInvstGrp  \
# 3469007  {"BOYAmt": "28402", "EOYAmt": "1050221"}
#
#                   AccountsReceivableGrp      InventoriesForSaleOrUseGrp  \
# 3469007  {"BOYAmt": "0", "EOYAmt": "0"}  {"BOYAmt": "0", "EOYAmt": "0"}
#
#                PrepaidExpensesDefrdChargesGrp LandBldgEquipCostOrOtherBssAmt  \
# 3469007  {"BOYAmt": "2937", "EOYAmt": "2937"}                              0
#
#         LandBldgEquipAccumDeprecAmt            LandBldgEquipBasisNetGrp  \
# 3469007                           0  {"BOYAmt": "58325", "EOYAmt": "0"}
#
#           InvestmentsOtherSecuritiesGrp                   IntangibleAssetsGrp  \
# 3469007  {"BOYAmt": "0", "EOYAmt": "0"}  {"BOYAmt": "7500", "EOYAmt": "7500"}
#
#                     AccountsPayableAccrExpnssGrp  \
# 3469007  {"BOYAmt": "32814", "EOYAmt": "126944"}
#
#                      DeferredRevenueGrp  MortgNotesPyblScrdInvstPropGrp  \
# 3469007  {"BOYAmt": "0", "EOYAmt": "0"}  {"BOYAmt": "0", "EOYAmt": "0"}
#
#                            OtherLiabilitiesGrp OrganizationFollowsSFAS117Ind  \
# 3469007  {"BOYAmt": "8608", "EOYAmt": "62455"}                          <NA>
#
#         UnrestrictedNetAssetsGrp TemporarilyRstrNetAssetsGrp  \
# 3469007                     None                        None
#
#         InfoInScheduleOPartXIInd NetUnrlzdGainsLossesInvstAmt  \
# 3469007                     <NA>                         None
#
#         InfoInScheduleOPartXIIInd AuditCommitteeInd AllAffiliatesIncludedInd  \
# 3469007                      <NA>              true                      NaN
#
#         GrantsToDomesticOrgsGrp   ForeignGrantsGrp BenefitsToMembersGrp  \
# 3469007       {"TotalAmt": "0"}  {"TotalAmt": "0"}    {"TotalAmt": "0"}
#
#         CompDisqualPersonsGrp FeesForServicesManagementGrp  \
# 3469007     {"TotalAmt": "0"}            {"TotalAmt": "0"}
#
#                                                                                                     FeesForServicesLegalGrp  \
# 3469007  {"TotalAmt": "80589", "ProgramServicesAmt": "61550", "ManagementAndGeneralAmt": "16244", "FundraisingAmt": "2795"}
#
#         FeesForServicesLobbyingGrp FeesForSrvcInvstMgmntFeesGrp  \
# 3469007          {"TotalAmt": "0"}            {"TotalAmt": "0"}
#
#               RoyaltiesGrp  \
# 3469007  {"TotalAmt": "0"}
#
#                                                                                     OccupancyGrp  \
# 3469007  {"TotalAmt": "98473", "ProgramServicesAmt": "92075", "ManagementAndGeneralAmt": "6398"}
#
#         PymtTravelEntrtnmntPubOfclGrp PaymentsToAffiliatesGrp  \
# 3469007             {"TotalAmt": "0"}       {"TotalAmt": "0"}
#
#                      PledgesAndGrantsReceivableGrp  \
# 3469007  {"BOYAmt": "1438671", "EOYAmt": "882483"}
#
#            RcvblFromDisqualifiedPrsnGrp   OthNotesLoansReceivableNetGrp  \
# 3469007  {"BOYAmt": "0", "EOYAmt": "0"}  {"BOYAmt": "0", "EOYAmt": "0"}
#
#              InvestmentsPubTradedSecGrp    InvestmentsProgramRelatedGrp  \
# 3469007  {"BOYAmt": "0", "EOYAmt": "0"}  {"BOYAmt": "0", "EOYAmt": "0"}
#
#                             OtherAssetsTotalGrp TotalOtherProgSrvcExpenseAmt  \
# 3469007  {"BOYAmt": "10000", "EOYAmt": "65709"}                      1341283
#
#         InfoInScheduleOPartVInd MethodOfAccountingAccrualInd  \
# 3469007                    <NA>                            X
#
#         NoncashContributionsAmt                GrantsPayableGrp  \
# 3469007                    None  {"BOYAmt": "0", "EOYAmt": "0"}
#
#         PermanentlyRstrNetAssetsGrp     TaxExemptBondLiabilitiesGrp  \
# 3469007                        None  {"BOYAmt": "0", "EOYAmt": "0"}
#
#               EscrowAccountLiabilityGrp   LoansFromOfficersDirectorsGrp  \
# 3469007  {"BOYAmt": "0", "EOYAmt": "0"}  {"BOYAmt": "0", "EOYAmt": "0"}
#
#           UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 3469007  {"BOYAmt": "0", "EOYAmt": "0"}                      None
#
#         FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd  \
# 3469007                          None                         None
#
#         OtherWebsiteInd AddressChangeInd WrittenPolicyOrProcedureInd  \
# 3469007               X                X                        None
#
#         RelatedOrganizationsAmt TotalOtherProgSrvcRevenueAmt OwnWebsiteInd  \
# 3469007                    None                         None          <NA>
#
#         TotalJointCostsGrp DonatedServicesAndUseFcltsAmt  \
# 3469007                NaN                          None
#
#         LegalDomicileCountryCd InfoInScheduleOPartIXInd  \
# 3469007                   None                        X
#
#         TypeOfOrganizationTrustInd FinalReturnInd ContractTerminationInd  \
# 3469007                       <NA>           <NA>                   <NA>
#
#         InfoInScheduleOPartXInd GroupExemptionNum InfoInScheduleOPartVIIInd  \
# 3469007                       X              None                         X
#
#         FederatedCampaignsAmt TypeOfOrganizationOtherInd OtherOrganizationDsc  \
# 3469007                  None                       <NA>                 None
#
#         InfoInScheduleOPartVIIIInd TypeOfOrganizationAssocInd  \
# 3469007                       <NA>                       <NA>
#
#         InitialReturnInd GamingGrossIncomeAmt GamingDirectExpensesAmt  \
# 3469007             <NA>                    0                       0
#
#         MethodOfAccountingOtherInd InvestmentExpenseAmt Organization501cInd  \
# 3469007                        NaN                 None                 NaN
#
#         Organization4947a1NotPFInd AmendedReturnInd SpecialConditionDesc  \
# 3469007                       <NA>             <NA>                 None
#
#         ActivityCd Timestamp TaxPeriodEndDate TaxPeriodBeginDate Officer  \
# 3469007       None      None             None               None     nan
#
#         TaxYear               BuildTS                   ReturnTs  \
# 3469007    None  2023-04-26 12:10:37Z  2024-05-23T21:05:34-05:00
#
#         TaxPeriodEndDt TaxPeriodBeginDt  \
# 3469007     2022-12-31       2022-01-01
#
#                                                                                                                                                   BusinessOfficerGrp  \
# 3469007  {'PersonNm': 'ALEXIS RATHBORNE', 'PersonTitleTxt': 'DIRECTOR', 'PhoneNum': '2012924224', 'SignatureDt': '2024-06-15', 'DiscussWithPaidPreparerInd': 'true'}
#
#         TaxYr fiscal_year        EIN Name NameControl Phone  \
# 3469007  2022        2022  472669712  nan        None  None
#
#                                                                                                                             USAddress  \
# 3469007  {'AddressLine1Txt': '261 MADISON AVENUE FL 9 Ste 1040', 'CityNm': 'NEW YORK', 'StateAbbreviationCd': 'NY', 'ZIPCd': '10016'}
#
#         ForeignAddress InCareOfName  \
# 3469007            nan         None
#
#                                           BusinessName BusinessNameControlTxt  \
# 3469007  {'BusinessNameLine1Txt': 'DIDTECHNOLOGY INC'}                   DIDT
#
#            PhoneNum       InCareOfNm ForeignPhoneNum
# 3469007  2012924224  % LEAH WILLIAMS            None

# %% [markdown]
# ### Create and save list of EINs for BMF File
# - We will use this in a future notebook: *IRS Form 990 e-File Data (7a) -- Create combined BMF dataset (NTEE, MSA, etc) for ALL EINs.ipynb*  and  *IRS Form 990 e-File Data (7b) -- Merge BMF Data into 990 Data and Limit to 501(c)(3) orgs.ipynb*

# %% [markdown]
# <br>What we are doing in the following code block is (in the first line) creating a Python list containing all *EIN* values in the dataframe. The second line shows the number of items in the list, which is the same as the number of observations in *df*. The third line uses the ``set`` function to show the number of *unique* items in the list. The fourth line applies the set function to our list, thereby producing an updated list with only all 358,707 unique EINs in our dataframe. The last line shows that the updated list contains the correct number of elements.

# %%
ein_list = df['EIN'].tolist()
print(len(ein_list))
print(len(set(ein_list)))
ein_list = list(set(ein_list))
print(len(ein_list))
# Out:
# 3469008
# 456945
# 456945

# %% [markdown]
# <br>Save list to a JSON file called `ein_list_2025.json`

# %%
import json
with open('ein_list_2025.json', 'w') as fp:
    json.dump(ein_list, fp)

# %% [markdown]
# ### Collapse *concordance* file
# A strange artifact of the e-file data is that there are generally two different names for each 990 variable -- with the first few years of filings having different names than later years. What we are doing in the following code block is collapsing the *concordance* file by the 'variable_name_new' column so that there is one row per variable; ``variable_name_new`` is the standardized, more descriptive variable name that several 990 researchers (including me, Jesse Lecy, Nathan Grasse, Dan Neely, etc.) have agreed on.

# %%
def agg_funcs(x):
    names = {
        #'name': x['variable_name_new'].head(1).values[0],
        'original_names':  list(set(x['MongoDB_Name'].tolist())),
        'data_type_xsd': x['data_type_xsd'].head(1).values[0],
        'binarize': x['BINARIZE'].head(1).values[0]
        }
    #THE FOLLOWING SHORTCUT WORKS BUT CHANGES THE ORDER OF THE COLUMNS
    #return pd.Series(names, index = list(names.keys()))
    return pd.Series(names, index=['original_names', 'data_type_xsd', 'binarize'])
new_variables_df = concordance[:].groupby(['variable_name_new']).apply(agg_funcs)
new_variables_df = new_variables_df.reset_index()
print('# of variables:', len(new_variables_df))
new_variables_df[:5]
# Out:
# DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# # of variables: 288
#                variable_name_new  \
# 0           F9_00_HD_ADDR_CHANGE
# 1        F9_00_HD_AMENDED_RETURN
# 2      F9_00_HD_BUILD_TIME_STAMP
# 3      F9_00_HD_CTRY_OF_DOMICILE
# 4  F9_00_HD_EXEMPT_STATUS_4847A1
#
#                                      original_names  data_type_xsd  binarize
# 0                 [AddressChange, AddressChangeInd]   CheckboxType  binarize
# 1                 [AmendedReturnInd, AmendedReturn]   CheckboxType  binarize
# 2                                         [BuildTS]  TimestampType       NaN
# 3    [CountryLegalDomicile, LegalDomicileCountryCd]    CountryType       NaN
# 4  [Organization4947a1NotPFInd, Organization4947a1]   CheckboxType  binarize

# %% [markdown]
# #### New Way

# %%
# %%time
new_variables_df = concordance.groupby('variable_name_new').agg(
    original_names=('MongoDB_Name', lambda x: list(set(x.tolist()))),
    data_type_xsd=('data_type_xsd', 'first'),
    binarize=('BINARIZE', 'first')
    ).reset_index()
print('# of variables:', len(new_variables_df))
new_variables_df[:5]
# Out:
# # of variables: 288
# CPU times: total: 0 ns
# Wall time: 17.9 ms
#                variable_name_new  \
# 0           F9_00_HD_ADDR_CHANGE
# 1        F9_00_HD_AMENDED_RETURN
# 2      F9_00_HD_BUILD_TIME_STAMP
# 3      F9_00_HD_CTRY_OF_DOMICILE
# 4  F9_00_HD_EXEMPT_STATUS_4847A1
#
#                                      original_names  data_type_xsd  binarize
# 0                 [AddressChange, AddressChangeInd]   CheckboxType  binarize
# 1                 [AmendedReturnInd, AmendedReturn]   CheckboxType  binarize
# 2                                         [BuildTS]  TimestampType      None
# 3    [CountryLegalDomicile, LegalDomicileCountryCd]    CountryType      None
# 4  [Organization4947a1NotPFInd, Organization4947a1]   CheckboxType  binarize

# %% [markdown]
# <br>This next block creates a variable that counts the number of 'locations' (xpaths in the original XML filings) for each variable. The ``value_counts( )`` output then tells us that there are 9 variables with only one location -- we will treat those separately. The other 279 variables have two locations (two different xpaths).

# %%
new_variables_df['len'] = new_variables_df['original_names'].apply(lambda x: len(x))
print(new_variables_df['len'].value_counts(), '\n')
new_variables_df[:4]
# Out:
# len
# 2    279
# 1      9
# Name: count, dtype: int64
#            variable_name_new                                  original_names  \
# 0       F9_00_HD_ADDR_CHANGE               [AddressChange, AddressChangeInd]
# 1    F9_00_HD_AMENDED_RETURN               [AmendedReturnInd, AmendedReturn]
# 2  F9_00_HD_BUILD_TIME_STAMP                                       [BuildTS]
# 3  F9_00_HD_CTRY_OF_DOMICILE  [CountryLegalDomicile, LegalDomicileCountryCd]
#
#    data_type_xsd  binarize  len
# 0   CheckboxType  binarize    2
# 1   CheckboxType  binarize    2
# 2  TimestampType      None    1
# 3    CountryType      None    2

# %% [markdown]
# ### Handle variables with only 1 original name
# NOTE:
# - Per *IRS 990 e-File Data -- Control Variables (4) -- Fees-for-Services Variables  - Extract from MongoDB and Process -- Part I (Python 3.6).ipynb*, there is only one path for this variables (there is no *FeesForServicesProfFundraisingGrp*)
#     - Instead, as seen in the concordance file, *FeesForServicesProfFundraising* has both a 'Total' and a 'TotalAmt' key, which suggests this is the only key that did not change names over time.
# - We won't be renaming *TaxPeriod* and we will parse *F9_00_HD_FILER_STATE_US* in a subsequent notebook

# %%
new_variables_df[new_variables_df['len']!=2]
# Out:
#                  variable_name_new                    original_names  \
# 2        F9_00_HD_BUILD_TIME_STAMP                         [BuildTS]
# 7        F9_00_HD_FILER_ADDR_US_L1                           [Filer]
# 8        F9_00_HD_FILER_ADDR_US_L2                           [Filer]
# 9           F9_00_HD_FILER_CITY_US                           [Filer]
# 10     F9_00_HD_FILER_COUNTRY_FRGN                           [Filer]
# 11         F9_00_HD_FILER_STATE_US                           [Filer]
# 12           F9_00_HD_FILER_ZIP_US                           [Filer]
# 205  F9_09_PC_FEES_FOR_SVCE_FR_TOT  [FeesForServicesProfFundraising]
# 286                      TaxPeriod                       [TaxPeriod]
#
#          data_type_xsd binarize  len
# 2        TimestampType     None    1
# 7    StreetAddressType     None    1
# 8    StreetAddressType     None    1
# 9             CityType     None    1
# 10         CountryType     None    1
# 11           StateType     None    1
# 12         ZIPCodeType     None    1
# 205       USAmountType     None    1
# 286      YearMonthType     None    1

# %% [markdown]
# #### Rename *FeesForServicesProfFundraising*
# Note that *describe* and *value_counts* won't work yet because some values are dictionaries

# %%
# %%time
df.rename(columns = {'FeesForServicesProfFundraising':'F9_09_PC_FEES_FOR_SVCE_FR_TOT'}, inplace = True)
#df['F9_09_PC_FEES_FOR_SVCE_FR_TOT'].describe()
#df['F9_09_PC_FEES_FOR_SVCE_FR_TOT'].value_counts()[:5]
# Out:
# CPU times: total: 0 ns
# Wall time: 14.5 ms

# %% [markdown]
# #### Rename *BuildTS*

# %%
# %%time
df.rename(columns = {'BuildTS':'F9_00_HD_BUILD_TIME_STAMP'}, inplace = True)
# Out:
# CPU times: total: 0 ns
# Wall time: 996 µs

# %% [markdown]
# <br>Show above two variables (plus *Filer* and *TaxPeriod*) for sample of 5 rows

# %% [markdown]
# ##### Update for XML
# Replace *TaxPeriod* with *TaxPeriodEndDt* and replace *Filer* with the parsed *Filer* columns

# %%
# %%time
#df[['F9_09_PC_FEES_FOR_SVCE_FR_TOT', 'F9_00_HD_BUILD_TIME_STAMP', 'Filer', 'TaxPeriod']].sample(5)
df[['F9_09_PC_FEES_FOR_SVCE_FR_TOT', 'F9_00_HD_BUILD_TIME_STAMP', 'TaxPeriodEndDt',
       'EIN', 'BusinessName', 'BusinessNameControlTxt', 'USAddress', 'PhoneNum', 'InCareOfNm',
       'ForeignAddress', 'ForeignPhoneNum']].sample(5)
# Out:
# CPU times: total: 766 ms
# Wall time: 1.09 s
#         F9_09_PC_FEES_FOR_SVCE_FR_TOT F9_00_HD_BUILD_TIME_STAMP  \
# 1624115                           NaN      2019-02-21 02:37:17Z
# 1455427                           NaN      2018-06-14 16:35:46Z
# 2947254                           NaN      2023-04-26 12:10:37Z
# 3035912                           NaN      2023-04-26 12:10:37Z
# 728734                            NaN      2016-02-25 16:41:14Z
#
#         TaxPeriodEndDt        EIN  \
# 1624115     2018-06-30  113335036
# 1455427     2017-09-30  237417523
# 2947254     2022-12-31  843705917
# 3035912     2022-12-31  251912781
# 728734      2014-06-30  205299027
#
#                                                                         BusinessName  \
# 1624115                        {'BusinessNameLine1Txt': 'THE ENRICHMENT CENTER INC'}
# 1455427  {'BusinessNameLine1Txt': 'AMERICAN SOCIETY OF INTERIOR DESIGN INC S CNTRL'}
# 2947254              {'BusinessNameLine1Txt': 'MONTANA YOUTH DIABETES ALLIANCE INC'}
# 3035912            {'BusinessNameLine1Txt': 'MOUNT CARMEL HEALTH INSURANCE COMPANY'}
# 728734                  {'BusinessNameLine1': 'MARYLAND CRIME VICTIMS RESOURCE FDN'}
#
#         BusinessNameControlTxt  \
# 1624115                   ENRI
# 1455427                   AMER
# 2947254                   MONT
# 3035912                   MOUN
# 728734                    MARY
#
#                                                                                                                          USAddress  \
# 1624115             {'AddressLine1Txt': '750 HICKSVILLE ROAD', 'CityNm': 'SEAFORD', 'StateAbbreviationCd': 'NY', 'ZIPCd': '11783'}
# 1455427             {'AddressLine1Txt': '108 FELICIE DRIVE', 'CityNm': 'Lafayette', 'StateAbbreviationCd': 'LA', 'ZIPCd': '70506'}
# 2947254               {'AddressLine1Txt': 'PO BOX 104', 'CityNm': 'COLUMBIA FALLS', 'StateAbbreviationCd': 'MT', 'ZIPCd': '59912'}
# 3035912  {'AddressLine1Txt': '3100 EASTON SQUARE PL 300', 'CityNm': 'COLUMBUS', 'StateAbbreviationCd': 'OH', 'ZIPCd': '432196290'}
# 728734                   {'AddressLine1': '1001 Prince Georges Blvd', 'City': 'Upper Marlboro', 'State': 'MD', 'ZIPCode': '20774'}
#
#            PhoneNum InCareOfNm ForeignAddress ForeignPhoneNum
# 1624115  5165206000       None            nan            None
# 1455427        None       None            nan            None
# 2947254  4064612185       None            nan            None
# 3035912  6145464000       None            nan            None
# 728734         None       None            nan            None

# %% [markdown]
# <br>Sidebar: generate separate dataset called *years* to get a rough sense of the spread of filings across years.

# %%
years = pd.DataFrame(df['fiscal_year'].value_counts())
years.index.name = 'year'
years = years.reset_index()
years = years.sort_values('year')
years
# Out:
#     year   count
# 15  2000       1
# 13  2001       2
# 14  2012       1
# 10  2013  103432
# 9   2014  210538
# 8   2015  228000
# 7   2016  240304
# 6   2017  251414
# 5   2018  261873
# 4   2019  276308
# 3   2020  308651
# 2   2021  332441
# 1   2022  345378
# 0   2023  346694
# 11  2024   68432
# 12  2025      16

# %% [markdown]
# # Combine all columns where *len*==2

# %% [markdown]
# ### Define Function to combine columns
# In Python we can create a series of functions that can be used as shortcuts. First we'll create a function called ``combine`` that will combine two columns that are both related to the same 990 variable. It takes as *inputs* four things: our dataset/dataframe (*df*), the name we'd like for our new variable (*newvar*), the name of the first variable to combine (*var1*), and the name of the second variable to combine (*var2*).

# %%
#def combine(df, newvar, var1, var2):
#    df[newvar] = np.where(df[var1].notnull(), df[var1], df[var2])
#    #print(df[newvar].value_counts().head(), '\n')
#    #print('# of missing observations:', len(df[df[newvar].isnull()]))
#    #print('# of valid observations:', len(df[df[newvar].notnull()]), '\n')  
#    #return df.sample(5)[[newvar, var1, var2, 'DLN']] 
#    #print(df[[newvar, var1, var2, 'ObjectId']][:5], '\n\n\n')

# %% [markdown]
# ##### New version of function for new XML filings

# %%
def combine(df, newvar, var1, var2):
    if var1 in df.columns and var2 in df.columns:
        df[newvar] = np.where(df[var1].notnull(), df[var1], df[var2])
    elif var1 in df.columns:
        #print(df[var1].value_counts().head())
        df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
    elif var2 in df.columns:
        #print(df[var2].value_counts().head())
        df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)        
    #print(df[newvar].value_counts().head(), '\n')
    #print('# of missing observations:', len(df[df[newvar].isnull()]))
    #print('# of valid observations:', len(df[df[newvar].notnull()]), '\n')  
    #return df.sample(5)[[newvar, var1, var2, 'DLN']] 
    #print(df[[newvar, var1, var2, 'ObjectId']][:5], '\n\n\n')

# %% [markdown]
# #### Do initial check to ensure that no row has values in both columns
# In the following code block we are initiating a ``loop``, a highly useful coding tactic. Note that in the last row we are asking the code to print out the number of observations in the dataset that are non-empty for both xpaths for a given variable, such as *FSAudited* and *FSAuditedInd* for our variable *F9_12_PC_FINCL_STMTS_AUDITED*. While we are fairly certain that our assumption is correct that *FSAudited* and *FSAuditedInd* are mutually exclusive (because the former is used in earlier years and the latter in later years), we need to do these types of data verifications in order to have faith in our data processing.

# %% [markdown]
# ##### The previous code block below doesn't work because there is only one of the two variable names -- updated version is below (but is not really needed)

# %%
#for index, row in new_variables_df[new_variables_df['len']==2][:].iterrows():
#    #print(row['variable_name_new'])
#    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
#    print('\t\t', len(df[df[row['original_names'][0]].notnull()]))
#    print('\t\t', len(df[df[row['original_names'][1]].notnull()]))
#    #print(len(df[(df[row['original_names'][0]].isnull()) & (df[row['original_names'][1]].isnull())]), '\n\n')      
#    print('OK IF ZERO:', len(df[(df[row['original_names'][0]].notnull()) & (df[row['original_names'][1]].notnull())]), '\n\n')

# %%
new_variables_df[:10]
# Out:
#                variable_name_new  \
# 0           F9_00_HD_ADDR_CHANGE
# 1        F9_00_HD_AMENDED_RETURN
# 2      F9_00_HD_BUILD_TIME_STAMP
# 3      F9_00_HD_CTRY_OF_DOMICILE
# 4  F9_00_HD_EXEMPT_STATUS_4847A1
# 5    F9_00_HD_EXEMPT_STATUS_501C
# 6   F9_00_HD_EXEMPT_STATUS_501C3
# 7      F9_00_HD_FILER_ADDR_US_L1
# 8      F9_00_HD_FILER_ADDR_US_L2
# 9         F9_00_HD_FILER_CITY_US
#
#                                      original_names      data_type_xsd  \
# 0                 [AddressChange, AddressChangeInd]       CheckboxType
# 1                 [AmendedReturnInd, AmendedReturn]       CheckboxType
# 2                                         [BuildTS]      TimestampType
# 3    [CountryLegalDomicile, LegalDomicileCountryCd]        CountryType
# 4  [Organization4947a1NotPFInd, Organization4947a1]       CheckboxType
# 5           [Organization501c, Organization501cInd]       CheckboxType
# 6         [Organization501c3, Organization501c3Ind]       CheckboxType
# 7                                           [Filer]  StreetAddressType
# 8                                           [Filer]  StreetAddressType
# 9                                           [Filer]           CityType
#
#              binarize  len
# 0            binarize    2
# 1            binarize    2
# 2                None    1
# 3                None    2
# 4            binarize    2
# 5  binarize_with_dict    2
# 6            binarize    2
# 7                None    1
# 8                None    1
# 9                None    1

# %% [markdown]
# # Better way
# This approach:
#
# First collects all the column pairs you need to check
# Then processes them using vectorized pandas operations rather than row-by-row iteration
# Summarizes the results in a single DataFrame
#
# The key performance improvement comes from using vectorized methods like .notnull().sum() instead of filtering with len(df[df[...]]) inside a loop, which forces pandas to create new temporary DataFrames for each iteration.
# If you need to print the exact same output format as your original code, you can add this after creating the results_df:

# %% [markdown]
# ### Replace 'NaN' (string) with `np.nan`

# %%
# %%time
# Before replacement, check how many string 'NaN' values you have
string_nan_count = (df == 'NaN').sum().sum()
print(f"Total string 'NaN' values in dataset: {string_nan_count}")
# Out:
# Total string 'NaN' values in dataset: 172804630

# %%
# %%time
# Replace string 'NaN' with np.nan throughout the entire dataframe
df = df.replace('NaN', np.nan)
# Out:
# CPU times: total: 1min 43s
# Wall time: 1min 54s

# %%
# %%time
# Verify the replacement
post_replacement_count = (df == 'NaN').sum().sum()
print(f"Remaining string 'NaN' values: {post_replacement_count}")
# Out:
# Remaining string 'NaN' values: 0
# CPU times: total: 1min
# Wall time: 1min 5s

# %%
# %%time
# Also check if there are other string variants of NaN
#variants = ['nan', 'Nan', 'NAN', '<NA>']
#for variant in variants:
#    count = (df == variant).sum().sum()
#    if count > 0:
#        print(f"Found {count} instances of '{variant}'")
#        df = df.replace(variant, np.nan)

# %% [markdown]
# One set of columns has 'nan':
# ```python
# print(len(df[df['Officer'].notnull()&df['BusinessOfficerGrp'].notnull()]))
# ```

# %%
# %%time
df = df.replace('nan', np.nan)
# Out:
# CPU times: total: 1min 38s
# Wall time: 1min 49s

# %% [markdown]
# #### Updated code

# %%
# %%time
# Create a list of all column pairs to check
column_pairs = []
for index, row in new_variables_df[new_variables_df['len']==2].iterrows():
    col1, col2 = row['original_names'][0], row['original_names'][1]
    var_name = row['variable_name_new']
    
    # Check if both columns exist in the DataFrame
    if col1 in df.columns and col2 in df.columns:
        column_pairs.append((var_name, col1, col2))

# Now process all pairs at once using vectorized operations
results = []
for var_name, col1, col2 in column_pairs:
    # Count non-null values in each column
    count1 = df[col1].notnull().sum()
    count2 = df[col2].notnull().sum()
    
    # Count rows where BOTH columns have values (should be zero)
    overlap_count = (df[col1].notnull() & df[col2].notnull()).sum()
    
    results.append({
        'variable_name_new': var_name,
        'column1': col1,
        'column2': col2,
        'count1': count1,
        'count2': count2,
        'overlap': overlap_count
    })

# Convert to DataFrame for easy viewing
results_df = pd.DataFrame(results)
results_df[:5]
# Out:
# CPU times: total: 1min 39s
# Wall time: 1min 46s
#                variable_name_new                     column1  \
# 0           F9_00_HD_ADDR_CHANGE               AddressChange
# 1        F9_00_HD_AMENDED_RETURN            AmendedReturnInd
# 2      F9_00_HD_CTRY_OF_DOMICILE        CountryLegalDomicile
# 3  F9_00_HD_EXEMPT_STATUS_4847A1  Organization4947a1NotPFInd
# 4    F9_00_HD_EXEMPT_STATUS_501C            Organization501c
#
#                   column2  count1  count2  overlap
# 0        AddressChangeInd   19701  118486        0
# 1           AmendedReturn   36676    4675        0
# 2  LegalDomicileCountryCd     272    2207        0
# 3      Organization4947a1    1724     737        0
# 4     Organization501cInd  145796  711309        0

# %%
results_df[results_df['overlap']>0]
# Out:
# Empty DataFrame
# Columns: [variable_name_new, column1, column2, count1, count2, overlap]
# Index: []

# %%
#print(len(df[df['Officer'].notnull()&df['BusinessOfficerGrp'].notnull()]))

# %%
df[df['Officer'].notnull()&df['BusinessOfficerGrp'].notnull()][:5][['Officer', 'BusinessOfficerGrp']]
# Out:
# Empty DataFrame
# Columns: [Officer, BusinessOfficerGrp]
# Index: []

# %% [markdown]
# ### Old Way

# %%
# %%time
for index, row in new_variables_df[new_variables_df['len']==2][:].iterrows():
    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    if (row['original_names'][0] in df.columns and row['original_names'][1] in df.columns):
        print('yes')
        print('\t\t', len(df[df[row['original_names'][0]].notnull()]))
        print('\t\t', len(df[df[row['original_names'][1]].notnull()]))
        print('OK IF ZERO:', len(df[(df[row['original_names'][0]].notnull()) & (df[row['original_names'][1]].notnull())]), '\n\n')
    elif row['original_names'][0] in df.columns:
        print('only', row['original_names'][0] )
        print('\t\t', len(df[df[row['original_names'][0]].notnull()]))
    elif row['original_names'][1] in df.columns:
        print('only', row['original_names'][1] )   
        print('\t\t', len(df[df[row['original_names'][1]].notnull()]))
# Out:
# F9_00_HD_ADDR_CHANGE AddressChange AddressChangeInd
# only AddressChangeInd
# 		 36528
# F9_00_HD_AMENDED_RETURN AmendedReturn AmendedReturnInd
# only AmendedReturnInd
# 		 14148
# F9_00_HD_CTRY_OF_DOMICILE LegalDomicileCountryCd CountryLegalDomicile
# only LegalDomicileCountryCd
# 		 878
# F9_00_HD_EXEMPT_STATUS_4847A1 Organization4947a1 Organization4947a1NotPFInd
# only Organization4947a1NotPFInd
# 		 573
# F9_00_HD_EXEMPT_STATUS_501C Organization501cInd Organization501c
# only Organization501cInd
# 		 226380
# F9_00_HD_EXEMPT_STATUS_501C3 Organization501c3 Organization501c3Ind
# only Organization501c3Ind
# 		 665027
# F9_00_HD_FINAL_RETURN FinalReturnInd TerminatedReturn
# only FinalReturnInd
# 		 5153
# F9_00_HD_GROSS_EXEMPT_NUM GroupExemptionNumber GroupExemptionNum
# only GroupExemptionNum
# 		 29605
# F9_00_HD_GROSS_RCPT GrossReceipts GrossReceiptsAmt
# only GrossReceiptsAmt
# 		 891980
# F9_00_HD_GROUP_RETURN GroupReturnForAffiliatesInd GroupReturnForAffiliates
# only GroupReturnForAffiliatesInd
# 		 891980
# F9_00_HD_INCLUDES_SUBORD_ORGS AllAffiliatesIncludedInd AllAffiliatesIncluded
# only AllAffiliatesIncludedInd
# 		 5414
# F9_00_HD_INITIAL_RETURN InitialReturn InitialReturnInd
# only InitialReturnInd
# 		 15451
# F9_00_HD_PRIN_OFF_NAME NameOfPrincipalOfficerPerson PrincipalOfficerNm
# only PrincipalOfficerNm
# 		 773667
# F9_00_HD_SIGNING_OFFICER_SIGNTR BusinessOfficerGrp Officer
# only BusinessOfficerGrp
# 		 891980
# F9_00_HD_SPECIAL_CONDITION_DESC SpecialConditionDescription SpecialConditionDesc
# only SpecialConditionDesc
# 		 1142
# F9_00_HD_STATE_OF_DOMICILE StateLegalDomicile LegalDomicileStateCd
# only LegalDomicileStateCd
# 		 847801
# F9_00_HD_TAX_PER_BEGIN TaxPeriodBeginDt TaxPeriodBeginDate
# only TaxPeriodBeginDt
# 		 891980
# F9_00_HD_TAX_PER_END TaxPeriodEndDt TaxPeriodEndDate
# only TaxPeriodEndDt
# 		 891980
# F9_00_HD_TAX_YEAR TaxYear TaxYr
# only TaxYr
# 		 891980
# F9_00_HD_TIME_STAMP Timestamp ReturnTs
# only ReturnTs
# 		 891980
# F9_00_HD_TYPE_ORG_ASSOCIATION TypeOfOrganizationAssociation TypeOfOrganizationAssocInd
# only TypeOfOrganizationAssocInd
# 		 40345
# F9_00_HD_TYPE_ORG_CORP TypeOfOrganizationCorpInd TypeOfOrganizationCorporation
# only TypeOfOrganizationCorpInd
# 		 789544
# F9_00_HD_TYPE_ORG_OTHER TypeOfOrganizationOther TypeOfOrganizationOtherInd
# only TypeOfOrganizationOtherInd
# 		 22722
# F9_00_HD_TYPE_ORG_OTHER_DESC OtherOrganizationDsc TypeOfOrgOtherDescription
# only OtherOrganizationDsc
# 		 18488
# F9_00_HD_TYPE_ORG_TRUST TypeOfOrganizationTrust TypeOfOrganizationTrustInd
# only TypeOfOrganizationTrustInd
# 		 28694
# F9_00_HD_WEBSITE WebsiteAddressTxt WebSite
# only WebsiteAddressTxt
# 		 778688
# F9_00_HD_YEAR_FORMED YearFormation FormationYr
# only FormationYr
# 		 835703
# F9_01_PC_BEN_PAID_MEMB_PRIOR BenefitsPaidToMembersPriorYear PYBenefitsPaidToMembersAmt
# only PYBenefitsPaidToMembersAmt
# 		 398359
# F9_01_PC_CONTR_GRANTS_CURR ContributionsGrantsCurrentYear CYContributionsGrantsAmt
# only CYContributionsGrantsAmt
# 		 891980
# F9_01_PC_CONTR_GRANTS_PRIOR PYContributionsGrantsAmt ContributionsGrantsPriorYear
# only PYContributionsGrantsAmt
# 		 771290
# F9_01_PC_GRANTS_PRIOR GrantsAndSimilarAmntsPriorYear PYGrantsAndSimilarPaidAmt
# only PYGrantsAndSimilarPaidAmt
# 		 500329
# F9_01_PC_INDEP_VOTING_MEMB VotingMembersIndependentCnt NbrIndependentVotingMembers
# only VotingMembersIndependentCnt
# 		 891980
# F9_01_PC_INVEST_INCOME_PRIOR InvestmentIncomePriorYear PYInvestmentIncomeAmt
# only PYInvestmentIncomeAmt
# 		 715498
# F9_01_PC_NET_ASSETS_BOY NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesBOYAmt
# only NetAssetsOrFundBalancesBOYAmt
# 		 873796
# F9_01_PC_OTHER_EXPENSE_PRIOR PYOtherExpensesAmt OtherExpensePriorYear
# only PYOtherExpensesAmt
# 		 849999
# F9_01_PC_OTHER_REV_PRIOR PYOtherRevenueAmt OtherRevenuePriorYear
# only PYOtherRevenueAmt
# 		 643912
# F9_01_PC_PROF_FUNDRISING_EXP_CURR CYTotalProfFndrsngExpnsAmt TotalProfFundrsngExpCY
# only CYTotalProfFndrsngExpnsAmt
# 		 891980
# F9_01_PC_PROF_FUNDRISING_EXP_PRIOR TotalProfFundrsngExpPriorYear PYTotalProfFndrsngExpnsAmt
# only PYTotalProfFndrsngExpnsAmt
# 		 390695
# F9_01_PC_PROG_SERVICE_REV_PRIOR ProgramServiceRevenuePriorYear PYProgramServiceRevenueAmt
# only PYProgramServiceRevenueAmt
# 		 668367
# F9_01_PC_REV_LESS_EXP_CURR RevenuesLessExpensesCY CYRevenuesLessExpensesAmt
# only CYRevenuesLessExpensesAmt
# 		 891980
# F9_01_PC_REV_LESS_EXP_PRIOR RevenuesLessExpensesPriorYear PYRevenuesLessExpensesAmt
# only PYRevenuesLessExpensesAmt
# 		 855788
# F9_01_PC_TERMINATION_CONTRACTION TerminationOrContraction ContractTerminationInd
# only ContractTerminationInd
# 		 6995
# F9_01_PC_TOT_ASSETS_EOY TotalAssetsEOYAmt TotalAssetsEOY
# only TotalAssetsEOYAmt
# 		 891980
# F9_01_PC_TOT_EXP_PRIOR TotalExpensesPriorYear PYTotalExpensesAmt
# only PYTotalExpensesAmt
# 		 854295
# F9_01_PC_TOT_FNDR_EXP_CURR TotalFundrsngExpCurrentYear CYTotalFundraisingExpenseAmt
# only CYTotalFundraisingExpenseAmt
# 		 891980
# F9_01_PC_TOT_INDIV_EMPLOYED TotalNbrEmployees TotalEmployeeCnt
# only TotalEmployeeCnt
# 		 891980
# F9_01_PC_TOT_INDIV_VOLUNTEERS TotalNbrVolunteers TotalVolunteersCnt
# only TotalVolunteersCnt
# 		 646391
# F9_01_PC_TOT_LIABILITIES_EOY TotalLiabilitiesEOYAmt TotalLiabilitiesEOY
# only TotalLiabilitiesEOYAmt
# 		 891980
# F9_01_PC_TOT_REVENUE_PRIOR PYTotalRevenueAmt TotalRevenuePriorYear
# only PYTotalRevenueAmt
# 		 855921
# F9_01_PC_TOT_UBI_GROSS TotalGrossUBIAmt TotalGrossUBI
# only TotalGrossUBIAmt
# 		 891980
# F9_01_PC_TOT_UBI_NET NetUnrelatedBusTxblIncmAmt NetUnrelatedBusinessTxblIncome
# only NetUnrelatedBusTxblIncmAmt
# 		 531587
# F9_01_PC_VOTING_MEMB_GOV_BODY VotingMembersGoverningBodyCnt NbrVotingMembersGoverningBody
# only VotingMembersGoverningBodyCnt
# 		 891980
# F9_01_PZ_BEN_PAID_TO_MEMB_CURR BenefitsPaidToMembersCY CYBenefitsPaidToMembersAmt
# only CYBenefitsPaidToMembersAmt
# 		 891980
# F9_01_PZ_GRANTS_PAID_CURR CYGrantsAndSimilarPaidAmt GrantsAndSimilarAmntsCY
# only CYGrantsAndSimilarPaidAmt
# 		 891980
# F9_01_PZ_INVEST_INCOME_CURR InvestmentIncomeCurrentYear CYInvestmentIncomeAmt
# only CYInvestmentIncomeAmt
# 		 891980
# F9_01_PZ_NAFB_EOY NetAssetsOrFundBalancesEOY NetAssetsOrFundBalancesEOYAmt
# only NetAssetsOrFundBalancesEOYAmt
# 		 891980
# F9_01_PZ_ORGANIZATIONAL_MISSION ActivityOrMissionDescription ActivityOrMissionDesc
# only ActivityOrMissionDesc
# 		 891980
# F9_01_PZ_OTHER_EXPENSE_CURR CYOtherExpensesAmt OtherExpensesCurrentYear
# only CYOtherExpensesAmt
# 		 891980
# F9_01_PZ_OTHER_REV_CURR CYOtherRevenueAmt OtherRevenueCurrentYear
# only CYOtherRevenueAmt
# 		 891980
# F9_01_PZ_PROG_SERVICE_REV_CURR CYProgramServiceRevenueAmt ProgramServiceRevenueCY
# only CYProgramServiceRevenueAmt
# 		 891980
# F9_01_PZ_SALARIES_CURR SalariesEtcCurrentYear CYSalariesCompEmpBnftPaidAmt
# only CYSalariesCompEmpBnftPaidAmt
# 		 891980
# F9_01_PZ_SALARIES_PRIOR PYSalariesCompEmpBnftPaidAmt SalariesEtcPriorYear
# only PYSalariesCompEmpBnftPaidAmt
# 		 695848
# F9_01_PZ_TOT_ASSETS_BOY TotalAssetsBOY TotalAssetsBOYAmt
# only TotalAssetsBOYAmt
# 		 874949
# F9_01_PZ_TOT_EXP_CURR TotalExpensesCurrentYear CYTotalExpensesAmt
# only CYTotalExpensesAmt
# 		 891980
# F9_01_PZ_TOT_LIAB_BOY TotalLiabilitiesBOY TotalLiabilitiesBOYAmt
# only TotalLiabilitiesBOYAmt
# 		 735681
# F9_01_PZ_TOT_REV_CURR TotalRevenueCurrentYear CYTotalRevenueAmt
# only CYTotalRevenueAmt
# 		 891980
# F9_03_PC_PGMSVC_SIGNIF_CHG SignificantChangeInd SignificantChange
# only SignificantChangeInd
# 		 881776
# F9_03_PC_PGMSVC_SIGNIF_NEW SignificantNewProgramSrvcInd SignificantNewProgramServices
# only SignificantNewProgramSrvcInd
# 		 881999
# F9_03_PC_PROG_SVC_ACC_1_CODE ActivityCode ActivityCd
# only ActivityCd
# 		 1506
# F9_03_PC_PROG_SVC_ACC_1_DESC Description Desc
# only Desc
# 		 891980
# F9_03_PC_PROG_SVC_ACC_1_EXP Expense ExpenseAmt
# only ExpenseAmt
# 		 742245
# F9_03_PC_PROG_SVC_ACC_1_GRNT Grants GrantAmt
# only GrantAmt
# 		 275648
# F9_03_PC_PROG_SVC_ACC_1_REV Revenue RevenueAmt
# only RevenueAmt
# 		 456609
# F9_03_PC_PROG_SVC_ACC_2_CODE Activity2 ProgSrvcAccomActy2Grp
# only ProgSrvcAccomActy2Grp
# 		 266413
# F9_03_PC_PROG_SVC_ACC_2_DESC Activity2 ProgSrvcAccomActy2Grp
# only ProgSrvcAccomActy2Grp
# 		 266413
# F9_03_PC_PROG_SVC_ACC_2_EXP Activity2 ProgSrvcAccomActy2Grp
# only ProgSrvcAccomActy2Grp
# 		 266413
# F9_03_PC_PROG_SVC_ACC_2_GRNT Activity2 ProgSrvcAccomActy2Grp
# only ProgSrvcAccomActy2Grp
# 		 266413
# F9_03_PC_PROG_SVC_ACC_2_REV Activity2 ProgSrvcAccomActy2Grp
# only ProgSrvcAccomActy2Grp
# 		 266413
# F9_03_PC_PROG_SVC_ACC_3_CODE Activity3 ProgSrvcAccomActy3Grp
# only ProgSrvcAccomActy3Grp
# 		 187714
# F9_03_PC_PROG_SVC_ACC_3_DESC Activity3 ProgSrvcAccomActy3Grp
# only ProgSrvcAccomActy3Grp
# 		 187714
# F9_03_PC_PROG_SVC_ACC_3_EXP Activity3 ProgSrvcAccomActy3Grp
# only ProgSrvcAccomActy3Grp
# 		 187714
# F9_03_PC_PROG_SVC_ACC_3_GRNT Activity3 ProgSrvcAccomActy3Grp
# only ProgSrvcAccomActy3Grp
# 		 187714
# F9_03_PC_PROG_SVC_ACC_3_REV Activity3 ProgSrvcAccomActy3Grp
# only ProgSrvcAccomActy3Grp
# 		 187714
# F9_03_PC_TOT_OTH_PROG_SVC_EXP TotalOfOtherProgramServiceExp TotalOtherProgSrvcExpenseAmt
# only TotalOtherProgSrvcExpenseAmt
# 		 137384
# F9_03_PC_TOT_OTH_PROG_SVC_GRNT TotalOfOtherProgramServiceGrnt TotalOtherProgSrvcGrantAmt
# only TotalOtherProgSrvcGrantAmt
# 		 72474
# F9_03_PC_TOT_OTH_PROG_SVC_REV TotalOtherProgSrvcRevenueAmt TotalOfOtherProgramServiceRev
# only TotalOtherProgSrvcRevenueAmt
# 		 84315
# F9_03_PC_TOT_PROG_SVC_EXPENSE TotalProgramServiceExpensesAmt TotalProgramServiceExpense
# only TotalProgramServiceExpensesAmt
# 		 759368
# F9_03_PZ_MISSION_DESCRIPTION MissionDescription MissionDesc
# only MissionDesc
# 		 889559
# F9_03_PZ_SCHEDULE_O_PART3 InfoInScheduleOPartIII InfoInScheduleOPartIIIInd
# only InfoInScheduleOPartIIIInd
# 		 278272
# F9_04_PC_ACTVITIES_VIA_PARTNER ActivitiesConductedPrtshpInd ActivitiesConductedPartnership
# only ActivitiesConductedPrtshpInd
# 		 891980
# F9_04_PC_CONTROLLED_ENTITY RelatedOrganizationCtrlEntInd RelatedOrgControlledEntity
# only RelatedOrganizationCtrlEntInd
# 		 891980
# F9_04_PC_DISREGARDED_ENTITY DisregardedEntity DisregardedEntityInd
# only DisregardedEntityInd
# 		 891980
# F9_04_PC_EXCESS_BENEFIT_TRANS ExcessBenefitTransaction EngagedInExcessBenefitTransInd
# only EngagedInExcessBenefitTransInd
# 		 706661
# F9_04_PC_FR_EVENT_INC_GT_15K FundraisingActivities FundraisingActivitiesInd
# only FundraisingActivitiesInd
# 		 891980
# F9_04_PC_GAMING_INC_GT_15K Gaming GamingActivitiesInd
# only GamingActivitiesInd
# 		 891980
# F9_04_PC_LOBBYING_ACTIVITIES LobbyingActivities LobbyingActivitiesInd
# only LobbyingActivitiesInd
# 		 669923
# F9_04_PC_POLITICAL_ACTIVITIES PoliticalActivities PoliticalCampaignActyInd
# only PoliticalCampaignActyInd
# 		 891980
# F9_04_PC_PRIOR_EXCESS_BEN_TRAN PriorExcessBenefitTransaction PYExcessBenefitTransInd
# only PYExcessBenefitTransInd
# 		 707477
# F9_04_PC_PROF_FR_EXP_GT_15K ProfessionalFundraising ProfessionalFundraisingInd
# only ProfessionalFundraisingInd
# 		 891980
# F9_04_PC_RELATED_ENTITY RelatedEntity RelatedEntityInd
# only RelatedEntityInd
# 		 891980
# F9_04_PC_TRANS_TO_CNTRLD_ENT TrnsfrExmptNonChrtblRltdOrgInd TransfersToExemptNonChrtblOrg
# only TrnsfrExmptNonChrtblRltdOrgInd
# 		 668296
# F9_04_PC_TRANS_WITH_CNTRLD_ENT TransactionWithControlEntInd TransactionRelatedEntity
# only TransactionWithControlEntInd
# 		 111869
# F9_05_EXP_SCHED_O_X InfoInScheduleOPartVInd InfoInScheduleOPartV
# only InfoInScheduleOPartVInd
# 		 18835
# F9_05_PC_NUMBER_EMPLOYEES_W3 EmployeeCnt NumberOfEmployees
# only EmployeeCnt
# 		 891980
# F9_05_PC_NUMBER_FORMS_1096 NumberFormsTransmittedWith1096 IRPDocumentCnt
# only IRPDocumentCnt
# 		 891980
# F9_05_PC_UNRELATED_BUS_INCOME UnrelatedBusIncmOverLimitInd UnrelatedBusinessIncome
# only UnrelatedBusIncmOverLimitInd
# 		 891980
# F9_06_EXP_SCHED_O_X InfoInScheduleOPartVI InfoInScheduleOPartVIInd
# only InfoInScheduleOPartVIInd
# 		 851491
# F9_06_PC_990_PROVIDED_GOV_BODY Form990ProvidedToGoverningBody Form990ProvidedToGvrnBodyInd
# only Form990ProvidedToGvrnBodyInd
# 		 891980
# F9_06_PC_ANNUAL_DISC_COVRD_PERS AnnualDisclosureCoveredPersons AnnualDisclosureCoveredPrsnInd
# only AnnualDisclosureCoveredPrsnInd
# 		 549670
# F9_06_PC_CEO_COMPENSTN_PROCESS CompensationProcessCEOInd CompensationProcessCEO
# only CompensationProcessCEOInd
# 		 889077
# F9_06_PC_CHANGES_ORGANIZING_DOCS ChangeToOrgDocumentsInd ChangesToOrganizingDocs
# only ChangeToOrgDocumentsInd
# 		 891980
# F9_06_PC_CONFLICT_OF_INTEREST ConflictOfInterestPolicyInd ConflictOfInterestPolicy
# only ConflictOfInterestPolicyInd
# 		 891980
# F9_06_PC_DECISIONS_SUBJ_APPROVAL DecisionsSubjectToApproval DecisionsSubjectToApprovaInd
# only DecisionsSubjectToApprovaInd
# 		 891980
# F9_06_PC_DELEGATION_MGT_DUTIES DelegationOfMgmtDutiesInd DelegationOfManagementDuties
# only DelegationOfMgmtDutiesInd
# 		 891980
# F9_06_PC_DELEGATION_OF_MGT DelegationOfMgmtDutiesInd DelegationOfManagementDuties
# only DelegationOfMgmtDutiesInd
# 		 891980
# F9_06_PC_DOCUMENT_RET_POLICY DocumentRetentionPolicyInd DocumentRetentionPolicy
# only DocumentRetentionPolicyInd
# 		 891980
# F9_06_PC_ELECTION_BOARD_MEMBERS ElectionOfBoardMembersInd ElectionOfBoardMembers
# only ElectionOfBoardMembersInd
# 		 891980
# F9_06_PC_FAMILY_OR_BUSINESS_REL FamilyOrBusinessRelationship FamilyOrBusinessRlnInd
# only FamilyOrBusinessRlnInd
# 		 891980
# F9_06_PC_FORM_AVAIL_OWN_WEBSITE OwnWebsiteInd OwnWebsite
# only OwnWebsiteInd
# 		 58480
# F9_06_PC_FORM_UPON_REQUEST UponRequest UponRequestInd
# only UponRequestInd
# 		 786526
# F9_06_PC_JOINT_VENTURE_INVESTMNT InvestmentInJointVenture InvestmentInJointVentureInd
# only InvestmentInJointVentureInd
# 		 891980
# F9_06_PC_JOINT_VENTURE_POLICY WrittenPolicyOrProcedure WrittenPolicyOrProcedureInd
# only WrittenPolicyOrProcedureInd
# 		 22939
# F9_06_PC_LOCAL_CHAPTERS LocalChapters LocalChaptersInd
# only LocalChaptersInd
# 		 891980
# F9_06_PC_MATERIAL_DIVERSION MaterialDiversionOrMisuseInd MaterialDiversionOrMisuse
# only MaterialDiversionOrMisuseInd
# 		 891980
# F9_06_PC_MEMBERS_OR_STOCKHOLDERS MembersOrStockholders MembersOrStockholdersInd
# only MembersOrStockholdersInd
# 		 891980
# F9_06_PC_MINUTES_COMMITTEES MinutesOfCommitteesInd MinutesOfCommittees
# only MinutesOfCommitteesInd
# 		 890119
# F9_06_PC_MINUTES_GOVERNING_BODY MinutesOfGoverningBody MinutesOfGoverningBodyInd
# only MinutesOfGoverningBodyInd
# 		 891980
# F9_06_PC_MONITORING_OF_COI_POLICY RegularMonitoringEnfrcInd RegularMonitoringEnforcement
# only RegularMonitoringEnfrcInd
# 		 552261
# F9_06_PC_NUM_IND_VOTING_MEMBERS NumberIndependentVotingMembers IndependentVotingMemberCnt
# only IndependentVotingMemberCnt
# 		 891980
# F9_06_PC_NUM_VOTING_GOV_MEMBERS GoverningBodyVotingMembersCnt NbrVotingGoverningBodyMembers
# only GoverningBodyVotingMembersCnt
# 		 891980
# F9_06_PC_OFFICER_MAILING_ADDRESS OfficerMailingAddressInd OfficerMailingAddress
# only OfficerMailingAddressInd
# 		 891980
# F9_06_PC_OTHER_COMPENSTN_PROCESS CompensationProcessOtherInd CompensationProcessOther
# only CompensationProcessOtherInd
# 		 888843
# F9_06_PC_OTHER_WEBSITE OtherWebsite OtherWebsiteInd
# only OtherWebsiteInd
# 		 101759
# F9_06_PC_OWN_WEBSITE OwnWebsiteInd OwnWebsite
# only OwnWebsiteInd
# 		 58480
# F9_06_PC_POLICIES_GOVERN_CHAPTER PoliciesReferenceChapters PoliciesReferenceChaptersInd
# only PoliciesReferenceChaptersInd
# 		 43494
# F9_06_PC_STATES_WHERE_RET_FILED StatesWhereCopyOfReturnIsFiled StatesWhereCopyOfReturnIsFldCd
# only StatesWhereCopyOfReturnIsFldCd
# 		 457219
# F9_06_PC_WHISTLEBLOWER_POLICY WhistleblowerPolicyInd WhistleblowerPolicy
# only WhistleblowerPolicyInd
# 		 891980
# F9_07_EXP_SCHED_O_X InfoInScheduleOPartVII InfoInScheduleOPartVIIInd
# only InfoInScheduleOPartVIIInd
# 		 26930
# F9_07_PC_COMPENSATION_OTHER_SRCE CompensationFromOtherSrcsInd CompensationFromOtherSources
# only CompensationFromOtherSrcsInd
# 		 891980
# F9_07_PC_FORMER_OFFICER_LISTED FormersListed FormerOfcrEmployeesListedInd
# only FormerOfcrEmployeesListedInd
# 		 891980
# F9_07_PC_NO_LISTED_PERS_COMPENSD NoListedPersonsCompensatedInd NoListedPersonsCompensated
# only NoListedPersonsCompensatedInd
# 		 411641
# F9_07_PC_NUM_CONTRCTRS_GRTR_100K NumberOfContractorsGT100K CntrctRcvdGreaterThan100KCnt
# only CntrctRcvdGreaterThan100KCnt
# 		 512412
# F9_07_PC_NUM_INDS_GREATER_100K IndivRcvdGreaterThan100KCnt NumberIndividualsGT100K
# only IndivRcvdGreaterThan100KCnt
# 		 620251
# F9_07_PC_TOTAL_COMP_GRTR_150K TotalCompGT150K TotalCompGreaterThan150KInd
# only TotalCompGreaterThan150KInd
# 		 891980
# F9_07_PC_TOT_OTHER_COMPENSATION TotalOtherCompensationAmt TotalOtherCompensation
# only TotalOtherCompensationAmt
# 		 562769
# F9_07_PC_TOT_REPRT_COMP_FROM_ORG TotalReportableCompFromOrg TotalReportableCompFromOrgAmt
# only TotalReportableCompFromOrgAmt
# 		 664789
# F9_07_PC_TOT_REPRT_COMP_RLTD_ORG TotReportableCompRltdOrgAmt TotalReportableCompFrmRltdOrgs
# only TotReportableCompRltdOrgAmt
# 		 524518
# F9_08_EXP_SCHED_O_X InfoInScheduleOPartVIIIInd InfoInScheduleOPartVIII
# only InfoInScheduleOPartVIIIInd
# 		 6511
# F9_08_PC_ALL_OTHER_CONTRIBUTIONS AllOtherContributionsAmt AllOtherContributions
# only AllOtherContributionsAmt
# 		 611416
# F9_08_PC_CONTS_REPRTD_FNDRAISNG CntrbtnsRprtdFundraisingEvents ContriRptFundraisingEventAmt
# only ContriRptFundraisingEventAmt
# 		 150470
# F9_08_PC_COST_OF_GOODS_SOLD CostOfGoodsSold CostOfGoodsSoldAmt
# only CostOfGoodsSoldAmt
# 		 135694
# F9_08_PC_FEDERATED_CAMPAIGNS FederatedCampaigns FederatedCampaignsAmt
# only FederatedCampaignsAmt
# 		 77700
# F9_08_PC_FUNDRAISING_DIRECT_EXP FundraisingDirectExpensesAmt FundraisingDirectExpenses
# only FundraisingDirectExpensesAmt
# 		 213137
# F9_08_PC_FUNDRAISING_EVENTS FundraisingAmt FundraisingEvents
# only FundraisingAmt
# 		 155291
# F9_08_PC_FUNDRAISING_GROSS_INC FundraisingGrossIncomeAmt GrossIncomeFundraisingEvents
# only FundraisingGrossIncomeAmt
# 		 221484
# F9_08_PC_GAMING_DIRECT_EXPENSES GamingDirectExpenses GamingDirectExpensesAmt
# only GamingDirectExpensesAmt
# 		 75294
# F9_08_PC_GAMING_GROSS_INCOME GrossIncomeGaming GamingGrossIncomeAmt
# only GamingGrossIncomeAmt
# 		 77463
# F9_08_PC_GOVERNMENT_GRANTS GovernmentGrantsAmt GovernmentGrants
# only GovernmentGrantsAmt
# 		 331093
# F9_08_PC_GROSS_SALES_INVENTORY GrossSalesOfInventory GrossSalesOfInventoryAmt
# only GrossSalesOfInventoryAmt
# 		 141718
# F9_08_PC_MEMBERSHIP_DUES MembershipDues MembershipDuesAmt
# only MembershipDuesAmt
# 		 184898
# F9_08_PC_NONCASH_CONTRIBUTIONS NoncashContributions NoncashContributionsAmt
# only NoncashContributionsAmt
# 		 155110
# F9_08_PC_PROGRAM_SVCE_REV_TOTAL TotalProgramServiceRevenueAmt TotalProgramServiceRevenue
# only TotalProgramServiceRevenueAmt
# 		 630629
# F9_08_PC_RELATED_ORGANIZATIONS RelatedOrganizations RelatedOrganizationsAmt
# only RelatedOrganizationsAmt
# 		 82731
# F9_08_PC_TOTAL_CONTRIBUTIONS TotalContributions TotalContributionsAmt
# only TotalContributionsAmt
# 		 753532
# F9_08_PC_TOTAL_OTHER_REVENUE OtherRevenueTotalAmt TotalOtherRevenue
# only OtherRevenueTotalAmt
# 		 456077
# F9_08_PC_TOTAL_PROG_SVCE_REVENUE TotalProgramServiceRevenueAmt TotalProgramServiceRevenue
# only TotalProgramServiceRevenueAmt
# 		 630629
# F9_08_PC_TOTAL_REVENUE TotalRevenueGrp TotalRevenue
# only TotalRevenueGrp
# 		 891980
# F9_09_EXP_AD_PROMO_TOT AdvertisingGrp Advertising
# only AdvertisingGrp
# 		 533968
# F9_09_EXP_BENF_PAID_MEMB_TOT BenefitsToMembersGrp BenefitsToMembers
# only BenefitsToMembersGrp
# 		 227901
# F9_09_EXP_CONF_MEETING_TOT ConferencesMeetings ConferencesMeetingsGrp
# only ConferencesMeetingsGrp
# 		 440265
# F9_09_EXP_DEPREC_FUNDR DepreciationDepletionGrp DepreciationDepletion
# only DepreciationDepletionGrp
# 		 602054
# F9_09_EXP_DEPREC_MAG DepreciationDepletionGrp DepreciationDepletion
# only DepreciationDepletionGrp
# 		 602054
# F9_09_EXP_DEPREC_PROG DepreciationDepletionGrp DepreciationDepletion
# only DepreciationDepletionGrp
# 		 602054
# F9_09_EXP_DEPREC_TOT DepreciationDepletionGrp DepreciationDepletion
# only DepreciationDepletionGrp
# 		 602054
# F9_09_EXP_GRANT_FRGN_TOT ForeignGrants ForeignGrantsGrp
# only ForeignGrantsGrp
# 		 222557
# F9_09_EXP_GRANT_INDIV_DMSTC_TOT GrantsToDomesticIndividuals GrantsToDomesticIndividualsGrp
# only GrantsToDomesticIndividualsGrp
# 		 292852
# F9_09_EXP_GRANT_ORG_DMSTC_TOT GrantsToDomesticOrgs GrantsToDomesticOrgsGrp
# only GrantsToDomesticOrgsGrp
# 		 339079
# F9_09_EXP_INFO_TECH_TOT InformationTechnology InformationTechnologyGrp
# only InformationTechnologyGrp
# 		 422706
# F9_09_EXP_INSURANCE_TOT InsuranceGrp Insurance
# only InsuranceGrp
# 		 693976
# F9_09_EXP_INTEREST_TOT InterestGrp Interest
# only InterestGrp
# 		 374000
# F9_09_EXP_JOINT_COSTS_TOT TotalJointCostsGrp TotalJointCosts
# only TotalJointCostsGrp
# 		 8651
# F9_09_EXP_OCCUPANCY_TOT OccupancyGrp Occupancy
# only OccupancyGrp
# 		 617995
# F9_09_EXP_OFFICE_TOT OfficeExpenses OfficeExpensesGrp
# only OfficeExpensesGrp
# 		 741406
# F9_09_EXP_OTH_OTH_TOT AllOtherExpenses AllOtherExpensesGrp
# only AllOtherExpensesGrp
# 		 559473
# F9_09_EXP_OTH_TOT OtherExpenses OtherExpensesGrp
# only OtherExpensesGrp
# 		 804457
# F9_09_EXP_ROY_TOT Royalties RoyaltiesGrp
# only RoyaltiesGrp
# 		 203098
# F9_09_EXP_SCHED_O_X InfoInScheduleOPartIXInd InfoInScheduleOPartIX
# only InfoInScheduleOPartIXInd
# 		 167512
# F9_09_EXP_TRAVEL_ENTRTNMNT_TOT TravelEntrtnmntPublicOfficials PymtTravelEntrtnmntPubOfclGrp
# only PymtTravelEntrtnmntPubOfclGrp
# 		 200339
# F9_09_EXP_TRAVEL_TOT TravelGrp Travel
# only TravelGrp
# 		 510962
# F9_09_PC_COMP_DISQUAL_FUNDRAISE CompDisqualPersonsGrp CompDisqualPersons
# only CompDisqualPersonsGrp
# 		 216011
# F9_09_PC_COMP_DISQUAL_MGMT CompDisqualPersonsGrp CompDisqualPersons
# only CompDisqualPersonsGrp
# 		 216011
# F9_09_PC_COMP_DISQUAL_PROG_SVCE CompDisqualPersonsGrp CompDisqualPersons
# only CompDisqualPersonsGrp
# 		 216011
# F9_09_PC_COMP_DISQUAL_TOTAL CompDisqualPersonsGrp CompDisqualPersons
# only CompDisqualPersonsGrp
# 		 216011
# F9_09_PC_COMP_OFFICERS_FUNDRAISE CompCurrentOfcrDirectorsGrp CompCurrentOfficersDirectors
# only CompCurrentOfcrDirectorsGrp
# 		 498765
# F9_09_PC_COMP_OFFICERS_MGMT CompCurrentOfcrDirectorsGrp CompCurrentOfficersDirectors
# only CompCurrentOfcrDirectorsGrp
# 		 498765
# F9_09_PC_COMP_OFFICERS_PROG_SVCE CompCurrentOfcrDirectorsGrp CompCurrentOfficersDirectors
# only CompCurrentOfcrDirectorsGrp
# 		 498765
# F9_09_PC_COMP_OFFICERS_TOTAL CompCurrentOfcrDirectorsGrp CompCurrentOfficersDirectors
# only CompCurrentOfcrDirectorsGrp
# 		 498765
# F9_09_PC_FEES_FOR_SVCE_ACCT_TOT FeesForServicesAccountingGrp FeesForServicesAccounting
# only FeesForServicesAccountingGrp
# 		 701248
# F9_09_PC_FEES_FOR_SVCE_INVST_TOT FeesForSrvcInvstMgmntFeesGrp FeesForServicesInvstMgmntFees
# only FeesForSrvcInvstMgmntFeesGrp
# 		 296478
# F9_09_PC_FEES_FOR_SVCE_LEGL_TOT FeesForServicesLegal FeesForServicesLegalGrp
# only FeesForServicesLegalGrp
# 		 412872
# F9_09_PC_FEES_FOR_SVCE_LOBB_TOT FeesForServicesLobbyingGrp FeesForServicesLobbying
# only FeesForServicesLobbyingGrp
# 		 220926
# F9_09_PC_FEES_FOR_SVCE_MGMT_TOT FeesForServicesManagement FeesForServicesManagementGrp
# only FeesForServicesManagementGrp
# 		 297721
# F9_09_PC_FEES_FOR_SVCE_OTH_TOT FeesForServicesOtherGrp FeesForServicesOther
# only FeesForServicesOtherGrp
# 		 526437
# F9_09_PC_OTHER_EMP_BEN_FUNDRAISE OtherEmployeeBenefits OtherEmployeeBenefitsGrp
# only OtherEmployeeBenefitsGrp
# 		 468445
# F9_09_PC_OTHER_EMP_BEN_MGMT OtherEmployeeBenefits OtherEmployeeBenefitsGrp
# only OtherEmployeeBenefitsGrp
# 		 468445
# F9_09_PC_OTHER_EMP_BEN_PROG_SVCE OtherEmployeeBenefits OtherEmployeeBenefitsGrp
# only OtherEmployeeBenefitsGrp
# 		 468445
# F9_09_PC_OTHER_EMP_BEN_TOTAL OtherEmployeeBenefits OtherEmployeeBenefitsGrp
# only OtherEmployeeBenefitsGrp
# 		 468445
# F9_09_PC_OTHER_SALARY_FUNDRAISE OtherSalariesAndWagesGrp OtherSalariesAndWages
# only OtherSalariesAndWagesGrp
# 		 603541
# F9_09_PC_OTHER_SALARY_MGMT OtherSalariesAndWagesGrp OtherSalariesAndWages
# only OtherSalariesAndWagesGrp
# 		 603541
# F9_09_PC_OTHER_SALARY_PROG_SVCE OtherSalariesAndWagesGrp OtherSalariesAndWages
# only OtherSalariesAndWagesGrp
# 		 603541
# F9_09_PC_OTHER_SALARY_TOTAL OtherSalariesAndWagesGrp OtherSalariesAndWages
# only OtherSalariesAndWagesGrp
# 		 603541
# F9_09_PC_PAYMENT_TO_AFFILIATES PaymentsToAffiliatesGrp PaymentsToAffiliates
# only PaymentsToAffiliatesGrp
# 		 226123
# F9_09_PC_PAYROLL_TAX_FUNDRAISE PayrollTaxesGrp PayrollTaxes
# only PayrollTaxesGrp
# 		 600304
# F9_09_PC_PAYROLL_TAX_MGMT PayrollTaxesGrp PayrollTaxes
# only PayrollTaxesGrp
# 		 600304
# F9_09_PC_PAYROLL_TAX_PROG_SVCE PayrollTaxesGrp PayrollTaxes
# only PayrollTaxesGrp
# 		 600304
# F9_09_PC_PAYROLL_TAX_TOTAL PayrollTaxesGrp PayrollTaxes
# only PayrollTaxesGrp
# 		 600304
# F9_09_PC_PENSION_CONT_FUNDRAISE PensionPlanContributions PensionPlanContributionsGrp
# only PensionPlanContributionsGrp
# 		 348168
# F9_09_PC_PENSION_CONT_MGMT PensionPlanContributions PensionPlanContributionsGrp
# only PensionPlanContributionsGrp
# 		 348168
# F9_09_PC_PENSION_CONT_PROG_SVCE PensionPlanContributions PensionPlanContributionsGrp
# only PensionPlanContributionsGrp
# 		 348168
# F9_09_PC_PENSION_CONT_TOTAL PensionPlanContributions PensionPlanContributionsGrp
# only PensionPlanContributionsGrp
# 		 348168
# F9_09_PC_TOTAL_FUNC_EXPENSES TotalFunctionalExpenses TotalFunctionalExpensesGrp
# only TotalFunctionalExpensesGrp
# 		 891980
# F9_09_PC_TOTAL_FUNDRAISE_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# only TotalFunctionalExpensesGrp
# 		 891980
# F9_09_PC_TOTAL_MGMT_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# only TotalFunctionalExpensesGrp
# 		 891980
# F9_09_PC_TOTAL_PROG_SVCE_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# only TotalFunctionalExpensesGrp
# 		 891980
# F9_10_ASSETS_ACC_NET_EOY AccountsReceivable AccountsReceivableGrp
# only AccountsReceivableGrp
# 		 477612
# F9_10_ASSETS_EXP_PREPAID_EOY PrepaidExpensesDeferredCharges PrepaidExpensesDefrdChargesGrp
# only PrepaidExpensesDefrdChargesGrp
# 		 465123
# F9_10_ASSETS_INTANGIB_EOY IntangibleAssets IntangibleAssetsGrp
# only IntangibleAssetsGrp
# 		 201674
# F9_10_ASSETS_INVENT_SALE_EOY InventoriesForSaleOrUse InventoriesForSaleOrUseGrp
# only InventoriesForSaleOrUseGrp
# 		 278199
# F9_10_ASSETS_LESS_DEPREC_EOY LandBldgEquipBasisNetGrp LandBuildingsEquipmentBasisNet
# only LandBldgEquipBasisNetGrp
# 		 646771
# F9_10_ASSETS_LOANS_DISQUAL_EOY ReceivablesFromDisqualPersons RcvblFromDisqualifiedPrsnGrp
# only RcvblFromDisqualifiedPrsnGrp
# 		 177139
# F9_10_ASSETS_NOTES_LOANS_NET_EOY OtherNotesLoansReceivableNet OthNotesLoansReceivableNetGrp
# only OthNotesLoansReceivableNetGrp
# 		 220347
# F9_10_ASSETS_OTH_EOY OtherAssetsTotal OtherAssetsTotalGrp
# only OtherAssetsTotalGrp
# 		 430652
# F9_10_ASSETS_PLEDGES_NET_EOY PledgesAndGrantsReceivableGrp PledgesAndGrantsReceivable
# only PledgesAndGrantsReceivableGrp
# 		 299162
# F9_10_LIAB_ACC_PAYABLE_EOY AccountsPayableAccrExpnssGrp AccountsPayableAccruedExpenses
# only AccountsPayableAccrExpnssGrp
# 		 583198
# F9_10_LIAB_GRANTS_PAYABLE_EOY GrantsPayableGrp GrantsPayable
# only GrantsPayableGrp
# 		 78586
# F9_10_LIAB_LOANS_OFF_EOY LoansFromOfficersDirectorsGrp LoansFromOfficersDirectors
# only LoansFromOfficersDirectorsGrp
# 		 80122
# F9_10_LIAB_REV_DEFERRED_EOY DeferredRevenueGrp DeferredRevenue
# only DeferredRevenueGrp
# 		 257009
# F9_10_NAFB_RESTRICT_PERM_EOY PermanentlyRestrictedNetAssets PermanentlyRstrNetAssetsGrp
# only PermanentlyRstrNetAssetsGrp
# 		 150
# F9_10_NAFB_RESTRICT_TEMP_EOY TemporarilyRestrictedNetAssets TemporarilyRstrNetAssetsGrp
# only TemporarilyRstrNetAssetsGrp
# 		 317
# F9_10_NAFB_UNRESTRICT_EOY UnrestrictedNetAssets UnrestrictedNetAssetsGrp
# only UnrestrictedNetAssetsGrp
# 		 939
# F9_10_PC_BOND_LIABILITY_EOY TaxExemptBondLiabilitiesGrp TaxExemptBondLiabilities
# only TaxExemptBondLiabilitiesGrp
# 		 70291
# F9_10_PC_CASH_NON_INTEREST_BOY CashNonInterestBearingGrp CashNonInterestBearing
# only CashNonInterestBearingGrp
# 		 829604
# F9_10_PC_CASH_NON_INTEREST_EOY CashNonInterestBearingGrp CashNonInterestBearing
# only CashNonInterestBearingGrp
# 		 829604
# F9_10_PC_ESCROW_LIABILITY_EOY EscrowAccountLiabilityGrp EscrowAccountLiability
# only EscrowAccountLiabilityGrp
# 		 73828
# F9_10_PC_INVEST_OTHER_SEC_EOY InvestmentsOtherSecuritiesGrp InvestmentsOtherSecurities
# only InvestmentsOtherSecuritiesGrp
# 		 241297
# F9_10_PC_INVEST_PROG_RELTD_EOY InvestmentsProgramRelated InvestmentsProgramRelatedGrp
# only InvestmentsProgramRelatedGrp
# 		 194528
# F9_10_PC_INVEST_PUB_TRADED_EOY InvestmentsPubTradedSecGrp InvestmentsPubTradedSecurities
# only InvestmentsPubTradedSecGrp
# 		 351115
# F9_10_PC_LAND_BLDG_EQPMT LandBldgEquipCostOrOtherBssAmt LandBuildingsEquipmentBasis
# only LandBldgEquipCostOrOtherBssAmt
# 		 609236
# F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN LandBldgEquipAccumDeprecAmt LandBldgEquipmentAccumDeprec
# only LandBldgEquipAccumDeprecAmt
# 		 578796
# F9_10_PC_LOANS_FROM_OFFICERS_EOY LoansFromOfficersDirectorsGrp LoansFromOfficersDirectors
# only LoansFromOfficersDirectorsGrp
# 		 80122
# F9_10_PC_ORG_FOLLOWS_SFAS117 OrganizationFollowsSFAS117Ind FollowSFAS117
# only OrganizationFollowsSFAS117Ind
# 		 954
# F9_10_PC_ORG_NOT_FOLLOW_SFAS117 DoNotFollowSFAS117 OrgDoesNotFollowSFAS117Ind
# only OrgDoesNotFollowSFAS117Ind
# 		 397
# F9_10_PC_OTHER_LIABILITIES_EOY OtherLiabilities OtherLiabilitiesGrp
# only OtherLiabilitiesGrp
# 		 396310
# F9_10_PC_RET_EARNINGS_ENDWMT_EOY RtnEarnEndowmentIncmOthFndsGrp RetainedEarningsEndowmentEtc
# only RtnEarnEndowmentIncmOthFndsGrp
# 		 212670
# F9_10_PC_SAVINGS_TEMP_INVEST_BOY SavingsAndTempCashInvestments SavingsAndTempCashInvstGrp
# only SavingsAndTempCashInvstGrp
# 		 553606
# F9_10_PC_SAVINGS_TEMP_INVEST_EOY SavingsAndTempCashInvestments SavingsAndTempCashInvstGrp
# only SavingsAndTempCashInvstGrp
# 		 553606
# F9_10_PC_SECURED_MORTGAGES_EOY MortgNotesPyblScrdInvstPropGrp MortNotesPyblSecuredInvestProp
# only MortgNotesPyblScrdInvstPropGrp
# 		 215812
# F9_10_PC_SECURE_MORT_NOTES_EOY MortgNotesPyblScrdInvstPropGrp MortNotesPyblSecuredInvestProp
# only MortgNotesPyblScrdInvstPropGrp
# 		 215812
# F9_10_PC_UNSECURED_LOANS_EOY UnsecuredNotesLoansPayable UnsecuredNotesLoansPayableGrp
# only UnsecuredNotesLoansPayableGrp
# 		 154121
# F9_10_PC_UNSECURED_NOTES_BOY UnsecuredNotesLoansPayable UnsecuredNotesLoansPayableGrp
# only UnsecuredNotesLoansPayableGrp
# 		 154121
# F9_10_PC_UNSECURED_NOTES_EOY UnsecuredNotesLoansPayable UnsecuredNotesLoansPayableGrp
# only UnsecuredNotesLoansPayableGrp
# 		 154121
# F9_10_PZ_TOTAL_ASSETS_EOY TotalAssets TotalAssetsGrp
# only TotalAssetsGrp
# 		 891980
# F9_10_SCHED_O_X InfoInScheduleOPartXInd InfoInScheduleOPartX
# only InfoInScheduleOPartXInd
# 		 8644
# F9_11_PC_RECNCLTN_DONATED_SVCES ReconcilationDonatedServices DonatedServicesAndUseFcltsAmt
# only DonatedServicesAndUseFcltsAmt
# 		 59088
# F9_11_PC_RECNCLTN_INVSTMNT_EXP ReconcilationInvestExpenses InvestmentExpenseAmt
# only InvestmentExpenseAmt
# 		 56706
# F9_11_PC_RECNCLTN_PRIOR_PER_ADJ ReconcilationPriorAdjustment PriorPeriodAdjustmentsAmt
# only PriorPeriodAdjustmentsAmt
# 		 122487
# F9_11_PC_RECNCLTN_REV_LESS_EXP ReconcilationRevenueExpnssAmt ReconcilationRevenueExpenses
# only ReconcilationRevenueExpnssAmt
# 		 891980
# F9_11_PC_RECNCLTN_UNRLZD_GAIN NetUnrlzdGainsLossesInvstAmt ReconciliationUnrealizedInvest
# only NetUnrlzdGainsLossesInvstAmt
# 		 259578
# F9_11_SCHED_O_X InfoInScheduleOPartXIInd InfoInScheduleOPartXI
# only InfoInScheduleOPartXIInd
# 		 159809
# F9_12_PC_ACCNT_COMPILE_OR_REVIEW AccountantCompileOrReview AccountantCompileOrReviewInd
# only AccountantCompileOrReviewInd
# 		 891980
# F9_12_PC_ACCTG_METHOD_ACCRUAL MethodOfAccountingAccrualInd MethodOfAccountingAccrual
# only MethodOfAccountingAccrualInd
# 		 538893
# F9_12_PC_ACCTG_METHOD_CASH MethodOfAccountingCash MethodOfAccountingCashInd
# only MethodOfAccountingCashInd
# 		 333039
# F9_12_PC_ACCTG_METHOD_OTHER MethodOfAccountingOther MethodOfAccountingOtherInd
# only MethodOfAccountingOtherInd
# 		 20048
# F9_12_PC_AUDIT_COMMITTEE AuditCommitteeInd AuditCommittee
# only AuditCommitteeInd
# 		 419638
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD FederalGrantAuditPerformed FederalGrantAuditPerformedInd
# only FederalGrantAuditPerformedInd
# 		 69843
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED FederalGrantAuditRequiredInd FederalGrantAuditRequired
# only FederalGrantAuditRequiredInd
# 		 792574
# F9_12_PC_FINCL_STMTS_AUDITED FSAudited FSAuditedInd
# only FSAuditedInd
# 		 891980
# F9_12_SCHED_O_X InfoInScheduleOPartXIIInd InfoInScheduleOPartXII
# only InfoInScheduleOPartXIIInd
# 		 130541
# number_of_other_prog_svces ProgSrvcAccomActyOtherGrp ActivityOther
# only ProgSrvcAccomActyOtherGrp
# 		 115604
# CPU times: total: 14min 50s
# Wall time: 16min 8s

# %% [markdown]
# ### Combine
# Now we can loop over every row in ``new_variables_df`` and combine the relevant variables. We are getting some 'performance warnings' here but we can ignore those. We do need to check the *combo_fails* output at the very end, however. We are hoping for an *empty list* - that is, ``[]``. If a variable is listed there it means the combining failed.

# %%
# %%time
combo_fails = []
for index, row in new_variables_df[new_variables_df['len']==2][:].iterrows():
    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    try:
        combine(df, row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    except:
        print('\n\n\n\n\n***********issue with variable: ', row['variable_name_new'])
        combo_fails.append(row['variable_name_new'])

print(combo_fails)
# Out:
# F9_00_HD_ADDR_CHANGE AddressChange AddressChangeInd
# F9_00_HD_AMENDED_RETURN AmendedReturn AmendedReturnInd
# F9_00_HD_CTRY_OF_DOMICILE LegalDomicileCountryCd CountryLegalDomicile
# F9_00_HD_EXEMPT_STATUS_4847A1 Organization4947a1 Organization4947a1NotPFInd
# F9_00_HD_EXEMPT_STATUS_501C Organization501cInd Organization501c
# F9_00_HD_EXEMPT_STATUS_501C3 Organization501c3 Organization501c3Ind
# F9_00_HD_FINAL_RETURN FinalReturnInd TerminatedReturn
# F9_00_HD_GROSS_EXEMPT_NUM GroupExemptionNumber GroupExemptionNum
# F9_00_HD_GROSS_RCPT GrossReceipts GrossReceiptsAmt
# F9_00_HD_GROUP_RETURN GroupReturnForAffiliatesInd GroupReturnForAffiliates
# F9_00_HD_INCLUDES_SUBORD_ORGS AllAffiliatesIncludedInd AllAffiliatesIncluded
# F9_00_HD_INITIAL_RETURN InitialReturn InitialReturnInd
# F9_00_HD_PRIN_OFF_NAME NameOfPrincipalOfficerPerson PrincipalOfficerNm
# F9_00_HD_SIGNING_OFFICER_SIGNTR BusinessOfficerGrp Officer
# F9_00_HD_SPECIAL_CONDITION_DESC SpecialConditionDescription SpecialConditionDesc
# F9_00_HD_STATE_OF_DOMICILE StateLegalDomicile LegalDomicileStateCd
# F9_00_HD_TAX_PER_BEGIN TaxPeriodBeginDt TaxPeriodBeginDate
# F9_00_HD_TAX_PER_END TaxPeriodEndDt TaxPeriodEndDate
# F9_00_HD_TAX_YEAR TaxYear TaxYr
# F9_00_HD_TIME_STAMP Timestamp ReturnTs
# F9_00_HD_TYPE_ORG_ASSOCIATION TypeOfOrganizationAssociation TypeOfOrganizationAssocInd
# F9_00_HD_TYPE_ORG_CORP TypeOfOrganizationCorpInd TypeOfOrganizationCorporation
# F9_00_HD_TYPE_ORG_OTHER TypeOfOrganizationOther TypeOfOrganizationOtherInd
# F9_00_HD_TYPE_ORG_OTHER_DESC OtherOrganizationDsc TypeOfOrgOtherDescription
# F9_00_HD_TYPE_ORG_TRUST TypeOfOrganizationTrust TypeOfOrganizationTrustInd
# F9_00_HD_WEBSITE WebsiteAddressTxt WebSite
# F9_00_HD_YEAR_FORMED YearFormation FormationYr
# F9_01_PC_BEN_PAID_MEMB_PRIOR BenefitsPaidToMembersPriorYear PYBenefitsPaidToMembersAmt
# F9_01_PC_CONTR_GRANTS_CURR ContributionsGrantsCurrentYear CYContributionsGrantsAmt
# F9_01_PC_CONTR_GRANTS_PRIOR PYContributionsGrantsAmt ContributionsGrantsPriorYear
# F9_01_PC_GRANTS_PRIOR GrantsAndSimilarAmntsPriorYear PYGrantsAndSimilarPaidAmt
# F9_01_PC_INDEP_VOTING_MEMB VotingMembersIndependentCnt NbrIndependentVotingMembers
# F9_01_PC_INVEST_INCOME_PRIOR InvestmentIncomePriorYear PYInvestmentIncomeAmt
# F9_01_PC_NET_ASSETS_BOY NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesBOYAmt
# F9_01_PC_OTHER_EXPENSE_PRIOR PYOtherExpensesAmt OtherExpensePriorYear
# F9_01_PC_OTHER_REV_PRIOR PYOtherRevenueAmt OtherRevenuePriorYear
# F9_01_PC_PROF_FUNDRISING_EXP_CURR CYTotalProfFndrsngExpnsAmt TotalProfFundrsngExpCY
# F9_01_PC_PROF_FUNDRISING_EXP_PRIOR TotalProfFundrsngExpPriorYear PYTotalProfFndrsngExpnsAmt
# F9_01_PC_PROG_SERVICE_REV_PRIOR ProgramServiceRevenuePriorYear PYProgramServiceRevenueAmt
# F9_01_PC_REV_LESS_EXP_CURR RevenuesLessExpensesCY CYRevenuesLessExpensesAmt
# F9_01_PC_REV_LESS_EXP_PRIOR RevenuesLessExpensesPriorYear PYRevenuesLessExpensesAmt
# F9_01_PC_TERMINATION_CONTRACTION TerminationOrContraction ContractTerminationInd
# F9_01_PC_TOT_ASSETS_EOY TotalAssetsEOYAmt TotalAssetsEOY
# F9_01_PC_TOT_EXP_PRIOR TotalExpensesPriorYear PYTotalExpensesAmt
# F9_01_PC_TOT_FNDR_EXP_CURR TotalFundrsngExpCurrentYear CYTotalFundraisingExpenseAmt
# F9_01_PC_TOT_INDIV_EMPLOYED TotalNbrEmployees TotalEmployeeCnt
# F9_01_PC_TOT_INDIV_VOLUNTEERS TotalNbrVolunteers TotalVolunteersCnt
# F9_01_PC_TOT_LIABILITIES_EOY TotalLiabilitiesEOYAmt TotalLiabilitiesEOY
# F9_01_PC_TOT_REVENUE_PRIOR PYTotalRevenueAmt TotalRevenuePriorYear
# F9_01_PC_TOT_UBI_GROSS TotalGrossUBIAmt TotalGrossUBI
# F9_01_PC_TOT_UBI_NET NetUnrelatedBusTxblIncmAmt NetUnrelatedBusinessTxblIncome
# F9_01_PC_VOTING_MEMB_GOV_BODY VotingMembersGoverningBodyCnt NbrVotingMembersGoverningBody
# F9_01_PZ_BEN_PAID_TO_MEMB_CURR BenefitsPaidToMembersCY CYBenefitsPaidToMembersAmt
# F9_01_PZ_GRANTS_PAID_CURR CYGrantsAndSimilarPaidAmt GrantsAndSimilarAmntsCY
# F9_01_PZ_INVEST_INCOME_CURR InvestmentIncomeCurrentYear CYInvestmentIncomeAmt
# F9_01_PZ_NAFB_EOY NetAssetsOrFundBalancesEOY NetAssetsOrFundBalancesEOYAmt
# F9_01_PZ_ORGANIZATIONAL_MISSION ActivityOrMissionDescription ActivityOrMissionDesc
# F9_01_PZ_OTHER_EXPENSE_CURR CYOtherExpensesAmt OtherExpensesCurrentYear
# F9_01_PZ_OTHER_REV_CURR CYOtherRevenueAmt OtherRevenueCurrentYear
# F9_01_PZ_PROG_SERVICE_REV_CURR CYProgramServiceRevenueAmt ProgramServiceRevenueCY
# F9_01_PZ_SALARIES_CURR SalariesEtcCurrentYear CYSalariesCompEmpBnftPaidAmt
# F9_01_PZ_SALARIES_PRIOR PYSalariesCompEmpBnftPaidAmt SalariesEtcPriorYear
# F9_01_PZ_TOT_ASSETS_BOY TotalAssetsBOY TotalAssetsBOYAmt
# F9_01_PZ_TOT_EXP_CURR TotalExpensesCurrentYear CYTotalExpensesAmt
# F9_01_PZ_TOT_LIAB_BOY TotalLiabilitiesBOY TotalLiabilitiesBOYAmt
# F9_01_PZ_TOT_REV_CURR TotalRevenueCurrentYear CYTotalRevenueAmt
# F9_03_PC_PGMSVC_SIGNIF_CHG SignificantChangeInd SignificantChange
# F9_03_PC_PGMSVC_SIGNIF_NEW SignificantNewProgramSrvcInd SignificantNewProgramServices
# F9_03_PC_PROG_SVC_ACC_1_CODE ActivityCode ActivityCd
# F9_03_PC_PROG_SVC_ACC_1_DESC Description Desc
# F9_03_PC_PROG_SVC_ACC_1_EXP Expense ExpenseAmt
# F9_03_PC_PROG_SVC_ACC_1_GRNT Grants GrantAmt
# F9_03_PC_PROG_SVC_ACC_1_REV Revenue RevenueAmt
# F9_03_PC_PROG_SVC_ACC_2_CODE Activity2 ProgSrvcAccomActy2Grp
# F9_03_PC_PROG_SVC_ACC_2_DESC Activity2 ProgSrvcAccomActy2Grp
# F9_03_PC_PROG_SVC_ACC_2_EXP Activity2 ProgSrvcAccomActy2Grp
# F9_03_PC_PROG_SVC_ACC_2_GRNT Activity2 ProgSrvcAccomActy2Grp
# F9_03_PC_PROG_SVC_ACC_2_REV Activity2 ProgSrvcAccomActy2Grp
# F9_03_PC_PROG_SVC_ACC_3_CODE Activity3 ProgSrvcAccomActy3Grp
# F9_03_PC_PROG_SVC_ACC_3_DESC Activity3 ProgSrvcAccomActy3Grp
# F9_03_PC_PROG_SVC_ACC_3_EXP Activity3 ProgSrvcAccomActy3Grp
# F9_03_PC_PROG_SVC_ACC_3_GRNT Activity3 ProgSrvcAccomActy3Grp
# F9_03_PC_PROG_SVC_ACC_3_REV Activity3 ProgSrvcAccomActy3Grp
# F9_03_PC_TOT_OTH_PROG_SVC_EXP TotalOfOtherProgramServiceExp TotalOtherProgSrvcExpenseAmt
# F9_03_PC_TOT_OTH_PROG_SVC_GRNT TotalOfOtherProgramServiceGrnt TotalOtherProgSrvcGrantAmt
# F9_03_PC_TOT_OTH_PROG_SVC_REV TotalOtherProgSrvcRevenueAmt TotalOfOtherProgramServiceRev
# F9_03_PC_TOT_PROG_SVC_EXPENSE TotalProgramServiceExpensesAmt TotalProgramServiceExpense
# F9_03_PZ_MISSION_DESCRIPTION MissionDescription MissionDesc
# F9_03_PZ_SCHEDULE_O_PART3 InfoInScheduleOPartIII InfoInScheduleOPartIIIInd
# F9_04_PC_ACTVITIES_VIA_PARTNER ActivitiesConductedPrtshpInd ActivitiesConductedPartnership
# F9_04_PC_CONTROLLED_ENTITY RelatedOrganizationCtrlEntInd RelatedOrgControlledEntity
# F9_04_PC_DISREGARDED_ENTITY DisregardedEntity DisregardedEntityInd
# F9_04_PC_EXCESS_BENEFIT_TRANS ExcessBenefitTransaction EngagedInExcessBenefitTransInd
# F9_04_PC_FR_EVENT_INC_GT_15K FundraisingActivities FundraisingActivitiesInd
# F9_04_PC_GAMING_INC_GT_15K Gaming GamingActivitiesInd
# F9_04_PC_LOBBYING_ACTIVITIES LobbyingActivities LobbyingActivitiesInd
# F9_04_PC_POLITICAL_ACTIVITIES PoliticalActivities PoliticalCampaignActyInd
# F9_04_PC_PRIOR_EXCESS_BEN_TRAN PriorExcessBenefitTransaction PYExcessBenefitTransInd
# F9_04_PC_PROF_FR_EXP_GT_15K ProfessionalFundraising ProfessionalFundraisingInd
# F9_04_PC_RELATED_ENTITY RelatedEntity RelatedEntityInd
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_04_PC_TRANS_TO_CNTRLD_ENT TrnsfrExmptNonChrtblRltdOrgInd TransfersToExemptNonChrtblOrg
# F9_04_PC_TRANS_WITH_CNTRLD_ENT TransactionWithControlEntInd TransactionRelatedEntity
# F9_05_EXP_SCHED_O_X InfoInScheduleOPartVInd InfoInScheduleOPartV
# F9_05_PC_NUMBER_EMPLOYEES_W3 EmployeeCnt NumberOfEmployees
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# F9_05_PC_NUMBER_FORMS_1096 NumberFormsTransmittedWith1096 IRPDocumentCnt
# F9_05_PC_UNRELATED_BUS_INCOME UnrelatedBusIncmOverLimitInd UnrelatedBusinessIncome
# F9_06_EXP_SCHED_O_X InfoInScheduleOPartVI InfoInScheduleOPartVIInd
# F9_06_PC_990_PROVIDED_GOV_BODY Form990ProvidedToGoverningBody Form990ProvidedToGvrnBodyInd
# F9_06_PC_ANNUAL_DISC_COVRD_PERS AnnualDisclosureCoveredPersons AnnualDisclosureCoveredPrsnInd
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_06_PC_CEO_COMPENSTN_PROCESS CompensationProcessCEOInd CompensationProcessCEO
# F9_06_PC_CHANGES_ORGANIZING_DOCS ChangeToOrgDocumentsInd ChangesToOrganizingDocs
# F9_06_PC_CONFLICT_OF_INTEREST ConflictOfInterestPolicyInd ConflictOfInterestPolicy
# F9_06_PC_DECISIONS_SUBJ_APPROVAL DecisionsSubjectToApproval DecisionsSubjectToApprovaInd
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_06_PC_DELEGATION_MGT_DUTIES DelegationOfMgmtDutiesInd DelegationOfManagementDuties
# F9_06_PC_DELEGATION_OF_MGT DelegationOfMgmtDutiesInd DelegationOfManagementDuties
# F9_06_PC_DOCUMENT_RET_POLICY DocumentRetentionPolicyInd DocumentRetentionPolicy
# F9_06_PC_ELECTION_BOARD_MEMBERS ElectionOfBoardMembersInd ElectionOfBoardMembers
# F9_06_PC_FAMILY_OR_BUSINESS_REL FamilyOrBusinessRelationship FamilyOrBusinessRlnInd
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# F9_06_PC_FORM_AVAIL_OWN_WEBSITE OwnWebsiteInd OwnWebsite
# F9_06_PC_FORM_UPON_REQUEST UponRequest UponRequestInd
# F9_06_PC_JOINT_VENTURE_INVESTMNT InvestmentInJointVenture InvestmentInJointVentureInd
# F9_06_PC_JOINT_VENTURE_POLICY WrittenPolicyOrProcedure WrittenPolicyOrProcedureInd
# F9_06_PC_LOCAL_CHAPTERS LocalChapters LocalChaptersInd
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# F9_06_PC_MATERIAL_DIVERSION MaterialDiversionOrMisuseInd MaterialDiversionOrMisuse
# F9_06_PC_MEMBERS_OR_STOCKHOLDERS MembersOrStockholders MembersOrStockholdersInd
# F9_06_PC_MINUTES_COMMITTEES MinutesOfCommitteesInd MinutesOfCommittees
# F9_06_PC_MINUTES_GOVERNING_BODY MinutesOfGoverningBody MinutesOfGoverningBodyInd
# F9_06_PC_MONITORING_OF_COI_POLICY RegularMonitoringEnfrcInd RegularMonitoringEnforcement
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_06_PC_NUM_IND_VOTING_MEMBERS NumberIndependentVotingMembers IndependentVotingMemberCnt
# F9_06_PC_NUM_VOTING_GOV_MEMBERS GoverningBodyVotingMembersCnt NbrVotingGoverningBodyMembers
# F9_06_PC_OFFICER_MAILING_ADDRESS OfficerMailingAddressInd OfficerMailingAddress
# F9_06_PC_OTHER_COMPENSTN_PROCESS CompensationProcessOtherInd CompensationProcessOther
# F9_06_PC_OTHER_WEBSITE OtherWebsite OtherWebsiteInd
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_06_PC_OWN_WEBSITE OwnWebsiteInd OwnWebsite
# F9_06_PC_POLICIES_GOVERN_CHAPTER PoliciesReferenceChapters PoliciesReferenceChaptersInd
# F9_06_PC_STATES_WHERE_RET_FILED StatesWhereCopyOfReturnIsFiled StatesWhereCopyOfReturnIsFldCd
# F9_06_PC_WHISTLEBLOWER_POLICY WhistleblowerPolicyInd WhistleblowerPolicy
# F9_07_EXP_SCHED_O_X InfoInScheduleOPartVII InfoInScheduleOPartVIIInd
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# F9_07_PC_COMPENSATION_OTHER_SRCE CompensationFromOtherSrcsInd CompensationFromOtherSources
# F9_07_PC_FORMER_OFFICER_LISTED FormersListed FormerOfcrEmployeesListedInd
# F9_07_PC_NO_LISTED_PERS_COMPENSD NoListedPersonsCompensatedInd NoListedPersonsCompensated
# F9_07_PC_NUM_CONTRCTRS_GRTR_100K NumberOfContractorsGT100K CntrctRcvdGreaterThan100KCnt
# F9_07_PC_NUM_INDS_GREATER_100K IndivRcvdGreaterThan100KCnt NumberIndividualsGT100K
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_07_PC_TOTAL_COMP_GRTR_150K TotalCompGT150K TotalCompGreaterThan150KInd
# F9_07_PC_TOT_OTHER_COMPENSATION TotalOtherCompensationAmt TotalOtherCompensation
# F9_07_PC_TOT_REPRT_COMP_FROM_ORG TotalReportableCompFromOrg TotalReportableCompFromOrgAmt
# F9_07_PC_TOT_REPRT_COMP_RLTD_ORG TotReportableCompRltdOrgAmt TotalReportableCompFrmRltdOrgs
# F9_08_EXP_SCHED_O_X InfoInScheduleOPartVIIIInd InfoInScheduleOPartVIII
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# F9_08_PC_ALL_OTHER_CONTRIBUTIONS AllOtherContributionsAmt AllOtherContributions
# F9_08_PC_CONTS_REPRTD_FNDRAISNG CntrbtnsRprtdFundraisingEvents ContriRptFundraisingEventAmt
# F9_08_PC_COST_OF_GOODS_SOLD CostOfGoodsSold CostOfGoodsSoldAmt
# F9_08_PC_FEDERATED_CAMPAIGNS FederatedCampaigns FederatedCampaignsAmt
# F9_08_PC_FUNDRAISING_DIRECT_EXP FundraisingDirectExpensesAmt FundraisingDirectExpenses
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# F9_08_PC_FUNDRAISING_EVENTS FundraisingAmt FundraisingEvents
# F9_08_PC_FUNDRAISING_GROSS_INC FundraisingGrossIncomeAmt GrossIncomeFundraisingEvents
# F9_08_PC_GAMING_DIRECT_EXPENSES GamingDirectExpenses GamingDirectExpensesAmt
# F9_08_PC_GAMING_GROSS_INCOME GrossIncomeGaming GamingGrossIncomeAmt
# F9_08_PC_GOVERNMENT_GRANTS GovernmentGrantsAmt GovernmentGrants
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_08_PC_GROSS_SALES_INVENTORY GrossSalesOfInventory GrossSalesOfInventoryAmt
# F9_08_PC_MEMBERSHIP_DUES MembershipDues MembershipDuesAmt
# F9_08_PC_NONCASH_CONTRIBUTIONS NoncashContributions NoncashContributionsAmt
# F9_08_PC_PROGRAM_SVCE_REV_TOTAL TotalProgramServiceRevenueAmt TotalProgramServiceRevenue
# F9_08_PC_RELATED_ORGANIZATIONS RelatedOrganizations RelatedOrganizationsAmt
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_08_PC_TOTAL_CONTRIBUTIONS TotalContributions TotalContributionsAmt
# F9_08_PC_TOTAL_OTHER_REVENUE OtherRevenueTotalAmt TotalOtherRevenue
# F9_08_PC_TOTAL_PROG_SVCE_REVENUE TotalProgramServiceRevenueAmt TotalProgramServiceRevenue
# F9_08_PC_TOTAL_REVENUE TotalRevenueGrp TotalRevenue
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_09_EXP_AD_PROMO_TOT AdvertisingGrp Advertising
# F9_09_EXP_BENF_PAID_MEMB_TOT BenefitsToMembersGrp BenefitsToMembers
# F9_09_EXP_CONF_MEETING_TOT ConferencesMeetings ConferencesMeetingsGrp
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_09_EXP_DEPREC_FUNDR DepreciationDepletionGrp DepreciationDepletion
# F9_09_EXP_DEPREC_MAG DepreciationDepletionGrp DepreciationDepletion
# F9_09_EXP_DEPREC_PROG DepreciationDepletionGrp DepreciationDepletion
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# F9_09_EXP_DEPREC_TOT DepreciationDepletionGrp DepreciationDepletion
# F9_09_EXP_GRANT_FRGN_TOT ForeignGrants ForeignGrantsGrp
# F9_09_EXP_GRANT_INDIV_DMSTC_TOT GrantsToDomesticIndividuals GrantsToDomesticIndividualsGrp
# F9_09_EXP_GRANT_ORG_DMSTC_TOT GrantsToDomesticOrgs GrantsToDomesticOrgsGrp
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_09_EXP_INFO_TECH_TOT InformationTechnology InformationTechnologyGrp
# F9_09_EXP_INSURANCE_TOT InsuranceGrp Insurance
# F9_09_EXP_INTEREST_TOT InterestGrp Interest
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_09_EXP_JOINT_COSTS_TOT TotalJointCostsGrp TotalJointCosts
# F9_09_EXP_OCCUPANCY_TOT OccupancyGrp Occupancy
# F9_09_EXP_OFFICE_TOT OfficeExpenses OfficeExpensesGrp
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# F9_09_EXP_OTH_OTH_TOT AllOtherExpenses AllOtherExpensesGrp
# ...
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_10_PC_INVEST_PROG_RELTD_EOY InvestmentsProgramRelated InvestmentsProgramRelatedGrp
# F9_10_PC_INVEST_PUB_TRADED_EOY InvestmentsPubTradedSecGrp InvestmentsPubTradedSecurities
# F9_10_PC_LAND_BLDG_EQPMT LandBldgEquipCostOrOtherBssAmt LandBuildingsEquipmentBasis
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN LandBldgEquipAccumDeprecAmt LandBldgEquipmentAccumDeprec
# F9_10_PC_LOANS_FROM_OFFICERS_EOY LoansFromOfficersDirectorsGrp LoansFromOfficersDirectors
# F9_10_PC_ORG_FOLLOWS_SFAS117 OrganizationFollowsSFAS117Ind FollowSFAS117
# F9_10_PC_ORG_NOT_FOLLOW_SFAS117 DoNotFollowSFAS117 OrgDoesNotFollowSFAS117Ind
# F9_10_PC_OTHER_LIABILITIES_EOY OtherLiabilities OtherLiabilitiesGrp
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# F9_10_PC_RET_EARNINGS_ENDWMT_EOY RtnEarnEndowmentIncmOthFndsGrp RetainedEarningsEndowmentEtc
# F9_10_PC_SAVINGS_TEMP_INVEST_BOY SavingsAndTempCashInvestments SavingsAndTempCashInvstGrp
# F9_10_PC_SAVINGS_TEMP_INVEST_EOY SavingsAndTempCashInvestments SavingsAndTempCashInvstGrp
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# F9_10_PC_SECURED_MORTGAGES_EOY MortgNotesPyblScrdInvstPropGrp MortNotesPyblSecuredInvestProp
# F9_10_PC_SECURE_MORT_NOTES_EOY MortgNotesPyblScrdInvstPropGrp MortNotesPyblSecuredInvestProp
# F9_10_PC_UNSECURED_LOANS_EOY UnsecuredNotesLoansPayable UnsecuredNotesLoansPayableGrp
# F9_10_PC_UNSECURED_NOTES_BOY UnsecuredNotesLoansPayable UnsecuredNotesLoansPayableGrp
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# F9_10_PC_UNSECURED_NOTES_EOY UnsecuredNotesLoansPayable UnsecuredNotesLoansPayableGrp
# F9_10_PZ_TOTAL_ASSETS_EOY TotalAssets TotalAssetsGrp
# F9_10_SCHED_O_X InfoInScheduleOPartXInd InfoInScheduleOPartX
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_11_PC_RECNCLTN_DONATED_SVCES ReconcilationDonatedServices DonatedServicesAndUseFcltsAmt
# F9_11_PC_RECNCLTN_INVSTMNT_EXP ReconcilationInvestExpenses InvestmentExpenseAmt
# F9_11_PC_RECNCLTN_PRIOR_PER_ADJ ReconcilationPriorAdjustment PriorPeriodAdjustmentsAmt
# F9_11_PC_RECNCLTN_REV_LESS_EXP ReconcilationRevenueExpnssAmt ReconcilationRevenueExpenses
# F9_11_PC_RECNCLTN_UNRLZD_GAIN NetUnrlzdGainsLossesInvstAmt ReconciliationUnrealizedInvest
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# F9_11_SCHED_O_X InfoInScheduleOPartXIInd InfoInScheduleOPartXI
# F9_12_PC_ACCNT_COMPILE_OR_REVIEW AccountantCompileOrReview AccountantCompileOrReviewInd
# F9_12_PC_ACCTG_METHOD_ACCRUAL MethodOfAccountingAccrualInd MethodOfAccountingAccrual
# F9_12_PC_ACCTG_METHOD_CASH MethodOfAccountingCash MethodOfAccountingCashInd
# F9_12_PC_ACCTG_METHOD_OTHER MethodOfAccountingOther MethodOfAccountingOtherInd
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var2].notnull(), df[var2], np.NaN)
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)
# F9_12_PC_AUDIT_COMMITTEE AuditCommitteeInd AuditCommittee
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD FederalGrantAuditPerformed FederalGrantAuditPerformedInd
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED FederalGrantAuditRequiredInd FederalGrantAuditRequired
# F9_12_PC_FINCL_STMTS_AUDITED FSAudited FSAuditedInd
# F9_12_SCHED_O_X InfoInScheduleOPartXIIInd InfoInScheduleOPartXII
# number_of_other_prog_svces ProgSrvcAccomActyOtherGrp ActivityOther
# []
# CPU times: total: 18.1 s
# Wall time: 21.3 s
# C:\Users\Gregory\AppData\Local\Temp\ipykernel_114372\1728140477.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newvar] = np.where(df[var1].notnull(), df[var1], np.NaN)

# %% [markdown]
# # New Way to Combine Columns
# The improvements include:
#
# Using combine_first() which is pandas' built-in method for this exact use case
# Handling cases where one or both columns might not exist in the dataframe
# More informative error reporting that captures both the variable name and the specific error
# Returning both the updated dataframe and a list of failures
# Adding better progress reporting
#
# This approach should be faster than your original version since it avoids the repeated function calls in a loop. It also handles edge cases more gracefully and provides better diagnostics if something goes wrong.

# %%
def prepare_for_save(df):
    """Safely prepare a large DataFrame for disk write without restarting the kernel."""
    print("🧼 Copying DataFrame to clear cached views...")
    df_clean = df.copy()

    print("🧹 Running garbage collection...")
    gc.collect()

    print("✅ Frame is cleaned and ready to save.")
    return df_clean

# %%
import gc
gc.collect()
# Out:
# 1273

# %%
# %%time
# Step 2: Clean any lazy eval or .head() artifacts
#df_clean = prepare_for_save(df)
# Out:
# 🧼 Copying DataFrame to clear cached views...
# 🧹 Running garbage collection...
# ✅ Frame is cleaned and ready to save.
# CPU times: total: 18.2 s
# Wall time: 21.2 s

# %%
#del df_clean

# %%
# Vectorized version that processes all variables at once
def combine_all_variables(df, mapping_df):
    """
    Process all variable combinations at once without looping
    
    Parameters:
    -----------
    df: pandas DataFrame
        The main dataframe with data
    mapping_df: pandas DataFrame 
        DataFrame with variable mappings (new_variables_df)
        
    Returns:
    --------
    tuple: (updated_df, failed_variables)
    """
    # Work on a copy to avoid unexpected side effects
    result_df = df.copy()
    failed_vars = []
    
    # Filter for len=2 rows
    to_combine = mapping_df[mapping_df['len']==2]
    
    for _, row in to_combine.iterrows():
        new_var = row['variable_name_new']
        var1, var2 = row['original_names'][0], row['original_names'][1]
        
        try:
            # Check if both columns exist in the dataframe
            if var1 in df.columns and var2 in df.columns:
                # Combine the columns
                result_df[new_var] = df[var1].combine_first(df[var2])
                
                # Alternative using numpy for potential performance improvement
                # result_df[new_var] = np.where(df[var1].notnull(), df[var1], df[var2])
            
            # If only the first column exists
            elif var1 in df.columns:
                result_df[new_var] = df[var1]
                
            # If only the second column exists
            elif var2 in df.columns:
                result_df[new_var] = df[var2]
                
            else:
                # Neither column exists
                failed_vars.append((new_var, "Columns not found"))
                continue
                
            # Add debugging stats if needed
            # print(f"Created {new_var}: {result_df[new_var].notna().sum()} non-null values")
            
        except Exception as e:
            print(f"\n***********Issue with variable: {new_var}, Error: {str(e)}")
            failed_vars.append((new_var, str(e)))
    
    return result_df, failed_vars

# %% [markdown]
# #### Try this version next time instead to avert `PerformanceWarning`

# %%
def combine_all_variables(df, mapping_df):
    """
    Optimized version that avoids DataFrame fragmentation by creating 
    all columns at once
    """
    # Work on a copy to avoid unexpected side effects
    result_df = df.copy()
    
    # Filter for len=2 rows
    to_combine = mapping_df[mapping_df['len']==2]
    
    # Create a dictionary to store all new columns
    new_columns = {}
    failed_vars = []
    
    for _, row in to_combine.iterrows():
        new_var = row['variable_name_new']
        var1, var2 = row['original_names'][0], row['original_names'][1]
        
        try:
            # Check if both columns exist in the dataframe
            if var1 in df.columns and var2 in df.columns:
                # Store the combined column in the dictionary
                new_columns[new_var] = df[var1].combine_first(df[var2])
            
            # If only the first column exists
            elif var1 in df.columns:
                new_columns[new_var] = df[var1]
                
            # If only the second column exists
            elif var2 in df.columns:
                new_columns[new_var] = df[var2]
                
            else:
                # Neither column exists
                failed_vars.append((new_var, "Columns not found"))
                
        except Exception as e:
            print(f"\n***********Issue with variable: {new_var}, Error: {str(e)}")
            failed_vars.append((new_var, str(e)))
    
    # Create a DataFrame with all the new columns
    new_columns_df = pd.DataFrame(new_columns, index=df.index)
    
    # Combine with the original DataFrame
    result_df = pd.concat([result_df, new_columns_df], axis=1)
    
    return result_df, failed_vars

# %%
# %%time
# Use the improved function
updated_df, failed_variables = combine_all_variables(df, new_variables_df)

# Report on results
print(f"Successfully combined {len(new_variables_df[new_variables_df['len']==2]) - len(failed_variables)} variables")
if failed_variables:
    print("\nFailed variables:")
    for var, reason in failed_variables:
        print(f"- {var}: {reason}")
# Out:
# Successfully combined 279 variables
# CPU times: total: 3min 52s
# Wall time: 4min 1s

# %%
failed_variables
# Out:
# []

# %%
updated_df[:1]
# Out:
#                         _id  \
# 0  5d019e6778ffca27b42818d7
#
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
#
#               DLN TaxPeriod AddressChange NameOfPrincipalOfficerPerson  \
# 0  93493313013011    201012             X                MICHAEL ANTON
#
#   GrossReceipts GroupReturnForAffiliates Organization501c3 WebSite  \
# 0       1473903                        0                 X     N/A
#
#   TypeOfOrganizationCorporation YearFormation StateLegalDomicile  \
# 0                             X          1992                 PA
#
#                                                                ActivityOrMissionDescription  \
# 0  MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
#
#   NbrVotingMembersGoverningBody NbrIndependentVotingMembers TotalNbrEmployees  \
# 0                            10                          10                 0
#
#   TotalNbrVolunteers TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 0                  0             0                              0
#
#   ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 0                      1044925                        1439340
#
#   ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 0                              0                       0
#
#   InvestmentIncomePriorYear InvestmentIncomeCurrentYear OtherRevenuePriorYear  \
# 0                     30447                       33563                     0
#
#   OtherRevenueCurrentYear TotalRevenuePriorYear TotalRevenueCurrentYear  \
# 0                    1000               1075372                 1473903
#
#   GrantsAndSimilarAmntsPriorYear GrantsAndSimilarAmntsCY  \
# 0                         638637                  925000
#
#   BenefitsPaidToMembersPriorYear BenefitsPaidToMembersCY SalariesEtcPriorYear  \
# 0                              0                       0                    0
#
#   SalariesEtcCurrentYear TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 0                      0                             0                      0
#
#   TotalFundrsngExpCurrentYear OtherExpensePriorYear OtherExpensesCurrentYear  \
# 0                      195892                243131                   459751
#
#   TotalExpensesPriorYear TotalExpensesCurrentYear  \
# 0                 881768                  1384751
#
#   RevenuesLessExpensesPriorYear RevenuesLessExpensesCY TotalAssetsBOY  \
# 0                        193604                  89152        1925215
#
#   TotalAssetsEOY TotalLiabilitiesBOY TotalLiabilitiesEOY  \
# 0        2440859              171810              450430
#
#   NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesEOY  \
# 0                    1753405                    1990429
#
#   InfoInScheduleOPartIII  \
# 0                      X
#
#                                                                                                                                                                                                                                           MissionDescription  \
# 0  THE CORPORATION IS ORGANIZED AND WILL BE OPERATED EXCLUSIVELY FOR CHARITABLE, EDUCATIONAL AND SCIENTIFIC PURPOSES WITHIN THE MEANING OF SECTION 501(C)(3) OF THE INTERNAL REVENUE CODE. SUCH PURPOSES SHALL BE LIMITED TO PROVIDING SUPPORT AND FUNDIN...
#
#   SignificantNewProgramServices SignificantChange  Expense  Grants  \
# 0                             0                 0  1043744  925000
#
#                                                                                                                                                                                                                                                  Description  \
# 0  RMHC OF THE PHILADELPHIA REGION, INC. GRANTS HUNDREDS OF THOUSANDS OF DOLLARS PER YEAR TO SUPPORT NON-PROFIT PROGRAMS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN. LOCALLY, RMHC SUPPORTS THE PHILADELPHIA, SOUTHERN NEW JERSEY AND DE...
#
#   TotalProgramServiceExpense PoliticalActivities LobbyingActivities  \
# 0                    1043744                 "0"                "0"
#
#   ProfessionalFundraising FundraisingActivities Gaming  \
# 0                     "0"                   "0"    "0"
#
#   ExcessBenefitTransaction PriorExcessBenefitTransaction DisregardedEntity  \
# 0                      "0"                           "0"               "0"
#
#   RelatedEntity RelatedOrgControlledEntity TransactionRelatedEntity  \
# 0           "0"                        "0"                      "0"
#
#   TransfersToExemptNonChrtblOrg ActivitiesConductedPartnership  \
# 0                           "0"                            "0"
#
#   NumberFormsTransmittedWith1096 NumberOfEmployees UnrelatedBusinessIncome  \
# 0                              0                 0                       0
#
#   InfoInScheduleOPartVI NbrVotingGoverningBodyMembers  \
# 0                     X                            10
#
#   NumberIndependentVotingMembers FamilyOrBusinessRelationship  \
# 0                             10                            0
#
#   DelegationOfManagementDuties ChangesToOrganizingDocs  \
# 0                            0                       0
#
#   MaterialDiversionOrMisuse MembersOrStockholders ElectionOfBoardMembers  \
# 0                         0                     0                      0
#
#   DecisionsSubjectToApproval MinutesOfGoverningBody MinutesOfCommittees  \
# 0                          0                      1                   1
#
#   OfficerMailingAddress LocalChapters Form990ProvidedToGoverningBody  \
# 0                     0             0                              1
#
#   ConflictOfInterestPolicy AnnualDisclosureCoveredPersons  \
# 0                        1                              1
#
#   RegularMonitoringEnforcement WhistleblowerPolicy DocumentRetentionPolicy  \
# 0                            1                   0                       0
#
#   CompensationProcessCEO CompensationProcessOther InvestmentInJointVenture  \
# 0                      0                        0                        0
#
#   StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 0             ["PA", "NJ", "DE"]           X                          X
#
#   TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 0                          0                              0
#
#   TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 0                      0                       0             0
#
#   TotalCompGT150K CompensationFromOtherSources NumberOfContractorsGT100K  \
# 0               0                            0                         0
#
#   AllOtherContributions TotalContributions TotalOtherRevenue  \
# 0               1439340            1439340              1000
#
#                                                                                                                               TotalRevenue  \
# 0  {"TotalRevenueColumn": "1473903", "RelatedOrExemptFunctionIncome": "1000", "UnrelatedBusinessRevenue": "0", "ExclusionAmount": "33563"}
#
#                                GrantsToDomesticOrgs  \
# 0  {"Total": "892000", "ProgramServices": "892000"}
#
#                       GrantsToDomesticIndividuals  \
# 0  {"Total": "33000", "ProgramServices": "33000"}
#
#                               FeesForServicesLegal  \
# 0  {"Total": "215", "ManagementAndGeneral": "215"}
#
#                              FeesForServicesAccounting  \
# 0  {"Total": "21675", "ManagementAndGeneral": "21675"}
#
#                                     OfficeExpenses  \
# 0  {"Total": "123", "ManagementAndGeneral": "123"}
#
#                                PaymentsToAffiliates  \
# 0  {"Total": "118744", "ProgramServices": "118744"}
#
#                                  DepreciationDepletion  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
#
#                                                                                                                                                                                                                                                OtherExpenses  \
# 0  [{"Description": "FUNDRAISING COSTS", "Total": "108311", "Fundraising": "108311"}, {"Description": "CANISTER COLLECTION FEE", "Total": "81925", "Fundraising": "81925"}, {"Description": "PR/ADMINISTRATIVE SERVI", "Total": "34517", "ManagementAndGe...
#
#                                   AllOtherExpenses  \
# 0  {"Total": "763", "ManagementAndGeneral": "763"}
#
#                                                                                          TotalFunctionalExpenses  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
#
#         SavingsAndTempCashInvestments                  AccountsReceivable  \
# 0  {"BOY": "332660", "EOY": "270700"}  {"BOY": "103412", "EOY": "147981"}
#
#   LandBuildingsEquipmentBasis LandBldgEquipmentAccumDeprec  \
# 0                      256845                        86228
#
#   LandBuildingsEquipmentBasisNet            InvestmentsOtherSecurities  \
# 0  {"BOY": "0", "EOY": "170617"}  {"BOY": "1489143", "EOY": "1851561"}
#
#                             TotalAssets    AccountsPayableAccruedExpenses  \
# 0  {"BOY": "1925215", "EOY": "2440859"}  {"BOY": "39670", "EOY": "44353"}
#
#                        GrantsPayable                   OtherLiabilities  \
# 0  {"BOY": "80500", "EOY": "166000"}  {"BOY": "51640", "EOY": "240077"}
#
#   FollowSFAS117                 UnrestrictedNetAssets InfoInScheduleOPartXI  \
# 0             X  {"BOY": "1753405", "EOY": "1990429"}                     X
#
#   ReconcilationRevenueExpenses InfoInScheduleOPartXII  \
# 0                        89152                      X
#
#   MethodOfAccountingAccrual AccountantCompileOrReview FSAudited  \
# 0                         X                         0         1
#
#   AuditCommittee FederalGrantAuditRequired AllAffiliatesIncluded  \
# 0              1                         0                  None
#
#   GroupExemptionNumber Revenue PoliciesReferenceChapters  \
# 0                 None    None                      None
#
#   WrittenPolicyOrProcedure TotalProgramServiceRevenue ForeignGrants  \
# 0                     None                       None          None
#
#   BenefitsToMembers CompCurrentOfficersDirectors CompDisqualPersons  \
# 0              None                         None               None
#
#   OtherSalariesAndWages PensionPlanContributions OtherEmployeeBenefits  \
# 0                  None                     None                  None
#
#   PayrollTaxes FeesForServicesManagement FeesForServicesLobbying  \
# 0         None                      None                    None
#
#   F9_09_PC_FEES_FOR_SVCE_FR_TOT FeesForServicesInvstMgmntFees  \
# 0                          None                          None
#
#   FeesForServicesOther Advertising InformationTechnology Royalties Occupancy  \
# 0                 None        None                  None      None      None
#
#   Travel TravelEntrtnmntPublicOfficials ConferencesMeetings Interest  \
# 0   None                           None                None     None
#
#   Insurance CashNonInterestBearing PledgesAndGrantsReceivable  \
# 0      None                   None                       None
#
#   ReceivablesFromDisqualPersons OtherNotesLoansReceivableNet  \
# 0                          None                         None
#
#   InventoriesForSaleOrUse PrepaidExpensesDeferredCharges  \
# 0                    None                           None
#
#   InvestmentsPubTradedSecurities InvestmentsProgramRelated IntangibleAssets  \
# 0                           None                      None             None
#
#   OtherAssetsTotal DeferredRevenue MortNotesPyblSecuredInvestProp  \
# 0             None            None                           None
#
#   FederalGrantAuditPerformed LoansFromOfficersDirectors  \
# 0                       None                       None
#
#   MethodOfAccountingCash Activity2 Activity3 InfoInScheduleOPartVII  \
# 0                   <NA>      None      None                   <NA>
#
#   TaxExemptBondLiabilities TemporarilyRestrictedNetAssets OtherWebsite  \
# 0                     None                           None         <NA>
#
#   PermanentlyRestrictedNetAssets FundraisingEvents  \
# 0                           None              None
#
#   CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 0                           None                 None
#
#   GrossIncomeFundraisingEvents FundraisingDirectExpenses FederatedCampaigns  \
# 0                         None                      None               None
#
#   GovernmentGrants MethodOfAccountingOther GrossSalesOfInventory  \
# 0             None                    <NA>                  None
#
#   CostOfGoodsSold DoNotFollowSFAS117 RetainedEarningsEndowmentEtc  \
# 0            None               <NA>                         None
#
#   InitialReturn MembershipDues GrossIncomeGaming GamingDirectExpenses  \
# 0          <NA>           None              None                 None
#
#   NoncashContributions InfoInScheduleOPartV OwnWebsite  \
# 0                 None                 <NA>       <NA>
#
#   UnsecuredNotesLoansPayable ActivityOther TotalOfOtherProgramServiceExp  \
# 0                       None          None                          None
#
#   TotalOfOtherProgramServiceRev EscrowAccountLiability  \
# 0                          None                   None
#
#   TotalOfOtherProgramServiceGrnt TypeOfOrganizationOther Organization501c  \
# 0                           None                    <NA>             <NA>
#
#   TypeOfOrganizationTrust TypeOfOrganizationAssociation CountryLegalDomicile  \
# 0                    <NA>                          <NA>                 None
#
#   AmendedReturn TypeOfOrgOtherDescription TotalJointCosts TerminatedReturn  \
# 0          <NA>                      None            None             <NA>
#
#   TerminationOrContraction ActivityCode SpecialConditionDescription  \
# 0                     <NA>         None                        None
#
#   Organization4947a1 InfoInScheduleOPartIX ReconciliationUnrealizedInvest  \
# 0               <NA>                  <NA>                           None
#
#   ReconcilationPriorAdjustment ReconcilationDonatedServices  \
# 0                         None                         None
#
#   ReconcilationInvestExpenses InfoInScheduleOPartVIII InfoInScheduleOPartX  \
# 0                        None                    <NA>                 <NA>
#
#   PrincipalOfficerNm GrossReceiptsAmt GroupReturnForAffiliatesInd  \
# 0               None             None                        None
#
#   Organization501c3Ind TypeOfOrganizationCorpInd FormationYr  \
# 0                 <NA>                      <NA>        None
#
#   LegalDomicileStateCd ActivityOrMissionDesc VotingMembersGoverningBodyCnt  \
# 0                 None                  None                          None
#
#   VotingMembersIndependentCnt TotalEmployeeCnt TotalGrossUBIAmt  \
# 0                        None             None             None
#
#   CYContributionsGrantsAmt CYProgramServiceRevenueAmt CYInvestmentIncomeAmt  \
# 0                     None                       None                  None
#
#   CYOtherRevenueAmt CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 0              None              None                      None
#
#   CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 0                       None                         None
#
#   CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt CYOtherExpensesAmt  \
# 0                       None                         None               None
#
#   CYTotalExpensesAmt CYRevenuesLessExpensesAmt TotalAssetsBOYAmt  \
# 0               None                      None              None
#
#   TotalAssetsEOYAmt TotalLiabilitiesEOYAmt NetAssetsOrFundBalancesBOYAmt  \
# 0              None                   None                          None
#
#   NetAssetsOrFundBalancesEOYAmt InfoInScheduleOPartIIIInd MissionDesc  \
# 0                          None                      <NA>        None
#
#   SignificantNewProgramSrvcInd SignificantChangeInd  Desc  \
# 0                         None                 None  None
#
#   PoliticalCampaignActyInd LobbyingActivitiesInd ProfessionalFundraisingInd  \
# 0                     None                  None                       None
#
#   FundraisingActivitiesInd GamingActivitiesInd EngagedInExcessBenefitTransInd  \
# 0                     None                None                           None
#
#   PYExcessBenefitTransInd DisregardedEntityInd RelatedEntityInd  \
# 0                    None                 None             None
#
#   RelatedOrganizationCtrlEntInd TransactionWithControlEntInd  \
# 0                          None                         None
#
#   TrnsfrExmptNonChrtblRltdOrgInd ActivitiesConductedPrtshpInd IRPDocumentCnt  \
# 0                           None                         None           None
#
#   EmployeeCnt UnrelatedBusIncmOverLimitInd GoverningBodyVotingMembersCnt  \
# 0        None                         None                          None
#
#   IndependentVotingMemberCnt FamilyOrBusinessRlnInd DelegationOfMgmtDutiesInd  \
# 0                       None                   None                      None
#
#   ChangeToOrgDocumentsInd MaterialDiversionOrMisuseInd  \
# 0                    None                         None
#
#   MembersOrStockholdersInd ElectionOfBoardMembersInd  \
# 0                     None                      None
#
#   DecisionsSubjectToApprovaInd MinutesOfGoverningBodyInd  \
# 0                         None                      None
#
#   MinutesOfCommitteesInd OfficerMailingAddressInd LocalChaptersInd  \
# 0                   None                     None             None
#
#   Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 0                         None                        None
#
#   WhistleblowerPolicyInd DocumentRetentionPolicyInd CompensationProcessCEOInd  \
# 0                   None                       None                      None
#
#   CompensationProcessOtherInd InvestmentInJointVentureInd  \
# 0                        None                        None
#
#   StatesWhereCopyOfReturnIsFldCd NoListedPersonsCompensatedInd  \
# 0                           None                          <NA>
#
#   FormerOfcrEmployeesListedInd TotalCompGreaterThan150KInd  \
# 0                         None                        None
#
#   CompensationFromOtherSrcsInd MembershipDuesAmt FundraisingAmt  \
# 0                         None              None           None
#
#   AllOtherContributionsAmt TotalContributionsAmt OtherRevenueTotalAmt  \
# 0                     None                  None                 None
#
#   TotalRevenueGrp FeesForServicesAccountingGrp OfficeExpensesGrp  \
# 0            None                         None              None
#
#   InformationTechnologyGrp ConferencesMeetingsGrp InsuranceGrp  \
# 0                     None                   None         None
#
#   OtherExpensesGrp AllOtherExpensesGrp TotalFunctionalExpensesGrp  \
# 0             None                None                       None
#
#   CashNonInterestBearingGrp TotalAssetsGrp OrgDoesNotFollowSFAS117Ind  \
# 0                      None           None                       <NA>
#
#   RtnEarnEndowmentIncmOthFndsGrp ReconcilationRevenueExpnssAmt  \
# 0                           None                          None
#
#   MethodOfAccountingCashInd AccountantCompileOrReviewInd FSAuditedInd  \
# 0                      <NA>                         None         None
#
#   FederalGrantAuditRequiredInd WebsiteAddressTxt TotalVolunteersCnt  \
# 0                         None              None               None
#
#   NetUnrelatedBusTxblIncmAmt PYContributionsGrantsAmt  \
# 0                       None                     None
#
#   PYProgramServiceRevenueAmt PYInvestmentIncomeAmt PYOtherRevenueAmt  \
# 0                       None                  None              None
#
#   PYTotalRevenueAmt PYGrantsAndSimilarPaidAmt PYBenefitsPaidToMembersAmt  \
# 0              None                      None                       None
#
#   PYSalariesCompEmpBnftPaidAmt PYTotalProfFndrsngExpnsAmt PYOtherExpensesAmt  \
# 0                         None                       None               None
#
#   PYTotalExpensesAmt PYRevenuesLessExpensesAmt TotalLiabilitiesBOYAmt  \
# 0               None                      None                   None
#
#   ExpenseAmt GrantAmt RevenueAmt ProgSrvcAccomActy2Grp ProgSrvcAccomActy3Grp  \
# 0       None     None       None                  None                  None
#
#   ProgSrvcAccomActyOtherGrp TotalOtherProgSrvcGrantAmt  \
# 0                      None                       None
#
#   TotalProgramServiceExpensesAmt InfoInScheduleOPartVIInd  \
# 0                           None                     <NA>
#
#   AnnualDisclosureCoveredPrsnInd RegularMonitoringEnfrcInd UponRequestInd  \
# 0                           None                      None           <NA>
#
#   TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 0                          None                        None
#
#   TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 0                      None                        None
#
#   CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 0                         None                None
#
#   TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 0                          None                      None
#
#   ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 0                         None                         None
#
#   GrossSalesOfInventoryAmt CostOfGoodsSoldAmt GrantsToDomesticIndividualsGrp  \
# 0                     None               None                           None
#
#   CompCurrentOfcrDirectorsGrp OtherSalariesAndWagesGrp  \
# 0                        None                     None
#
#   PensionPlanContributionsGrp OtherEmployeeBenefitsGrp PayrollTaxesGrp  \
# 0                        None                     None            None
#
#   FeesForServicesOtherGrp AdvertisingGrp TravelGrp InterestGrp  \
# 0                    None           None      None        None
#
#   DepreciationDepletionGrp SavingsAndTempCashInvstGrp AccountsReceivableGrp  \
# 0                     None                       None                  None
#
#   InventoriesForSaleOrUseGrp PrepaidExpensesDefrdChargesGrp  \
# 0                       None                           None
#
#   LandBldgEquipCostOrOtherBssAmt LandBldgEquipAccumDeprecAmt  \
# 0                           None                        None
#
#   LandBldgEquipBasisNetGrp InvestmentsOtherSecuritiesGrp IntangibleAssetsGrp  \
# 0                     None                          None                None
#
#   AccountsPayableAccrExpnssGrp DeferredRevenueGrp  \
# 0                         None               None
#
#   MortgNotesPyblScrdInvstPropGrp OtherLiabilitiesGrp  \
# 0                           None                None
#
#   OrganizationFollowsSFAS117Ind UnrestrictedNetAssetsGrp  \
# 0                          <NA>                     None
#
#   TemporarilyRstrNetAssetsGrp InfoInScheduleOPartXIInd  \
# 0                        None                     <NA>
#
#   NetUnrlzdGainsLossesInvstAmt InfoInScheduleOPartXIIInd AuditCommitteeInd  \
# 0                         None                      <NA>              None
#
#   AllAffiliatesIncludedInd GrantsToDomesticOrgsGrp ForeignGrantsGrp  \
# 0                     None                    None             None
#
#   BenefitsToMembersGrp CompDisqualPersonsGrp FeesForServicesManagementGrp  \
# 0                 None                  None                         None
#
#   FeesForServicesLegalGrp FeesForServicesLobbyingGrp  \
# 0                    None                       None
#
#   FeesForSrvcInvstMgmntFeesGrp RoyaltiesGrp OccupancyGrp  \
# 0                         None         None         None
#
#   PymtTravelEntrtnmntPubOfclGrp PaymentsToAffiliatesGrp  \
# 0                          None                    None
#
#   PledgesAndGrantsReceivableGrp RcvblFromDisqualifiedPrsnGrp  \
# 0                          None                         None
#
#   OthNotesLoansReceivableNetGrp InvestmentsPubTradedSecGrp  \
# 0                          None                       None
#
#   InvestmentsProgramRelatedGrp OtherAssetsTotalGrp  \
# 0                         None                None
#
#   TotalOtherProgSrvcExpenseAmt InfoInScheduleOPartVInd  \
# 0                         None                    <NA>
#
#   MethodOfAccountingAccrualInd NoncashContributionsAmt GrantsPayableGrp  \
# 0                         <NA>                    None             None
#
#   PermanentlyRstrNetAssetsGrp TaxExemptBondLiabilitiesGrp  \
# 0                        None                        None
#
#   EscrowAccountLiabilityGrp LoansFromOfficersDirectorsGrp  \
# 0                      None                          None
#
#   UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 0                          None                      None
#
#   FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd OtherWebsiteInd  \
# 0                          None                         None            <NA>
#
#   AddressChangeInd WrittenPolicyOrProcedureInd RelatedOrganizationsAmt  \
# 0             <NA>                        None                    None
#
#   TotalOtherProgSrvcRevenueAmt OwnWebsiteInd TotalJointCostsGrp  \
# 0                         None          <NA>               None
#
#   DonatedServicesAndUseFcltsAmt LegalDomicileCountryCd  \
# 0                          None                   None
#
#   InfoInScheduleOPartIXInd TypeOfOrganizationTrustInd FinalReturnInd  \
# 0                     <NA>                       <NA>           <NA>
#
#   ContractTerminationInd InfoInScheduleOPartXInd GroupExemptionNum  \
# 0                   <NA>                    <NA>              None
#
#   InfoInScheduleOPartVIIInd FederatedCampaignsAmt TypeOfOrganizationOtherInd  \
# 0                      <NA>                  None                       <NA>
#
#   OtherOrganizationDsc InfoInScheduleOPartVIIIInd TypeOfOrganizationAssocInd  \
# 0                 None                       <NA>                       <NA>
#
#   InitialReturnInd GamingGrossIncomeAmt GamingDirectExpensesAmt  \
# 0             <NA>                 None                    None
#
#   MethodOfAccountingOtherInd InvestmentExpenseAmt Organization501cInd  \
# 0                       <NA>                 None                <NA>
#
#   Organization4947a1NotPFInd AmendedReturnInd SpecialConditionDesc ActivityCd  \
# 0                       <NA>             <NA>                 None       None
#
#                    Timestamp TaxPeriodEndDate TaxPeriodBeginDate  \
# 0  2011-11-09T06:41:09-06:00       2010-12-31         2010-01-01
#
#                                                                                                                         Officer  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
#
#   TaxYear F9_00_HD_BUILD_TIME_STAMP ReturnTs TaxPeriodEndDt TaxPeriodBeginDt  \
# 0    2010      2016-02-24 21:20:13Z     None           None             None
#
#   BusinessOfficerGrp TaxYr fiscal_year        EIN  \
# 0               None  None        None  232705170
#
#                                                                                                         Name  \
# 0  {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}
#
#   NameControl       Phone  \
# 0        RONA  8565826843
#
#                                                                                                        USAddress  \
# 0  {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300', 'City': 'BETHLEHEM', 'State': 'PA', 'ZIPCode': '18017'}
#
#   ForeignAddress InCareOfName BusinessName BusinessNameControlTxt PhoneNum  \
# 0           None         None         None                   None     None
#
#   InCareOfNm ForeignPhoneNum F9_00_HD_ADDR_CHANGE F9_00_HD_AMENDED_RETURN  \
# 0       None            None                    X                    <NA>
#
#   F9_00_HD_CTRY_OF_DOMICILE F9_00_HD_EXEMPT_STATUS_4847A1  \
# 0                      None                          <NA>
#
#   F9_00_HD_EXEMPT_STATUS_501C F9_00_HD_EXEMPT_STATUS_501C3  \
# 0                        <NA>                            X
#
#   F9_00_HD_FINAL_RETURN F9_00_HD_GROSS_EXEMPT_NUM F9_00_HD_GROSS_RCPT  \
# 0                  <NA>                      None             1473903
#
#   F9_00_HD_GROUP_RETURN F9_00_HD_INCLUDES_SUBORD_ORGS F9_00_HD_INITIAL_RETURN  \
# 0                     0                          None                    <NA>
#
#   F9_00_HD_PRIN_OFF_NAME  \
# 0          MICHAEL ANTON
#
#                                                                                                 F9_00_HD_SIGNING_OFFICER_SIGNTR  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
#
#   F9_00_HD_SPECIAL_CONDITION_DESC F9_00_HD_STATE_OF_DOMICILE  \
# 0                            None                         PA
#
#   F9_00_HD_TAX_PER_BEGIN F9_00_HD_TAX_PER_END F9_00_HD_TAX_YEAR  \
# 0             2010-01-01           2010-12-31              2010
#
#          F9_00_HD_TIME_STAMP F9_00_HD_TYPE_ORG_ASSOCIATION  \
# 0  2011-11-09T06:41:09-06:00                          <NA>
#
#   F9_00_HD_TYPE_ORG_CORP F9_00_HD_TYPE_ORG_OTHER F9_00_HD_TYPE_ORG_OTHER_DESC  \
# 0                      X                    <NA>                         None
#
#   F9_00_HD_TYPE_ORG_TRUST F9_00_HD_WEBSITE F9_00_HD_YEAR_FORMED  \
# 0                    <NA>              N/A                 1992
#
#   F9_01_PC_BEN_PAID_MEMB_PRIOR F9_01_PC_CONTR_GRANTS_CURR  \
# 0                            0                    1439340
#
#   F9_01_PC_CONTR_GRANTS_PRIOR F9_01_PC_GRANTS_PRIOR  \
# 0                     1044925                638637
#
#   F9_01_PC_INDEP_VOTING_MEMB F9_01_PC_INVEST_INCOME_PRIOR  \
# 0                         10                        30447
#
#   F9_01_PC_NET_ASSETS_BOY F9_01_PC_OTHER_EXPENSE_PRIOR  \
# 0                 1753405                       243131
#
#   F9_01_PC_OTHER_REV_PRIOR F9_01_PC_PROF_FUNDRISING_EXP_CURR  \
# 0                        0                                 0
#
#   F9_01_PC_PROF_FUNDRISING_EXP_PRIOR F9_01_PC_PROG_SERVICE_REV_PRIOR  \
# 0                                  0                               0
#
#   F9_01_PC_REV_LESS_EXP_CURR F9_01_PC_REV_LESS_EXP_PRIOR  \
# 0                      89152                      193604
#
#   F9_01_PC_TERMINATION_CONTRACTION F9_01_PC_TOT_ASSETS_EOY  \
# 0                             <NA>                 2440859
#
#   F9_01_PC_TOT_EXP_PRIOR F9_01_PC_TOT_FNDR_EXP_CURR  \
# 0                 881768                     195892
#
#   F9_01_PC_TOT_INDIV_EMPLOYED F9_01_PC_TOT_INDIV_VOLUNTEERS  \
# 0                           0                             0
#
#   F9_01_PC_TOT_LIABILITIES_EOY F9_01_PC_TOT_REVENUE_PRIOR  \
# 0                       450430                    1075372
#
#   F9_01_PC_TOT_UBI_GROSS F9_01_PC_TOT_UBI_NET F9_01_PC_VOTING_MEMB_GOV_BODY  \
# 0                      0                    0                            10
#
#   F9_01_PZ_BEN_PAID_TO_MEMB_CURR F9_01_PZ_GRANTS_PAID_CURR  \
# 0                              0                    925000
#
#   F9_01_PZ_INVEST_INCOME_CURR F9_01_PZ_NAFB_EOY  \
# 0                       33563           1990429
#
#                                                             F9_01_PZ_ORGANIZATIONAL_MISSION  \
# 0  MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
#
#   F9_01_PZ_OTHER_EXPENSE_CURR F9_01_PZ_OTHER_REV_CURR  \
# 0                      459751                    1000
#
#   F9_01_PZ_PROG_SERVICE_REV_CURR F9_01_PZ_SALARIES_CURR  \
# 0                              0                      0
#
#   F9_01_PZ_SALARIES_PRIOR F9_01_PZ_TOT_ASSETS_BOY F9_01_PZ_TOT_EXP_CURR  \
# 0                       0                 1925215               1384751
#
#   F9_01_PZ_TOT_LIAB_BOY F9_01_PZ_TOT_REV_CURR F9_03_PC_PGMSVC_SIGNIF_CHG  \
# 0                171810               1473903                          0
#
#   F9_03_PC_PGMSVC_SIGNIF_NEW F9_03_PC_PROG_SVC_ACC_1_CODE  \
# 0                          0                         None
#
#                                                                                                                                                                                                                                 F9_03_PC_PROG_SVC_ACC_1_DESC  \
# 0  RMHC OF THE PHILADELPHIA REGION, INC. GRANTS HUNDREDS OF THOUSANDS OF DOLLARS PER YEAR TO SUPPORT NON-PROFIT PROGRAMS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN. LOCALLY, RMHC SUPPORTS THE PHILADELPHIA, SOUTHERN NEW JERSEY AND DE...
#
#   F9_03_PC_PROG_SVC_ACC_1_EXP F9_03_PC_PROG_SVC_ACC_1_GRNT  \
# 0                     1043744                       925000
#
#   F9_03_PC_PROG_SVC_ACC_1_REV F9_03_PC_PROG_SVC_ACC_2_CODE  \
# 0                        None                         None
#
#   F9_03_PC_PROG_SVC_ACC_2_DESC F9_03_PC_PROG_SVC_ACC_2_EXP  \
# 0                         None                        None
#
#   F9_03_PC_PROG_SVC_ACC_2_GRNT F9_03_PC_PROG_SVC_ACC_2_REV  \
# 0                         None                        None
#
#   F9_03_PC_PROG_SVC_ACC_3_CODE F9_03_PC_PROG_SVC_ACC_3_DESC  \
# 0                         None                         None
#
#   F9_03_PC_PROG_SVC_ACC_3_EXP F9_03_PC_PROG_SVC_ACC_3_GRNT  \
# 0                        None                         None
#
#   F9_03_PC_PROG_SVC_ACC_3_REV F9_03_PC_TOT_OTH_PROG_SVC_EXP  \
# 0                        None                          None
#
#   F9_03_PC_TOT_OTH_PROG_SVC_GRNT F9_03_PC_TOT_OTH_PROG_SVC_REV  \
# 0                           None                          None
#
#   F9_03_PC_TOT_PROG_SVC_EXPENSE  \
# 0                       1043744
#
#                                                                                                                                                                                                                                 F9_03_PZ_MISSION_DESCRIPTION  \
# 0  THE CORPORATION IS ORGANIZED AND WILL BE OPERATED EXCLUSIVELY FOR CHARITABLE, EDUCATIONAL AND SCIENTIFIC PURPOSES WITHIN THE MEANING OF SECTION 501(C)(3) OF THE INTERNAL REVENUE CODE. SUCH PURPOSES SHALL BE LIMITED TO PROVIDING SUPPORT AND FUNDIN...
#
#   F9_03_PZ_SCHEDULE_O_PART3 F9_04_PC_ACTVITIES_VIA_PARTNER  \
# 0                         X                            "0"
#
#   F9_04_PC_CONTROLLED_ENTITY F9_04_PC_DISREGARDED_ENTITY  \
# 0                        "0"                         "0"
#
#   F9_04_PC_EXCESS_BENEFIT_TRANS F9_04_PC_FR_EVENT_INC_GT_15K  \
# 0                           "0"                          "0"
#
#   F9_04_PC_GAMING_INC_GT_15K F9_04_PC_LOBBYING_ACTIVITIES  \
# 0                        "0"                          "0"
#
#   F9_04_PC_POLITICAL_ACTIVITIES F9_04_PC_PRIOR_EXCESS_BEN_TRAN  \
# 0                           "0"                            "0"
#
#   F9_04_PC_PROF_FR_EXP_GT_15K F9_04_PC_RELATED_ENTITY  \
# 0                         "0"                     "0"
#
#   F9_04_PC_TRANS_TO_CNTRLD_ENT F9_04_PC_TRANS_WITH_CNTRLD_ENT  \
# 0                          "0"                            "0"
#
#   F9_05_EXP_SCHED_O_X F9_05_PC_NUMBER_EMPLOYEES_W3 F9_05_PC_NUMBER_FORMS_1096  \
# 0                <NA>                            0                          0
#
#   F9_05_PC_UNRELATED_BUS_INCOME F9_06_EXP_SCHED_O_X  \
# 0                             0                   X
#
#   F9_06_PC_990_PROVIDED_GOV_BODY F9_06_PC_ANNUAL_DISC_COVRD_PERS  \
# 0                              1                               1
#
#   F9_06_PC_CEO_COMPENSTN_PROCESS F9_06_PC_CHANGES_ORGANIZING_DOCS  \
# 0                              0                                0
#
#   F9_06_PC_CONFLICT_OF_INTEREST F9_06_PC_DECISIONS_SUBJ_APPROVAL  \
# 0                             1                                0
#
#   F9_06_PC_DELEGATION_MGT_DUTIES F9_06_PC_DELEGATION_OF_MGT  \
# 0                              0                          0
#
#   F9_06_PC_DOCUMENT_RET_POLICY F9_06_PC_ELECTION_BOARD_MEMBERS  \
# 0                            0                               0
#
#   F9_06_PC_FAMILY_OR_BUSINESS_REL F9_06_PC_FORM_AVAIL_OWN_WEBSITE  \
# 0                               0                            <NA>
#
#   F9_06_PC_FORM_UPON_REQUEST F9_06_PC_JOINT_VENTURE_INVESTMNT  \
# 0                          X                                0
#
#   F9_06_PC_JOINT_VENTURE_POLICY F9_06_PC_LOCAL_CHAPTERS  \
# 0                          None                       0
#
#   F9_06_PC_MATERIAL_DIVERSION F9_06_PC_MEMBERS_OR_STOCKHOLDERS  \
# 0                           0                                0
#
#   F9_06_PC_MINUTES_COMMITTEES F9_06_PC_MINUTES_GOVERNING_BODY  \
# 0                           1                               1
#
#   F9_06_PC_MONITORING_OF_COI_POLICY F9_06_PC_NUM_IND_VOTING_MEMBERS  \
# 0                                 1                              10
#
#   F9_06_PC_NUM_VOTING_GOV_MEMBERS F9_06_PC_OFFICER_MAILING_ADDRESS  \
# 0                              10                                0
#
#   F9_06_PC_OTHER_COMPENSTN_PROCESS F9_06_PC_OTHER_WEBSITE  \
# 0                                0                   <NA>
#
#   F9_06_PC_OWN_WEBSITE F9_06_PC_POLICIES_GOVERN_CHAPTER  \
# 0                 <NA>                             None
#
#   F9_06_PC_STATES_WHERE_RET_FILED F9_06_PC_WHISTLEBLOWER_POLICY  \
# 0              ["PA", "NJ", "DE"]                             0
#
#   F9_07_EXP_SCHED_O_X F9_07_PC_COMPENSATION_OTHER_SRCE  \
# 0                <NA>                                0
#
#   F9_07_PC_FORMER_OFFICER_LISTED F9_07_PC_NO_LISTED_PERS_COMPENSD  \
# 0                              0                                X
#
#   F9_07_PC_NUM_CONTRCTRS_GRTR_100K F9_07_PC_NUM_INDS_GREATER_100K  \
# 0                                0                              0
#
#   F9_07_PC_TOTAL_COMP_GRTR_150K F9_07_PC_TOT_OTHER_COMPENSATION  \
# 0                             0                               0
#
#   F9_07_PC_TOT_REPRT_COMP_FROM_ORG F9_07_PC_TOT_REPRT_COMP_RLTD_ORG  \
# 0                                0                                0
#
#   F9_08_EXP_SCHED_O_X F9_08_PC_ALL_OTHER_CONTRIBUTIONS  \
# 0                <NA>                          1439340
#
#   F9_08_PC_CONTS_REPRTD_FNDRAISNG F9_08_PC_COST_OF_GOODS_SOLD  \
# 0                            None                        None
#
#   F9_08_PC_FEDERATED_CAMPAIGNS F9_08_PC_FUNDRAISING_DIRECT_EXP  \
# 0                         None                            None
#
#   F9_08_PC_FUNDRAISING_EVENTS F9_08_PC_FUNDRAISING_GROSS_INC  \
# 0                        None                           None
#
#   F9_08_PC_GAMING_DIRECT_EXPENSES F9_08_PC_GAMING_GROSS_INCOME  \
# 0                            None                         None
#
#   F9_08_PC_GOVERNMENT_GRANTS F9_08_PC_GROSS_SALES_INVENTORY  \
# 0                       None                           None
#
#   F9_08_PC_MEMBERSHIP_DUES F9_08_PC_NONCASH_CONTRIBUTIONS  \
# 0                     None                           None
#
#   F9_08_PC_PROGRAM_SVCE_REV_TOTAL F9_08_PC_RELATED_ORGANIZATIONS  \
# 0                            None                           None
#
#   F9_08_PC_TOTAL_CONTRIBUTIONS F9_08_PC_TOTAL_OTHER_REVENUE  \
# 0                      1439340                         1000
#
#   F9_08_PC_TOTAL_PROG_SVCE_REVENUE  \
# 0                             None
#
#                                                                                                                     F9_08_PC_TOTAL_REVENUE  \
# 0  {"TotalRevenueColumn": "1473903", "RelatedOrExemptFunctionIncome": "1000", "UnrelatedBusinessRevenue": "0", "ExclusionAmount": "33563"}
#
#   F9_09_EXP_AD_PROMO_TOT F9_09_EXP_BENF_PAID_MEMB_TOT  \
# 0                   None                         None
#
#   F9_09_EXP_CONF_MEETING_TOT  \
# 0                       None
#
#                                 F9_09_EXP_DEPREC_FUNDR  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
#
#                                   F9_09_EXP_DEPREC_MAG  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
#
#                                  F9_09_EXP_DEPREC_PROG  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
#
#                                   F9_09_EXP_DEPREC_TOT  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
#
#   F9_09_EXP_GRANT_FRGN_TOT                 F9_09_EXP_GRANT_INDIV_DMSTC_TOT  \
# 0                     None  {"Total": "33000", "ProgramServices": "33000"}
#
#                       F9_09_EXP_GRANT_ORG_DMSTC_TOT F9_09_EXP_INFO_TECH_TOT  \
# 0  {"Total": "892000", "ProgramServices": "892000"}                    None
#
#   F9_09_EXP_INSURANCE_TOT F9_09_EXP_INTEREST_TOT F9_09_EXP_JOINT_COSTS_TOT  \
# 0                    None                   None                      None
#
#   F9_09_EXP_OCCUPANCY_TOT                             F9_09_EXP_OFFICE_TOT  \
# 0                    None  {"Total": "123", "ManagementAndGeneral": "123"}
#
#                              F9_09_EXP_OTH_OTH_TOT  \
# 0  {"Total": "763", "ManagementAndGeneral": "763"}
#
#                                                                                                                                                                                                                                            F9_09_EXP_OTH_TOT  \
# 0  [{"Description": "FUNDRAISING COSTS", "Total": "108311", "Fundraising": "108311"}, {"Description": "CANISTER COLLECTION FEE", "Total": "81925", "Fundraising": "81925"}, {"Description": "PR/ADMINISTRATIVE SERVI", "Total": "34517", "ManagementAndGe...
#
#   F9_09_EXP_ROY_TOT F9_09_EXP_SCHED_O_X F9_09_EXP_TRAVEL_ENTRTNMNT_TOT  \
# 0              None                <NA>                           None
#
#   F9_09_EXP_TRAVEL_TOT F9_09_PC_COMP_DISQUAL_FUNDRAISE  \
# 0                 None                            None
#
#   F9_09_PC_COMP_DISQUAL_MGMT F9_09_PC_COMP_DISQUAL_PROG_SVCE  \
# 0                       None                            None
#
#   F9_09_PC_COMP_DISQUAL_TOTAL F9_09_PC_COMP_OFFICERS_FUNDRAISE  \
# 0                        None                             None
#
#   F9_09_PC_COMP_OFFICERS_MGMT F9_09_PC_COMP_OFFICERS_PROG_SVCE  \
# 0                        None                             None
#
#   F9_09_PC_COMP_OFFICERS_TOTAL  \
# 0                         None
#
#                        F9_09_PC_FEES_FOR_SVCE_ACCT_TOT  \
# 0  {"Total": "21675", "ManagementAndGeneral": "21675"}
#
#   F9_09_PC_FEES_FOR_SVCE_INVST_TOT  \
# 0                             None
#
#                    F9_09_PC_FEES_FOR_SVCE_LEGL_TOT  \
# 0  {"Total": "215", "ManagementAndGeneral": "215"}
#
#   F9_09_PC_FEES_FOR_SVCE_LOBB_TOT F9_09_PC_FEES_FOR_SVCE_MGMT_TOT  \
# 0                            None                            None
#
#   F9_09_PC_FEES_FOR_SVCE_OTH_TOT F9_09_PC_OTHER_EMP_BEN_FUNDRAISE  \
# 0                           None                             None
#
#   F9_09_PC_OTHER_EMP_BEN_MGMT F9_09_PC_OTHER_EMP_BEN_PROG_SVCE  \
# 0                        None                             None
#
#   F9_09_PC_OTHER_EMP_BEN_TOTAL F9_09_PC_OTHER_SALARY_FUNDRAISE  \
# 0                         None                            None
#
#   F9_09_PC_OTHER_SALARY_MGMT F9_09_PC_OTHER_SALARY_PROG_SVCE  \
# 0                       None                            None
#
#   F9_09_PC_OTHER_SALARY_TOTAL  \
# 0                        None
#
#                      F9_09_PC_PAYMENT_TO_AFFILIATES  \
# 0  {"Total": "118744", "ProgramServices": "118744"}
#
#   F9_09_PC_PAYROLL_TAX_FUNDRAISE F9_09_PC_PAYROLL_TAX_MGMT  \
# 0                           None                      None
#
#   F9_09_PC_PAYROLL_TAX_PROG_SVCE F9_09_PC_PAYROLL_TAX_TOTAL  \
# 0                           None                       None
#
#   F9_09_PC_PENSION_CONT_FUNDRAISE F9_09_PC_PENSION_CONT_MGMT  \
# 0                            None                       None
#
#   F9_09_PC_PENSION_CONT_PROG_SVCE F9_09_PC_PENSION_CONT_TOTAL  \
# 0                            None                        None
#
#                                                                                     F9_09_PC_TOTAL_FUNC_EXPENSES  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
#
#                                                                                 F9_09_PC_TOTAL_FUNDRAISE_EXPENSE  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
#
#                                                                                      F9_09_PC_TOTAL_MGMT_EXPENSE  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
#
#                                                                                 F9_09_PC_TOTAL_PROG_SVCE_EXPENSE  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
#
#              F9_10_ASSETS_ACC_NET_EOY F9_10_ASSETS_EXP_PREPAID_EOY  \
# 0  {"BOY": "103412", "EOY": "147981"}                         None
#
#   F9_10_ASSETS_INTANGIB_EOY F9_10_ASSETS_INVENT_SALE_EOY  \
# 0                      None                         None
#
#     F9_10_ASSETS_LESS_DEPREC_EOY F9_10_ASSETS_LOANS_DISQUAL_EOY  \
# 0  {"BOY": "0", "EOY": "170617"}                           None
#
#   F9_10_ASSETS_NOTES_LOANS_NET_EOY F9_10_ASSETS_OTH_EOY  \
# 0                             None                 None
#
#   F9_10_ASSETS_PLEDGES_NET_EOY        F9_10_LIAB_ACC_PAYABLE_EOY  \
# 0                         None  {"BOY": "39670", "EOY": "44353"}
#
#        F9_10_LIAB_GRANTS_PAYABLE_EOY F9_10_LIAB_LOANS_OFF_EOY  \
# 0  {"BOY": "80500", "EOY": "166000"}                     None
#
#   F9_10_LIAB_REV_DEFERRED_EOY F9_10_NAFB_RESTRICT_PERM_EOY  \
# 0                        None                         None
#
#   F9_10_NAFB_RESTRICT_TEMP_EOY             F9_10_NAFB_UNRESTRICT_EOY  \
# 0                         None  {"BOY": "1753405", "EOY": "1990429"}
#
#   F9_10_PC_BOND_LIABILITY_EOY F9_10_PC_CASH_NON_INTEREST_BOY  \
# 0                        None                           None
#
#   F9_10_PC_CASH_NON_INTEREST_EOY F9_10_PC_ESCROW_LIABILITY_EOY  \
# 0                           None                          None
#
#           F9_10_PC_INVEST_OTHER_SEC_EOY F9_10_PC_INVEST_PROG_RELTD_EOY  \
# 0  {"BOY": "1489143", "EOY": "1851561"}                           None
#
#   F9_10_PC_INVEST_PUB_TRADED_EOY F9_10_PC_LAND_BLDG_EQPMT  \
# 0                           None                   256845
#
#   F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN F9_10_PC_LOANS_FROM_OFFICERS_EOY  \
# 0                            86228                             None
#
#   F9_10_PC_ORG_FOLLOWS_SFAS117 F9_10_PC_ORG_NOT_FOLLOW_SFAS117  \
# 0                            X                            <NA>
#
#       F9_10_PC_OTHER_LIABILITIES_EOY F9_10_PC_RET_EARNINGS_ENDWMT_EOY  \
# 0  {"BOY": "51640", "EOY": "240077"}                             None
#
#      F9_10_PC_SAVINGS_TEMP_INVEST_BOY    F9_10_PC_SAVINGS_TEMP_INVEST_EOY  \
# 0  {"BOY": "332660", "EOY": "270700"}  {"BOY": "332660", "EOY": "270700"}
#
#   F9_10_PC_SECURED_MORTGAGES_EOY F9_10_PC_SECURE_MORT_NOTES_EOY  \
# 0                           None                           None
#
#   F9_10_PC_UNSECURED_LOANS_EOY F9_10_PC_UNSECURED_NOTES_BOY  \
# 0                         None                         None
#
#   F9_10_PC_UNSECURED_NOTES_EOY             F9_10_PZ_TOTAL_ASSETS_EOY  \
# 0                         None  {"BOY": "1925215", "EOY": "2440859"}
#
#   F9_10_SCHED_O_X F9_11_PC_RECNCLTN_DONATED_SVCES  \
# 0            <NA>                            None
#
#   F9_11_PC_RECNCLTN_INVSTMNT_EXP F9_11_PC_RECNCLTN_PRIOR_PER_ADJ  \
# 0                           None                            None
#
#   F9_11_PC_RECNCLTN_REV_LESS_EXP F9_11_PC_RECNCLTN_UNRLZD_GAIN  \
# 0                          89152                          None
#
#   F9_11_SCHED_O_X F9_12_PC_ACCNT_COMPILE_OR_REVIEW  \
# 0               X                                0
#
#   F9_12_PC_ACCTG_METHOD_ACCRUAL F9_12_PC_ACCTG_METHOD_CASH  \
# 0                             X                       <NA>
#
#   F9_12_PC_ACCTG_METHOD_OTHER F9_12_PC_AUDIT_COMMITTEE  \
# 0                        <NA>                        1
#
#   F9_12_PC_FED_GRNT_AUDIT_PERFORMD F9_12_PC_FED_GRNT_AUDIT_REQUIRED  \
# 0                             None                                0
#
#   F9_12_PC_FINCL_STMTS_AUDITED F9_12_SCHED_O_X number_of_other_prog_svces
# 0                            1               X                       None

# %%
gc.collect()
# Out:
# 0

# %%
df = updated_df.copy(deep=True)

# %%
gc.collect()
# Out:
# 0

# %%
del updated_df

# %%
gc.collect()
# Out:
# 0

# %% [markdown]
# #### Save DF
# Whenever I'm dealing with time-intensive computations I like to save the dataset several times throughout the notebook. Here I'm using a slightly different file name (adding 'renamed') to differentiate it from our original file.

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df.to_feather('D:/all_filings_april_2025_all_controls.feather')
# Out:
# Current date and time :  2025-04-16 23:18:10
#
# CPU times: total: 5min 30s
# Wall time: 4min 36s

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df = pd.read_feather("D:/all_filings_april_2025_all_controls.feather")
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
df[:2]
# Out:
# Current date and time :  2025-04-16 23:02:39
#
# # of columns: 496
# # of observations: 3469008
# CPU times: total: 5min 23s
# Wall time: 4min 48s
#                         _id  \
# 0  5d019e6778ffca27b42818d7
# 1  5d019e6778ffca27b42818d8
#
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#               DLN TaxPeriod AddressChange NameOfPrincipalOfficerPerson  \
# 0  93493313013011    201012             X                MICHAEL ANTON
# 1  93493313013111    201106          <NA>                         None
#
#   GrossReceipts GroupReturnForAffiliates Organization501c3 WebSite  \
# 0       1473903                        0                 X     N/A
# 1        266420                    false                 X     N/A
#
#   TypeOfOrganizationCorporation YearFormation StateLegalDomicile  \
# 0                             X          1992                 PA
# 1                             X          1993                 WY
#
#                                                                                                                     ActivityOrMissionDescription  \
# 0                                                       MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
# 1  PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   NbrVotingMembersGoverningBody NbrIndependentVotingMembers TotalNbrEmployees  \
# 0                            10                          10                 0
# 1                            19                          13                 0
#
#   TotalNbrVolunteers TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 0                  0             0                              0
# 1               None             0                           None
#
#   ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 0                      1044925                        1439340
# 1                         None                              0
#
#   ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 0                              0                       0
# 1                         222839                  265592
#
#   InvestmentIncomePriorYear InvestmentIncomeCurrentYear OtherRevenuePriorYear  \
# 0                     30447                       33563                     0
# 1                      1425                         828                  None
#
#   OtherRevenueCurrentYear TotalRevenuePriorYear TotalRevenueCurrentYear  \
# 0                    1000               1075372                 1473903
# 1                       0                224264                  266420
#
#   GrantsAndSimilarAmntsPriorYear GrantsAndSimilarAmntsCY  \
# 0                         638637                  925000
# 1                           None                       0
#
#   BenefitsPaidToMembersPriorYear BenefitsPaidToMembersCY SalariesEtcPriorYear  \
# 0                              0                       0                    0
# 1                           None                       0                71405
#
#   SalariesEtcCurrentYear TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 0                      0                             0                      0
# 1                  82955                          None                      0
#
#   TotalFundrsngExpCurrentYear OtherExpensePriorYear OtherExpensesCurrentYear  \
# 0                      195892                243131                   459751
# 1                           0                189785                   222550
#
#   TotalExpensesPriorYear TotalExpensesCurrentYear  \
# 0                 881768                  1384751
# 1                 261190                   305505
#
#   RevenuesLessExpensesPriorYear RevenuesLessExpensesCY TotalAssetsBOY  \
# 0                        193604                  89152        1925215
# 1                        -36926                 -39085        1455332
#
#   TotalAssetsEOY TotalLiabilitiesBOY TotalLiabilitiesEOY  \
# 0        2440859              171810              450430
# 1        1433342               17482               34577
#
#   NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesEOY  \
# 0                    1753405                    1990429
# 1                    1437850                    1398765
#
#   InfoInScheduleOPartIII  \
# 0                      X
# 1                   <NA>
#
#                                                                                                                                                                                                                                           MissionDescription  \
# 0  THE CORPORATION IS ORGANIZED AND WILL BE OPERATED EXCLUSIVELY FOR CHARITABLE, EDUCATIONAL AND SCIENTIFIC PURPOSES WITHIN THE MEANING OF SECTION 501(C)(3) OF THE INTERNAL REVENUE CODE. SUCH PURPOSES SHALL BE LIMITED TO PROVIDING SUPPORT AND FUNDIN...
# 1                                                                                                              PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   SignificantNewProgramServices SignificantChange  Expense  Grants  \
# 0                             0                 0  1043744  925000
# 1                         false             false   276405    None
#
#                                                                                                                                                                                                                                                  Description  \
# 0  RMHC OF THE PHILADELPHIA REGION, INC. GRANTS HUNDREDS OF THOUSANDS OF DOLLARS PER YEAR TO SUPPORT NON-PROFIT PROGRAMS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN. LOCALLY, RMHC SUPPORTS THE PHILADELPHIA, SOUTHERN NEW JERSEY AND DE...
# 1                                                                                                              PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   TotalProgramServiceExpense PoliticalActivities LobbyingActivities  \
# 0                    1043744                 "0"                "0"
# 1                     276405             "false"            "false"
#
#   ProfessionalFundraising FundraisingActivities   Gaming  \
# 0                     "0"                   "0"      "0"
# 1                 "false"               "false"  "false"
#
#   ExcessBenefitTransaction PriorExcessBenefitTransaction  \
# 0                      "0"                           "0"
# 1                  "false"                       "false"
#
#                                                DisregardedEntity  \
# 0                                                            "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "true"}
#
#                                                    RelatedEntity  \
# 0                                                            "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "true"}
#
#   RelatedOrgControlledEntity  \
# 0                        "0"
# 1                    "false"
#
#                                          TransactionRelatedEntity  \
# 0                                                             "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
#
#                                     TransfersToExemptNonChrtblOrg  \
# 0                                                             "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
#
#                                    ActivitiesConductedPartnership  \
# 0                                                             "0"
# 1  {"@referenceDocumentId": " IRS990ScheduleR", "#text": "false"}
#
#   NumberFormsTransmittedWith1096 NumberOfEmployees UnrelatedBusinessIncome  \
# 0                              0                 0                       0
# 1                              0                 0                   false
#
#   InfoInScheduleOPartVI NbrVotingGoverningBodyMembers  \
# 0                     X                            10
# 1                     X                            19
#
#   NumberIndependentVotingMembers FamilyOrBusinessRelationship  \
# 0                             10                            0
# 1                             13                         true
#
#   DelegationOfManagementDuties ChangesToOrganizingDocs  \
# 0                            0                       0
# 1                         true                   false
#
#   MaterialDiversionOrMisuse MembersOrStockholders ElectionOfBoardMembers  \
# 0                         0                     0                      0
# 1                     false                 false                   true
#
#   DecisionsSubjectToApproval MinutesOfGoverningBody MinutesOfCommittees  \
# 0                          0                      1                   1
# 1                       true                   true                true
#
#   OfficerMailingAddress LocalChapters Form990ProvidedToGoverningBody  \
# 0                     0             0                              1
# 1                 false         false                           true
#
#   ConflictOfInterestPolicy AnnualDisclosureCoveredPersons  \
# 0                        1                              1
# 1                     true                           true
#
#   RegularMonitoringEnforcement WhistleblowerPolicy DocumentRetentionPolicy  \
# 0                            1                   0                       0
# 1                         true               false                   false
#
#   CompensationProcessCEO CompensationProcessOther InvestmentInJointVenture  \
# 0                      0                        0                        0
# 1                   true                     true                    false
#
#   StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 0             ["PA", "NJ", "DE"]           X                          X
# 1                           None           X                       <NA>
#
#   TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 0                          0                              0
# 1                       None                        1180355
#
#   TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 0                      0                       0             0
# 1                 411648                       0          true
#
#   TotalCompGT150K CompensationFromOtherSources NumberOfContractorsGT100K  \
# 0               0                            0                         0
# 1            true                        false                         0
#
#   AllOtherContributions TotalContributions TotalOtherRevenue  \
# 0               1439340            1439340              1000
# 1                  None                  0                 0
#
#                                                                                                                               TotalRevenue  \
# 0  {"TotalRevenueColumn": "1473903", "RelatedOrExemptFunctionIncome": "1000", "UnrelatedBusinessRevenue": "0", "ExclusionAmount": "33563"}
# 1                                                              {"TotalRevenueColumn": "266420", "RelatedOrExemptFunctionIncome": "266420"}
#
#                                GrantsToDomesticOrgs  \
# 0  {"Total": "892000", "ProgramServices": "892000"}
# 1                                    {"Total": "0"}
#
#                       GrantsToDomesticIndividuals  \
# 0  {"Total": "33000", "ProgramServices": "33000"}
# 1                                  {"Total": "0"}
#
#                               FeesForServicesLegal  \
# 0  {"Total": "215", "ManagementAndGeneral": "215"}
# 1                                   {"Total": "0"}
#
#                              FeesForServicesAccounting  \
# 0  {"Total": "21675", "ManagementAndGeneral": "21675"}
# 1    {"Total": "7500", "ManagementAndGeneral": "7500"}
#
#                                     OfficeExpenses  \
# 0  {"Total": "123", "ManagementAndGeneral": "123"}
# 1   {"Total": "14222", "ProgramServices": "14222"}
#
#                                PaymentsToAffiliates  \
# 0  {"Total": "118744", "ProgramServices": "118744"}
# 1                                    {"Total": "0"}
#
#                                  DepreciationDepletion  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
# 1       {"Total": "66166", "ProgramServices": "66166"}
#
#                                                                                                                                                                                                                                                OtherExpenses  \
# 0  [{"Description": "FUNDRAISING COSTS", "Total": "108311", "Fundraising": "108311"}, {"Description": "CANISTER COLLECTION FEE", "Total": "81925", "Fundraising": "81925"}, {"Description": "PR/ADMINISTRATIVE SERVI", "Total": "34517", "ManagementAndGe...
# 1                [{"Description": "OPER. & MAINT.", "Total": "46164", "ProgramServices": "46164"}, {"Description": "MISC TAXES", "Total": "298", "ProgramServices": "298"}, {"Description": "ADMINISTRATIVE", "Total": "12176", "ProgramServices": "12176"}]
#
#                                   AllOtherExpenses  \
# 0  {"Total": "763", "ManagementAndGeneral": "763"}
# 1                                   {"Total": "0"}
#
#                                                                                          TotalFunctionalExpenses  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
# 1          {"Total": "305505", "ProgramServices": "276405", "ManagementAndGeneral": "29100", "Fundraising": "0"}
#
#         SavingsAndTempCashInvestments                  AccountsReceivable  \
# 0  {"BOY": "332660", "EOY": "270700"}  {"BOY": "103412", "EOY": "147981"}
# 1                        {"EOY": "0"}        {"BOY": "231", "EOY": "474"}
#
#   LandBuildingsEquipmentBasis LandBldgEquipmentAccumDeprec  \
# 0                      256845                        86228
# 1                     2187206                       904332
#
#          LandBuildingsEquipmentBasisNet            InvestmentsOtherSecurities  \
# 0         {"BOY": "0", "EOY": "170617"}  {"BOY": "1489143", "EOY": "1851561"}
# 1  {"BOY": "1306860", "EOY": "1282874"}    {"BOY": "125980", "EOY": "102794"}
#
#                             TotalAssets    AccountsPayableAccruedExpenses  \
# 0  {"BOY": "1925215", "EOY": "2440859"}  {"BOY": "39670", "EOY": "44353"}
# 1  {"BOY": "1455332", "EOY": "1433342"}   {"BOY": "2040", "EOY": "16145"}
#
#                        GrantsPayable                   OtherLiabilities  \
# 0  {"BOY": "80500", "EOY": "166000"}  {"BOY": "51640", "EOY": "240077"}
# 1                               None    {"BOY": "9203", "EOY": "11349"}
#
#   FollowSFAS117                 UnrestrictedNetAssets InfoInScheduleOPartXI  \
# 0             X  {"BOY": "1753405", "EOY": "1990429"}                     X
# 1             X  {"BOY": "1437850", "EOY": "1398765"}                  <NA>
#
#   ReconcilationRevenueExpenses InfoInScheduleOPartXII  \
# 0                        89152                      X
# 1                       -39085                   <NA>
#
#   MethodOfAccountingAccrual AccountantCompileOrReview FSAudited  \
# 0                         X                         0         1
# 1                         X                     false      true
#
#   AuditCommittee FederalGrantAuditRequired AllAffiliatesIncluded  \
# 0              1                         0                  None
# 1           true                      true               "false"
#
#   GroupExemptionNumber Revenue PoliciesReferenceChapters  \
# 0                 None    None                      None
# 1                 1736  266420                     false
#
#   WrittenPolicyOrProcedure TotalProgramServiceRevenue   ForeignGrants  \
# 0                     None                       None            None
# 1                    false                     265592  {"Total": "0"}
#
#   BenefitsToMembers CompCurrentOfficersDirectors CompDisqualPersons  \
# 0              None                         None               None
# 1    {"Total": "0"}               {"Total": "0"}     {"Total": "0"}
#
#                             OtherSalariesAndWages PensionPlanContributions  \
# 0                                            None                     None
# 1  {"Total": "59440", "ProgramServices": "59440"}           {"Total": "0"}
#
#                             OtherEmployeeBenefits  \
# 0                                            None
# 1  {"Total": "17714", "ProgramServices": "17714"}
#
#                                    PayrollTaxes  \
# 0                                          None
# 1  {"Total": "5801", "ProgramServices": "5801"}
#
#                              FeesForServicesManagement  \
# 0                                                 None
# 1  {"Total": "21600", "ManagementAndGeneral": "21600"}
#
#   FeesForServicesLobbying F9_09_PC_FEES_FOR_SVCE_FR_TOT  \
# 0                    None                          None
# 1          {"Total": "0"}                {"Total": "0"}
#
#   FeesForServicesInvstMgmntFees FeesForServicesOther  \
# 0                          None                 None
# 1                {"Total": "0"}       {"Total": "0"}
#
#                                     Advertising InformationTechnology  \
# 0                                          None                  None
# 1  {"Total": "8433", "ProgramServices": "8433"}        {"Total": "0"}
#
#         Royalties                                       Occupancy  \
# 0            None                                            None
# 1  {"Total": "0"}  {"Total": "44077", "ProgramServices": "44077"}
#
#            Travel TravelEntrtnmntPublicOfficials  \
# 0            None                           None
# 1  {"Total": "0"}                 {"Total": "0"}
#
#                           ConferencesMeetings        Interest  \
# 0                                        None            None
# 1  {"Total": "806", "ProgramServices": "806"}  {"Total": "0"}
#
#                                       Insurance  \
# 0                                          None
# 1  {"Total": "1108", "ProgramServices": "1108"}
#
#            CashNonInterestBearing PledgesAndGrantsReceivable  \
# 0                            None                       None
# 1  {"BOY": "250", "EOY": "22261"}               {"EOY": "0"}
#
#   ReceivablesFromDisqualPersons OtherNotesLoansReceivableNet  \
# 0                          None                         None
# 1                  {"EOY": "0"}                 {"EOY": "0"}
#
#   InventoriesForSaleOrUse  PrepaidExpensesDeferredCharges  \
# 0                    None                            None
# 1            {"EOY": "0"}  {"BOY": "7628", "EOY": "7554"}
#
#   InvestmentsPubTradedSecurities InvestmentsProgramRelated IntangibleAssets  \
# 0                           None                      None             None
# 1                   {"EOY": "0"}              {"EOY": "0"}     {"EOY": "0"}
#
#                    OtherAssetsTotal             DeferredRevenue  \
# 0                              None                        None
# 1  {"BOY": "14383", "EOY": "17385"}  {"BOY": "20", "EOY": "48"}
#
#    MortNotesPyblSecuredInvestProp FederalGrantAuditPerformed  \
# 0                            None                       None
# 1  {"BOY": "6219", "EOY": "7035"}                       true
#
#   LoansFromOfficersDirectors MethodOfAccountingCash Activity2 Activity3  \
# 0                       None                   <NA>      None      None
# 1                       None                   <NA>      None      None
#
#   InfoInScheduleOPartVII TaxExemptBondLiabilities  \
# 0                   <NA>                     None
# 1                   <NA>                     None
#
#   TemporarilyRestrictedNetAssets OtherWebsite PermanentlyRestrictedNetAssets  \
# 0                           None         <NA>                           None
# 1                           None         <NA>                           None
#
#   FundraisingEvents CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 0              None                           None                 None
# 1              None                           None                 None
#
#   GrossIncomeFundraisingEvents FundraisingDirectExpenses FederatedCampaigns  \
# 0                         None                      None               None
# 1                         None                      None               None
#
#   GovernmentGrants MethodOfAccountingOther GrossSalesOfInventory  \
# 0             None                    <NA>                  None
# 1             None                    <NA>                  None
#
#   CostOfGoodsSold DoNotFollowSFAS117 RetainedEarningsEndowmentEtc  \
# 0            None               <NA>                         None
# 1            None               <NA>                         None
#
#   InitialReturn MembershipDues GrossIncomeGaming GamingDirectExpenses  \
# 0          <NA>           None              None                 None
# 1          <NA>           None              None                 None
#
#   NoncashContributions InfoInScheduleOPartV OwnWebsite  \
# 0                 None                 <NA>       <NA>
# 1                 None                 <NA>       <NA>
#
#   UnsecuredNotesLoansPayable ActivityOther TotalOfOtherProgramServiceExp  \
# 0                       None          None                          None
# 1                       None          None                          None
#
#   TotalOfOtherProgramServiceRev EscrowAccountLiability  \
# 0                          None                   None
# 1                          None                   None
#
#   TotalOfOtherProgramServiceGrnt TypeOfOrganizationOther Organization501c  \
# 0                           None                    <NA>             <NA>
# 1                           None                    <NA>             <NA>
#
#   TypeOfOrganizationTrust TypeOfOrganizationAssociation CountryLegalDomicile  \
# 0                    <NA>                          <NA>                 None
# 1                    <NA>                          <NA>                 None
#
#   AmendedReturn TypeOfOrgOtherDescription TotalJointCosts TerminatedReturn  \
# 0          <NA>                      None            None             <NA>
# 1          <NA>                      None            None             <NA>
#
#   TerminationOrContraction ActivityCode SpecialConditionDescription  \
# 0                     <NA>         None                        None
# 1                     <NA>         None                        None
#
#   Organization4947a1 InfoInScheduleOPartIX ReconciliationUnrealizedInvest  \
# 0               <NA>                  <NA>                           None
# 1               <NA>                  <NA>                           None
#
#   ReconcilationPriorAdjustment ReconcilationDonatedServices  \
# 0                         None                         None
# 1                         None                         None
#
#   ReconcilationInvestExpenses InfoInScheduleOPartVIII InfoInScheduleOPartX  \
# 0                        None                    <NA>                 <NA>
# 1                        None                    <NA>                 <NA>
#
#   PrincipalOfficerNm GrossReceiptsAmt GroupReturnForAffiliatesInd  \
# 0               None             None                        None
# 1               None             None                        None
#
#   Organization501c3Ind TypeOfOrganizationCorpInd FormationYr  \
# 0                 <NA>                      <NA>        None
# 1                 <NA>                      <NA>        None
#
#   LegalDomicileStateCd ActivityOrMissionDesc VotingMembersGoverningBodyCnt  \
# 0                 None                  None                          None
# 1                 None                  None                          None
#
#   VotingMembersIndependentCnt TotalEmployeeCnt TotalGrossUBIAmt  \
# 0                        None             None             None
# 1                        None             None             None
#
#   CYContributionsGrantsAmt CYProgramServiceRevenueAmt CYInvestmentIncomeAmt  \
# 0                     None                       None                  None
# 1                     None                       None                  None
#
#   CYOtherRevenueAmt CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 0              None              None                      None
# 1              None              None                      None
#
#   CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 0                       None                         None
# 1                       None                         None
#
#   CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt CYOtherExpensesAmt  \
# 0                       None                         None               None
# 1                       None                         None               None
#
#   CYTotalExpensesAmt CYRevenuesLessExpensesAmt TotalAssetsBOYAmt  \
# 0               None                      None              None
# 1               None                      None              None
#
#   TotalAssetsEOYAmt TotalLiabilitiesEOYAmt NetAssetsOrFundBalancesBOYAmt  \
# 0              None                   None                          None
# 1              None                   None                          None
#
#   NetAssetsOrFundBalancesEOYAmt InfoInScheduleOPartIIIInd MissionDesc  \
# 0                          None                      <NA>        None
# 1                          None                      <NA>        None
#
#   SignificantNewProgramSrvcInd SignificantChangeInd  Desc  \
# 0                         None                 None  None
# 1                         None                 None  None
#
#   PoliticalCampaignActyInd LobbyingActivitiesInd ProfessionalFundraisingInd  \
# 0                     None                  None                       None
# 1                     None                  None                       None
#
#   FundraisingActivitiesInd GamingActivitiesInd EngagedInExcessBenefitTransInd  \
# 0                     None                None                           None
# 1                     None                None                           None
#
#   PYExcessBenefitTransInd DisregardedEntityInd RelatedEntityInd  \
# 0                    None                 None             None
# 1                    None                 None             None
#
#   RelatedOrganizationCtrlEntInd TransactionWithControlEntInd  \
# 0                          None                         None
# 1                          None                         None
#
#   TrnsfrExmptNonChrtblRltdOrgInd ActivitiesConductedPrtshpInd IRPDocumentCnt  \
# 0                           None                         None           None
# 1                           None                         None           None
#
#   EmployeeCnt UnrelatedBusIncmOverLimitInd GoverningBodyVotingMembersCnt  \
# 0        None                         None                          None
# 1        None                         None                          None
#
#   IndependentVotingMemberCnt FamilyOrBusinessRlnInd DelegationOfMgmtDutiesInd  \
# 0                       None                   None                      None
# 1                       None                   None                      None
#
#   ChangeToOrgDocumentsInd MaterialDiversionOrMisuseInd  \
# 0                    None                         None
# 1                    None                         None
#
#   MembersOrStockholdersInd ElectionOfBoardMembersInd  \
# 0                     None                      None
# 1                     None                      None
#
#   DecisionsSubjectToApprovaInd MinutesOfGoverningBodyInd  \
# 0                         None                      None
# 1                         None                      None
#
#   MinutesOfCommitteesInd OfficerMailingAddressInd LocalChaptersInd  \
# 0                   None                     None             None
# 1                   None                     None             None
#
#   Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 0                         None                        None
# 1                         None                        None
#
#   WhistleblowerPolicyInd DocumentRetentionPolicyInd CompensationProcessCEOInd  \
# 0                   None                       None                      None
# 1                   None                       None                      None
#
#   CompensationProcessOtherInd InvestmentInJointVentureInd  \
# 0                        None                        None
# 1                        None                        None
#
#   StatesWhereCopyOfReturnIsFldCd NoListedPersonsCompensatedInd  \
# 0                           None                          <NA>
# 1                           None                          <NA>
#
#   FormerOfcrEmployeesListedInd TotalCompGreaterThan150KInd  \
# 0                         None                        None
# 1                         None                        None
#
#   CompensationFromOtherSrcsInd MembershipDuesAmt FundraisingAmt  \
# 0                         None              None           None
# 1                         None              None           None
#
#   AllOtherContributionsAmt TotalContributionsAmt OtherRevenueTotalAmt  \
# 0                     None                  None                 None
# 1                     None                  None                 None
#
#   TotalRevenueGrp FeesForServicesAccountingGrp OfficeExpensesGrp  \
# 0            None                         None              None
# 1            None                         None              None
#
#   InformationTechnologyGrp ConferencesMeetingsGrp InsuranceGrp  \
# 0                     None                   None         None
# 1                     None                   None         None
#
#   OtherExpensesGrp AllOtherExpensesGrp TotalFunctionalExpensesGrp  \
# 0             None                None                       None
# 1             None                None                       None
#
#   CashNonInterestBearingGrp TotalAssetsGrp OrgDoesNotFollowSFAS117Ind  \
# 0                      None           None                       <NA>
# 1                      None           None                       <NA>
#
#   RtnEarnEndowmentIncmOthFndsGrp ReconcilationRevenueExpnssAmt  \
# 0                           None                          None
# 1                           None                          None
#
#   MethodOfAccountingCashInd AccountantCompileOrReviewInd FSAuditedInd  \
# 0                      <NA>                         None         None
# 1                      <NA>                         None         None
#
#   FederalGrantAuditRequiredInd WebsiteAddressTxt TotalVolunteersCnt  \
# 0                         None              None               None
# 1                         None              None               None
#
#   NetUnrelatedBusTxblIncmAmt PYContributionsGrantsAmt  \
# 0                       None                     None
# 1                       None                     None
#
#   PYProgramServiceRevenueAmt PYInvestmentIncomeAmt PYOtherRevenueAmt  \
# 0                       None                  None              None
# 1                       None                  None              None
#
#   PYTotalRevenueAmt PYGrantsAndSimilarPaidAmt PYBenefitsPaidToMembersAmt  \
# 0              None                      None                       None
# 1              None                      None                       None
#
#   PYSalariesCompEmpBnftPaidAmt PYTotalProfFndrsngExpnsAmt PYOtherExpensesAmt  \
# 0                         None                       None               None
# 1                         None                       None               None
#
#   PYTotalExpensesAmt PYRevenuesLessExpensesAmt TotalLiabilitiesBOYAmt  \
# 0               None                      None                   None
# 1               None                      None                   None
#
#   ExpenseAmt GrantAmt RevenueAmt ProgSrvcAccomActy2Grp ProgSrvcAccomActy3Grp  \
# 0       None     None       None                  None                  None
# 1       None     None       None                  None                  None
#
#   ProgSrvcAccomActyOtherGrp TotalOtherProgSrvcGrantAmt  \
# 0                      None                       None
# 1                      None                       None
#
#   TotalProgramServiceExpensesAmt InfoInScheduleOPartVIInd  \
# 0                           None                     <NA>
# 1                           None                     <NA>
#
#   AnnualDisclosureCoveredPrsnInd RegularMonitoringEnfrcInd UponRequestInd  \
# 0                           None                      None           <NA>
# 1                           None                      None           <NA>
#
#   TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 0                          None                        None
# 1                          None                        None
#
#   TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 0                      None                        None
# 1                      None                        None
#
#   CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 0                         None                None
# 1                         None                None
#
#   TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 0                          None                      None
# 1                          None                      None
#
#   ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 0                         None                         None
# 1                         None                         None
#
#   GrossSalesOfInventoryAmt CostOfGoodsSoldAmt GrantsToDomesticIndividualsGrp  \
# 0                     None               None                           None
# 1                     None               None                           None
#
#   CompCurrentOfcrDirectorsGrp OtherSalariesAndWagesGrp  \
# 0                        None                     None
# 1                        None                     None
#
#   PensionPlanContributionsGrp OtherEmployeeBenefitsGrp PayrollTaxesGrp  \
# 0                        None                     None            None
# 1                        None                     None            None
#
#   FeesForServicesOtherGrp AdvertisingGrp TravelGrp InterestGrp  \
# 0                    None           None      None        None
# 1                    None           None      None        None
#
#   DepreciationDepletionGrp SavingsAndTempCashInvstGrp AccountsReceivableGrp  \
# 0                     None                       None                  None
# 1                     None                       None                  None
#
#   InventoriesForSaleOrUseGrp PrepaidExpensesDefrdChargesGrp  \
# 0                       None                           None
# 1                       None                           None
#
#   LandBldgEquipCostOrOtherBssAmt LandBldgEquipAccumDeprecAmt  \
# 0                           None                        None
# 1                           None                        None
#
#   LandBldgEquipBasisNetGrp InvestmentsOtherSecuritiesGrp IntangibleAssetsGrp  \
# 0                     None                          None                None
# 1                     None                          None                None
#
#   AccountsPayableAccrExpnssGrp DeferredRevenueGrp  \
# 0                         None               None
# 1                         None               None
#
#   MortgNotesPyblScrdInvstPropGrp OtherLiabilitiesGrp  \
# 0                           None                None
# 1                           None                None
#
#   OrganizationFollowsSFAS117Ind UnrestrictedNetAssetsGrp  \
# 0                          <NA>                     None
# 1                          <NA>                     None
#
#   TemporarilyRstrNetAssetsGrp InfoInScheduleOPartXIInd  \
# 0                        None                     <NA>
# 1                        None                     <NA>
#
#   NetUnrlzdGainsLossesInvstAmt InfoInScheduleOPartXIIInd AuditCommitteeInd  \
# 0                         None                      <NA>              None
# 1                         None                      <NA>              None
#
#   AllAffiliatesIncludedInd GrantsToDomesticOrgsGrp ForeignGrantsGrp  \
# 0                     None                    None             None
# 1                     None                    None             None
#
#   BenefitsToMembersGrp CompDisqualPersonsGrp FeesForServicesManagementGrp  \
# 0                 None                  None                         None
# 1                 None                  None                         None
#
#   FeesForServicesLegalGrp FeesForServicesLobbyingGrp  \
# 0                    None                       None
# 1                    None                       None
#
#   FeesForSrvcInvstMgmntFeesGrp RoyaltiesGrp OccupancyGrp  \
# 0                         None         None         None
# 1                         None         None         None
#
#   PymtTravelEntrtnmntPubOfclGrp PaymentsToAffiliatesGrp  \
# 0                          None                    None
# 1                          None                    None
#
#   PledgesAndGrantsReceivableGrp RcvblFromDisqualifiedPrsnGrp  \
# 0                          None                         None
# 1                          None                         None
#
#   OthNotesLoansReceivableNetGrp InvestmentsPubTradedSecGrp  \
# 0                          None                       None
# 1                          None                       None
#
#   InvestmentsProgramRelatedGrp OtherAssetsTotalGrp  \
# 0                         None                None
# 1                         None                None
#
#   TotalOtherProgSrvcExpenseAmt InfoInScheduleOPartVInd  \
# 0                         None                    <NA>
# 1                         None                    <NA>
#
#   MethodOfAccountingAccrualInd NoncashContributionsAmt GrantsPayableGrp  \
# 0                         <NA>                    None             None
# 1                         <NA>                    None             None
#
#   PermanentlyRstrNetAssetsGrp TaxExemptBondLiabilitiesGrp  \
# 0                        None                        None
# 1                        None                        None
#
#   EscrowAccountLiabilityGrp LoansFromOfficersDirectorsGrp  \
# 0                      None                          None
# 1                      None                          None
#
#   UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 0                          None                      None
# 1                          None                      None
#
#   FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd OtherWebsiteInd  \
# 0                          None                         None            <NA>
# 1                          None                         None            <NA>
#
#   AddressChangeInd WrittenPolicyOrProcedureInd RelatedOrganizationsAmt  \
# 0             <NA>                        None                    None
# 1             <NA>                        None                    None
#
#   TotalOtherProgSrvcRevenueAmt OwnWebsiteInd TotalJointCostsGrp  \
# 0                         None          <NA>               None
# 1                         None          <NA>               None
#
#   DonatedServicesAndUseFcltsAmt LegalDomicileCountryCd  \
# 0                          None                   None
# 1                          None                   None
#
#   InfoInScheduleOPartIXInd TypeOfOrganizationTrustInd FinalReturnInd  \
# 0                     <NA>                       <NA>           <NA>
# 1                     <NA>                       <NA>           <NA>
#
#   ContractTerminationInd InfoInScheduleOPartXInd GroupExemptionNum  \
# 0                   <NA>                    <NA>              None
# 1                   <NA>                    <NA>              None
#
#   InfoInScheduleOPartVIIInd FederatedCampaignsAmt TypeOfOrganizationOtherInd  \
# 0                      <NA>                  None                       <NA>
# 1                      <NA>                  None                       <NA>
#
#   OtherOrganizationDsc InfoInScheduleOPartVIIIInd TypeOfOrganizationAssocInd  \
# 0                 None                       <NA>                       <NA>
# 1                 None                       <NA>                       <NA>
#
#   InitialReturnInd GamingGrossIncomeAmt GamingDirectExpensesAmt  \
# 0             <NA>                 None                    None
# 1             <NA>                 None                    None
#
#   MethodOfAccountingOtherInd InvestmentExpenseAmt Organization501cInd  \
# 0                       <NA>                 None                <NA>
# 1                       <NA>                 None                <NA>
#
#   Organization4947a1NotPFInd AmendedReturnInd SpecialConditionDesc ActivityCd  \
# 0                       <NA>             <NA>                 None       None
# 1                       <NA>             <NA>                 None       None
#
#                    Timestamp TaxPeriodEndDate TaxPeriodBeginDate  \
# 0  2011-11-09T06:41:09-06:00       2010-12-31         2010-01-01
# 1  2011-11-09T07:32:06-08:00       2011-06-30         2010-07-01
#
#                                                                                                                         Officer  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
# 1                                         {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
#
#   TaxYear F9_00_HD_BUILD_TIME_STAMP ReturnTs TaxPeriodEndDt TaxPeriodBeginDt  \
# 0    2010      2016-02-24 21:20:13Z     None           None             None
# 1    2010      2016-02-24 21:20:13Z     None           None             None
#
#   BusinessOfficerGrp TaxYr fiscal_year        EIN  \
# 0               None  None        None  232705170
# 1               None  None        None  581805618
#
#                                                                                                         Name  \
# 0  {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}
# 1        {'BusinessNameLine1': 'TORRINGTON VOA ELDERLY HOUSING INC', 'BusinessNameLine2': 'BELL PARK TOWER'}
#
#   NameControl       Phone  \
# 0        RONA  8565826843
# 1        TORR  7033415000
#
#                                                                                                        USAddress  \
# 0  {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300', 'City': 'BETHLEHEM', 'State': 'PA', 'ZIPCode': '18017'}
# 1                  {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA', 'State': 'VA', 'ZIPCode': '22314'}
#
#   ForeignAddress InCareOfName BusinessName BusinessNameControlTxt PhoneNum  \
# 0           None         None         None                   None     None
# 1           None         None         None                   None     None
#
#   InCareOfNm ForeignPhoneNum
# 0       None            None
# 1       None            None

# %% [markdown]
# #### Traditional method

# %%
#%%time
#import datetime
#print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
#df.to_pickle('all NEW filings February 2024 - all control variables (renamed).pkl.gz', compression='gzip')
# Out:
# Current date and time :  2024-03-29 11:54:17
#
# CPU times: total: 25min 15s
# Wall time: 27min 6s

# %% [markdown]
# #### Re-read in DF
# In case you took a break or the notebook failed somewhere below, you could come back here and re-read the updated file and start from here.

# %%
#%%time
#import datetime
#print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
#df = pd.read_pickle('all NEW filings February 2024 - all control variables (renamed).pkl.gz', compression='gzip')
#print('# of columns:', len(df.columns))
#print('# of observations:', len(df))
#df[:2]

# %% [markdown]
# # Binarize
# We will now 'binarize' certain variables. Variables that should be made binary are indicated by the *binarize* column in our concordance file -- those columns were inspected in previous iterations of this notebook and then added to the concordance file.
#
# The reason this is necessary is that some years of e-file data have 'True' or 'X' or '1' to indicate 'yes' and 'False' or '0' or blank to indicate no. We will change all the former to '1' and all the latter to '0'.
#
# Note that in the concordance file I use two different values - 'binarize' indicates columns that simply have one or more of the above values, while 'binarize_with_dict' indicates variables where the above values are (for some unknown reason) 'nested' under a JSON dictionary. This will become clearer below once we look at these variables. The frequencies below show that there are 64 variables with the label 'binarize' and 16 with the label 'binarize_with_dict'.

# %%
new_variables_df['binarize'].value_counts()
# Out:
# binarize
# binarize              64
# binarize_with_dict    16
# Name: count, dtype: int64

# %% [markdown]
# <br>We'll create a list of all the updated (standardized) variable names we want to process that have a value of 'binarize' in our concordance file.

# %%
binarize_cols = [c for c in new_variables_df[new_variables_df['binarize']=='binarize']['variable_name_new'].tolist()] 
print(len(binarize_cols))
print(binarize_cols)
# Out:
# 64
# ['F9_00_HD_ADDR_CHANGE', 'F9_00_HD_AMENDED_RETURN', 'F9_00_HD_EXEMPT_STATUS_4847A1', 'F9_00_HD_EXEMPT_STATUS_501C3', 'F9_00_HD_FINAL_RETURN', 'F9_00_HD_GROUP_RETURN', 'F9_00_HD_INITIAL_RETURN', 'F9_00_HD_TYPE_ORG_ASSOCIATION', 'F9_00_HD_TYPE_ORG_CORP', 'F9_00_HD_TYPE_ORG_OTHER', 'F9_00_HD_TYPE_ORG_TRUST', 'F9_01_PC_TERMINATION_CONTRACTION', 'F9_03_PC_PGMSVC_SIGNIF_CHG', 'F9_03_PC_PGMSVC_SIGNIF_NEW', 'F9_03_PZ_SCHEDULE_O_PART3', 'F9_05_EXP_SCHED_O_X', 'F9_05_PC_UNRELATED_BUS_INCOME', 'F9_06_EXP_SCHED_O_X', 'F9_06_PC_990_PROVIDED_GOV_BODY', 'F9_06_PC_ANNUAL_DISC_COVRD_PERS', 'F9_06_PC_CEO_COMPENSTN_PROCESS', 'F9_06_PC_CHANGES_ORGANIZING_DOCS', 'F9_06_PC_CONFLICT_OF_INTEREST', 'F9_06_PC_DECISIONS_SUBJ_APPROVAL', 'F9_06_PC_DELEGATION_MGT_DUTIES', 'F9_06_PC_DELEGATION_OF_MGT', 'F9_06_PC_DOCUMENT_RET_POLICY', 'F9_06_PC_ELECTION_BOARD_MEMBERS', 'F9_06_PC_FAMILY_OR_BUSINESS_REL', 'F9_06_PC_FORM_AVAIL_OWN_WEBSITE', 'F9_06_PC_FORM_UPON_REQUEST', 'F9_06_PC_JOINT_VENTURE_INVESTMNT', 'F9_06_PC_JOINT_VENTURE_POLICY', 'F9_06_PC_LOCAL_CHAPTERS', 'F9_06_PC_MATERIAL_DIVERSION', 'F9_06_PC_MEMBERS_OR_STOCKHOLDERS', 'F9_06_PC_MINUTES_COMMITTEES', 'F9_06_PC_MINUTES_GOVERNING_BODY', 'F9_06_PC_MONITORING_OF_COI_POLICY', 'F9_06_PC_OFFICER_MAILING_ADDRESS', 'F9_06_PC_OTHER_COMPENSTN_PROCESS', 'F9_06_PC_OTHER_WEBSITE', 'F9_06_PC_OWN_WEBSITE', 'F9_06_PC_POLICIES_GOVERN_CHAPTER', 'F9_06_PC_WHISTLEBLOWER_POLICY', 'F9_07_EXP_SCHED_O_X', 'F9_07_PC_COMPENSATION_OTHER_SRCE', 'F9_07_PC_FORMER_OFFICER_LISTED', 'F9_07_PC_NO_LISTED_PERS_COMPENSD', 'F9_07_PC_TOTAL_COMP_GRTR_150K', 'F9_08_EXP_SCHED_O_X', 'F9_09_EXP_SCHED_O_X', 'F9_10_PC_ORG_FOLLOWS_SFAS117', 'F9_10_PC_ORG_NOT_FOLLOW_SFAS117', 'F9_10_SCHED_O_X', 'F9_11_SCHED_O_X', 'F9_12_PC_ACCNT_COMPILE_OR_REVIEW', 'F9_12_PC_ACCTG_METHOD_ACCRUAL', 'F9_12_PC_ACCTG_METHOD_CASH', 'F9_12_PC_AUDIT_COMMITTEE', 'F9_12_PC_FED_GRNT_AUDIT_PERFORMD', 'F9_12_PC_FED_GRNT_AUDIT_REQUIRED', 'F9_12_PC_FINCL_STMTS_AUDITED', 'F9_12_SCHED_O_X']

# %% [markdown]
# <br>Then we'll do the same for the variables that have a value of 'binarize_with_dict'.

# %%
binarize_with_dict_cols = [c for c in new_variables_df[new_variables_df['binarize']=='binarize_with_dict']['variable_name_new'].tolist()] 
print(len(binarize_with_dict_cols))
binarize_with_dict_cols
# Out:
# 16
# ['F9_00_HD_EXEMPT_STATUS_501C',
#  'F9_00_HD_INCLUDES_SUBORD_ORGS',
#  'F9_04_PC_ACTVITIES_VIA_PARTNER',
#  'F9_04_PC_CONTROLLED_ENTITY',
#  'F9_04_PC_DISREGARDED_ENTITY',
#  'F9_04_PC_EXCESS_BENEFIT_TRANS',
#  'F9_04_PC_FR_EVENT_INC_GT_15K',
#  'F9_04_PC_GAMING_INC_GT_15K',
#  'F9_04_PC_LOBBYING_ACTIVITIES',
#  'F9_04_PC_POLITICAL_ACTIVITIES',
#  'F9_04_PC_PRIOR_EXCESS_BEN_TRAN',
#  'F9_04_PC_PROF_FR_EXP_GT_15K',
#  'F9_04_PC_RELATED_ENTITY',
#  'F9_04_PC_TRANS_TO_CNTRLD_ENT',
#  'F9_04_PC_TRANS_WITH_CNTRLD_ENT',
#  'F9_12_PC_ACCTG_METHOD_OTHER']

# %% [markdown]
# <br>Loop over all 64 variables with a 'binarize' value. What we're looking for are any variables that do not fit in the above pattern of values (that is, any variables that are not checkbox or True/False variables. I have previously verified all 64 of these variables, but it is always sound practice to double-check. Values in more recent filings could always change.

# %%
#df = updated_df.copy(deep=True)

# %%
#del updated_df

# %%
gc.collect()
# Out:
# 0

# %%
# %%time
for c in binarize_cols[:2]:
    print(df[df[c].notnull()][c].value_counts().head(), '\n')
# Out:
# F9_00_HD_ADDR_CHANGE
# X    138187
# Name: count, dtype: Int64
#
# F9_00_HD_AMENDED_RETURN
# X    41351
# Name: count, dtype: Int64
#
# CPU times: total: 9.91 s
# Wall time: 10.4 s

# %% [markdown]
# <br>Now look at frequences for the 16 variables with 'binarize_with_dict' values in the *binarize* column. I identified all 16 of these in earlier data verifications. These 16 variables all have values that are 'dictionaries' (as indicated by the curly braces) and are more difficult to parse. Therefore, we will process them separately.

# %%
# %%time 
for c in binarize_with_dict_cols[:2]:
    print(df[df[c].notnull()][c].value_counts()[:10], '\n')
# Out:
# {'@organization501cTypeTxt': '6', '#text': 'X'}     60746
# {'@organization501cTypeTxt': '4', '#text': 'X'}     36718
# {'@organization501cTypeTxt': '5', '#text': 'X'}     29271
# {'@organization501cTypeTxt': '7', '#text': 'X'}     28402
# {'@organization501cTypeTxt': '9', '#text': 'X'}     13876
# {'@organization501cTypeTxt': '8', '#text': 'X'}     12859
# {'@organization501cTypeTxt': '19', '#text': 'X'}    12295
# {'@organization501cTypeTxt': '12', '#text': 'X'}     8731
# {'@organization501cTypeTxt': '13', '#text': 'X'}     6193
# {'@organization501cTypeTxt': '2', '#text': 'X'}      6058
# Name: F9_00_HD_EXEMPT_STATUS_501C, dtype: int64
#
# 1                                                                                    2301
# false                                                                                1155
# true                                                                                  788
# 0                                                                                     356
# {'@referenceDocumentId': 'RetDoc1 RetDoc2', '#text': 'true'}                          145
# {'@referenceDocumentId': 'STM131', '#text': 'true'}                                    95
# {'@referenceDocumentId': 'RetDoc2030100001', '#text': '0'}                             79
# {'@referenceDocumentName': 'AffiliateListing BinaryAttachment', '#text': 'false'}      64
# {'@referenceDocumentId': 'BinaryAttachment-1', '#text': 'true'}                        41
# {'@referenceDocumentId': 'RetDoc1 RetDoc2', '#text': 'false'}                          40
# Name: F9_00_HD_INCLUDES_SUBORD_ORGS, dtype: int64
#
# false                                                                                                            464584
# 0                                                                                                                226934
# {'@referenceDocumentId': 'RetDoc1043400001', '#text': '0'}                                                       113373
# {'@referenceDocumentId': 'IRS990ScheduleR', '#text': 'false'}                                                     32627
# {'@referenceDocumentName': 'IRS990ScheduleR', '#text': 'false'}                                                   12134
# {'@referenceDocumentId': 'RetDoc1043500001', '#text': '0'}                                                         8428
# {'@referenceDocumentId': 'RetDoc6', '#text': 'false'}                                                              7041
# {'@referenceDocumentId': 'IRS990ScheduleR-01', '@referenceDocumentName': 'IRS990ScheduleR', '#text': 'false'}      7035
# {'@referenceDocumentId': 'RetDoc5', '#text': 'false'}                                                              5850
# {'@referenceDocumentId': 'RetDoc7', '#text': 'false'}                                                              4466
# Name: F9_04_PC_ACTVITIES_VIA_PARTNER, dtype: int64
#
# false    527301
# 0        319562
# 1         29660
# true      15457
# Name: F9_04_PC_CONTROLLED_ENTITY, dtype: int64
#
# false                                                                                                            463058
# 0                                                                                                                226460
# {'@referenceDocumentId': 'RetDoc1043400001', '#text': '0'}                                                        98724
# {'@referenceDocumentId': 'IRS990ScheduleR', '#text': 'false'}                                                     29157
# {'@referenceDocumentId': 'RetDoc1043400001', '#text': '1'}                                                        14806
# {'@referenceDocumentName': 'IRS990ScheduleR', '#text': 'false'}                                                   12076
# {'@referenceDocumentId': 'RetDoc1043500001', '#text': '0'}                                                         8449
# {'@referenceDocumentId': 'IRS990ScheduleR-01', '@referenceDocumentName': 'IRS990ScheduleR', '#text': 'false'}      6523
# {'@referenceDocumentId': 'RetDoc6', '#text': 'false'}                                                              6051
# {'@referenceDocumentId': 'RetDoc5', '#text': 'false'}                                                              5394
# Name: F9_04_PC_DISREGARDED_ENTITY, dtype: int64
#
# false                                                                                                            394553
# 0                                                                                                                254137
# {'@referenceDocumentId': 'RetDoc1042800001', '#text': '0'}                                                        23949
# {'@referenceDocumentName': 'IRS990ScheduleL', '#text': 'false'}                                                    9906
# {'@referenceDocumentId': 'IRS990ScheduleL', '#text': 'false'}                                                      8057
# {'@referenceDocumentId': 'IRS990ScheduleL-01', '@referenceDocumentName': 'IRS990ScheduleL', '#text': 'false'}      4354
# {'@referenceDocumentId': 'RetDoc5', '#text': 'false'}                                                              3132
# {'@referenceDocumentId': 'RetDoc4', '#text': 'false'}                                                              2619
# {'@referenceDocumentId': 'RetDoc6', '#text': 'false'}                                                              1879
# {'@referenceDocumentId': 'RetDoc3', '#text': 'false'}                                                              1023
# Name: F9_04_PC_EXCESS_BENEFIT_TRANS, dtype: int64
#
# false                                                                                                           424874
# 0                                                                                                               277842
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '1'}                                                       51703
# {'@referenceDocumentId': 'IRS990ScheduleG', '#text': 'true'}                                                     27075
# {'@referenceDocumentId': '990G', '#text': 'true'}                                                                16699
# {'@referenceDocumentId': 'RetDoc4', '#text': 'true'}                                                             12611
# {'@referenceDocumentId': 'RetDoc5', '#text': 'true'}                                                             11965
# {'@referenceDocumentName': 'IRS990ScheduleG', '#text': 'false'}                                                  10572
# {'@referenceDocumentId': 'IRS990ScheduleG-01', '@referenceDocumentName': 'IRS990ScheduleG', '#text': 'true'}      9910
# {'@referenceDocumentId': 'RetDoc1041200001', '#text': '1'}                                                        6731
# Name: F9_04_PC_FR_EVENT_INC_GT_15K, dtype: int64
#
# false                                                                                                            436948
# 0                                                                                                                282073
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '0'}                                                        49768
# {'@referenceDocumentId': 'IRS990ScheduleG', '#text': 'false'}                                                     25785
# {'@referenceDocumentId': 'RetDoc4', '#text': 'false'}                                                             12279
# {'@referenceDocumentId': 'RetDoc5', '#text': 'false'}                                                             11790
# {'@referenceDocumentName': 'IRS990ScheduleG', '#text': 'false'}                                                   11547
# {'@referenceDocumentId': 'RetDoc1041200001', '#text': '0'}                                                        11117
# {'@referenceDocumentId': 'IRS990ScheduleG-01', '@referenceDocumentName': 'IRS990ScheduleG', '#text': 'false'}      9512
# {'@referenceDocumentId': '990G', '#text': 'true'}                                                                  5896
# Name: F9_04_PC_GAMING_INC_GT_15K, dtype: int64
#
# false                                                                                                           380961
# 0                                                                                                               245535
# {'@referenceDocumentName': 'IRS990ScheduleC', '#text': 'false'}                                                  10611
# {'@referenceDocumentId': 'RetDoc1039700001', '#text': '1'}                                                        9750
# {'@referenceDocumentId': 'RetDoc1039600001', '#text': '1'}                                                        8041
# {'@referenceDocumentId': 'IRS990ScheduleC', '#text': 'true'}                                                      6444
# {'@referenceDocumentId': 'RetDoc3', '#text': 'true'}                                                              1691
# {'@referenceDocumentId': 'RetDoc4', '#text': 'true'}                                                              1135
# {'@referenceDocumentId': '990C', '#text': 'true'}                                                                  935
# {'@referenceDocumentId': 'IRS990ScheduleC-01', '@referenceDocumentName': 'IRS990ScheduleC', '#text': 'true'}       837
# Name: F9_04_PC_LOBBYING_ACTIVITIES, dtype: int64
# false                                                                                                            495838
# 0                                                                                                                302067
# {'@referenceDocumentId': 'RetDoc1039700001', '#text': '0'}                                                        31554
# {'@referenceDocumentName': 'IRS990ScheduleC', '#text': 'false'}                                                   12125
# {'@referenceDocumentId': 'IRS990ScheduleC', '#text': 'false'}                                                     10643
# {'@referenceDocumentId': 'RetDoc1039600001', '#text': '0'}                                                         8557
# {'@referenceDocumentId': 'RetDoc3', '#text': 'false'}                                                              5827
# {'@referenceDocumentId': 'IRS990ScheduleC-01', '@referenceDocumentName': 'IRS990ScheduleC', '#text': 'false'}      4952
# {'@referenceDocumentId': 'RetDoc2', '#text': 'false'}                                                              4819
# {'@referenceDocumentId': 'RetDoc1039500001', '#text': '1'}                                                         4277
# Name: F9_04_PC_POLITICAL_ACTIVITIES, dtype: int64
#
# false                                                                                                            395352
# 0                                                                                                                254161
# {'@referenceDocumentId': 'RetDoc1042800001', '#text': '0'}                                                        23986
# {'@referenceDocumentName': 'IRS990ScheduleL', '#text': 'false'}                                                    9907
# {'@referenceDocumentId': 'IRS990ScheduleL', '#text': 'false'}                                                      8061
# {'@referenceDocumentId': 'IRS990ScheduleL-01', '@referenceDocumentName': 'IRS990ScheduleL', '#text': 'false'}      4337
# {'@referenceDocumentId': 'RetDoc5', '#text': 'false'}                                                              3140
# {'@referenceDocumentId': 'RetDoc4', '#text': 'false'}                                                              2627
# {'@referenceDocumentId': 'RetDoc6', '#text': 'false'}                                                              1887
# {'@referenceDocumentId': 'RetDoc3', '#text': 'false'}                                                              1027
# Name: F9_04_PC_PRIOR_EXCESS_BEN_TRAN, dtype: int64
#
# false                                                                                                            438123
# 0                                                                                                                282605
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '0'}                                                        54539
# {'@referenceDocumentId': 'IRS990ScheduleG', '#text': 'false'}                                                     27080
# {'@referenceDocumentId': 'RetDoc4', '#text': 'false'}                                                             14862
# {'@referenceDocumentId': 'RetDoc5', '#text': 'false'}                                                             12578
# {'@referenceDocumentId': 'IRS990ScheduleG-01', '@referenceDocumentName': 'IRS990ScheduleG', '#text': 'false'}     11974
# {'@referenceDocumentName': 'IRS990ScheduleG', '#text': 'false'}                                                   11798
# {'@referenceDocumentId': 'RetDoc1041200001', '#text': '1'}                                                         9362
# {'@referenceDocumentId': 'RetDoc3', '#text': 'false'}                                                              5864
# Name: F9_04_PC_PROF_FR_EXP_GT_15K, dtype: int64
#
# false                                                                                                           452537
# 0                                                                                                               221816
# {'@referenceDocumentId': 'RetDoc1043400001', '#text': '1'}                                                      107959
# {'@referenceDocumentId': 'IRS990ScheduleR', '#text': 'true'}                                                     35980
# {'@referenceDocumentName': 'IRS990ScheduleR', '#text': 'false'}                                                  11299
# {'@referenceDocumentId': 'RetDoc1043500001', '#text': '1'}                                                        8319
# {'@referenceDocumentId': '990R', '#text': 'true'}                                                                 7499
# {'@referenceDocumentId': 'IRS990ScheduleR-01', '@referenceDocumentName': 'IRS990ScheduleR', '#text': 'true'}      6704
# {'@referenceDocumentId': 'RetDoc6', '#text': 'true'}                                                              6664
# {'@referenceDocumentId': 'RetDoc5', '#text': 'true'}                                                              5609
# Name: F9_04_PC_RELATED_ENTITY, dtype: int64
#
# false                                                                                                            346762
# 0                                                                                                                175291
# {'@referenceDocumentId': 'RetDoc1043400001', '#text': '0'}                                                        81227
# {'@referenceDocumentId': 'IRS990ScheduleR', '#text': 'false'}                                                     20786
# {'@referenceDocumentName': 'IRS990ScheduleR', '#text': 'false'}                                                   10279
# {'@referenceDocumentId': 'RetDoc1043500001', '#text': '0'}                                                         4930
# {'@referenceDocumentId': 'RetDoc6', '#text': 'false'}                                                              4845
# {'@referenceDocumentId': 'IRS990ScheduleR-01', '@referenceDocumentName': 'IRS990ScheduleR', '#text': 'false'}      4350
# {'@referenceDocumentId': 'RetDoc5', '#text': 'false'}                                                              3795
# {'@referenceDocumentId': 'RetDoc1043400001', '#text': '1'}                                                         3750
# Name: F9_04_PC_TRANS_TO_CNTRLD_ENT, dtype: int64
#
# false                                                                                                            62445
# {'@referenceDocumentId': 'RetDoc1043400001', '#text': '0'}                                                       13127
# {'@referenceDocumentId': 'RetDoc1043400001', '#text': '1'}                                                       12494
# {'@referenceDocumentId': 'IRS990ScheduleR', '#text': 'true'}                                                      6102
# {'@referenceDocumentId': 'IRS990ScheduleR-01', '@referenceDocumentName': 'IRS990ScheduleR', '#text': 'false'}     2737
# {'@referenceDocumentId': 'IRS990ScheduleR', '#text': 'false'}                                                     2440
# {'@referenceDocumentName': 'IRS990ScheduleR', '#text': 'false'}                                                   1991
# {'@referenceDocumentId': 'RetDoc1043500001', '#text': '0'}                                                        1811
# 0                                                                                                                 1374
# {'@referenceDocumentId': 'RetDoc1043500001', '#text': '1'}                                                        1193
# Name: F9_04_PC_TRANS_WITH_CNTRLD_ENT, dtype: int64
#
# {'@methodOfAccountingOtherDesc': 'MODIFIED CASH', '#text': 'X'}          7606
# {'@methodOfAccountingOtherDesc': 'Modified Cash', '#text': 'X'}          2237
# X                                                                        1560
# {'@methodOfAccountingOtherDesc': 'MODIFIED CASH BASIS', '#text': 'X'}    1046
# {'@methodOfAccountingOtherDesc': 'Modified Cash Basis', '#text': 'X'}     631
# {'@methodOfAccountingOtherDesc': 'modified cash', '#text': 'X'}           526
# {'@methodOfAccountingOtherDesc': 'HYBRID', '#text': 'X'}                  509
# {'@methodOfAccountingOtherDesc': 'Modified cash', '#text': 'X'}           450
# {'@methodOfAccountingOtherDesc': 'MODIFIED CAS', '#text': 'X'}            372
# {'@methodOfAccountingOtherDesc': 'Modified Accrual', '#text': 'X'}        227
# Name: F9_12_PC_ACCTG_METHOD_OTHER, dtype: int64
#
# CPU times: total: 2min 4s
# Wall time: 2min 7s

# %% [markdown]
# ##### Check *F9_12_PC_ACCTG_METHOD_OTHER*, *F9_00_HD_EXEMPT_STATUS_501C*, and *F9_00_HD_INCLUDES_SUBORD_ORGS*
# Based on the following frequencies,for *F9_12_PC_ACCTG_METHOD_OTHER* do an *np.where* and make it 'other'. Leave *F9_00_HD_EXEMPT_STATUS_501C* and *F9_00_HD_INCLUDES_SUBORD_ORGS* alone.

# %%
# %%time
print(df[df['F9_00_HD_EXEMPT_STATUS_501C'].notnull()]['F9_00_HD_EXEMPT_STATUS_501C'].value_counts().head())
# Out:
# F9_00_HD_EXEMPT_STATUS_501C
# {"@organization501cTypeTxt": "6", "#text": "X"}    198899
# {"@organization501cTypeTxt": "4", "#text": "X"}    110643
# {"@organization501cTypeTxt": "5", "#text": "X"}     91522
# {"@organization501cTypeTxt": "7", "#text": "X"}     87154
# {"@organization501cTypeTxt": "9", "#text": "X"}     44800
# Name: count, dtype: Int64
# CPU times: total: 15.6 s
# Wall time: 16 s

# %% [markdown]
# #### Fix *F9_00_HD_EXEMPT_STATUS_501C*
# We'll write a custom function for processing this variable

# %%
def func(x, key1, key2):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    elif key1 in x.keys():
        return x[key1]
    elif key2 in x.keys():
        return x[key2]
    else:
        return np.nan

# %% [markdown]
# <br>Apply the function and then show updated frequencies. You can see that the 'dictionaries' have all disappeared and what remains is the 501(c) value.

# %%
df['F9_00_HD_EXEMPT_STATUS_501C'].dtype
# Out:
# string[python]

# %%
import ast
import json

def convert_to_dict(x):
    """Convert string to dictionary if needed"""
    if pd.isnull(x):
        return np.nan
    
    if isinstance(x, dict):
        return x
        
    try:
        # Try using json.loads first (safer and handles more formats)
        return json.loads(x)
    except:
        try:
            # Fallback to ast.literal_eval
            return ast.literal_eval(x)
        except:
            return np.nan

# %%
# %%time
# Apply the conversion to each column directly
for col in binarize_with_dict_cols:
    if col in df.columns:
        print(f"Converting {col}...")
        # Apply the exact same approach that worked for the individual column
        df[col] = df[col].apply(convert_to_dict)
        
        # Show a quick verification
        #sample = df[df[col].notnull()][col].head(1).values
        #print(f"Sample after conversion: {sample}")
        #print(f"Type after conversion: {type(sample[0]) if len(sample) > 0 else 'N/A'}")
# Out:
# Converting F9_00_HD_EXEMPT_STATUS_501C...
# Converting F9_00_HD_INCLUDES_SUBORD_ORGS...
# Converting F9_04_PC_ACTVITIES_VIA_PARTNER...
# Converting F9_04_PC_CONTROLLED_ENTITY...
# Converting F9_04_PC_DISREGARDED_ENTITY...
# Converting F9_04_PC_EXCESS_BENEFIT_TRANS...
# Converting F9_04_PC_FR_EVENT_INC_GT_15K...
# Converting F9_04_PC_GAMING_INC_GT_15K...
# Converting F9_04_PC_LOBBYING_ACTIVITIES...
# Converting F9_04_PC_POLITICAL_ACTIVITIES...
# Converting F9_04_PC_PRIOR_EXCESS_BEN_TRAN...
# Converting F9_04_PC_PROF_FR_EXP_GT_15K...
# Converting F9_04_PC_RELATED_ENTITY...
# Converting F9_04_PC_TRANS_TO_CNTRLD_ENT...
# Converting F9_04_PC_TRANS_WITH_CNTRLD_ENT...
# Converting F9_12_PC_ACCTG_METHOD_OTHER...

# %%
#%%time
## First convert strings to dictionaries
#df['F9_00_HD_EXEMPT_STATUS_501C'] = df['F9_00_HD_EXEMPT_STATUS_501C'].apply(convert_to_dict)
# Out:
# CPU times: total: 5.5 s
# Wall time: 5.69 s

# %%
df['F9_00_HD_EXEMPT_STATUS_501C'].dtype
# Out:
# dtype('O')

# %%
if sample_col in df.columns:
    # Print a few non-null values to see what we're working with
    sample_values = df[df[sample_col].notnull()][sample_col].head(3).tolist()
    print(f"Sample values from {sample_col}:")
    for val in sample_values:
        print(f"Value: {val}")
        print(f"Type: {type(val)}")

    ## Try the conversion on just these values to see what happens
    #print("\nTrying conversion:")
    #for val in sample_values:
    #    converted = convert_to_dict(val)
    #    print(f"Original: {val}")
    #    print(f"Converted: {converted}")
    #    print(f"Converted type: {type(converted)}")
    #    print("---")
# Out:
# Sample values from F9_00_HD_EXEMPT_STATUS_501C:
# Value: {'@typeOf501cOrganization': '7', '#text': 'X'}
# Type: <class 'dict'>
# Value: {'@typeOf501cOrganization': '4', '#text': 'X'}
# Type: <class 'dict'>
# Value: {'@typeOf501cOrganization': '6', '#text': 'X'}
# Type: <class 'dict'>

# %%
#df = df.drop('F9_00_HD_EXEMPT_STATUS_501C_dict', axis=1)

# %%
# %%time
df['F9_00_HD_EXEMPT_STATUS_501C'] = df['F9_00_HD_EXEMPT_STATUS_501C'][:].apply(func, 
                            key1='@organization501cTypeTxt', key2 ='@typeOf501cOrganization')
# Out:
# CPU times: total: 6.73 s
# Wall time: 7.06 s

# %%
df['F9_00_HD_EXEMPT_STATUS_501C'].value_counts()[:10]
# Out:
# F9_00_HD_EXEMPT_STATUS_501C
# 6     231858
# 4     127070
# 5     106056
# 7     100604
# 9      54868
# 8      42206
# 19     40678
# 12     33678
# 3      28339
# 14     28043
# Name: count, dtype: int64

# %% [markdown]
# #### Fix other 'dictionary' variables

# %%
binarize_with_dict_cols
# Out:
# ['F9_00_HD_EXEMPT_STATUS_501C',
#  'F9_00_HD_INCLUDES_SUBORD_ORGS',
#  'F9_04_PC_ACTVITIES_VIA_PARTNER',
#  'F9_04_PC_CONTROLLED_ENTITY',
#  'F9_04_PC_DISREGARDED_ENTITY',
#  'F9_04_PC_EXCESS_BENEFIT_TRANS',
#  'F9_04_PC_FR_EVENT_INC_GT_15K',
#  'F9_04_PC_GAMING_INC_GT_15K',
#  'F9_04_PC_LOBBYING_ACTIVITIES',
#  'F9_04_PC_POLITICAL_ACTIVITIES',
#  'F9_04_PC_PRIOR_EXCESS_BEN_TRAN',
#  'F9_04_PC_PROF_FR_EXP_GT_15K',
#  'F9_04_PC_RELATED_ENTITY',
#  'F9_04_PC_TRANS_TO_CNTRLD_ENT',
#  'F9_04_PC_TRANS_WITH_CNTRLD_ENT',
#  'F9_12_PC_ACCTG_METHOD_OTHER']

# %% [markdown]
# <br>The remaining *binarize_with_dict* variables have the core values nested in the dictionary's 'text' key. Let's write a function to allow us to grab the value for the 'text' key in each dictionary.

# %%
def func_text(x, key1):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    
    elif type(x)==dict: 
        if key1 in x.keys():
            return x[key1]
    else:
        return x

# %% [markdown]
# <br>Apply the function to the first variable.

# %%
df['F9_00_HD_INCLUDES_SUBORD_ORGS'] = df['F9_00_HD_INCLUDES_SUBORD_ORGS'][:].apply(func_text, 
                            key1='#text')

# %% [markdown]
# <br>Now when we run the frequencies for this variable we see that there are four values -- just like the 'binarize' variables.

# %%
df['F9_00_HD_INCLUDES_SUBORD_ORGS'].value_counts()
# Out:
# F9_00_HD_INCLUDES_SUBORD_ORGS
# False    292935
# True      17788
# false      1157
# true        888
# 0           647
# 1           114
# Name: count, dtype: int64

# %%
df[binarize_with_dict_cols].dtypes
# Out:
# F9_00_HD_INCLUDES_SUBORD_ORGS     object
# F9_04_PC_ACTVITIES_VIA_PARTNER    object
# F9_04_PC_CONTROLLED_ENTITY        object
# F9_04_PC_DISREGARDED_ENTITY       object
# F9_04_PC_EXCESS_BENEFIT_TRANS     object
# F9_04_PC_FR_EVENT_INC_GT_15K      object
# F9_04_PC_GAMING_INC_GT_15K        object
# F9_04_PC_LOBBYING_ACTIVITIES      object
# F9_04_PC_POLITICAL_ACTIVITIES     object
# F9_04_PC_PRIOR_EXCESS_BEN_TRAN    object
# F9_04_PC_PROF_FR_EXP_GT_15K       object
# F9_04_PC_RELATED_ENTITY           object
# F9_04_PC_TRANS_TO_CNTRLD_ENT      object
# F9_04_PC_TRANS_WITH_CNTRLD_ENT    object
# dtype: object

# %% [markdown]
# <br>Now let's apply the function and show frequencies for each of the remaining *binarize_with_dict* variables in turn.

# %%
df['F9_04_PC_EXCESS_BENEFIT_TRANS'] = df['F9_04_PC_EXCESS_BENEFIT_TRANS'][:].apply(func_text, 
                            key1='#text')

# %%
df['F9_04_PC_EXCESS_BENEFIT_TRANS'].value_counts()
# Out:
# F9_04_PC_EXCESS_BENEFIT_TRANS
# false    1720098
# 0        1128172
# true         418
# 1            340
# False          4
# Name: count, dtype: int64

# %%
# %%time
df['F9_04_PC_FR_EVENT_INC_GT_15K'] = df['F9_04_PC_FR_EVENT_INC_GT_15K'][:].apply(func_text, 
                            key1='#text')
# Out:
# CPU times: total: 6.41 s
# Wall time: 6.6 s

# %%
df['F9_04_PC_FR_EVENT_INC_GT_15K'].value_counts()
# Out:
# F9_04_PC_FR_EVENT_INC_GT_15K
# false    1643695
# 0        1079137
# true      428605
# 1         317528
# False         40
# 1              3
# Name: count, dtype: int64

# %%
# %%time
df['F9_04_PC_GAMING_INC_GT_15K'] = df['F9_04_PC_GAMING_INC_GT_15K'][:].apply(func_text, 
                            key1='#text')
# Out:
# CPU times: total: 6.03 s
# Wall time: 6.23 s

# %%
df['F9_04_PC_GAMING_INC_GT_15K'].value_counts()
# Out:
# F9_04_PC_GAMING_INC_GT_15K
# false    1993496
# 0        1369654
# true       78804
# 1          27011
# False         43
# Name: count, dtype: int64

# %%
# %%time
df['F9_04_PC_PRIOR_EXCESS_BEN_TRAN'] = df['F9_04_PC_PRIOR_EXCESS_BEN_TRAN'][:].apply(func_text, 
                            key1='#text')
# Out:
# CPU times: total: 4.98 s
# Wall time: 5.14 s

# %%
df['F9_04_PC_PRIOR_EXCESS_BEN_TRAN'].value_counts()
# Out:
# F9_04_PC_PRIOR_EXCESS_BEN_TRAN
# false    1721545
# 0        1128272
# true         393
# 1            209
# False          4
# Name: count, dtype: int64

# %%
# %%time
df['F9_04_PC_PROF_FR_EXP_GT_15K'] = df['F9_04_PC_PROF_FR_EXP_GT_15K'][:].apply(func_text, 
                            key1='#text')
# Out:
# CPU times: total: 6.03 s
# Wall time: 6.2 s

# %%
df['F9_04_PC_FR_EVENT_INC_GT_15K'].value_counts()
# Out:
# F9_04_PC_FR_EVENT_INC_GT_15K
# false    1643695
# 0        1079137
# true      428605
# 1         317528
# False         40
# 1              3
# Name: count, dtype: int64

# %%
# %%time
df['F9_04_PC_ACTVITIES_VIA_PARTNER'] = df['F9_04_PC_ACTVITIES_VIA_PARTNER'][:].apply(func_text, 
                            key1='#text')
# Out:
# CPU times: total: 6.5 s
# Wall time: 6.64 s

# %%
df['F9_04_PC_ACTVITIES_VIA_PARTNER'].value_counts()
# Out:
# F9_04_PC_ACTVITIES_VIA_PARTNER
# false    2071549
# 0        1395447
# 1           1245
# true         767
# Name: count, dtype: int64

# %%
# %%time
df['F9_04_PC_CONTROLLED_ENTITY'] = df['F9_04_PC_CONTROLLED_ENTITY'][:].apply(func_text, 
                            key1='#text')
# Out:
# CPU times: total: 3.97 s
# Wall time: 4.18 s

# %%
df['F9_04_PC_CONTROLLED_ENTITY'].value_counts()
# Out:
# F9_04_PC_CONTROLLED_ENTITY
# False    3061951
# 1         177057
# false     119283
# 0          94343
# 1           9963
# true        6411
# Name: count, dtype: int64

# %%
# %%time
df['F9_04_PC_DISREGARDED_ENTITY'] = df['F9_04_PC_DISREGARDED_ENTITY'][:].apply(func_text, 
                            key1='#text')
# Out:
# CPU times: total: 6.8 s
# Wall time: 7.09 s

# %%
df['F9_04_PC_DISREGARDED_ENTITY'].value_counts()
# Out:
# F9_04_PC_DISREGARDED_ENTITY
# false    2035297
# 0        1339639
# 1          57053
# true       37019
# Name: count, dtype: int64

# %%
# %%time
df['F9_04_PC_LOBBYING_ACTIVITIES'] = df['F9_04_PC_LOBBYING_ACTIVITIES'][:].apply(func_text, 
                            key1='#text')
# Out:
# CPU times: total: 4.44 s
# Wall time: 4.65 s

# %%
df['F9_04_PC_LOBBYING_ACTIVITIES'].value_counts()
# Out:
# F9_04_PC_LOBBYING_ACTIVITIES
# false    1589524
# 0         999903
# 1          86110
# true       56722
# 0             22
# Name: count, dtype: int64

# %%
# %%time
df['F9_04_PC_POLITICAL_ACTIVITIES'] = df['F9_04_PC_POLITICAL_ACTIVITIES'][:].apply(func_text, 
                            key1='#text')
# Out:
# CPU times: total: 4.84 s
# Wall time: 5.17 s

# %%
df['F9_04_PC_POLITICAL_ACTIVITIES'].value_counts()
# Out:
# F9_04_PC_POLITICAL_ACTIVITIES
# false    2054355
# 0        1380007
# true       17956
# 1          16682
# False          8
# Name: count, dtype: int64

# %%
# %%time
df['F9_04_PC_RELATED_ENTITY'] = df['F9_04_PC_RELATED_ENTITY'][:].apply(func_text, 
                            key1='#text')
# Out:
# CPU times: total: 6.64 s
# Wall time: 6.88 s

# %%
df['F9_04_PC_RELATED_ENTITY'].value_counts()
# Out:
# F9_04_PC_RELATED_ENTITY
# false    1745005
# 0         879575
# 1         517117
# true      327311
# Name: count, dtype: int64

# %%
# %%time
df['F9_04_PC_TRANS_TO_CNTRLD_ENT'] = df['F9_04_PC_TRANS_TO_CNTRLD_ENT'][:].apply(func_text, 
                            key1='#text')
# Out:
# CPU times: total: 6.12 s
# Wall time: 6.34 s

# %%
df['F9_04_PC_TRANS_TO_CNTRLD_ENT'].value_counts()
# Out:
# F9_04_PC_TRANS_TO_CNTRLD_ENT
# false    1504504
# 0        1067944
# 1          18148
# true       13565
# 0              1
# Name: count, dtype: int64

# %%
# %%time
df['F9_04_PC_TRANS_WITH_CNTRLD_ENT'] = df['F9_04_PC_TRANS_WITH_CNTRLD_ENT'][:].apply(func_text, 
                            key1='#text')
# Out:
# CPU times: total: 4.67 s
# Wall time: 4.91 s

# %%
df['F9_04_PC_TRANS_WITH_CNTRLD_ENT'].value_counts()
# Out:
# F9_04_PC_TRANS_WITH_CNTRLD_ENT
# false    624181
# 0        177129
# 1         59556
# true      51225
# Name: count, dtype: int64

# %% [markdown]
# #### Fix *F9_12_PC_ACCTG_METHOD_OTHER*
# Write function to process this variable

# %%
def func_text2(x, key1, key2):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    
    elif type(x)==dict: 
        if key1 in x.keys():
            return x[key1]
        elif key2 in x.keys():
            return x[key2]
    else:
        return x

# %%
# %%time
df['F9_12_PC_ACCTG_METHOD_OTHER'] = df['F9_12_PC_ACCTG_METHOD_OTHER'][:].apply(func_text2, 
                            key1='@note', key2='@methodOfAccountingOtherDesc')
# Out:
# CPU times: total: 4.33 s
# Wall time: 4.45 s

# %% [markdown]
# <br>We'll now look at the frequencies for all the variables in our *binarize_with_dict* list. From this we'll see which ones now need to be binarized.

# %%
for c in binarize_with_dict_cols[:1]:
    print(df[df[c].notnull()][c].value_counts()[:10], '\n')
# Out:
# F9_00_HD_EXEMPT_STATUS_501C
# 6     231858
# 4     127070
# 5     106056
# 7     100604
# 9      54868
# 8      42206
# 19     40678
# 12     33678
# 3      28339
# 14     28043
# Name: count, dtype: int64

# %% [markdown]
# ##### Remove two variables from *binarize_with_dict_cols*
# These have already been processed above (and are not True/False variables). The remaining variables will be processed below with the other 'binarize' variables.

# %%
gc.collect()
# Out:
# 1495

# %%
print(len(binarize_with_dict_cols))
binarize_with_dict_cols.remove('F9_12_PC_ACCTG_METHOD_OTHER') 
binarize_with_dict_cols.remove('F9_00_HD_EXEMPT_STATUS_501C')
print(len(binarize_with_dict_cols))
# Out:
# 16
# 14

# %% [markdown]
# #### Save DF

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df.to_feather('D:/all_filings_april_2025_all_controls.feather')
# Out:
# Current date and time :  2025-04-16 23:47:12
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# File <timed exec>:3
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:2938, in DataFrame.to_feather(self, path, **kwargs)
#    2910 """
#    2911 Write a DataFrame to the binary Feather format.
#    2912
#    (...)
#    2934 >>> df.to_feather("file.feather")  # doctest: +SKIP
#    2935 """
#    2936 from pandas.io.feather_format import to_feather
# -> 2938 to_feather(self, path, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\feather_format.py:66, in to_feather(df, path, storage_options, **kwargs)
#      61     raise ValueError("feather only support IO with DataFrames")
#      63 with get_handle(
#      64     path, "wb", storage_options=storage_options, is_text=False
#      65 ) as handles:
# ---> 66     feather.write_feather(df, handles.handle, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pyarrow\feather.py:156, in write_feather(df, dest, compression, compression_level, chunksize, version)
#     153 else:
#     154     raise ValueError("Version value should either be 1 or 2")
# --> 156 table = Table.from_pandas(df, preserve_index=preserve_index)
#     158 if version == 1:
#     159     # Version 1 does not chunking
#     160     for i, name in enumerate(table.schema.names):
#
# File ~\anaconda3\lib\site-packages\pyarrow\table.pxi:4751, in pyarrow.lib.Table.from_pandas()
#
# File ~\anaconda3\lib\site-packages\pyarrow\pandas_compat.py:652, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     650     for i, maybe_fut in enumerate(arrays):
#     651         if isinstance(maybe_fut, futures.Future):
# --> 652             arrays[i] = maybe_fut.result()
#     654 types = [x.type for x in arrays]
#     656 if schema is None:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~\anaconda3\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~\anaconda3\lib\site-packages\pyarrow\pandas_compat.py:626, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     621 except (pa.ArrowInvalid,
#     622         pa.ArrowNotImplementedError,
#     623         pa.ArrowTypeError) as e:
#     624     e.args += ("Conversion failed for column {!s} with type {!s}"
#     625                .format(col.name, col.dtype),)
# --> 626     raise e
#     627 if not field_nullable and result.null_count > 0:
#     628     raise ValueError("Field {} was non-nullable but pandas column "
#     629                      "had {} null values".format(str(field),
#     630                                                  result.null_count))
#
# File ~\anaconda3\lib\site-packages\pyarrow\pandas_compat.py:620, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     617     type_ = field.type
#     619 try:
# --> 620     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     621 except (pa.ArrowInvalid,
#     622         pa.ArrowNotImplementedError,
#     623         pa.ArrowTypeError) as e:
#     624     e.args += ("Conversion failed for column {!s} with type {!s}"
#     625                .format(col.name, col.dtype),)
#
# File ~\anaconda3\lib\site-packages\pyarrow\array.pxi:362, in pyarrow.lib.array()
#
# File ~\anaconda3\lib\site-packages\pyarrow\array.pxi:87, in pyarrow.lib._ndarray_to_array()
#
# File ~\anaconda3\lib\site-packages\pyarrow\error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowInvalid: ("Could not convert 'false' with type str: tried to convert to boolean", 'Conversion failed for column F9_00_HD_INCLUDES_SUBORD_ORGS with type object')

# %%
#Use HDF5 format (handles mixed types better than feather):
#df.to_hdf('D:/all_filings_april_2025_all_controls.h5', key='df')

# %%
#Use parquet with string type enforcement:
#df.to_parquet('D:/all_filings_april_2025_all_controls.parquet', 
#             engine='pyarrow', 
#             allow_truncated_timestamps=True)

# %% [markdown]
# #### Create *501c3* variable
# There are two variables to look at here: ``F9_00_HD_EXEMPT_STATUS_501C`` and ``F9_00_HD_EXEMPT_STATUS_501C3``
#
# You can see that there are 5,137 observations with a value of '3' on the first of these variables

# %%
df['F9_00_HD_EXEMPT_STATUS_501C'].value_counts()[:15]
# Out:
# F9_00_HD_EXEMPT_STATUS_501C
# 6     231858
# 4     127070
# 5     106056
# 7     100604
# 9      54868
# 8      42206
# 19     40678
# 12     33678
# 3      28339
# 14     28043
# 2      22782
# 13     21118
# 10     12610
# 25      4660
# 15      1382
# Name: count, dtype: int64

# %% [markdown]
# <br>And there are 665,027 501c3 observations on the second variable

# %%
df['F9_00_HD_EXEMPT_STATUS_501C3'].value_counts()
# Out:
# F9_00_HD_EXEMPT_STATUS_501C3
# X    2609442
# Name: count, dtype: Int64

# %%
df['F9_00_HD_EXEMPT_STATUS_501C3'] = df['F9_00_HD_EXEMPT_STATUS_501C3'].astype('string')

# %%
df['F9_00_HD_EXEMPT_STATUS_501C3'].value_counts()
# Out:
# F9_00_HD_EXEMPT_STATUS_501C3
# X    2609442
# Name: count, dtype: Int64

# %% [markdown]
# <br>Run a cross-tab of the two variables. There's no overlap, so we should expect 5,137 + 1,605,635 = 1,610,772 expected filings with a value of '1' on the ``501c3`` variable we will create.

# %%
pd.crosstab(df['F9_00_HD_EXEMPT_STATUS_501C3'], df['F9_00_HD_EXEMPT_STATUS_501C'])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Fill NaN values with 0 before applying np.where
df['501c3'] = np.where(df['F9_00_HD_EXEMPT_STATUS_501C3'].fillna('').eq('X'), 1, 0)
print(df['501c3'].value_counts(),'\n')
# Out:
# 501c3
# 1    2609442
# 0     859566
# Name: count, dtype: int64

# %%
df['501c3'] = np.where(df['F9_00_HD_EXEMPT_STATUS_501C'].fillna('').eq('3'), 1, df['501c3'])
print(df['501c3'].value_counts())
# Out:
# 501c3
# 1    2637781
# 0     831227
# Name: count, dtype: int64

# %% [markdown]
# <br>We see above that the frequencies for our new variable ``501c3`` are as expected.

# %% [markdown]
# #### Save DF

# %%
#%%time
#import datetime
#print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
#df.to_pickle('all NEW filings February 2024 - all control variables (renamed).pkl.gz', compression='gzip')
# Out:
# Current date and time :  2024-03-29 14:31:43
#
# CPU times: total: 25min 39s
# Wall time: 26min 15s

# %% [markdown]
# # Binarize Columns

# %% [markdown]
# Loop over the all 'binarize' variables. In this loop we're just inspecting the frequencies for each of the 64 variables.

# %%
# %%time
for col in binarize_cols[:2]:
    print(df[col].value_counts(), '\n\n')
# Out:
# F9_00_HD_ADDR_CHANGE
# X    138187
# Name: count, dtype: Int64
#
#
# F9_00_HD_AMENDED_RETURN
# X    41351
# Name: count, dtype: Int64
#
#
# CPU times: total: 46.9 ms
# Wall time: 67.4 ms

# %% [markdown]
# <br>Write a function to make the values binary (0,1)

# %%
def binarize(df, variable):
    print(f"Before – {variable}:\n", df[variable].value_counts(dropna=False).head(), '\n')
    
    # Handle actual booleans
    df[variable] = np.where(df[variable] == True, 1, df[variable])
    df[variable] = np.where(df[variable] == False, 0, df[variable])

    # Handle strings
    df[variable] = np.where(df[variable] == 'true', 1, df[variable])
    df[variable] = np.where(df[variable] == 'false', 0, df[variable])
    df[variable] = np.where(df[variable] == '1', 1, df[variable])
    df[variable] = np.where(df[variable] == '0', 0, df[variable])
    df[variable] = np.where(df[variable] == 'X', 1, df[variable])    

    # Convert to consistent binary int type
    df[variable] = df[variable].astype('Int64')  # Nullable integer type

    print(f"After – {variable}:\n", df[variable].value_counts(dropna=False).head(), '\n')
    return df.sample(10)[['EIN', variable]]

# %% [markdown]
# <br>Run the above function for the six remaining variables in the *binarize_with_dict_cols* list. The ouptut below will show the frequencies for each variable before and after processing. All are successfully converted into 0/1 variables.

# %%
# %%time 
for col in binarize_with_dict_cols:
    binarize(df, col)
# Out:
# Before – F9_00_HD_INCLUDES_SUBORD_ORGS:
#  F9_00_HD_INCLUDES_SUBORD_ORGS
# NaN    3155479
# 0       294739
# 1        18790
# Name: count, dtype: int64
#
# After – F9_00_HD_INCLUDES_SUBORD_ORGS:
#  F9_00_HD_INCLUDES_SUBORD_ORGS
# <NA>    3155479
# 0        294739
# 1         18790
# Name: count, dtype: Int64
#
# Before – F9_04_PC_ACTVITIES_VIA_PARTNER:
#  F9_04_PC_ACTVITIES_VIA_PARTNER
# 0    3466996
# 1       2012
# Name: count, dtype: int64
#
# After – F9_04_PC_ACTVITIES_VIA_PARTNER:
#  F9_04_PC_ACTVITIES_VIA_PARTNER
# 0    3466996
# 1       2012
# Name: count, dtype: Int64
#
# Before – F9_04_PC_CONTROLLED_ENTITY:
#  F9_04_PC_CONTROLLED_ENTITY
# 0    3275577
# 1     193431
# Name: count, dtype: int64
#
# After – F9_04_PC_CONTROLLED_ENTITY:
#  F9_04_PC_CONTROLLED_ENTITY
# 0    3275577
# 1     193431
# Name: count, dtype: Int64
#
# Before – F9_04_PC_DISREGARDED_ENTITY:
#  F9_04_PC_DISREGARDED_ENTITY
# 0    3374936
# 1      94072
# Name: count, dtype: int64
#
# After – F9_04_PC_DISREGARDED_ENTITY:
#  F9_04_PC_DISREGARDED_ENTITY
# 0    3374936
# 1      94072
# Name: count, dtype: Int64
#
# Before – F9_04_PC_EXCESS_BENEFIT_TRANS:
#  F9_04_PC_EXCESS_BENEFIT_TRANS
# 0      2848274
# NaN     619976
# 1          758
# Name: count, dtype: int64
#
# After – F9_04_PC_EXCESS_BENEFIT_TRANS:
#  F9_04_PC_EXCESS_BENEFIT_TRANS
# 0       2848274
# <NA>     619976
# 1           758
# Name: count, dtype: Int64
#
# Before – F9_04_PC_FR_EVENT_INC_GT_15K:
#  F9_04_PC_FR_EVENT_INC_GT_15K
# 0    2722872
# 1     746136
# Name: count, dtype: int64
#
# After – F9_04_PC_FR_EVENT_INC_GT_15K:
#  F9_04_PC_FR_EVENT_INC_GT_15K
# 0    2722872
# 1     746136
# Name: count, dtype: Int64
#
# Before – F9_04_PC_GAMING_INC_GT_15K:
#  F9_04_PC_GAMING_INC_GT_15K
# 0    3363193
# 1     105815
# Name: count, dtype: int64
#
# After – F9_04_PC_GAMING_INC_GT_15K:
#  F9_04_PC_GAMING_INC_GT_15K
# 0    3363193
# 1     105815
# Name: count, dtype: Int64
#
# Before – F9_04_PC_LOBBYING_ACTIVITIES:
#  F9_04_PC_LOBBYING_ACTIVITIES
# 0      2589449
# NaN     736727
# 1       142832
# Name: count, dtype: int64
#
# After – F9_04_PC_LOBBYING_ACTIVITIES:
#  F9_04_PC_LOBBYING_ACTIVITIES
# 0       2589449
# <NA>     736727
# 1        142832
# Name: count, dtype: Int64
#
# Before – F9_04_PC_POLITICAL_ACTIVITIES:
#  F9_04_PC_POLITICAL_ACTIVITIES
# 0    3434370
# 1      34638
# Name: count, dtype: int64
#
# After – F9_04_PC_POLITICAL_ACTIVITIES:
#  F9_04_PC_POLITICAL_ACTIVITIES
# 0    3434370
# 1      34638
# Name: count, dtype: Int64
#
# Before – F9_04_PC_PRIOR_EXCESS_BEN_TRAN:
#  F9_04_PC_PRIOR_EXCESS_BEN_TRAN
# 0      2849821
# NaN     618585
# 1          602
# Name: count, dtype: int64
#
# After – F9_04_PC_PRIOR_EXCESS_BEN_TRAN:
#  F9_04_PC_PRIOR_EXCESS_BEN_TRAN
# 0       2849821
# <NA>     618585
# 1           602
# Name: count, dtype: Int64
#
# Before – F9_04_PC_PROF_FR_EXP_GT_15K:
#  F9_04_PC_PROF_FR_EXP_GT_15K
# 0    3375717
# 1      93291
# Name: count, dtype: int64
#
# After – F9_04_PC_PROF_FR_EXP_GT_15K:
#  F9_04_PC_PROF_FR_EXP_GT_15K
# 0    3375717
# 1      93291
# Name: count, dtype: Int64
#
# Before – F9_04_PC_RELATED_ENTITY:
#  F9_04_PC_RELATED_ENTITY
# 0    2624580
# 1     844428
# Name: count, dtype: int64
#
# After – F9_04_PC_RELATED_ENTITY:
#  F9_04_PC_RELATED_ENTITY
# 0    2624580
# 1     844428
# Name: count, dtype: Int64
#
# Before – F9_04_PC_TRANS_TO_CNTRLD_ENT:
#  F9_04_PC_TRANS_TO_CNTRLD_ENT
# 0      2572449
# NaN     864846
# 1        31713
# Name: count, dtype: int64
#
# After – F9_04_PC_TRANS_TO_CNTRLD_ENT:
#  F9_04_PC_TRANS_TO_CNTRLD_ENT
# 0       2572449
# <NA>     864846
# 1         31713
# Name: count, dtype: Int64
#
# Before – F9_04_PC_TRANS_WITH_CNTRLD_ENT:
#  F9_04_PC_TRANS_WITH_CNTRLD_ENT
# NaN    2556917
# 0       801310
# 1       110781
# Name: count, dtype: int64
#
# After – F9_04_PC_TRANS_WITH_CNTRLD_ENT:
#  F9_04_PC_TRANS_WITH_CNTRLD_ENT
# <NA>    2556917
# 0        801310
# 1        110781
# Name: count, dtype: Int64
#
# CPU times: total: 40.6 s
# Wall time: 41.7 s

# %%
#binarize(df, 'F9_00_HD_INCLUDES_SUBORD_ORGS')
# Out:
# F9_00_HD_INCLUDES_SUBORD_ORGS
# False    294739
# True      18790
# Name: count, dtype: int64
#
# F9_00_HD_INCLUDES_SUBORD_ORGS
# 0    294739
# 1     18790
# Name: count, dtype: int64
#                EIN F9_00_HD_INCLUDES_SUBORD_ORGS
# 1454999  550735567                           NaN
# 2446405  330578620                           NaN
# 2257556  821515568                           NaN
# 3141806  882818905                           NaN
# 2969228  943297380                           NaN
# 450620   453621984                           NaN
# 3433614  232603853                           NaN
# 241872   133560387                           NaN
# 2955765  841893677                           NaN
# 3325722  272718480                           NaN

# %%
binarize_with_dict_cols
# Out:
# ['F9_00_HD_INCLUDES_SUBORD_ORGS',
#  'F9_04_PC_ACTVITIES_VIA_PARTNER',
#  'F9_04_PC_CONTROLLED_ENTITY',
#  'F9_04_PC_DISREGARDED_ENTITY',
#  'F9_04_PC_EXCESS_BENEFIT_TRANS',
#  'F9_04_PC_FR_EVENT_INC_GT_15K',
#  'F9_04_PC_GAMING_INC_GT_15K',
#  'F9_04_PC_LOBBYING_ACTIVITIES',
#  'F9_04_PC_POLITICAL_ACTIVITIES',
#  'F9_04_PC_PRIOR_EXCESS_BEN_TRAN',
#  'F9_04_PC_PROF_FR_EXP_GT_15K',
#  'F9_04_PC_RELATED_ENTITY',
#  'F9_04_PC_TRANS_TO_CNTRLD_ENT',
#  'F9_04_PC_TRANS_WITH_CNTRLD_ENT']

# %%
df['F9_04_PC_CONTROLLED_ENTITY'].value_counts()
# Out:
# F9_04_PC_CONTROLLED_ENTITY
# 0    3275577
# 1     193431
# Name: count, dtype: Int64

# %%
#binarize(df, 'F9_04_PC_CONTROLLED_ENTITY')

# %% [markdown]
# <br>Now run it for the 64 variables in the *binarize_cols* list

# %%
len(binarize_cols)
# Out:
# 64

# %% [markdown]
# # 4/16/2025 - new version of binarize
# - To avert `TypeError: boolean value of NA is ambiguous`
#
# Ah yes — this is a classic `pandas.NA` issue. You're getting this error:
#
# `TypeError: boolean value of NA is ambiguou`s
#
# because you're comparing a column that uses the nullable integer type (Int64, capital I) with a string ('true'), and it's encountering `pd.NA` values during the comparison. Unlike np.nan, pd.NA cannot be evaluated in boolean operations — it's designed to raise an error instead of guessing.
#
# ✅ Best Fix: Coerce everything to string first
# Update your binarize function so it converts the column to strings at the beginning, before doing any comparisons. That way, the pd.NA gets turned into the string "nan" and won’t cause issues.
#
# Why this works:
# - `astype(str)` converts all values to strings, including `pd.NA → 'nan'`
# - `.map({...})` applies clean mapping
# - Unrecognized values (like 'nan') become `NaN`
# - Casting to 'Int64' ensures valid binary or null values

# %%
def binarize(df, variable):
    print("Before:\n", df[variable].value_counts(dropna=False).head(), '\n')

    # Coerce all values to string and normalize
    df[variable] = df[variable].astype(str).str.strip().str.lower()

    # Map known values to binary
    df[variable] = df[variable].map({
        'true': 1,
        '1': 1,
        'x': 1,
        'X': 1,        
        'false': 0,
        '0': 0
    })

    print("After:\n", df[variable].value_counts(dropna=False).head(), '\n')
    
    # Cast to nullable Int64 type (preserves NaNs)
    df[variable] = df[variable].astype('Int64')
    
    return df.sample(5)[['EIN', variable]]

# %%
# %%time
for col in binarize_cols:
    binarize(df, col)
# Out:
# Before:
#  F9_00_HD_ADDR_CHANGE
# <NA>    3330821
# X        138187
# Name: count, dtype: Int64
#
# After:
#  F9_00_HD_ADDR_CHANGE
# NaN    3330821
# 1.0     138187
# Name: count, dtype: int64
#
# Before:
#  F9_00_HD_AMENDED_RETURN
# <NA>    3427657
# X         41351
# Name: count, dtype: Int64
#
# After:
#  F9_00_HD_AMENDED_RETURN
# NaN    3427657
# 1.0      41351
# Name: count, dtype: int64
#
# Before:
#  F9_00_HD_EXEMPT_STATUS_4847A1
# <NA>    3466547
# X          2461
# Name: count, dtype: Int64
#
# After:
#  F9_00_HD_EXEMPT_STATUS_4847A1
# NaN    3466547
# 1.0       2461
# Name: count, dtype: int64
#
# Before:
#  F9_00_HD_EXEMPT_STATUS_501C3
# X       2609442
# <NA>     859566
# Name: count, dtype: Int64
#
# After:
#  F9_00_HD_EXEMPT_STATUS_501C3
# 1.0    2609442
# NaN     859566
# Name: count, dtype: int64
#
# Before:
#  F9_00_HD_FINAL_RETURN
# <NA>    3449629
# X         19379
# Name: count, dtype: Int64
#
# After:
#  F9_00_HD_FINAL_RETURN
# NaN    3449629
# 1.0      19379
# Name: count, dtype: int64
#
# Before:
#  F9_00_HD_GROUP_RETURN
# false    2068591
# 0        1392941
# 1           3751
# true        3725
# Name: count, dtype: int64
#
# After:
#  F9_00_HD_GROUP_RETURN
# 0    3461532
# 1       7476
# Name: count, dtype: int64
#
# Before:
#  F9_00_HD_INITIAL_RETURN
# <NA>    3424859
# X         44149
# Name: count, dtype: Int64
#
# After:
#  F9_00_HD_INITIAL_RETURN
# NaN    3424859
# 1.0      44149
# Name: count, dtype: int64
#
# Before:
#  F9_00_HD_TYPE_ORG_ASSOCIATION
# <NA>    3316652
# X        152356
# Name: count, dtype: Int64
#
# After:
#  F9_00_HD_TYPE_ORG_ASSOCIATION
# NaN    3316652
# 1.0     152356
# Name: count, dtype: int64
#
# Before:
#  F9_00_HD_TYPE_ORG_CORP
# X       3066503
# <NA>     402505
# Name: count, dtype: Int64
#
# After:
#  F9_00_HD_TYPE_ORG_CORP
# 1.0    3066503
# NaN     402505
# Name: count, dtype: int64
#
# Before:
#  F9_00_HD_TYPE_ORG_OTHER
# <NA>    3384373
# X         84635
# Name: count, dtype: Int64
#
# After:
#  F9_00_HD_TYPE_ORG_OTHER
# NaN    3384373
# 1.0      84635
# Name: count, dtype: int64
#
# Before:
#  F9_00_HD_TYPE_ORG_TRUST
# <NA>    3359856
# X        109152
# Name: count, dtype: Int64
#
# After:
#  F9_00_HD_TYPE_ORG_TRUST
# NaN    3359856
# 1.0     109152
# Name: count, dtype: int64
#
# Before:
#  F9_01_PC_TERMINATION_CONTRACTION
# <NA>    3442871
# X         26137
# Name: count, dtype: Int64
#
# After:
#  F9_01_PC_TERMINATION_CONTRACTION
# NaN    3442871
# 1.0      26137
# Name: count, dtype: int64
#
# Before:
#  F9_03_PC_PGMSVC_SIGNIF_CHG
# false    2022885
# 0        1377044
# None       33885
# 1          19539
# true       15655
# Name: count, dtype: int64
#
# After:
#  F9_03_PC_PGMSVC_SIGNIF_CHG
# 0.0    3399929
# 1.0      35194
# NaN      33885
# Name: count, dtype: int64
#
# Before:
#  F9_03_PC_PGMSVC_SIGNIF_NEW
# false    2021234
# 0        1375198
# None       33445
# 1          21400
# true       17731
# Name: count, dtype: int64
#
# After:
#  F9_03_PC_PGMSVC_SIGNIF_NEW
# 0.0    3396432
# 1.0      39131
# NaN      33445
# Name: count, dtype: int64
#
# Before:
#  F9_03_PZ_SCHEDULE_O_PART3
# <NA>    2374968
# X       1094040
# Name: count, dtype: Int64
#
# After:
#  F9_03_PZ_SCHEDULE_O_PART3
# NaN    2374968
# 1.0    1094040
# Name: count, dtype: int64
#
# Before:
#  F9_05_EXP_SCHED_O_X
# <NA>    3401947
# X         67061
# Name: count, dtype: Int64
#
# After:
#  F9_05_EXP_SCHED_O_X
# NaN    3401947
# 1.0      67061
# Name: count, dtype: int64
#
# Before:
#  F9_05_PC_UNRELATED_BUS_INCOME
# false    1914804
# 0        1227405
# 1         169287
# true      157512
# Name: count, dtype: int64
#
# After:
#  F9_05_PC_UNRELATED_BUS_INCOME
# 0    3142209
# 1     326799
# Name: count, dtype: int64
#
# Before:
#  F9_06_EXP_SCHED_O_X
# X       3297779
# <NA>     171229
# Name: count, dtype: Int64
#
# After:
#  F9_06_EXP_SCHED_O_X
# 1.0    3297779
# NaN     171229
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_990_PROVIDED_GOV_BODY
# true     1306153
# 1        1118367
# false     766163
# 0         278325
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_990_PROVIDED_GOV_BODY
# 1    2424520
# 0    1044488
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_ANNUAL_DISC_COVRD_PERS
# None     1160336
# true     1004985
# 1         955952
# false     270827
# 0          76908
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_ANNUAL_DISC_COVRD_PERS
# 1.0    1960937
# NaN    1160336
# 0.0     347735
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_CEO_COMPENSTN_PROCESS
# false    1291344
# true      765630
# 0         704897
# 1         691383
# None       15754
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_CEO_COMPENSTN_PROCESS
# 0.0    1996241
# 1.0    1457013
# NaN      15754
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_CHANGES_ORGANIZING_DOCS
# false    2048177
# 0        1362999
# 1          33693
# true       24139
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_CHANGES_ORGANIZING_DOCS
# 0    3411176
# 1      57832
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_CONFLICT_OF_INTEREST
# true     1123877
# 1        1031849
# false     948439
# 0         364843
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_CONFLICT_OF_INTEREST
# 1    2155726
# 0    1313282
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_DECISIONS_SUBJ_APPROVAL
# false    1782233
# 0        1162163
# true      290083
# 1         234529
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_DECISIONS_SUBJ_APPROVAL
# 0    2944396
# 1     524612
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_DELEGATION_MGT_DUTIES
# false    1987607
# 0        1284190
# 1         112502
# true       84709
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_DELEGATION_MGT_DUTIES
# 0    3271797
# 1     197211
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_DELEGATION_OF_MGT
# false    1987607
# 0        1284190
# 1         112502
# true       84709
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_DELEGATION_OF_MGT
# 0    3271797
# 1     197211
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_DOCUMENT_RET_POLICY
# false    1213158
# true      859158
# 1         843182
# 0         553510
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_DOCUMENT_RET_POLICY
# 0    1766668
# 1    1702340
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_ELECTION_BOARD_MEMBERS
# false    1608198
# 0        1004425
# true      464118
# 1         392267
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_ELECTION_BOARD_MEMBERS
# 0    2612623
# 1     856385
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_FAMILY_OR_BUSINESS_REL
# false    1805384
# 0        1190050
# true      266932
# 1         206642
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_FAMILY_OR_BUSINESS_REL
# 0    2995434
# 1     473574
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_FORM_AVAIL_OWN_WEBSITE
# <NA>    3244763
# X        224245
# Name: count, dtype: Int64
#
# After:
#  F9_06_PC_FORM_AVAIL_OWN_WEBSITE
# NaN    3244763
# 1.0     224245
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_FORM_UPON_REQUEST
# X       3112440
# <NA>     356568
# Name: count, dtype: Int64
#
# After:
#  F9_06_PC_FORM_UPON_REQUEST
# 1.0    3112440
# NaN     356568
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_JOINT_VENTURE_INVESTMNT
# false    2050284
# 0        1373049
# 1          23643
# true       22032
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_JOINT_VENTURE_INVESTMNT
# 0    3423333
# 1      45675
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_JOINT_VENTURE_POLICY
# None     3326679
# false      99576
# 1          18806
# true       17463
# 0           6484
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_JOINT_VENTURE_POLICY
# NaN    3326679
# 0.0     106060
# 1.0      36269
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_LOCAL_CHAPTERS
# false    1991327
# 0        1318642
# true       80989
# 1          78050
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_LOCAL_CHAPTERS
# 0    3309969
# 1     159039
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_MATERIAL_DIVERSION
# false    2070154
# 0        1395517
# true        2162
# 1           1175
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_MATERIAL_DIVERSION
# 0    3465671
# 1       3337
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_MEMBERS_OR_STOCKHOLDERS
# false    1660114
# 0        1030245
# true      412202
# 1         366447
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_MEMBERS_OR_STOCKHOLDERS
# 0    2690359
# 1     778649
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_MINUTES_COMMITTEES
# true     1716504
# 1        1229529
# false     346365
# 0         166808
# None        9802
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_MINUTES_COMMITTEES
# 1.0    2946033
# 0.0     513173
# NaN       9802
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_MINUTES_GOVERNING_BODY
# true     1890035
# 1        1379212
# false     182281
# 0          17480
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_MINUTES_GOVERNING_BODY
# 1    3269247
# 0     199761
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_MONITORING_OF_COI_POLICY
# None     1156585
# true      929254
# 1         919619
# false     350510
# 0         113040
# Name: count, dtype: int64
# After:
#  F9_06_PC_MONITORING_OF_COI_POLICY
# 1.0    1848873
# NaN    1156585
# 0.0     463550
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_OFFICER_MAILING_ADDRESS
# false    2033316
# 0        1382310
# true       39000
# 1          14382
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_OFFICER_MAILING_ADDRESS
# 0    3415626
# 1      53382
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_OTHER_COMPENSTN_PROCESS
# false    1524387
# 0         899664
# true      530210
# 1         496512
# None       18235
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_OTHER_COMPENSTN_PROCESS
# 0.0    2424051
# 1.0    1026722
# NaN      18235
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_OTHER_WEBSITE
# <NA>    3033593
# X        435415
# Name: count, dtype: Int64
#
# After:
#  F9_06_PC_OTHER_WEBSITE
# NaN    3033593
# 1.0     435415
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_OWN_WEBSITE
# <NA>    3244763
# X        224245
# Name: count, dtype: Int64
#
# After:
#  F9_06_PC_OWN_WEBSITE
# NaN    3244763
# 1.0     224245
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_POLICIES_GOVERN_CHAPTER
# None     3242434
# true       78050
# 1          75943
# false      68935
# 0           3646
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_POLICIES_GOVERN_CHAPTER
# NaN    3242434
# 1.0     153993
# 0.0      72581
# Name: count, dtype: int64
#
# Before:
#  F9_06_PC_WHISTLEBLOWER_POLICY
# false    1325353
# 1         792324
# true      746963
# 0         604368
# Name: count, dtype: int64
#
# After:
#  F9_06_PC_WHISTLEBLOWER_POLICY
# 0    1929721
# 1    1539287
# Name: count, dtype: int64
#
# Before:
#  F9_07_EXP_SCHED_O_X
# <NA>    3347613
# X        121395
# Name: count, dtype: Int64
#
# After:
#  F9_07_EXP_SCHED_O_X
# NaN    3347613
# 1.0     121395
# Name: count, dtype: int64
#
# Before:
#  F9_07_PC_COMPENSATION_OTHER_SRCE
# false    2064182
# 0        1387104
# 1           9588
# true        8134
# Name: count, dtype: int64
#
# After:
#  F9_07_PC_COMPENSATION_OTHER_SRCE
# 0    3451286
# 1      17722
# Name: count, dtype: int64
#
# Before:
#  F9_07_PC_FORMER_OFFICER_LISTED
# false    2015533
# 0        1349327
# true       56783
# 1          47365
# Name: count, dtype: int64
#
# After:
#  F9_07_PC_FORMER_OFFICER_LISTED
# 0    3364860
# 1     104148
# Name: count, dtype: int64
#
# Before:
#  F9_07_PC_NO_LISTED_PERS_COMPENSD
# <NA>    1944702
# X       1524306
# Name: count, dtype: Int64
#
# After:
#  F9_07_PC_NO_LISTED_PERS_COMPENSD
# NaN    1944702
# 1.0    1524306
# Name: count, dtype: int64
#
# Before:
#  F9_07_PC_TOTAL_COMP_GRTR_150K
# false    1823538
# 0         936410
# 1         460282
# true      248778
# Name: count, dtype: int64
#
# After:
#  F9_07_PC_TOTAL_COMP_GRTR_150K
# 0    2759948
# 1     709060
# Name: count, dtype: int64
#
# Before:
#  F9_08_EXP_SCHED_O_X
# <NA>    3441060
# X         27948
# Name: count, dtype: Int64
#
# After:
#  F9_08_EXP_SCHED_O_X
# NaN    3441060
# 1.0      27948
# Name: count, dtype: int64
#
# Before:
#  F9_09_EXP_SCHED_O_X
# <NA>    2897014
# X        571994
# Name: count, dtype: Int64
#
# After:
#  F9_09_EXP_SCHED_O_X
# NaN    2897014
# 1.0     571994
# Name: count, dtype: int64
#
# Before:
#  F9_10_PC_ORG_FOLLOWS_SFAS117
# <NA>    2000973
# X       1468035
# Name: count, dtype: Int64
#
# After:
#  F9_10_PC_ORG_FOLLOWS_SFAS117
# NaN    2000973
# 1.0    1468035
# Name: count, dtype: int64
#
# Before:
#  F9_10_PC_ORG_NOT_FOLLOW_SFAS117
# <NA>    3033710
# X        435298
# Name: count, dtype: Int64
#
# After:
#  F9_10_PC_ORG_NOT_FOLLOW_SFAS117
# NaN    3033710
# 1.0     435298
# Name: count, dtype: int64
#
# Before:
#  F9_10_SCHED_O_X
# <NA>    3439054
# X         29954
# Name: count, dtype: Int64
#
# After:
#  F9_10_SCHED_O_X
# NaN    3439054
# 1.0      29954
# Name: count, dtype: int64
#
# Before:
#  F9_11_SCHED_O_X
# <NA>    2853992
# X        615016
# Name: count, dtype: Int64
#
# After:
#  F9_11_SCHED_O_X
# NaN    2853992
# 1.0     615016
# Name: count, dtype: int64
#
# Before:
#  F9_12_PC_ACCNT_COMPILE_OR_REVIEW
# false    1755494
# 0        1278887
# true      316822
# 1         117805
# Name: count, dtype: int64
#
# After:
#  F9_12_PC_ACCNT_COMPILE_OR_REVIEW
# 0    3034381
# 1     434627
# Name: count, dtype: int64
#
# Before:
#  F9_12_PC_ACCTG_METHOD_ACCRUAL
# X       2222419
# <NA>    1246589
# Name: count, dtype: Int64
#
# After:
#  F9_12_PC_ACCTG_METHOD_ACCRUAL
# 1.0    2222419
# NaN    1246589
# Name: count, dtype: int64
#
# Before:
#  F9_12_PC_ACCTG_METHOD_CASH
# <NA>    2296089
# X       1172919
# Name: count, dtype: Int64
#
# After:
#  F9_12_PC_ACCTG_METHOD_CASH
# NaN    2296089
# 1.0    1172919
# Name: count, dtype: int64
#
# Before:
#  F9_12_PC_AUDIT_COMMITTEE
# None     1595656
# 1         775542
# true      743366
# false     209171
# 0         145273
# Name: count, dtype: int64
#
# After:
#  F9_12_PC_AUDIT_COMMITTEE
# NaN    1595656
# 1.0    1518908
# 0.0     354444
# Name: count, dtype: int64
#
# Before:
#  F9_12_PC_FED_GRNT_AUDIT_PERFORMD
# None     3106636
# 1         166848
# true      131142
# false      62238
# 0           2144
# Name: count, dtype: int64
#
# After:
#  F9_12_PC_FED_GRNT_AUDIT_PERFORMD
# NaN    3106636
# 1.0     297990
# 0.0      64382
# Name: count, dtype: int64
#
# Before:
#  F9_12_PC_FED_GRNT_AUDIT_REQUIRED
# false    1589748
# 0        1227853
# None      350768
# 1         168420
# true      132219
# Name: count, dtype: int64
#
# After:
#  F9_12_PC_FED_GRNT_AUDIT_REQUIRED
# 0.0    2817601
# NaN     350768
# 1.0     300639
# Name: count, dtype: int64
#
# Before:
#  F9_12_PC_FINCL_STMTS_AUDITED
# false    1376779
# 1         813142
# true      695537
# 0         583550
# Name: count, dtype: int64
#
# After:
#  F9_12_PC_FINCL_STMTS_AUDITED
# 0    1960329
# 1    1508679
# Name: count, dtype: int64
#
# Before:
#  F9_12_SCHED_O_X
# <NA>    2894568
# X        574440
# Name: count, dtype: Int64
#
# After:
#  F9_12_SCHED_O_X
# NaN    2894568
# 1.0     574440
# Name: count, dtype: int64
#
# CPU times: total: 3min 10s
# Wall time: 3min 23s

# %% [markdown]
# <br>Show a sample of 5 observations for all variables in the *binarize_with_dict* list then the *binarize_cols* list.

# %%
df[binarize_with_dict_cols].dtypes
# Out:
# F9_00_HD_INCLUDES_SUBORD_ORGS     object
# F9_04_PC_ACTVITIES_VIA_PARTNER    object
# F9_04_PC_CONTROLLED_ENTITY        object
# F9_04_PC_DISREGARDED_ENTITY       object
# F9_04_PC_EXCESS_BENEFIT_TRANS     object
# F9_04_PC_FR_EVENT_INC_GT_15K      object
# F9_04_PC_GAMING_INC_GT_15K        object
# F9_04_PC_LOBBYING_ACTIVITIES      object
# F9_04_PC_POLITICAL_ACTIVITIES     object
# F9_04_PC_PRIOR_EXCESS_BEN_TRAN    object
# F9_04_PC_PROF_FR_EXP_GT_15K       object
# F9_04_PC_RELATED_ENTITY           object
# F9_04_PC_TRANS_TO_CNTRLD_ENT      object
# F9_04_PC_TRANS_WITH_CNTRLD_ENT    object
# dtype: object

# %%
df[binarize_with_dict_cols].describe().T
# Out:
#                                     count      mean       std  min  25%  50%  \
# F9_00_HD_INCLUDES_SUBORD_ORGS    313529.0  0.059931  0.237359  0.0  0.0  0.0
# F9_04_PC_ACTVITIES_VIA_PARTNER  3469008.0   0.00058  0.024076  0.0  0.0  0.0
# F9_04_PC_CONTROLLED_ENTITY      3469008.0   0.05576  0.229457  0.0  0.0  0.0
# F9_04_PC_DISREGARDED_ENTITY     3469008.0  0.027118  0.162427  0.0  0.0  0.0
# F9_04_PC_EXCESS_BENEFIT_TRANS   2849032.0  0.000266  0.016309  0.0  0.0  0.0
# F9_04_PC_FR_EVENT_INC_GT_15K    3469008.0  0.215086  0.410882  0.0  0.0  0.0
# F9_04_PC_GAMING_INC_GT_15K      3469008.0  0.030503  0.171967  0.0  0.0  0.0
# F9_04_PC_LOBBYING_ACTIVITIES    2732281.0  0.052276  0.222583  0.0  0.0  0.0
# F9_04_PC_POLITICAL_ACTIVITIES   3469008.0  0.009985  0.099425  0.0  0.0  0.0
# F9_04_PC_PRIOR_EXCESS_BEN_TRAN  2850423.0  0.000211  0.014531  0.0  0.0  0.0
# F9_04_PC_PROF_FR_EXP_GT_15K     3469008.0  0.026893   0.16177  0.0  0.0  0.0
# F9_04_PC_RELATED_ENTITY         3469008.0  0.243421  0.429147  0.0  0.0  0.0
# F9_04_PC_TRANS_TO_CNTRLD_ENT    2604162.0  0.012178  0.109679  0.0  0.0  0.0
# F9_04_PC_TRANS_WITH_CNTRLD_ENT   912091.0  0.121458  0.326659  0.0  0.0  0.0
#
#                                 75%  max
# F9_00_HD_INCLUDES_SUBORD_ORGS   0.0  1.0
# F9_04_PC_ACTVITIES_VIA_PARTNER  0.0  1.0
# F9_04_PC_CONTROLLED_ENTITY      0.0  1.0
# F9_04_PC_DISREGARDED_ENTITY     0.0  1.0
# F9_04_PC_EXCESS_BENEFIT_TRANS   0.0  1.0
# F9_04_PC_FR_EVENT_INC_GT_15K    0.0  1.0
# F9_04_PC_GAMING_INC_GT_15K      0.0  1.0
# F9_04_PC_LOBBYING_ACTIVITIES    0.0  1.0
# F9_04_PC_POLITICAL_ACTIVITIES   0.0  1.0
# F9_04_PC_PRIOR_EXCESS_BEN_TRAN  0.0  1.0
# F9_04_PC_PROF_FR_EXP_GT_15K     0.0  1.0
# F9_04_PC_RELATED_ENTITY         0.0  1.0
# F9_04_PC_TRANS_TO_CNTRLD_ENT    0.0  1.0
# F9_04_PC_TRANS_WITH_CNTRLD_ENT  0.0  1.0

# %%
df[binarize_with_dict_cols].sample(5)
# Out:
#          F9_00_HD_INCLUDES_SUBORD_ORGS  F9_04_PC_ACTVITIES_VIA_PARTNER  \
# 2531478                           <NA>                               0
# 3388090                           <NA>                               0
# 2985105                           <NA>                               0
# 2387705                           <NA>                               0
# 3128191                           <NA>                               0
#
#          F9_04_PC_CONTROLLED_ENTITY  F9_04_PC_DISREGARDED_ENTITY  \
# 2531478                           0                            0
# 3388090                           0                            0
# 2985105                           0                            0
# 2387705                           0                            1
# 3128191                           0                            0
#
#          F9_04_PC_EXCESS_BENEFIT_TRANS  F9_04_PC_FR_EVENT_INC_GT_15K  \
# 2531478                              0                             0
# 3388090                              0                             0
# 2985105                              0                             0
# 2387705                              0                             1
# 3128191                           <NA>                             0
#
#          F9_04_PC_GAMING_INC_GT_15K  F9_04_PC_LOBBYING_ACTIVITIES  \
# 2531478                           0                             0
# 3388090                           0                             0
# 2985105                           0                             0
# 2387705                           0                             0
# 3128191                           0                             0
#
#          F9_04_PC_POLITICAL_ACTIVITIES  F9_04_PC_PRIOR_EXCESS_BEN_TRAN  \
# 2531478                              0                               0
# 3388090                              0                               0
# 2985105                              0                               0
# 2387705                              0                               0
# 3128191                              0                            <NA>
#
#          F9_04_PC_PROF_FR_EXP_GT_15K  F9_04_PC_RELATED_ENTITY  \
# 2531478                            0                        0
# 3388090                            0                        1
# 2985105                            0                        0
# 2387705                            0                        0
# 3128191                            0                        0
#
#          F9_04_PC_TRANS_TO_CNTRLD_ENT  F9_04_PC_TRANS_WITH_CNTRLD_ENT
# 2531478                             0                            <NA>
# 3388090                             0                            <NA>
# 2985105                             0                            <NA>
# 2387705                             0                            <NA>
# 3128191                          <NA>                            <NA>

# %%
df[binarize_cols].describe().T
# Out:
#                                       count      mean       std  min  25%  \
# F9_00_HD_ADDR_CHANGE               138187.0       1.0       0.0  1.0  1.0
# F9_00_HD_AMENDED_RETURN             41351.0       1.0       0.0  1.0  1.0
# F9_00_HD_EXEMPT_STATUS_4847A1        2461.0       1.0       0.0  1.0  1.0
# F9_00_HD_EXEMPT_STATUS_501C3      2609442.0       1.0       0.0  1.0  1.0
# F9_00_HD_FINAL_RETURN               19379.0       1.0       0.0  1.0  1.0
# ...                                     ...       ...       ...  ...  ...
# F9_12_PC_AUDIT_COMMITTEE          1873352.0  0.810797   0.39167  0.0  1.0
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD   362372.0  0.822332  0.382234  0.0  1.0
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED  3118240.0  0.096413  0.295157  0.0  0.0
# F9_12_PC_FINCL_STMTS_AUDITED      3469008.0  0.434902  0.495744  0.0  0.0
# F9_12_SCHED_O_X                    574440.0       1.0       0.0  1.0  1.0
#
#                                   50%  75%  max
# F9_00_HD_ADDR_CHANGE              1.0  1.0  1.0
# F9_00_HD_AMENDED_RETURN           1.0  1.0  1.0
# F9_00_HD_EXEMPT_STATUS_4847A1     1.0  1.0  1.0
# F9_00_HD_EXEMPT_STATUS_501C3      1.0  1.0  1.0
# F9_00_HD_FINAL_RETURN             1.0  1.0  1.0
# ...                               ...  ...  ...
# F9_12_PC_AUDIT_COMMITTEE          1.0  1.0  1.0
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD  1.0  1.0  1.0
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED  0.0  0.0  1.0
# F9_12_PC_FINCL_STMTS_AUDITED      0.0  1.0  1.0
# F9_12_SCHED_O_X                   1.0  1.0  1.0
#
# [64 rows x 8 columns]

# %%
df[binarize_cols].sample(5)
# Out:
#          F9_00_HD_ADDR_CHANGE  F9_00_HD_AMENDED_RETURN  \
# 2331038                  <NA>                     <NA>
# 1706860                  <NA>                     <NA>
# 3127596                  <NA>                     <NA>
# 1570356                  <NA>                     <NA>
# 206036                   <NA>                     <NA>
#
#          F9_00_HD_EXEMPT_STATUS_4847A1  F9_00_HD_EXEMPT_STATUS_501C3  \
# 2331038                           <NA>                             1
# 1706860                           <NA>                          <NA>
# 3127596                           <NA>                             1
# 1570356                           <NA>                             1
# 206036                            <NA>                             1
#
#          F9_00_HD_FINAL_RETURN  F9_00_HD_GROUP_RETURN  \
# 2331038                   <NA>                      0
# 1706860                   <NA>                      0
# 3127596                   <NA>                      0
# 1570356                   <NA>                      0
# 206036                    <NA>                      0
#
#          F9_00_HD_INITIAL_RETURN  F9_00_HD_TYPE_ORG_ASSOCIATION  \
# 2331038                     <NA>                           <NA>
# 1706860                     <NA>                           <NA>
# 3127596                     <NA>                           <NA>
# 1570356                     <NA>                           <NA>
# 206036                      <NA>                           <NA>
#
#          F9_00_HD_TYPE_ORG_CORP  F9_00_HD_TYPE_ORG_OTHER  \
# 2331038                       1                     <NA>
# 1706860                       1                     <NA>
# 3127596                       1                     <NA>
# 1570356                       1                     <NA>
# 206036                        1                     <NA>
#
#          F9_00_HD_TYPE_ORG_TRUST  F9_01_PC_TERMINATION_CONTRACTION  \
# 2331038                     <NA>                              <NA>
# 1706860                     <NA>                              <NA>
# 3127596                     <NA>                              <NA>
# 1570356                     <NA>                              <NA>
# 206036                      <NA>                              <NA>
#
#          F9_03_PC_PGMSVC_SIGNIF_CHG  F9_03_PC_PGMSVC_SIGNIF_NEW  \
# 2331038                           0                           0
# 1706860                           0                           0
# 3127596                           0                           0
# 1570356                           0                           0
# 206036                            0                           0
#
#          F9_03_PZ_SCHEDULE_O_PART3  F9_05_EXP_SCHED_O_X  \
# 2331038                       <NA>                 <NA>
# 1706860                       <NA>                 <NA>
# 3127596                       <NA>                 <NA>
# 1570356                       <NA>                 <NA>
# 206036                           1                 <NA>
#
#          F9_05_PC_UNRELATED_BUS_INCOME  F9_06_EXP_SCHED_O_X  \
# 2331038                              0                    1
# 1706860                              0                    1
# 3127596                              0                    1
# 1570356                              0                    1
# 206036                               0                    1
#
#          F9_06_PC_990_PROVIDED_GOV_BODY  F9_06_PC_ANNUAL_DISC_COVRD_PERS  \
# 2331038                               0                                1
# 1706860                               0                             <NA>
# 3127596                               0                             <NA>
# 1570356                               0                                1
# 206036                                0                             <NA>
#
#          F9_06_PC_CEO_COMPENSTN_PROCESS  F9_06_PC_CHANGES_ORGANIZING_DOCS  \
# 2331038                               0                                 0
# 1706860                               0                                 0
# 3127596                               0                                 0
# 1570356                               0                                 0
# 206036                                0                                 0
#
#          F9_06_PC_CONFLICT_OF_INTEREST  F9_06_PC_DECISIONS_SUBJ_APPROVAL  \
# 2331038                              1                                 0
# 1706860                              0                                 0
# 3127596                              0                                 0
# 1570356                              1                                 0
# 206036                               0                                 0
#
#          F9_06_PC_DELEGATION_MGT_DUTIES  F9_06_PC_DELEGATION_OF_MGT  \
# 2331038                               0                           0
# 1706860                               0                           0
# 3127596                               0                           0
# 1570356                               0                           0
# 206036                                0                           0
#
#          F9_06_PC_DOCUMENT_RET_POLICY  F9_06_PC_ELECTION_BOARD_MEMBERS  \
# 2331038                             1                                0
# 1706860                             0                                0
# 3127596                             0                                0
# 1570356                             1                                0
# 206036                              0                                0
#
#          F9_06_PC_FAMILY_OR_BUSINESS_REL  F9_06_PC_FORM_AVAIL_OWN_WEBSITE  \
# 2331038                                0                             <NA>
# 1706860                                0                             <NA>
# 3127596                                0                             <NA>
# 1570356                                0                             <NA>
# 206036                                 0                             <NA>
#
#          F9_06_PC_FORM_UPON_REQUEST  F9_06_PC_JOINT_VENTURE_INVESTMNT  \
# 2331038                           1                                 0
# 1706860                           1                                 0
# 3127596                           1                                 0
# 1570356                           1                                 0
# 206036                         <NA>                                 0
#
#          F9_06_PC_JOINT_VENTURE_POLICY  F9_06_PC_LOCAL_CHAPTERS  \
# 2331038                           <NA>                        0
# 1706860                           <NA>                        1
# 3127596                           <NA>                        0
# 1570356                           <NA>                        0
# 206036                            <NA>                        0
#
#          F9_06_PC_MATERIAL_DIVERSION  F9_06_PC_MEMBERS_OR_STOCKHOLDERS  \
# 2331038                            0                                 0
# 1706860                            0                                 0
# 3127596                            0                                 0
# 1570356                            0                                 0
# 206036                             0                                 0
#
#          F9_06_PC_MINUTES_COMMITTEES  F9_06_PC_MINUTES_GOVERNING_BODY  \
# 2331038                            1                                1
# 1706860                            1                                1
# 3127596                            1                                1
# 1570356                            1                                1
# 206036                             1                                1
#
#          F9_06_PC_MONITORING_OF_COI_POLICY  F9_06_PC_OFFICER_MAILING_ADDRESS  \
# 2331038                                  1                                 0
# 1706860                               <NA>                                 0
# 3127596                               <NA>                                 0
# 1570356                                  1                                 0
# 206036                                <NA>                                 0
#
#          F9_06_PC_OTHER_COMPENSTN_PROCESS  F9_06_PC_OTHER_WEBSITE  \
# 2331038                                 0                    <NA>
# 1706860                                 0                    <NA>
# 3127596                                 0                    <NA>
# 1570356                                 0                    <NA>
# 206036                                  0                    <NA>
#
#          F9_06_PC_OWN_WEBSITE  F9_06_PC_POLICIES_GOVERN_CHAPTER  \
# 2331038                  <NA>                              <NA>
# 1706860                  <NA>                                 1
# 3127596                  <NA>                              <NA>
# 1570356                  <NA>                              <NA>
# 206036                   <NA>                              <NA>
#
#          F9_06_PC_WHISTLEBLOWER_POLICY  F9_07_EXP_SCHED_O_X  \
# 2331038                              1                 <NA>
# 1706860                              0                 <NA>
# 3127596                              0                 <NA>
# 1570356                              1                 <NA>
# 206036                               0                 <NA>
#
#          F9_07_PC_COMPENSATION_OTHER_SRCE  F9_07_PC_FORMER_OFFICER_LISTED  \
# 2331038                                 0                               0
# 1706860                                 0                               0
# 3127596                                 0                               0
# 1570356                                 0                               0
# 206036                                  0                               0
#
#          F9_07_PC_NO_LISTED_PERS_COMPENSD  F9_07_PC_TOTAL_COMP_GRTR_150K  \
# 2331038                              <NA>                              0
# 1706860                              <NA>                              0
# 3127596                              <NA>                              0
# 1570356                              <NA>                              0
# 206036                                  1                              0
#
#          F9_08_EXP_SCHED_O_X  F9_09_EXP_SCHED_O_X  \
# 2331038                 <NA>                 <NA>
# 1706860                 <NA>                    1
# 3127596                 <NA>                 <NA>
# 1570356                 <NA>                 <NA>
# 206036                  <NA>                 <NA>
#
#          F9_10_PC_ORG_FOLLOWS_SFAS117  F9_10_PC_ORG_NOT_FOLLOW_SFAS117  \
# 2331038                          <NA>                             <NA>
# 1706860                          <NA>                                1
# 3127596                          <NA>                             <NA>
# 1570356                             1                             <NA>
# 206036                              1                             <NA>
#
#          F9_10_SCHED_O_X  F9_11_SCHED_O_X  F9_12_PC_ACCNT_COMPILE_OR_REVIEW  \
# 2331038             <NA>                1                                 0
# 1706860             <NA>             <NA>                                 0
# 3127596             <NA>                1                                 0
# 1570356             <NA>             <NA>                                 0
# 206036              <NA>             <NA>                                 0
#
#          F9_12_PC_ACCTG_METHOD_ACCRUAL  F9_12_PC_ACCTG_METHOD_CASH  \
# 2331038                              1                        <NA>
# 1706860                           <NA>                           1
# 3127596                              1                        <NA>
# 1570356                              1                        <NA>
# 206036                            <NA>                           1
#
#          F9_12_PC_AUDIT_COMMITTEE  F9_12_PC_FED_GRNT_AUDIT_PERFORMD  \
# 2331038                         1                              <NA>
# 1706860                      <NA>                              <NA>
# 3127596                      <NA>                              <NA>
# 1570356                         1                              <NA>
# 206036                       <NA>                              <NA>
#
#          F9_12_PC_FED_GRNT_AUDIT_REQUIRED  F9_12_PC_FINCL_STMTS_AUDITED  \
# 2331038                                 0                             1
# 1706860                                 0                             0
# 3127596                              <NA>                             0
# 1570356                                 0                             1
# 206036                               <NA>                             0
#
#          F9_12_SCHED_O_X
# 2331038             <NA>
# 1706860             <NA>
# 3127596             <NA>
# 1570356             <NA>
# 206036              <NA>

# %% [markdown]
# ### Check that total number of values in new variable equal sum of prior 2 variables
# Now we are doing some additional verifications to ensure that we have the expected number of observations for our 'combined' variables. We're printing out two numbers for each variable; they should match.

# %% [markdown]
# ##### Skip for the new XML filings

# %%
"""
for index, row in new_variables_df[new_variables_df['len']==2][:].iterrows():
    #print(row['variable_name_new'])
    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    print(len(df[df[row['original_names'][0]].notnull()]) + len(df[df[row['original_names'][1]].notnull()]))    
    print(len(df[df[row['variable_name_new']].notnull()]), '\n')
    #print(len(df[(df[row['original_names'][0]].notnull()) & (df[row['original_names'][1]].notnull())]), '\n')     
"""
# Out:
# F9_00_HD_ADDR_CHANGE AddressChange AddressChangeInd
# 82976
# 82976
#
# F9_00_HD_AMENDED_RETURN AmendedReturnInd AmendedReturn
# 19445
# 19445
#
# F9_00_HD_CTRY_OF_DOMICILE LegalDomicileCountryCd CountryLegalDomicile
# 1155
# 1155
#
# F9_00_HD_EXEMPT_STATUS_4847A1 Organization4947a1 Organization4947a1NotPFInd
# 1420
# 1420
#
# F9_00_HD_EXEMPT_STATUS_501C Organization501cInd Organization501c
# 497380
# 497380
#
# F9_00_HD_EXEMPT_STATUS_501C3 Organization501c3Ind Organization501c3
# 1605635
# 1605635
#
# F9_00_HD_FINAL_RETURN FinalReturnInd TerminatedReturn
# 11573
# 11573
#
# F9_00_HD_GROSS_EXEMPT_NUM GroupExemptionNum GroupExemptionNumber
# 70836
# 70836
#
# F9_00_HD_GROSS_RCPT GrossReceiptsAmt GrossReceipts
# 2104435
# 2104435
#
# F9_00_HD_GROUP_RETURN GroupReturnForAffiliatesInd GroupReturnForAffiliates
# 2104435
# 2104435
#
# F9_00_HD_INCLUDES_SUBORD_ORGS AllAffiliatesIncluded AllAffiliatesIncludedInd
# 292934
# 292934
#
# F9_00_HD_INITIAL_RETURN InitialReturn InitialReturnInd
# 20875
# 20875
#
# F9_00_HD_PRIN_OFF_NAME PrincipalOfficerNm NameOfPrincipalOfficerPerson
# 1778342
# 1778342
#
# F9_00_HD_SIGNING_OFFICER_SIGNTR Officer BusinessOfficerGrp
# 2104435
# 2104435
#
# F9_00_HD_SPECIAL_CONDITION_DESC SpecialConditionDescription SpecialConditionDesc
# 1046
# 1046
#
# F9_00_HD_STATE_OF_DOMICILE StateLegalDomicile LegalDomicileStateCd
# 1989861
# 1989861
#
# F9_00_HD_TAX_PER_BEGIN TaxPeriodBeginDt TaxPeriodBeginDate
# 2104435
# 2104435
#
# F9_00_HD_TAX_PER_END TaxPeriodEndDt TaxPeriodEndDate
# 2104435
# 2104435
#
# F9_00_HD_TAX_YEAR TaxYear TaxYr
# 2104435
# 2104435
#
# F9_00_HD_TIME_STAMP Timestamp ReturnTs
# 2104435
# 2104435
#
# F9_00_HD_TYPE_ORG_ASSOCIATION TypeOfOrganizationAssociation TypeOfOrganizationAssocInd
# 91408
# 91408
#
# F9_00_HD_TYPE_ORG_CORP TypeOfOrganizationCorpInd TypeOfOrganizationCorporation
# 1858212
# 1858212
#
# F9_00_HD_TYPE_ORG_OTHER TypeOfOrganizationOther TypeOfOrganizationOtherInd
# 49927
# 49927
#
# F9_00_HD_TYPE_ORG_OTHER_DESC TypeOfOrgOtherDescription OtherOrganizationDsc
# 37238
# 37238
#
# F9_00_HD_TYPE_ORG_TRUST TypeOfOrganizationTrustInd TypeOfOrganizationTrust
# 66064
# 66064
#
# F9_00_HD_WEBSITE WebsiteAddressTxt WebSite
# 1883339
# 1883339
#
# F9_00_HD_YEAR_FORMED FormationYr YearFormation
# 1947845
# 1947845
#
# F9_01_PC_BEN_PAID_MEMB_PRIOR PYBenefitsPaidToMembersAmt BenefitsPaidToMembersPriorYear
# 984677
# 984677
#
# F9_01_PC_CONTR_GRANTS_CURR CYContributionsGrantsAmt ContributionsGrantsCurrentYear
# 2104435
# 2104435
#
# F9_01_PC_CONTR_GRANTS_PRIOR PYContributionsGrantsAmt ContributionsGrantsPriorYear
# 1824372
# 1824372
#
# F9_01_PC_GRANTS_PRIOR GrantsAndSimilarAmntsPriorYear PYGrantsAndSimilarPaidAmt
# 1204684
# 1204684
#
# F9_01_PC_INDEP_VOTING_MEMB VotingMembersIndependentCnt NbrIndependentVotingMembers
# 2104435
# 2104435
#
# F9_01_PC_INVEST_INCOME_PRIOR InvestmentIncomePriorYear PYInvestmentIncomeAmt
# 1761951
# 1761951
#
# F9_01_PC_NET_ASSETS_BOY NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesBOYAmt
# 2076636
# 2076636
#
# F9_01_PC_OTHER_EXPENSE_PRIOR PYOtherExpensesAmt OtherExpensePriorYear
# 2031716
# 2031716
#
# F9_01_PC_OTHER_REV_PRIOR OtherRevenuePriorYear PYOtherRevenueAmt
# 1581128
# 1581128
#
# F9_01_PC_PROF_FUNDRISING_EXP_CURR TotalProfFundrsngExpCY CYTotalProfFndrsngExpnsAmt
# 2104435
# 2104435
#
# F9_01_PC_PROF_FUNDRISING_EXP_PRIOR PYTotalProfFndrsngExpnsAmt TotalProfFundrsngExpPriorYear
# 969195
# 969195
#
# F9_01_PC_PROG_SERVICE_REV_PRIOR PYProgramServiceRevenueAmt ProgramServiceRevenuePriorYear
# 1660110
# 1660110
#
# F9_01_PC_REV_LESS_EXP_CURR CYRevenuesLessExpensesAmt RevenuesLessExpensesCY
# 2104435
# 2104435
#
# F9_01_PC_REV_LESS_EXP_PRIOR PYRevenuesLessExpensesAmt RevenuesLessExpensesPriorYear
# 2039995
# 2039995
#
# F9_01_PC_TERMINATION_CONTRACTION ContractTerminationInd TerminationOrContraction
# 15523
# 15523
#
# F9_01_PC_TOT_ASSETS_EOY TotalAssetsEOYAmt TotalAssetsEOY
# 2104435
# 2104435
#
# F9_01_PC_TOT_EXP_PRIOR PYTotalExpensesAmt TotalExpensesPriorYear
# 2038379
# 2038379
#
# F9_01_PC_TOT_FNDR_EXP_CURR CYTotalFundraisingExpenseAmt TotalFundrsngExpCurrentYear
# 2104435
# 2104435
#
# F9_01_PC_TOT_INDIV_EMPLOYED TotalNbrEmployees TotalEmployeeCnt
# 2104435
# 2104435
#
# F9_01_PC_TOT_INDIV_VOLUNTEERS TotalNbrVolunteers TotalVolunteersCnt
# 1549023
# 1549023
#
# F9_01_PC_TOT_LIABILITIES_EOY TotalLiabilitiesEOY TotalLiabilitiesEOYAmt
# 2104435
# 2104435
#
# F9_01_PC_TOT_REVENUE_PRIOR PYTotalRevenueAmt TotalRevenuePriorYear
# 2042100
# 2042100
#
# F9_01_PC_TOT_UBI_GROSS TotalGrossUBI TotalGrossUBIAmt
# 2104435
# 2104435
#
# F9_01_PC_TOT_UBI_NET NetUnrelatedBusTxblIncmAmt NetUnrelatedBusinessTxblIncome
# 1132460
# 1132460
#
# F9_01_PC_VOTING_MEMB_GOV_BODY NbrVotingMembersGoverningBody VotingMembersGoverningBodyCnt
# 2104435
# 2104435
#
# F9_01_PZ_BEN_PAID_TO_MEMB_CURR BenefitsPaidToMembersCY CYBenefitsPaidToMembersAmt
# 2104435
# 2104435
#
# F9_01_PZ_GRANTS_PAID_CURR GrantsAndSimilarAmntsCY CYGrantsAndSimilarPaidAmt
# 2104435
# 2104435
#
# F9_01_PZ_INVEST_INCOME_CURR InvestmentIncomeCurrentYear CYInvestmentIncomeAmt
# 2104435
# 2104435
#
# F9_01_PZ_NAFB_EOY NetAssetsOrFundBalancesEOYAmt NetAssetsOrFundBalancesEOY
# 2104435
# 2104435
#
# F9_01_PZ_ORGANIZATIONAL_MISSION ActivityOrMissionDesc ActivityOrMissionDescription
# 2104435
# 2104435
#
# F9_01_PZ_OTHER_EXPENSE_CURR OtherExpensesCurrentYear CYOtherExpensesAmt
# 2104435
# 2104435
#
# F9_01_PZ_OTHER_REV_CURR CYOtherRevenueAmt OtherRevenueCurrentYear
# 2104435
# 2104435
#
# F9_01_PZ_PROG_SERVICE_REV_CURR ProgramServiceRevenueCY CYProgramServiceRevenueAmt
# 2104435
# 2104435
#
# F9_01_PZ_SALARIES_CURR CYSalariesCompEmpBnftPaidAmt SalariesEtcCurrentYear
# 2104435
# 2104435
#
# F9_01_PZ_SALARIES_PRIOR PYSalariesCompEmpBnftPaidAmt SalariesEtcPriorYear
# 1696977
# 1696977
#
# F9_01_PZ_TOT_ASSETS_BOY TotalAssetsBOYAmt TotalAssetsBOY
# 2078757
# 2078757
#
# F9_01_PZ_TOT_EXP_CURR TotalExpensesCurrentYear CYTotalExpensesAmt
# 2104435
# 2104435
#
# F9_01_PZ_TOT_LIAB_BOY TotalLiabilitiesBOY TotalLiabilitiesBOYAmt
# 1781149
# 1781149
#
# F9_01_PZ_TOT_REV_CURR TotalRevenueCurrentYear CYTotalRevenueAmt
# 2104435
# 2104435
#
# F9_03_PC_PGMSVC_SIGNIF_CHG SignificantChangeInd SignificantChange
# 2086086
# 2086086
#
# F9_03_PC_PGMSVC_SIGNIF_NEW SignificantNewProgramServices SignificantNewProgramSrvcInd
# 2086353
# 2086353
#
# F9_03_PC_PROG_SVC_ACC_1_CODE ActivityCode ActivityCd
# 3154
# 3154
#
# F9_03_PC_PROG_SVC_ACC_1_DESC Desc Description
# 2104435
# 2104435
#
# F9_03_PC_PROG_SVC_ACC_1_EXP Expense ExpenseAmt
# 1785397
# 1785397
#
# F9_03_PC_PROG_SVC_ACC_1_GRNT Grants GrantAmt
# 524132
# 524132
#
# F9_03_PC_PROG_SVC_ACC_1_REV Revenue RevenueAmt
# 1071386
# 1071386
#
# F9_03_PC_PROG_SVC_ACC_2_CODE ProgSrvcAccomActy2Grp Activity2
# 641426
# 641426
#
# F9_03_PC_PROG_SVC_ACC_2_DESC ProgSrvcAccomActy2Grp Activity2
# 641426
# 641426
#
# F9_03_PC_PROG_SVC_ACC_2_EXP ProgSrvcAccomActy2Grp Activity2
# 641426
# 641426
#
# F9_03_PC_PROG_SVC_ACC_2_GRNT ProgSrvcAccomActy2Grp Activity2
# 641426
# 641426
#
# F9_03_PC_PROG_SVC_ACC_2_REV ProgSrvcAccomActy2Grp Activity2
# 641426
# 641426
#
# F9_03_PC_PROG_SVC_ACC_3_CODE Activity3 ProgSrvcAccomActy3Grp
# 449032
# 449032
#
# F9_03_PC_PROG_SVC_ACC_3_DESC Activity3 ProgSrvcAccomActy3Grp
# 449032
# 449032
#
# F9_03_PC_PROG_SVC_ACC_3_EXP Activity3 ProgSrvcAccomActy3Grp
# 449032
# 449032
#
# F9_03_PC_PROG_SVC_ACC_3_GRNT Activity3 ProgSrvcAccomActy3Grp
# 449032
# 449032
#
# F9_03_PC_PROG_SVC_ACC_3_REV Activity3 ProgSrvcAccomActy3Grp
# 449032
# 449032
#
# F9_03_PC_TOT_OTH_PROG_SVC_EXP TotalOtherProgSrvcExpenseAmt TotalOfOtherProgramServiceExp
# 304752
# 304752
#
# F9_03_PC_TOT_OTH_PROG_SVC_GRNT TotalOfOtherProgramServiceGrnt TotalOtherProgSrvcGrantAmt
# 109230
# 109230
#
# F9_03_PC_TOT_OTH_PROG_SVC_REV TotalOtherProgSrvcRevenueAmt TotalOfOtherProgramServiceRev
# 160634
# 160634
#
# F9_03_PC_TOT_PROG_SVC_EXPENSE TotalProgramServiceExpense TotalProgramServiceExpensesAmt
# 1823455
# 1823455
#
# F9_03_PZ_MISSION_DESCRIPTION MissionDesc MissionDescription
# 2101649
# 2101649
#
# F9_03_PZ_SCHEDULE_O_PART3 InfoInScheduleOPartIII InfoInScheduleOPartIIIInd
# 680490
# 680490
#
# F9_04_PC_ACTVITIES_VIA_PARTNER ActivitiesConductedPrtshpInd ActivitiesConductedPartnership
# 2104435
# 2104435
#
# F9_04_PC_CONTROLLED_ENTITY RelatedOrgControlledEntity RelatedOrganizationCtrlEntInd
# 2104435
# 2104435
#
# F9_04_PC_DISREGARDED_ENTITY DisregardedEntity DisregardedEntityInd
# 2104435
# 2104435
#
# F9_04_PC_EXCESS_BENEFIT_TRANS EngagedInExcessBenefitTransInd ExcessBenefitTransaction
# 1756198
# 1756198
#
# F9_04_PC_FR_EVENT_INC_GT_15K FundraisingActivities FundraisingActivitiesInd
# 2104435
# 2104435
#
# F9_04_PC_GAMING_INC_GT_15K Gaming GamingActivitiesInd
# 2104435
# 2104435
#
# F9_04_PC_LOBBYING_ACTIVITIES LobbyingActivitiesInd LobbyingActivities
# 1692396
# 1692396
#
# F9_04_PC_POLITICAL_ACTIVITIES PoliticalCampaignActyInd PoliticalActivities
# 2104435
# 2104435
#
# F9_04_PC_PRIOR_EXCESS_BEN_TRAN PYExcessBenefitTransInd PriorExcessBenefitTransaction
# 1756505
# 1756505
#
# F9_04_PC_PROF_FR_EXP_GT_15K ProfessionalFundraising ProfessionalFundraisingInd
# 2104435
# 2104435
#
# F9_04_PC_RELATED_ENTITY RelatedEntityInd RelatedEntity
# 2104435
# 2104435
#
# F9_04_PC_TRANS_TO_CNTRLD_ENT TrnsfrExmptNonChrtblRltdOrgInd TransfersToExemptNonChrtblOrg
# 1572460
# 1572460
#
# F9_04_PC_TRANS_WITH_CNTRLD_ENT TransactionRelatedEntity TransactionWithControlEntInd
# 691900
# 691900
#
# F9_05_EXP_SCHED_O_X InfoInScheduleOPartVInd InfoInScheduleOPartV
# 39329
# 39329
#
# F9_05_PC_NUMBER_EMPLOYEES_W3 EmployeeCnt NumberOfEmployees
# 2104435
# 2104435
#
# F9_05_PC_NUMBER_FORMS_1096 IRPDocumentCnt NumberFormsTransmittedWith1096
# 2104435
# 2104435
#
# F9_05_PC_UNRELATED_BUS_INCOME UnrelatedBusIncmOverLimitInd UnrelatedBusinessIncome
# 2104435
# 2104435
#
# F9_06_EXP_SCHED_O_X InfoInScheduleOPartVIInd InfoInScheduleOPartVI
# 2024991
# 2024991
#
# F9_06_PC_990_PROVIDED_GOV_BODY Form990ProvidedToGvrnBodyInd Form990ProvidedToGoverningBody
# 2104435
# 2104435
#
# F9_06_PC_ANNUAL_DISC_COVRD_PERS AnnualDisclosureCoveredPersons AnnualDisclosureCoveredPrsnInd
# 1459641
# 1459641
#
# F9_06_PC_CEO_COMPENSTN_PROCESS CompensationProcessCEO CompensationProcessCEOInd
# 2093571
# 2093571
#
# F9_06_PC_CHANGES_ORGANIZING_DOCS ChangeToOrgDocumentsInd ChangesToOrganizingDocs
# 2104435
# 2104435
#
# F9_06_PC_CONFLICT_OF_INTEREST ConflictOfInterestPolicy ConflictOfInterestPolicyInd
# 2104435
# 2104435
#
# F9_06_PC_DECISIONS_SUBJ_APPROVAL DecisionsSubjectToApproval DecisionsSubjectToApprovaInd
# 2104435
# 2104435
#
# F9_06_PC_DELEGATION_MGT_DUTIES DelegationOfMgmtDutiesInd DelegationOfManagementDuties
# 2104435
# 2104435
#
# F9_06_PC_DELEGATION_OF_MGT DelegationOfMgmtDutiesInd DelegationOfManagementDuties
# 2104435
# 2104435
#
# F9_06_PC_DOCUMENT_RET_POLICY DocumentRetentionPolicy DocumentRetentionPolicyInd
# 2104435
# 2104435
#
# F9_06_PC_ELECTION_BOARD_MEMBERS ElectionOfBoardMembers ElectionOfBoardMembersInd
# 2104435
# 2104435
#
# F9_06_PC_FAMILY_OR_BUSINESS_REL FamilyOrBusinessRelationship FamilyOrBusinessRlnInd
# 2104435
# 2104435
#
# F9_06_PC_FORM_AVAIL_OWN_WEBSITE OwnWebsite OwnWebsiteInd
# 133879
# 133879
#
# F9_06_PC_FORM_UPON_REQUEST UponRequestInd UponRequest
# 1910701
# 1910701
#
# F9_06_PC_JOINT_VENTURE_INVESTMNT InvestmentInJointVentureInd InvestmentInJointVenture
# 2104435
# 2104435
#
# F9_06_PC_JOINT_VENTURE_POLICY WrittenPolicyOrProcedureInd WrittenPolicyOrProcedure
# 91842
# 91842
#
# F9_06_PC_LOCAL_CHAPTERS LocalChapters LocalChaptersInd
# 2104435
# 2104435
#
# F9_06_PC_MATERIAL_DIVERSION MaterialDiversionOrMisuseInd MaterialDiversionOrMisuse
# 2104435
# 2104435
#
# F9_06_PC_MEMBERS_OR_STOCKHOLDERS MembersOrStockholders MembersOrStockholdersInd
# 2104435
# 2104435
#
# F9_06_PC_MINUTES_COMMITTEES MinutesOfCommittees MinutesOfCommitteesInd
# 2097766
# 2097766
#
# F9_06_PC_MINUTES_GOVERNING_BODY MinutesOfGoverningBody MinutesOfGoverningBodyInd
# 2104435
# 2104435
#
# F9_06_PC_MONITORING_OF_COI_POLICY RegularMonitoringEnforcement RegularMonitoringEnfrcInd
# 1459542
# 1459542
#
# F9_06_PC_NUM_IND_VOTING_MEMBERS NumberIndependentVotingMembers IndependentVotingMemberCnt
# 2104435
# 2104435
#
# F9_06_PC_NUM_VOTING_GOV_MEMBERS NbrVotingGoverningBodyMembers GoverningBodyVotingMembersCnt
# 2104435
# 2104435
#
# F9_06_PC_OFFICER_MAILING_ADDRESS OfficerMailingAddressInd OfficerMailingAddress
# 2104435
# 2104435
#
# F9_06_PC_OTHER_COMPENSTN_PROCESS CompensationProcessOther CompensationProcessOtherInd
# 2091558
# 2091558
#
# F9_06_PC_OTHER_WEBSITE OtherWebsiteInd OtherWebsite
# 275617
# 275617
#
# F9_06_PC_OWN_WEBSITE OwnWebsite OwnWebsiteInd
# 133879
# 133879
#
# F9_06_PC_POLICIES_GOVERN_CHAPTER PoliciesReferenceChaptersInd PoliciesReferenceChapters
# 146231
# 146231
#
# F9_06_PC_STATES_WHERE_RET_FILED StatesWhereCopyOfReturnIsFiled StatesWhereCopyOfReturnIsFldCd
# 1079526
# 1079526
#
# F9_06_PC_WHISTLEBLOWER_POLICY WhistleblowerPolicyInd WhistleblowerPolicy
# 2104435
# 2104435
#
# F9_07_EXP_SCHED_O_X InfoInScheduleOPartVIIInd InfoInScheduleOPartVII
# 80411
# 80411
#
# F9_07_PC_COMPENSATION_OTHER_SRCE CompensationFromOtherSources CompensationFromOtherSrcsInd
# 2104435
# 2104435
#
# F9_07_PC_FORMER_OFFICER_LISTED FormerOfcrEmployeesListedInd FormersListed
# 2104435
# 2104435
#
# F9_07_PC_NO_LISTED_PERS_COMPENSD NoListedPersonsCompensated NoListedPersonsCompensatedInd
# 900867
# 900867
#
# F9_07_PC_NUM_CONTRCTRS_GRTR_100K CntrctRcvdGreaterThan100KCnt NumberOfContractorsGT100K
# 1308532
# 1308532
#
# F9_07_PC_NUM_INDS_GREATER_100K NumberIndividualsGT100K IndivRcvdGreaterThan100KCnt
# 1486794
# 1486794
#
# F9_07_PC_TOTAL_COMP_GRTR_150K TotalCompGT150K TotalCompGreaterThan150KInd
# 2104435
# 2104435
#
# F9_07_PC_TOT_OTHER_COMPENSATION TotalOtherCompensation TotalOtherCompensationAmt
# 1293080
# 1293080
#
# F9_07_PC_TOT_REPRT_COMP_FROM_ORG TotalReportableCompFromOrgAmt TotalReportableCompFromOrg
# 1577239
# 1577239
#
# F9_07_PC_TOT_REPRT_COMP_RLTD_ORG TotReportableCompRltdOrgAmt TotalReportableCompFrmRltdOrgs
# 1177931
# 1177931
#
# F9_08_EXP_SCHED_O_X InfoInScheduleOPartVIIIInd InfoInScheduleOPartVIII
# 18893
# 18893
#
# F9_08_PC_ALL_OTHER_CONTRIBUTIONS AllOtherContributions AllOtherContributionsAmt
# 1405348
# 1405348
#
# F9_08_PC_CONTS_REPRTD_FNDRAISNG CntrbtnsRprtdFundraisingEvents ContriRptFundraisingEventAmt
# 356104
# 356104
#
# F9_08_PC_COST_OF_GOODS_SOLD CostOfGoodsSoldAmt CostOfGoodsSold
# 290722
# 290722
#
# F9_08_PC_FEDERATED_CAMPAIGNS FederatedCampaignsAmt FederatedCampaigns
# 143260
# 143260
#
# F9_08_PC_FUNDRAISING_DIRECT_EXP FundraisingDirectExpensesAmt FundraisingDirectExpenses
# 581514
# 581514
#
# F9_08_PC_FUNDRAISING_EVENTS FundraisingAmt FundraisingEvents
# 374350
# 374350
#
# F9_08_PC_FUNDRAISING_GROSS_INC GrossIncomeFundraisingEvents FundraisingGrossIncomeAmt
# 603163
# 603163
#
# F9_08_PC_GAMING_DIRECT_EXPENSES GamingDirectExpensesAmt GamingDirectExpenses
# 124916
# 124916
#
# F9_08_PC_GAMING_GROSS_INCOME GrossIncomeGaming GamingGrossIncomeAmt
# 130647
# 130647
#
# F9_08_PC_GOVERNMENT_GRANTS GovernmentGrants GovernmentGrantsAmt
# 591546
# 591546
#
# F9_08_PC_GROSS_SALES_INVENTORY GrossSalesOfInventory GrossSalesOfInventoryAmt
# 306138
# 306138
#
# F9_08_PC_MEMBERSHIP_DUES MembershipDues MembershipDuesAmt
# 370102
# 370102
#
# F9_08_PC_NONCASH_CONTRIBUTIONS NoncashContributions NoncashContributionsAmt
# 348699
# 348699
#
# F9_08_PC_PROGRAM_SVCE_REV_TOTAL TotalProgramServiceRevenueAmt TotalProgramServiceRevenue
# 1565297
# 1565297
#
# F9_08_PC_RELATED_ORGANIZATIONS RelatedOrganizationsAmt RelatedOrganizations
# 142861
# 142861
#
# F9_08_PC_TOTAL_CONTRIBUTIONS TotalContributions TotalContributionsAmt
# 1753790
# 1753790
#
# F9_08_PC_TOTAL_OTHER_REVENUE OtherRevenueTotalAmt TotalOtherRevenue
# 1101679
# 1101679
#
# F9_08_PC_TOTAL_PROG_SVCE_REVENUE TotalProgramServiceRevenueAmt TotalProgramServiceRevenue
# 1565297
# 1565297
#
# F9_08_PC_TOTAL_REVENUE TotalRevenue TotalRevenueGrp
# 2104435
# 2104435
#
# F9_09_EXP_AD_PROMO_TOT AdvertisingGrp Advertising
# 1293397
# 1293397
#
# F9_09_EXP_BENF_PAID_MEMB_TOT BenefitsToMembers BenefitsToMembersGrp
# 566695
# 566695
#
# F9_09_EXP_CONF_MEETING_TOT ConferencesMeetingsGrp ConferencesMeetings
# 1169252
# 1169252
#
# F9_09_EXP_DEPREC_FUNDR DepreciationDepletion DepreciationDepletionGrp
# 1550879
# 1550879
#
# F9_09_EXP_DEPREC_MAG DepreciationDepletion DepreciationDepletionGrp
# 1550879
# 1550879
#
# F9_09_EXP_DEPREC_PROG DepreciationDepletion DepreciationDepletionGrp
# 1550879
# 1550879
#
# F9_09_EXP_DEPREC_TOT DepreciationDepletion DepreciationDepletionGrp
# 1550879
# 1550879
#
# F9_09_EXP_GRANT_FRGN_TOT ForeignGrants ForeignGrantsGrp
# 546623
# 546623
#
# F9_09_EXP_GRANT_INDIV_DMSTC_TOT GrantsToDomesticIndividualsGrp GrantsToDomesticIndividuals
# 719005
# 719005
#
# F9_09_EXP_GRANT_ORG_DMSTC_TOT GrantsToDomesticOrgsGrp GrantsToDomesticOrgs
# 810635
# 810635
#
# F9_09_EXP_INFO_TECH_TOT InformationTechnology InformationTechnologyGrp
# 964238
# 964238
#
# F9_09_EXP_INSURANCE_TOT Insurance InsuranceGrp
# 1639935
# 1639935
#
# F9_09_EXP_INTEREST_TOT Interest InterestGrp
# 969300
# 969300
#
# F9_09_EXP_JOINT_COSTS_TOT TotalJointCosts TotalJointCostsGrp
# 14923
# 14923
#
# F9_09_EXP_OCCUPANCY_TOT OccupancyGrp Occupancy
# 1521723
# 1521723
#
# F9_09_EXP_OFFICE_TOT OfficeExpenses OfficeExpensesGrp
# 1765091
# 1765091
#
# F9_09_EXP_OTH_OTH_TOT AllOtherExpenses AllOtherExpensesGrp
# 1424339
# 1424339
#
# F9_09_EXP_OTH_TOT OtherExpenses OtherExpensesGrp
# 1948561
# 1948561
#
# F9_09_EXP_ROY_TOT RoyaltiesGrp Royalties
# 513944
# 513944
#
# F9_09_EXP_SCHED_O_X InfoInScheduleOPartIXInd InfoInScheduleOPartIX
# 328361
# 328361
#
# F9_09_EXP_TRAVEL_ENTRTNMNT_TOT PymtTravelEntrtnmntPubOfclGrp TravelEntrtnmntPublicOfficials
# 506307
# 506307
#
# F9_09_EXP_TRAVEL_TOT TravelGrp Travel
# 1328365
# 1328365
#
# F9_09_PC_COMP_DISQUAL_FUNDRAISE CompDisqualPersonsGrp CompDisqualPersons
# 542588
# 542588
#
# F9_09_PC_COMP_DISQUAL_MGMT CompDisqualPersonsGrp CompDisqualPersons
# 542588
# 542588
#
# F9_09_PC_COMP_DISQUAL_PROG_SVCE CompDisqualPersonsGrp CompDisqualPersons
# 542588
# 542588
#
# F9_09_PC_COMP_DISQUAL_TOTAL CompDisqualPersonsGrp CompDisqualPersons
# 542588
# 542588
#
# F9_09_PC_COMP_OFFICERS_FUNDRAISE CompCurrentOfcrDirectorsGrp CompCurrentOfficersDirectors
# 1232247
# 1232247
#
# F9_09_PC_COMP_OFFICERS_MGMT CompCurrentOfcrDirectorsGrp CompCurrentOfficersDirectors
# 1232247
# 1232247
#
# F9_09_PC_COMP_OFFICERS_PROG_SVCE CompCurrentOfcrDirectorsGrp CompCurrentOfficersDirectors
# 1232247
# 1232247
#
# F9_09_PC_COMP_OFFICERS_TOTAL CompCurrentOfcrDirectorsGrp CompCurrentOfficersDirectors
# 1232247
# 1232247
#
# F9_09_PC_FEES_FOR_SVCE_ACCT_TOT FeesForServicesAccounting FeesForServicesAccountingGrp
# 1717676
# 1717676
#
# F9_09_PC_FEES_FOR_SVCE_INVST_TOT FeesForSrvcInvstMgmntFeesGrp FeesForServicesInvstMgmntFees
# 707477
# 707477
#
# F9_09_PC_FEES_FOR_SVCE_LEGL_TOT FeesForServicesLegal FeesForServicesLegalGrp
# 1026258
# 1026258
#
# F9_09_PC_FEES_FOR_SVCE_LOBB_TOT FeesForServicesLobbying FeesForServicesLobbyingGrp
# 551749
# 551749
#
# F9_09_PC_FEES_FOR_SVCE_MGMT_TOT FeesForServicesManagement FeesForServicesManagementGrp
# 735544
# 735544
#
# F9_09_PC_FEES_FOR_SVCE_OTH_TOT FeesForServicesOther FeesForServicesOtherGrp
# 1254088
# 1254088
#
# F9_09_PC_OTHER_EMP_BEN_FUNDRAISE OtherEmployeeBenefits OtherEmployeeBenefitsGrp
# 1208899
# 1208899
#
# F9_09_PC_OTHER_EMP_BEN_MGMT OtherEmployeeBenefits OtherEmployeeBenefitsGrp
# 1208899
# 1208899
#
# F9_09_PC_OTHER_EMP_BEN_PROG_SVCE OtherEmployeeBenefits OtherEmployeeBenefitsGrp
# 1208899
# 1208899
#
# F9_09_PC_OTHER_EMP_BEN_TOTAL OtherEmployeeBenefits OtherEmployeeBenefitsGrp
# 1208899
# 1208899
#
# F9_09_PC_OTHER_SALARY_FUNDRAISE OtherSalariesAndWages OtherSalariesAndWagesGrp
# 1497471
# 1497471
#
# F9_09_PC_OTHER_SALARY_MGMT OtherSalariesAndWages OtherSalariesAndWagesGrp
# 1497471
# 1497471
#
# F9_09_PC_OTHER_SALARY_PROG_SVCE OtherSalariesAndWages OtherSalariesAndWagesGrp
# 1497471
# 1497471
#
# F9_09_PC_OTHER_SALARY_TOTAL OtherSalariesAndWages OtherSalariesAndWagesGrp
# 1497471
# 1497471
#
# F9_09_PC_PAYMENT_TO_AFFILIATES PaymentsToAffiliatesGrp PaymentsToAffiliates
# 570514
# 570514
#
# F9_09_PC_PAYROLL_TAX_FUNDRAISE PayrollTaxesGrp PayrollTaxes
# 1480299
# 1480299
#
# F9_09_PC_PAYROLL_TAX_MGMT PayrollTaxesGrp PayrollTaxes
# 1480299
# 1480299
#
# F9_09_PC_PAYROLL_TAX_PROG_SVCE PayrollTaxesGrp PayrollTaxes
# 1480299
# 1480299
#
# F9_09_PC_PAYROLL_TAX_TOTAL PayrollTaxesGrp PayrollTaxes
# 1480299
# 1480299
#
# F9_09_PC_PENSION_CONT_FUNDRAISE PensionPlanContributionsGrp PensionPlanContributions
# 893515
# 893515
#
# F9_09_PC_PENSION_CONT_MGMT PensionPlanContributionsGrp PensionPlanContributions
# 893515
# 893515
#
# F9_09_PC_PENSION_CONT_PROG_SVCE PensionPlanContributionsGrp PensionPlanContributions
# 893515
# 893515
#
# F9_09_PC_PENSION_CONT_TOTAL PensionPlanContributionsGrp PensionPlanContributions
# 893515
# 893515
#
# F9_09_PC_TOTAL_FUNC_EXPENSES TotalFunctionalExpenses TotalFunctionalExpensesGrp
# 2104435
# 2104435
#
# F9_09_PC_TOTAL_FUNDRAISE_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# 2104435
# 2104435
#
# F9_09_PC_TOTAL_MGMT_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# 2104435
# 2104435
#
# F9_09_PC_TOTAL_PROG_SVCE_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# 2104435
# 2104435
#
# F9_10_ASSETS_ACC_NET_EOY AccountsReceivableGrp AccountsReceivable
# 1227243
# 1227243
#
# F9_10_ASSETS_EXP_PREPAID_EOY PrepaidExpensesDefrdChargesGrp PrepaidExpensesDeferredCharges
# 1195436
# 1195436
#
# F9_10_ASSETS_INTANGIB_EOY IntangibleAssets IntangibleAssetsGrp
# 500227
# 500227
#
# F9_10_ASSETS_INVENT_SALE_EOY InventoriesForSaleOrUse InventoriesForSaleOrUseGrp
# 700811
# 700811
#
# F9_10_ASSETS_LESS_DEPREC_EOY LandBldgEquipBasisNetGrp LandBuildingsEquipmentBasisNet
# 1634188
# 1634188
#
# F9_10_ASSETS_LOANS_DISQUAL_EOY RcvblFromDisqualifiedPrsnGrp ReceivablesFromDisqualPersons
# 431671
# 431671
#
# F9_10_ASSETS_NOTES_LOANS_NET_EOY OthNotesLoansReceivableNetGrp OtherNotesLoansReceivableNet
# 559887
# 559887
#
# F9_10_ASSETS_OTH_EOY OtherAssetsTotalGrp OtherAssetsTotal
# 1084016
# 1084016
#
# F9_10_ASSETS_PLEDGES_NET_EOY PledgesAndGrantsReceivable PledgesAndGrantsReceivableGrp
# 768518
# 768518
#
# F9_10_LIAB_ACC_PAYABLE_EOY AccountsPayableAccrExpnssGrp AccountsPayableAccruedExpenses
# 1462819
# 1462819
#
# F9_10_LIAB_GRANTS_PAYABLE_EOY GrantsPayableGrp GrantsPayable
# 158489
# 158489
#
# F9_10_LIAB_LOANS_OFF_EOY LoansFromOfficersDirectors LoansFromOfficersDirectorsGrp
# 166551
# 166551
#
# F9_10_LIAB_REV_DEFERRED_EOY DeferredRevenue DeferredRevenueGrp
# 610479
# 610479
#
# F9_10_NAFB_RESTRICT_PERM_EOY PermanentlyRstrNetAssetsGrp PermanentlyRestrictedNetAssets
# 297699
# 297699
#
# F9_10_NAFB_RESTRICT_TEMP_EOY TemporarilyRstrNetAssetsGrp TemporarilyRestrictedNetAssets
# 628829
# 628829
#
# F9_10_NAFB_UNRESTRICT_EOY UnrestrictedNetAssets UnrestrictedNetAssetsGrp
# 1386338
# 1386338
#
# F9_10_PC_BOND_LIABILITY_EOY TaxExemptBondLiabilities TaxExemptBondLiabilitiesGrp
# 156056
# 156056
#
# F9_10_PC_CASH_NON_INTEREST_BOY CashNonInterestBearing CashNonInterestBearingGrp
# 1935128
# 1935128
#
# F9_10_PC_CASH_NON_INTEREST_EOY CashNonInterestBearing CashNonInterestBearingGrp
# 1935128
# 1935128
#
# F9_10_PC_ESCROW_LIABILITY_EOY EscrowAccountLiabilityGrp EscrowAccountLiability
# 150334
# 150334
#
# F9_10_PC_INVEST_OTHER_SEC_EOY InvestmentsOtherSecurities InvestmentsOtherSecuritiesGrp
# 618080
# 618080
#
# F9_10_PC_INVEST_PROG_RELTD_EOY InvestmentsProgramRelated InvestmentsProgramRelatedGrp
# 482344
# 482344
#
# F9_10_PC_INVEST_PUB_TRADED_EOY InvestmentsPubTradedSecGrp InvestmentsPubTradedSecurities
# 837286
# 837286
#
# F9_10_PC_LAND_BLDG_EQPMT LandBldgEquipCostOrOtherBssAmt LandBuildingsEquipmentBasis
# 1546151
# 1546151
#
# F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN LandBldgEquipAccumDeprecAmt LandBldgEquipmentAccumDeprec
# 1481897
# 1481897
#
# F9_10_PC_LOANS_FROM_OFFICERS_EOY LoansFromOfficersDirectors LoansFromOfficersDirectorsGrp
# 166551
# 166551
#
# F9_10_PC_ORG_FOLLOWS_SFAS117 OrganizationFollowsSFAS117Ind FollowSFAS117
# 1399938
# 1399938
#
# F9_10_PC_ORG_NOT_FOLLOW_SFAS117 DoNotFollowSFAS117 OrgDoesNotFollowSFAS117Ind
# 414340
# 414340
#
# F9_10_PC_OTHER_LIABILITIES_EOY OtherLiabilities OtherLiabilitiesGrp
# 920215
# 920215
#
# F9_10_PC_RET_EARNINGS_ENDWMT_EOY RtnEarnEndowmentIncmOthFndsGrp RetainedEarningsEndowmentEtc
# 460172
# 460172
#
# F9_10_PC_SAVINGS_TEMP_INVEST_BOY SavingsAndTempCashInvestments SavingsAndTempCashInvstGrp
# 1393470
# 1393470
#
# F9_10_PC_SAVINGS_TEMP_INVEST_EOY SavingsAndTempCashInvestments SavingsAndTempCashInvstGrp
# 1393470
# 1393470
#
# F9_10_PC_SECURED_MORTGAGES_EOY MortNotesPyblSecuredInvestProp MortgNotesPyblScrdInvstPropGrp
# 546760
# 546760
#
# F9_10_PC_SECURE_MORT_NOTES_EOY MortNotesPyblSecuredInvestProp MortgNotesPyblScrdInvstPropGrp
# 546760
# 546760
#
# F9_10_PC_UNSECURED_LOANS_EOY UnsecuredNotesLoansPayableGrp UnsecuredNotesLoansPayable
# 238687
# 238687
#
# F9_10_PC_UNSECURED_NOTES_BOY UnsecuredNotesLoansPayableGrp UnsecuredNotesLoansPayable
# 238687
# 238687
#
# F9_10_PC_UNSECURED_NOTES_EOY UnsecuredNotesLoansPayableGrp UnsecuredNotesLoansPayable
# 238687
# 238687
#
# F9_10_PZ_TOTAL_ASSETS_EOY TotalAssetsGrp TotalAssets
# 2104435
# 2104435
#
# F9_10_SCHED_O_X InfoInScheduleOPartX InfoInScheduleOPartXInd
# 17683
# 17683
#
# F9_11_PC_RECNCLTN_DONATED_SVCES ReconcilationDonatedServices DonatedServicesAndUseFcltsAmt
# 64834
# 64834
#
# F9_11_PC_RECNCLTN_INVSTMNT_EXP ReconcilationInvestExpenses InvestmentExpenseAmt
# 52794
# 52794
#
# F9_11_PC_RECNCLTN_PRIOR_PER_ADJ ReconcilationPriorAdjustment PriorPeriodAdjustmentsAmt
# 173617
# 173617
#
# F9_11_PC_RECNCLTN_REV_LESS_EXP ReconcilationRevenueExpenses ReconcilationRevenueExpnssAmt
# 2098475
# 2098475
#
# F9_11_PC_RECNCLTN_UNRLZD_GAIN NetUnrlzdGainsLossesInvstAmt ReconciliationUnrealizedInvest
# 484112
# 484112
#
# F9_11_SCHED_O_X InfoInScheduleOPartXIInd InfoInScheduleOPartXI
# 369369
# 369369
#
# F9_12_PC_ACCNT_COMPILE_OR_REVIEW AccountantCompileOrReview AccountantCompileOrReviewInd
# 2104435
# 2104435
#
# F9_12_PC_ACCTG_METHOD_ACCRUAL MethodOfAccountingAccrual MethodOfAccountingAccrualInd
# 1392441
# 1392441
#
# F9_12_PC_ACCTG_METHOD_CASH MethodOfAccountingCashInd MethodOfAccountingCash
# 668184
# 668184
#
# F9_12_PC_ACCTG_METHOD_OTHER MethodOfAccountingOther MethodOfAccountingOtherInd
# 43810
# 43810
#
# F9_12_PC_AUDIT_COMMITTEE AuditCommittee AuditCommitteeInd
# 1216828
# 1216828
#
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD FederalGrantAuditPerformedInd FederalGrantAuditPerformed
# 237299
# 237299
#
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED FederalGrantAuditRequiredInd FederalGrantAuditRequired
# 1904509
# 1904509
#
# F9_12_PC_FINCL_STMTS_AUDITED FSAudited FSAuditedInd
# 2104435
# 2104435
#
# F9_12_SCHED_O_X InfoInScheduleOPartXIIInd InfoInScheduleOPartXII
# 379406
# 379406
#
# number_of_other_prog_svces ActivityOther ProgSrvcAccomActyOtherGrp
# 293660
# 293660

# %%
print(len(concordance))
print(len(new_variables_df))
print(len(set(new_variables_df['variable_name_new'].tolist())))
new_variables_df[:2]
# Out:
# 574
# 288
# 288
#          variable_name_new                     original_names data_type_xsd  \
# 0     F9_00_HD_ADDR_CHANGE  [AddressChange, AddressChangeInd]  CheckboxType
# 1  F9_00_HD_AMENDED_RETURN  [AmendedReturnInd, AmendedReturn]  CheckboxType
#
#    binarize  len
# 0  binarize    2
# 1  binarize    2

# %% [markdown]
# <br><br>
# From the above we are fine with deleting the ~574 variables related to the 288 above variables in *variable_name_new* (numbers from earlier version of notebook).

# %% [markdown]
# ### Inspect the Combined and Original Variables
# Here I'm showing one variable. What we're seeing here is the new 'combined' column -- the one with the standardized name ``F9_12_PC_FED_GRNT_AUDIT_REQUIRED`` and the two columns from which this variable was combined. Recall that the reason for this is that in early years the IRS used one name (*FederalGrantAuditRequired*) for storing this data in the XML files, while for later years the IRS used a different name (*FederalGrantAuditRequired*). Our checks above verified that no filing contains data on both variables; it's one or the other, so we are safe combining.

# %%
#df[df['F9_12_PC_FED_GRNT_AUDIT_REQUIRED'].notnull()].sample(5)[['F9_12_PC_FED_GRNT_AUDIT_REQUIRED', 'FederalGrantAuditRequiredInd', 'FederalGrantAuditRequired']]

# %%
df[df['F9_12_PC_FED_GRNT_AUDIT_REQUIRED'].notnull()].sample(5)[['F9_12_PC_FED_GRNT_AUDIT_REQUIRED', 'FederalGrantAuditRequiredInd']]
# Out:
#          F9_12_PC_FED_GRNT_AUDIT_REQUIRED FederalGrantAuditRequiredInd
# 2553147                                 0                        false
# 385507                                  0                         None
# 139093                                  0                         None
# 2196320                                 0                        false
# 2023345                                 1                            1

# %% [markdown]
# # Fill Null Values for binary variables

# %%
print(binarize_with_dict_cols)
# Out:
# ['F9_00_HD_INCLUDES_SUBORD_ORGS', 'F9_04_PC_ACTVITIES_VIA_PARTNER', 'F9_04_PC_CONTROLLED_ENTITY', 'F9_04_PC_DISREGARDED_ENTITY', 'F9_04_PC_EXCESS_BENEFIT_TRANS', 'F9_04_PC_FR_EVENT_INC_GT_15K', 'F9_04_PC_GAMING_INC_GT_15K', 'F9_04_PC_LOBBYING_ACTIVITIES', 'F9_04_PC_POLITICAL_ACTIVITIES', 'F9_04_PC_PRIOR_EXCESS_BEN_TRAN', 'F9_04_PC_PROF_FR_EXP_GT_15K', 'F9_04_PC_RELATED_ENTITY', 'F9_04_PC_TRANS_TO_CNTRLD_ENT', 'F9_04_PC_TRANS_WITH_CNTRLD_ENT']

# %%
df[binarize_with_dict_cols] = df[binarize_with_dict_cols].fillna(0).astype('int64')

# %%
print(binarize_cols)
# Out:
# ['F9_00_HD_ADDR_CHANGE', 'F9_00_HD_AMENDED_RETURN', 'F9_00_HD_EXEMPT_STATUS_4847A1', 'F9_00_HD_EXEMPT_STATUS_501C3', 'F9_00_HD_FINAL_RETURN', 'F9_00_HD_GROUP_RETURN', 'F9_00_HD_INITIAL_RETURN', 'F9_00_HD_TYPE_ORG_ASSOCIATION', 'F9_00_HD_TYPE_ORG_CORP', 'F9_00_HD_TYPE_ORG_OTHER', 'F9_00_HD_TYPE_ORG_TRUST', 'F9_01_PC_TERMINATION_CONTRACTION', 'F9_03_PC_PGMSVC_SIGNIF_CHG', 'F9_03_PC_PGMSVC_SIGNIF_NEW', 'F9_03_PZ_SCHEDULE_O_PART3', 'F9_05_EXP_SCHED_O_X', 'F9_05_PC_UNRELATED_BUS_INCOME', 'F9_06_EXP_SCHED_O_X', 'F9_06_PC_990_PROVIDED_GOV_BODY', 'F9_06_PC_ANNUAL_DISC_COVRD_PERS', 'F9_06_PC_CEO_COMPENSTN_PROCESS', 'F9_06_PC_CHANGES_ORGANIZING_DOCS', 'F9_06_PC_CONFLICT_OF_INTEREST', 'F9_06_PC_DECISIONS_SUBJ_APPROVAL', 'F9_06_PC_DELEGATION_MGT_DUTIES', 'F9_06_PC_DELEGATION_OF_MGT', 'F9_06_PC_DOCUMENT_RET_POLICY', 'F9_06_PC_ELECTION_BOARD_MEMBERS', 'F9_06_PC_FAMILY_OR_BUSINESS_REL', 'F9_06_PC_FORM_AVAIL_OWN_WEBSITE', 'F9_06_PC_FORM_UPON_REQUEST', 'F9_06_PC_JOINT_VENTURE_INVESTMNT', 'F9_06_PC_JOINT_VENTURE_POLICY', 'F9_06_PC_LOCAL_CHAPTERS', 'F9_06_PC_MATERIAL_DIVERSION', 'F9_06_PC_MEMBERS_OR_STOCKHOLDERS', 'F9_06_PC_MINUTES_COMMITTEES', 'F9_06_PC_MINUTES_GOVERNING_BODY', 'F9_06_PC_MONITORING_OF_COI_POLICY', 'F9_06_PC_OFFICER_MAILING_ADDRESS', 'F9_06_PC_OTHER_COMPENSTN_PROCESS', 'F9_06_PC_OTHER_WEBSITE', 'F9_06_PC_OWN_WEBSITE', 'F9_06_PC_POLICIES_GOVERN_CHAPTER', 'F9_06_PC_WHISTLEBLOWER_POLICY', 'F9_07_EXP_SCHED_O_X', 'F9_07_PC_COMPENSATION_OTHER_SRCE', 'F9_07_PC_FORMER_OFFICER_LISTED', 'F9_07_PC_NO_LISTED_PERS_COMPENSD', 'F9_07_PC_TOTAL_COMP_GRTR_150K', 'F9_08_EXP_SCHED_O_X', 'F9_09_EXP_SCHED_O_X', 'F9_10_PC_ORG_FOLLOWS_SFAS117', 'F9_10_PC_ORG_NOT_FOLLOW_SFAS117', 'F9_10_SCHED_O_X', 'F9_11_SCHED_O_X', 'F9_12_PC_ACCNT_COMPILE_OR_REVIEW', 'F9_12_PC_ACCTG_METHOD_ACCRUAL', 'F9_12_PC_ACCTG_METHOD_CASH', 'F9_12_PC_AUDIT_COMMITTEE', 'F9_12_PC_FED_GRNT_AUDIT_PERFORMD', 'F9_12_PC_FED_GRNT_AUDIT_REQUIRED', 'F9_12_PC_FINCL_STMTS_AUDITED', 'F9_12_SCHED_O_X']

# %%
df[binarize_cols] = df[binarize_cols].fillna(0).astype('int64')

# %%
df[binarize_with_dict_cols].dtypes
# Out:
# F9_00_HD_INCLUDES_SUBORD_ORGS     int64
# F9_04_PC_ACTVITIES_VIA_PARTNER    int64
# F9_04_PC_CONTROLLED_ENTITY        int64
# F9_04_PC_DISREGARDED_ENTITY       int64
# F9_04_PC_EXCESS_BENEFIT_TRANS     int64
# F9_04_PC_FR_EVENT_INC_GT_15K      int64
# F9_04_PC_GAMING_INC_GT_15K        int64
# F9_04_PC_LOBBYING_ACTIVITIES      int64
# F9_04_PC_POLITICAL_ACTIVITIES     int64
# F9_04_PC_PRIOR_EXCESS_BEN_TRAN    int64
# F9_04_PC_PROF_FR_EXP_GT_15K       int64
# F9_04_PC_RELATED_ENTITY           int64
# F9_04_PC_TRANS_TO_CNTRLD_ENT      int64
# F9_04_PC_TRANS_WITH_CNTRLD_ENT    int64
# dtype: object

# %%
df[binarize_with_dict_cols].isna().sum()
# Out:
# F9_00_HD_INCLUDES_SUBORD_ORGS     0
# F9_04_PC_ACTVITIES_VIA_PARTNER    0
# F9_04_PC_CONTROLLED_ENTITY        0
# F9_04_PC_DISREGARDED_ENTITY       0
# F9_04_PC_EXCESS_BENEFIT_TRANS     0
# F9_04_PC_FR_EVENT_INC_GT_15K      0
# F9_04_PC_GAMING_INC_GT_15K        0
# F9_04_PC_LOBBYING_ACTIVITIES      0
# F9_04_PC_POLITICAL_ACTIVITIES     0
# F9_04_PC_PRIOR_EXCESS_BEN_TRAN    0
# F9_04_PC_PROF_FR_EXP_GT_15K       0
# F9_04_PC_RELATED_ENTITY           0
# F9_04_PC_TRANS_TO_CNTRLD_ENT      0
# F9_04_PC_TRANS_WITH_CNTRLD_ENT    0
# dtype: int64

# %%
df[binarize_with_dict_cols].apply(pd.Series.value_counts, dropna=False)
# Out:
#    F9_00_HD_INCLUDES_SUBORD_ORGS  F9_04_PC_ACTVITIES_VIA_PARTNER  \
# 0                        3450218                         3466996
# 1                          18790                            2012
#
#    F9_04_PC_CONTROLLED_ENTITY  F9_04_PC_DISREGARDED_ENTITY  \
# 0                     3275577                      3374936
# 1                      193431                        94072
#
#    F9_04_PC_EXCESS_BENEFIT_TRANS  F9_04_PC_FR_EVENT_INC_GT_15K  \
# 0                        3468250                       2722872
# 1                            758                        746136
#
#    F9_04_PC_GAMING_INC_GT_15K  F9_04_PC_LOBBYING_ACTIVITIES  \
# 0                     3363193                       3326176
# 1                      105815                        142832
#
#    F9_04_PC_POLITICAL_ACTIVITIES  F9_04_PC_PRIOR_EXCESS_BEN_TRAN  \
# 0                        3434370                         3468406
# 1                          34638                             602
#
#    F9_04_PC_PROF_FR_EXP_GT_15K  F9_04_PC_RELATED_ENTITY  \
# 0                      3375717                  2624580
# 1                        93291                   844428
#
#    F9_04_PC_TRANS_TO_CNTRLD_ENT  F9_04_PC_TRANS_WITH_CNTRLD_ENT
# 0                       3437295                         3358227
# 1                         31713                          110781

# %%
df[binarize_with_dict_cols].describe().T
# Out:
#                                     count      mean       std  min  25%  50%  \
# F9_00_HD_INCLUDES_SUBORD_ORGS   3469008.0  0.005417  0.073398  0.0  0.0  0.0
# F9_04_PC_ACTVITIES_VIA_PARTNER  3469008.0  0.000580  0.024076  0.0  0.0  0.0
# F9_04_PC_CONTROLLED_ENTITY      3469008.0  0.055760  0.229457  0.0  0.0  0.0
# F9_04_PC_DISREGARDED_ENTITY     3469008.0  0.027118  0.162427  0.0  0.0  0.0
# F9_04_PC_EXCESS_BENEFIT_TRANS   3469008.0  0.000219  0.014780  0.0  0.0  0.0
# F9_04_PC_FR_EVENT_INC_GT_15K    3469008.0  0.215086  0.410882  0.0  0.0  0.0
# F9_04_PC_GAMING_INC_GT_15K      3469008.0  0.030503  0.171967  0.0  0.0  0.0
# F9_04_PC_LOBBYING_ACTIVITIES    3469008.0  0.041174  0.198692  0.0  0.0  0.0
# F9_04_PC_POLITICAL_ACTIVITIES   3469008.0  0.009985  0.099425  0.0  0.0  0.0
# F9_04_PC_PRIOR_EXCESS_BEN_TRAN  3469008.0  0.000174  0.013172  0.0  0.0  0.0
# F9_04_PC_PROF_FR_EXP_GT_15K     3469008.0  0.026893  0.161770  0.0  0.0  0.0
# F9_04_PC_RELATED_ENTITY         3469008.0  0.243421  0.429147  0.0  0.0  0.0
# F9_04_PC_TRANS_TO_CNTRLD_ENT    3469008.0  0.009142  0.095175  0.0  0.0  0.0
# F9_04_PC_TRANS_WITH_CNTRLD_ENT  3469008.0  0.031934  0.175826  0.0  0.0  0.0
#
#                                 75%  max
# F9_00_HD_INCLUDES_SUBORD_ORGS   0.0  1.0
# F9_04_PC_ACTVITIES_VIA_PARTNER  0.0  1.0
# F9_04_PC_CONTROLLED_ENTITY      0.0  1.0
# F9_04_PC_DISREGARDED_ENTITY     0.0  1.0
# F9_04_PC_EXCESS_BENEFIT_TRANS   0.0  1.0
# F9_04_PC_FR_EVENT_INC_GT_15K    0.0  1.0
# F9_04_PC_GAMING_INC_GT_15K      0.0  1.0
# F9_04_PC_LOBBYING_ACTIVITIES    0.0  1.0
# F9_04_PC_POLITICAL_ACTIVITIES   0.0  1.0
# F9_04_PC_PRIOR_EXCESS_BEN_TRAN  0.0  1.0
# F9_04_PC_PROF_FR_EXP_GT_15K     0.0  1.0
# F9_04_PC_RELATED_ENTITY         0.0  1.0
# F9_04_PC_TRANS_TO_CNTRLD_ENT    0.0  1.0
# F9_04_PC_TRANS_WITH_CNTRLD_ENT  0.0  1.0

# %%
df[binarize_cols].describe().T
# Out:
#                                       count      mean       std  min  25%  \
# F9_00_HD_ADDR_CHANGE              3469008.0  0.039835  0.195571  0.0  0.0
# F9_00_HD_AMENDED_RETURN           3469008.0  0.011920  0.108527  0.0  0.0
# F9_00_HD_EXEMPT_STATUS_4847A1     3469008.0  0.000709  0.026626  0.0  0.0
# F9_00_HD_EXEMPT_STATUS_501C3      3469008.0  0.752216  0.431726  0.0  1.0
# F9_00_HD_FINAL_RETURN             3469008.0  0.005586  0.074533  0.0  0.0
# ...                                     ...       ...       ...  ...  ...
# F9_12_PC_AUDIT_COMMITTEE          3469008.0  0.437851  0.496123  0.0  0.0
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD  3469008.0  0.085901  0.280217  0.0  0.0
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED  3469008.0  0.086664  0.281342  0.0  0.0
# F9_12_PC_FINCL_STMTS_AUDITED      3469008.0  0.434902  0.495744  0.0  0.0
# F9_12_SCHED_O_X                   3469008.0  0.165592  0.371714  0.0  0.0
#
#                                   50%  75%  max
# F9_00_HD_ADDR_CHANGE              0.0  0.0  1.0
# F9_00_HD_AMENDED_RETURN           0.0  0.0  1.0
# F9_00_HD_EXEMPT_STATUS_4847A1     0.0  0.0  1.0
# F9_00_HD_EXEMPT_STATUS_501C3      1.0  1.0  1.0
# F9_00_HD_FINAL_RETURN             0.0  0.0  1.0
# ...                               ...  ...  ...
# F9_12_PC_AUDIT_COMMITTEE          0.0  1.0  1.0
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD  0.0  0.0  1.0
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED  0.0  0.0  1.0
# F9_12_PC_FINCL_STMTS_AUDITED      0.0  1.0  1.0
# F9_12_SCHED_O_X                   0.0  0.0  1.0
#
# [64 rows x 8 columns]

# %%
df[binarize_cols].dtypes
# Out:
# F9_00_HD_ADDR_CHANGE                int64
# F9_00_HD_AMENDED_RETURN             int64
# F9_00_HD_EXEMPT_STATUS_4847A1       int64
# F9_00_HD_EXEMPT_STATUS_501C3        int64
# F9_00_HD_FINAL_RETURN               int64
#                                     ...
# F9_12_PC_AUDIT_COMMITTEE            int64
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD    int64
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED    int64
# F9_12_PC_FINCL_STMTS_AUDITED        int64
# F9_12_SCHED_O_X                     int64
# Length: 64, dtype: object

# %%
df[binarize_cols].isna().sum()
# Out:
# F9_00_HD_ADDR_CHANGE                0
# F9_00_HD_AMENDED_RETURN             0
# F9_00_HD_EXEMPT_STATUS_4847A1       0
# F9_00_HD_EXEMPT_STATUS_501C3        0
# F9_00_HD_FINAL_RETURN               0
#                                    ..
# F9_12_PC_AUDIT_COMMITTEE            0
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD    0
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED    0
# F9_12_PC_FINCL_STMTS_AUDITED        0
# F9_12_SCHED_O_X                     0
# Length: 64, dtype: int64

# %% [markdown]
# ### Drop variables
# Above we have combined columns that relate to the same 990 variable. Generally, there are two different names -- and thus two different columns -- for each 990 variable. Given that above we have combined these two columns into a new variable -- with a new name -- we can delete all the old columns.

# %%
new_variables_df['original_names'].tolist()
# Out:
# [['AddressChange', 'AddressChangeInd'],
#  ['AmendedReturnInd', 'AmendedReturn'],
#  ['BuildTS'],
#  ['CountryLegalDomicile', 'LegalDomicileCountryCd'],
#  ['Organization4947a1NotPFInd', 'Organization4947a1'],
#  ['Organization501c', 'Organization501cInd'],
#  ['Organization501c3', 'Organization501c3Ind'],
#  ['Filer'],
#  ['Filer'],
#  ['Filer'],
#  ['Filer'],
#  ['Filer'],
#  ['Filer'],
#  ['FinalReturnInd', 'TerminatedReturn'],
#  ['GroupExemptionNumber', 'GroupExemptionNum'],
#  ['GrossReceipts', 'GrossReceiptsAmt'],
#  ['GroupReturnForAffiliates', 'GroupReturnForAffiliatesInd'],
#  ['AllAffiliatesIncluded', 'AllAffiliatesIncludedInd'],
#  ['InitialReturnInd', 'InitialReturn'],
#  ['NameOfPrincipalOfficerPerson', 'PrincipalOfficerNm'],
#  ['Officer', 'BusinessOfficerGrp'],
#  ['SpecialConditionDesc', 'SpecialConditionDescription'],
#  ['StateLegalDomicile', 'LegalDomicileStateCd'],
#  ['TaxPeriodBeginDate', 'TaxPeriodBeginDt'],
#  ['TaxPeriodEndDt', 'TaxPeriodEndDate'],
#  ['TaxYr', 'TaxYear'],
#  ['ReturnTs', 'Timestamp'],
#  ['TypeOfOrganizationAssocInd', 'TypeOfOrganizationAssociation'],
#  ['TypeOfOrganizationCorpInd', 'TypeOfOrganizationCorporation'],
#  ['TypeOfOrganizationOtherInd', 'TypeOfOrganizationOther'],
#  ['TypeOfOrgOtherDescription', 'OtherOrganizationDsc'],
#  ['TypeOfOrganizationTrust', 'TypeOfOrganizationTrustInd'],
#  ['WebSite', 'WebsiteAddressTxt'],
#  ['FormationYr', 'YearFormation'],
#  ['BenefitsPaidToMembersPriorYear', 'PYBenefitsPaidToMembersAmt'],
#  ['ContributionsGrantsCurrentYear', 'CYContributionsGrantsAmt'],
#  ['PYContributionsGrantsAmt', 'ContributionsGrantsPriorYear'],
#  ['GrantsAndSimilarAmntsPriorYear', 'PYGrantsAndSimilarPaidAmt'],
#  ['VotingMembersIndependentCnt', 'NbrIndependentVotingMembers'],
#  ['PYInvestmentIncomeAmt', 'InvestmentIncomePriorYear'],
#  ['NetAssetsOrFundBalancesBOYAmt', 'NetAssetsOrFundBalancesBOY'],
#  ['PYOtherExpensesAmt', 'OtherExpensePriorYear'],
#  ['PYOtherRevenueAmt', 'OtherRevenuePriorYear'],
#  ['CYTotalProfFndrsngExpnsAmt', 'TotalProfFundrsngExpCY'],
#  ['TotalProfFundrsngExpPriorYear', 'PYTotalProfFndrsngExpnsAmt'],
#  ['PYProgramServiceRevenueAmt', 'ProgramServiceRevenuePriorYear'],
#  ['CYRevenuesLessExpensesAmt', 'RevenuesLessExpensesCY'],
#  ['PYRevenuesLessExpensesAmt', 'RevenuesLessExpensesPriorYear'],
#  ['ContractTerminationInd', 'TerminationOrContraction'],
#  ['TotalAssetsEOY', 'TotalAssetsEOYAmt'],
#  ['TotalExpensesPriorYear', 'PYTotalExpensesAmt'],
#  ['TotalFundrsngExpCurrentYear', 'CYTotalFundraisingExpenseAmt'],
#  ['TotalNbrEmployees', 'TotalEmployeeCnt'],
#  ['TotalVolunteersCnt', 'TotalNbrVolunteers'],
#  ['TotalLiabilitiesEOYAmt', 'TotalLiabilitiesEOY'],
#  ['PYTotalRevenueAmt', 'TotalRevenuePriorYear'],
#  ['TotalGrossUBI', 'TotalGrossUBIAmt'],
#  ['NetUnrelatedBusinessTxblIncome', 'NetUnrelatedBusTxblIncmAmt'],
#  ['VotingMembersGoverningBodyCnt', 'NbrVotingMembersGoverningBody'],
#  ['BenefitsPaidToMembersCY', 'CYBenefitsPaidToMembersAmt'],
#  ['CYGrantsAndSimilarPaidAmt', 'GrantsAndSimilarAmntsCY'],
#  ['CYInvestmentIncomeAmt', 'InvestmentIncomeCurrentYear'],
#  ['NetAssetsOrFundBalancesEOYAmt', 'NetAssetsOrFundBalancesEOY'],
#  ['ActivityOrMissionDescription', 'ActivityOrMissionDesc'],
#  ['CYOtherExpensesAmt', 'OtherExpensesCurrentYear'],
#  ['OtherRevenueCurrentYear', 'CYOtherRevenueAmt'],
#  ['CYProgramServiceRevenueAmt', 'ProgramServiceRevenueCY'],
#  ['CYSalariesCompEmpBnftPaidAmt', 'SalariesEtcCurrentYear'],
#  ['PYSalariesCompEmpBnftPaidAmt', 'SalariesEtcPriorYear'],
#  ['TotalAssetsBOYAmt', 'TotalAssetsBOY'],
#  ['TotalExpensesCurrentYear', 'CYTotalExpensesAmt'],
#  ['TotalLiabilitiesBOY', 'TotalLiabilitiesBOYAmt'],
#  ['TotalRevenueCurrentYear', 'CYTotalRevenueAmt'],
#  ['SignificantChangeInd', 'SignificantChange'],
#  ['SignificantNewProgramSrvcInd', 'SignificantNewProgramServices'],
#  ['ActivityCd', 'ActivityCode'],
#  ['Desc', 'Description'],
#  ['ExpenseAmt', 'Expense'],
#  ['Grants', 'GrantAmt'],
#  ['Revenue', 'RevenueAmt'],
#  ['Activity2', 'ProgSrvcAccomActy2Grp'],
#  ['Activity2', 'ProgSrvcAccomActy2Grp'],
#  ['Activity2', 'ProgSrvcAccomActy2Grp'],
#  ['Activity2', 'ProgSrvcAccomActy2Grp'],
#  ['Activity2', 'ProgSrvcAccomActy2Grp'],
#  ['ProgSrvcAccomActy3Grp', 'Activity3'],
#  ['ProgSrvcAccomActy3Grp', 'Activity3'],
#  ['ProgSrvcAccomActy3Grp', 'Activity3'],
#  ['ProgSrvcAccomActy3Grp', 'Activity3'],
#  ['ProgSrvcAccomActy3Grp', 'Activity3'],
#  ['TotalOfOtherProgramServiceExp', 'TotalOtherProgSrvcExpenseAmt'],
#  ['TotalOfOtherProgramServiceGrnt', 'TotalOtherProgSrvcGrantAmt'],
#  ['TotalOtherProgSrvcRevenueAmt', 'TotalOfOtherProgramServiceRev'],
#  ['TotalProgramServiceExpensesAmt', 'TotalProgramServiceExpense'],
#  ['MissionDesc', 'MissionDescription'],
#  ['InfoInScheduleOPartIII', 'InfoInScheduleOPartIIIInd'],
#  ['ActivitiesConductedPartnership', 'ActivitiesConductedPrtshpInd'],
#  ['RelatedOrganizationCtrlEntInd', 'RelatedOrgControlledEntity'],
#  ['DisregardedEntityInd', 'DisregardedEntity'],
#  ['EngagedInExcessBenefitTransInd', 'ExcessBenefitTransaction'],
#  ['FundraisingActivities', 'FundraisingActivitiesInd'],
#  ['GamingActivitiesInd', 'Gaming'],
#  ['LobbyingActivities', 'LobbyingActivitiesInd'],
#  ['PoliticalActivities', 'PoliticalCampaignActyInd'],
#  ['PYExcessBenefitTransInd', 'PriorExcessBenefitTransaction'],
#  ['ProfessionalFundraisingInd', 'ProfessionalFundraising'],
#  ['RelatedEntityInd', 'RelatedEntity'],
#  ['TrnsfrExmptNonChrtblRltdOrgInd', 'TransfersToExemptNonChrtblOrg'],
#  ['TransactionRelatedEntity', 'TransactionWithControlEntInd'],
#  ['InfoInScheduleOPartVInd', 'InfoInScheduleOPartV'],
#  ['EmployeeCnt', 'NumberOfEmployees'],
#  ['IRPDocumentCnt', 'NumberFormsTransmittedWith1096'],
#  ['UnrelatedBusIncmOverLimitInd', 'UnrelatedBusinessIncome'],
#  ['InfoInScheduleOPartVIInd', 'InfoInScheduleOPartVI'],
#  ['Form990ProvidedToGoverningBody', 'Form990ProvidedToGvrnBodyInd'],
#  ['AnnualDisclosureCoveredPrsnInd', 'AnnualDisclosureCoveredPersons'],
#  ['CompensationProcessCEOInd', 'CompensationProcessCEO'],
#  ['ChangeToOrgDocumentsInd', 'ChangesToOrganizingDocs'],
#  ['ConflictOfInterestPolicy', 'ConflictOfInterestPolicyInd'],
#  ['DecisionsSubjectToApproval', 'DecisionsSubjectToApprovaInd'],
#  ['DelegationOfManagementDuties', 'DelegationOfMgmtDutiesInd'],
#  ['DelegationOfManagementDuties', 'DelegationOfMgmtDutiesInd'],
#  ['DocumentRetentionPolicy', 'DocumentRetentionPolicyInd'],
#  ['ElectionOfBoardMembersInd', 'ElectionOfBoardMembers'],
#  ['FamilyOrBusinessRelationship', 'FamilyOrBusinessRlnInd'],
#  ['OwnWebsite', 'OwnWebsiteInd'],
#  ['UponRequestInd', 'UponRequest'],
#  ['InvestmentInJointVenture', 'InvestmentInJointVentureInd'],
#  ['WrittenPolicyOrProcedure', 'WrittenPolicyOrProcedureInd'],
#  ['LocalChapters', 'LocalChaptersInd'],
#  ['MaterialDiversionOrMisuseInd', 'MaterialDiversionOrMisuse'],
#  ['MembersOrStockholders', 'MembersOrStockholdersInd'],
#  ['MinutesOfCommittees', 'MinutesOfCommitteesInd'],
#  ['MinutesOfGoverningBody', 'MinutesOfGoverningBodyInd'],
#  ['RegularMonitoringEnforcement', 'RegularMonitoringEnfrcInd'],
#  ['IndependentVotingMemberCnt', 'NumberIndependentVotingMembers'],
#  ['GoverningBodyVotingMembersCnt', 'NbrVotingGoverningBodyMembers'],
#  ['OfficerMailingAddress', 'OfficerMailingAddressInd'],
#  ['CompensationProcessOtherInd', 'CompensationProcessOther'],
#  ['OtherWebsite', 'OtherWebsiteInd'],
#  ['OwnWebsite', 'OwnWebsiteInd'],
#  ['PoliciesReferenceChapters', 'PoliciesReferenceChaptersInd'],
#  ['StatesWhereCopyOfReturnIsFiled', 'StatesWhereCopyOfReturnIsFldCd'],
#  ['WhistleblowerPolicyInd', 'WhistleblowerPolicy'],
#  ['InfoInScheduleOPartVIIInd', 'InfoInScheduleOPartVII'],
#  ['CompensationFromOtherSrcsInd', 'CompensationFromOtherSources'],
#  ['FormerOfcrEmployeesListedInd', 'FormersListed'],
#  ['NoListedPersonsCompensated', 'NoListedPersonsCompensatedInd'],
#  ['CntrctRcvdGreaterThan100KCnt', 'NumberOfContractorsGT100K'],
#  ['NumberIndividualsGT100K', 'IndivRcvdGreaterThan100KCnt'],
#  ['TotalCompGreaterThan150KInd', 'TotalCompGT150K'],
#  ['TotalOtherCompensationAmt', 'TotalOtherCompensation'],
#  ['TotalReportableCompFromOrgAmt', 'TotalReportableCompFromOrg'],
#  ['TotReportableCompRltdOrgAmt', 'TotalReportableCompFrmRltdOrgs'],
#  ['InfoInScheduleOPartVIIIInd', 'InfoInScheduleOPartVIII'],
#  ['AllOtherContributionsAmt', 'AllOtherContributions'],
#  ['CntrbtnsRprtdFundraisingEvents', 'ContriRptFundraisingEventAmt'],
#  ['CostOfGoodsSold', 'CostOfGoodsSoldAmt'],
#  ['FederatedCampaignsAmt', 'FederatedCampaigns'],
#  ['FundraisingDirectExpenses', 'FundraisingDirectExpensesAmt'],
#  ['FundraisingEvents', 'FundraisingAmt'],
#  ['FundraisingGrossIncomeAmt', 'GrossIncomeFundraisingEvents'],
#  ['GamingDirectExpenses', 'GamingDirectExpensesAmt'],
#  ['GamingGrossIncomeAmt', 'GrossIncomeGaming'],
#  ['GovernmentGrants', 'GovernmentGrantsAmt'],
#  ['GrossSalesOfInventory', 'GrossSalesOfInventoryAmt'],
#  ['MembershipDuesAmt', 'MembershipDues'],
#  ['NoncashContributionsAmt', 'NoncashContributions'],
#  ['TotalProgramServiceRevenue', 'TotalProgramServiceRevenueAmt'],
#  ['RelatedOrganizations', 'RelatedOrganizationsAmt'],
#  ['TotalContributionsAmt', 'TotalContributions'],
#  ['TotalOtherRevenue', 'OtherRevenueTotalAmt'],
#  ['TotalProgramServiceRevenue', 'TotalProgramServiceRevenueAmt'],
#  ['TotalRevenueGrp', 'TotalRevenue'],
#  ['AdvertisingGrp', 'Advertising'],
#  ['BenefitsToMembers', 'BenefitsToMembersGrp'],
#  ['ConferencesMeetings', 'ConferencesMeetingsGrp'],
#  ['DepreciationDepletion', 'DepreciationDepletionGrp'],
#  ['DepreciationDepletion', 'DepreciationDepletionGrp'],
#  ['DepreciationDepletion', 'DepreciationDepletionGrp'],
#  ['DepreciationDepletion', 'DepreciationDepletionGrp'],
#  ['ForeignGrants', 'ForeignGrantsGrp'],
#  ['GrantsToDomesticIndividualsGrp', 'GrantsToDomesticIndividuals'],
#  ['GrantsToDomesticOrgs', 'GrantsToDomesticOrgsGrp'],
#  ['InformationTechnology', 'InformationTechnologyGrp'],
#  ['InsuranceGrp', 'Insurance'],
#  ['Interest', 'InterestGrp'],
#  ['TotalJointCosts', 'TotalJointCostsGrp'],
#  ['OccupancyGrp', 'Occupancy'],
#  ['OfficeExpensesGrp', 'OfficeExpenses'],
#  ['AllOtherExpensesGrp', 'AllOtherExpenses'],
#  ['OtherExpenses', 'OtherExpensesGrp'],
#  ['RoyaltiesGrp', 'Royalties'],
#  ['InfoInScheduleOPartIX', 'InfoInScheduleOPartIXInd'],
#  ['PymtTravelEntrtnmntPubOfclGrp', 'TravelEntrtnmntPublicOfficials'],
#  ['TravelGrp', 'Travel'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompCurrentOfcrDirectorsGrp', 'CompCurrentOfficersDirectors'],
#  ['CompCurrentOfcrDirectorsGrp', 'CompCurrentOfficersDirectors'],
#  ['CompCurrentOfcrDirectorsGrp', 'CompCurrentOfficersDirectors'],
#  ['CompCurrentOfcrDirectorsGrp', 'CompCurrentOfficersDirectors'],
#  ['FeesForServicesAccounting', 'FeesForServicesAccountingGrp'],
#  ['FeesForServicesProfFundraising'],
#  ['FeesForSrvcInvstMgmntFeesGrp', 'FeesForServicesInvstMgmntFees'],
#  ['FeesForServicesLegal', 'FeesForServicesLegalGrp'],
#  ['FeesForServicesLobbyingGrp', 'FeesForServicesLobbying'],
#  ['FeesForServicesManagement', 'FeesForServicesManagementGrp'],
#  ['FeesForServicesOther', 'FeesForServicesOtherGrp'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherSalariesAndWages', 'OtherSalariesAndWagesGrp'],
#  ['OtherSalariesAndWages', 'OtherSalariesAndWagesGrp'],
#  ['OtherSalariesAndWages', 'OtherSalariesAndWagesGrp'],
#  ['OtherSalariesAndWages', 'OtherSalariesAndWagesGrp'],
#  ['PaymentsToAffiliates', 'PaymentsToAffiliatesGrp'],
#  ['PayrollTaxesGrp', 'PayrollTaxes'],
#  ['PayrollTaxesGrp', 'PayrollTaxes'],
#  ['PayrollTaxesGrp', 'PayrollTaxes'],
#  ['PayrollTaxesGrp', 'PayrollTaxes'],
#  ['PensionPlanContributions', 'PensionPlanContributionsGrp'],
#  ['PensionPlanContributions', 'PensionPlanContributionsGrp'],
#  ['PensionPlanContributions', 'PensionPlanContributionsGrp'],
#  ['PensionPlanContributions', 'PensionPlanContributionsGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['AccountsReceivable', 'AccountsReceivableGrp'],
#  ['PrepaidExpensesDefrdChargesGrp', 'PrepaidExpensesDeferredCharges'],
#  ['IntangibleAssets', 'IntangibleAssetsGrp'],
#  ['InventoriesForSaleOrUseGrp', 'InventoriesForSaleOrUse'],
#  ['LandBldgEquipBasisNetGrp', 'LandBuildingsEquipmentBasisNet'],
#  ['RcvblFromDisqualifiedPrsnGrp', 'ReceivablesFromDisqualPersons'],
#  ['OthNotesLoansReceivableNetGrp', 'OtherNotesLoansReceivableNet'],
#  ['OtherAssetsTotal', 'OtherAssetsTotalGrp'],
#  ['PledgesAndGrantsReceivable', 'PledgesAndGrantsReceivableGrp'],
#  ['AccountsPayableAccrExpnssGrp', 'AccountsPayableAccruedExpenses'],
#  ['GrantsPayable', 'GrantsPayableGrp'],
#  ['LoansFromOfficersDirectorsGrp', 'LoansFromOfficersDirectors'],
#  ['DeferredRevenueGrp', 'DeferredRevenue'],
#  ['PermanentlyRstrNetAssetsGrp', 'PermanentlyRestrictedNetAssets'],
#  ['TemporarilyRestrictedNetAssets', 'TemporarilyRstrNetAssetsGrp'],
#  ['UnrestrictedNetAssets', 'UnrestrictedNetAssetsGrp'],
#  ['TaxExemptBondLiabilitiesGrp', 'TaxExemptBondLiabilities'],
#  ['CashNonInterestBearing', 'CashNonInterestBearingGrp'],
#  ['CashNonInterestBearing', 'CashNonInterestBearingGrp'],
#  ['EscrowAccountLiability', 'EscrowAccountLiabilityGrp'],
#  ['InvestmentsOtherSecuritiesGrp', 'InvestmentsOtherSecurities'],
#  ['InvestmentsProgramRelated', 'InvestmentsProgramRelatedGrp'],
#  ['InvestmentsPubTradedSecurities', 'InvestmentsPubTradedSecGrp'],
#  ['LandBldgEquipCostOrOtherBssAmt', 'LandBuildingsEquipmentBasis'],
#  ['LandBldgEquipAccumDeprecAmt', 'LandBldgEquipmentAccumDeprec'],
#  ['LoansFromOfficersDirectorsGrp', 'LoansFromOfficersDirectors'],
#  ['OrganizationFollowsSFAS117Ind', 'FollowSFAS117'],
#  ['OrgDoesNotFollowSFAS117Ind', 'DoNotFollowSFAS117'],
#  ['OtherLiabilities', 'OtherLiabilitiesGrp'],
#  ['RetainedEarningsEndowmentEtc', 'RtnEarnEndowmentIncmOthFndsGrp'],
#  ['SavingsAndTempCashInvestments', 'SavingsAndTempCashInvstGrp'],
#  ['SavingsAndTempCashInvestments', 'SavingsAndTempCashInvstGrp'],
#  ['MortgNotesPyblScrdInvstPropGrp', 'MortNotesPyblSecuredInvestProp'],
#  ['MortgNotesPyblScrdInvstPropGrp', 'MortNotesPyblSecuredInvestProp'],
#  ['UnsecuredNotesLoansPayableGrp', 'UnsecuredNotesLoansPayable'],
#  ['UnsecuredNotesLoansPayableGrp', 'UnsecuredNotesLoansPayable'],
#  ['UnsecuredNotesLoansPayableGrp', 'UnsecuredNotesLoansPayable'],
#  ['TotalAssets', 'TotalAssetsGrp'],
#  ['InfoInScheduleOPartXInd', 'InfoInScheduleOPartX'],
#  ['DonatedServicesAndUseFcltsAmt', 'ReconcilationDonatedServices'],
#  ['ReconcilationInvestExpenses', 'InvestmentExpenseAmt'],
#  ['PriorPeriodAdjustmentsAmt', 'ReconcilationPriorAdjustment'],
#  ['ReconcilationRevenueExpenses', 'ReconcilationRevenueExpnssAmt'],
#  ['ReconciliationUnrealizedInvest', 'NetUnrlzdGainsLossesInvstAmt'],
#  ['InfoInScheduleOPartXIInd', 'InfoInScheduleOPartXI'],
#  ['AccountantCompileOrReviewInd', 'AccountantCompileOrReview'],
#  ['MethodOfAccountingAccrualInd', 'MethodOfAccountingAccrual'],
#  ['MethodOfAccountingCashInd', 'MethodOfAccountingCash'],
#  ['MethodOfAccountingOtherInd', 'MethodOfAccountingOther'],
#  ['AuditCommittee', 'AuditCommitteeInd'],
#  ['FederalGrantAuditPerformedInd', 'FederalGrantAuditPerformed'],
#  ['FederalGrantAuditRequiredInd', 'FederalGrantAuditRequired'],
#  ['FSAudited', 'FSAuditedInd'],
#  ['InfoInScheduleOPartXII', 'InfoInScheduleOPartXIIInd'],
#  ['TaxPeriod'],
#  ['ProgSrvcAccomActyOtherGrp', 'ActivityOther']]

# %%
new_variables_df[new_variables_df['len']!=2]['original_names'].tolist()
# Out:
# [['BuildTS'],
#  ['Filer'],
#  ['Filer'],
#  ['Filer'],
#  ['Filer'],
#  ['Filer'],
#  ['Filer'],
#  ['FeesForServicesProfFundraising'],
#  ['TaxPeriod']]

# %%
new_variables_df[new_variables_df['len']==2]['original_names'].tolist()
# Out:
# [['AddressChange', 'AddressChangeInd'],
#  ['AmendedReturnInd', 'AmendedReturn'],
#  ['CountryLegalDomicile', 'LegalDomicileCountryCd'],
#  ['Organization4947a1NotPFInd', 'Organization4947a1'],
#  ['Organization501c', 'Organization501cInd'],
#  ['Organization501c3', 'Organization501c3Ind'],
#  ['FinalReturnInd', 'TerminatedReturn'],
#  ['GroupExemptionNumber', 'GroupExemptionNum'],
#  ['GrossReceipts', 'GrossReceiptsAmt'],
#  ['GroupReturnForAffiliates', 'GroupReturnForAffiliatesInd'],
#  ['AllAffiliatesIncluded', 'AllAffiliatesIncludedInd'],
#  ['InitialReturnInd', 'InitialReturn'],
#  ['NameOfPrincipalOfficerPerson', 'PrincipalOfficerNm'],
#  ['Officer', 'BusinessOfficerGrp'],
#  ['SpecialConditionDesc', 'SpecialConditionDescription'],
#  ['StateLegalDomicile', 'LegalDomicileStateCd'],
#  ['TaxPeriodBeginDate', 'TaxPeriodBeginDt'],
#  ['TaxPeriodEndDt', 'TaxPeriodEndDate'],
#  ['TaxYr', 'TaxYear'],
#  ['ReturnTs', 'Timestamp'],
#  ['TypeOfOrganizationAssocInd', 'TypeOfOrganizationAssociation'],
#  ['TypeOfOrganizationCorpInd', 'TypeOfOrganizationCorporation'],
#  ['TypeOfOrganizationOtherInd', 'TypeOfOrganizationOther'],
#  ['TypeOfOrgOtherDescription', 'OtherOrganizationDsc'],
#  ['TypeOfOrganizationTrust', 'TypeOfOrganizationTrustInd'],
#  ['WebSite', 'WebsiteAddressTxt'],
#  ['FormationYr', 'YearFormation'],
#  ['BenefitsPaidToMembersPriorYear', 'PYBenefitsPaidToMembersAmt'],
#  ['ContributionsGrantsCurrentYear', 'CYContributionsGrantsAmt'],
#  ['PYContributionsGrantsAmt', 'ContributionsGrantsPriorYear'],
#  ['GrantsAndSimilarAmntsPriorYear', 'PYGrantsAndSimilarPaidAmt'],
#  ['VotingMembersIndependentCnt', 'NbrIndependentVotingMembers'],
#  ['PYInvestmentIncomeAmt', 'InvestmentIncomePriorYear'],
#  ['NetAssetsOrFundBalancesBOYAmt', 'NetAssetsOrFundBalancesBOY'],
#  ['PYOtherExpensesAmt', 'OtherExpensePriorYear'],
#  ['PYOtherRevenueAmt', 'OtherRevenuePriorYear'],
#  ['CYTotalProfFndrsngExpnsAmt', 'TotalProfFundrsngExpCY'],
#  ['TotalProfFundrsngExpPriorYear', 'PYTotalProfFndrsngExpnsAmt'],
#  ['PYProgramServiceRevenueAmt', 'ProgramServiceRevenuePriorYear'],
#  ['CYRevenuesLessExpensesAmt', 'RevenuesLessExpensesCY'],
#  ['PYRevenuesLessExpensesAmt', 'RevenuesLessExpensesPriorYear'],
#  ['ContractTerminationInd', 'TerminationOrContraction'],
#  ['TotalAssetsEOY', 'TotalAssetsEOYAmt'],
#  ['TotalExpensesPriorYear', 'PYTotalExpensesAmt'],
#  ['TotalFundrsngExpCurrentYear', 'CYTotalFundraisingExpenseAmt'],
#  ['TotalNbrEmployees', 'TotalEmployeeCnt'],
#  ['TotalVolunteersCnt', 'TotalNbrVolunteers'],
#  ['TotalLiabilitiesEOYAmt', 'TotalLiabilitiesEOY'],
#  ['PYTotalRevenueAmt', 'TotalRevenuePriorYear'],
#  ['TotalGrossUBI', 'TotalGrossUBIAmt'],
#  ['NetUnrelatedBusinessTxblIncome', 'NetUnrelatedBusTxblIncmAmt'],
#  ['VotingMembersGoverningBodyCnt', 'NbrVotingMembersGoverningBody'],
#  ['BenefitsPaidToMembersCY', 'CYBenefitsPaidToMembersAmt'],
#  ['CYGrantsAndSimilarPaidAmt', 'GrantsAndSimilarAmntsCY'],
#  ['CYInvestmentIncomeAmt', 'InvestmentIncomeCurrentYear'],
#  ['NetAssetsOrFundBalancesEOYAmt', 'NetAssetsOrFundBalancesEOY'],
#  ['ActivityOrMissionDescription', 'ActivityOrMissionDesc'],
#  ['CYOtherExpensesAmt', 'OtherExpensesCurrentYear'],
#  ['OtherRevenueCurrentYear', 'CYOtherRevenueAmt'],
#  ['CYProgramServiceRevenueAmt', 'ProgramServiceRevenueCY'],
#  ['CYSalariesCompEmpBnftPaidAmt', 'SalariesEtcCurrentYear'],
#  ['PYSalariesCompEmpBnftPaidAmt', 'SalariesEtcPriorYear'],
#  ['TotalAssetsBOYAmt', 'TotalAssetsBOY'],
#  ['TotalExpensesCurrentYear', 'CYTotalExpensesAmt'],
#  ['TotalLiabilitiesBOY', 'TotalLiabilitiesBOYAmt'],
#  ['TotalRevenueCurrentYear', 'CYTotalRevenueAmt'],
#  ['SignificantChangeInd', 'SignificantChange'],
#  ['SignificantNewProgramSrvcInd', 'SignificantNewProgramServices'],
#  ['ActivityCd', 'ActivityCode'],
#  ['Desc', 'Description'],
#  ['ExpenseAmt', 'Expense'],
#  ['Grants', 'GrantAmt'],
#  ['Revenue', 'RevenueAmt'],
#  ['Activity2', 'ProgSrvcAccomActy2Grp'],
#  ['Activity2', 'ProgSrvcAccomActy2Grp'],
#  ['Activity2', 'ProgSrvcAccomActy2Grp'],
#  ['Activity2', 'ProgSrvcAccomActy2Grp'],
#  ['Activity2', 'ProgSrvcAccomActy2Grp'],
#  ['ProgSrvcAccomActy3Grp', 'Activity3'],
#  ['ProgSrvcAccomActy3Grp', 'Activity3'],
#  ['ProgSrvcAccomActy3Grp', 'Activity3'],
#  ['ProgSrvcAccomActy3Grp', 'Activity3'],
#  ['ProgSrvcAccomActy3Grp', 'Activity3'],
#  ['TotalOfOtherProgramServiceExp', 'TotalOtherProgSrvcExpenseAmt'],
#  ['TotalOfOtherProgramServiceGrnt', 'TotalOtherProgSrvcGrantAmt'],
#  ['TotalOtherProgSrvcRevenueAmt', 'TotalOfOtherProgramServiceRev'],
#  ['TotalProgramServiceExpensesAmt', 'TotalProgramServiceExpense'],
#  ['MissionDesc', 'MissionDescription'],
#  ['InfoInScheduleOPartIII', 'InfoInScheduleOPartIIIInd'],
#  ['ActivitiesConductedPartnership', 'ActivitiesConductedPrtshpInd'],
#  ['RelatedOrganizationCtrlEntInd', 'RelatedOrgControlledEntity'],
#  ['DisregardedEntityInd', 'DisregardedEntity'],
#  ['EngagedInExcessBenefitTransInd', 'ExcessBenefitTransaction'],
#  ['FundraisingActivities', 'FundraisingActivitiesInd'],
#  ['GamingActivitiesInd', 'Gaming'],
#  ['LobbyingActivities', 'LobbyingActivitiesInd'],
#  ['PoliticalActivities', 'PoliticalCampaignActyInd'],
#  ['PYExcessBenefitTransInd', 'PriorExcessBenefitTransaction'],
#  ['ProfessionalFundraisingInd', 'ProfessionalFundraising'],
#  ['RelatedEntityInd', 'RelatedEntity'],
#  ['TrnsfrExmptNonChrtblRltdOrgInd', 'TransfersToExemptNonChrtblOrg'],
#  ['TransactionRelatedEntity', 'TransactionWithControlEntInd'],
#  ['InfoInScheduleOPartVInd', 'InfoInScheduleOPartV'],
#  ['EmployeeCnt', 'NumberOfEmployees'],
#  ['IRPDocumentCnt', 'NumberFormsTransmittedWith1096'],
#  ['UnrelatedBusIncmOverLimitInd', 'UnrelatedBusinessIncome'],
#  ['InfoInScheduleOPartVIInd', 'InfoInScheduleOPartVI'],
#  ['Form990ProvidedToGoverningBody', 'Form990ProvidedToGvrnBodyInd'],
#  ['AnnualDisclosureCoveredPrsnInd', 'AnnualDisclosureCoveredPersons'],
#  ['CompensationProcessCEOInd', 'CompensationProcessCEO'],
#  ['ChangeToOrgDocumentsInd', 'ChangesToOrganizingDocs'],
#  ['ConflictOfInterestPolicy', 'ConflictOfInterestPolicyInd'],
#  ['DecisionsSubjectToApproval', 'DecisionsSubjectToApprovaInd'],
#  ['DelegationOfManagementDuties', 'DelegationOfMgmtDutiesInd'],
#  ['DelegationOfManagementDuties', 'DelegationOfMgmtDutiesInd'],
#  ['DocumentRetentionPolicy', 'DocumentRetentionPolicyInd'],
#  ['ElectionOfBoardMembersInd', 'ElectionOfBoardMembers'],
#  ['FamilyOrBusinessRelationship', 'FamilyOrBusinessRlnInd'],
#  ['OwnWebsite', 'OwnWebsiteInd'],
#  ['UponRequestInd', 'UponRequest'],
#  ['InvestmentInJointVenture', 'InvestmentInJointVentureInd'],
#  ['WrittenPolicyOrProcedure', 'WrittenPolicyOrProcedureInd'],
#  ['LocalChapters', 'LocalChaptersInd'],
#  ['MaterialDiversionOrMisuseInd', 'MaterialDiversionOrMisuse'],
#  ['MembersOrStockholders', 'MembersOrStockholdersInd'],
#  ['MinutesOfCommittees', 'MinutesOfCommitteesInd'],
#  ['MinutesOfGoverningBody', 'MinutesOfGoverningBodyInd'],
#  ['RegularMonitoringEnforcement', 'RegularMonitoringEnfrcInd'],
#  ['IndependentVotingMemberCnt', 'NumberIndependentVotingMembers'],
#  ['GoverningBodyVotingMembersCnt', 'NbrVotingGoverningBodyMembers'],
#  ['OfficerMailingAddress', 'OfficerMailingAddressInd'],
#  ['CompensationProcessOtherInd', 'CompensationProcessOther'],
#  ['OtherWebsite', 'OtherWebsiteInd'],
#  ['OwnWebsite', 'OwnWebsiteInd'],
#  ['PoliciesReferenceChapters', 'PoliciesReferenceChaptersInd'],
#  ['StatesWhereCopyOfReturnIsFiled', 'StatesWhereCopyOfReturnIsFldCd'],
#  ['WhistleblowerPolicyInd', 'WhistleblowerPolicy'],
#  ['InfoInScheduleOPartVIIInd', 'InfoInScheduleOPartVII'],
#  ['CompensationFromOtherSrcsInd', 'CompensationFromOtherSources'],
#  ['FormerOfcrEmployeesListedInd', 'FormersListed'],
#  ['NoListedPersonsCompensated', 'NoListedPersonsCompensatedInd'],
#  ['CntrctRcvdGreaterThan100KCnt', 'NumberOfContractorsGT100K'],
#  ['NumberIndividualsGT100K', 'IndivRcvdGreaterThan100KCnt'],
#  ['TotalCompGreaterThan150KInd', 'TotalCompGT150K'],
#  ['TotalOtherCompensationAmt', 'TotalOtherCompensation'],
#  ['TotalReportableCompFromOrgAmt', 'TotalReportableCompFromOrg'],
#  ['TotReportableCompRltdOrgAmt', 'TotalReportableCompFrmRltdOrgs'],
#  ['InfoInScheduleOPartVIIIInd', 'InfoInScheduleOPartVIII'],
#  ['AllOtherContributionsAmt', 'AllOtherContributions'],
#  ['CntrbtnsRprtdFundraisingEvents', 'ContriRptFundraisingEventAmt'],
#  ['CostOfGoodsSold', 'CostOfGoodsSoldAmt'],
#  ['FederatedCampaignsAmt', 'FederatedCampaigns'],
#  ['FundraisingDirectExpenses', 'FundraisingDirectExpensesAmt'],
#  ['FundraisingEvents', 'FundraisingAmt'],
#  ['FundraisingGrossIncomeAmt', 'GrossIncomeFundraisingEvents'],
#  ['GamingDirectExpenses', 'GamingDirectExpensesAmt'],
#  ['GamingGrossIncomeAmt', 'GrossIncomeGaming'],
#  ['GovernmentGrants', 'GovernmentGrantsAmt'],
#  ['GrossSalesOfInventory', 'GrossSalesOfInventoryAmt'],
#  ['MembershipDuesAmt', 'MembershipDues'],
#  ['NoncashContributionsAmt', 'NoncashContributions'],
#  ['TotalProgramServiceRevenue', 'TotalProgramServiceRevenueAmt'],
#  ['RelatedOrganizations', 'RelatedOrganizationsAmt'],
#  ['TotalContributionsAmt', 'TotalContributions'],
#  ['TotalOtherRevenue', 'OtherRevenueTotalAmt'],
#  ['TotalProgramServiceRevenue', 'TotalProgramServiceRevenueAmt'],
#  ['TotalRevenueGrp', 'TotalRevenue'],
#  ['AdvertisingGrp', 'Advertising'],
#  ['BenefitsToMembers', 'BenefitsToMembersGrp'],
#  ['ConferencesMeetings', 'ConferencesMeetingsGrp'],
#  ['DepreciationDepletion', 'DepreciationDepletionGrp'],
#  ['DepreciationDepletion', 'DepreciationDepletionGrp'],
#  ['DepreciationDepletion', 'DepreciationDepletionGrp'],
#  ['DepreciationDepletion', 'DepreciationDepletionGrp'],
#  ['ForeignGrants', 'ForeignGrantsGrp'],
#  ['GrantsToDomesticIndividualsGrp', 'GrantsToDomesticIndividuals'],
#  ['GrantsToDomesticOrgs', 'GrantsToDomesticOrgsGrp'],
#  ['InformationTechnology', 'InformationTechnologyGrp'],
#  ['InsuranceGrp', 'Insurance'],
#  ['Interest', 'InterestGrp'],
#  ['TotalJointCosts', 'TotalJointCostsGrp'],
#  ['OccupancyGrp', 'Occupancy'],
#  ['OfficeExpensesGrp', 'OfficeExpenses'],
#  ['AllOtherExpensesGrp', 'AllOtherExpenses'],
#  ['OtherExpenses', 'OtherExpensesGrp'],
#  ['RoyaltiesGrp', 'Royalties'],
#  ['InfoInScheduleOPartIX', 'InfoInScheduleOPartIXInd'],
#  ['PymtTravelEntrtnmntPubOfclGrp', 'TravelEntrtnmntPublicOfficials'],
#  ['TravelGrp', 'Travel'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompCurrentOfcrDirectorsGrp', 'CompCurrentOfficersDirectors'],
#  ['CompCurrentOfcrDirectorsGrp', 'CompCurrentOfficersDirectors'],
#  ['CompCurrentOfcrDirectorsGrp', 'CompCurrentOfficersDirectors'],
#  ['CompCurrentOfcrDirectorsGrp', 'CompCurrentOfficersDirectors'],
#  ['FeesForServicesAccounting', 'FeesForServicesAccountingGrp'],
#  ['FeesForSrvcInvstMgmntFeesGrp', 'FeesForServicesInvstMgmntFees'],
#  ['FeesForServicesLegal', 'FeesForServicesLegalGrp'],
#  ['FeesForServicesLobbyingGrp', 'FeesForServicesLobbying'],
#  ['FeesForServicesManagement', 'FeesForServicesManagementGrp'],
#  ['FeesForServicesOther', 'FeesForServicesOtherGrp'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherSalariesAndWages', 'OtherSalariesAndWagesGrp'],
#  ['OtherSalariesAndWages', 'OtherSalariesAndWagesGrp'],
#  ['OtherSalariesAndWages', 'OtherSalariesAndWagesGrp'],
#  ['OtherSalariesAndWages', 'OtherSalariesAndWagesGrp'],
#  ['PaymentsToAffiliates', 'PaymentsToAffiliatesGrp'],
#  ['PayrollTaxesGrp', 'PayrollTaxes'],
#  ['PayrollTaxesGrp', 'PayrollTaxes'],
#  ['PayrollTaxesGrp', 'PayrollTaxes'],
#  ['PayrollTaxesGrp', 'PayrollTaxes'],
#  ['PensionPlanContributions', 'PensionPlanContributionsGrp'],
#  ['PensionPlanContributions', 'PensionPlanContributionsGrp'],
#  ['PensionPlanContributions', 'PensionPlanContributionsGrp'],
#  ['PensionPlanContributions', 'PensionPlanContributionsGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['AccountsReceivable', 'AccountsReceivableGrp'],
#  ['PrepaidExpensesDefrdChargesGrp', 'PrepaidExpensesDeferredCharges'],
#  ['IntangibleAssets', 'IntangibleAssetsGrp'],
#  ['InventoriesForSaleOrUseGrp', 'InventoriesForSaleOrUse'],
#  ['LandBldgEquipBasisNetGrp', 'LandBuildingsEquipmentBasisNet'],
#  ['RcvblFromDisqualifiedPrsnGrp', 'ReceivablesFromDisqualPersons'],
#  ['OthNotesLoansReceivableNetGrp', 'OtherNotesLoansReceivableNet'],
#  ['OtherAssetsTotal', 'OtherAssetsTotalGrp'],
#  ['PledgesAndGrantsReceivable', 'PledgesAndGrantsReceivableGrp'],
#  ['AccountsPayableAccrExpnssGrp', 'AccountsPayableAccruedExpenses'],
#  ['GrantsPayable', 'GrantsPayableGrp'],
#  ['LoansFromOfficersDirectorsGrp', 'LoansFromOfficersDirectors'],
#  ['DeferredRevenueGrp', 'DeferredRevenue'],
#  ['PermanentlyRstrNetAssetsGrp', 'PermanentlyRestrictedNetAssets'],
#  ['TemporarilyRestrictedNetAssets', 'TemporarilyRstrNetAssetsGrp'],
#  ['UnrestrictedNetAssets', 'UnrestrictedNetAssetsGrp'],
#  ['TaxExemptBondLiabilitiesGrp', 'TaxExemptBondLiabilities'],
#  ['CashNonInterestBearing', 'CashNonInterestBearingGrp'],
#  ['CashNonInterestBearing', 'CashNonInterestBearingGrp'],
#  ['EscrowAccountLiability', 'EscrowAccountLiabilityGrp'],
#  ['InvestmentsOtherSecuritiesGrp', 'InvestmentsOtherSecurities'],
#  ['InvestmentsProgramRelated', 'InvestmentsProgramRelatedGrp'],
#  ['InvestmentsPubTradedSecurities', 'InvestmentsPubTradedSecGrp'],
#  ['LandBldgEquipCostOrOtherBssAmt', 'LandBuildingsEquipmentBasis'],
#  ['LandBldgEquipAccumDeprecAmt', 'LandBldgEquipmentAccumDeprec'],
#  ['LoansFromOfficersDirectorsGrp', 'LoansFromOfficersDirectors'],
#  ['OrganizationFollowsSFAS117Ind', 'FollowSFAS117'],
#  ['OrgDoesNotFollowSFAS117Ind', 'DoNotFollowSFAS117'],
#  ['OtherLiabilities', 'OtherLiabilitiesGrp'],
#  ['RetainedEarningsEndowmentEtc', 'RtnEarnEndowmentIncmOthFndsGrp'],
#  ['SavingsAndTempCashInvestments', 'SavingsAndTempCashInvstGrp'],
#  ['SavingsAndTempCashInvestments', 'SavingsAndTempCashInvstGrp'],
#  ['MortgNotesPyblScrdInvstPropGrp', 'MortNotesPyblSecuredInvestProp'],
#  ['MortgNotesPyblScrdInvstPropGrp', 'MortNotesPyblSecuredInvestProp'],
#  ['UnsecuredNotesLoansPayableGrp', 'UnsecuredNotesLoansPayable'],
#  ['UnsecuredNotesLoansPayableGrp', 'UnsecuredNotesLoansPayable'],
#  ['UnsecuredNotesLoansPayableGrp', 'UnsecuredNotesLoansPayable'],
#  ['TotalAssets', 'TotalAssetsGrp'],
#  ['InfoInScheduleOPartXInd', 'InfoInScheduleOPartX'],
#  ['DonatedServicesAndUseFcltsAmt', 'ReconcilationDonatedServices'],
#  ['ReconcilationInvestExpenses', 'InvestmentExpenseAmt'],
#  ['PriorPeriodAdjustmentsAmt', 'ReconcilationPriorAdjustment'],
#  ['ReconcilationRevenueExpenses', 'ReconcilationRevenueExpnssAmt'],
#  ['ReconciliationUnrealizedInvest', 'NetUnrlzdGainsLossesInvstAmt'],
#  ['InfoInScheduleOPartXIInd', 'InfoInScheduleOPartXI'],
#  ['AccountantCompileOrReviewInd', 'AccountantCompileOrReview'],
#  ['MethodOfAccountingAccrualInd', 'MethodOfAccountingAccrual'],
#  ['MethodOfAccountingCashInd', 'MethodOfAccountingCash'],
#  ['MethodOfAccountingOtherInd', 'MethodOfAccountingOther'],
#  ['AuditCommittee', 'AuditCommitteeInd'],
#  ['FederalGrantAuditPerformedInd', 'FederalGrantAuditPerformed'],
#  ['FederalGrantAuditRequiredInd', 'FederalGrantAuditRequired'],
#  ['FSAudited', 'FSAuditedInd'],
#  ['InfoInScheduleOPartXII', 'InfoInScheduleOPartXIIInd'],
#  ['ProgSrvcAccomActyOtherGrp', 'ActivityOther']]

# %%
flat_list = [item for sublist in new_variables_df[new_variables_df['len']==2]['original_names'].tolist() for item in sublist]
print(len(flat_list))
print(flat_list[:])
# Out:
# 558
# ['AddressChange', 'AddressChangeInd', 'AmendedReturnInd', 'AmendedReturn', 'CountryLegalDomicile', 'LegalDomicileCountryCd', 'Organization4947a1NotPFInd', 'Organization4947a1', 'Organization501c', 'Organization501cInd', 'Organization501c3', 'Organization501c3Ind', 'FinalReturnInd', 'TerminatedReturn', 'GroupExemptionNumber', 'GroupExemptionNum', 'GrossReceipts', 'GrossReceiptsAmt', 'GroupReturnForAffiliates', 'GroupReturnForAffiliatesInd', 'AllAffiliatesIncluded', 'AllAffiliatesIncludedInd', 'InitialReturnInd', 'InitialReturn', 'NameOfPrincipalOfficerPerson', 'PrincipalOfficerNm', 'Officer', 'BusinessOfficerGrp', 'SpecialConditionDesc', 'SpecialConditionDescription', 'StateLegalDomicile', 'LegalDomicileStateCd', 'TaxPeriodBeginDate', 'TaxPeriodBeginDt', 'TaxPeriodEndDt', 'TaxPeriodEndDate', 'TaxYr', 'TaxYear', 'ReturnTs', 'Timestamp', 'TypeOfOrganizationAssocInd', 'TypeOfOrganizationAssociation', 'TypeOfOrganizationCorpInd', 'TypeOfOrganizationCorporation', 'TypeOfOrganizationOtherInd', 'TypeOfOrganizationOther', 'TypeOfOrgOtherDescription', 'OtherOrganizationDsc', 'TypeOfOrganizationTrust', 'TypeOfOrganizationTrustInd', 'WebSite', 'WebsiteAddressTxt', 'FormationYr', 'YearFormation', 'BenefitsPaidToMembersPriorYear', 'PYBenefitsPaidToMembersAmt', 'ContributionsGrantsCurrentYear', 'CYContributionsGrantsAmt', 'PYContributionsGrantsAmt', 'ContributionsGrantsPriorYear', 'GrantsAndSimilarAmntsPriorYear', 'PYGrantsAndSimilarPaidAmt', 'VotingMembersIndependentCnt', 'NbrIndependentVotingMembers', 'PYInvestmentIncomeAmt', 'InvestmentIncomePriorYear', 'NetAssetsOrFundBalancesBOYAmt', 'NetAssetsOrFundBalancesBOY', 'PYOtherExpensesAmt', 'OtherExpensePriorYear', 'PYOtherRevenueAmt', 'OtherRevenuePriorYear', 'CYTotalProfFndrsngExpnsAmt', 'TotalProfFundrsngExpCY', 'TotalProfFundrsngExpPriorYear', 'PYTotalProfFndrsngExpnsAmt', 'PYProgramServiceRevenueAmt', 'ProgramServiceRevenuePriorYear', 'CYRevenuesLessExpensesAmt', 'RevenuesLessExpensesCY', 'PYRevenuesLessExpensesAmt', 'RevenuesLessExpensesPriorYear', 'ContractTerminationInd', 'TerminationOrContraction', 'TotalAssetsEOY', 'TotalAssetsEOYAmt', 'TotalExpensesPriorYear', 'PYTotalExpensesAmt', 'TotalFundrsngExpCurrentYear', 'CYTotalFundraisingExpenseAmt', 'TotalNbrEmployees', 'TotalEmployeeCnt', 'TotalVolunteersCnt', 'TotalNbrVolunteers', 'TotalLiabilitiesEOYAmt', 'TotalLiabilitiesEOY', 'PYTotalRevenueAmt', 'TotalRevenuePriorYear', 'TotalGrossUBI', 'TotalGrossUBIAmt', 'NetUnrelatedBusinessTxblIncome', 'NetUnrelatedBusTxblIncmAmt', 'VotingMembersGoverningBodyCnt', 'NbrVotingMembersGoverningBody', 'BenefitsPaidToMembersCY', 'CYBenefitsPaidToMembersAmt', 'CYGrantsAndSimilarPaidAmt', 'GrantsAndSimilarAmntsCY', 'CYInvestmentIncomeAmt', 'InvestmentIncomeCurrentYear', 'NetAssetsOrFundBalancesEOYAmt', 'NetAssetsOrFundBalancesEOY', 'ActivityOrMissionDescription', 'ActivityOrMissionDesc', 'CYOtherExpensesAmt', 'OtherExpensesCurrentYear', 'OtherRevenueCurrentYear', 'CYOtherRevenueAmt', 'CYProgramServiceRevenueAmt', 'ProgramServiceRevenueCY', 'CYSalariesCompEmpBnftPaidAmt', 'SalariesEtcCurrentYear', 'PYSalariesCompEmpBnftPaidAmt', 'SalariesEtcPriorYear', 'TotalAssetsBOYAmt', 'TotalAssetsBOY', 'TotalExpensesCurrentYear', 'CYTotalExpensesAmt', 'TotalLiabilitiesBOY', 'TotalLiabilitiesBOYAmt', 'TotalRevenueCurrentYear', 'CYTotalRevenueAmt', 'SignificantChangeInd', 'SignificantChange', 'SignificantNewProgramSrvcInd', 'SignificantNewProgramServices', 'ActivityCd', 'ActivityCode', 'Desc', 'Description', 'ExpenseAmt', 'Expense', 'Grants', 'GrantAmt', 'Revenue', 'RevenueAmt', 'Activity2', 'ProgSrvcAccomActy2Grp', 'Activity2', 'ProgSrvcAccomActy2Grp', 'Activity2', 'ProgSrvcAccomActy2Grp', 'Activity2', 'ProgSrvcAccomActy2Grp', 'Activity2', 'ProgSrvcAccomActy2Grp', 'ProgSrvcAccomActy3Grp', 'Activity3', 'ProgSrvcAccomActy3Grp', 'Activity3', 'ProgSrvcAccomActy3Grp', 'Activity3', 'ProgSrvcAccomActy3Grp', 'Activity3', 'ProgSrvcAccomActy3Grp', 'Activity3', 'TotalOfOtherProgramServiceExp', 'TotalOtherProgSrvcExpenseAmt', ' ...

# %% [markdown]
# <br> Flatten a list of lists: https://stackoverflow.com/questions/952914/how-to-make-a-flat-list-out-of-list-of-lists

# %%
print(len([c for c in df.columns.tolist() if c not in flat_list]))
print([c for c in df.columns.tolist() if c not in flat_list])
# Out:
# 300
# ['_id', 'OrganizationName', 'URL', 'DLN', 'TaxPeriod', 'F9_09_PC_FEES_FOR_SVCE_FR_TOT', 'F9_00_HD_BUILD_TIME_STAMP', 'fiscal_year', 'EIN', 'Name', 'NameControl', 'Phone', 'USAddress', 'ForeignAddress', 'InCareOfName', 'BusinessName', 'BusinessNameControlTxt', 'PhoneNum', 'InCareOfNm', 'ForeignPhoneNum', 'F9_00_HD_ADDR_CHANGE', 'F9_00_HD_AMENDED_RETURN', 'F9_00_HD_CTRY_OF_DOMICILE', 'F9_00_HD_EXEMPT_STATUS_4847A1', 'F9_00_HD_EXEMPT_STATUS_501C', 'F9_00_HD_EXEMPT_STATUS_501C3', 'F9_00_HD_FINAL_RETURN', 'F9_00_HD_GROSS_EXEMPT_NUM', 'F9_00_HD_GROSS_RCPT', 'F9_00_HD_GROUP_RETURN', 'F9_00_HD_INCLUDES_SUBORD_ORGS', 'F9_00_HD_INITIAL_RETURN', 'F9_00_HD_PRIN_OFF_NAME', 'F9_00_HD_SIGNING_OFFICER_SIGNTR', 'F9_00_HD_SPECIAL_CONDITION_DESC', 'F9_00_HD_STATE_OF_DOMICILE', 'F9_00_HD_TAX_PER_BEGIN', 'F9_00_HD_TAX_PER_END', 'F9_00_HD_TAX_YEAR', 'F9_00_HD_TIME_STAMP', 'F9_00_HD_TYPE_ORG_ASSOCIATION', 'F9_00_HD_TYPE_ORG_CORP', 'F9_00_HD_TYPE_ORG_OTHER', 'F9_00_HD_TYPE_ORG_OTHER_DESC', 'F9_00_HD_TYPE_ORG_TRUST', 'F9_00_HD_WEBSITE', 'F9_00_HD_YEAR_FORMED', 'F9_01_PC_BEN_PAID_MEMB_PRIOR', 'F9_01_PC_CONTR_GRANTS_CURR', 'F9_01_PC_CONTR_GRANTS_PRIOR', 'F9_01_PC_GRANTS_PRIOR', 'F9_01_PC_INDEP_VOTING_MEMB', 'F9_01_PC_INVEST_INCOME_PRIOR', 'F9_01_PC_NET_ASSETS_BOY', 'F9_01_PC_OTHER_EXPENSE_PRIOR', 'F9_01_PC_OTHER_REV_PRIOR', 'F9_01_PC_PROF_FUNDRISING_EXP_CURR', 'F9_01_PC_PROF_FUNDRISING_EXP_PRIOR', 'F9_01_PC_PROG_SERVICE_REV_PRIOR', 'F9_01_PC_REV_LESS_EXP_CURR', 'F9_01_PC_REV_LESS_EXP_PRIOR', 'F9_01_PC_TERMINATION_CONTRACTION', 'F9_01_PC_TOT_ASSETS_EOY', 'F9_01_PC_TOT_EXP_PRIOR', 'F9_01_PC_TOT_FNDR_EXP_CURR', 'F9_01_PC_TOT_INDIV_EMPLOYED', 'F9_01_PC_TOT_INDIV_VOLUNTEERS', 'F9_01_PC_TOT_LIABILITIES_EOY', 'F9_01_PC_TOT_REVENUE_PRIOR', 'F9_01_PC_TOT_UBI_GROSS', 'F9_01_PC_TOT_UBI_NET', 'F9_01_PC_VOTING_MEMB_GOV_BODY', 'F9_01_PZ_BEN_PAID_TO_MEMB_CURR', 'F9_01_PZ_GRANTS_PAID_CURR', 'F9_01_PZ_INVEST_INCOME_CURR', 'F9_01_PZ_NAFB_EOY', 'F9_01_PZ_ORGANIZATIONAL_MISSION', 'F9_01_PZ_OTHER_EXPENSE_CURR', 'F9_01_PZ_OTHER_REV_CURR', 'F9_01_PZ_PROG_SERVICE_REV_CURR', 'F9_01_PZ_SALARIES_CURR', 'F9_01_PZ_SALARIES_PRIOR', 'F9_01_PZ_TOT_ASSETS_BOY', 'F9_01_PZ_TOT_EXP_CURR', 'F9_01_PZ_TOT_LIAB_BOY', 'F9_01_PZ_TOT_REV_CURR', 'F9_03_PC_PGMSVC_SIGNIF_CHG', 'F9_03_PC_PGMSVC_SIGNIF_NEW', 'F9_03_PC_PROG_SVC_ACC_1_CODE', 'F9_03_PC_PROG_SVC_ACC_1_DESC', 'F9_03_PC_PROG_SVC_ACC_1_EXP', 'F9_03_PC_PROG_SVC_ACC_1_GRNT', 'F9_03_PC_PROG_SVC_ACC_1_REV', 'F9_03_PC_PROG_SVC_ACC_2_CODE', 'F9_03_PC_PROG_SVC_ACC_2_DESC', 'F9_03_PC_PROG_SVC_ACC_2_EXP', 'F9_03_PC_PROG_SVC_ACC_2_GRNT', 'F9_03_PC_PROG_SVC_ACC_2_REV', 'F9_03_PC_PROG_SVC_ACC_3_CODE', 'F9_03_PC_PROG_SVC_ACC_3_DESC', 'F9_03_PC_PROG_SVC_ACC_3_EXP', 'F9_03_PC_PROG_SVC_ACC_3_GRNT', 'F9_03_PC_PROG_SVC_ACC_3_REV', 'F9_03_PC_TOT_OTH_PROG_SVC_EXP', 'F9_03_PC_TOT_OTH_PROG_SVC_GRNT', 'F9_03_PC_TOT_OTH_PROG_SVC_REV', 'F9_03_PC_TOT_PROG_SVC_EXPENSE', 'F9_03_PZ_MISSION_DESCRIPTION', 'F9_03_PZ_SCHEDULE_O_PART3', 'F9_04_PC_ACTVITIES_VIA_PARTNER', 'F9_04_PC_CONTROLLED_ENTITY', 'F9_04_PC_DISREGARDED_ENTITY', 'F9_04_PC_EXCESS_BENEFIT_TRANS', 'F9_04_PC_FR_EVENT_INC_GT_15K', 'F9_04_PC_GAMING_INC_GT_15K', 'F9_04_PC_LOBBYING_ACTIVITIES', 'F9_04_PC_POLITICAL_ACTIVITIES', 'F9_04_PC_PRIOR_EXCESS_BEN_TRAN', 'F9_04_PC_PROF_FR_EXP_GT_15K', 'F9_04_PC_RELATED_ENTITY', 'F9_04_PC_TRANS_TO_CNTRLD_ENT', 'F9_04_PC_TRANS_WITH_CNTRLD_ENT', 'F9_05_EXP_SCHED_O_X', 'F9_05_PC_NUMBER_EMPLOYEES_W3', 'F9_05_PC_NUMBER_FORMS_1096', 'F9_05_PC_UNRELATED_BUS_INCOME', 'F9_06_EXP_SCHED_O_X', 'F9_06_PC_990_PROVIDED_GOV_BODY', 'F9_06_PC_ANNUAL_DISC_COVRD_PERS', 'F9_06_PC_CEO_COMPENSTN_PROCESS', 'F9_06_PC_CHANGES_ORGANIZING_DOCS', 'F9_06_PC_CONFLICT_OF_INTEREST', 'F9_06_PC_DECISIONS_SUBJ_APPROVAL', 'F9_06_PC_DELEGATION_MGT_DUTIES', 'F9_06_PC_DELEGATION_OF_MGT', 'F9_06_PC_DOCUMENT_RET_POLICY', 'F9_06_PC_ELECTION_BOARD_MEMBERS', 'F9_06_PC_FAMILY_OR_BUSINESS_REL', 'F9_06_PC_FORM_AVAIL_OWN_WEBSITE', 'F9_06_PC_FORM_UPON_REQUEST', 'F9_06_PC_JOINT_VENTURE_INVESTMNT', 'F9_06_PC_JOINT_VENTURE_POLI ...

# %%
print(len(new_variables_df['variable_name_new'].tolist()))
# Out:
# 288

# %%
set([c for c in df.columns.tolist() if c not in flat_list]) - set(new_variables_df['variable_name_new'].tolist())
# Out:
# {'501c3',
#  'BusinessName',
#  'BusinessNameControlTxt',
#  'DLN',
#  'EIN',
#  'ForeignAddress',
#  'ForeignPhoneNum',
#  'InCareOfName',
#  'InCareOfNm',
#  'Name',
#  'NameControl',
#  'OrganizationName',
#  'Phone',
#  'PhoneNum',
#  'URL',
#  'USAddress',
#  '_id',
#  'fiscal_year'}

# %% [markdown]
# <br>The following block drops a lot of columns. We are then left with the 292 combined, renamed, and (as appropriate) binarized columns.

# %%
gc.collect()
# Out:
# 18965

# %%
# %%time
print(len(df.columns))
df = df[[c for c in df.columns.tolist() if c not in flat_list]]
print(len(df.columns))
df[:2]
# Out:
# 776
# 300
# CPU times: total: 12.4 s
# Wall time: 13 s
#                         _id  \
# 0  5d019e6778ffca27b42818d7
# 1  5d019e6778ffca27b42818d8
#
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#               DLN TaxPeriod F9_09_PC_FEES_FOR_SVCE_FR_TOT  \
# 0  93493313013011    201012                          None
# 1  93493313013111    201106                {"Total": "0"}
#
#   F9_00_HD_BUILD_TIME_STAMP fiscal_year        EIN  \
# 0      2016-02-24 21:20:13Z        None  232705170
# 1      2016-02-24 21:20:13Z        None  581805618
#
#                                                                                                         Name  \
# 0  {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}
# 1        {'BusinessNameLine1': 'TORRINGTON VOA ELDERLY HOUSING INC', 'BusinessNameLine2': 'BELL PARK TOWER'}
#
#   NameControl       Phone  \
# 0        RONA  8565826843
# 1        TORR  7033415000
#
#                                                                                                        USAddress  \
# 0  {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300', 'City': 'BETHLEHEM', 'State': 'PA', 'ZIPCode': '18017'}
# 1                  {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA', 'State': 'VA', 'ZIPCode': '22314'}
#
#   ForeignAddress InCareOfName BusinessName BusinessNameControlTxt PhoneNum  \
# 0           None         None         None                   None     None
# 1           None         None         None                   None     None
#
#   InCareOfNm ForeignPhoneNum  F9_00_HD_ADDR_CHANGE  F9_00_HD_AMENDED_RETURN  \
# 0       None            None                     1                        0
# 1       None            None                     0                        0
#
#   F9_00_HD_CTRY_OF_DOMICILE  F9_00_HD_EXEMPT_STATUS_4847A1  \
# 0                      None                              0
# 1                      None                              0
#
#   F9_00_HD_EXEMPT_STATUS_501C  F9_00_HD_EXEMPT_STATUS_501C3  \
# 0                         NaN                             1
# 1                         NaN                             1
#
#    F9_00_HD_FINAL_RETURN F9_00_HD_GROSS_EXEMPT_NUM F9_00_HD_GROSS_RCPT  \
# 0                      0                      None             1473903
# 1                      0                      1736              266420
#
#    F9_00_HD_GROUP_RETURN  F9_00_HD_INCLUDES_SUBORD_ORGS  \
# 0                      0                              0
# 1                      0                              0
#
#    F9_00_HD_INITIAL_RETURN F9_00_HD_PRIN_OFF_NAME  \
# 0                        0          MICHAEL ANTON
# 1                        0                   None
#
#                                                                                                 F9_00_HD_SIGNING_OFFICER_SIGNTR  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
# 1                                         {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
#
#   F9_00_HD_SPECIAL_CONDITION_DESC F9_00_HD_STATE_OF_DOMICILE  \
# 0                            None                         PA
# 1                            None                         WY
#
#   F9_00_HD_TAX_PER_BEGIN F9_00_HD_TAX_PER_END F9_00_HD_TAX_YEAR  \
# 0             2010-01-01           2010-12-31              2010
# 1             2010-07-01           2011-06-30              2010
#
#          F9_00_HD_TIME_STAMP  F9_00_HD_TYPE_ORG_ASSOCIATION  \
# 0  2011-11-09T06:41:09-06:00                              0
# 1  2011-11-09T07:32:06-08:00                              0
#
#    F9_00_HD_TYPE_ORG_CORP  F9_00_HD_TYPE_ORG_OTHER  \
# 0                       1                        0
# 1                       1                        0
#
#   F9_00_HD_TYPE_ORG_OTHER_DESC  F9_00_HD_TYPE_ORG_TRUST F9_00_HD_WEBSITE  \
# 0                         None                        0              N/A
# 1                         None                        0              N/A
#
#   F9_00_HD_YEAR_FORMED F9_01_PC_BEN_PAID_MEMB_PRIOR  \
# 0                 1992                            0
# 1                 1993                         None
#
#   F9_01_PC_CONTR_GRANTS_CURR F9_01_PC_CONTR_GRANTS_PRIOR  \
# 0                    1439340                     1044925
# 1                          0                        None
#
#   F9_01_PC_GRANTS_PRIOR F9_01_PC_INDEP_VOTING_MEMB  \
# 0                638637                         10
# 1                  None                         13
#
#   F9_01_PC_INVEST_INCOME_PRIOR F9_01_PC_NET_ASSETS_BOY  \
# 0                        30447                 1753405
# 1                         1425                 1437850
#
#   F9_01_PC_OTHER_EXPENSE_PRIOR F9_01_PC_OTHER_REV_PRIOR  \
# 0                       243131                        0
# 1                       189785                     None
#
#   F9_01_PC_PROF_FUNDRISING_EXP_CURR F9_01_PC_PROF_FUNDRISING_EXP_PRIOR  \
# 0                                 0                                  0
# 1                                 0                               None
#
#   F9_01_PC_PROG_SERVICE_REV_PRIOR F9_01_PC_REV_LESS_EXP_CURR  \
# 0                               0                      89152
# 1                          222839                     -39085
#
#   F9_01_PC_REV_LESS_EXP_PRIOR  F9_01_PC_TERMINATION_CONTRACTION  \
# 0                      193604                                 0
# 1                      -36926                                 0
#
#   F9_01_PC_TOT_ASSETS_EOY F9_01_PC_TOT_EXP_PRIOR F9_01_PC_TOT_FNDR_EXP_CURR  \
# 0                 2440859                 881768                     195892
# 1                 1433342                 261190                          0
#
#   F9_01_PC_TOT_INDIV_EMPLOYED F9_01_PC_TOT_INDIV_VOLUNTEERS  \
# 0                           0                             0
# 1                           0                          None
#
#   F9_01_PC_TOT_LIABILITIES_EOY F9_01_PC_TOT_REVENUE_PRIOR  \
# 0                       450430                    1075372
# 1                        34577                     224264
#
#   F9_01_PC_TOT_UBI_GROSS F9_01_PC_TOT_UBI_NET F9_01_PC_VOTING_MEMB_GOV_BODY  \
# 0                      0                    0                            10
# 1                      0                 None                            19
#
#   F9_01_PZ_BEN_PAID_TO_MEMB_CURR F9_01_PZ_GRANTS_PAID_CURR  \
# 0                              0                    925000
# 1                              0                         0
#
#   F9_01_PZ_INVEST_INCOME_CURR F9_01_PZ_NAFB_EOY  \
# 0                       33563           1990429
# 1                         828           1398765
#
#                                                                                                                  F9_01_PZ_ORGANIZATIONAL_MISSION  \
# 0                                                       MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
# 1  PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   F9_01_PZ_OTHER_EXPENSE_CURR F9_01_PZ_OTHER_REV_CURR  \
# 0                      459751                    1000
# 1                      222550                       0
#
#   F9_01_PZ_PROG_SERVICE_REV_CURR F9_01_PZ_SALARIES_CURR  \
# 0                              0                      0
# 1                         265592                  82955
#
#   F9_01_PZ_SALARIES_PRIOR F9_01_PZ_TOT_ASSETS_BOY F9_01_PZ_TOT_EXP_CURR  \
# 0                       0                 1925215               1384751
# 1                   71405                 1455332                305505
#
#   F9_01_PZ_TOT_LIAB_BOY F9_01_PZ_TOT_REV_CURR  F9_03_PC_PGMSVC_SIGNIF_CHG  \
# 0                171810               1473903                           0
# 1                 17482                266420                           0
#
#    F9_03_PC_PGMSVC_SIGNIF_NEW F9_03_PC_PROG_SVC_ACC_1_CODE  \
# 0                           0                         None
# 1                           0                         None
#
#                                                                                                                                                                                                                                 F9_03_PC_PROG_SVC_ACC_1_DESC  \
# 0  RMHC OF THE PHILADELPHIA REGION, INC. GRANTS HUNDREDS OF THOUSANDS OF DOLLARS PER YEAR TO SUPPORT NON-PROFIT PROGRAMS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN. LOCALLY, RMHC SUPPORTS THE PHILADELPHIA, SOUTHERN NEW JERSEY AND DE...
# 1                                                                                                              PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   F9_03_PC_PROG_SVC_ACC_1_EXP F9_03_PC_PROG_SVC_ACC_1_GRNT  \
# 0                     1043744                       925000
# 1                      276405                         None
#
#   F9_03_PC_PROG_SVC_ACC_1_REV F9_03_PC_PROG_SVC_ACC_2_CODE  \
# 0                        None                         None
# 1                      266420                         None
#
#   F9_03_PC_PROG_SVC_ACC_2_DESC F9_03_PC_PROG_SVC_ACC_2_EXP  \
# 0                         None                        None
# 1                         None                        None
#
#   F9_03_PC_PROG_SVC_ACC_2_GRNT F9_03_PC_PROG_SVC_ACC_2_REV  \
# 0                         None                        None
# 1                         None                        None
#
#   F9_03_PC_PROG_SVC_ACC_3_CODE F9_03_PC_PROG_SVC_ACC_3_DESC  \
# 0                         None                         None
# 1                         None                         None
#
#   F9_03_PC_PROG_SVC_ACC_3_EXP F9_03_PC_PROG_SVC_ACC_3_GRNT  \
# 0                        None                         None
# 1                        None                         None
#
#   F9_03_PC_PROG_SVC_ACC_3_REV F9_03_PC_TOT_OTH_PROG_SVC_EXP  \
# 0                        None                          None
# 1                        None                          None
#
#   F9_03_PC_TOT_OTH_PROG_SVC_GRNT F9_03_PC_TOT_OTH_PROG_SVC_REV  \
# 0                           None                          None
# 1                           None                          None
#
#   F9_03_PC_TOT_PROG_SVC_EXPENSE  \
# 0                       1043744
# 1                        276405
#
#                                                                                                                                                                                                                                 F9_03_PZ_MISSION_DESCRIPTION  \
# 0  THE CORPORATION IS ORGANIZED AND WILL BE OPERATED EXCLUSIVELY FOR CHARITABLE, EDUCATIONAL AND SCIENTIFIC PURPOSES WITHIN THE MEANING OF SECTION 501(C)(3) OF THE INTERNAL REVENUE CODE. SUCH PURPOSES SHALL BE LIMITED TO PROVIDING SUPPORT AND FUNDIN...
# 1                                                                                                              PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#    F9_03_PZ_SCHEDULE_O_PART3  F9_04_PC_ACTVITIES_VIA_PARTNER  \
# 0                          1                               0
# 1                          0                               0
#
#    F9_04_PC_CONTROLLED_ENTITY  F9_04_PC_DISREGARDED_ENTITY  \
# 0                           0                            0
# 1                           0                            1
#
#    F9_04_PC_EXCESS_BENEFIT_TRANS  F9_04_PC_FR_EVENT_INC_GT_15K  \
# 0                              0                             0
# 1                              0                             0
#
#    F9_04_PC_GAMING_INC_GT_15K  F9_04_PC_LOBBYING_ACTIVITIES  \
# 0                           0                             0
# 1                           0                             0
#
#    F9_04_PC_POLITICAL_ACTIVITIES  F9_04_PC_PRIOR_EXCESS_BEN_TRAN  \
# 0                              0                               0
# 1                              0                               0
#
#    F9_04_PC_PROF_FR_EXP_GT_15K  F9_04_PC_RELATED_ENTITY  \
# 0                            0                        0
# 1                            0                        1
#
#    F9_04_PC_TRANS_TO_CNTRLD_ENT  F9_04_PC_TRANS_WITH_CNTRLD_ENT  \
# 0                             0                               0
# 1                             0                               0
#
#    F9_05_EXP_SCHED_O_X F9_05_PC_NUMBER_EMPLOYEES_W3  \
# 0                    0                            0
# 1                    0                            0
#
#   F9_05_PC_NUMBER_FORMS_1096  F9_05_PC_UNRELATED_BUS_INCOME  \
# 0                          0                              0
# 1                          0                              0
#
#    F9_06_EXP_SCHED_O_X  F9_06_PC_990_PROVIDED_GOV_BODY  \
# 0                    1                               1
# 1                    1                               1
#
#    F9_06_PC_ANNUAL_DISC_COVRD_PERS  F9_06_PC_CEO_COMPENSTN_PROCESS  \
# 0                                1                               0
# 1                                1                               1
#
#    F9_06_PC_CHANGES_ORGANIZING_DOCS  F9_06_PC_CONFLICT_OF_INTEREST  \
# 0                                 0                              1
# 1                                 0                              1
#
#    F9_06_PC_DECISIONS_SUBJ_APPROVAL  F9_06_PC_DELEGATION_MGT_DUTIES  \
# 0                                 0                               0
# 1                                 1                               1
#
#    F9_06_PC_DELEGATION_OF_MGT  F9_06_PC_DOCUMENT_RET_POLICY  \
# 0                           0                             0
# 1                           1                             0
#
#    F9_06_PC_ELECTION_BOARD_MEMBERS  F9_06_PC_FAMILY_OR_BUSINESS_REL  \
# 0                                0                                0
# 1                                1                                1
#
#    F9_06_PC_FORM_AVAIL_OWN_WEBSITE  F9_06_PC_FORM_UPON_REQUEST  \
# 0                                0                           1
# 1                                0                           1
#
#    F9_06_PC_JOINT_VENTURE_INVESTMNT  F9_06_PC_JOINT_VENTURE_POLICY  \
# 0                                 0                              0
# 1                                 0                              0
#
#    F9_06_PC_LOCAL_CHAPTERS  F9_06_PC_MATERIAL_DIVERSION  \
# 0                        0                            0
# 1                        0                            0
#
#    F9_06_PC_MEMBERS_OR_STOCKHOLDERS  F9_06_PC_MINUTES_COMMITTEES  \
# 0                                 0                            1
# 1                                 0                            1
#
#    F9_06_PC_MINUTES_GOVERNING_BODY  F9_06_PC_MONITORING_OF_COI_POLICY  \
# 0                                1                                  1
# 1                                1                                  1
#
#   F9_06_PC_NUM_IND_VOTING_MEMBERS F9_06_PC_NUM_VOTING_GOV_MEMBERS  \
# 0                              10                              10
# 1                              13                              19
#
#    F9_06_PC_OFFICER_MAILING_ADDRESS  F9_06_PC_OTHER_COMPENSTN_PROCESS  \
# 0                                 0                                 0
# 1                                 0                                 1
#
#    F9_06_PC_OTHER_WEBSITE  F9_06_PC_OWN_WEBSITE  \
# 0                       0                     0
# 1                       0                     0
#
#    F9_06_PC_POLICIES_GOVERN_CHAPTER F9_06_PC_STATES_WHERE_RET_FILED  \
# 0                                 0              ["PA", "NJ", "DE"]
# 1                                 0                            None
#
#    F9_06_PC_WHISTLEBLOWER_POLICY  F9_07_EXP_SCHED_O_X  \
# 0                              0                    0
# 1                              0                    0
#
#    F9_07_PC_COMPENSATION_OTHER_SRCE  F9_07_PC_FORMER_OFFICER_LISTED  \
# 0                                 0                               0
# 1                                 0                               1
#
#    F9_07_PC_NO_LISTED_PERS_COMPENSD F9_07_PC_NUM_CONTRCTRS_GRTR_100K  \
# 0                                 1                                0
# 1                                 0                                0
#
#   F9_07_PC_NUM_INDS_GREATER_100K  F9_07_PC_TOTAL_COMP_GRTR_150K  \
# 0                              0                              0
# 1                              0                              1
#
#   F9_07_PC_TOT_OTHER_COMPENSATION F9_07_PC_TOT_REPRT_COMP_FROM_ORG  \
# 0                               0                                0
# 1                          411648                             None
#
#   F9_07_PC_TOT_REPRT_COMP_RLTD_ORG  F9_08_EXP_SCHED_O_X  \
# 0                                0                    0
# 1                          1180355                    0
#
#   F9_08_PC_ALL_OTHER_CONTRIBUTIONS F9_08_PC_CONTS_REPRTD_FNDRAISNG  \
# 0                          1439340                            None
# 1                             None                            None
#
#   F9_08_PC_COST_OF_GOODS_SOLD F9_08_PC_FEDERATED_CAMPAIGNS  \
# 0                        None                         None
# 1                        None                         None
#
#   F9_08_PC_FUNDRAISING_DIRECT_EXP F9_08_PC_FUNDRAISING_EVENTS  \
# 0                            None                        None
# 1                            None                        None
#
#   F9_08_PC_FUNDRAISING_GROSS_INC F9_08_PC_GAMING_DIRECT_EXPENSES  \
# 0                           None                            None
# 1                           None                            None
#
#   F9_08_PC_GAMING_GROSS_INCOME F9_08_PC_GOVERNMENT_GRANTS  \
# 0                         None                       None
# 1                         None                       None
#
#   F9_08_PC_GROSS_SALES_INVENTORY F9_08_PC_MEMBERSHIP_DUES  \
# 0                           None                     None
# 1                           None                     None
#
#   F9_08_PC_NONCASH_CONTRIBUTIONS F9_08_PC_PROGRAM_SVCE_REV_TOTAL  \
# 0                           None                            None
# 1                           None                          265592
#
#   F9_08_PC_RELATED_ORGANIZATIONS F9_08_PC_TOTAL_CONTRIBUTIONS  \
# 0                           None                      1439340
# 1                           None                            0
#
#   F9_08_PC_TOTAL_OTHER_REVENUE F9_08_PC_TOTAL_PROG_SVCE_REVENUE  \
# 0                         1000                             None
# 1                            0                           265592
#
#                                                                                                                     F9_08_PC_TOTAL_REVENUE  \
# 0  {"TotalRevenueColumn": "1473903", "RelatedOrExemptFunctionIncome": "1000", "UnrelatedBusinessRevenue": "0", "ExclusionAmount": "33563"}
# 1                                                              {"TotalRevenueColumn": "266420", "RelatedOrExemptFunctionIncome": "266420"}
#
#                          F9_09_EXP_AD_PROMO_TOT F9_09_EXP_BENF_PAID_MEMB_TOT  \
# 0                                          None                         None
# 1  {"Total": "8433", "ProgramServices": "8433"}               {"Total": "0"}
#
#                    F9_09_EXP_CONF_MEETING_TOT  \
# 0                                        None
# 1  {"Total": "806", "ProgramServices": "806"}
#
#                                 F9_09_EXP_DEPREC_FUNDR  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
# 1       {"Total": "66166", "ProgramServices": "66166"}
#
#                                   F9_09_EXP_DEPREC_MAG  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
# 1       {"Total": "66166", "ProgramServices": "66166"}
#
#                                  F9_09_EXP_DEPREC_PROG  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
# 1       {"Total": "66166", "ProgramServices": "66166"}
#
#                                   F9_09_EXP_DEPREC_TOT  \
# 0  {"Total": "86228", "ManagementAndGeneral": "86228"}
# 1       {"Total": "66166", "ProgramServices": "66166"}
#
#   F9_09_EXP_GRANT_FRGN_TOT                 F9_09_EXP_GRANT_INDIV_DMSTC_TOT  \
# 0                     None  {"Total": "33000", "ProgramServices": "33000"}
# 1           {"Total": "0"}                                  {"Total": "0"}
#
#                       F9_09_EXP_GRANT_ORG_DMSTC_TOT F9_09_EXP_INFO_TECH_TOT  \
# 0  {"Total": "892000", "ProgramServices": "892000"}                    None
# 1                                    {"Total": "0"}          {"Total": "0"}
#
#                         F9_09_EXP_INSURANCE_TOT F9_09_EXP_INTEREST_TOT  \
# 0                                          None                   None
# 1  {"Total": "1108", "ProgramServices": "1108"}         {"Total": "0"}
#
#   F9_09_EXP_JOINT_COSTS_TOT                         F9_09_EXP_OCCUPANCY_TOT  \
# 0                      None                                            None
# 1                      None  {"Total": "44077", "ProgramServices": "44077"}
#
#                               F9_09_EXP_OFFICE_TOT  \
# 0  {"Total": "123", "ManagementAndGeneral": "123"}
# 1   {"Total": "14222", "ProgramServices": "14222"}
#
#                              F9_09_EXP_OTH_OTH_TOT  \
# 0  {"Total": "763", "ManagementAndGeneral": "763"}
# 1                                   {"Total": "0"}
#
#                                                                                                                                                                                                                                            F9_09_EXP_OTH_TOT  \
# 0  [{"Description": "FUNDRAISING COSTS", "Total": "108311", "Fundraising": "108311"}, {"Description": "CANISTER COLLECTION FEE", "Total": "81925", "Fundraising": "81925"}, {"Description": "PR/ADMINISTRATIVE SERVI", "Total": "34517", "ManagementAndGe...
# 1                [{"Description": "OPER. & MAINT.", "Total": "46164", "ProgramServices": "46164"}, {"Description": "MISC TAXES", "Total": "298", "ProgramServices": "298"}, {"Description": "ADMINISTRATIVE", "Total": "12176", "ProgramServices": "12176"}]
#
#   F9_09_EXP_ROY_TOT  F9_09_EXP_SCHED_O_X F9_09_EXP_TRAVEL_ENTRTNMNT_TOT  \
# 0              None                    0                           None
# 1    {"Total": "0"}                    0                 {"Total": "0"}
#
#   F9_09_EXP_TRAVEL_TOT F9_09_PC_COMP_DISQUAL_FUNDRAISE  \
# 0                 None                            None
# 1       {"Total": "0"}                  {"Total": "0"}
#
#   F9_09_PC_COMP_DISQUAL_MGMT F9_09_PC_COMP_DISQUAL_PROG_SVCE  \
# 0                       None                            None
# 1             {"Total": "0"}                  {"Total": "0"}
#
#   F9_09_PC_COMP_DISQUAL_TOTAL F9_09_PC_COMP_OFFICERS_FUNDRAISE  \
# 0                        None                             None
# 1              {"Total": "0"}                   {"Total": "0"}
#
#   F9_09_PC_COMP_OFFICERS_MGMT F9_09_PC_COMP_OFFICERS_PROG_SVCE  \
# 0                        None                             None
# 1              {"Total": "0"}                   {"Total": "0"}
#
#   F9_09_PC_COMP_OFFICERS_TOTAL  \
# 0                         None
# 1               {"Total": "0"}
#
#                        F9_09_PC_FEES_FOR_SVCE_ACCT_TOT  \
# 0  {"Total": "21675", "ManagementAndGeneral": "21675"}
# 1    {"Total": "7500", "ManagementAndGeneral": "7500"}
#
#   F9_09_PC_FEES_FOR_SVCE_INVST_TOT  \
# 0                             None
# 1                   {"Total": "0"}
#
#                    F9_09_PC_FEES_FOR_SVCE_LEGL_TOT  \
# 0  {"Total": "215", "ManagementAndGeneral": "215"}
# 1                                   {"Total": "0"}
#
#   F9_09_PC_FEES_FOR_SVCE_LOBB_TOT  \
# 0                            None
# 1                  {"Total": "0"}
#
#                        F9_09_PC_FEES_FOR_SVCE_MGMT_TOT  \
# 0                                                 None
# 1  {"Total": "21600", "ManagementAndGeneral": "21600"}
#
#   F9_09_PC_FEES_FOR_SVCE_OTH_TOT  \
# 0                           None
# 1                 {"Total": "0"}
#
#                  F9_09_PC_OTHER_EMP_BEN_FUNDRAISE  \
# 0                                            None
# 1  {"Total": "17714", "ProgramServices": "17714"}
#
#                       F9_09_PC_OTHER_EMP_BEN_MGMT  \
# 0                                            None
# 1  {"Total": "17714", "ProgramServices": "17714"}
#
#                  F9_09_PC_OTHER_EMP_BEN_PROG_SVCE  \
# 0                                            None
# 1  {"Total": "17714", "ProgramServices": "17714"}
#
#                      F9_09_PC_OTHER_EMP_BEN_TOTAL  \
# 0                                            None
# 1  {"Total": "17714", "ProgramServices": "17714"}
#
#                   F9_09_PC_OTHER_SALARY_FUNDRAISE  \
# 0                                            None
# 1  {"Total": "59440", "ProgramServices": "59440"}
#
#                        F9_09_PC_OTHER_SALARY_MGMT  \
# 0                                            None
# 1  {"Total": "59440", "ProgramServices": "59440"}
#
#                   F9_09_PC_OTHER_SALARY_PROG_SVCE  \
# 0                                            None
# 1  {"Total": "59440", "ProgramServices": "59440"}
#
#                       F9_09_PC_OTHER_SALARY_TOTAL  \
# 0                                            None
# 1  {"Total": "59440", "ProgramServices": "59440"}
#
#                      F9_09_PC_PAYMENT_TO_AFFILIATES  \
# 0  {"Total": "118744", "ProgramServices": "118744"}
# 1                                    {"Total": "0"}
#
#                  F9_09_PC_PAYROLL_TAX_FUNDRAISE  \
# 0                                          None
# 1  {"Total": "5801", "ProgramServices": "5801"}
#
#                       F9_09_PC_PAYROLL_TAX_MGMT  \
# 0                                          None
# 1  {"Total": "5801", "ProgramServices": "5801"}
#
#                  F9_09_PC_PAYROLL_TAX_PROG_SVCE  \
# 0                                          None
# 1  {"Total": "5801", "ProgramServices": "5801"}
#
#                      F9_09_PC_PAYROLL_TAX_TOTAL  \
# 0                                          None
# 1  {"Total": "5801", "ProgramServices": "5801"}
#
#   F9_09_PC_PENSION_CONT_FUNDRAISE F9_09_PC_PENSION_CONT_MGMT  \
# 0                            None                       None
# 1                  {"Total": "0"}             {"Total": "0"}
#
#   F9_09_PC_PENSION_CONT_PROG_SVCE F9_09_PC_PENSION_CONT_TOTAL  \
# 0                            None                        None
# 1                  {"Total": "0"}              {"Total": "0"}
#
#                                                                                     F9_09_PC_TOTAL_FUNC_EXPENSES  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
# 1          {"Total": "305505", "ProgramServices": "276405", "ManagementAndGeneral": "29100", "Fundraising": "0"}
#
#                                                                                 F9_09_PC_TOTAL_FUNDRAISE_EXPENSE  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
# 1          {"Total": "305505", "ProgramServices": "276405", "ManagementAndGeneral": "29100", "Fundraising": "0"}
#
#                                                                                      F9_09_PC_TOTAL_MGMT_EXPENSE  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
# 1          {"Total": "305505", "ProgramServices": "276405", "ManagementAndGeneral": "29100", "Fundraising": "0"}
#
#                                                                                 F9_09_PC_TOTAL_PROG_SVCE_EXPENSE  \
# 0  {"Total": "1384751", "ProgramServices": "1043744", "ManagementAndGeneral": "145115", "Fundraising": "195892"}
# 1          {"Total": "305505", "ProgramServices": "276405", "ManagementAndGeneral": "29100", "Fundraising": "0"}
#
#              F9_10_ASSETS_ACC_NET_EOY    F9_10_ASSETS_EXP_PREPAID_EOY  \
# 0  {"BOY": "103412", "EOY": "147981"}                            None
# 1        {"BOY": "231", "EOY": "474"}  {"BOY": "7628", "EOY": "7554"}
#
#   F9_10_ASSETS_INTANGIB_EOY F9_10_ASSETS_INVENT_SALE_EOY  \
# 0                      None                         None
# 1              {"EOY": "0"}                 {"EOY": "0"}
#
#            F9_10_ASSETS_LESS_DEPREC_EOY F9_10_ASSETS_LOANS_DISQUAL_EOY  \
# 0         {"BOY": "0", "EOY": "170617"}                           None
# 1  {"BOY": "1306860", "EOY": "1282874"}                   {"EOY": "0"}
#
#   F9_10_ASSETS_NOTES_LOANS_NET_EOY              F9_10_ASSETS_OTH_EOY  \
# 0                             None                              None
# 1                     {"EOY": "0"}  {"BOY": "14383", "EOY": "17385"}
#
#   F9_10_ASSETS_PLEDGES_NET_EOY        F9_10_LIAB_ACC_PAYABLE_EOY  \
# 0                         None  {"BOY": "39670", "EOY": "44353"}
# 1                 {"EOY": "0"}   {"BOY": "2040", "EOY": "16145"}
#
#        F9_10_LIAB_GRANTS_PAYABLE_EOY F9_10_LIAB_LOANS_OFF_EOY  \
# 0  {"BOY": "80500", "EOY": "166000"}                     None
# 1                               None                     None
#
#   F9_10_LIAB_REV_DEFERRED_EOY F9_10_NAFB_RESTRICT_PERM_EOY  \
# 0                        None                         None
# 1  {"BOY": "20", "EOY": "48"}                         None
#
#   F9_10_NAFB_RESTRICT_TEMP_EOY             F9_10_NAFB_UNRESTRICT_EOY  \
# 0                         None  {"BOY": "1753405", "EOY": "1990429"}
# 1                         None  {"BOY": "1437850", "EOY": "1398765"}
#
#   F9_10_PC_BOND_LIABILITY_EOY  F9_10_PC_CASH_NON_INTEREST_BOY  \
# 0                        None                            None
# 1                        None  {"BOY": "250", "EOY": "22261"}
#
#    F9_10_PC_CASH_NON_INTEREST_EOY F9_10_PC_ESCROW_LIABILITY_EOY  \
# 0                            None                          None
# 1  {"BOY": "250", "EOY": "22261"}                          None
#
#           F9_10_PC_INVEST_OTHER_SEC_EOY F9_10_PC_INVEST_PROG_RELTD_EOY  \
# 0  {"BOY": "1489143", "EOY": "1851561"}                           None
# 1    {"BOY": "125980", "EOY": "102794"}                   {"EOY": "0"}
#
#   F9_10_PC_INVEST_PUB_TRADED_EOY F9_10_PC_LAND_BLDG_EQPMT  \
# 0                           None                   256845
# 1                   {"EOY": "0"}                  2187206
#
#   F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN F9_10_PC_LOANS_FROM_OFFICERS_EOY  \
# 0                            86228                             None
# 1                           904332                             None
#
#    F9_10_PC_ORG_FOLLOWS_SFAS117  F9_10_PC_ORG_NOT_FOLLOW_SFAS117  \
# 0                             1                                0
# 1                             1                                0
#
#       F9_10_PC_OTHER_LIABILITIES_EOY F9_10_PC_RET_EARNINGS_ENDWMT_EOY  \
# 0  {"BOY": "51640", "EOY": "240077"}                             None
# 1    {"BOY": "9203", "EOY": "11349"}                             None
#
#      F9_10_PC_SAVINGS_TEMP_INVEST_BOY    F9_10_PC_SAVINGS_TEMP_INVEST_EOY  \
# 0  {"BOY": "332660", "EOY": "270700"}  {"BOY": "332660", "EOY": "270700"}
# 1                        {"EOY": "0"}                        {"EOY": "0"}
#
#    F9_10_PC_SECURED_MORTGAGES_EOY  F9_10_PC_SECURE_MORT_NOTES_EOY  \
# 0                            None                            None
# 1  {"BOY": "6219", "EOY": "7035"}  {"BOY": "6219", "EOY": "7035"}
#
#   F9_10_PC_UNSECURED_LOANS_EOY F9_10_PC_UNSECURED_NOTES_BOY  \
# 0                         None                         None
# 1                         None                         None
#
#   F9_10_PC_UNSECURED_NOTES_EOY             F9_10_PZ_TOTAL_ASSETS_EOY  \
# 0                         None  {"BOY": "1925215", "EOY": "2440859"}
# 1                         None  {"BOY": "1455332", "EOY": "1433342"}
#
#    F9_10_SCHED_O_X F9_11_PC_RECNCLTN_DONATED_SVCES  \
# 0                0                            None
# 1                0                            None
#
#   F9_11_PC_RECNCLTN_INVSTMNT_EXP F9_11_PC_RECNCLTN_PRIOR_PER_ADJ  \
# 0                           None                            None
# 1                           None                            None
#
#   F9_11_PC_RECNCLTN_REV_LESS_EXP F9_11_PC_RECNCLTN_UNRLZD_GAIN  \
# 0                          89152                          None
# 1                         -39085                          None
#
#    F9_11_SCHED_O_X  F9_12_PC_ACCNT_COMPILE_OR_REVIEW  \
# 0                1                                 0
# 1                0                                 0
#
#    F9_12_PC_ACCTG_METHOD_ACCRUAL  F9_12_PC_ACCTG_METHOD_CASH  \
# 0                              1                           0
# 1                              1                           0
#
#   F9_12_PC_ACCTG_METHOD_OTHER  F9_12_PC_AUDIT_COMMITTEE  \
# 0                         NaN                         1
# 1                         NaN                         1
#
#    F9_12_PC_FED_GRNT_AUDIT_PERFORMD  F9_12_PC_FED_GRNT_AUDIT_REQUIRED  \
# 0                                 0                                 0
# 1                                 1                                 1
#
#    F9_12_PC_FINCL_STMTS_AUDITED  F9_12_SCHED_O_X number_of_other_prog_svces  \
# 0                             1                1                       None
# 1                             1                0                       None
#
#    501c3
# 0      1
# 1      1

# %% [markdown]
# ##### Verify

# %%
print(len(df.columns.tolist()))
# Out:
# 300

# %% [markdown]
# <br>Below we are seeing whether there are any columns in *df* that are not in *new_variables_df*. All 7 columns are the expected 'identfier' columns so there are no issues here.
#
# As an aside, the *df.columns.tolist( )* command will produce a list of all the column names. The *set* command does two things: 1) it creates a type of list of all *unique* values in a list and 2) it allowsd for 'set' operations, such as *union*, *intersection*, and (as below) *difference*.

# %%
set(df.columns.tolist()) - set(new_variables_df['variable_name_new'].tolist())
# Out:
# {'501c3',
#  'BusinessName',
#  'BusinessNameControlTxt',
#  'DLN',
#  'EIN',
#  'ForeignAddress',
#  'ForeignPhoneNum',
#  'InCareOfName',
#  'InCareOfNm',
#  'Name',
#  'NameControl',
#  'OrganizationName',
#  'Phone',
#  'PhoneNum',
#  'URL',
#  'USAddress',
#  '_id',
#  'fiscal_year'}

# %% [markdown]
# <br>Now we will check whether there are any columns in *new_variables_df* that are not in *df*. There are a few address-related columns -- but we will deal with these in a later notebook.

# %%
set(new_variables_df['variable_name_new'].tolist()) - set(df.columns.tolist())
# Out:
# {'F9_00_HD_FILER_ADDR_US_L1',
#  'F9_00_HD_FILER_ADDR_US_L2',
#  'F9_00_HD_FILER_CITY_US',
#  'F9_00_HD_FILER_COUNTRY_FRGN',
#  'F9_00_HD_FILER_STATE_US',
#  'F9_00_HD_FILER_ZIP_US'}

# %% [markdown]
# ##### Save DF

# %%
import psutil

def check_memory_status(threshold=85):
    mem = psutil.virtual_memory()
    print(f"🧠 RAM Usage: {mem.percent}% ({mem.used / 1e9:.2f} GB / {mem.total / 1e9:.2f} GB)")
    if mem.percent >= threshold:
        print("⚠️  Warning: RAM usage is high. Consider restarting the kernel before saving.")
    else:
        print("✅ Good to go!")

# %%
# Step 1: Check RAM before saving
check_memory_status()
# Out:
# 🧠 RAM Usage: 48.8% (99.84 GB / 204.69 GB)
# ✅ Good to go!

# %%
def prepare_for_save(df):
    import gc

    # Drop any cached views
    df = df.copy()  # Break reference to any partial evaluation from .head(), etc.

    # Optionally sort or reset if needed
    # df = df.sort_values("some_column")  # Only if relevant
    # df = df.reset_index(drop=True)

    # Trigger garbage collection
    gc.collect()

    print("🧼 DataFrame copied + garbage collected. Ready to save.")
    return df

# %%
# Step 2: Clean up df (especially if you’ve been doing .head(), .sort(), etc.)
df = prepare_for_save(df)

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df.to_feather('D:/all_filings_april_2025_all_controls_combined.feather')
# Out:
# Current date and time :  2025-04-17 00:39:12
#
# CPU times: total: 2min 43s
# Wall time: 2min

# %%
# %%time
df.to_parquet("D:/all_filings_april_2025_all_controls_combined.parquet", engine="pyarrow", compression="snappy", index=False)
# Out:
# CPU times: total: 3min 6s
# Wall time: 3min 13s

# %%
#Use HDF5 format (handles mixed types better than feather):
#ImportError: Missing optional dependency 'pytables'.  Use pip or conda to install pytables.
#df.to_hdf('D:/all_filings_april_2025_all_controls.h5', key='df')

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df.to_pickle('D:/all_filings_april_2025_all_controls_combined.pkl.gz', compression='gzip')
# Out:
# Current date and time :  2025-04-17 00:47:45
#
# CPU times: total: 42min 18s
# Wall time: 42min 40s

# %% [markdown]
# <br>Now we're done with this step. In the next notebook we'll parse variables that have complex 'nested' structures.
