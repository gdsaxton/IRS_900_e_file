# %% [markdown]
# # Overview - Identify and Remove Duplicates
#
# `4/20/2025` update of the notebook. I have done enough verifications in the past that I am going to do an abbreviated version of the code here
#
# This was originally an update of this notebook:
# - *IRS Form 990 e-File Data (8a) -- Identify and Drop Duplicate Org-Year Filings*
#
# Notes 4/20/2025
# ```python
# - df['direct_donations'] = df['F9_08_PC_TOTAL_CONTRIBUTIONS']-df['F9_08_PC_FEDERATED_CAMPAIGNS'] -df['F9_08_PC_GOVERNMENT_GRANTS']
# ```

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from pandas import Series

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
from platform import python_version
print(python_version())
# Out:
# 3.10.11

# %%
# http://pandas.pydata.org/pandas-docs/stable/options.html
pd.set_option('display.max_columns', None)
# http://pandas.pydata.org/pandas-docs/stable/options.html
pd.set_option('display.max_colwidth', 4000)

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
pd.options.display.float_format = '{:,.1f}'.format

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)

# %%
import datetime
import gc

# %% [markdown]
# #### Set working directory

# %%
cd "C:\\Users\\Gregory\\IRS 990 Control Variables\\"
# Out:
# C:\Users\Gregory\IRS 990 Control Variables

# %% [markdown]
# # Read in PANDAS DF

# %%
#%%time
#import datetime
#print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
#df = pd.read_pickle('990 and BMF control variables for all NEW filings February 2024 -- 277,112 501c3 orgs (N=664,761).pkl.gz', compression='gzip')
#print('# of columns:', len(df.columns))
#print('# of observations:', len(df))
#df[:1]
# Out:
# Current date and time :  2024-06-16 14:51:11
#
# # of columns: 340
# # of observations: 664761
# CPU times: total: 2min 33s
# Wall time: 2min 46s
#                                                                         URL  \
# 812471  https://s3.amazonaws.com/irs-form-990/202323189349305317_public.xml
#
#         F9_09_PC_FEES_FOR_SVCE_FR_TOT F9_00_HD_BUILD_TIME_STAMP fiscal_year  \
# 812471                            0.0 2023-04-26 12:10:37+00:00        2022
#
#               EIN                                            BusinessName  \
# 812471  010017496  {'BusinessNameLine1Txt': 'AGAMENTICUS YACHT CLUB INC'}
#
#        BusinessNameControlTxt    PhoneNum  \
# 812471                   AGAM  2073638510
#
#                                                                                                         USAddress  \
# 812471  {'AddressLine1Txt': 'PO BOX 534', 'CityNm': 'YORK HARBOR', 'StateAbbreviationCd': 'ME', 'ZIPCd': '03911'}
#
# ...

# %%
# %%time
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df = pd.read_feather('D:/990_and_bmf_april_2025_all_controls_351875_orgs_2633270_filings.feather')
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
df[:1]
# Out:
# Current date and time :  2025-04-20 19:40:56
#
# # of columns: 356
# # of observations: 2633270
# CPU times: total: 57.2 s
# Wall time: 33.9 s
#                               _id OrganizationName  \
# 3016720  65c1a1d52a9ba8ce45342904             None
#
#                                                                          URL  \
# 3016720  https://s3.amazonaws.com/irs-form-990/202323189349305317_public.xml
#
#           DLN TaxPeriod  F9_09_PC_FEES_FOR_SVCE_FR_TOT  \
# 3016720  None      None                              0
#
#         F9_00_HD_BUILD_TIME_STAMP fiscal_year        EIN  Name NameControl  \
# 3016720 2023-04-26 12:10:37+00:00        2022  010017496  None        None
#
#         Phone  \
# 3016720  None
#
#                                                                                                                                                                                                                             USAddress  \
# ...

# %%
print('# of observations:', len(df))
print('# of unique organizations:', len(set(df['EIN'].tolist())))
print('# of observations that are by 501(c)(3) organizations:', df['501c3'].value_counts())
# Out:
# # of observations: 2633270
# # of unique organizations: 351875
# # of observations that are by 501(c)(3) organizations: 501c3
# 1    2633270
# Name: count, dtype: int64

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# # Select Latest Filing per Org/Year

# %%
df['F9_00_HD_TAX_YEAR'].value_counts().sort_index()
# Out:
# F9_00_HD_TAX_YEAR
# 2009     28392
# 2010     92910
# 2011    120596
# 2012    135811
# 2013    150462
# 2014    165382
# 2015    176852
# 2016    184814
# 2017    193481
# 2018    202483
# 2019    216427
# 2020    242299
# 2021    256105
# 2022    264605
# 2023    200213
# 2024      2438
# Name: count, dtype: Int64

# %%
df.sample(1)
# Out:
#                                                                         URL  \
# 528959  https://s3.amazonaws.com/irs-form-990/202310169349300311_public.xml
#
#         F9_09_PC_FEES_FOR_SVCE_FR_TOT F9_00_HD_BUILD_TIME_STAMP fiscal_year  \
# 528959                           0.00 2023-03-07 01:45:13+00:00        2022
#
#               EIN                                            BusinessName  \
# 528959  376039121  {'BusinessNameLine1Txt': 'Prairieland United Way Inc'}
#
#        BusinessNameControlTxt    PhoneNum  \
# 528959                   PRAI  2172454557
#
#                                                                                                                         USAddress  \
# 528959  {'AddressLine1Txt': '200 W Douglas Ave Box 244', 'CityNm': 'Jacksonville', 'StateAbbreviationCd': 'IL', 'ZIPCd': '62651'}
#
#        InCareOfNm ForeignAddress ForeignPhoneNum  F9_00_HD_ADDR_CHANGE  \
# 528959        NaN            NaN             NaN                  0.00
#
# ...

# %% [markdown]
# #### Create DF with duplicate observations

# %%
# %%time
grouped = df.groupby(['EIN', 'F9_00_HD_TAX_YEAR']).count()
print(len(grouped[grouped['URL']>1]))
print(grouped[grouped['URL']>1]['URL'].value_counts())
grouped = grouped[grouped['URL']>1]
grouped = grouped.reset_index()
grouped = grouped[['EIN', 'F9_00_HD_TAX_YEAR', 'URL']]
grouped.columns = ['EIN', 'F9_00_HD_TAX_YEAR', 'number of org-year duplicates']
print(len(grouped))
grouped[:2]
# Out:
# 33668
# URL
# 2    32664
# 3      899
# 4       90
# 5       14
# 6        1
# Name: count, dtype: int64
# 33668
# CPU times: total: 13.4 s
# Wall time: 14 s
#          EIN  F9_00_HD_TAX_YEAR  number of org-year duplicates
# 0  010211481               2017                              2
# 1  010211486               2015                              2

# %%
# %%time
pd.merge(df, grouped, left_on=['EIN', 'F9_00_HD_TAX_YEAR'], right_on=['EIN', 'F9_00_HD_TAX_YEAR'], how='left', indicator=True)['_merge'].value_counts()
# Out:
# CPU times: total: 22 s
# Wall time: 23.1 s
# _merge
# left_only     2564809
# both            68461
# right_only          0
# Name: count, dtype: int64

# %%
#print((14159*2)+(366*3)+(19*4)+(2*5))
#print(grouped['number of org-year duplicates'].sum())
# Out:
# 29502
# 29502

# %%
# %%time
print('# of observations:', len(df))
print('# of columns:', len(df.columns))
print(len(pd.merge(df, grouped, left_on=['EIN', 'F9_00_HD_TAX_YEAR'], right_on=['EIN', 'F9_00_HD_TAX_YEAR'], how='left', indicator=True)))
df = pd.merge(df, grouped, left_on=['EIN', 'F9_00_HD_TAX_YEAR'], right_on=['EIN', 'F9_00_HD_TAX_YEAR'], how='left', indicator=True)
print(df['_merge'].value_counts())
df = df.drop('_merge', axis=1)
print('# of observations:', len(df))
print('# of columns:', len(df.columns))
df[:1]
# Out:
# # of observations: 2633270
# # of columns: 356
# 2633270
# _merge
# left_only     2564809
# both            68461
# right_only          0
# Name: count, dtype: int64
# # of observations: 2633270
# # of columns: 357
# CPU times: total: 45 s
# Wall time: 46.5 s
#                         _id OrganizationName  \
# 0  65c1a1d52a9ba8ce45342904             None
#
#                                                                    URL   DLN  \
# 0  https://s3.amazonaws.com/irs-form-990/202323189349305317_public.xml  None
#
#   TaxPeriod  F9_09_PC_FEES_FOR_SVCE_FR_TOT F9_00_HD_BUILD_TIME_STAMP  \
# 0      None                              0 2023-04-26 12:10:37+00:00
#
#   fiscal_year        EIN  Name NameControl Phone  \
# 0        2022  010017496  None        None  None
#
# ...

# %% [markdown]
# ### Collapse data for the duplicates, taking the last entry for each org/year row
# This works because we have (as also done earlier) sorted the dataset by tax year and signing officer date

# %%
# %%time
df = df.sort_values(['EIN', 'F9_00_HD_TAX_YEAR', 'F9_00_HD_SIGNING_OFFICER_SIGNTR'])
df[:1]
# Out:
# CPU times: total: 6.58 s
# Wall time: 6.75 s
#                         _id OrganizationName  \
# 0  65c1a1d52a9ba8ce45342904             None
#
#                                                                    URL   DLN  \
# 0  https://s3.amazonaws.com/irs-form-990/202323189349305317_public.xml  None
#
#   TaxPeriod  F9_09_PC_FEES_FOR_SVCE_FR_TOT F9_00_HD_BUILD_TIME_STAMP  \
# 0      None                              0 2023-04-26 12:10:37+00:00
#
#   fiscal_year        EIN  Name NameControl Phone  \
# 0        2022  010017496  None        None  None
#
#                                                                                                                                                                                                                       USAddress  \
# ...

# %%
df[(df['EIN'].isin(dups))&(df['number of org-year duplicates'].notnull())][['URL', 'BMF_ORG_NAME_CURRENT', 'F9_00_HD_TAX_YEAR', 
                          'F9_00_HD_BUILD_TIME_STAMP', 'F9_00_HD_TIME_STAMP', 'F9_00_HD_SIGNING_OFFICER_SIGNTR', 'F9_00_HD_AMENDED_RETURN', 'number of org-year duplicates']][:10]
# Out:
#                                                                      URL  \
# 243  https://s3.amazonaws.com/irs-form-990/201910169349300336_public.xml
# 242  https://s3.amazonaws.com/irs-form-990/201900449349300005_public.xml
# 290  https://s3.amazonaws.com/irs-form-990/201612149349301391_public.xml
# 289  https://s3.amazonaws.com/irs-form-990/201612289349306266_public.xml
# 292  https://s3.amazonaws.com/irs-form-990/202032129349300713_public.xml
# 293  https://s3.amazonaws.com/irs-form-990/202043149349303484_public.xml
# 295  https://s3.amazonaws.com/irs-form-990/202132259349300308_public.xml
# 294  https://s3.amazonaws.com/irs-form-990/202231649349301203_public.xml
# 359  https://s3.amazonaws.com/irs-form-990/201731359349301753_public.xml
# 360  https://s3.amazonaws.com/irs-form-990/201820089349300342_public.xml
#
#                       BMF_ORG_NAME_CURRENT  F9_00_HD_TAX_YEAR  \
# 243                  BANGOR CHILDRENS HOME               2017
# ...

# %%
len(grouped)
# Out:
# 33668

# %%
df['number of org-year duplicates'].value_counts()
# Out:
# number of org-year duplicates
# 2.00    65328
# 3.00     2697
# 4.00      360
# 5.00       70
# 6.00        6
# Name: count, dtype: int64

# %%
df['number of org-year duplicates'].value_counts().sum()
# Out:
# 68461

# %%
df['number of org-year duplicates'].describe()
# Out:
# count   68461.00
# mean        2.05
# std         0.26
# min         2.00
# 25%         2.00
# 50%         2.00
# 75%         2.00
# max         6.00
# Name: number of org-year duplicates, dtype: float64

# %%
print(len(df[df['number of org-year duplicates'].notnull()]))
print(len(set(df[df['number of org-year duplicates'].notnull()]['EIN'].tolist())))
# Out:
# 68461
# 26466

# %%
len(df[(df['EIN'].isin(dups))&(df['number of org-year duplicates'].notnull())])
# Out:
# 68461

# %%
dups = df[df['number of org-year duplicates'].notnull()]['EIN'].tolist()
print(len(dups), len(set(dups)))
# Out:
# 68461 26466

# %% [markdown]
# <br>Of the 68,461 filings with duplicates (for 26,466 unique EINs), there are 33,668 affected *EIN filing/years*.
#
# Note that the code block below takes the `last( )` duplicate. This is why the descriptives for `number of org-year duplicates` are different than they are in `df`
#
# Given that there are 68,461 filings in `df` with a duplicate value, and that of these there are 33,668 'valid' filings, we should expect the final dataset to have 2,598,477 observations.

# %%
#11/14/2021 -- NOT RUN
print(len(df))
print(len(df) - 68461)
print(len(df) - 68461 + 33668)
# Out:
# 2633270
# 2564809
# 2598477

# %%
gc.collect()
# Out:
# 0

# %%
# %%time
df = df.groupby(['EIN', 'F9_00_HD_TAX_YEAR']).last()
print(len(df))
df = df.reset_index()
df[:2]
# Out:
# 2598477
# CPU times: total: 36.4 s
# Wall time: 37.3 s
#          EIN  F9_00_HD_TAX_YEAR                       _id  \
# 0  010017496               2022  65c1a1d52a9ba8ce45342904
# 1  010024645               2009  5d01baf378ffca27b4286d51
#
#             OrganizationName  \
# 0                       None
# 1  BANGOR SYMPHONY ORCHESTRA
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/202323189349305317_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201121379349300422_public.xml
#
#               DLN TaxPeriod  F9_09_PC_FEES_FOR_SVCE_FR_TOT  \
# 0            None      None                              0
# 1  93493137004221    201006                              0
#
#   F9_00_HD_BUILD_TIME_STAMP fiscal_year  \
# 0 2023-04-26 12:10:37+00:00        2022
# 1 2016-02-24 21:20:13+00:00        None
#
#                                                  Name NameControl       Phone  \
# ...

# %% [markdown]
# #### Now inspect dataset

# %%
# %%time
df[(df['EIN'].isin(dups))&(df['number of org-year duplicates']>1)][['URL', 'BMF_ORG_NAME_CURRENT', 'F9_00_HD_TAX_YEAR', 
                          'F9_00_HD_BUILD_TIME_STAMP', 'F9_00_HD_TIME_STAMP', 'F9_00_HD_SIGNING_OFFICER_SIGNTR', 'F9_00_HD_AMENDED_RETURN', 'number of org-year duplicates']][:10]
# Out:
# CPU times: total: 516 ms
# Wall time: 556 ms
#                                                                       URL  \
# 243   https://s3.amazonaws.com/irs-form-990/201900449349300005_public.xml
# 289   https://s3.amazonaws.com/irs-form-990/201612289349306266_public.xml
# 291   https://s3.amazonaws.com/irs-form-990/202043149349303484_public.xml
# 292   https://s3.amazonaws.com/irs-form-990/202231649349301203_public.xml
# 359   https://s3.amazonaws.com/irs-form-990/201820089349300342_public.xml
# 546   https://s3.amazonaws.com/irs-form-990/201922599349301132_public.xml
# 617   https://s3.amazonaws.com/irs-form-990/202332149349300838_public.xml
# 666   https://s3.amazonaws.com/irs-form-990/202140199349300314_public.xml
# 1078  https://s3.amazonaws.com/irs-form-990/201412129349300711_public.xml
# 1178  https://s3.amazonaws.com/irs-form-990/201400439349301280_public.xml
#
#                        BMF_ORG_NAME_CURRENT  F9_00_HD_TAX_YEAR  \
# ...

# %% [markdown]
# #### Look for duplicates again
# There are no more duplicates

# %%
# %%time
grouped = df.groupby(['EIN', 'F9_00_HD_TAX_YEAR']).count()
print(len(grouped[grouped['URL']>1]))
print(grouped[grouped['URL']>1]['URL'].value_counts())
grouped = grouped[grouped['URL']>1]
grouped = grouped.reset_index()
grouped = grouped[['EIN', 'F9_00_HD_TAX_YEAR', 'URL']]
grouped.columns = ['EIN', 'F9_00_HD_TAX_YEAR', 'number of org-year duplicates']
print(len(grouped))
grouped[:2]
# Out:
# 0
# Series([], Name: count, dtype: int64)
# 0
# CPU times: total: 10.5 s
# Wall time: 10.9 s
# Empty DataFrame
# Columns: [EIN, F9_00_HD_TAX_YEAR, number of org-year duplicates]
# Index: []

# %% [markdown]
# #### Create variable that indicates whether there was a duplicate

# %%
df['filing_year_had_duplicate'] = np.where(df['number of org-year duplicates']>0, 1,0)
df['filing_year_had_duplicate'].value_counts()
# Out:
# filing_year_had_duplicate
# 0    2564809
# 1      33668
# Name: count, dtype: int64

# %%
df['number of org-year duplicates'].value_counts()
# Out:
# number of org-year duplicates
# 2.00    32664
# 3.00      899
# 4.00       90
# 5.00       14
# 6.00        1
# Name: count, dtype: int64

# %%
pd.crosstab(df['filing_year_had_duplicate'], df['number of org-year duplicates'])
# Out:
# number of org-year duplicates   2.00  3.00  4.00  5.00  6.00
# filing_year_had_duplicate
# 1                              32664   899    90    14     1

# %%
df = df.drop('number of org-year duplicates', axis=1)

# %% [markdown]
# #### Inspect Data

# %%
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
# Out:
# # of columns: 357
# # of observations: 2598477

# %%
df.sample(1)
# Out:
#                EIN  F9_00_HD_TAX_YEAR                       _id  \
# 1558567  520610545               2019  617c5978b1ca7b56cbd8f4e9
#
#               OrganizationName  \
# 1558567  SUBURBAN HOSPITAL INC
#
#                                                                          URL  \
# 1558567  https://s3.amazonaws.com/irs-form-990/202111339349303186_public.xml
#
#                     DLN TaxPeriod  F9_09_PC_FEES_FOR_SVCE_FR_TOT  \
# 1558567  93493133031861    202006                              0
#
#         F9_00_HD_BUILD_TIME_STAMP fiscal_year  Name NameControl Phone  \
# 1558567 2021-01-29 14:40:06+00:00        2020  None        None  None
#
#                                                                                                                                                                                                                                            USAddress  \
# ...

# %%
print(df.columns.tolist())
# Out:
# ['EIN', 'F9_00_HD_TAX_YEAR', '_id', 'OrganizationName', 'URL', 'DLN', 'TaxPeriod', 'F9_09_PC_FEES_FOR_SVCE_FR_TOT', 'F9_00_HD_BUILD_TIME_STAMP', 'fiscal_year', 'Name', 'NameControl', 'Phone', 'USAddress', 'ForeignAddress', 'InCareOfName', 'BusinessName', 'BusinessNameControlTxt', 'PhoneNum', 'InCareOfNm', 'ForeignPhoneNum', 'F9_00_HD_ADDR_CHANGE', 'F9_00_HD_AMENDED_RETURN', 'F9_00_HD_CTRY_OF_DOMICILE', 'F9_00_HD_EXEMPT_STATUS_4847A1', 'F9_00_HD_EXEMPT_STATUS_501C', 'F9_00_HD_EXEMPT_STATUS_501C3', 'F9_00_HD_FINAL_RETURN', 'F9_00_HD_GROSS_EXEMPT_NUM', 'F9_00_HD_GROSS_RCPT', 'F9_00_HD_GROUP_RETURN', 'F9_00_HD_INCLUDES_SUBORD_ORGS', 'F9_00_HD_INITIAL_RETURN', 'F9_00_HD_PRIN_OFF_NAME', 'F9_00_HD_SIGNING_OFFICER_SIGNTR', 'F9_00_HD_SPECIAL_CONDITION_DESC', 'F9_00_HD_STATE_OF_DOMICILE', 'F9_00_HD_TAX_PER_BEGIN', 'F9_00_HD_TAX_PER_END', 'F9_00_HD_TIME_STAMP', 'F9_00_HD_TYPE_ORG_ASSOCIATION', 'F9_00_HD_TYPE_ORG_CORP', 'F9_00_HD_TYPE_ORG_OTHER', 'F9_00_HD_TYPE_ORG_OTHER_DESC', 'F9_00_HD_TYPE_OR
# ...

# %%
df.describe().T
# Out:
#                                    count    mean       std       min     25%  \
# F9_00_HD_TAX_YEAR             2598477.00 2017.37      3.89   2009.00 2014.00
# F9_09_PC_FEES_FOR_SVCE_FR_TOT 2598477.00 4948.57 158234.29 -35000.00    0.00
# F9_00_HD_ADDR_CHANGE          2598477.00    0.04      0.20      0.00    0.00
# F9_00_HD_AMENDED_RETURN       2598477.00    0.01      0.11      0.00    0.00
# F9_00_HD_EXEMPT_STATUS_4847A1 2598477.00    0.00      0.00      0.00    0.00
# ...                                  ...     ...       ...       ...     ...
# BMF_ORG_YEAR_FIRST            2594238.00 1999.07     10.20   1989.00 1989.00
# BMF_ORG_YEAR_LAST             2594238.00 2023.76      1.21   1989.00 2024.00
# BMF_ORG_YEAR_COUNT            2594238.00   25.68     10.28      1.00   17.00
# BMF_ORG_FISCAL_PERIOD         2594238.00    6.38      3.38      1.00    3.00
# filing_year_had_duplicate     2598477.00    0.01      0.11      0.00    0.00
#
# ...

# %%
df['F9_00_HD_TAX_YEAR'].value_counts().sort_index()
# Out:
# F9_00_HD_TAX_YEAR
# 2009     28060
# 2010     91891
# 2011    119309
# 2012    134445
# 2013    149089
# 2014    163652
# 2015    175038
# 2016    182842
# 2017    191289
# 2018    200139
# 2019    213238
# 2020    237976
# 2021    251105
# 2022    259785
# 2023    198193
# 2024      2426
# Name: count, dtype: Int64

# %%
len(set(df['EIN'].tolist()))
# Out:
# 351875

# %%
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
# Out:
# # of columns: 357
# # of observations: 2598477

# %%
df['501c3'].value_counts()
# Out:
# 501c3
# 1    2598477
# Name: count, dtype: int64

# %%
len(df)
# Out:
# 2598477

# %%
len(set(df['EIN']))
# Out:
# 351875

# %% [markdown]
# #### Save DF

# %%
# %%time
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df.to_feather('D:/990_and_bmf_april_2025_all_controls_351875_orgs_2598477_filings_no_duplicates.feather')
# Out:
# Current date and time :  2025-04-20 19:59:36
#
# CPU times: total: 30.3 s
# Wall time: 25.4 s

# %%
# %%time
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df.to_parquet("D:/990_and_bmf_april_2025_all_controls_351875_orgs_2598477_filings_no_duplicates.parquet", engine="pyarrow", compression="snappy", index=False)
# Out:
# Current date and time :  2025-04-20 20:00:01
#
# CPU times: total: 1min 8s
# Wall time: 1min 7s

# %%
# %%time
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df.to_pickle('990_and_bmf_april_2025_all_controls_351875_orgs_2598477_filings_no_duplicates.pkl.gz', compression='gzip')
# Out:
# Current date and time :  2025-04-20 20:01:09
#
# CPU times: total: 34min 34s
# Wall time: 35min 14s
